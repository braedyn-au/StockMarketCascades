# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_200_7200_100_10_20.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_200_7200_100_10_20.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_200_7200_100_10_20.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_200_7200_100_10_20.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 1   993     yshfc      1   -1.0
# 1                 2   993     yshfc      2   -2.0
# 2                10   993     yshfc     10    1.0
# 3                11   993     yshfc     11    1.0
# 4                13   993     yshfc     13   -1.0
# ...             ...   ...       ...    ...    ...
# 3836251           7  8192     xbcot     35    1.0
# 3836252           9  8192     xbcot     42    1.0
# 3836253           2  8192     jmeyl     76    1.0
# 3836254           3  8192     jmeyl     43   -1.0
# 3836255          16  8192     jmeyl     66   -1.0
#
# [3836256 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades22_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  3836256

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades21_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades12_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5192], traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5192)
with open('../causalCascades/7-9/causalCascades11_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2217038
# Cascade length:  4082
# New Orders left:  2212956
# making new cascade
#
#
# OG Orders left:  2212956
# Cascade length:  2112
# New Orders left:  2210844
# making new cascade
#
#
# OG Orders left:  2210844
# Cascade length:  4045
# New Orders left:  2206799
# making new cascade
#
#
# OG Orders left:  2206799
# Cascade length:  5079
# New Orders left:  2201720
# making new cascade
#
#
# OG Orders left:  2201720
# Cascade length:  4831
# New Orders left:  2196889
# making new cascade
#
#
# OG Orders left:  2196889
# Cascade length:  3216
# New Orders left:  2193673
# making new cascade
#
#
# OG Orders left:  2193673
# Cascade length:  3418
# New Orders left:  2190255
# making new cascade
#
#
# OG Orders left:  2190255
# Cascade length:  4012
# New Orders left:  2186243
# making new cascade
#
#
# OG Orders left:  2186243
# Cascade length:  4104
# New Orders left:  2182139
# making new cascade
#
#
# OG Orders left:  2182139
# Cascade length:  3358
# New Orders left:  2178781
# making new cascade
#
#
# OG Orders left:  2178781
# Cascade length:  3264
# New Orders left:  2175517
# making new cascade
#
#
# OG Orders left:  2175517
# Cascade length:  3368
# New Orders left:  2172149
# making new cascade
#
#
# OG Orders left:  2172149
# Cascade length:  2264
# New Orders left:  2169885
# making new cascade
#
#
# OG Orders left:  2169885
# Cascade length:  4033
# New Orders left:  2165852
# making new cascade
#
#
# OG Orders left:  2165852
# Cascade length:  1424
# New Orders left:  2164428
# making new cascade
#
#
# OG Orders left:  2164428
# Cascade length:  2588
# New Orders left:  2161840
# making new cascade
#
#
# OG Orders left:  2161840
# Cascade length:  4025
# New Orders left:  2157815
# making new cascade
#
#
# OG Orders left:  2157815
# Cascade length:  3423
# New Orders left:  2154392
# making new cascade
#
#
# OG Orders left:  2154392
# Cascade length:  3174
# New Orders left:  2151218
# making new cascade
#
#
# OG Orders left:  2151218
# Cascade length:  2315
# New Orders left:  2148903
# making new cascade
#
#
# OG Orders left:  2148903
# Cascade length:  4353
# New Orders left:  2144550
# making new cascade
#
#
# OG Orders left:  2144550
# Cascade length:  3311
# New Orders left:  2141239
# making new cascade
#
#
# OG Orders left:  2141239
# Cascade length:  3534
# New Orders left:  2137705
# making new cascade
#
#
# OG Orders left:  2137705
# Cascade length:  2321
# New Orders left:  2135384
# making new cascade
#
#
# OG Orders left:  2135384
# Cascade length:  2949
# New Orders left:  2132435
# making new cascade
#
#
# OG Orders left:  2132435
# Cascade length:  3772
# New Orders left:  2128663
# making new cascade
#
#
# OG Orders left:  2128663
# Cascade length:  2095
# New Orders left:  2126568
# making new cascade
#
#
# OG Orders left:  2126568
# Cascade length:  1109
# New Orders left:  2125459
# making new cascade
#
#
# OG Orders left:  2125459
# Cascade length:  2935
# New Orders left:  2122524
# making new cascade
#
#
# OG Orders left:  2122524
# Cascade length:  3589
# New Orders left:  2118935
# making new cascade
#
#
# OG Orders left:  2118935
# Cascade length:  2108
# New Orders left:  2116827
# making new cascade
#
#
# OG Orders left:  2116827
# Cascade length:  1761
# New Orders left:  2115066
# making new cascade
#
#
# OG Orders left:  2115066
# Cascade length:  2816
# New Orders left:  2112250
# making new cascade
#
#
# OG Orders left:  2112250
# Cascade length:  3468
# New Orders left:  2108782
# making new cascade
#
#
# OG Orders left:  2108782
# Cascade length:  2153
# New Orders left:  2106629
# making new cascade
#
#
# OG Orders left:  2106629
# Cascade length:  2549
# New Orders left:  2104080
# making new cascade
#
#
# OG Orders left:  2104080
# Cascade length:  2420
# New Orders left:  2101660
# making new cascade
#
#
# OG Orders left:  2101660
# Cascade length:  1817
# New Orders left:  2099843
# making new cascade
#
#
# OG Orders left:  2099843
# Cascade length:  3653
# New Orders left:  2096190
# making new cascade
#
#
# OG Orders left:  2096190
# Cascade length:  2669
# New Orders left:  2093521
# making new cascade
#
#
# OG Orders left:  2093521
# Cascade length:  2293
# New Orders left:  2091228
# making new cascade
#
#
# OG Orders left:  2091228
# Cascade length:  2397
# New Orders left:  2088831
# making new cascade
#
#
# OG Orders left:  2088831
# Cascade length:  3510
# New Orders left:  2085321
# making new cascade
#
#
# OG Orders left:  2085321
# Cascade length:  2615
# New Orders left:  2082706
# making new cascade
#
#
# OG Orders left:  2082706
# Cascade length:  3437
# New Orders left:  2079269
# making new cascade
#
#
# OG Orders left:  2079269
# Cascade length:  2191
# New Orders left:  2077078
# making new cascade
#
#
# OG Orders left:  2077078
# Cascade length:  2000
# New Orders left:  2075078
# making new cascade
#
#
# OG Orders left:  2075078
# Cascade length:  12
# New Orders left:  2075066
# making new cascade
#
#
# OG Orders left:  2075066
# Cascade length:  2328
# New Orders left:  2072738
# making new cascade
#
#
# OG Orders left:  2072738
# Cascade length:  2675
# New Orders left:  2070063
# making new cascade
#
#
# OG Orders left:  2070063
# Cascade length:  2650
# New Orders left:  2067413
# making new cascade
#
#
# OG Orders left:  2067413
# Cascade length:  1951
# New Orders left:  2065462
# making new cascade
#
#
# OG Orders left:  2065462
# Cascade length:  2926
# New Orders left:  2062536
# making new cascade
#
#
# OG Orders left:  2062536
# Cascade length:  2507
# New Orders left:  2060029
# making new cascade
#
#
# OG Orders left:  2060029
# Cascade length:  2262
# New Orders left:  2057767
# making new cascade
#
#
# OG Orders left:  2057767
# Cascade length:  1864
# New Orders left:  2055903
# making new cascade
#
#
# OG Orders left:  2055903
# Cascade length:  2567
# New Orders left:  2053336
# making new cascade
#
#
# OG Orders left:  2053336
# Cascade length:  1948
# New Orders left:  2051388
# making new cascade
#
#
# OG Orders left:  2051388
# Cascade length:  1985
# New Orders left:  2049403
# making new cascade
#
#
# OG Orders left:  2049403
# Cascade length:  3230
# New Orders left:  2046173
# making new cascade
#
#
# OG Orders left:  2046173
# Cascade length:  2516
# New Orders left:  2043657
# making new cascade
#
#
# OG Orders left:  2043657
# Cascade length:  2111
# New Orders left:  2041546
# making new cascade
#
#
# OG Orders left:  2041546
# Cascade length:  1855
# New Orders left:  2039691
# making new cascade
#
#
# OG Orders left:  2039691
# Cascade length:  2280
# New Orders left:  2037411
# making new cascade
#
#
# OG Orders left:  2037411
# Cascade length:  2093
# New Orders left:  2035318
# making new cascade
#
#
# OG Orders left:  2035318
# Cascade length:  2331
# New Orders left:  2032987
# making new cascade
#
#
# OG Orders left:  2032987
# Cascade length:  2256
# New Orders left:  2030731
# making new cascade
#
#
# OG Orders left:  2030731
# Cascade length:  2056
# New Orders left:  2028675
# making new cascade
#
#
# OG Orders left:  2028675
# Cascade length:  1898
# New Orders left:  2026777
# making new cascade
#
#
# OG Orders left:  2026777
# Cascade length:  1802
# New Orders left:  2024975
# making new cascade
#
#
# OG Orders left:  2024975
# Cascade length:  2137
# New Orders left:  2022838
# making new cascade
#
#
# OG Orders left:  2022838
# Cascade length:  1969
# New Orders left:  2020869
# making new cascade
#
#
# OG Orders left:  2020869
# Cascade length:  2643
# New Orders left:  2018226
# making new cascade
#
#
# OG Orders left:  2018226
# Cascade length:  2483
# New Orders left:  2015743
# making new cascade
#
#
# OG Orders left:  2015743
# Cascade length:  1837
# New Orders left:  2013906
# making new cascade
#
#
# OG Orders left:  2013906
# Cascade length:  2789
# New Orders left:  2011117
# making new cascade
#
#
# OG Orders left:  2011117
# Cascade length:  2387
# New Orders left:  2008730
# making new cascade
#
#
# OG Orders left:  2008730
# Cascade length:  1713
# New Orders left:  2007017
# making new cascade
#
#
# OG Orders left:  2007017
# Cascade length:  1785
# New Orders left:  2005232
# making new cascade
#
#
# OG Orders left:  2005232
# Cascade length:  2307
# New Orders left:  2002925
# making new cascade
#
#
# OG Orders left:  2002925
# Cascade length:  1907
# New Orders left:  2001018
# making new cascade
#
#
# OG Orders left:  2001018
# Cascade length:  2507
# New Orders left:  1998511
# making new cascade
#
#
# OG Orders left:  1998511
# Cascade length:  2679
# New Orders left:  1995832
# making new cascade
#
#
# OG Orders left:  1995832
# Cascade length:  1884
# New Orders left:  1993948
# making new cascade
#
#
# OG Orders left:  1993948
# Cascade length:  1804
# New Orders left:  1992144
# making new cascade
#
#
# OG Orders left:  1992144
# Cascade length:  2516
# New Orders left:  1989628
# making new cascade
#
#
# OG Orders left:  1989628
# Cascade length:  1531
# New Orders left:  1988097
# making new cascade
#
#
# OG Orders left:  1988097
# Cascade length:  2800
# New Orders left:  1985297
# making new cascade
#
#
# OG Orders left:  1985297
# Cascade length:  2419
# New Orders left:  1982878
# making new cascade
#
#
# OG Orders left:  1982878
# Cascade length:  1873
# New Orders left:  1981005
# making new cascade
#
#
# OG Orders left:  1981005
# Cascade length:  2666
# New Orders left:  1978339
# making new cascade
#
#
# OG Orders left:  1978339
# Cascade length:  2187
# New Orders left:  1976152
# making new cascade
#
#
# OG Orders left:  1976152
# Cascade length:  334
# New Orders left:  1975818
# making new cascade
#
#
# OG Orders left:  1975818
# Cascade length:  2075
# New Orders left:  1973743
# making new cascade
#
#
# OG Orders left:  1973743
# Cascade length:  876
# New Orders left:  1972867
# making new cascade
#
#
# OG Orders left:  1972867
# Cascade length:  2230
# New Orders left:  1970637
# making new cascade
#
#
# OG Orders left:  1970637
# Cascade length:  1496
# New Orders left:  1969141
# making new cascade
#
#
# OG Orders left:  1969141
# Cascade length:  2329
# New Orders left:  1966812
# making new cascade
#
#
# OG Orders left:  1966812
# Cascade length:  1762
# New Orders left:  1965050
# making new cascade
#
#
# OG Orders left:  1965050
# Cascade length:  2560
# New Orders left:  1962490
# making new cascade
#
#
# OG Orders left:  1962490
# Cascade length:  2296
# New Orders left:  1960194
# making new cascade
#
#
# OG Orders left:  1960194
# Cascade length:  1708
# New Orders left:  1958486
# making new cascade
#
#
# OG Orders left:  1958486
# Cascade length:  1690
# New Orders left:  1956796
# making new cascade
#
#
# OG Orders left:  1956796
# Cascade length:  1757
# New Orders left:  1955039
# making new cascade
#
#
# OG Orders left:  1955039
# Cascade length:  1886
# New Orders left:  1953153
# making new cascade
#
#
# OG Orders left:  1953153
# Cascade length:  1595
# New Orders left:  1951558
# making new cascade
#
#
# OG Orders left:  1951558
# Cascade length:  1806
# New Orders left:  1949752
# making new cascade
#
#
# OG Orders left:  1949752
# Cascade length:  1475
# New Orders left:  1948277
# making new cascade
#
#
# OG Orders left:  1948277
# Cascade length:  2010
# New Orders left:  1946267
# making new cascade
#
#
# OG Orders left:  1946267
# Cascade length:  1778
# New Orders left:  1944489
# making new cascade
#
#
# OG Orders left:  1944489
# Cascade length:  1650
# New Orders left:  1942839
# making new cascade
#
#
# OG Orders left:  1942839
# Cascade length:  1483
# New Orders left:  1941356
# making new cascade
#
#
# OG Orders left:  1941356
# Cascade length:  2042
# New Orders left:  1939314
# making new cascade
#
#
# OG Orders left:  1939314
# Cascade length:  1454
# New Orders left:  1937860
# making new cascade
#
#
# OG Orders left:  1937860
# Cascade length:  1888
# New Orders left:  1935972
# making new cascade
#
#
# OG Orders left:  1935972
# Cascade length:  1982
# New Orders left:  1933990
# making new cascade
#
#
# OG Orders left:  1933990
# Cascade length:  1475
# New Orders left:  1932515
# making new cascade
#
#
# OG Orders left:  1932515
# Cascade length:  1525
# New Orders left:  1930990
# making new cascade
#
#
# OG Orders left:  1930990
# Cascade length:  1997
# New Orders left:  1928993
# making new cascade
#
#
# OG Orders left:  1928993
# Cascade length:  1724
# New Orders left:  1927269
# making new cascade
#
#
# OG Orders left:  1927269
# Cascade length:  1300
# New Orders left:  1925969
# making new cascade
#
#
# OG Orders left:  1925969
# Cascade length:  1706
# New Orders left:  1924263
# making new cascade
#
#
# OG Orders left:  1924263
# Cascade length:  1765
# New Orders left:  1922498
# making new cascade
#
#
# OG Orders left:  1922498
# Cascade length:  1874
# New Orders left:  1920624
# making new cascade
#
#
# OG Orders left:  1920624
# Cascade length:  1694
# New Orders left:  1918930
# making new cascade
#
#
# OG Orders left:  1918930
# Cascade length:  2119
# New Orders left:  1916811
# making new cascade
#
#
# OG Orders left:  1916811
# Cascade length:  1498
# New Orders left:  1915313
# making new cascade
#
#
# OG Orders left:  1915313
# Cascade length:  2097
# New Orders left:  1913216
# making new cascade
#
#
# OG Orders left:  1913216
# Cascade length:  2041
# New Orders left:  1911175
# making new cascade
#
#
# OG Orders left:  1911175
# Cascade length:  1873
# New Orders left:  1909302
# making new cascade
#
#
# OG Orders left:  1909302
# Cascade length:  1476
# New Orders left:  1907826
# making new cascade
#
#
# OG Orders left:  1907826
# Cascade length:  1214
# New Orders left:  1906612
# making new cascade
#
#
# OG Orders left:  1906612
# Cascade length:  2237
# New Orders left:  1904375
# making new cascade
#
#
# OG Orders left:  1904375
# Cascade length:  1551
# New Orders left:  1902824
# making new cascade
#
#
# OG Orders left:  1902824
# Cascade length:  1712
# New Orders left:  1901112
# making new cascade
#
#
# OG Orders left:  1901112
# Cascade length:  1624
# New Orders left:  1899488
# making new cascade
#
#
# OG Orders left:  1899488
# Cascade length:  2074
# New Orders left:  1897414
# making new cascade
#
#
# OG Orders left:  1897414
# Cascade length:  2171
# New Orders left:  1895243
# making new cascade
#
#
# OG Orders left:  1895243
# Cascade length:  1430
# New Orders left:  1893813
# making new cascade
#
#
# OG Orders left:  1893813
# Cascade length:  1603
# New Orders left:  1892210
# making new cascade
#
#
# OG Orders left:  1892210
# Cascade length:  1745
# New Orders left:  1890465
# making new cascade
#
#
# OG Orders left:  1890465
# Cascade length:  1108
# New Orders left:  1889357
# making new cascade
#
#
# OG Orders left:  1889357
# Cascade length:  1184
# New Orders left:  1888173
# making new cascade
#
#
# OG Orders left:  1888173
# Cascade length:  1381
# New Orders left:  1886792
# making new cascade
#
#
# OG Orders left:  1886792
# Cascade length:  1558
# New Orders left:  1885234
# making new cascade
#
#
# OG Orders left:  1885234
# Cascade length:  1021
# New Orders left:  1884213
# making new cascade
#
#
# OG Orders left:  1884213
# Cascade length:  1420
# New Orders left:  1882793
# making new cascade
#
#
# OG Orders left:  1882793
# Cascade length:  4
# New Orders left:  1882789
# making new cascade
#
#
# OG Orders left:  1882789
# Cascade length:  1324
# New Orders left:  1881465
# making new cascade
#
#
# OG Orders left:  1881465
# Cascade length:  1912
# New Orders left:  1879553
# making new cascade
#
#
# OG Orders left:  1879553
# Cascade length:  1080
# New Orders left:  1878473
# making new cascade
#
#
# OG Orders left:  1878473
# Cascade length:  2512
# New Orders left:  1875961
# making new cascade
#
#
# OG Orders left:  1875961
# Cascade length:  1361
# New Orders left:  1874600
# making new cascade
#
#
# OG Orders left:  1874600
# Cascade length:  1283
# New Orders left:  1873317
# making new cascade
#
#
# OG Orders left:  1873317
# Cascade length:  1433
# New Orders left:  1871884
# making new cascade
#
#
# OG Orders left:  1871884
# Cascade length:  930
# New Orders left:  1870954
# making new cascade
#
#
# OG Orders left:  1870954
# Cascade length:  1990
# New Orders left:  1868964
# making new cascade
#
#
# OG Orders left:  1868964
# Cascade length:  1748
# New Orders left:  1867216
# making new cascade
#
#
# OG Orders left:  1867216
# Cascade length:  1399
# New Orders left:  1865817
# making new cascade
#
#
# OG Orders left:  1865817
# Cascade length:  1776
# New Orders left:  1864041
# making new cascade
#
#
# OG Orders left:  1864041
# Cascade length:  1296
# New Orders left:  1862745
# making new cascade
#
#
# OG Orders left:  1862745
# Cascade length:  1707
# New Orders left:  1861038
# making new cascade
#
#
# OG Orders left:  1861038
# Cascade length:  1831
# New Orders left:  1859207
# making new cascade
#
#
# OG Orders left:  1859207
# Cascade length:  1798
# New Orders left:  1857409
# making new cascade
#
#
# OG Orders left:  1857409
# Cascade length:  1941
# New Orders left:  1855468
# making new cascade
#
#
# OG Orders left:  1855468
# Cascade length:  4
# New Orders left:  1855464
# making new cascade
#
#
# OG Orders left:  1855464
# Cascade length:  1693
# New Orders left:  1853771
# making new cascade
#
#
# OG Orders left:  1853771
# Cascade length:  923
# New Orders left:  1852848
# making new cascade
#
#
# OG Orders left:  1852848
# Cascade length:  1900
# New Orders left:  1850948
# making new cascade
#
#
# OG Orders left:  1850948
# Cascade length:  1620
# New Orders left:  1849328
# making new cascade
#
#
# OG Orders left:  1849328
# Cascade length:  1740
# New Orders left:  1847588
# making new cascade
#
#
# OG Orders left:  1847588
# Cascade length:  1544
# New Orders left:  1846044
# making new cascade
#
#
# OG Orders left:  1846044
# Cascade length:  1732
# New Orders left:  1844312
# making new cascade
#
#
# OG Orders left:  1844312
# Cascade length:  1408
# New Orders left:  1842904
# making new cascade
#
#
# OG Orders left:  1842904
# Cascade length:  2
# New Orders left:  1842902
# making new cascade
#
#
# OG Orders left:  1842902
# Cascade length:  1521
# New Orders left:  1841381
# making new cascade
#
#
# OG Orders left:  1841381
# Cascade length:  1686
# New Orders left:  1839695
# making new cascade
#
#
# OG Orders left:  1839695
# Cascade length:  1465
# New Orders left:  1838230
# making new cascade
#
#
# OG Orders left:  1838230
# Cascade length:  1055
# New Orders left:  1837175
# making new cascade
#
#
# OG Orders left:  1837175
# Cascade length:  1924
# New Orders left:  1835251
# making new cascade
#
#
# OG Orders left:  1835251
# Cascade length:  1438
# New Orders left:  1833813
# making new cascade
#
#
# OG Orders left:  1833813
# Cascade length:  1725
# New Orders left:  1832088
# making new cascade
#
#
# OG Orders left:  1832088
# Cascade length:  1737
# New Orders left:  1830351
# making new cascade
#
#
# OG Orders left:  1830351
# Cascade length:  1565
# New Orders left:  1828786
# making new cascade
#
#
# OG Orders left:  1828786
# Cascade length:  1963
# New Orders left:  1826823
# making new cascade
#
#
# OG Orders left:  1826823
# Cascade length:  719
# New Orders left:  1826104
# making new cascade
#
#
# OG Orders left:  1826104
# Cascade length:  1910
# New Orders left:  1824194
# making new cascade
#
#
# OG Orders left:  1824194
# Cascade length:  1846
# New Orders left:  1822348
# making new cascade
#
#
# OG Orders left:  1822348
# Cascade length:  1165
# New Orders left:  1821183
# making new cascade
#
#
# OG Orders left:  1821183
# Cascade length:  2544
# New Orders left:  1818639
# making new cascade
#
#
# OG Orders left:  1818639
# Cascade length:  2144
# New Orders left:  1816495
# making new cascade
#
#
# OG Orders left:  1816495
# Cascade length:  1568
# New Orders left:  1814927
# making new cascade
#
#
# OG Orders left:  1814927
# Cascade length:  1818
# New Orders left:  1813109
# making new cascade
#
#
# OG Orders left:  1813109
# Cascade length:  1616
# New Orders left:  1811493
# making new cascade
#
#
# OG Orders left:  1811493
# Cascade length:  1541
# New Orders left:  1809952
# making new cascade
#
#
# OG Orders left:  1809952
# Cascade length:  1486
# New Orders left:  1808466
# making new cascade
#
#
# OG Orders left:  1808466
# Cascade length:  1769
# New Orders left:  1806697
# making new cascade
#
#
# OG Orders left:  1806697
# Cascade length:  1338
# New Orders left:  1805359
# making new cascade
#
#
# OG Orders left:  1805359
# Cascade length:  1610
# New Orders left:  1803749
# making new cascade
#
#
# OG Orders left:  1803749
# Cascade length:  1
# New Orders left:  1803748
# making new cascade
#
#
# OG Orders left:  1803748
# Cascade length:  1404
# New Orders left:  1802344
# making new cascade
#
#
# OG Orders left:  1802344
# Cascade length:  1914
# New Orders left:  1800430
# making new cascade
#
#
# OG Orders left:  1800430
# Cascade length:  1947
# New Orders left:  1798483
# making new cascade
#
#
# OG Orders left:  1798483
# Cascade length:  1130
# New Orders left:  1797353
# making new cascade
#
#
# OG Orders left:  1797353
# Cascade length:  1739
# New Orders left:  1795614
# making new cascade
#
#
# OG Orders left:  1795614
# Cascade length:  1458
# New Orders left:  1794156
# making new cascade
#
#
# OG Orders left:  1794156
# Cascade length:  1520
# New Orders left:  1792636
# making new cascade
#
#
# OG Orders left:  1792636
# Cascade length:  1640
# New Orders left:  1790996
# making new cascade
#
#
# OG Orders left:  1790996
# Cascade length:  1867
# New Orders left:  1789129
# making new cascade
#
#
# OG Orders left:  1789129
# Cascade length:  1646
# New Orders left:  1787483
# making new cascade
#
#
# OG Orders left:  1787483
# Cascade length:  1347
# New Orders left:  1786136
# making new cascade
#
#
# OG Orders left:  1786136
# Cascade length:  1431
# New Orders left:  1784705
# making new cascade
#
#
# OG Orders left:  1784705
# Cascade length:  1799
# New Orders left:  1782906
# making new cascade
#
#
# OG Orders left:  1782906
# Cascade length:  1802
# New Orders left:  1781104
# making new cascade
#
#
# OG Orders left:  1781104
# Cascade length:  1673
# New Orders left:  1779431
# making new cascade
#
#
# OG Orders left:  1779431
# Cascade length:  1369
# New Orders left:  1778062
# making new cascade
#
#
# OG Orders left:  1778062
# Cascade length:  1417
# New Orders left:  1776645
# making new cascade
#
#
# OG Orders left:  1776645
# Cascade length:  2583
# New Orders left:  1774062
# making new cascade
#
#
# OG Orders left:  1774062
# Cascade length:  1798
# New Orders left:  1772264
# making new cascade
#
#
# OG Orders left:  1772264
# Cascade length:  1565
# New Orders left:  1770699
# making new cascade
#
#
# OG Orders left:  1770699
# Cascade length:  2
# New Orders left:  1770697
# making new cascade
#
#
# OG Orders left:  1770697
# Cascade length:  1785
# New Orders left:  1768912
# making new cascade
#
#
# OG Orders left:  1768912
# Cascade length:  38
# New Orders left:  1768874
# making new cascade
#
#
# OG Orders left:  1768874
# Cascade length:  2881
# New Orders left:  1765993
# making new cascade
#
#
# OG Orders left:  1765993
# Cascade length:  2010
# New Orders left:  1763983
# making new cascade
#
#
# OG Orders left:  1763983
# Cascade length:  1867
# New Orders left:  1762116
# making new cascade
#
#
# OG Orders left:  1762116
# Cascade length:  2702
# New Orders left:  1759414
# making new cascade
#
#
# OG Orders left:  1759414
# Cascade length:  1378
# New Orders left:  1758036
# making new cascade
#
#
# OG Orders left:  1758036
# Cascade length:  1689
# New Orders left:  1756347
# making new cascade
#
#
# OG Orders left:  1756347
# Cascade length:  2385
# New Orders left:  1753962
# making new cascade
#
#
# OG Orders left:  1753962
# Cascade length:  1702
# New Orders left:  1752260
# making new cascade
#
#
# OG Orders left:  1752260
# Cascade length:  2159
# New Orders left:  1750101
# making new cascade
#
#
# OG Orders left:  1750101
# Cascade length:  1813
# New Orders left:  1748288
# making new cascade
#
#
# OG Orders left:  1748288
# Cascade length:  1964
# New Orders left:  1746324
# making new cascade
#
#
# OG Orders left:  1746324
# Cascade length:  1935
# New Orders left:  1744389
# making new cascade
#
#
# OG Orders left:  1744389
# Cascade length:  3146
# New Orders left:  1741243
# making new cascade
#
#
# OG Orders left:  1741243
# Cascade length:  2615
# New Orders left:  1738628
# making new cascade
#
#
# OG Orders left:  1738628
# Cascade length:  2297
# New Orders left:  1736331
# making new cascade
#
#
# OG Orders left:  1736331
# Cascade length:  1930
# New Orders left:  1734401
# making new cascade
#
#
# OG Orders left:  1734401
# Cascade length:  2150
# New Orders left:  1732251
# making new cascade
#
#
# OG Orders left:  1732251
# Cascade length:  1699
# New Orders left:  1730552
# making new cascade
#
#
# OG Orders left:  1730552
# Cascade length:  1
# New Orders left:  1730551
# making new cascade
#
#
# OG Orders left:  1730551
# Cascade length:  29
# New Orders left:  1730522
# making new cascade
#
#
# OG Orders left:  1730522
# Cascade length:  2726
# New Orders left:  1727796
# making new cascade
#
#
# OG Orders left:  1727796
# Cascade length:  2396
# New Orders left:  1725400
# making new cascade
#
#
# OG Orders left:  1725400
# Cascade length:  1852
# New Orders left:  1723548
# making new cascade
#
#
# OG Orders left:  1723548
# Cascade length:  1782
# New Orders left:  1721766
# making new cascade
#
#
# OG Orders left:  1721766
# Cascade length:  2031
# New Orders left:  1719735
# making new cascade
#
#
# OG Orders left:  1719735
# Cascade length:  1955
# New Orders left:  1717780
# making new cascade
#
#
# OG Orders left:  1717780
# Cascade length:  1888
# New Orders left:  1715892
# making new cascade
#
#
# OG Orders left:  1715892
# Cascade length:  2456
# New Orders left:  1713436
# making new cascade
#
#
# OG Orders left:  1713436
# Cascade length:  1752
# New Orders left:  1711684
# making new cascade
#
#
# OG Orders left:  1711684
# Cascade length:  2035
# New Orders left:  1709649
# making new cascade
#
#
# OG Orders left:  1709649
# Cascade length:  1715
# New Orders left:  1707934
# making new cascade
#
#
# OG Orders left:  1707934
# Cascade length:  1956
# New Orders left:  1705978
# making new cascade
#
#
# OG Orders left:  1705978
# Cascade length:  2938
# New Orders left:  1703040
# making new cascade
#
#
# OG Orders left:  1703040
# Cascade length:  1927
# New Orders left:  1701113
# making new cascade
#
#
# OG Orders left:  1701113
# Cascade length:  1844
# New Orders left:  1699269
# making new cascade
#
#
# OG Orders left:  1699269
# Cascade length:  2621
# New Orders left:  1696648
# making new cascade
#
#
# OG Orders left:  1696648
# Cascade length:  2411
# New Orders left:  1694237
# making new cascade
#
#
# OG Orders left:  1694237
# Cascade length:  965
# New Orders left:  1693272
# making new cascade
#
#
# OG Orders left:  1693272
# Cascade length:  1430
# New Orders left:  1691842
# making new cascade
#
#
# OG Orders left:  1691842
# Cascade length:  1495
# New Orders left:  1690347
# making new cascade
#
#
# OG Orders left:  1690347
# Cascade length:  2003
# New Orders left:  1688344
# making new cascade
#
#
# OG Orders left:  1688344
# Cascade length:  2474
# New Orders left:  1685870
# making new cascade
#
#
# OG Orders left:  1685870
# Cascade length:  2121
# New Orders left:  1683749
# making new cascade
#
#
# OG Orders left:  1683749
# Cascade length:  2162
# New Orders left:  1681587
# making new cascade
#
#
# OG Orders left:  1681587
# Cascade length:  1916
# New Orders left:  1679671
# making new cascade
#
#
# OG Orders left:  1679671
# Cascade length:  2300
# New Orders left:  1677371
# making new cascade
#
#
# OG Orders left:  1677371
# Cascade length:  2348
# New Orders left:  1675023
# making new cascade
#
#
# OG Orders left:  1675023
# Cascade length:  2611
# New Orders left:  1672412
# making new cascade
#
#
# OG Orders left:  1672412
# Cascade length:  2147
# New Orders left:  1670265
# making new cascade
#
#
# OG Orders left:  1670265
# Cascade length:  2454
# New Orders left:  1667811
# making new cascade
#
#
# OG Orders left:  1667811
# Cascade length:  2150
# New Orders left:  1665661
# making new cascade
#
#
# OG Orders left:  1665661
# Cascade length:  1686
# New Orders left:  1663975
# making new cascade
#
#
# OG Orders left:  1663975
# Cascade length:  1920
# New Orders left:  1662055
# making new cascade
#
#
# OG Orders left:  1662055
# Cascade length:  1835
# New Orders left:  1660220
# making new cascade
#
#
# OG Orders left:  1660220
# Cascade length:  1471
# New Orders left:  1658749
# making new cascade
#
#
# OG Orders left:  1658749
# Cascade length:  2410
# New Orders left:  1656339
# making new cascade
#
#
# OG Orders left:  1656339
# Cascade length:  2381
# New Orders left:  1653958
# making new cascade
#
#
# OG Orders left:  1653958
# Cascade length:  1631
# New Orders left:  1652327
# making new cascade
#
#
# OG Orders left:  1652327
# Cascade length:  2996
# New Orders left:  1649331
# making new cascade
#
#
# OG Orders left:  1649331
# Cascade length:  2533
# New Orders left:  1646798
# making new cascade
#
#
# OG Orders left:  1646798
# Cascade length:  2360
# New Orders left:  1644438
# making new cascade
#
#
# OG Orders left:  1644438
# Cascade length:  851
# New Orders left:  1643587
# making new cascade
#
#
# OG Orders left:  1643587
# Cascade length:  1451
# New Orders left:  1642136
# making new cascade
#
#
# OG Orders left:  1642136
# Cascade length:  2233
# New Orders left:  1639903
# making new cascade
#
#
# OG Orders left:  1639903
# Cascade length:  2243
# New Orders left:  1637660
# making new cascade
#
#
# OG Orders left:  1637660
# Cascade length:  1970
# New Orders left:  1635690
# making new cascade
#
#
# OG Orders left:  1635690
# Cascade length:  2919
# New Orders left:  1632771
# making new cascade
#
#
# OG Orders left:  1632771
# Cascade length:  1757
# New Orders left:  1631014
# making new cascade
#
#
# OG Orders left:  1631014
# Cascade length:  2424
# New Orders left:  1628590
# making new cascade
#
#
# OG Orders left:  1628590
# Cascade length:  2062
# New Orders left:  1626528
# making new cascade
#
#
# OG Orders left:  1626528
# Cascade length:  2029
# New Orders left:  1624499
# making new cascade
#
#
# OG Orders left:  1624499
# Cascade length:  1780
# New Orders left:  1622719
# making new cascade
#
#
# OG Orders left:  1622719
# Cascade length:  2754
# New Orders left:  1619965
# making new cascade
#
#
# OG Orders left:  1619965
# Cascade length:  2023
# New Orders left:  1617942
# making new cascade
#
#
# OG Orders left:  1617942
# Cascade length:  2034
# New Orders left:  1615908
# making new cascade
#
#
# OG Orders left:  1615908
# Cascade length:  2263
# New Orders left:  1613645
# making new cascade
#
#
# OG Orders left:  1613645
# Cascade length:  1757
# New Orders left:  1611888
# making new cascade
#
#
# OG Orders left:  1611888
# Cascade length:  1481
# New Orders left:  1610407
# making new cascade
#
#
# OG Orders left:  1610407
# Cascade length:  2006
# New Orders left:  1608401
# making new cascade
#
#
# OG Orders left:  1608401
# Cascade length:  2049
# New Orders left:  1606352
# making new cascade
#
#
# OG Orders left:  1606352
# Cascade length:  3034
# New Orders left:  1603318
# making new cascade
#
#
# OG Orders left:  1603318
# Cascade length:  1835
# New Orders left:  1601483
# making new cascade
#
#
# OG Orders left:  1601483
# Cascade length:  3264
# New Orders left:  1598219
# making new cascade
#
#
# OG Orders left:  1598219
# Cascade length:  2315
# New Orders left:  1595904
# making new cascade
#
#
# OG Orders left:  1595904
# Cascade length:  2016
# New Orders left:  1593888
# making new cascade
#
#
# OG Orders left:  1593888
# Cascade length:  1696
# New Orders left:  1592192
# making new cascade
#
#
# OG Orders left:  1592192
# Cascade length:  2079
# New Orders left:  1590113
# making new cascade
#
#
# OG Orders left:  1590113
# Cascade length:  1225
# New Orders left:  1588888
# making new cascade
#
#
# OG Orders left:  1588888
# Cascade length:  2883
# New Orders left:  1586005
# making new cascade
#
#
# OG Orders left:  1586005
# Cascade length:  2395
# New Orders left:  1583610
# making new cascade
#
#
# OG Orders left:  1583610
# Cascade length:  1993
# New Orders left:  1581617
# making new cascade
#
#
# OG Orders left:  1581617
# Cascade length:  1547
# New Orders left:  1580070
# making new cascade
#
#
# OG Orders left:  1580070
# Cascade length:  2020
# New Orders left:  1578050
# making new cascade
#
#
# OG Orders left:  1578050
# Cascade length:  2363
# New Orders left:  1575687
# making new cascade
#
#
# OG Orders left:  1575687
# Cascade length:  2976
# New Orders left:  1572711
# making new cascade
#
#
# OG Orders left:  1572711
# Cascade length:  2666
# New Orders left:  1570045
# making new cascade
#
#
# OG Orders left:  1570045
# Cascade length:  1620
# New Orders left:  1568425
# making new cascade
#
#
# OG Orders left:  1568425
# Cascade length:  1535
# New Orders left:  1566890
# making new cascade
#
#
# OG Orders left:  1566890
# Cascade length:  1905
# New Orders left:  1564985
# making new cascade
#
#
# OG Orders left:  1564985
# Cascade length:  2312
# New Orders left:  1562673
# making new cascade
#
#
# OG Orders left:  1562673
# Cascade length:  478
# New Orders left:  1562195
# making new cascade
#
#
# OG Orders left:  1562195
# Cascade length:  22
# New Orders left:  1562173
# making new cascade
#
#
# OG Orders left:  1562173
# Cascade length:  1551
# New Orders left:  1560622
# making new cascade
#
#
# OG Orders left:  1560622
# Cascade length:  1541
# New Orders left:  1559081
# making new cascade
#
#
# OG Orders left:  1559081
# Cascade length:  2054
# New Orders left:  1557027
# making new cascade
#
#
# OG Orders left:  1557027
# Cascade length:  17
# New Orders left:  1557010
# making new cascade
#
#
# OG Orders left:  1557010
# Cascade length:  2164
# New Orders left:  1554846
# making new cascade
#
#
# OG Orders left:  1554846
# Cascade length:  1703
# New Orders left:  1553143
# making new cascade
#
#
# OG Orders left:  1553143
# Cascade length:  1612
# New Orders left:  1551531
# making new cascade
#
#
# OG Orders left:  1551531
# Cascade length:  1131
# New Orders left:  1550400
# making new cascade
#
#
# OG Orders left:  1550400
# Cascade length:  1954
# New Orders left:  1548446
# making new cascade
#
#
# OG Orders left:  1548446
# Cascade length:  2256
# New Orders left:  1546190
# making new cascade
#
#
# OG Orders left:  1546190
# Cascade length:  2085
# New Orders left:  1544105
# making new cascade
#
#
# OG Orders left:  1544105
# Cascade length:  1697
# New Orders left:  1542408
# making new cascade
#
#
# OG Orders left:  1542408
# Cascade length:  2482
# New Orders left:  1539926
# making new cascade
#
#
# OG Orders left:  1539926
# Cascade length:  1468
# New Orders left:  1538458
# making new cascade
#
#
# OG Orders left:  1538458
# Cascade length:  1933
# New Orders left:  1536525
# making new cascade
#
#
# OG Orders left:  1536525
# Cascade length:  1502
# New Orders left:  1535023
# making new cascade
#
#
# OG Orders left:  1535023
# Cascade length:  2971
# New Orders left:  1532052
# making new cascade
#
#
# OG Orders left:  1532052
# Cascade length:  1935
# New Orders left:  1530117
# making new cascade
#
#
# OG Orders left:  1530117
# Cascade length:  1
# New Orders left:  1530116
# making new cascade
#
#
# OG Orders left:  1530116
# Cascade length:  1908
# New Orders left:  1528208
# making new cascade
#
#
# OG Orders left:  1528208
# Cascade length:  1805
# New Orders left:  1526403
# making new cascade
#
#
# OG Orders left:  1526403
# Cascade length:  2045
# New Orders left:  1524358
# making new cascade
#
#
# OG Orders left:  1524358
# Cascade length:  2195
# New Orders left:  1522163
# making new cascade
#
#
# OG Orders left:  1522163
# Cascade length:  1871
# New Orders left:  1520292
# making new cascade
#
#
# OG Orders left:  1520292
# Cascade length:  1648
# New Orders left:  1518644
# making new cascade
#
#
# OG Orders left:  1518644
# Cascade length:  1
# New Orders left:  1518643
# making new cascade
#
#
# OG Orders left:  1518643
# Cascade length:  1901
# New Orders left:  1516742
# making new cascade
#
#
# OG Orders left:  1516742
# Cascade length:  3
# New Orders left:  1516739
# making new cascade
#
#
# OG Orders left:  1516739
# Cascade length:  1
# New Orders left:  1516738
# making new cascade
#
#
# OG Orders left:  1516738
# Cascade length:  1994
# New Orders left:  1514744
# making new cascade
#
#
# OG Orders left:  1514744
# Cascade length:  2130
# New Orders left:  1512614
# making new cascade
#
#
# OG Orders left:  1512614
# Cascade length:  1616
# New Orders left:  1510998
# making new cascade
#
#
# OG Orders left:  1510998
# Cascade length:  1829
# New Orders left:  1509169
# making new cascade
#
#
# OG Orders left:  1509169
# Cascade length:  1979
# New Orders left:  1507190
# making new cascade
#
#
# OG Orders left:  1507190
# Cascade length:  2729
# New Orders left:  1504461
# making new cascade
#
#
# OG Orders left:  1504461
# Cascade length:  1808
# New Orders left:  1502653
# making new cascade
#
#
# OG Orders left:  1502653
# Cascade length:  2085
# New Orders left:  1500568
# making new cascade
#
#
# OG Orders left:  1500568
# Cascade length:  2485
# New Orders left:  1498083
# making new cascade
#
#
# OG Orders left:  1498083
# Cascade length:  2683
# New Orders left:  1495400
# making new cascade
#
#
# OG Orders left:  1495400
# Cascade length:  1492
# New Orders left:  1493908
# making new cascade
#
#
# OG Orders left:  1493908
# Cascade length:  2038
# New Orders left:  1491870
# making new cascade
#
#
# OG Orders left:  1491870
# Cascade length:  2793
# New Orders left:  1489077
# making new cascade
#
#
# OG Orders left:  1489077
# Cascade length:  2391
# New Orders left:  1486686
# making new cascade
#
#
# OG Orders left:  1486686
# Cascade length:  2083
# New Orders left:  1484603
# making new cascade
#
#
# OG Orders left:  1484603
# Cascade length:  1848
# New Orders left:  1482755
# making new cascade
#
#
# OG Orders left:  1482755
# Cascade length:  1908
# New Orders left:  1480847
# making new cascade
#
#
# OG Orders left:  1480847
# Cascade length:  2350
# New Orders left:  1478497
# making new cascade
#
#
# OG Orders left:  1478497
# Cascade length:  1771
# New Orders left:  1476726
# making new cascade
#
#
# OG Orders left:  1476726
# Cascade length:  1
# New Orders left:  1476725
# making new cascade
#
#
# OG Orders left:  1476725
# Cascade length:  2
# New Orders left:  1476723
# making new cascade
#
#
# OG Orders left:  1476723
# Cascade length:  1875
# New Orders left:  1474848
# making new cascade
#
#
# OG Orders left:  1474848
# Cascade length:  1966
# New Orders left:  1472882
# making new cascade
#
#
# OG Orders left:  1472882
# Cascade length:  1318
# New Orders left:  1471564
# making new cascade
#
#
# OG Orders left:  1471564
# Cascade length:  1917
# New Orders left:  1469647
# making new cascade
#
#
# OG Orders left:  1469647
# Cascade length:  2676
# New Orders left:  1466971
# making new cascade
#
#
# OG Orders left:  1466971
# Cascade length:  1563
# New Orders left:  1465408
# making new cascade
#
#
# OG Orders left:  1465408
# Cascade length:  1619
# New Orders left:  1463789
# making new cascade
#
#
# OG Orders left:  1463789
# Cascade length:  2061
# New Orders left:  1461728
# making new cascade
#
#
# OG Orders left:  1461728
# Cascade length:  1823
# New Orders left:  1459905
# making new cascade
#
#
# OG Orders left:  1459905
# Cascade length:  3251
# New Orders left:  1456654
# making new cascade
#
#
# OG Orders left:  1456654
# Cascade length:  2068
# New Orders left:  1454586
# making new cascade
#
#
# OG Orders left:  1454586
# Cascade length:  1839
# New Orders left:  1452747
# making new cascade
#
#
# OG Orders left:  1452747
# Cascade length:  1827
# New Orders left:  1450920
# making new cascade
#
#
# OG Orders left:  1450920
# Cascade length:  2518
# New Orders left:  1448402
# making new cascade
#
#
# OG Orders left:  1448402
# Cascade length:  737
# New Orders left:  1447665
# making new cascade
#
#
# OG Orders left:  1447665
# Cascade length:  5
# New Orders left:  1447660
# making new cascade
#
#
# OG Orders left:  1447660
# Cascade length:  2317
# New Orders left:  1445343
# making new cascade
#
#
# OG Orders left:  1445343
# Cascade length:  1318
# New Orders left:  1444025
# making new cascade
#
#
# OG Orders left:  1444025
# Cascade length:  2271
# New Orders left:  1441754
# making new cascade
#
#
# OG Orders left:  1441754
# Cascade length:  2247
# New Orders left:  1439507
# making new cascade
#
#
# OG Orders left:  1439507
# Cascade length:  4
# New Orders left:  1439503
# making new cascade
#
#
# OG Orders left:  1439503
# Cascade length:  2259
# New Orders left:  1437244
# making new cascade
#
#
# OG Orders left:  1437244
# Cascade length:  1871
# New Orders left:  1435373
# making new cascade
#
#
# OG Orders left:  1435373
# Cascade length:  1895
# New Orders left:  1433478
# making new cascade
#
#
# OG Orders left:  1433478
# Cascade length:  4
# New Orders left:  1433474
# making new cascade
#
#
# OG Orders left:  1433474
# Cascade length:  1525
# New Orders left:  1431949
# making new cascade
#
#
# OG Orders left:  1431949
# Cascade length:  1727
# New Orders left:  1430222
# making new cascade
#
#
# OG Orders left:  1430222
# Cascade length:  2361
# New Orders left:  1427861
# making new cascade
#
#
# OG Orders left:  1427861
# Cascade length:  1951
# New Orders left:  1425910
# making new cascade
#
#
# OG Orders left:  1425910
# Cascade length:  1727
# New Orders left:  1424183
# making new cascade
#
#
# OG Orders left:  1424183
# Cascade length:  1
# New Orders left:  1424182
# making new cascade
#
#
# OG Orders left:  1424182
# Cascade length:  2202
# New Orders left:  1421980
# making new cascade
#
#
# OG Orders left:  1421980
# Cascade length:  2377
# New Orders left:  1419603
# making new cascade
#
#
# OG Orders left:  1419603
# Cascade length:  2288
# New Orders left:  1417315
# making new cascade
#
#
# OG Orders left:  1417315
# Cascade length:  2462
# New Orders left:  1414853
# making new cascade
#
#
# OG Orders left:  1414853
# Cascade length:  2867
# New Orders left:  1411986
# making new cascade
#
#
# OG Orders left:  1411986
# Cascade length:  2401
# New Orders left:  1409585
# making new cascade
#
#
# OG Orders left:  1409585
# Cascade length:  2265
# New Orders left:  1407320
# making new cascade
#
#
# OG Orders left:  1407320
# Cascade length:  2235
# New Orders left:  1405085
# making new cascade
#
#
# OG Orders left:  1405085
# Cascade length:  3989
# New Orders left:  1401096
# making new cascade
#
#
# OG Orders left:  1401096
# Cascade length:  2840
# New Orders left:  1398256
# making new cascade
#
#
# OG Orders left:  1398256
# Cascade length:  3236
# New Orders left:  1395020
# making new cascade
#
#
# OG Orders left:  1395020
# Cascade length:  2
# New Orders left:  1395018
# making new cascade
#
#
# OG Orders left:  1395018
# Cascade length:  25
# New Orders left:  1394993
# making new cascade
#
#
# OG Orders left:  1394993
# Cascade length:  2028
# New Orders left:  1392965
# making new cascade
#
#
# OG Orders left:  1392965
# Cascade length:  1
# New Orders left:  1392964
# making new cascade
#
#
# OG Orders left:  1392964
# Cascade length:  3749
# New Orders left:  1389215
# making new cascade
#
#
# OG Orders left:  1389215
# Cascade length:  1832
# New Orders left:  1387383
# making new cascade
#
#
# OG Orders left:  1387383
# Cascade length:  3023
# New Orders left:  1384360
# making new cascade
#
#
# OG Orders left:  1384360
# Cascade length:  2133
# New Orders left:  1382227
# making new cascade
#
#
# OG Orders left:  1382227
# Cascade length:  895
# New Orders left:  1381332
# making new cascade
#
#
# OG Orders left:  1381332
# Cascade length:  2244
# New Orders left:  1379088
# making new cascade
#
#
# OG Orders left:  1379088
# Cascade length:  2392
# New Orders left:  1376696
# making new cascade
#
#
# OG Orders left:  1376696
# Cascade length:  1862
# New Orders left:  1374834
# making new cascade
#
#
# OG Orders left:  1374834
# Cascade length:  2112
# New Orders left:  1372722
# making new cascade
#
#
# OG Orders left:  1372722
# Cascade length:  2732
# New Orders left:  1369990
# making new cascade
#
#
# OG Orders left:  1369990
# Cascade length:  1
# New Orders left:  1369989
# making new cascade
#
#
# OG Orders left:  1369989
# Cascade length:  2795
# New Orders left:  1367194
# making new cascade
#
#
# OG Orders left:  1367194
# Cascade length:  1608
# New Orders left:  1365586
# making new cascade
#
#
# OG Orders left:  1365586
# Cascade length:  1956
# New Orders left:  1363630
# making new cascade
#
#
# OG Orders left:  1363630
# Cascade length:  1
# New Orders left:  1363629
# making new cascade
#
#
# OG Orders left:  1363629
# Cascade length:  2608
# New Orders left:  1361021
# making new cascade
#
#
# OG Orders left:  1361021
# Cascade length:  1842
# New Orders left:  1359179
# making new cascade
#
#
# OG Orders left:  1359179
# Cascade length:  2343
# New Orders left:  1356836
# making new cascade
#
#
# OG Orders left:  1356836
# Cascade length:  2252
# New Orders left:  1354584
# making new cascade
#
#
# OG Orders left:  1354584
# Cascade length:  2023
# New Orders left:  1352561
# making new cascade
#
#
# OG Orders left:  1352561
# Cascade length:  2116
# New Orders left:  1350445
# making new cascade
#
#
# OG Orders left:  1350445
# Cascade length:  2
# New Orders left:  1350443
# making new cascade
#
#
# OG Orders left:  1350443
# Cascade length:  2501
# New Orders left:  1347942
# making new cascade
#
#
# OG Orders left:  1347942
# Cascade length:  1849
# New Orders left:  1346093
# making new cascade
#
#
# OG Orders left:  1346093
# Cascade length:  2751
# New Orders left:  1343342
# making new cascade
#
#
# OG Orders left:  1343342
# Cascade length:  2201
# New Orders left:  1341141
# making new cascade
#
#
# OG Orders left:  1341141
# Cascade length:  2977
# New Orders left:  1338164
# making new cascade
#
#
# OG Orders left:  1338164
# Cascade length:  2235
# New Orders left:  1335929
# making new cascade
#
#
# OG Orders left:  1335929
# Cascade length:  1734
# New Orders left:  1334195
# making new cascade
#
#
# OG Orders left:  1334195
# Cascade length:  1839
# New Orders left:  1332356
# making new cascade
#
#
# OG Orders left:  1332356
# Cascade length:  1620
# New Orders left:  1330736
# making new cascade
#
#
# OG Orders left:  1330736
# Cascade length:  2202
# New Orders left:  1328534
# making new cascade
#
#
# OG Orders left:  1328534
# Cascade length:  2
# New Orders left:  1328532
# making new cascade
#
#
# OG Orders left:  1328532
# Cascade length:  1963
# New Orders left:  1326569
# making new cascade
#
#
# OG Orders left:  1326569
# Cascade length:  2390
# New Orders left:  1324179
# making new cascade
#
#
# OG Orders left:  1324179
# Cascade length:  1654
# New Orders left:  1322525
# making new cascade
#
#
# OG Orders left:  1322525
# Cascade length:  2243
# New Orders left:  1320282
# making new cascade
#
#
# OG Orders left:  1320282
# Cascade length:  2156
# New Orders left:  1318126
# making new cascade
#
#
# OG Orders left:  1318126
# Cascade length:  3015
# New Orders left:  1315111
# making new cascade
#
#
# OG Orders left:  1315111
# Cascade length:  2234
# New Orders left:  1312877
# making new cascade
#
#
# OG Orders left:  1312877
# Cascade length:  2255
# New Orders left:  1310622
# making new cascade
#
#
# OG Orders left:  1310622
# Cascade length:  2640
# New Orders left:  1307982
# making new cascade
#
#
# OG Orders left:  1307982
# Cascade length:  2234
# New Orders left:  1305748
# making new cascade
#
#
# OG Orders left:  1305748
# Cascade length:  2131
# New Orders left:  1303617
# making new cascade
#
#
# OG Orders left:  1303617
# Cascade length:  1656
# New Orders left:  1301961
# making new cascade
#
#
# OG Orders left:  1301961
# Cascade length:  2598
# New Orders left:  1299363
# making new cascade
#
#
# OG Orders left:  1299363
# Cascade length:  2112
# New Orders left:  1297251
# making new cascade
#
#
# OG Orders left:  1297251
# Cascade length:  1527
# New Orders left:  1295724
# making new cascade
#
#
# OG Orders left:  1295724
# Cascade length:  1806
# New Orders left:  1293918
# making new cascade
#
#
# OG Orders left:  1293918
# Cascade length:  1541
# New Orders left:  1292377
# making new cascade
#
#
# OG Orders left:  1292377
# Cascade length:  1827
# New Orders left:  1290550
# making new cascade
#
#
# OG Orders left:  1290550
# Cascade length:  1970
# New Orders left:  1288580
# making new cascade
#
#
# OG Orders left:  1288580
# Cascade length:  1280
# New Orders left:  1287300
# making new cascade
#
#
# OG Orders left:  1287300
# Cascade length:  2154
# New Orders left:  1285146
# making new cascade
#
#
# OG Orders left:  1285146
# Cascade length:  2149
# New Orders left:  1282997
# making new cascade
#
#
# OG Orders left:  1282997
# Cascade length:  1493
# New Orders left:  1281504
# making new cascade
#
#
# OG Orders left:  1281504
# Cascade length:  2103
# New Orders left:  1279401
# making new cascade
#
#
# OG Orders left:  1279401
# Cascade length:  2173
# New Orders left:  1277228
# making new cascade
#
#
# OG Orders left:  1277228
# Cascade length:  1550
# New Orders left:  1275678
# making new cascade
#
#
# OG Orders left:  1275678
# Cascade length:  2202
# New Orders left:  1273476
# making new cascade
#
#
# OG Orders left:  1273476
# Cascade length:  1595
# New Orders left:  1271881
# making new cascade
#
#
# OG Orders left:  1271881
# Cascade length:  3107
# New Orders left:  1268774
# making new cascade
#
#
# OG Orders left:  1268774
# Cascade length:  2322
# New Orders left:  1266452
# making new cascade
#
#
# OG Orders left:  1266452
# Cascade length:  3253
# New Orders left:  1263199
# making new cascade
#
#
# OG Orders left:  1263199
# Cascade length:  1870
# New Orders left:  1261329
# making new cascade
#
#
# OG Orders left:  1261329
# Cascade length:  8
# New Orders left:  1261321
# making new cascade
#
#
# OG Orders left:  1261321
# Cascade length:  3359
# New Orders left:  1257962
# making new cascade
#
#
# OG Orders left:  1257962
# Cascade length:  1617
# New Orders left:  1256345
# making new cascade
#
#
# OG Orders left:  1256345
# Cascade length:  1600
# New Orders left:  1254745
# making new cascade
#
#
# OG Orders left:  1254745
# Cascade length:  2211
# New Orders left:  1252534
# making new cascade
#
#
# OG Orders left:  1252534
# Cascade length:  1747
# New Orders left:  1250787
# making new cascade
#
#
# OG Orders left:  1250787
# Cascade length:  1745
# New Orders left:  1249042
# making new cascade
#
#
# OG Orders left:  1249042
# Cascade length:  2455
# New Orders left:  1246587
# making new cascade
#
#
# OG Orders left:  1246587
# Cascade length:  2942
# New Orders left:  1243645
# making new cascade
#
#
# OG Orders left:  1243645
# Cascade length:  1608
# New Orders left:  1242037
# making new cascade
#
#
# OG Orders left:  1242037
# Cascade length:  1348
# New Orders left:  1240689
# making new cascade
#
#
# OG Orders left:  1240689
# Cascade length:  19
# New Orders left:  1240670
# making new cascade
#
#
# OG Orders left:  1240670
# Cascade length:  1802
# New Orders left:  1238868
# making new cascade
#
#
# OG Orders left:  1238868
# Cascade length:  1314
# New Orders left:  1237554
# making new cascade
#
#
# OG Orders left:  1237554
# Cascade length:  2887
# New Orders left:  1234667
# making new cascade
#
#
# OG Orders left:  1234667
# Cascade length:  1549
# New Orders left:  1233118
# making new cascade
#
#
# OG Orders left:  1233118
# Cascade length:  1846
# New Orders left:  1231272
# making new cascade
#
#
# OG Orders left:  1231272
# Cascade length:  2175
# New Orders left:  1229097
# making new cascade
#
#
# OG Orders left:  1229097
# Cascade length:  1494
# New Orders left:  1227603
# making new cascade
#
#
# OG Orders left:  1227603
# Cascade length:  1220
# New Orders left:  1226383
# making new cascade
#
#
# OG Orders left:  1226383
# Cascade length:  7
# New Orders left:  1226376
# making new cascade
#
#
# OG Orders left:  1226376
# Cascade length:  1315
# New Orders left:  1225061
# making new cascade
#
#
# OG Orders left:  1225061
# Cascade length:  72
# New Orders left:  1224989
# making new cascade
#
#
# OG Orders left:  1224989
# Cascade length:  1356
# New Orders left:  1223633
# making new cascade
#
#
# OG Orders left:  1223633
# Cascade length:  1581
# New Orders left:  1222052
# making new cascade
#
#
# OG Orders left:  1222052
# Cascade length:  2743
# ...
#
#
# OG Orders left:  298793
# Cascade length:  3
# New Orders left:  298790
# making new cascade
#
#
# OG Orders left:  298790
# Cascade length:  1975
# New Orders left:  296815
# making new cascade
#
#
# OG Orders left:  296815
# Cascade length:  2
# New Orders left:  296813
# making new cascade
#
#
# OG Orders left:  296813
# Cascade length:  4
# New Orders left:  296809
# making new cascade
#
#
# OG Orders left:  296809
# Cascade length:  1707
# New Orders left:  295102
# making new cascade
#
#
# OG Orders left:  295102
# Cascade length:  3
# New Orders left:  295099
# making new cascade
#
#
# OG Orders left:  295099
# Cascade length:  1525
# New Orders left:  293574
# making new cascade
#
#
# OG Orders left:  293574
# Cascade length:  1237
# New Orders left:  292337
# making new cascade
#
#
# OG Orders left:  292337
# Cascade length:  2678
# New Orders left:  289659
# making new cascade
#
#
# OG Orders left:  289659
# Cascade length:  3434
# New Orders left:  286225
# making new cascade
#
#
# OG Orders left:  286225
# Cascade length:  1348
# New Orders left:  284877
# making new cascade
#
#
# OG Orders left:  284877
# Cascade length:  1
# New Orders left:  284876
# making new cascade
#
#
# OG Orders left:  284876
# Cascade length:  1793
# New Orders left:  283083
# making new cascade
#
#
# OG Orders left:  283083
# Cascade length:  2390
# New Orders left:  280693
# making new cascade
#
#
# OG Orders left:  280693
# Cascade length:  1
# New Orders left:  280692
# making new cascade
#
#
# OG Orders left:  280692
# Cascade length:  2961
# New Orders left:  277731
# making new cascade
#
#
# OG Orders left:  277731
# Cascade length:  1172
# New Orders left:  276559
# making new cascade
#
#
# OG Orders left:  276559
# Cascade length:  5
# New Orders left:  276554
# making new cascade
#
#
# OG Orders left:  276554
# Cascade length:  3346
# New Orders left:  273208
# making new cascade
#
#
# OG Orders left:  273208
# Cascade length:  2653
# New Orders left:  270555
# making new cascade
#
#
# OG Orders left:  270555
# Cascade length:  1784
# New Orders left:  268771
# making new cascade
#
#
# OG Orders left:  268771
# Cascade length:  2
# New Orders left:  268769
# making new cascade
#
#
# OG Orders left:  268769
# Cascade length:  2110
# New Orders left:  266659
# making new cascade
#
#
# OG Orders left:  266659
# Cascade length:  2298
# New Orders left:  264361
# making new cascade
#
#
# OG Orders left:  264361
# Cascade length:  2646
# New Orders left:  261715
# making new cascade
#
#
# OG Orders left:  261715
# Cascade length:  1601
# New Orders left:  260114
# making new cascade
#
#
# OG Orders left:  260114
# Cascade length:  2071
# New Orders left:  258043
# making new cascade
#
#
# OG Orders left:  258043
# Cascade length:  3540
# New Orders left:  254503
# making new cascade
#
#
# OG Orders left:  254503
# Cascade length:  2714
# New Orders left:  251789
# making new cascade
#
#
# OG Orders left:  251789
# Cascade length:  1234
# New Orders left:  250555
# making new cascade
#
#
# OG Orders left:  250555
# Cascade length:  1922
# New Orders left:  248633
# making new cascade
#
#
# OG Orders left:  248633
# Cascade length:  2288
# New Orders left:  246345
# making new cascade
#
#
# OG Orders left:  246345
# Cascade length:  1571
# New Orders left:  244774
# making new cascade
#
#
# OG Orders left:  244774
# Cascade length:  2265
# New Orders left:  242509
# making new cascade
#
#
# OG Orders left:  242509
# Cascade length:  3472
# New Orders left:  239037
# making new cascade
#
#
# OG Orders left:  239037
# Cascade length:  2421
# New Orders left:  236616
# making new cascade
#
#
# OG Orders left:  236616
# Cascade length:  2240
# New Orders left:  234376
# making new cascade
#
#
# OG Orders left:  234376
# Cascade length:  2314
# New Orders left:  232062
# making new cascade
#
#
# OG Orders left:  232062
# Cascade length:  1777
# New Orders left:  230285
# making new cascade
#
#
# OG Orders left:  230285
# Cascade length:  2696
# New Orders left:  227589
# making new cascade
#
#
# OG Orders left:  227589
# Cascade length:  1993
# New Orders left:  225596
# making new cascade
#
#
# OG Orders left:  225596
# Cascade length:  2101
# New Orders left:  223495
# making new cascade
#
#
# OG Orders left:  223495
# Cascade length:  1551
# New Orders left:  221944
# making new cascade
#
#
# OG Orders left:  221944
# Cascade length:  1814
# New Orders left:  220130
# making new cascade
#
#
# OG Orders left:  220130
# Cascade length:  1771
# New Orders left:  218359
# making new cascade
#
#
# OG Orders left:  218359
# Cascade length:  2164
# New Orders left:  216195
# making new cascade
#
#
# OG Orders left:  216195
# Cascade length:  2735
# New Orders left:  213460
# making new cascade
#
#
# OG Orders left:  213460
# Cascade length:  1954
# New Orders left:  211506
# making new cascade
#
#
# OG Orders left:  211506
# Cascade length:  2065
# New Orders left:  209441
# making new cascade
#
#
# OG Orders left:  209441
# Cascade length:  3122
# New Orders left:  206319
# making new cascade
#
#
# OG Orders left:  206319
# Cascade length:  1
# New Orders left:  206318
# making new cascade
#
#
# OG Orders left:  206318
# Cascade length:  1622
# New Orders left:  204696
# making new cascade
#
#
# OG Orders left:  204696
# Cascade length:  1852
# New Orders left:  202844
# making new cascade
#
#
# OG Orders left:  202844
# Cascade length:  1801
# New Orders left:  201043
# making new cascade
#
#
# OG Orders left:  201043
# Cascade length:  2940
# New Orders left:  198103
# making new cascade
#
#
# OG Orders left:  198103
# Cascade length:  2337
# New Orders left:  195766
# making new cascade
#
#
# OG Orders left:  195766
# Cascade length:  1960
# New Orders left:  193806
# making new cascade
#
#
# OG Orders left:  193806
# Cascade length:  2
# New Orders left:  193804
# making new cascade
#
#
# OG Orders left:  193804
# Cascade length:  2574
# New Orders left:  191230
# making new cascade
#
#
# OG Orders left:  191230
# Cascade length:  2007
# New Orders left:  189223
# making new cascade
#
#
# OG Orders left:  189223
# Cascade length:  2194
# New Orders left:  187029
# making new cascade
#
#
# OG Orders left:  187029
# Cascade length:  2298
# New Orders left:  184731
# making new cascade
#
#
# OG Orders left:  184731
# Cascade length:  1519
# New Orders left:  183212
# making new cascade
#
#
# OG Orders left:  183212
# Cascade length:  1713
# New Orders left:  181499
# making new cascade
#
#
# OG Orders left:  181499
# Cascade length:  1967
# New Orders left:  179532
# making new cascade
#
#
# OG Orders left:  179532
# Cascade length:  4844
# New Orders left:  174688
# making new cascade
#
#
# OG Orders left:  174688
# Cascade length:  2595
# New Orders left:  172093
# making new cascade
#
#
# OG Orders left:  172093
# Cascade length:  2542
# New Orders left:  169551
# making new cascade
#
#
# OG Orders left:  169551
# Cascade length:  1679
# New Orders left:  167872
# making new cascade
#
#
# OG Orders left:  167872
# Cascade length:  2116
# New Orders left:  165756
# making new cascade
#
#
# OG Orders left:  165756
# Cascade length:  1812
# New Orders left:  163944
# making new cascade
#
#
# OG Orders left:  163944
# Cascade length:  3147
# New Orders left:  160797
# making new cascade
#
#
# OG Orders left:  160797
# Cascade length:  1984
# New Orders left:  158813
# making new cascade
#
#
# OG Orders left:  158813
# Cascade length:  2856
# New Orders left:  155957
# making new cascade
#
#
# OG Orders left:  155957
# Cascade length:  2613
# New Orders left:  153344
# making new cascade
#
#
# OG Orders left:  153344
# Cascade length:  2229
# New Orders left:  151115
# making new cascade
#
#
# OG Orders left:  151115
# Cascade length:  3207
# New Orders left:  147908
# making new cascade
#
#
# OG Orders left:  147908
# Cascade length:  3146
# New Orders left:  144762
# making new cascade
#
#
# OG Orders left:  144762
# Cascade length:  2236
# New Orders left:  142526
# making new cascade
#
#
# OG Orders left:  142526
# Cascade length:  2291
# New Orders left:  140235
# making new cascade
#
#
# OG Orders left:  140235
# Cascade length:  2072
# New Orders left:  138163
# making new cascade
#
#
# OG Orders left:  138163
# Cascade length:  1889
# New Orders left:  136274
# making new cascade
#
#
# OG Orders left:  136274
# Cascade length:  2892
# New Orders left:  133382
# making new cascade
#
#
# OG Orders left:  133382
# Cascade length:  1872
# New Orders left:  131510
# making new cascade
#
#
# OG Orders left:  131510
# Cascade length:  2467
# New Orders left:  129043
# making new cascade
#
#
# OG Orders left:  129043
# Cascade length:  2967
# New Orders left:  126076
# making new cascade
#
#
# OG Orders left:  126076
# Cascade length:  2105
# New Orders left:  123971
# making new cascade
#
#
# OG Orders left:  123971
# Cascade length:  2293
# New Orders left:  121678
# making new cascade
#
#
# OG Orders left:  121678
# Cascade length:  2140
# New Orders left:  119538
# making new cascade
#
#
# OG Orders left:  119538
# Cascade length:  2332
# New Orders left:  117206
# making new cascade
#
#
# OG Orders left:  117206
# Cascade length:  2454
# New Orders left:  114752
# making new cascade
#
#
# OG Orders left:  114752
# Cascade length:  2570
# New Orders left:  112182
# making new cascade
#
#
# OG Orders left:  112182
# Cascade length:  2660
# New Orders left:  109522
# making new cascade
#
#
# OG Orders left:  109522
# Cascade length:  2288
# New Orders left:  107234
# making new cascade
#
#
# OG Orders left:  107234
# Cascade length:  1799
# New Orders left:  105435
# making new cascade
#
#
# OG Orders left:  105435
# Cascade length:  1678
# New Orders left:  103757
# making new cascade
#
#
# OG Orders left:  103757
# Cascade length:  1963
# New Orders left:  101794
# making new cascade
#
#
# OG Orders left:  101794
# Cascade length:  1772
# New Orders left:  100022
# making new cascade
#
#
# OG Orders left:  100022
# Cascade length:  2491
# New Orders left:  97531
# making new cascade
#
#
# OG Orders left:  97531
# Cascade length:  2572
# New Orders left:  94959
# making new cascade
#
#
# OG Orders left:  94959
# Cascade length:  2009
# New Orders left:  92950
# making new cascade
#
#
# OG Orders left:  92950
# Cascade length:  2191
# New Orders left:  90759
# making new cascade
#
#
# OG Orders left:  90759
# Cascade length:  2217
# New Orders left:  88542
# making new cascade
#
#
# OG Orders left:  88542
# Cascade length:  1905
# New Orders left:  86637
# making new cascade
#
#
# OG Orders left:  86637
# Cascade length:  1959
# New Orders left:  84678
# making new cascade
#
#
# OG Orders left:  84678
# Cascade length:  2076
# New Orders left:  82602
# making new cascade
#
#
# OG Orders left:  82602
# Cascade length:  1813
# New Orders left:  80789
# making new cascade
#
#
# OG Orders left:  80789
# Cascade length:  1329
# New Orders left:  79460
# making new cascade
#
#
# OG Orders left:  79460
# Cascade length:  1
# New Orders left:  79459
# making new cascade
#
#
# OG Orders left:  79459
# Cascade length:  2301
# New Orders left:  77158
# making new cascade
#
#
# OG Orders left:  77158
# Cascade length:  2391
# New Orders left:  74767
# making new cascade
#
#
# OG Orders left:  74767
# Cascade length:  1527
# New Orders left:  73240
# making new cascade
#
#
# OG Orders left:  73240
# Cascade length:  1960
# New Orders left:  71280
# making new cascade
#
#
# OG Orders left:  71280
# Cascade length:  1963
# New Orders left:  69317
# making new cascade
#
#
# OG Orders left:  69317
# Cascade length:  2284
# New Orders left:  67033
# making new cascade
#
#
# OG Orders left:  67033
# Cascade length:  2267
# New Orders left:  64766
# making new cascade
#
#
# OG Orders left:  64766
# Cascade length:  1541
# New Orders left:  63225
# making new cascade
#
#
# OG Orders left:  63225
# Cascade length:  1670
# New Orders left:  61555
# making new cascade
#
#
# OG Orders left:  61555
# Cascade length:  1410
# New Orders left:  60145
# making new cascade
#
#
# OG Orders left:  60145
# Cascade length:  2164
# New Orders left:  57981
# making new cascade
#
#
# OG Orders left:  57981
# Cascade length:  1762
# New Orders left:  56219
# making new cascade
#
#
# OG Orders left:  56219
# Cascade length:  2609
# New Orders left:  53610
# making new cascade
#
#
# OG Orders left:  53610
# Cascade length:  1611
# New Orders left:  51999
# making new cascade
#
#
# OG Orders left:  51999
# Cascade length:  1450
# New Orders left:  50549
# making new cascade
#
#
# OG Orders left:  50549
# Cascade length:  1839
# New Orders left:  48710
# making new cascade
#
#
# OG Orders left:  48710
# Cascade length:  1687
# New Orders left:  47023
# making new cascade
#
#
# OG Orders left:  47023
# Cascade length:  1217
# New Orders left:  45806
# making new cascade
#
#
# OG Orders left:  45806
# Cascade length:  1347
# New Orders left:  44459
# making new cascade
#
#
# OG Orders left:  44459
# Cascade length:  1709
# New Orders left:  42750
# making new cascade
#
#
# OG Orders left:  42750
# Cascade length:  1354
# New Orders left:  41396
# making new cascade
#
#
# OG Orders left:  41396
# Cascade length:  1325
# New Orders left:  40071
# making new cascade
#
#
# OG Orders left:  40071
# Cascade length:  1725
# New Orders left:  38346
# making new cascade
#
#
# OG Orders left:  38346
# Cascade length:  1663
# New Orders left:  36683
# making new cascade
#
#
# OG Orders left:  36683
# Cascade length:  1928
# New Orders left:  34755
# making new cascade
#
#
# OG Orders left:  34755
# Cascade length:  1343
# New Orders left:  33412
# making new cascade
#
#
# OG Orders left:  33412
# Cascade length:  2111
# New Orders left:  31301
# making new cascade
#
#
# OG Orders left:  31301
# Cascade length:  1324
# New Orders left:  29977
# making new cascade
#
#
# OG Orders left:  29977
# Cascade length:  1417
# New Orders left:  28560
# making new cascade
#
#
# OG Orders left:  28560
# Cascade length:  1458
# New Orders left:  27102
# making new cascade
#
#
# OG Orders left:  27102
# Cascade length:  1329
# New Orders left:  25773
# making new cascade
#
#
# OG Orders left:  25773
# Cascade length:  1489
# New Orders left:  24284
# making new cascade
#
#
# OG Orders left:  24284
# Cascade length:  1403
# New Orders left:  22881
# making new cascade
#
#
# OG Orders left:  22881
# Cascade length:  1513
# New Orders left:  21368
# making new cascade
#
#
# OG Orders left:  21368
# Cascade length:  1359
# New Orders left:  20009
# making new cascade
#
#
# OG Orders left:  20009
# Cascade length:  1073
# New Orders left:  18936
# making new cascade
#
#
# OG Orders left:  18936
# Cascade length:  977
# New Orders left:  17959
# making new cascade
#
#
# OG Orders left:  17959
# Cascade length:  1140
# New Orders left:  16819
# making new cascade
#
#
# OG Orders left:  16819
# Cascade length:  1487
# New Orders left:  15332
# making new cascade
#
#
# OG Orders left:  15332
# Cascade length:  1216
# New Orders left:  14116
# making new cascade
#
#
# OG Orders left:  14116
# Cascade length:  774
# New Orders left:  13342
# making new cascade
#
#
# OG Orders left:  13342
# Cascade length:  1052
# New Orders left:  12290
# making new cascade
#
#
# OG Orders left:  12290
# Cascade length:  890
# New Orders left:  11400
# making new cascade
#
#
# OG Orders left:  11400
# Cascade length:  1027
# New Orders left:  10373
# making new cascade
#
#
# OG Orders left:  10373
# Cascade length:  995
# New Orders left:  9378
# making new cascade
#
#
# OG Orders left:  9378
# Cascade length:  687
# New Orders left:  8691
# making new cascade
#
#
# OG Orders left:  8691
# Cascade length:  582
# New Orders left:  8109
# making new cascade
#
#
# OG Orders left:  8109
# Cascade length:  637
# New Orders left:  7472
# making new cascade
#
#
# OG Orders left:  7472
# Cascade length:  720
# New Orders left:  6752
# making new cascade
#
#
# OG Orders left:  6752
# Cascade length:  849
# New Orders left:  5903
# making new cascade
#
#
# OG Orders left:  5903
# Cascade length:  650
# New Orders left:  5253
# making new cascade
#
#
# OG Orders left:  5253
# Cascade length:  562
# New Orders left:  4691
# making new cascade
#
#
# OG Orders left:  4691
# Cascade length:  591
# New Orders left:  4100
# making new cascade
#
#
# OG Orders left:  4100
# Cascade length:  633
# New Orders left:  3467
# making new cascade
#
#
# OG Orders left:  3467
# Cascade length:  583
# New Orders left:  2884
# making new cascade
#
#
# OG Orders left:  2884
# Cascade length:  529
# New Orders left:  2355
# making new cascade
#
#
# OG Orders left:  2355
# Cascade length:  459
# New Orders left:  1896
# making new cascade
#
#
# OG Orders left:  1896
# Cascade length:  344
# New Orders left:  1552
# making new cascade
#
#
# OG Orders left:  1552
# Cascade length:  295
# New Orders left:  1257
# making new cascade
#
#
# OG Orders left:  1257
# Cascade length:  293
# New Orders left:  964
# making new cascade
#
#
# OG Orders left:  964
# Cascade length:  184
# New Orders left:  780
# making new cascade
#
#
# OG Orders left:  780
# Cascade length:  1
# New Orders left:  779
# making new cascade
#
#
# OG Orders left:  779
# Cascade length:  260
# New Orders left:  519
# making new cascade
#
#
# OG Orders left:  519
# Cascade length:  173
# New Orders left:  346
# making new cascade
#
#
# OG Orders left:  346
# Cascade length:  150
# New Orders left:  196
# making new cascade
#
#
# OG Orders left:  196
# Cascade length:  122
# New Orders left:  74
# making new cascade
#
#
# OG Orders left:  74
# Cascade length:  48
# New Orders left:  26
# making new cascade
#
#
# OG Orders left:  26
# Cascade length:  26
# New Orders left:  0
# making new cascade

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*5, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.3), '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_10_20_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*4, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_10_20_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),10))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.5)*2, '-.', label= "$x^{-1.5}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_10_20_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
