# %%
import matlab.engine
import numpy as np
import scipy
import matplotlib.pyplot as plt

eng = matlab.engine.start_matlab()

# %%
def fbm(H,n=(2**13),T=(1)):
    """
    H - hurst index in float format
    n - number of timesteps as multiple of 2 in float format
    T - total time can keep 1?? float
    
    calls the matlab function from wikipedia
    ensure import matlab.engine
    Zdravko Botev (2020). Fractional Brownian motion generator 
    (https://www.mathworks.com/matlabcentral/fileexchange/38935-fractional-brownian-motion-generator)
    Kroese, D. P., & Botev, Z. I. (2015). Spatial Process Simulation.
    In Stochastic Geometry, Spatial Statistics and Random Fields(pp. 369-404)
    Springer International Publishing, DOI: 10.1007/978-3-319-10064-7_12
    """
    T = float(T)
    n = float(n)
    H = float(H)
    
    #eng = matlab.engine.start_matlab()
    a = eng.fbm1d(H,n,T)
    fbm = np.asarray([])
    for i in range(len(a)):
        fbm = np.concatenate((fbm,np.asarray(a[i])))

    #plt.plot(np.linspace(0,1,int(n+1)),fbm)
    
    return fbm

# %%
tfbm = fbm(0.55,2**13,2**13)
print(min(tfbm))
plt.plot(np.linspace(0,2**13,int(2**13+1)),(tfbm+abs(np.min(tfbm)))*10)
# Out:
# -180.60540164415244

# %%
fbm20 = np.empty(2**13+1)

for i in range(20):
    fbmnp = (fbm(np.random.uniform(0.55,0.65), 2**13,2**13)+5)
    fbmnp = (fbmnp + abs(np.min(fbmnp)))*20
    #fbmnp = fbm(0.5)+100
    print(fbmnp)
    print(np.shape(fbm20),np.shape(fbmnp))
    fbm20 = np.vstack((fbm20,fbmnp))
# Out:
# [183.77260084 181.90040858 181.83542367 ... 193.76433646 192.99888595
#  192.71329389]
# (8193,) (8193,)
# [316.75457196 318.17119239 317.72443954 ... 362.67485954 361.20692542
#  360.1797894 ]
# (2, 8193) (8193,)
# [167.36525926 168.81137078 169.84471187 ... 134.62779447 134.53584231
#  132.69271661]
# (3, 8193) (8193,)
# [206.91106589 206.96641351 206.41264625 ... 240.30140657 241.78353043
#  242.49783044]
# (4, 8193) (8193,)
# [105.87687033 105.86705693 106.71853417 ... 651.62269909 651.51432779
#  649.74733531]
# (5, 8193) (8193,)
# [149.02715994 149.11992519 149.81314198 ... 415.42713587 416.75690387
#  415.61078416]
# (6, 8193) (8193,)
# [116.29742282 115.94172561 117.58232511 ... 572.28640105 572.39382384
#  572.55623769]
# (7, 8193) (8193,)
# [167.53710219 168.95325771 167.74994425 ... 196.50516311 197.24334914
#  198.5595283 ]
# (8, 8193) (8193,)
# [195.98149119 195.11864752 194.38221248 ... 439.52874878 439.40385022
#  439.54825082]
# (9, 8193) (8193,)
# [190.69416944 190.00709778 189.43499866 ... 254.95012009 256.02929911
#  255.7445812 ]
# (10, 8193) (8193,)
# [206.27677871 206.34547744 205.81532684 ... 345.18214758 345.33607014
#  345.4486306 ]
# (11, 8193) (8193,)
# [109.67461384 109.07311593 108.94401774 ... 404.60481584 404.85446692
#  406.35684557]
# (12, 8193) (8193,)
# [729.33396652 727.50047368 725.73933518 ... 181.03274891 182.09847271
#  182.65513554]
# (13, 8193) (8193,)
# [156.23586121 155.2047096  155.28072129 ... 358.48651341 356.63740582
#  356.2808397 ]
# (14, 8193) (8193,)
# [217.97778212 219.25642361 218.23383822 ... 116.24220851 116.37612365
#  116.544831  ]
# (15, 8193) (8193,)
# [168.9271217  168.40249596 167.06287674 ... 147.48199815 145.85554787
#  144.63179593]
# (16, 8193) (8193,)
# [385.16481208 385.88683663 386.6412729  ... 183.5387519  182.59828208
#  182.68111336]
# (17, 8193) (8193,)
# [136.23908748 136.04135327 136.57511626 ... 270.40414089 270.31484914
#  272.02834626]
# (18, 8193) (8193,)
# [474.44802237 474.29720679 474.86289913 ... 209.60525746 209.68943441
#  209.52712532]
# (19, 8193) (8193,)
# [175.19262857 175.51002197 174.54851083 ... 110.55589958 109.31502895
#  108.55705694]
# (20, 8193) (8193,)

# %%
for i in range(1,np.shape(fbm20)[0]):
    plt.plot(np.linspace(0,1,int(2**13+1)),fbm20[i])
plt.show()

# %%
#np.savetxt('./fbm20+min+100.txt',fbm20)

# %%
fbm20 = np.asarray([])

# %%
fbm20 = np.append(fbm20,fbmnp)

# %%
fbm20 = np.append(aaaa,[4,5,6])

# %%
aaaa
# Out:
# array([1., 2., 3., 4., 5., 6.])
