# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_200_7200_100_new2threshold_fixedhurst.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_200_7200_100_new2threshold_fixedhurst.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_200_7200_100_new2threshold_fixedhurst.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_200_7200_100_new2threshold_fixedhurst.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 1   993     yshfc      1   -1.0
# 1                 2   993     yshfc      2   -2.0
# 2                10   993     yshfc     10    1.0
# 3                11   993     yshfc     11    1.0
# 4                13   993     yshfc     13   -1.0
# ...             ...   ...       ...    ...    ...
# 3836251           7  8192     xbcot     35    1.0
# 3836252           9  8192     xbcot     42    1.0
# 3836253           2  8192     jmeyl     76    1.0
# 3836254           3  8192     jmeyl     43   -1.0
# 3836255          16  8192     jmeyl     66   -1.0
#
# [3836256 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades22_npc_200_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1911853

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades21_npc_200_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1911853

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades12_npc_200_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1911853

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades11_npc_200_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1911853
# Cascade length:  2758
# New Orders left:  1909095
# making new cascade
#
#
# OG Orders left:  1909095
# Cascade length:  2796
# New Orders left:  1906299
# making new cascade
#
#
# OG Orders left:  1906299
# Cascade length:  3
# New Orders left:  1906296
# making new cascade
#
#
# OG Orders left:  1906296
# Cascade length:  2614
# New Orders left:  1903682
# making new cascade
#
#
# OG Orders left:  1903682
# Cascade length:  2
# New Orders left:  1903680
# making new cascade
#
#
# OG Orders left:  1903680
# Cascade length:  287
# New Orders left:  1903393
# making new cascade
#
#
# OG Orders left:  1903393
# Cascade length:  3117
# New Orders left:  1900276
# making new cascade
#
#
# OG Orders left:  1900276
# Cascade length:  2
# New Orders left:  1900274
# making new cascade
#
#
# OG Orders left:  1900274
# Cascade length:  2735
# New Orders left:  1897539
# making new cascade
#
#
# OG Orders left:  1897539
# Cascade length:  2807
# New Orders left:  1894732
# making new cascade
#
#
# OG Orders left:  1894732
# Cascade length:  2250
# New Orders left:  1892482
# making new cascade
#
#
# OG Orders left:  1892482
# Cascade length:  1
# New Orders left:  1892481
# making new cascade
#
#
# OG Orders left:  1892481
# Cascade length:  1969
# New Orders left:  1890512
# making new cascade
#
#
# OG Orders left:  1890512
# Cascade length:  19
# New Orders left:  1890493
# making new cascade
#
#
# OG Orders left:  1890493
# Cascade length:  2362
# New Orders left:  1888131
# making new cascade
#
#
# OG Orders left:  1888131
# Cascade length:  1722
# New Orders left:  1886409
# making new cascade
#
#
# OG Orders left:  1886409
# Cascade length:  2119
# New Orders left:  1884290
# making new cascade
#
#
# OG Orders left:  1884290
# Cascade length:  2265
# New Orders left:  1882025
# making new cascade
#
#
# OG Orders left:  1882025
# Cascade length:  7
# New Orders left:  1882018
# making new cascade
#
#
# OG Orders left:  1882018
# Cascade length:  1760
# New Orders left:  1880258
# making new cascade
#
#
# OG Orders left:  1880258
# Cascade length:  2371
# New Orders left:  1877887
# making new cascade
#
#
# OG Orders left:  1877887
# Cascade length:  2311
# New Orders left:  1875576
# making new cascade
#
#
# OG Orders left:  1875576
# Cascade length:  2
# New Orders left:  1875574
# making new cascade
#
#
# OG Orders left:  1875574
# Cascade length:  3
# New Orders left:  1875571
# making new cascade
#
#
# OG Orders left:  1875571
# Cascade length:  13
# New Orders left:  1875558
# making new cascade
#
#
# OG Orders left:  1875558
# Cascade length:  2229
# New Orders left:  1873329
# making new cascade
#
#
# OG Orders left:  1873329
# Cascade length:  4
# New Orders left:  1873325
# making new cascade
#
#
# OG Orders left:  1873325
# Cascade length:  2692
# New Orders left:  1870633
# making new cascade
#
#
# OG Orders left:  1870633
# Cascade length:  2252
# New Orders left:  1868381
# making new cascade
#
#
# OG Orders left:  1868381
# Cascade length:  1898
# New Orders left:  1866483
# making new cascade
#
#
# OG Orders left:  1866483
# Cascade length:  5
# New Orders left:  1866478
# making new cascade
#
#
# OG Orders left:  1866478
# Cascade length:  5
# New Orders left:  1866473
# making new cascade
#
#
# OG Orders left:  1866473
# Cascade length:  1687
# New Orders left:  1864786
# making new cascade
#
#
# OG Orders left:  1864786
# Cascade length:  1751
# New Orders left:  1863035
# making new cascade
#
#
# OG Orders left:  1863035
# Cascade length:  1910
# New Orders left:  1861125
# making new cascade
#
#
# OG Orders left:  1861125
# Cascade length:  2
# New Orders left:  1861123
# making new cascade
#
#
# OG Orders left:  1861123
# Cascade length:  1176
# New Orders left:  1859947
# making new cascade
#
#
# OG Orders left:  1859947
# Cascade length:  1972
# New Orders left:  1857975
# making new cascade
#
#
# OG Orders left:  1857975
# Cascade length:  1267
# New Orders left:  1856708
# making new cascade
#
#
# OG Orders left:  1856708
# Cascade length:  1895
# New Orders left:  1854813
# making new cascade
#
#
# OG Orders left:  1854813
# Cascade length:  2018
# New Orders left:  1852795
# making new cascade
#
#
# OG Orders left:  1852795
# Cascade length:  2382
# New Orders left:  1850413
# making new cascade
#
#
# OG Orders left:  1850413
# Cascade length:  38
# New Orders left:  1850375
# making new cascade
#
#
# OG Orders left:  1850375
# Cascade length:  13
# New Orders left:  1850362
# making new cascade
#
#
# OG Orders left:  1850362
# Cascade length:  1788
# New Orders left:  1848574
# making new cascade
#
#
# OG Orders left:  1848574
# Cascade length:  2336
# New Orders left:  1846238
# making new cascade
#
#
# OG Orders left:  1846238
# Cascade length:  1
# New Orders left:  1846237
# making new cascade
#
#
# OG Orders left:  1846237
# Cascade length:  1590
# New Orders left:  1844647
# making new cascade
#
#
# OG Orders left:  1844647
# Cascade length:  1751
# New Orders left:  1842896
# making new cascade
#
#
# OG Orders left:  1842896
# Cascade length:  5
# New Orders left:  1842891
# making new cascade
#
#
# OG Orders left:  1842891
# Cascade length:  2028
# New Orders left:  1840863
# making new cascade
#
#
# OG Orders left:  1840863
# Cascade length:  15
# New Orders left:  1840848
# making new cascade
#
#
# OG Orders left:  1840848
# Cascade length:  58
# New Orders left:  1840790
# making new cascade
#
#
# OG Orders left:  1840790
# Cascade length:  2001
# New Orders left:  1838789
# making new cascade
#
#
# OG Orders left:  1838789
# Cascade length:  15
# New Orders left:  1838774
# making new cascade
#
#
# OG Orders left:  1838774
# Cascade length:  1662
# New Orders left:  1837112
# making new cascade
#
#
# OG Orders left:  1837112
# Cascade length:  1434
# New Orders left:  1835678
# making new cascade
#
#
# OG Orders left:  1835678
# Cascade length:  1801
# New Orders left:  1833877
# making new cascade
#
#
# OG Orders left:  1833877
# Cascade length:  5
# New Orders left:  1833872
# making new cascade
#
#
# OG Orders left:  1833872
# Cascade length:  1347
# New Orders left:  1832525
# making new cascade
#
#
# OG Orders left:  1832525
# Cascade length:  18
# New Orders left:  1832507
# making new cascade
#
#
# OG Orders left:  1832507
# Cascade length:  2
# New Orders left:  1832505
# making new cascade
#
#
# OG Orders left:  1832505
# Cascade length:  1869
# New Orders left:  1830636
# making new cascade
#
#
# OG Orders left:  1830636
# Cascade length:  1523
# New Orders left:  1829113
# making new cascade
#
#
# OG Orders left:  1829113
# Cascade length:  1
# New Orders left:  1829112
# making new cascade
#
#
# OG Orders left:  1829112
# Cascade length:  1195
# New Orders left:  1827917
# making new cascade
#
#
# OG Orders left:  1827917
# Cascade length:  1421
# New Orders left:  1826496
# making new cascade
#
#
# OG Orders left:  1826496
# Cascade length:  2068
# New Orders left:  1824428
# making new cascade
#
#
# OG Orders left:  1824428
# Cascade length:  1492
# New Orders left:  1822936
# making new cascade
#
#
# OG Orders left:  1822936
# Cascade length:  25
# New Orders left:  1822911
# making new cascade
#
#
# OG Orders left:  1822911
# Cascade length:  1241
# New Orders left:  1821670
# making new cascade
#
#
# OG Orders left:  1821670
# Cascade length:  1
# New Orders left:  1821669
# making new cascade
#
#
# OG Orders left:  1821669
# Cascade length:  1515
# New Orders left:  1820154
# making new cascade
#
#
# OG Orders left:  1820154
# Cascade length:  1584
# New Orders left:  1818570
# making new cascade
#
#
# OG Orders left:  1818570
# Cascade length:  1594
# New Orders left:  1816976
# making new cascade
#
#
# OG Orders left:  1816976
# Cascade length:  1592
# New Orders left:  1815384
# making new cascade
#
#
# OG Orders left:  1815384
# Cascade length:  1485
# New Orders left:  1813899
# making new cascade
#
#
# OG Orders left:  1813899
# Cascade length:  1540
# New Orders left:  1812359
# making new cascade
#
#
# OG Orders left:  1812359
# Cascade length:  1483
# New Orders left:  1810876
# making new cascade
#
#
# OG Orders left:  1810876
# Cascade length:  1
# New Orders left:  1810875
# making new cascade
#
#
# OG Orders left:  1810875
# Cascade length:  1037
# New Orders left:  1809838
# making new cascade
#
#
# OG Orders left:  1809838
# Cascade length:  1497
# New Orders left:  1808341
# making new cascade
#
#
# OG Orders left:  1808341
# Cascade length:  1623
# New Orders left:  1806718
# making new cascade
#
#
# OG Orders left:  1806718
# Cascade length:  6
# New Orders left:  1806712
# making new cascade
#
#
# OG Orders left:  1806712
# Cascade length:  1379
# New Orders left:  1805333
# making new cascade
#
#
# OG Orders left:  1805333
# Cascade length:  1658
# New Orders left:  1803675
# making new cascade
#
#
# OG Orders left:  1803675
# Cascade length:  12
# New Orders left:  1803663
# making new cascade
#
#
# OG Orders left:  1803663
# Cascade length:  1419
# New Orders left:  1802244
# making new cascade
#
#
# OG Orders left:  1802244
# Cascade length:  1235
# New Orders left:  1801009
# making new cascade
#
#
# OG Orders left:  1801009
# Cascade length:  9
# New Orders left:  1801000
# making new cascade
#
#
# OG Orders left:  1801000
# Cascade length:  3
# New Orders left:  1800997
# making new cascade
#
#
# OG Orders left:  1800997
# Cascade length:  1527
# New Orders left:  1799470
# making new cascade
#
#
# OG Orders left:  1799470
# Cascade length:  12
# New Orders left:  1799458
# making new cascade
#
#
# OG Orders left:  1799458
# Cascade length:  30
# New Orders left:  1799428
# making new cascade
#
#
# OG Orders left:  1799428
# Cascade length:  1385
# New Orders left:  1798043
# making new cascade
#
#
# OG Orders left:  1798043
# Cascade length:  8
# New Orders left:  1798035
# making new cascade
#
#
# OG Orders left:  1798035
# Cascade length:  1623
# New Orders left:  1796412
# making new cascade
#
#
# OG Orders left:  1796412
# Cascade length:  1726
# New Orders left:  1794686
# making new cascade
#
#
# OG Orders left:  1794686
# Cascade length:  1800
# New Orders left:  1792886
# making new cascade
#
#
# OG Orders left:  1792886
# Cascade length:  838
# New Orders left:  1792048
# making new cascade
#
#
# OG Orders left:  1792048
# Cascade length:  1370
# New Orders left:  1790678
# making new cascade
#
#
# OG Orders left:  1790678
# Cascade length:  1131
# New Orders left:  1789547
# making new cascade
#
#
# OG Orders left:  1789547
# Cascade length:  1
# New Orders left:  1789546
# making new cascade
#
#
# OG Orders left:  1789546
# Cascade length:  5
# New Orders left:  1789541
# making new cascade
#
#
# OG Orders left:  1789541
# Cascade length:  1395
# New Orders left:  1788146
# making new cascade
#
#
# OG Orders left:  1788146
# Cascade length:  1375
# New Orders left:  1786771
# making new cascade
#
#
# OG Orders left:  1786771
# Cascade length:  1405
# New Orders left:  1785366
# making new cascade
#
#
# OG Orders left:  1785366
# Cascade length:  62
# New Orders left:  1785304
# making new cascade
#
#
# OG Orders left:  1785304
# Cascade length:  1353
# New Orders left:  1783951
# making new cascade
#
#
# OG Orders left:  1783951
# Cascade length:  21
# New Orders left:  1783930
# making new cascade
#
#
# OG Orders left:  1783930
# Cascade length:  1647
# New Orders left:  1782283
# making new cascade
#
#
# OG Orders left:  1782283
# Cascade length:  1
# New Orders left:  1782282
# making new cascade
#
#
# OG Orders left:  1782282
# Cascade length:  74
# New Orders left:  1782208
# making new cascade
#
#
# OG Orders left:  1782208
# Cascade length:  1445
# New Orders left:  1780763
# making new cascade
#
#
# OG Orders left:  1780763
# Cascade length:  1737
# New Orders left:  1779026
# making new cascade
#
#
# OG Orders left:  1779026
# Cascade length:  5
# New Orders left:  1779021
# making new cascade
#
#
# OG Orders left:  1779021
# Cascade length:  1095
# New Orders left:  1777926
# making new cascade
#
#
# OG Orders left:  1777926
# Cascade length:  1483
# New Orders left:  1776443
# making new cascade
#
#
# OG Orders left:  1776443
# Cascade length:  3
# New Orders left:  1776440
# making new cascade
#
#
# OG Orders left:  1776440
# Cascade length:  5
# New Orders left:  1776435
# making new cascade
#
#
# OG Orders left:  1776435
# Cascade length:  393
# New Orders left:  1776042
# making new cascade
#
#
# OG Orders left:  1776042
# Cascade length:  6
# New Orders left:  1776036
# making new cascade
#
#
# OG Orders left:  1776036
# Cascade length:  917
# New Orders left:  1775119
# making new cascade
#
#
# OG Orders left:  1775119
# Cascade length:  1408
# New Orders left:  1773711
# making new cascade
#
#
# OG Orders left:  1773711
# Cascade length:  5
# New Orders left:  1773706
# making new cascade
#
#
# OG Orders left:  1773706
# Cascade length:  1626
# New Orders left:  1772080
# making new cascade
#
#
# OG Orders left:  1772080
# Cascade length:  1096
# New Orders left:  1770984
# making new cascade
#
#
# OG Orders left:  1770984
# Cascade length:  1343
# New Orders left:  1769641
# making new cascade
#
#
# OG Orders left:  1769641
# Cascade length:  1097
# New Orders left:  1768544
# making new cascade
#
#
# OG Orders left:  1768544
# Cascade length:  1
# New Orders left:  1768543
# making new cascade
#
#
# OG Orders left:  1768543
# Cascade length:  2
# New Orders left:  1768541
# making new cascade
#
#
# OG Orders left:  1768541
# Cascade length:  1799
# New Orders left:  1766742
# making new cascade
#
#
# OG Orders left:  1766742
# Cascade length:  801
# New Orders left:  1765941
# making new cascade
#
#
# OG Orders left:  1765941
# Cascade length:  1002
# New Orders left:  1764939
# making new cascade
#
#
# OG Orders left:  1764939
# Cascade length:  1159
# New Orders left:  1763780
# making new cascade
#
#
# OG Orders left:  1763780
# Cascade length:  904
# New Orders left:  1762876
# making new cascade
#
#
# OG Orders left:  1762876
# Cascade length:  1467
# New Orders left:  1761409
# making new cascade
#
#
# OG Orders left:  1761409
# Cascade length:  11
# New Orders left:  1761398
# making new cascade
#
#
# OG Orders left:  1761398
# Cascade length:  1189
# New Orders left:  1760209
# making new cascade
#
#
# OG Orders left:  1760209
# Cascade length:  1047
# New Orders left:  1759162
# making new cascade
#
#
# OG Orders left:  1759162
# Cascade length:  1545
# New Orders left:  1757617
# making new cascade
#
#
# OG Orders left:  1757617
# Cascade length:  1264
# New Orders left:  1756353
# making new cascade
#
#
# OG Orders left:  1756353
# Cascade length:  1454
# New Orders left:  1754899
# making new cascade
#
#
# OG Orders left:  1754899
# Cascade length:  2
# New Orders left:  1754897
# making new cascade
#
#
# OG Orders left:  1754897
# Cascade length:  1
# New Orders left:  1754896
# making new cascade
#
#
# OG Orders left:  1754896
# Cascade length:  109
# New Orders left:  1754787
# making new cascade
#
#
# OG Orders left:  1754787
# Cascade length:  922
# New Orders left:  1753865
# making new cascade
#
#
# OG Orders left:  1753865
# Cascade length:  965
# New Orders left:  1752900
# making new cascade
#
#
# OG Orders left:  1752900
# Cascade length:  1380
# New Orders left:  1751520
# making new cascade
#
#
# OG Orders left:  1751520
# Cascade length:  1379
# New Orders left:  1750141
# making new cascade
#
#
# OG Orders left:  1750141
# Cascade length:  970
# New Orders left:  1749171
# making new cascade
#
#
# OG Orders left:  1749171
# Cascade length:  62
# New Orders left:  1749109
# making new cascade
#
#
# OG Orders left:  1749109
# Cascade length:  17
# New Orders left:  1749092
# making new cascade
#
#
# OG Orders left:  1749092
# Cascade length:  1437
# New Orders left:  1747655
# making new cascade
#
#
# OG Orders left:  1747655
# Cascade length:  26
# New Orders left:  1747629
# making new cascade
#
#
# OG Orders left:  1747629
# Cascade length:  995
# New Orders left:  1746634
# making new cascade
#
#
# OG Orders left:  1746634
# Cascade length:  1005
# New Orders left:  1745629
# making new cascade
#
#
# OG Orders left:  1745629
# Cascade length:  17
# New Orders left:  1745612
# making new cascade
#
#
# OG Orders left:  1745612
# Cascade length:  1019
# New Orders left:  1744593
# making new cascade
#
#
# OG Orders left:  1744593
# Cascade length:  1125
# New Orders left:  1743468
# making new cascade
#
#
# OG Orders left:  1743468
# Cascade length:  779
# New Orders left:  1742689
# making new cascade
#
#
# OG Orders left:  1742689
# Cascade length:  982
# New Orders left:  1741707
# making new cascade
#
#
# OG Orders left:  1741707
# Cascade length:  2
# New Orders left:  1741705
# making new cascade
#
#
# OG Orders left:  1741705
# Cascade length:  383
# New Orders left:  1741322
# making new cascade
#
#
# OG Orders left:  1741322
# Cascade length:  970
# New Orders left:  1740352
# making new cascade
#
#
# OG Orders left:  1740352
# Cascade length:  907
# New Orders left:  1739445
# making new cascade
#
#
# OG Orders left:  1739445
# Cascade length:  931
# New Orders left:  1738514
# making new cascade
#
#
# OG Orders left:  1738514
# Cascade length:  1026
# New Orders left:  1737488
# making new cascade
#
#
# OG Orders left:  1737488
# Cascade length:  872
# New Orders left:  1736616
# making new cascade
#
#
# OG Orders left:  1736616
# Cascade length:  1201
# New Orders left:  1735415
# making new cascade
#
#
# OG Orders left:  1735415
# Cascade length:  1006
# New Orders left:  1734409
# making new cascade
#
#
# OG Orders left:  1734409
# Cascade length:  592
# New Orders left:  1733817
# making new cascade
#
#
# OG Orders left:  1733817
# Cascade length:  1
# New Orders left:  1733816
# making new cascade
#
#
# OG Orders left:  1733816
# Cascade length:  155
# New Orders left:  1733661
# making new cascade
#
#
# OG Orders left:  1733661
# Cascade length:  548
# New Orders left:  1733113
# making new cascade
#
#
# OG Orders left:  1733113
# Cascade length:  10
# New Orders left:  1733103
# making new cascade
#
#
# OG Orders left:  1733103
# Cascade length:  812
# New Orders left:  1732291
# making new cascade
#
#
# OG Orders left:  1732291
# Cascade length:  12
# New Orders left:  1732279
# making new cascade
#
#
# OG Orders left:  1732279
# Cascade length:  826
# New Orders left:  1731453
# making new cascade
#
#
# OG Orders left:  1731453
# Cascade length:  67
# New Orders left:  1731386
# making new cascade
#
#
# OG Orders left:  1731386
# Cascade length:  1300
# New Orders left:  1730086
# making new cascade
#
#
# OG Orders left:  1730086
# Cascade length:  21
# New Orders left:  1730065
# making new cascade
#
#
# OG Orders left:  1730065
# Cascade length:  140
# New Orders left:  1729925
# making new cascade
#
#
# OG Orders left:  1729925
# Cascade length:  3
# New Orders left:  1729922
# making new cascade
#
#
# OG Orders left:  1729922
# Cascade length:  1122
# New Orders left:  1728800
# making new cascade
#
#
# OG Orders left:  1728800
# Cascade length:  16
# New Orders left:  1728784
# making new cascade
#
#
# OG Orders left:  1728784
# Cascade length:  1139
# New Orders left:  1727645
# making new cascade
#
#
# OG Orders left:  1727645
# Cascade length:  1091
# New Orders left:  1726554
# making new cascade
#
#
# OG Orders left:  1726554
# Cascade length:  1
# New Orders left:  1726553
# making new cascade
#
#
# OG Orders left:  1726553
# Cascade length:  1443
# New Orders left:  1725110
# making new cascade
#
#
# OG Orders left:  1725110
# Cascade length:  585
# New Orders left:  1724525
# making new cascade
#
#
# OG Orders left:  1724525
# Cascade length:  6
# New Orders left:  1724519
# making new cascade
#
#
# OG Orders left:  1724519
# Cascade length:  400
# New Orders left:  1724119
# making new cascade
#
#
# OG Orders left:  1724119
# Cascade length:  770
# New Orders left:  1723349
# making new cascade
#
#
# OG Orders left:  1723349
# Cascade length:  1079
# New Orders left:  1722270
# making new cascade
#
#
# OG Orders left:  1722270
# Cascade length:  21
# New Orders left:  1722249
# making new cascade
#
#
# OG Orders left:  1722249
# Cascade length:  830
# New Orders left:  1721419
# making new cascade
#
#
# OG Orders left:  1721419
# Cascade length:  11
# New Orders left:  1721408
# making new cascade
#
#
# OG Orders left:  1721408
# Cascade length:  881
# New Orders left:  1720527
# making new cascade
#
#
# OG Orders left:  1720527
# Cascade length:  10
# New Orders left:  1720517
# making new cascade
#
#
# OG Orders left:  1720517
# Cascade length:  829
# New Orders left:  1719688
# making new cascade
#
#
# OG Orders left:  1719688
# Cascade length:  1
# New Orders left:  1719687
# making new cascade
#
#
# OG Orders left:  1719687
# Cascade length:  38
# New Orders left:  1719649
# making new cascade
#
#
# OG Orders left:  1719649
# Cascade length:  1136
# New Orders left:  1718513
# making new cascade
#
#
# OG Orders left:  1718513
# Cascade length:  1
# New Orders left:  1718512
# making new cascade
#
#
# OG Orders left:  1718512
# Cascade length:  182
# New Orders left:  1718330
# making new cascade
#
#
# OG Orders left:  1718330
# Cascade length:  764
# New Orders left:  1717566
# making new cascade
#
#
# OG Orders left:  1717566
# Cascade length:  876
# New Orders left:  1716690
# making new cascade
#
#
# OG Orders left:  1716690
# Cascade length:  1056
# New Orders left:  1715634
# making new cascade
#
#
# OG Orders left:  1715634
# Cascade length:  8
# New Orders left:  1715626
# making new cascade
#
#
# OG Orders left:  1715626
# Cascade length:  2
# New Orders left:  1715624
# making new cascade
#
#
# OG Orders left:  1715624
# Cascade length:  775
# New Orders left:  1714849
# making new cascade
#
#
# OG Orders left:  1714849
# Cascade length:  681
# New Orders left:  1714168
# making new cascade
#
#
# OG Orders left:  1714168
# Cascade length:  10
# New Orders left:  1714158
# making new cascade
#
#
# OG Orders left:  1714158
# Cascade length:  1243
# New Orders left:  1712915
# making new cascade
#
#
# OG Orders left:  1712915
# Cascade length:  2
# New Orders left:  1712913
# making new cascade
#
#
# OG Orders left:  1712913
# Cascade length:  58
# New Orders left:  1712855
# making new cascade
#
#
# OG Orders left:  1712855
# Cascade length:  1
# New Orders left:  1712854
# making new cascade
#
#
# OG Orders left:  1712854
# Cascade length:  892
# New Orders left:  1711962
# making new cascade
#
#
# OG Orders left:  1711962
# Cascade length:  7
# New Orders left:  1711955
# making new cascade
#
#
# OG Orders left:  1711955
# Cascade length:  103
# New Orders left:  1711852
# making new cascade
#
#
# OG Orders left:  1711852
# Cascade length:  640
# New Orders left:  1711212
# making new cascade
#
#
# OG Orders left:  1711212
# Cascade length:  1
# New Orders left:  1711211
# making new cascade
#
#
# OG Orders left:  1711211
# Cascade length:  901
# New Orders left:  1710310
# making new cascade
#
#
# OG Orders left:  1710310
# Cascade length:  520
# New Orders left:  1709790
# making new cascade
#
#
# OG Orders left:  1709790
# Cascade length:  8
# New Orders left:  1709782
# making new cascade
#
#
# OG Orders left:  1709782
# Cascade length:  32
# New Orders left:  1709750
# making new cascade
#
#
# OG Orders left:  1709750
# Cascade length:  3
# New Orders left:  1709747
# making new cascade
#
#
# OG Orders left:  1709747
# Cascade length:  1
# New Orders left:  1709746
# making new cascade
#
#
# OG Orders left:  1709746
# Cascade length:  1024
# New Orders left:  1708722
# making new cascade
#
#
# OG Orders left:  1708722
# Cascade length:  1146
# New Orders left:  1707576
# making new cascade
#
#
# OG Orders left:  1707576
# Cascade length:  1127
# New Orders left:  1706449
# making new cascade
#
#
# OG Orders left:  1706449
# Cascade length:  1116
# New Orders left:  1705333
# making new cascade
#
#
# OG Orders left:  1705333
# Cascade length:  72
# New Orders left:  1705261
# making new cascade
#
#
# OG Orders left:  1705261
# Cascade length:  808
# New Orders left:  1704453
# making new cascade
#
#
# OG Orders left:  1704453
# Cascade length:  3
# New Orders left:  1704450
# making new cascade
#
#
# OG Orders left:  1704450
# Cascade length:  877
# New Orders left:  1703573
# making new cascade
#
#
# OG Orders left:  1703573
# Cascade length:  1
# New Orders left:  1703572
# making new cascade
#
#
# OG Orders left:  1703572
# Cascade length:  989
# New Orders left:  1702583
# making new cascade
#
#
# OG Orders left:  1702583
# Cascade length:  55
# New Orders left:  1702528
# making new cascade
#
#
# OG Orders left:  1702528
# Cascade length:  93
# New Orders left:  1702435
# making new cascade
#
#
# OG Orders left:  1702435
# Cascade length:  911
# New Orders left:  1701524
# making new cascade
#
#
# OG Orders left:  1701524
# Cascade length:  899
# New Orders left:  1700625
# making new cascade
#
#
# OG Orders left:  1700625
# Cascade length:  780
# New Orders left:  1699845
# making new cascade
#
#
# OG Orders left:  1699845
# Cascade length:  1201
# New Orders left:  1698644
# making new cascade
#
#
# OG Orders left:  1698644
# Cascade length:  15
# New Orders left:  1698629
# making new cascade
#
#
# OG Orders left:  1698629
# Cascade length:  11
# New Orders left:  1698618
# making new cascade
#
#
# OG Orders left:  1698618
# Cascade length:  58
# New Orders left:  1698560
# making new cascade
#
#
# OG Orders left:  1698560
# Cascade length:  2
# New Orders left:  1698558
# making new cascade
#
#
# OG Orders left:  1698558
# Cascade length:  1061
# New Orders left:  1697497
# making new cascade
#
#
# OG Orders left:  1697497
# Cascade length:  802
# New Orders left:  1696695
# making new cascade
#
#
# OG Orders left:  1696695
# Cascade length:  14
# New Orders left:  1696681
# making new cascade
#
#
# OG Orders left:  1696681
# Cascade length:  780
# New Orders left:  1695901
# making new cascade
#
#
# OG Orders left:  1695901
# Cascade length:  3
# New Orders left:  1695898
# making new cascade
#
#
# OG Orders left:  1695898
# Cascade length:  19
# New Orders left:  1695879
# making new cascade
#
#
# OG Orders left:  1695879
# Cascade length:  11
# New Orders left:  1695868
# making new cascade
#
#
# OG Orders left:  1695868
# Cascade length:  1042
# New Orders left:  1694826
# making new cascade
#
#
# OG Orders left:  1694826
# Cascade length:  853
# New Orders left:  1693973
# making new cascade
#
#
# OG Orders left:  1693973
# Cascade length:  1084
# New Orders left:  1692889
# making new cascade
#
#
# OG Orders left:  1692889
# Cascade length:  109
# New Orders left:  1692780
# making new cascade
#
#
# OG Orders left:  1692780
# Cascade length:  922
# New Orders left:  1691858
# making new cascade
#
#
# OG Orders left:  1691858
# Cascade length:  1201
# New Orders left:  1690657
# making new cascade
#
#
# OG Orders left:  1690657
# Cascade length:  1378
# New Orders left:  1689279
# making new cascade
#
#
# OG Orders left:  1689279
# Cascade length:  26
# New Orders left:  1689253
# making new cascade
#
#
# OG Orders left:  1689253
# Cascade length:  39
# New Orders left:  1689214
# making new cascade
#
#
# OG Orders left:  1689214
# Cascade length:  1174
# New Orders left:  1688040
# making new cascade
#
#
# OG Orders left:  1688040
# Cascade length:  794
# New Orders left:  1687246
# making new cascade
#
#
# OG Orders left:  1687246
# Cascade length:  883
# New Orders left:  1686363
# making new cascade
#
#
# OG Orders left:  1686363
# Cascade length:  1111
# New Orders left:  1685252
# making new cascade
#
#
# OG Orders left:  1685252
# Cascade length:  382
# New Orders left:  1684870
# making new cascade
#
#
# OG Orders left:  1684870
# Cascade length:  52
# New Orders left:  1684818
# making new cascade
#
#
# OG Orders left:  1684818
# Cascade length:  1254
# New Orders left:  1683564
# making new cascade
#
#
# OG Orders left:  1683564
# Cascade length:  98
# New Orders left:  1683466
# making new cascade
#
#
# OG Orders left:  1683466
# Cascade length:  1
# New Orders left:  1683465
# making new cascade
#
#
# OG Orders left:  1683465
# Cascade length:  21
# New Orders left:  1683444
# making new cascade
#
#
# OG Orders left:  1683444
# Cascade length:  1115
# New Orders left:  1682329
# making new cascade
#
#
# OG Orders left:  1682329
# Cascade length:  1258
# New Orders left:  1681071
# making new cascade
#
#
# OG Orders left:  1681071
# Cascade length:  516
# New Orders left:  1680555
# making new cascade
#
#
# OG Orders left:  1680555
# Cascade length:  78
# New Orders left:  1680477
# making new cascade
#
#
# OG Orders left:  1680477
# Cascade length:  790
# New Orders left:  1679687
# making new cascade
#
#
# OG Orders left:  1679687
# Cascade length:  9
# New Orders left:  1679678
# making new cascade
#
#
# OG Orders left:  1679678
# Cascade length:  1
# New Orders left:  1679677
# making new cascade
#
#
# OG Orders left:  1679677
# Cascade length:  991
# New Orders left:  1678686
# making new cascade
#
#
# OG Orders left:  1678686
# Cascade length:  8
# New Orders left:  1678678
# making new cascade
#
#
# OG Orders left:  1678678
# Cascade length:  5
# New Orders left:  1678673
# making new cascade
#
#
# OG Orders left:  1678673
# Cascade length:  4
# New Orders left:  1678669
# making new cascade
#
#
# OG Orders left:  1678669
# Cascade length:  1045
# New Orders left:  1677624
# making new cascade
#
#
# OG Orders left:  1677624
# Cascade length:  921
# New Orders left:  1676703
# making new cascade
#
#
# OG Orders left:  1676703
# Cascade length:  1476
# New Orders left:  1675227
# making new cascade
#
#
# OG Orders left:  1675227
# Cascade length:  2
# New Orders left:  1675225
# making new cascade
#
#
# OG Orders left:  1675225
# Cascade length:  583
# New Orders left:  1674642
# making new cascade
#
#
# OG Orders left:  1674642
# Cascade length:  461
# New Orders left:  1674181
# making new cascade
#
#
# OG Orders left:  1674181
# Cascade length:  885
# New Orders left:  1673296
# making new cascade
#
#
# OG Orders left:  1673296
# Cascade length:  22
# New Orders left:  1673274
# making new cascade
#
#
# OG Orders left:  1673274
# Cascade length:  7
# New Orders left:  1673267
# making new cascade
#
#
# OG Orders left:  1673267
# Cascade length:  843
# New Orders left:  1672424
# making new cascade
#
#
# OG Orders left:  1672424
# Cascade length:  6
# New Orders left:  1672418
# making new cascade
#
#
# OG Orders left:  1672418
# Cascade length:  942
# New Orders left:  1671476
# making new cascade
#
#
# OG Orders left:  1671476
# Cascade length:  12
# New Orders left:  1671464
# making new cascade
#
#
# OG Orders left:  1671464
# Cascade length:  43
# New Orders left:  1671421
# making new cascade
#
#
# OG Orders left:  1671421
# Cascade length:  49
# New Orders left:  1671372
# making new cascade
#
#
# OG Orders left:  1671372
# Cascade length:  533
# New Orders left:  1670839
# making new cascade
#
#
# OG Orders left:  1670839
# Cascade length:  1
# New Orders left:  1670838
# making new cascade
#
#
# OG Orders left:  1670838
# Cascade length:  2
# New Orders left:  1670836
# making new cascade
#
#
# OG Orders left:  1670836
# Cascade length:  778
# New Orders left:  1670058
# making new cascade
#
#
# OG Orders left:  1670058
# Cascade length:  966
# New Orders left:  1669092
# making new cascade
#
#
# OG Orders left:  1669092
# Cascade length:  3
# New Orders left:  1669089
# making new cascade
#
#
# OG Orders left:  1669089
# Cascade length:  772
# New Orders left:  1668317
# making new cascade
#
#
# OG Orders left:  1668317
# Cascade length:  2
# New Orders left:  1668315
# making new cascade
#
#
# OG Orders left:  1668315
# Cascade length:  1
# New Orders left:  1668314
# making new cascade
#
#
# OG Orders left:  1668314
# Cascade length:  3
# New Orders left:  1668311
# making new cascade
#
#
# OG Orders left:  1668311
# Cascade length:  1193
# New Orders left:  1667118
# making new cascade
#
#
# OG Orders left:  1667118
# Cascade length:  4
# New Orders left:  1667114
# making new cascade
#
#
# OG Orders left:  1667114
# Cascade length:  759
# New Orders left:  1666355
# making new cascade
#
#
# OG Orders left:  1666355
# Cascade length:  1294
# New Orders left:  1665061
# making new cascade
#
#
# OG Orders left:  1665061
# Cascade length:  1169
# New Orders left:  1663892
# making new cascade
#
#
# OG Orders left:  1663892
# Cascade length:  660
# New Orders left:  1663232
# making new cascade
#
#
# OG Orders left:  1663232
# Cascade length:  455
# New Orders left:  1662777
# making new cascade
#
#
# OG Orders left:  1662777
# Cascade length:  3
# New Orders left:  1662774
# making new cascade
#
#
# OG Orders left:  1662774
# Cascade length:  1288
# New Orders left:  1661486
# making new cascade
#
#
# OG Orders left:  1661486
# Cascade length:  918
# New Orders left:  1660568
# making new cascade
#
#
# OG Orders left:  1660568
# Cascade length:  43
# New Orders left:  1660525
# making new cascade
#
#
# OG Orders left:  1660525
# Cascade length:  749
# New Orders left:  1659776
# making new cascade
#
#
# OG Orders left:  1659776
# Cascade length:  1171
# New Orders left:  1658605
# making new cascade
#
#
# OG Orders left:  1658605
# Cascade length:  398
# New Orders left:  1658207
# making new cascade
#
#
# OG Orders left:  1658207
# Cascade length:  1
# New Orders left:  1658206
# making new cascade
#
#
# OG Orders left:  1658206
# Cascade length:  800
# New Orders left:  1657406
# making new cascade
#
#
# OG Orders left:  1657406
# Cascade length:  780
# New Orders left:  1656626
# making new cascade
#
#
# OG Orders left:  1656626
# Cascade length:  2
# New Orders left:  1656624
# making new cascade
#
#
# OG Orders left:  1656624
# Cascade length:  4
# New Orders left:  1656620
# making new cascade
#
#
# OG Orders left:  1656620
# Cascade length:  2
# New Orders left:  1656618
# making new cascade
#
#
# OG Orders left:  1656618
# Cascade length:  892
# New Orders left:  1655726
# making new cascade
#
#
# OG Orders left:  1655726
# Cascade length:  706
# New Orders left:  1655020
# making new cascade
#
#
# OG Orders left:  1655020
# Cascade length:  25
# New Orders left:  1654995
# making new cascade
#
#
# OG Orders left:  1654995
# Cascade length:  1053
# New Orders left:  1653942
# making new cascade
#
#
# OG Orders left:  1653942
# Cascade length:  1035
# New Orders left:  1652907
# making new cascade
#
#
# OG Orders left:  1652907
# Cascade length:  178
# New Orders left:  1652729
# making new cascade
#
#
# OG Orders left:  1652729
# Cascade length:  30
# New Orders left:  1652699
# making new cascade
#
#
# OG Orders left:  1652699
# Cascade length:  125
# New Orders left:  1652574
# making new cascade
#
#
# OG Orders left:  1652574
# Cascade length:  1078
# New Orders left:  1651496
# making new cascade
#
#
# OG Orders left:  1651496
# Cascade length:  2
# New Orders left:  1651494
# making new cascade
#
#
# OG Orders left:  1651494
# Cascade length:  54
# New Orders left:  1651440
# making new cascade
#
#
# OG Orders left:  1651440
# Cascade length:  5
# New Orders left:  1651435
# making new cascade
#
#
# OG Orders left:  1651435
# Cascade length:  90
# New Orders left:  1651345
# making new cascade
#
#
# OG Orders left:  1651345
# Cascade length:  11
# New Orders left:  1651334
# making new cascade
#
#
# OG Orders left:  1651334
# Cascade length:  2
# New Orders left:  1651332
# making new cascade
#
#
# OG Orders left:  1651332
# Cascade length:  544
# New Orders left:  1650788
# making new cascade
#
#
# OG Orders left:  1650788
# Cascade length:  1
# New Orders left:  1650787
# making new cascade
#
#
# OG Orders left:  1650787
# Cascade length:  1045
# New Orders left:  1649742
# making new cascade
#
#
# OG Orders left:  1649742
# Cascade length:  3
# New Orders left:  1649739
# making new cascade
#
#
# OG Orders left:  1649739
# Cascade length:  787
# New Orders left:  1648952
# making new cascade
#
#
# OG Orders left:  1648952
# Cascade length:  39
# New Orders left:  1648913
# making new cascade
#
#
# OG Orders left:  1648913
# Cascade length:  2
# New Orders left:  1648911
# making new cascade
#
#
# OG Orders left:  1648911
# Cascade length:  502
# New Orders left:  1648409
# making new cascade
#
#
# OG Orders left:  1648409
# Cascade length:  71
# New Orders left:  1648338
# making new cascade
#
#
# OG Orders left:  1648338
# Cascade length:  12
# New Orders left:  1648326
# making new cascade
#
#
# OG Orders left:  1648326
# Cascade length:  3
# New Orders left:  1648323
# making new cascade
#
#
# OG Orders left:  1648323
# Cascade length:  2
# New Orders left:  1648321
# making new cascade
#
#
# OG Orders left:  1648321
# Cascade length:  973
# New Orders left:  1647348
# making new cascade
#
#
# OG Orders left:  1647348
# Cascade length:  1148
# New Orders left:  1646200
# making new cascade
#
#
# OG Orders left:  1646200
# Cascade length:  560
# New Orders left:  1645640
# making new cascade
#
#
# OG Orders left:  1645640
# Cascade length:  62
# New Orders left:  1645578
# making new cascade
#
#
# OG Orders left:  1645578
# Cascade length:  628
# New Orders left:  1644950
# making new cascade
#
#
# OG Orders left:  1644950
# Cascade length:  923
# New Orders left:  1644027
# making new cascade
#
#
# OG Orders left:  1644027
# Cascade length:  76
# New Orders left:  1643951
# making new cascade
#
#
# OG Orders left:  1643951
# Cascade length:  1108
# New Orders left:  1642843
# making new cascade
#
#
# OG Orders left:  1642843
# Cascade length:  4
# New Orders left:  1642839
# making new cascade
#
#
# OG Orders left:  1642839
# Cascade length:  508
# New Orders left:  1642331
# making new cascade
#
#
# OG Orders left:  1642331
# Cascade length:  3
# New Orders left:  1642328
# making new cascade
#
#
# OG Orders left:  1642328
# Cascade length:  90
# New Orders left:  1642238
# making new cascade
#
#
# OG Orders left:  1642238
# Cascade length:  22
# New Orders left:  1642216
# making new cascade
#
#
# OG Orders left:  1642216
# Cascade length:  12
# New Orders left:  1642204
# making new cascade
#
#
# OG Orders left:  1642204
# Cascade length:  2
# New Orders left:  1642202
# making new cascade
#
#
# OG Orders left:  1642202
# Cascade length:  1
# New Orders left:  1642201
# making new cascade
#
#
# OG Orders left:  1642201
# Cascade length:  691
# New Orders left:  1641510
# making new cascade
#
#
# OG Orders left:  1641510
# Cascade length:  176
# New Orders left:  1641334
# making new cascade
#
#
# OG Orders left:  1641334
# Cascade length:  981
# New Orders left:  1640353
# making new cascade
#
#
# OG Orders left:  1640353
# Cascade length:  866
# New Orders left:  1639487
# making new cascade
#
#
# OG Orders left:  1639487
# Cascade length:  2
# New Orders left:  1639485
# making new cascade
#
#
# OG Orders left:  1639485
# Cascade length:  8
# New Orders left:  1639477
# making new cascade
#
#
# OG Orders left:  1639477
# Cascade length:  5
# New Orders left:  1639472
# making new cascade
#
#
# OG Orders left:  1639472
# Cascade length:  1
# New Orders left:  1639471
# making new cascade
#
#
# OG Orders left:  1639471
# Cascade length:  43
# New Orders left:  1639428
# making new cascade
#
#
# OG Orders left:  1639428
# Cascade length:  860
# New Orders left:  1638568
# making new cascade
#
#
# OG Orders left:  1638568
# Cascade length:  3
# New Orders left:  1638565
# making new cascade
#
#
# OG Orders left:  1638565
# Cascade length:  3
# New Orders left:  1638562
# making new cascade
#
#
# OG Orders left:  1638562
# Cascade length:  138
# New Orders left:  1638424
# making new cascade
#
#
# OG Orders left:  1638424
# Cascade length:  34
# New Orders left:  1638390
# making new cascade
#
#
# OG Orders left:  1638390
# Cascade length:  1
# New Orders left:  1638389
# making new cascade
#
#
# OG Orders left:  1638389
# Cascade length:  37
# New Orders left:  1638352
# making new cascade
#
#
# OG Orders left:  1638352
# Cascade length:  42
# New Orders left:  1638310
# making new cascade
#
#
# OG Orders left:  1638310
# Cascade length:  1
# New Orders left:  1638309
# making new cascade
#
#
# OG Orders left:  1638309
# Cascade length:  1016
# New Orders left:  1637293
# making new cascade
#
#
# OG Orders left:  1637293
# Cascade length:  662
# New Orders left:  1636631
# making new cascade
#
#
# OG Orders left:  1636631
# Cascade length:  37
# New Orders left:  1636594
# making new cascade
#
#
# OG Orders left:  1636594
# Cascade length:  1
# New Orders left:  1636593
# making new cascade
#
#
# OG Orders left:  1636593
# Cascade length:  2
# New Orders left:  1636591
# making new cascade
#
#
# OG Orders left:  1636591
# Cascade length:  681
# New Orders left:  1635910
# making new cascade
#
#
# OG Orders left:  1635910
# Cascade length:  1
# New Orders left:  1635909
# making new cascade
#
#
# OG Orders left:  1635909
# Cascade length:  13
# New Orders left:  1635896
# making new cascade
#
#
# OG Orders left:  1635896
# Cascade length:  3
# New Orders left:  1635893
# making new cascade
#
#
# OG Orders left:  1635893
# Cascade length:  5
# New Orders left:  1635888
# making new cascade
#
#
# OG Orders left:  1635888
# Cascade length:  971
# New Orders left:  1634917
# making new cascade
#
#
# OG Orders left:  1634917
# Cascade length:  22
# New Orders left:  1634895
# making new cascade
#
#
# OG Orders left:  1634895
# Cascade length:  4
# New Orders left:  1634891
# making new cascade
#
#
# OG Orders left:  1634891
# Cascade length:  1
# New Orders left:  1634890
# making new cascade
#
#
# OG Orders left:  1634890
# Cascade length:  37
# New Orders left:  1634853
# making new cascade
#
#
# OG Orders left:  1634853
# Cascade length:  1
# New Orders left:  1634852
# making new cascade
#
#
# OG Orders left:  1634852
# Cascade length:  16
# New Orders left:  1634836
# making new cascade
#
#
# OG Orders left:  1634836
# Cascade length:  2
# New Orders left:  1634834
# making new cascade
#
#
# OG Orders left:  1634834
# Cascade length:  519
# New Orders left:  1634315
# making new cascade
#
#
# OG Orders left:  1634315
# Cascade length:  1060
# New Orders left:  1633255
# making new cascade
#
#
# OG Orders left:  1633255
# Cascade length:  2
# New Orders left:  1633253
# making new cascade
#
#
# OG Orders left:  1633253
# Cascade length:  95
# New Orders left:  1633158
# making new cascade
#
#
# OG Orders left:  1633158
# Cascade length:  2
# New Orders left:  1633156
# making new cascade
#
#
# OG Orders left:  1633156
# Cascade length:  812
# New Orders left:  1632344
# making new cascade
#
#
# OG Orders left:  1632344
# Cascade length:  2
# New Orders left:  1632342
# making new cascade
#
#
# OG Orders left:  1632342
# Cascade length:  1
# New Orders left:  1632341
# making new cascade
#
#
# OG Orders left:  1632341
# Cascade length:  11
# New Orders left:  1632330
# making new cascade
#
#
# OG Orders left:  1632330
# Cascade length:  159
# New Orders left:  1632171
# making new cascade
#
#
# OG Orders left:  1632171
# Cascade length:  14
# New Orders left:  1632157
# making new cascade
#
#
# OG Orders left:  1632157
# Cascade length:  24
# New Orders left:  1632133
# making new cascade
#
#
# OG Orders left:  1632133
# Cascade length:  2
# New Orders left:  1632131
# making new cascade
#
#
# OG Orders left:  1632131
# Cascade length:  20
# New Orders left:  1632111
# making new cascade
#
#
# OG Orders left:  1632111
# Cascade length:  2
# New Orders left:  1632109
# making new cascade
#
#
# OG Orders left:  1632109
# Cascade length:  1
# New Orders left:  1632108
# making new cascade
#
#
# OG Orders left:  1632108
# Cascade length:  701
# New Orders left:  1631407
# making new cascade
#
#
# OG Orders left:  1631407
# Cascade length:  12
# New Orders left:  1631395
# making new cascade
#
#
# OG Orders left:  1631395
# Cascade length:  2
# New Orders left:  1631393
# making new cascade
#
#
# OG Orders left:  1631393
# Cascade length:  90
# New Orders left:  1631303
# making new cascade
#
#
# OG Orders left:  1631303
# Cascade length:  736
# New Orders left:  1630567
# making new cascade
#
#
# OG Orders left:  1630567
# Cascade length:  675
# New Orders left:  1629892
# making new cascade
#
#
# OG Orders left:  1629892
# Cascade length:  762
# New Orders left:  1629130
# making new cascade
#
#
# OG Orders left:  1629130
# Cascade length:  910
# New Orders left:  1628220
# making new cascade
#
#
# OG Orders left:  1628220
# Cascade length:  22
# New Orders left:  1628198
# making new cascade
#
#
# OG Orders left:  1628198
# Cascade length:  1
# New Orders left:  1628197
# making new cascade
#
#
# OG Orders left:  1628197
# Cascade length:  714
# New Orders left:  1627483
# making new cascade
#
#
# OG Orders left:  1627483
# Cascade length:  2
# New Orders left:  1627481
# making new cascade
#
#
# OG Orders left:  1627481
# Cascade length:  841
# New Orders left:  1626640
# making new cascade
#
#
# OG Orders left:  1626640
# Cascade length:  1
# New Orders left:  1626639
# making new cascade
#
#
# OG Orders left:  1626639
# Cascade length:  1065
# New Orders left:  1625574
# making new cascade
#
#
# OG Orders left:  1625574
# Cascade length:  1
# New Orders left:  1625573
# making new cascade
#
#
# OG Orders left:  1625573
# Cascade length:  3
# New Orders left:  1625570
# making new cascade
#
#
# OG Orders left:  1625570
# Cascade length:  648
# New Orders left:  1624922
# making new cascade
#
#
# OG Orders left:  1624922
# Cascade length:  19
# New Orders left:  1624903
# making new cascade
#
#
# OG Orders left:  1624903
# Cascade length:  499
# New Orders left:  1624404
# making new cascade
#
#
# OG Orders left:  1624404
# Cascade length:  207
# New Orders left:  1624197
# making new cascade
#
#
# OG Orders left:  1624197
# Cascade length:  2
# New Orders left:  1624195
# making new cascade
#
#
# OG Orders left:  1624195
# Cascade length:  1
# New Orders left:  1624194
# making new cascade
#
#
# OG Orders left:  1624194
# Cascade length:  797
# New Orders left:  1623397
# making new cascade
#
#
# OG Orders left:  1623397
# Cascade length:  27
# New Orders left:  1623370
# making new cascade
#
#
# OG Orders left:  1623370
# Cascade length:  628
# New Orders left:  1622742
# making new cascade
#
#
# OG Orders left:  1622742
# Cascade length:  27
# New Orders left:  1622715
# making new cascade
#
#
# OG Orders left:  1622715
# Cascade length:  8
# New Orders left:  1622707
# making new cascade
#
#
# OG Orders left:  1622707
# Cascade length:  870
# New Orders left:  1621837
# making new cascade
#
#
# OG Orders left:  1621837
# Cascade length:  888
# New Orders left:  1620949
# making new cascade
#
#
# OG Orders left:  1620949
# Cascade length:  3
# New Orders left:  1620946
# making new cascade
#
#
# OG Orders left:  1620946
# Cascade length:  6
# New Orders left:  1620940
# making new cascade
#
#
# OG Orders left:  1620940
# Cascade length:  1142
# New Orders left:  1619798
# making new cascade
#
#
# OG Orders left:  1619798
# Cascade length:  2
# New Orders left:  1619796
# making new cascade
#
#
# OG Orders left:  1619796
# Cascade length:  12
# New Orders left:  1619784
# making new cascade
#
#
# OG Orders left:  1619784
# Cascade length:  1
# New Orders left:  1619783
# making new cascade
#
#
# OG Orders left:  1619783
# Cascade length:  18
# New Orders left:  1619765
# making new cascade
#
#
# OG Orders left:  1619765
# Cascade length:  1
# New Orders left:  1619764
# making new cascade
#
#
# OG Orders left:  1619764
# Cascade length:  2
# New Orders left:  1619762
# making new cascade
#
#
# OG Orders left:  1619762
# Cascade length:  214
# New Orders left:  1619548
# making new cascade
#
#
# OG Orders left:  1619548
# Cascade length:  4
# New Orders left:  1619544
# making new cascade
#
#
# OG Orders left:  1619544
# Cascade length:  831
# New Orders left:  1618713
# making new cascade
#
#
# OG Orders left:  1618713
# Cascade length:  696
# New Orders left:  1618017
# making new cascade
#
#
# OG Orders left:  1618017
# Cascade length:  602
# New Orders left:  1617415
# making new cascade
#
#
# OG Orders left:  1617415
# Cascade length:  2
# New Orders left:  1617413
# making new cascade
#
#
# OG Orders left:  1617413
# Cascade length:  827
# New Orders left:  1616586
# making new cascade
#
#
# OG Orders left:  1616586
# Cascade length:  45
# New Orders left:  1616541
# making new cascade
#
#
# OG Orders left:  1616541
# Cascade length:  1
# New Orders left:  1616540
# making new cascade
#
#
# OG Orders left:  1616540
# Cascade length:  877
# New Orders left:  1615663
# making new cascade
#
#
# OG Orders left:  1615663
# Cascade length:  1
# New Orders left:  1615662
# making new cascade
#
#
# OG Orders left:  1615662
# Cascade length:  743
# New Orders left:  1614919
# making new cascade
#
#
# OG Orders left:  1614919
# Cascade length:  33
# New Orders left:  1614886
# making new cascade
#
#
# OG Orders left:  1614886
# Cascade length:  2
# New Orders left:  1614884
# making new cascade
#
#
# OG Orders left:  1614884
# Cascade length:  668
# New Orders left:  1614216
# making new cascade
#
#
# OG Orders left:  1614216
# Cascade length:  56
# New Orders left:  1614160
# making new cascade
#
#
# OG Orders left:  1614160
# Cascade length:  586
# New Orders left:  1613574
# making new cascade
#
#
# OG Orders left:  1613574
# Cascade length:  1
# New Orders left:  1613573
# making new cascade
#
#
# OG Orders left:  1613573
# Cascade length:  2
# New Orders left:  1613571
# making new cascade
#
#
# OG Orders left:  1613571
# Cascade length:  21
# New Orders left:  1613550
# making new cascade
#
#
# OG Orders left:  1613550
# Cascade length:  6
# New Orders left:  1613544
# making new cascade
#
#
# OG Orders left:  1613544
# Cascade length:  1048
# New Orders left:  1612496
# making new cascade
#
#
# OG Orders left:  1612496
# Cascade length:  1
# New Orders left:  1612495
# making new cascade
#
#
# OG Orders left:  1612495
# Cascade length:  3
# New Orders left:  1612492
# making new cascade
#
#
# OG Orders left:  1612492
# Cascade length:  3
# New Orders left:  1612489
# making new cascade
#
#
# OG Orders left:  1612489
# Cascade length:  544
# New Orders left:  1611945
# making new cascade
#
#
# OG Orders left:  1611945
# Cascade length:  697
# New Orders left:  1611248
# making new cascade
#
#
# OG Orders left:  1611248
# Cascade length:  692
# New Orders left:  1610556
# making new cascade
#
#
# OG Orders left:  1610556
# Cascade length:  45
# New Orders left:  1610511
# making new cascade
#
#
# OG Orders left:  1610511
# Cascade length:  72
# New Orders left:  1610439
# making new cascade
#
#
# OG Orders left:  1610439
# Cascade length:  6
# New Orders left:  1610433
# making new cascade
#
#
# OG Orders left:  1610433
# Cascade length:  842
# New Orders left:  1609591
# making new cascade
#
#
# OG Orders left:  1609591
# Cascade length:  19
# New Orders left:  1609572
# making new cascade
#
#
# OG Orders left:  1609572
# Cascade length:  4
# New Orders left:  1609568
# making new cascade
#
#
# OG Orders left:  1609568
# Cascade length:  433
# New Orders left:  1609135
# making new cascade
#
#
# OG Orders left:  1609135
# Cascade length:  12
# New Orders left:  1609123
# making new cascade
#
#
# OG Orders left:  1609123
# Cascade length:  4
# New Orders left:  1609119
# making new cascade
#
#
# OG Orders left:  1609119
# Cascade length:  32
# New Orders left:  1609087
# making new cascade
#
#
# OG Orders left:  1609087
# Cascade length:  224
# New Orders left:  1608863
# making new cascade
#
#
# OG Orders left:  1608863
# Cascade length:  2
# New Orders left:  1608861
# making new cascade
#
#
# OG Orders left:  1608861
# Cascade length:  2
# New Orders left:  1608859
# making new cascade
#
#
# OG Orders left:  1608859
# Cascade length:  1073
# New Orders left:  1607786
# making new cascade
#
#
# OG Orders left:  1607786
# Cascade length:  1
# New Orders left:  1607785
# making new cascade
#
#
# OG Orders left:  1607785
# Cascade length:  8
# New Orders left:  1607777
# making new cascade
#
#
# OG Orders left:  1607777
# Cascade length:  805
# New Orders left:  1606972
# making new cascade
#
#
# OG Orders left:  1606972
# Cascade length:  1428
# New Orders left:  1605544
# making new cascade
#
#
# OG Orders left:  1605544
# Cascade length:  2
# New Orders left:  1605542
# making new cascade
#
#
# OG Orders left:  1605542
# Cascade length:  257
# New Orders left:  1605285
# making new cascade
#
#
# OG Orders left:  1605285
# Cascade length:  87
# New Orders left:  1605198
# making new cascade
#
#
# OG Orders left:  1605198
# Cascade length:  1
# New Orders left:  1605197
# making new cascade
#
#
# OG Orders left:  1605197
# Cascade length:  8
# New Orders left:  1605189
# making new cascade
#
#
# OG Orders left:  1605189
# Cascade length:  1
# New Orders left:  1605188
# making new cascade
#
#
# OG Orders left:  1605188
# Cascade length:  1
# New Orders left:  1605187
# making new cascade
#
#
# OG Orders left:  1605187
# Cascade length:  731
# New Orders left:  1604456
# ...
#
#
# OG Orders left:  68009
# Cascade length:  1730
# New Orders left:  66279
# making new cascade
#
#
# OG Orders left:  66279
# Cascade length:  23
# New Orders left:  66256
# making new cascade
#
#
# OG Orders left:  66256
# Cascade length:  1347
# New Orders left:  64909
# making new cascade
#
#
# OG Orders left:  64909
# Cascade length:  1
# New Orders left:  64908
# making new cascade
#
#
# OG Orders left:  64908
# Cascade length:  1051
# New Orders left:  63857
# making new cascade
#
#
# OG Orders left:  63857
# Cascade length:  1137
# New Orders left:  62720
# making new cascade
#
#
# OG Orders left:  62720
# Cascade length:  1450
# New Orders left:  61270
# making new cascade
#
#
# OG Orders left:  61270
# Cascade length:  682
# New Orders left:  60588
# making new cascade
#
#
# OG Orders left:  60588
# Cascade length:  1
# New Orders left:  60587
# making new cascade
#
#
# OG Orders left:  60587
# Cascade length:  1117
# New Orders left:  59470
# making new cascade
#
#
# OG Orders left:  59470
# Cascade length:  1349
# New Orders left:  58121
# making new cascade
#
#
# OG Orders left:  58121
# Cascade length:  1332
# New Orders left:  56789
# making new cascade
#
#
# OG Orders left:  56789
# Cascade length:  1245
# New Orders left:  55544
# making new cascade
#
#
# OG Orders left:  55544
# Cascade length:  6
# New Orders left:  55538
# making new cascade
#
#
# OG Orders left:  55538
# Cascade length:  12
# New Orders left:  55526
# making new cascade
#
#
# OG Orders left:  55526
# Cascade length:  1427
# New Orders left:  54099
# making new cascade
#
#
# OG Orders left:  54099
# Cascade length:  557
# New Orders left:  53542
# making new cascade
#
#
# OG Orders left:  53542
# Cascade length:  2
# New Orders left:  53540
# making new cascade
#
#
# OG Orders left:  53540
# Cascade length:  955
# New Orders left:  52585
# making new cascade
#
#
# OG Orders left:  52585
# Cascade length:  774
# New Orders left:  51811
# making new cascade
#
#
# OG Orders left:  51811
# Cascade length:  3
# New Orders left:  51808
# making new cascade
#
#
# OG Orders left:  51808
# Cascade length:  4
# New Orders left:  51804
# making new cascade
#
#
# OG Orders left:  51804
# Cascade length:  1427
# New Orders left:  50377
# making new cascade
#
#
# OG Orders left:  50377
# Cascade length:  1
# New Orders left:  50376
# making new cascade
#
#
# OG Orders left:  50376
# Cascade length:  941
# New Orders left:  49435
# making new cascade
#
#
# OG Orders left:  49435
# Cascade length:  1116
# New Orders left:  48319
# making new cascade
#
#
# OG Orders left:  48319
# Cascade length:  1114
# New Orders left:  47205
# making new cascade
#
#
# OG Orders left:  47205
# Cascade length:  1526
# New Orders left:  45679
# making new cascade
#
#
# OG Orders left:  45679
# Cascade length:  10
# New Orders left:  45669
# making new cascade
#
#
# OG Orders left:  45669
# Cascade length:  1
# New Orders left:  45668
# making new cascade
#
#
# OG Orders left:  45668
# Cascade length:  1373
# New Orders left:  44295
# making new cascade
#
#
# OG Orders left:  44295
# Cascade length:  3
# New Orders left:  44292
# making new cascade
#
#
# OG Orders left:  44292
# Cascade length:  1080
# New Orders left:  43212
# making new cascade
#
#
# OG Orders left:  43212
# Cascade length:  1194
# New Orders left:  42018
# making new cascade
#
#
# OG Orders left:  42018
# Cascade length:  1460
# New Orders left:  40558
# making new cascade
#
#
# OG Orders left:  40558
# Cascade length:  1589
# New Orders left:  38969
# making new cascade
#
#
# OG Orders left:  38969
# Cascade length:  32
# New Orders left:  38937
# making new cascade
#
#
# OG Orders left:  38937
# Cascade length:  1178
# New Orders left:  37759
# making new cascade
#
#
# OG Orders left:  37759
# Cascade length:  1038
# New Orders left:  36721
# making new cascade
#
#
# OG Orders left:  36721
# Cascade length:  1
# New Orders left:  36720
# making new cascade
#
#
# OG Orders left:  36720
# Cascade length:  1392
# New Orders left:  35328
# making new cascade
#
#
# OG Orders left:  35328
# Cascade length:  9
# New Orders left:  35319
# making new cascade
#
#
# OG Orders left:  35319
# Cascade length:  1647
# New Orders left:  33672
# making new cascade
#
#
# OG Orders left:  33672
# Cascade length:  19
# New Orders left:  33653
# making new cascade
#
#
# OG Orders left:  33653
# Cascade length:  2
# New Orders left:  33651
# making new cascade
#
#
# OG Orders left:  33651
# Cascade length:  32
# New Orders left:  33619
# making new cascade
#
#
# OG Orders left:  33619
# Cascade length:  724
# New Orders left:  32895
# making new cascade
#
#
# OG Orders left:  32895
# Cascade length:  2
# New Orders left:  32893
# making new cascade
#
#
# OG Orders left:  32893
# Cascade length:  1179
# New Orders left:  31714
# making new cascade
#
#
# OG Orders left:  31714
# Cascade length:  8
# New Orders left:  31706
# making new cascade
#
#
# OG Orders left:  31706
# Cascade length:  75
# New Orders left:  31631
# making new cascade
#
#
# OG Orders left:  31631
# Cascade length:  449
# New Orders left:  31182
# making new cascade
#
#
# OG Orders left:  31182
# Cascade length:  1
# New Orders left:  31181
# making new cascade
#
#
# OG Orders left:  31181
# Cascade length:  711
# New Orders left:  30470
# making new cascade
#
#
# OG Orders left:  30470
# Cascade length:  12
# New Orders left:  30458
# making new cascade
#
#
# OG Orders left:  30458
# Cascade length:  1
# New Orders left:  30457
# making new cascade
#
#
# OG Orders left:  30457
# Cascade length:  930
# New Orders left:  29527
# making new cascade
#
#
# OG Orders left:  29527
# Cascade length:  8
# New Orders left:  29519
# making new cascade
#
#
# OG Orders left:  29519
# Cascade length:  776
# New Orders left:  28743
# making new cascade
#
#
# OG Orders left:  28743
# Cascade length:  1
# New Orders left:  28742
# making new cascade
#
#
# OG Orders left:  28742
# Cascade length:  78
# New Orders left:  28664
# making new cascade
#
#
# OG Orders left:  28664
# Cascade length:  1019
# New Orders left:  27645
# making new cascade
#
#
# OG Orders left:  27645
# Cascade length:  63
# New Orders left:  27582
# making new cascade
#
#
# OG Orders left:  27582
# Cascade length:  1079
# New Orders left:  26503
# making new cascade
#
#
# OG Orders left:  26503
# Cascade length:  719
# New Orders left:  25784
# making new cascade
#
#
# OG Orders left:  25784
# Cascade length:  567
# New Orders left:  25217
# making new cascade
#
#
# OG Orders left:  25217
# Cascade length:  13
# New Orders left:  25204
# making new cascade
#
#
# OG Orders left:  25204
# Cascade length:  921
# New Orders left:  24283
# making new cascade
#
#
# OG Orders left:  24283
# Cascade length:  1088
# New Orders left:  23195
# making new cascade
#
#
# OG Orders left:  23195
# Cascade length:  188
# New Orders left:  23007
# making new cascade
#
#
# OG Orders left:  23007
# Cascade length:  1218
# New Orders left:  21789
# making new cascade
#
#
# OG Orders left:  21789
# Cascade length:  4
# New Orders left:  21785
# making new cascade
#
#
# OG Orders left:  21785
# Cascade length:  1010
# New Orders left:  20775
# making new cascade
#
#
# OG Orders left:  20775
# Cascade length:  1
# New Orders left:  20774
# making new cascade
#
#
# OG Orders left:  20774
# Cascade length:  908
# New Orders left:  19866
# making new cascade
#
#
# OG Orders left:  19866
# Cascade length:  2
# New Orders left:  19864
# making new cascade
#
#
# OG Orders left:  19864
# Cascade length:  1
# New Orders left:  19863
# making new cascade
#
#
# OG Orders left:  19863
# Cascade length:  645
# New Orders left:  19218
# making new cascade
#
#
# OG Orders left:  19218
# Cascade length:  72
# New Orders left:  19146
# making new cascade
#
#
# OG Orders left:  19146
# Cascade length:  558
# New Orders left:  18588
# making new cascade
#
#
# OG Orders left:  18588
# Cascade length:  658
# New Orders left:  17930
# making new cascade
#
#
# OG Orders left:  17930
# Cascade length:  901
# New Orders left:  17029
# making new cascade
#
#
# OG Orders left:  17029
# Cascade length:  823
# New Orders left:  16206
# making new cascade
#
#
# OG Orders left:  16206
# Cascade length:  68
# New Orders left:  16138
# making new cascade
#
#
# OG Orders left:  16138
# Cascade length:  413
# New Orders left:  15725
# making new cascade
#
#
# OG Orders left:  15725
# Cascade length:  6
# New Orders left:  15719
# making new cascade
#
#
# OG Orders left:  15719
# Cascade length:  5
# New Orders left:  15714
# making new cascade
#
#
# OG Orders left:  15714
# Cascade length:  531
# New Orders left:  15183
# making new cascade
#
#
# OG Orders left:  15183
# Cascade length:  776
# New Orders left:  14407
# making new cascade
#
#
# OG Orders left:  14407
# Cascade length:  46
# New Orders left:  14361
# making new cascade
#
#
# OG Orders left:  14361
# Cascade length:  743
# New Orders left:  13618
# making new cascade
#
#
# OG Orders left:  13618
# Cascade length:  609
# New Orders left:  13009
# making new cascade
#
#
# OG Orders left:  13009
# Cascade length:  46
# New Orders left:  12963
# making new cascade
#
#
# OG Orders left:  12963
# Cascade length:  7
# New Orders left:  12956
# making new cascade
#
#
# OG Orders left:  12956
# Cascade length:  352
# New Orders left:  12604
# making new cascade
#
#
# OG Orders left:  12604
# Cascade length:  666
# New Orders left:  11938
# making new cascade
#
#
# OG Orders left:  11938
# Cascade length:  2
# New Orders left:  11936
# making new cascade
#
#
# OG Orders left:  11936
# Cascade length:  637
# New Orders left:  11299
# making new cascade
#
#
# OG Orders left:  11299
# Cascade length:  528
# New Orders left:  10771
# making new cascade
#
#
# OG Orders left:  10771
# Cascade length:  443
# New Orders left:  10328
# making new cascade
#
#
# OG Orders left:  10328
# Cascade length:  20
# New Orders left:  10308
# making new cascade
#
#
# OG Orders left:  10308
# Cascade length:  1
# New Orders left:  10307
# making new cascade
#
#
# OG Orders left:  10307
# Cascade length:  589
# New Orders left:  9718
# making new cascade
#
#
# OG Orders left:  9718
# Cascade length:  491
# New Orders left:  9227
# making new cascade
#
#
# OG Orders left:  9227
# Cascade length:  440
# New Orders left:  8787
# making new cascade
#
#
# OG Orders left:  8787
# Cascade length:  4
# New Orders left:  8783
# making new cascade
#
#
# OG Orders left:  8783
# Cascade length:  601
# New Orders left:  8182
# making new cascade
#
#
# OG Orders left:  8182
# Cascade length:  302
# New Orders left:  7880
# making new cascade
#
#
# OG Orders left:  7880
# Cascade length:  523
# New Orders left:  7357
# making new cascade
#
#
# OG Orders left:  7357
# Cascade length:  233
# New Orders left:  7124
# making new cascade
#
#
# OG Orders left:  7124
# Cascade length:  6
# New Orders left:  7118
# making new cascade
#
#
# OG Orders left:  7118
# Cascade length:  1
# New Orders left:  7117
# making new cascade
#
#
# OG Orders left:  7117
# Cascade length:  5
# New Orders left:  7112
# making new cascade
#
#
# OG Orders left:  7112
# Cascade length:  365
# New Orders left:  6747
# making new cascade
#
#
# OG Orders left:  6747
# Cascade length:  3
# New Orders left:  6744
# making new cascade
#
#
# OG Orders left:  6744
# Cascade length:  37
# New Orders left:  6707
# making new cascade
#
#
# OG Orders left:  6707
# Cascade length:  354
# New Orders left:  6353
# making new cascade
#
#
# OG Orders left:  6353
# Cascade length:  424
# New Orders left:  5929
# making new cascade
#
#
# OG Orders left:  5929
# Cascade length:  219
# New Orders left:  5710
# making new cascade
#
#
# OG Orders left:  5710
# Cascade length:  505
# New Orders left:  5205
# making new cascade
#
#
# OG Orders left:  5205
# Cascade length:  233
# New Orders left:  4972
# making new cascade
#
#
# OG Orders left:  4972
# Cascade length:  6
# New Orders left:  4966
# making new cascade
#
#
# OG Orders left:  4966
# Cascade length:  396
# New Orders left:  4570
# making new cascade
#
#
# OG Orders left:  4570
# Cascade length:  4
# New Orders left:  4566
# making new cascade
#
#
# OG Orders left:  4566
# Cascade length:  340
# New Orders left:  4226
# making new cascade
#
#
# OG Orders left:  4226
# Cascade length:  7
# New Orders left:  4219
# making new cascade
#
#
# OG Orders left:  4219
# Cascade length:  293
# New Orders left:  3926
# making new cascade
#
#
# OG Orders left:  3926
# Cascade length:  328
# New Orders left:  3598
# making new cascade
#
#
# OG Orders left:  3598
# Cascade length:  248
# New Orders left:  3350
# making new cascade
#
#
# OG Orders left:  3350
# Cascade length:  230
# New Orders left:  3120
# making new cascade
#
#
# OG Orders left:  3120
# Cascade length:  10
# New Orders left:  3110
# making new cascade
#
#
# OG Orders left:  3110
# Cascade length:  344
# New Orders left:  2766
# making new cascade
#
#
# OG Orders left:  2766
# Cascade length:  186
# New Orders left:  2580
# making new cascade
#
#
# OG Orders left:  2580
# Cascade length:  5
# New Orders left:  2575
# making new cascade
#
#
# OG Orders left:  2575
# Cascade length:  244
# New Orders left:  2331
# making new cascade
#
#
# OG Orders left:  2331
# Cascade length:  6
# New Orders left:  2325
# making new cascade
#
#
# OG Orders left:  2325
# Cascade length:  326
# New Orders left:  1999
# making new cascade
#
#
# OG Orders left:  1999
# Cascade length:  167
# New Orders left:  1832
# making new cascade
#
#
# OG Orders left:  1832
# Cascade length:  155
# New Orders left:  1677
# making new cascade
#
#
# OG Orders left:  1677
# Cascade length:  143
# New Orders left:  1534
# making new cascade
#
#
# OG Orders left:  1534
# Cascade length:  4
# New Orders left:  1530
# making new cascade
#
#
# OG Orders left:  1530
# Cascade length:  37
# New Orders left:  1493
# making new cascade
#
#
# OG Orders left:  1493
# Cascade length:  76
# New Orders left:  1417
# making new cascade
#
#
# OG Orders left:  1417
# Cascade length:  130
# New Orders left:  1287
# making new cascade
#
#
# OG Orders left:  1287
# Cascade length:  3
# New Orders left:  1284
# making new cascade
#
#
# OG Orders left:  1284
# Cascade length:  90
# New Orders left:  1194
# making new cascade
#
#
# OG Orders left:  1194
# Cascade length:  3
# New Orders left:  1191
# making new cascade
#
#
# OG Orders left:  1191
# Cascade length:  99
# New Orders left:  1092
# making new cascade
#
#
# OG Orders left:  1092
# Cascade length:  105
# New Orders left:  987
# making new cascade
#
#
# OG Orders left:  987
# Cascade length:  2
# New Orders left:  985
# making new cascade
#
#
# OG Orders left:  985
# Cascade length:  92
# New Orders left:  893
# making new cascade
#
#
# OG Orders left:  893
# Cascade length:  2
# New Orders left:  891
# making new cascade
#
#
# OG Orders left:  891
# Cascade length:  108
# New Orders left:  783
# making new cascade
#
#
# OG Orders left:  783
# Cascade length:  91
# New Orders left:  692
# making new cascade
#
#
# OG Orders left:  692
# Cascade length:  6
# New Orders left:  686
# making new cascade
#
#
# OG Orders left:  686
# Cascade length:  1
# New Orders left:  685
# making new cascade
#
#
# OG Orders left:  685
# Cascade length:  7
# New Orders left:  678
# making new cascade
#
#
# OG Orders left:  678
# Cascade length:  3
# New Orders left:  675
# making new cascade
#
#
# OG Orders left:  675
# Cascade length:  2
# New Orders left:  673
# making new cascade
#
#
# OG Orders left:  673
# Cascade length:  9
# New Orders left:  664
# making new cascade
#
#
# OG Orders left:  664
# Cascade length:  98
# New Orders left:  566
# making new cascade
#
#
# OG Orders left:  566
# Cascade length:  100
# New Orders left:  466
# making new cascade
#
#
# OG Orders left:  466
# Cascade length:  63
# New Orders left:  403
# making new cascade
#
#
# OG Orders left:  403
# Cascade length:  7
# New Orders left:  396
# making new cascade
#
#
# OG Orders left:  396
# Cascade length:  51
# New Orders left:  345
# making new cascade
#
#
# OG Orders left:  345
# Cascade length:  4
# New Orders left:  341
# making new cascade
#
#
# OG Orders left:  341
# Cascade length:  16
# New Orders left:  325
# making new cascade
#
#
# OG Orders left:  325
# Cascade length:  1
# New Orders left:  324
# making new cascade
#
#
# OG Orders left:  324
# Cascade length:  5
# New Orders left:  319
# making new cascade
#
#
# OG Orders left:  319
# Cascade length:  46
# New Orders left:  273
# making new cascade
#
#
# OG Orders left:  273
# Cascade length:  40
# New Orders left:  233
# making new cascade
#
#
# OG Orders left:  233
# Cascade length:  40
# New Orders left:  193
# making new cascade
#
#
# OG Orders left:  193
# Cascade length:  75
# New Orders left:  118
# making new cascade
#
#
# OG Orders left:  118
# Cascade length:  1
# New Orders left:  117
# making new cascade
#
#
# OG Orders left:  117
# Cascade length:  7
# New Orders left:  110
# making new cascade
#
#
# OG Orders left:  110
# Cascade length:  20
# New Orders left:  90
# making new cascade
#
#
# OG Orders left:  90
# Cascade length:  8
# New Orders left:  82
# making new cascade
#
#
# OG Orders left:  82
# Cascade length:  36
# New Orders left:  46
# making new cascade
#
#
# OG Orders left:  46
# Cascade length:  13
# New Orders left:  33
# making new cascade
#
#
# OG Orders left:  33
# Cascade length:  20
# New Orders left:  13
# making new cascade
#
#
# OG Orders left:  13
# Cascade length:  6
# New Orders left:  7
# making new cascade
#
#
# OG Orders left:  7
# Cascade length:  4
# New Orders left:  3
# making new cascade
#
#
# OG Orders left:  3
# Cascade length:  1
# New Orders left:  2
# making new cascade
#
#
# OG Orders left:  2
# Cascade length:  2
# New Orders left:  0
# making new cascade

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.9)*2, '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8)/10, '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.65)/5, '-.', label= "$x^{-0.65}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*5, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1), '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1), '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
