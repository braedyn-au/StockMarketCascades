# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from library import utils, config, cascades

# %%
with open('./results/7-9/traderIDs_501_1000_100_new2threshold_fixedhurst.pkl', 'rb') as f:
    traderIDsPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolPC = np.load("./results/7-9/stockPool_501_1000_100_new2threshold_fixedhurst.npy")
hurstPoolPC = np.load("./results/7-9/hurstPool_501_1000_100_new2threshold_fixedhurst.npy")
TtransactionsPC = pd.read_csv("./results/7-9/transactions_501_1000_100_new2threshold_fixedhurst.csv")
TtotalOrdersPC = pd.read_csv("./results/7-9/totalOrders_501_1000_100_new2threshold_fixedhurst.csv")

# %%
cascades_minsep2 = {}

for stock in range(len(stockPoolPC)):
#     print(stock)
    cascades_minsep2 = utils.findStockOrderCascades(TtotalOrdersPC[TtotalOrdersPC['stock']==stock], 
                                                    cascades = cascades_minsep2, minSep = 2)

# %%
sizes, nrows, duration = utils.cascadeAnalyzer(cascades_minsep2, stockPoolPC)
# Out:
# passed cascade 2 of size 2917
# passed cascade 7 of size 5665
# passed cascade 13 of size 399
# passed cascade 24 of size 10888
# passed cascade 31 of size 1810
# passed cascade 37 of size 9214
# passed cascade 43 of size 19751
# passed cascade 51 of size 8534
# passed cascade 67 of size 2900
# passed cascade 70 of size 8092
# passed cascade 74 of size 2093
# passed cascade 95 of size 13214
# passed cascade 98 of size 37
# passed cascade 121 of size 2545
# passed cascade 130 of size 1206
# passed cascade 132 of size 9055
# passed cascade 139 of size 7105
# passed cascade 161 of size 3876
# passed cascade 162 of size 11451
# passed cascade 166 of size 11417
# passed cascade 173 of size 1674
# passed cascade 188 of size 327
# passed cascade 192 of size 1182
# passed cascade 206 of size 8204
# passed cascade 214 of size 2241
# passed cascade 225 of size 11559
# passed cascade 227 of size 25
# passed cascade 233 of size 2613
# passed cascade 236 of size 17838
# passed cascade 250 of size 9050
# passed cascade 266 of size 1639
# passed cascade 268 of size 767
# passed cascade 277 of size 8616
# passed cascade 278 of size 8094
# passed cascade 280 of size 14830
# passed cascade 285 of size 10249
# passed cascade 288 of size 16664
# passed cascade 289 of size 4717
# passed cascade 292 of size 169
# passed cascade 294 of size 5506

# %%
hist, bins = np.histogram(nrows, bins=np.logspace(np.log10(min(nrows)),np.log10(max(nrows)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("PC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/7-9/stockcascadesize_ntrans_79o501p1000s100t_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes, bins=np.logspace(np.log10(min(sizes)),np.log10(max(sizes)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("PC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/7-9/stockcascadesize_ntrans_79o501p1000s100t_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration, bins=np.logspace(np.log10(min(duration)),np.log10(max(duration)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*5, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("PC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/7-9/stockcascadesize_ntrans_79o501p1000s100t_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
cascades_minsep1 = {}

for stock in range(len(stockPoolPC)):
#     print(stock)
    cascades_minsep1 = utils.findStockOrderCascades(TtotalOrdersPC[TtotalOrdersPC['stock']==stock], 
                                                    cascades = cascades_minsep1, minSep = 1)

# %%
sizes1, nrows1, duration1 = utils.cascadeAnalyzer(cascades_minsep1, stockPoolPC)
# Out:
# passed cascade 4 of size 2917
# passed cascade 12 of size 5665
# passed cascade 19 of size 399
# passed cascade 34 of size 10881
# passed cascade 44 of size 1796
# passed cascade 57 of size 9202
# passed cascade 72 of size 19751
# passed cascade 81 of size 8532
# passed cascade 106 of size 2900
# passed cascade 111 of size 8092
# passed cascade 116 of size 2093
# passed cascade 146 of size 13214
# passed cascade 149 of size 25
# passed cascade 185 of size 2257
# passed cascade 205 of size 1195
# passed cascade 209 of size 9028
# passed cascade 220 of size 7639
# passed cascade 222 of size 7105
# passed cascade 258 of size 3876
# passed cascade 261 of size 11451
# passed cascade 271 of size 11417
# passed cascade 284 of size 1659
# passed cascade 308 of size 326
# passed cascade 317 of size 1180
# passed cascade 339 of size 8204
# passed cascade 349 of size 2241
# passed cascade 362 of size 11556
# passed cascade 367 of size 25
# passed cascade 374 of size 10825
# passed cascade 375 of size 2613
# passed cascade 380 of size 17813
# passed cascade 404 of size 9050
# passed cascade 431 of size 1629
# passed cascade 435 of size 756
# passed cascade 452 of size 8616
# passed cascade 453 of size 8094
# passed cascade 456 of size 14830
# passed cascade 463 of size 10249
# passed cascade 467 of size 16664
# passed cascade 468 of size 1520
# passed cascade 469 of size 4717
# passed cascade 475 of size 169
# passed cascade 478 of size 5506

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("PC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/7-9/stockcascadesize_ntrans_79o501p1000s100t_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("PC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/7-9/stockcascadesize_ntrans_79o501p1000s100t_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*5, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("PC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/7-9/stockcascadesize_ntrans_79o501p1000s100t_minSep1_.png", dpi=250)
plt.show()
plt.close()
