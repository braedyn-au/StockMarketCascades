# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_200_7200_100_5_10.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_200_7200_100_5_10.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_200_7200_100_5_10.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_200_7200_100_5_10.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 1   993     yshfc      1   -1.0
# 1                 2   993     yshfc      2   -2.0
# 2                10   993     yshfc     10    1.0
# 3                11   993     yshfc     11    1.0
# 4                13   993     yshfc     13   -1.0
# ...             ...   ...       ...    ...    ...
# 3836251           7  8192     xbcot     35    1.0
# 3836252           9  8192     xbcot     42    1.0
# 3836253           2  8192     jmeyl     76    1.0
# 3836254           3  8192     jmeyl     43   -1.0
# 3836255          16  8192     jmeyl     66   -1.0
#
# [3836256 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades22_npc_200_7200_100_5_10.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1322106

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades21_npc_200_7200_100_5_10.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1322106
# Cascade length:  1681
# New Orders left:  1320425
# making new cascade
#
#
# OG Orders left:  1320425
# Cascade length:  334
# New Orders left:  1320091
# making new cascade
#
#
# OG Orders left:  1320091
# Cascade length:  1594
# New Orders left:  1318497
# making new cascade
#
#
# OG Orders left:  1318497
# Cascade length:  1589
# New Orders left:  1316908
# making new cascade
#
#
# OG Orders left:  1316908
# Cascade length:  3
# New Orders left:  1316905
# making new cascade
#
#
# OG Orders left:  1316905
# Cascade length:  1287
# New Orders left:  1315618
# making new cascade
#
#
# OG Orders left:  1315618
# Cascade length:  1229
# New Orders left:  1314389
# making new cascade
#
#
# OG Orders left:  1314389
# Cascade length:  1855
# New Orders left:  1312534
# making new cascade
#
#
# OG Orders left:  1312534
# Cascade length:  17
# New Orders left:  1312517
# making new cascade
#
#
# OG Orders left:  1312517
# Cascade length:  1212
# New Orders left:  1311305
# making new cascade
#
#
# OG Orders left:  1311305
# Cascade length:  1671
# New Orders left:  1309634
# making new cascade
#
#
# OG Orders left:  1309634
# Cascade length:  1082
# New Orders left:  1308552
# making new cascade
#
#
# OG Orders left:  1308552
# Cascade length:  1491
# New Orders left:  1307061
# making new cascade
#
#
# OG Orders left:  1307061
# Cascade length:  8
# New Orders left:  1307053
# making new cascade
#
#
# OG Orders left:  1307053
# Cascade length:  1088
# New Orders left:  1305965
# making new cascade
#
#
# OG Orders left:  1305965
# Cascade length:  9
# New Orders left:  1305956
# making new cascade
#
#
# OG Orders left:  1305956
# Cascade length:  1091
# New Orders left:  1304865
# making new cascade
#
#
# OG Orders left:  1304865
# Cascade length:  998
# New Orders left:  1303867
# making new cascade
#
#
# OG Orders left:  1303867
# Cascade length:  1000
# New Orders left:  1302867
# making new cascade
#
#
# OG Orders left:  1302867
# Cascade length:  453
# New Orders left:  1302414
# making new cascade
#
#
# OG Orders left:  1302414
# Cascade length:  1843
# New Orders left:  1300571
# making new cascade
#
#
# OG Orders left:  1300571
# Cascade length:  5
# New Orders left:  1300566
# making new cascade
#
#
# OG Orders left:  1300566
# Cascade length:  1061
# New Orders left:  1299505
# making new cascade
#
#
# OG Orders left:  1299505
# Cascade length:  1066
# New Orders left:  1298439
# making new cascade
#
#
# OG Orders left:  1298439
# Cascade length:  790
# New Orders left:  1297649
# making new cascade
#
#
# OG Orders left:  1297649
# Cascade length:  1344
# New Orders left:  1296305
# making new cascade
#
#
# OG Orders left:  1296305
# Cascade length:  1503
# New Orders left:  1294802
# making new cascade
#
#
# OG Orders left:  1294802
# Cascade length:  747
# New Orders left:  1294055
# making new cascade
#
#
# OG Orders left:  1294055
# Cascade length:  1207
# New Orders left:  1292848
# making new cascade
#
#
# OG Orders left:  1292848
# Cascade length:  965
# New Orders left:  1291883
# making new cascade
#
#
# OG Orders left:  1291883
# Cascade length:  938
# New Orders left:  1290945
# making new cascade
#
#
# OG Orders left:  1290945
# Cascade length:  1081
# New Orders left:  1289864
# making new cascade
#
#
# OG Orders left:  1289864
# Cascade length:  628
# New Orders left:  1289236
# making new cascade
#
#
# OG Orders left:  1289236
# Cascade length:  66
# New Orders left:  1289170
# making new cascade
#
#
# OG Orders left:  1289170
# Cascade length:  976
# New Orders left:  1288194
# making new cascade
#
#
# OG Orders left:  1288194
# Cascade length:  3
# New Orders left:  1288191
# making new cascade
#
#
# OG Orders left:  1288191
# Cascade length:  1152
# New Orders left:  1287039
# making new cascade
#
#
# OG Orders left:  1287039
# Cascade length:  2
# New Orders left:  1287037
# making new cascade
#
#
# OG Orders left:  1287037
# Cascade length:  10
# New Orders left:  1287027
# making new cascade
#
#
# OG Orders left:  1287027
# Cascade length:  945
# New Orders left:  1286082
# making new cascade
#
#
# OG Orders left:  1286082
# Cascade length:  1316
# New Orders left:  1284766
# making new cascade
#
#
# OG Orders left:  1284766
# Cascade length:  68
# New Orders left:  1284698
# making new cascade
#
#
# OG Orders left:  1284698
# Cascade length:  412
# New Orders left:  1284286
# making new cascade
#
#
# OG Orders left:  1284286
# Cascade length:  981
# New Orders left:  1283305
# making new cascade
#
#
# OG Orders left:  1283305
# Cascade length:  1483
# New Orders left:  1281822
# making new cascade
#
#
# OG Orders left:  1281822
# Cascade length:  14
# New Orders left:  1281808
# making new cascade
#
#
# OG Orders left:  1281808
# Cascade length:  11
# New Orders left:  1281797
# making new cascade
#
#
# OG Orders left:  1281797
# Cascade length:  620
# New Orders left:  1281177
# making new cascade
#
#
# OG Orders left:  1281177
# Cascade length:  1343
# New Orders left:  1279834
# making new cascade
#
#
# OG Orders left:  1279834
# Cascade length:  1105
# New Orders left:  1278729
# making new cascade
#
#
# OG Orders left:  1278729
# Cascade length:  966
# New Orders left:  1277763
# making new cascade
#
#
# OG Orders left:  1277763
# Cascade length:  1
# New Orders left:  1277762
# making new cascade
#
#
# OG Orders left:  1277762
# Cascade length:  10
# New Orders left:  1277752
# making new cascade
#
#
# OG Orders left:  1277752
# Cascade length:  3
# New Orders left:  1277749
# making new cascade
#
#
# OG Orders left:  1277749
# Cascade length:  11
# New Orders left:  1277738
# making new cascade
#
#
# OG Orders left:  1277738
# Cascade length:  4
# New Orders left:  1277734
# making new cascade
#
#
# OG Orders left:  1277734
# Cascade length:  689
# New Orders left:  1277045
# making new cascade
#
#
# OG Orders left:  1277045
# Cascade length:  942
# New Orders left:  1276103
# making new cascade
#
#
# OG Orders left:  1276103
# Cascade length:  9
# New Orders left:  1276094
# making new cascade
#
#
# OG Orders left:  1276094
# Cascade length:  1227
# New Orders left:  1274867
# making new cascade
#
#
# OG Orders left:  1274867
# Cascade length:  983
# New Orders left:  1273884
# making new cascade
#
#
# OG Orders left:  1273884
# Cascade length:  2
# New Orders left:  1273882
# making new cascade
#
#
# OG Orders left:  1273882
# Cascade length:  687
# New Orders left:  1273195
# making new cascade
#
#
# OG Orders left:  1273195
# Cascade length:  1
# New Orders left:  1273194
# making new cascade
#
#
# OG Orders left:  1273194
# Cascade length:  1115
# New Orders left:  1272079
# making new cascade
#
#
# OG Orders left:  1272079
# Cascade length:  1284
# New Orders left:  1270795
# making new cascade
#
#
# OG Orders left:  1270795
# Cascade length:  5
# New Orders left:  1270790
# making new cascade
#
#
# OG Orders left:  1270790
# Cascade length:  16
# New Orders left:  1270774
# making new cascade
#
#
# OG Orders left:  1270774
# Cascade length:  1069
# New Orders left:  1269705
# making new cascade
#
#
# OG Orders left:  1269705
# Cascade length:  910
# New Orders left:  1268795
# making new cascade
#
#
# OG Orders left:  1268795
# Cascade length:  1
# New Orders left:  1268794
# making new cascade
#
#
# OG Orders left:  1268794
# Cascade length:  5
# New Orders left:  1268789
# making new cascade
#
#
# OG Orders left:  1268789
# Cascade length:  1297
# New Orders left:  1267492
# making new cascade
#
#
# OG Orders left:  1267492
# Cascade length:  918
# New Orders left:  1266574
# making new cascade
#
#
# OG Orders left:  1266574
# Cascade length:  1196
# New Orders left:  1265378
# making new cascade
#
#
# OG Orders left:  1265378
# Cascade length:  1280
# New Orders left:  1264098
# making new cascade
#
#
# OG Orders left:  1264098
# Cascade length:  28
# New Orders left:  1264070
# making new cascade
#
#
# OG Orders left:  1264070
# Cascade length:  662
# New Orders left:  1263408
# making new cascade
#
#
# OG Orders left:  1263408
# Cascade length:  473
# New Orders left:  1262935
# making new cascade
#
#
# OG Orders left:  1262935
# Cascade length:  881
# New Orders left:  1262054
# making new cascade
#
#
# OG Orders left:  1262054
# Cascade length:  676
# New Orders left:  1261378
# making new cascade
#
#
# OG Orders left:  1261378
# Cascade length:  8
# New Orders left:  1261370
# making new cascade
#
#
# OG Orders left:  1261370
# Cascade length:  15
# New Orders left:  1261355
# making new cascade
#
#
# OG Orders left:  1261355
# Cascade length:  3
# New Orders left:  1261352
# making new cascade
#
#
# OG Orders left:  1261352
# Cascade length:  53
# New Orders left:  1261299
# making new cascade
#
#
# OG Orders left:  1261299
# Cascade length:  1106
# New Orders left:  1260193
# making new cascade
#
#
# OG Orders left:  1260193
# Cascade length:  12
# New Orders left:  1260181
# making new cascade
#
#
# OG Orders left:  1260181
# Cascade length:  899
# New Orders left:  1259282
# making new cascade
#
#
# OG Orders left:  1259282
# Cascade length:  1205
# New Orders left:  1258077
# making new cascade
#
#
# OG Orders left:  1258077
# Cascade length:  18
# New Orders left:  1258059
# making new cascade
#
#
# OG Orders left:  1258059
# Cascade length:  6
# New Orders left:  1258053
# making new cascade
#
#
# OG Orders left:  1258053
# Cascade length:  832
# New Orders left:  1257221
# making new cascade
#
#
# OG Orders left:  1257221
# Cascade length:  1034
# New Orders left:  1256187
# making new cascade
#
#
# OG Orders left:  1256187
# Cascade length:  664
# New Orders left:  1255523
# making new cascade
#
#
# OG Orders left:  1255523
# Cascade length:  523
# New Orders left:  1255000
# making new cascade
#
#
# OG Orders left:  1255000
# Cascade length:  1209
# New Orders left:  1253791
# making new cascade
#
#
# OG Orders left:  1253791
# Cascade length:  1095
# New Orders left:  1252696
# making new cascade
#
#
# OG Orders left:  1252696
# Cascade length:  36
# New Orders left:  1252660
# making new cascade
#
#
# OG Orders left:  1252660
# Cascade length:  968
# New Orders left:  1251692
# making new cascade
#
#
# OG Orders left:  1251692
# Cascade length:  1378
# New Orders left:  1250314
# making new cascade
#
#
# OG Orders left:  1250314
# Cascade length:  1
# New Orders left:  1250313
# making new cascade
#
#
# OG Orders left:  1250313
# Cascade length:  8
# New Orders left:  1250305
# making new cascade
#
#
# OG Orders left:  1250305
# Cascade length:  2
# New Orders left:  1250303
# making new cascade
#
#
# OG Orders left:  1250303
# Cascade length:  10
# New Orders left:  1250293
# making new cascade
#
#
# OG Orders left:  1250293
# Cascade length:  102
# New Orders left:  1250191
# making new cascade
#
#
# OG Orders left:  1250191
# Cascade length:  1091
# New Orders left:  1249100
# making new cascade
#
#
# OG Orders left:  1249100
# Cascade length:  1151
# New Orders left:  1247949
# making new cascade
#
#
# OG Orders left:  1247949
# Cascade length:  1043
# New Orders left:  1246906
# making new cascade
#
#
# OG Orders left:  1246906
# Cascade length:  6
# New Orders left:  1246900
# making new cascade
#
#
# OG Orders left:  1246900
# Cascade length:  2
# New Orders left:  1246898
# making new cascade
#
#
# OG Orders left:  1246898
# Cascade length:  631
# New Orders left:  1246267
# making new cascade
#
#
# OG Orders left:  1246267
# Cascade length:  786
# New Orders left:  1245481
# making new cascade
#
#
# OG Orders left:  1245481
# Cascade length:  976
# New Orders left:  1244505
# making new cascade
#
#
# OG Orders left:  1244505
# Cascade length:  642
# New Orders left:  1243863
# making new cascade
#
#
# OG Orders left:  1243863
# Cascade length:  897
# New Orders left:  1242966
# making new cascade
#
#
# OG Orders left:  1242966
# Cascade length:  19
# New Orders left:  1242947
# making new cascade
#
#
# OG Orders left:  1242947
# Cascade length:  1
# New Orders left:  1242946
# making new cascade
#
#
# OG Orders left:  1242946
# Cascade length:  230
# New Orders left:  1242716
# making new cascade
#
#
# OG Orders left:  1242716
# Cascade length:  19
# New Orders left:  1242697
# making new cascade
#
#
# OG Orders left:  1242697
# Cascade length:  562
# New Orders left:  1242135
# making new cascade
#
#
# OG Orders left:  1242135
# Cascade length:  1003
# New Orders left:  1241132
# making new cascade
#
#
# OG Orders left:  1241132
# Cascade length:  40
# New Orders left:  1241092
# making new cascade
#
#
# OG Orders left:  1241092
# Cascade length:  748
# New Orders left:  1240344
# making new cascade
#
#
# OG Orders left:  1240344
# Cascade length:  815
# New Orders left:  1239529
# making new cascade
#
#
# OG Orders left:  1239529
# Cascade length:  17
# New Orders left:  1239512
# making new cascade
#
#
# OG Orders left:  1239512
# Cascade length:  10
# New Orders left:  1239502
# making new cascade
#
#
# OG Orders left:  1239502
# Cascade length:  550
# New Orders left:  1238952
# making new cascade
#
#
# OG Orders left:  1238952
# Cascade length:  4
# New Orders left:  1238948
# making new cascade
#
#
# OG Orders left:  1238948
# Cascade length:  727
# New Orders left:  1238221
# making new cascade
#
#
# OG Orders left:  1238221
# Cascade length:  495
# New Orders left:  1237726
# making new cascade
#
#
# OG Orders left:  1237726
# Cascade length:  1264
# New Orders left:  1236462
# making new cascade
#
#
# OG Orders left:  1236462
# Cascade length:  10
# New Orders left:  1236452
# making new cascade
#
#
# OG Orders left:  1236452
# Cascade length:  6
# New Orders left:  1236446
# making new cascade
#
#
# OG Orders left:  1236446
# Cascade length:  753
# New Orders left:  1235693
# making new cascade
#
#
# OG Orders left:  1235693
# Cascade length:  745
# New Orders left:  1234948
# making new cascade
#
#
# OG Orders left:  1234948
# Cascade length:  26
# New Orders left:  1234922
# making new cascade
#
#
# OG Orders left:  1234922
# Cascade length:  16
# New Orders left:  1234906
# making new cascade
#
#
# OG Orders left:  1234906
# Cascade length:  9
# New Orders left:  1234897
# making new cascade
#
#
# OG Orders left:  1234897
# Cascade length:  728
# New Orders left:  1234169
# making new cascade
#
#
# OG Orders left:  1234169
# Cascade length:  820
# New Orders left:  1233349
# making new cascade
#
#
# OG Orders left:  1233349
# Cascade length:  277
# New Orders left:  1233072
# making new cascade
#
#
# OG Orders left:  1233072
# Cascade length:  11
# New Orders left:  1233061
# making new cascade
#
#
# OG Orders left:  1233061
# Cascade length:  2
# New Orders left:  1233059
# making new cascade
#
#
# OG Orders left:  1233059
# Cascade length:  645
# New Orders left:  1232414
# making new cascade
#
#
# OG Orders left:  1232414
# Cascade length:  578
# New Orders left:  1231836
# making new cascade
#
#
# OG Orders left:  1231836
# Cascade length:  14
# New Orders left:  1231822
# making new cascade
#
#
# OG Orders left:  1231822
# Cascade length:  24
# New Orders left:  1231798
# making new cascade
#
#
# OG Orders left:  1231798
# Cascade length:  144
# New Orders left:  1231654
# making new cascade
#
#
# OG Orders left:  1231654
# Cascade length:  2
# New Orders left:  1231652
# making new cascade
#
#
# OG Orders left:  1231652
# Cascade length:  64
# New Orders left:  1231588
# making new cascade
#
#
# OG Orders left:  1231588
# Cascade length:  1016
# New Orders left:  1230572
# making new cascade
#
#
# OG Orders left:  1230572
# Cascade length:  553
# New Orders left:  1230019
# making new cascade
#
#
# OG Orders left:  1230019
# Cascade length:  301
# New Orders left:  1229718
# making new cascade
#
#
# OG Orders left:  1229718
# Cascade length:  516
# New Orders left:  1229202
# making new cascade
#
#
# OG Orders left:  1229202
# Cascade length:  22
# New Orders left:  1229180
# making new cascade
#
#
# OG Orders left:  1229180
# Cascade length:  3
# New Orders left:  1229177
# making new cascade
#
#
# OG Orders left:  1229177
# Cascade length:  613
# New Orders left:  1228564
# making new cascade
#
#
# OG Orders left:  1228564
# Cascade length:  748
# New Orders left:  1227816
# making new cascade
#
#
# OG Orders left:  1227816
# Cascade length:  11
# New Orders left:  1227805
# making new cascade
#
#
# OG Orders left:  1227805
# Cascade length:  30
# New Orders left:  1227775
# making new cascade
#
#
# OG Orders left:  1227775
# Cascade length:  583
# New Orders left:  1227192
# making new cascade
#
#
# OG Orders left:  1227192
# Cascade length:  818
# New Orders left:  1226374
# making new cascade
#
#
# OG Orders left:  1226374
# Cascade length:  4
# New Orders left:  1226370
# making new cascade
#
#
# OG Orders left:  1226370
# Cascade length:  14
# New Orders left:  1226356
# making new cascade
#
#
# OG Orders left:  1226356
# Cascade length:  687
# New Orders left:  1225669
# making new cascade
#
#
# OG Orders left:  1225669
# Cascade length:  8
# New Orders left:  1225661
# making new cascade
#
#
# OG Orders left:  1225661
# Cascade length:  4
# New Orders left:  1225657
# making new cascade
#
#
# OG Orders left:  1225657
# Cascade length:  7
# New Orders left:  1225650
# making new cascade
#
#
# OG Orders left:  1225650
# Cascade length:  322
# New Orders left:  1225328
# making new cascade
#
#
# OG Orders left:  1225328
# Cascade length:  21
# New Orders left:  1225307
# making new cascade
#
#
# OG Orders left:  1225307
# Cascade length:  2
# New Orders left:  1225305
# making new cascade
#
#
# OG Orders left:  1225305
# Cascade length:  495
# New Orders left:  1224810
# making new cascade
#
#
# OG Orders left:  1224810
# Cascade length:  80
# New Orders left:  1224730
# making new cascade
#
#
# OG Orders left:  1224730
# Cascade length:  762
# New Orders left:  1223968
# making new cascade
#
#
# OG Orders left:  1223968
# Cascade length:  357
# New Orders left:  1223611
# making new cascade
#
#
# OG Orders left:  1223611
# Cascade length:  11
# New Orders left:  1223600
# making new cascade
#
#
# OG Orders left:  1223600
# Cascade length:  37
# New Orders left:  1223563
# making new cascade
#
#
# OG Orders left:  1223563
# Cascade length:  8
# New Orders left:  1223555
# making new cascade
#
#
# OG Orders left:  1223555
# Cascade length:  76
# New Orders left:  1223479
# making new cascade
#
#
# OG Orders left:  1223479
# Cascade length:  497
# New Orders left:  1222982
# making new cascade
#
#
# OG Orders left:  1222982
# Cascade length:  708
# New Orders left:  1222274
# making new cascade
#
#
# OG Orders left:  1222274
# Cascade length:  483
# New Orders left:  1221791
# making new cascade
#
#
# OG Orders left:  1221791
# Cascade length:  1
# New Orders left:  1221790
# making new cascade
#
#
# OG Orders left:  1221790
# Cascade length:  292
# New Orders left:  1221498
# making new cascade
#
#
# OG Orders left:  1221498
# Cascade length:  5
# New Orders left:  1221493
# making new cascade
#
#
# OG Orders left:  1221493
# Cascade length:  521
# New Orders left:  1220972
# making new cascade
#
#
# OG Orders left:  1220972
# Cascade length:  2
# New Orders left:  1220970
# making new cascade
#
#
# OG Orders left:  1220970
# Cascade length:  633
# New Orders left:  1220337
# making new cascade
#
#
# OG Orders left:  1220337
# Cascade length:  254
# New Orders left:  1220083
# making new cascade
#
#
# OG Orders left:  1220083
# Cascade length:  659
# New Orders left:  1219424
# making new cascade
#
#
# OG Orders left:  1219424
# Cascade length:  6
# New Orders left:  1219418
# making new cascade
#
#
# OG Orders left:  1219418
# Cascade length:  55
# New Orders left:  1219363
# making new cascade
#
#
# OG Orders left:  1219363
# Cascade length:  1
# New Orders left:  1219362
# making new cascade
#
#
# OG Orders left:  1219362
# Cascade length:  1
# New Orders left:  1219361
# making new cascade
#
#
# OG Orders left:  1219361
# Cascade length:  471
# New Orders left:  1218890
# making new cascade
#
#
# OG Orders left:  1218890
# Cascade length:  207
# New Orders left:  1218683
# making new cascade
#
#
# OG Orders left:  1218683
# Cascade length:  701
# New Orders left:  1217982
# making new cascade
#
#
# OG Orders left:  1217982
# Cascade length:  458
# New Orders left:  1217524
# making new cascade
#
#
# OG Orders left:  1217524
# Cascade length:  53
# New Orders left:  1217471
# making new cascade
#
#
# OG Orders left:  1217471
# Cascade length:  468
# New Orders left:  1217003
# making new cascade
#
#
# OG Orders left:  1217003
# Cascade length:  300
# New Orders left:  1216703
# making new cascade
#
#
# OG Orders left:  1216703
# Cascade length:  608
# New Orders left:  1216095
# making new cascade
#
#
# OG Orders left:  1216095
# Cascade length:  122
# New Orders left:  1215973
# making new cascade
#
#
# OG Orders left:  1215973
# Cascade length:  423
# New Orders left:  1215550
# making new cascade
#
#
# OG Orders left:  1215550
# Cascade length:  716
# New Orders left:  1214834
# making new cascade
#
#
# OG Orders left:  1214834
# Cascade length:  22
# New Orders left:  1214812
# making new cascade
#
#
# OG Orders left:  1214812
# Cascade length:  6
# New Orders left:  1214806
# making new cascade
#
#
# OG Orders left:  1214806
# Cascade length:  10
# New Orders left:  1214796
# making new cascade
#
#
# OG Orders left:  1214796
# Cascade length:  547
# New Orders left:  1214249
# making new cascade
#
#
# OG Orders left:  1214249
# Cascade length:  12
# New Orders left:  1214237
# making new cascade
#
#
# OG Orders left:  1214237
# Cascade length:  7
# New Orders left:  1214230
# making new cascade
#
#
# OG Orders left:  1214230
# Cascade length:  440
# New Orders left:  1213790
# making new cascade
#
#
# OG Orders left:  1213790
# Cascade length:  134
# New Orders left:  1213656
# making new cascade
#
#
# OG Orders left:  1213656
# Cascade length:  305
# New Orders left:  1213351
# making new cascade
#
#
# OG Orders left:  1213351
# Cascade length:  531
# New Orders left:  1212820
# making new cascade
#
#
# OG Orders left:  1212820
# Cascade length:  13
# New Orders left:  1212807
# making new cascade
#
#
# OG Orders left:  1212807
# Cascade length:  2
# New Orders left:  1212805
# making new cascade
#
#
# OG Orders left:  1212805
# Cascade length:  75
# New Orders left:  1212730
# making new cascade
#
#
# OG Orders left:  1212730
# Cascade length:  205
# New Orders left:  1212525
# making new cascade
#
#
# OG Orders left:  1212525
# Cascade length:  14
# New Orders left:  1212511
# making new cascade
#
#
# OG Orders left:  1212511
# Cascade length:  665
# New Orders left:  1211846
# making new cascade
#
#
# OG Orders left:  1211846
# Cascade length:  37
# New Orders left:  1211809
# making new cascade
#
#
# OG Orders left:  1211809
# Cascade length:  442
# New Orders left:  1211367
# making new cascade
#
#
# OG Orders left:  1211367
# Cascade length:  4
# New Orders left:  1211363
# making new cascade
#
#
# OG Orders left:  1211363
# Cascade length:  72
# New Orders left:  1211291
# making new cascade
#
#
# OG Orders left:  1211291
# Cascade length:  172
# New Orders left:  1211119
# making new cascade
#
#
# OG Orders left:  1211119
# Cascade length:  251
# New Orders left:  1210868
# making new cascade
#
#
# OG Orders left:  1210868
# Cascade length:  310
# New Orders left:  1210558
# making new cascade
#
#
# OG Orders left:  1210558
# Cascade length:  10
# New Orders left:  1210548
# making new cascade
#
#
# OG Orders left:  1210548
# Cascade length:  722
# New Orders left:  1209826
# making new cascade
#
#
# OG Orders left:  1209826
# Cascade length:  1
# New Orders left:  1209825
# making new cascade
#
#
# OG Orders left:  1209825
# Cascade length:  16
# New Orders left:  1209809
# making new cascade
#
#
# OG Orders left:  1209809
# Cascade length:  348
# New Orders left:  1209461
# making new cascade
#
#
# OG Orders left:  1209461
# Cascade length:  752
# New Orders left:  1208709
# making new cascade
#
#
# OG Orders left:  1208709
# Cascade length:  8
# New Orders left:  1208701
# making new cascade
#
#
# OG Orders left:  1208701
# Cascade length:  313
# New Orders left:  1208388
# making new cascade
#
#
# OG Orders left:  1208388
# Cascade length:  2
# New Orders left:  1208386
# making new cascade
#
#
# OG Orders left:  1208386
# Cascade length:  253
# New Orders left:  1208133
# making new cascade
#
#
# OG Orders left:  1208133
# Cascade length:  137
# New Orders left:  1207996
# making new cascade
#
#
# OG Orders left:  1207996
# Cascade length:  66
# New Orders left:  1207930
# making new cascade
#
#
# OG Orders left:  1207930
# Cascade length:  390
# New Orders left:  1207540
# making new cascade
#
#
# OG Orders left:  1207540
# Cascade length:  1
# New Orders left:  1207539
# making new cascade
#
#
# OG Orders left:  1207539
# Cascade length:  674
# New Orders left:  1206865
# making new cascade
#
#
# OG Orders left:  1206865
# Cascade length:  106
# New Orders left:  1206759
# making new cascade
#
#
# OG Orders left:  1206759
# Cascade length:  148
# New Orders left:  1206611
# making new cascade
#
#
# OG Orders left:  1206611
# Cascade length:  84
# New Orders left:  1206527
# making new cascade
#
#
# OG Orders left:  1206527
# Cascade length:  193
# New Orders left:  1206334
# making new cascade
#
#
# OG Orders left:  1206334
# Cascade length:  190
# New Orders left:  1206144
# making new cascade
#
#
# OG Orders left:  1206144
# Cascade length:  423
# New Orders left:  1205721
# making new cascade
#
#
# OG Orders left:  1205721
# Cascade length:  246
# New Orders left:  1205475
# making new cascade
#
#
# OG Orders left:  1205475
# Cascade length:  507
# New Orders left:  1204968
# making new cascade
#
#
# OG Orders left:  1204968
# Cascade length:  20
# New Orders left:  1204948
# making new cascade
#
#
# OG Orders left:  1204948
# Cascade length:  8
# New Orders left:  1204940
# making new cascade
#
#
# OG Orders left:  1204940
# Cascade length:  259
# New Orders left:  1204681
# making new cascade
#
#
# OG Orders left:  1204681
# Cascade length:  23
# New Orders left:  1204658
# making new cascade
#
#
# OG Orders left:  1204658
# Cascade length:  378
# New Orders left:  1204280
# making new cascade
#
#
# OG Orders left:  1204280
# Cascade length:  3
# New Orders left:  1204277
# making new cascade
#
#
# OG Orders left:  1204277
# Cascade length:  668
# New Orders left:  1203609
# making new cascade
#
#
# OG Orders left:  1203609
# Cascade length:  337
# New Orders left:  1203272
# making new cascade
#
#
# OG Orders left:  1203272
# Cascade length:  246
# New Orders left:  1203026
# making new cascade
#
#
# OG Orders left:  1203026
# Cascade length:  596
# New Orders left:  1202430
# making new cascade
#
#
# OG Orders left:  1202430
# Cascade length:  528
# New Orders left:  1201902
# making new cascade
#
#
# OG Orders left:  1201902
# Cascade length:  583
# New Orders left:  1201319
# making new cascade
#
#
# OG Orders left:  1201319
# Cascade length:  722
# New Orders left:  1200597
# making new cascade
#
#
# OG Orders left:  1200597
# Cascade length:  6
# New Orders left:  1200591
# making new cascade
#
#
# OG Orders left:  1200591
# Cascade length:  4
# New Orders left:  1200587
# making new cascade
#
#
# OG Orders left:  1200587
# Cascade length:  440
# New Orders left:  1200147
# making new cascade
#
#
# OG Orders left:  1200147
# Cascade length:  1
# New Orders left:  1200146
# making new cascade
#
#
# OG Orders left:  1200146
# Cascade length:  530
# New Orders left:  1199616
# making new cascade
#
#
# OG Orders left:  1199616
# Cascade length:  494
# New Orders left:  1199122
# making new cascade
#
#
# OG Orders left:  1199122
# Cascade length:  562
# New Orders left:  1198560
# making new cascade
#
#
# OG Orders left:  1198560
# Cascade length:  275
# New Orders left:  1198285
# making new cascade
#
#
# OG Orders left:  1198285
# Cascade length:  2
# New Orders left:  1198283
# making new cascade
#
#
# OG Orders left:  1198283
# Cascade length:  4
# New Orders left:  1198279
# making new cascade
#
#
# OG Orders left:  1198279
# Cascade length:  782
# New Orders left:  1197497
# making new cascade
#
#
# OG Orders left:  1197497
# Cascade length:  519
# New Orders left:  1196978
# making new cascade
#
#
# OG Orders left:  1196978
# Cascade length:  292
# New Orders left:  1196686
# making new cascade
#
#
# OG Orders left:  1196686
# Cascade length:  540
# New Orders left:  1196146
# making new cascade
#
#
# OG Orders left:  1196146
# Cascade length:  647
# New Orders left:  1195499
# making new cascade
#
#
# OG Orders left:  1195499
# Cascade length:  4
# New Orders left:  1195495
# making new cascade
#
#
# OG Orders left:  1195495
# Cascade length:  537
# New Orders left:  1194958
# making new cascade
#
#
# OG Orders left:  1194958
# Cascade length:  12
# New Orders left:  1194946
# making new cascade
#
#
# OG Orders left:  1194946
# Cascade length:  4
# New Orders left:  1194942
# making new cascade
#
#
# OG Orders left:  1194942
# Cascade length:  605
# New Orders left:  1194337
# making new cascade
#
#
# OG Orders left:  1194337
# Cascade length:  361
# New Orders left:  1193976
# making new cascade
#
#
# OG Orders left:  1193976
# Cascade length:  369
# New Orders left:  1193607
# making new cascade
#
#
# OG Orders left:  1193607
# Cascade length:  10
# New Orders left:  1193597
# making new cascade
#
#
# OG Orders left:  1193597
# Cascade length:  4
# New Orders left:  1193593
# making new cascade
#
#
# OG Orders left:  1193593
# Cascade length:  468
# New Orders left:  1193125
# making new cascade
#
#
# OG Orders left:  1193125
# Cascade length:  117
# New Orders left:  1193008
# making new cascade
#
#
# OG Orders left:  1193008
# Cascade length:  12
# New Orders left:  1192996
# making new cascade
#
#
# OG Orders left:  1192996
# Cascade length:  631
# New Orders left:  1192365
# making new cascade
#
#
# OG Orders left:  1192365
# Cascade length:  394
# New Orders left:  1191971
# making new cascade
#
#
# OG Orders left:  1191971
# Cascade length:  474
# New Orders left:  1191497
# making new cascade
#
#
# OG Orders left:  1191497
# Cascade length:  4
# New Orders left:  1191493
# making new cascade
#
#
# OG Orders left:  1191493
# Cascade length:  2
# New Orders left:  1191491
# making new cascade
#
#
# OG Orders left:  1191491
# Cascade length:  532
# New Orders left:  1190959
# making new cascade
#
#
# OG Orders left:  1190959
# Cascade length:  412
# New Orders left:  1190547
# making new cascade
#
#
# OG Orders left:  1190547
# Cascade length:  29
# New Orders left:  1190518
# making new cascade
#
#
# OG Orders left:  1190518
# Cascade length:  12
# New Orders left:  1190506
# making new cascade
#
#
# OG Orders left:  1190506
# Cascade length:  202
# New Orders left:  1190304
# making new cascade
#
#
# OG Orders left:  1190304
# Cascade length:  456
# New Orders left:  1189848
# making new cascade
#
#
# OG Orders left:  1189848
# Cascade length:  646
# New Orders left:  1189202
# making new cascade
#
#
# OG Orders left:  1189202
# Cascade length:  261
# New Orders left:  1188941
# making new cascade
#
#
# OG Orders left:  1188941
# Cascade length:  481
# New Orders left:  1188460
# making new cascade
#
#
# OG Orders left:  1188460
# Cascade length:  21
# New Orders left:  1188439
# making new cascade
#
#
# OG Orders left:  1188439
# Cascade length:  624
# New Orders left:  1187815
# making new cascade
#
#
# OG Orders left:  1187815
# Cascade length:  577
# New Orders left:  1187238
# making new cascade
#
#
# OG Orders left:  1187238
# Cascade length:  232
# New Orders left:  1187006
# making new cascade
#
#
# OG Orders left:  1187006
# Cascade length:  4
# New Orders left:  1187002
# making new cascade
#
#
# OG Orders left:  1187002
# Cascade length:  25
# New Orders left:  1186977
# making new cascade
#
#
# OG Orders left:  1186977
# Cascade length:  588
# New Orders left:  1186389
# making new cascade
#
#
# OG Orders left:  1186389
# Cascade length:  211
# New Orders left:  1186178
# making new cascade
#
#
# OG Orders left:  1186178
# Cascade length:  4
# New Orders left:  1186174
# making new cascade
#
#
# OG Orders left:  1186174
# Cascade length:  621
# New Orders left:  1185553
# making new cascade
#
#
# OG Orders left:  1185553
# Cascade length:  735
# New Orders left:  1184818
# making new cascade
#
#
# OG Orders left:  1184818
# Cascade length:  21
# New Orders left:  1184797
# making new cascade
#
#
# OG Orders left:  1184797
# Cascade length:  820
# New Orders left:  1183977
# making new cascade
#
#
# OG Orders left:  1183977
# Cascade length:  324
# New Orders left:  1183653
# making new cascade
#
#
# OG Orders left:  1183653
# Cascade length:  268
# New Orders left:  1183385
# making new cascade
#
#
# OG Orders left:  1183385
# Cascade length:  9
# New Orders left:  1183376
# making new cascade
#
#
# OG Orders left:  1183376
# Cascade length:  1
# New Orders left:  1183375
# making new cascade
#
#
# OG Orders left:  1183375
# Cascade length:  566
# New Orders left:  1182809
# making new cascade
#
#
# OG Orders left:  1182809
# Cascade length:  723
# New Orders left:  1182086
# making new cascade
#
#
# OG Orders left:  1182086
# Cascade length:  129
# New Orders left:  1181957
# making new cascade
#
#
# OG Orders left:  1181957
# Cascade length:  373
# New Orders left:  1181584
# making new cascade
#
#
# OG Orders left:  1181584
# Cascade length:  421
# New Orders left:  1181163
# making new cascade
#
#
# OG Orders left:  1181163
# Cascade length:  568
# New Orders left:  1180595
# making new cascade
#
#
# OG Orders left:  1180595
# Cascade length:  235
# New Orders left:  1180360
# making new cascade
#
#
# OG Orders left:  1180360
# Cascade length:  609
# New Orders left:  1179751
# making new cascade
#
#
# OG Orders left:  1179751
# Cascade length:  3
# New Orders left:  1179748
# making new cascade
#
#
# OG Orders left:  1179748
# Cascade length:  617
# New Orders left:  1179131
# making new cascade
#
#
# OG Orders left:  1179131
# Cascade length:  96
# New Orders left:  1179035
# making new cascade
#
#
# OG Orders left:  1179035
# Cascade length:  472
# New Orders left:  1178563
# making new cascade
#
#
# OG Orders left:  1178563
# Cascade length:  460
# New Orders left:  1178103
# making new cascade
#
#
# OG Orders left:  1178103
# Cascade length:  4
# New Orders left:  1178099
# making new cascade
#
#
# OG Orders left:  1178099
# Cascade length:  2
# New Orders left:  1178097
# making new cascade
#
#
# OG Orders left:  1178097
# Cascade length:  701
# New Orders left:  1177396
# making new cascade
#
#
# OG Orders left:  1177396
# Cascade length:  632
# New Orders left:  1176764
# making new cascade
#
#
# OG Orders left:  1176764
# Cascade length:  872
# New Orders left:  1175892
# making new cascade
#
#
# OG Orders left:  1175892
# Cascade length:  610
# New Orders left:  1175282
# making new cascade
#
#
# OG Orders left:  1175282
# Cascade length:  85
# New Orders left:  1175197
# making new cascade
#
#
# OG Orders left:  1175197
# Cascade length:  368
# New Orders left:  1174829
# making new cascade
#
#
# OG Orders left:  1174829
# Cascade length:  26
# New Orders left:  1174803
# making new cascade
#
#
# OG Orders left:  1174803
# Cascade length:  757
# New Orders left:  1174046
# making new cascade
#
#
# OG Orders left:  1174046
# Cascade length:  810
# New Orders left:  1173236
# making new cascade
#
#
# OG Orders left:  1173236
# Cascade length:  5
# New Orders left:  1173231
# making new cascade
#
#
# OG Orders left:  1173231
# Cascade length:  20
# New Orders left:  1173211
# making new cascade
#
#
# OG Orders left:  1173211
# Cascade length:  1
# New Orders left:  1173210
# making new cascade
#
#
# OG Orders left:  1173210
# Cascade length:  601
# New Orders left:  1172609
# making new cascade
#
#
# OG Orders left:  1172609
# Cascade length:  10
# New Orders left:  1172599
# making new cascade
#
#
# OG Orders left:  1172599
# Cascade length:  3
# New Orders left:  1172596
# making new cascade
#
#
# OG Orders left:  1172596
# Cascade length:  9
# New Orders left:  1172587
# making new cascade
#
#
# OG Orders left:  1172587
# Cascade length:  658
# New Orders left:  1171929
# making new cascade
#
#
# OG Orders left:  1171929
# Cascade length:  11
# New Orders left:  1171918
# making new cascade
#
#
# OG Orders left:  1171918
# Cascade length:  10
# New Orders left:  1171908
# making new cascade
#
#
# OG Orders left:  1171908
# Cascade length:  613
# New Orders left:  1171295
# making new cascade
#
#
# OG Orders left:  1171295
# Cascade length:  210
# New Orders left:  1171085
# making new cascade
#
#
# OG Orders left:  1171085
# Cascade length:  562
# New Orders left:  1170523
# making new cascade
#
#
# OG Orders left:  1170523
# Cascade length:  137
# New Orders left:  1170386
# making new cascade
#
#
# OG Orders left:  1170386
# Cascade length:  805
# New Orders left:  1169581
# making new cascade
#
#
# OG Orders left:  1169581
# Cascade length:  34
# New Orders left:  1169547
# making new cascade
#
#
# OG Orders left:  1169547
# Cascade length:  797
# New Orders left:  1168750
# making new cascade
#
#
# OG Orders left:  1168750
# Cascade length:  4
# New Orders left:  1168746
# making new cascade
#
#
# OG Orders left:  1168746
# Cascade length:  568
# New Orders left:  1168178
# making new cascade
#
#
# OG Orders left:  1168178
# Cascade length:  532
# New Orders left:  1167646
# making new cascade
#
#
# OG Orders left:  1167646
# Cascade length:  212
# New Orders left:  1167434
# making new cascade
#
#
# OG Orders left:  1167434
# Cascade length:  43
# New Orders left:  1167391
# making new cascade
#
#
# OG Orders left:  1167391
# Cascade length:  642
# New Orders left:  1166749
# making new cascade
#
#
# OG Orders left:  1166749
# Cascade length:  4
# New Orders left:  1166745
# making new cascade
#
#
# OG Orders left:  1166745
# Cascade length:  667
# New Orders left:  1166078
# making new cascade
#
#
# OG Orders left:  1166078
# Cascade length:  278
# New Orders left:  1165800
# making new cascade
#
#
# OG Orders left:  1165800
# Cascade length:  2
# New Orders left:  1165798
# making new cascade
#
#
# OG Orders left:  1165798
# Cascade length:  714
# New Orders left:  1165084
# making new cascade
#
#
# OG Orders left:  1165084
# Cascade length:  18
# New Orders left:  1165066
# making new cascade
#
#
# OG Orders left:  1165066
# Cascade length:  611
# New Orders left:  1164455
# making new cascade
#
#
# OG Orders left:  1164455
# Cascade length:  723
# New Orders left:  1163732
# making new cascade
#
#
# OG Orders left:  1163732
# Cascade length:  38
# New Orders left:  1163694
# making new cascade
#
#
# OG Orders left:  1163694
# Cascade length:  6
# New Orders left:  1163688
# making new cascade
#
#
# OG Orders left:  1163688
# Cascade length:  557
# New Orders left:  1163131
# making new cascade
#
#
# OG Orders left:  1163131
# Cascade length:  736
# New Orders left:  1162395
# making new cascade
#
#
# OG Orders left:  1162395
# Cascade length:  671
# New Orders left:  1161724
# making new cascade
#
#
# OG Orders left:  1161724
# Cascade length:  483
# New Orders left:  1161241
# making new cascade
#
#
# OG Orders left:  1161241
# Cascade length:  245
# New Orders left:  1160996
# making new cascade
#
#
# OG Orders left:  1160996
# Cascade length:  1
# New Orders left:  1160995
# making new cascade
#
#
# OG Orders left:  1160995
# Cascade length:  452
# New Orders left:  1160543
# making new cascade
#
#
# OG Orders left:  1160543
# Cascade length:  590
# New Orders left:  1159953
# making new cascade
#
#
# OG Orders left:  1159953
# Cascade length:  363
# New Orders left:  1159590
# making new cascade
#
#
# OG Orders left:  1159590
# Cascade length:  11
# New Orders left:  1159579
# making new cascade
#
#
# OG Orders left:  1159579
# Cascade length:  560
# New Orders left:  1159019
# making new cascade
#
#
# OG Orders left:  1159019
# Cascade length:  533
# New Orders left:  1158486
# making new cascade
#
#
# OG Orders left:  1158486
# Cascade length:  13
# New Orders left:  1158473
# making new cascade
#
#
# OG Orders left:  1158473
# Cascade length:  3
# New Orders left:  1158470
# making new cascade
#
#
# OG Orders left:  1158470
# Cascade length:  112
# New Orders left:  1158358
# making new cascade
#
#
# OG Orders left:  1158358
# Cascade length:  672
# New Orders left:  1157686
# making new cascade
#
#
# OG Orders left:  1157686
# Cascade length:  718
# New Orders left:  1156968
# making new cascade
#
#
# OG Orders left:  1156968
# Cascade length:  620
# New Orders left:  1156348
# making new cascade
#
#
# OG Orders left:  1156348
# Cascade length:  622
# New Orders left:  1155726
# making new cascade
#
#
# OG Orders left:  1155726
# Cascade length:  22
# New Orders left:  1155704
# making new cascade
#
#
# OG Orders left:  1155704
# Cascade length:  1
# New Orders left:  1155703
# making new cascade
#
#
# OG Orders left:  1155703
# Cascade length:  642
# New Orders left:  1155061
# making new cascade
#
#
# OG Orders left:  1155061
# Cascade length:  11
# New Orders left:  1155050
# making new cascade
#
#
# OG Orders left:  1155050
# Cascade length:  51
# New Orders left:  1154999
# making new cascade
#
#
# OG Orders left:  1154999
# Cascade length:  2
# New Orders left:  1154997
# making new cascade
#
#
# OG Orders left:  1154997
# Cascade length:  428
# New Orders left:  1154569
# making new cascade
#
#
# OG Orders left:  1154569
# Cascade length:  526
# New Orders left:  1154043
# making new cascade
#
#
# OG Orders left:  1154043
# Cascade length:  35
# New Orders left:  1154008
# making new cascade
#
#
# OG Orders left:  1154008
# Cascade length:  51
# New Orders left:  1153957
# making new cascade
#
#
# OG Orders left:  1153957
# Cascade length:  288
# New Orders left:  1153669
# making new cascade
#
#
# OG Orders left:  1153669
# Cascade length:  360
# New Orders left:  1153309
# making new cascade
#
#
# OG Orders left:  1153309
# Cascade length:  4
# New Orders left:  1153305
# making new cascade
#
#
# OG Orders left:  1153305
# Cascade length:  181
# New Orders left:  1153124
# making new cascade
#
#
# OG Orders left:  1153124
# Cascade length:  1
# New Orders left:  1153123
# making new cascade
#
#
# OG Orders left:  1153123
# Cascade length:  2
# New Orders left:  1153121
# making new cascade
#
#
# OG Orders left:  1153121
# Cascade length:  302
# New Orders left:  1152819
# making new cascade
#
#
# OG Orders left:  1152819
# Cascade length:  696
# New Orders left:  1152123
# making new cascade
#
#
# OG Orders left:  1152123
# Cascade length:  15
# New Orders left:  1152108
# making new cascade
#
#
# OG Orders left:  1152108
# Cascade length:  14
# New Orders left:  1152094
# making new cascade
#
#
# OG Orders left:  1152094
# Cascade length:  185
# New Orders left:  1151909
# making new cascade
#
#
# OG Orders left:  1151909
# Cascade length:  72
# New Orders left:  1151837
# making new cascade
#
#
# OG Orders left:  1151837
# Cascade length:  41
# New Orders left:  1151796
# making new cascade
#
#
# OG Orders left:  1151796
# Cascade length:  579
# New Orders left:  1151217
# making new cascade
#
#
# OG Orders left:  1151217
# Cascade length:  2
# New Orders left:  1151215
# making new cascade
#
#
# OG Orders left:  1151215
# Cascade length:  68
# New Orders left:  1151147
# making new cascade
#
#
# OG Orders left:  1151147
# Cascade length:  1
# New Orders left:  1151146
# making new cascade
#
#
# OG Orders left:  1151146
# Cascade length:  645
# New Orders left:  1150501
# making new cascade
#
#
# OG Orders left:  1150501
# Cascade length:  2
# New Orders left:  1150499
# making new cascade
#
#
# OG Orders left:  1150499
# Cascade length:  72
# New Orders left:  1150427
# making new cascade
#
#
# OG Orders left:  1150427
# Cascade length:  14
# New Orders left:  1150413
# making new cascade
#
#
# OG Orders left:  1150413
# Cascade length:  16
# New Orders left:  1150397
# making new cascade
#
#
# OG Orders left:  1150397
# Cascade length:  1
# New Orders left:  1150396
# making new cascade
#
#
# OG Orders left:  1150396
# Cascade length:  26
# New Orders left:  1150370
# making new cascade
#
#
# OG Orders left:  1150370
# Cascade length:  44
# New Orders left:  1150326
# making new cascade
#
#
# OG Orders left:  1150326
# Cascade length:  3
# New Orders left:  1150323
# making new cascade
#
#
# OG Orders left:  1150323
# Cascade length:  1
# New Orders left:  1150322
# making new cascade
#
#
# OG Orders left:  1150322
# Cascade length:  106
# New Orders left:  1150216
# making new cascade
#
#
# OG Orders left:  1150216
# Cascade length:  503
# New Orders left:  1149713
# making new cascade
#
#
# OG Orders left:  1149713
# Cascade length:  101
# New Orders left:  1149612
# making new cascade
#
#
# OG Orders left:  1149612
# Cascade length:  5
# New Orders left:  1149607
# making new cascade
#
#
# OG Orders left:  1149607
# Cascade length:  7
# New Orders left:  1149600
# making new cascade
#
#
# OG Orders left:  1149600
# Cascade length:  615
# New Orders left:  1148985
# making new cascade
#
#
# OG Orders left:  1148985
# Cascade length:  135
# New Orders left:  1148850
# making new cascade
#
#
# OG Orders left:  1148850
# Cascade length:  1
# New Orders left:  1148849
# making new cascade
#
#
# OG Orders left:  1148849
# Cascade length:  88
# New Orders left:  1148761
# making new cascade
#
#
# OG Orders left:  1148761
# Cascade length:  270
# New Orders left:  1148491
# making new cascade
#
#
# OG Orders left:  1148491
# Cascade length:  1
# New Orders left:  1148490
# making new cascade
#
#
# OG Orders left:  1148490
# Cascade length:  3
# New Orders left:  1148487
# making new cascade
#
#
# OG Orders left:  1148487
# Cascade length:  96
# New Orders left:  1148391
# making new cascade
#
#
# OG Orders left:  1148391
# Cascade length:  12
# New Orders left:  1148379
# making new cascade
#
#
# OG Orders left:  1148379
# Cascade length:  82
# New Orders left:  1148297
# making new cascade
#
#
# OG Orders left:  1148297
# Cascade length:  159
# New Orders left:  1148138
# making new cascade
#
#
# OG Orders left:  1148138
# Cascade length:  693
# New Orders left:  1147445
# making new cascade
#
#
# OG Orders left:  1147445
# Cascade length:  58
# New Orders left:  1147387
# making new cascade
#
#
# OG Orders left:  1147387
# Cascade length:  23
# New Orders left:  1147364
# making new cascade
#
#
# OG Orders left:  1147364
# Cascade length:  33
# New Orders left:  1147331
# making new cascade
#
#
# OG Orders left:  1147331
# Cascade length:  16
# New Orders left:  1147315
# making new cascade
#
#
# OG Orders left:  1147315
# Cascade length:  655
# New Orders left:  1146660
# making new cascade
#
#
# OG Orders left:  1146660
# Cascade length:  547
# New Orders left:  1146113
# making new cascade
#
#
# OG Orders left:  1146113
# Cascade length:  1
# New Orders left:  1146112
# making new cascade
#
#
# OG Orders left:  1146112
# Cascade length:  91
# New Orders left:  1146021
# making new cascade
#
#
# OG Orders left:  1146021
# Cascade length:  625
# New Orders left:  1145396
# making new cascade
#
#
# OG Orders left:  1145396
# Cascade length:  709
# New Orders left:  1144687
# making new cascade
#
#
# OG Orders left:  1144687
# Cascade length:  27
# New Orders left:  1144660
# making new cascade
#
#
# OG Orders left:  1144660
# Cascade length:  1
# New Orders left:  1144659
# making new cascade
#
#
# OG Orders left:  1144659
# Cascade length:  13
# New Orders left:  1144646
# making new cascade
#
#
# OG Orders left:  1144646
# Cascade length:  1
# New Orders left:  1144645
# making new cascade
#
#
# OG Orders left:  1144645
# Cascade length:  14
# New Orders left:  1144631
# making new cascade
#
#
# OG Orders left:  1144631
# Cascade length:  183
# New Orders left:  1144448
# making new cascade
#
#
# OG Orders left:  1144448
# Cascade length:  193
# New Orders left:  1144255
# making new cascade
#
#
# OG Orders left:  1144255
# Cascade length:  24
# New Orders left:  1144231
# making new cascade
#
#
# OG Orders left:  1144231
# Cascade length:  168
# New Orders left:  1144063
# making new cascade
#
#
# OG Orders left:  1144063
# Cascade length:  558
# New Orders left:  1143505
# making new cascade
#
#
# OG Orders left:  1143505
# Cascade length:  435
# New Orders left:  1143070
# making new cascade
#
#
# OG Orders left:  1143070
# Cascade length:  32
# New Orders left:  1143038
# making new cascade
#
#
# OG Orders left:  1143038
# Cascade length:  388
# New Orders left:  1142650
# making new cascade
#
#
# OG Orders left:  1142650
# Cascade length:  637
# New Orders left:  1142013
# making new cascade
#
#
# OG Orders left:  1142013
# Cascade length:  219
# New Orders left:  1141794
# making new cascade
#
#
# OG Orders left:  1141794
# Cascade length:  573
# New Orders left:  1141221
# making new cascade
#
#
# OG Orders left:  1141221
# Cascade length:  155
# New Orders left:  1141066
# making new cascade
#
#
# OG Orders left:  1141066
# Cascade length:  50
# New Orders left:  1141016
# making new cascade
#
#
# OG Orders left:  1141016
# Cascade length:  123
# New Orders left:  1140893
# making new cascade
#
#
# OG Orders left:  1140893
# Cascade length:  119
# New Orders left:  1140774
# making new cascade
#
#
# OG Orders left:  1140774
# Cascade length:  236
# New Orders left:  1140538
# making new cascade
#
#
# OG Orders left:  1140538
# Cascade length:  181
# New Orders left:  1140357
# making new cascade
#
#
# OG Orders left:  1140357
# Cascade length:  1
# New Orders left:  1140356
# making new cascade
#
#
# OG Orders left:  1140356
# Cascade length:  3
# New Orders left:  1140353
# making new cascade
#
#
# OG Orders left:  1140353
# Cascade length:  7
# New Orders left:  1140346
# making new cascade
#
#
# OG Orders left:  1140346
# Cascade length:  275
# New Orders left:  1140071
# making new cascade
#
#
# OG Orders left:  1140071
# Cascade length:  12
# New Orders left:  1140059
# making new cascade
#
#
# OG Orders left:  1140059
# Cascade length:  540
# New Orders left:  1139519
# making new cascade
#
#
# OG Orders left:  1139519
# Cascade length:  569
# New Orders left:  1138950
# making new cascade
#
#
# OG Orders left:  1138950
# Cascade length:  12
# New Orders left:  1138938
# making new cascade
#
#
# OG Orders left:  1138938
# Cascade length:  3
# New Orders left:  1138935
# making new cascade
#
#
# OG Orders left:  1138935
# Cascade length:  31
# New Orders left:  1138904
# making new cascade
#
#
# OG Orders left:  1138904
# Cascade length:  82
# New Orders left:  1138822
# making new cascade
#
#
# OG Orders left:  1138822
# Cascade length:  766
# New Orders left:  1138056
# making new cascade
#
#
# OG Orders left:  1138056
# Cascade length:  20
# New Orders left:  1138036
# making new cascade
#
#
# OG Orders left:  1138036
# Cascade length:  474
# New Orders left:  1137562
# making new cascade
#
#
# OG Orders left:  1137562
# Cascade length:  457
# New Orders left:  1137105
# making new cascade
#
#
# OG Orders left:  1137105
# Cascade length:  143
# New Orders left:  1136962
# making new cascade
#
#
# OG Orders left:  1136962
# Cascade length:  135
# New Orders left:  1136827
# making new cascade
#
#
# OG Orders left:  1136827
# Cascade length:  1
# New Orders left:  1136826
# making new cascade
#
#
# OG Orders left:  1136826
# Cascade length:  490
# New Orders left:  1136336
# making new cascade
#
#
# OG Orders left:  1136336
# Cascade length:  552
# New Orders left:  1135784
# making new cascade
#
#
# OG Orders left:  1135784
# Cascade length:  127
# New Orders left:  1135657
# making new cascade
#
#
# OG Orders left:  1135657
# Cascade length:  492
# New Orders left:  1135165
# making new cascade
#
#
# OG Orders left:  1135165
# Cascade length:  27
# New Orders left:  1135138
# making new cascade
#
#
# OG Orders left:  1135138
# Cascade length:  632
# New Orders left:  1134506
# making new cascade
#
#
# OG Orders left:  1134506
# Cascade length:  1
# New Orders left:  1134505
# making new cascade
#
#
# OG Orders left:  1134505
# Cascade length:  114
# New Orders left:  1134391
# making new cascade
#
#
# OG Orders left:  1134391
# Cascade length:  501
# New Orders left:  1133890
# making new cascade
#
#
# OG Orders left:  1133890
# Cascade length:  53
# New Orders left:  1133837
# making new cascade
#
#
# OG Orders left:  1133837
# Cascade length:  1
# New Orders left:  1133836
# making new cascade
#
#
# OG Orders left:  1133836
# Cascade length:  11
# New Orders left:  1133825
# making new cascade
#
#
# OG Orders left:  1133825
# Cascade length:  1
# New Orders left:  1133824
# making new cascade
#
#
# OG Orders left:  1133824
# Cascade length:  85
# New Orders left:  1133739
# making new cascade
#
#
# OG Orders left:  1133739
# Cascade length:  15
# New Orders left:  1133724
# making new cascade
#
#
# OG Orders left:  1133724
# Cascade length:  4
# New Orders left:  1133720
# making new cascade
#
#
# OG Orders left:  1133720
# Cascade length:  2
# New Orders left:  1133718
# making new cascade
#
#
# ...
# making new cascade
#
#
# OG Orders left:  10335
# Cascade length:  37
# New Orders left:  10298
# making new cascade
#
#
# OG Orders left:  10298
# Cascade length:  234
# New Orders left:  10064
# making new cascade
#
#
# OG Orders left:  10064
# Cascade length:  23
# New Orders left:  10041
# making new cascade
#
#
# OG Orders left:  10041
# Cascade length:  24
# New Orders left:  10017
# making new cascade
#
#
# OG Orders left:  10017
# Cascade length:  98
# New Orders left:  9919
# making new cascade
#
#
# OG Orders left:  9919
# Cascade length:  63
# New Orders left:  9856
# making new cascade
#
#
# OG Orders left:  9856
# Cascade length:  37
# New Orders left:  9819
# making new cascade
#
#
# OG Orders left:  9819
# Cascade length:  355
# New Orders left:  9464
# making new cascade
#
#
# OG Orders left:  9464
# Cascade length:  238
# New Orders left:  9226
# making new cascade
#
#
# OG Orders left:  9226
# Cascade length:  95
# New Orders left:  9131
# making new cascade
#
#
# OG Orders left:  9131
# Cascade length:  204
# New Orders left:  8927
# making new cascade
#
#
# OG Orders left:  8927
# Cascade length:  225
# New Orders left:  8702
# making new cascade
#
#
# OG Orders left:  8702
# Cascade length:  1
# New Orders left:  8701
# making new cascade
#
#
# OG Orders left:  8701
# Cascade length:  118
# New Orders left:  8583
# making new cascade
#
#
# OG Orders left:  8583
# Cascade length:  22
# New Orders left:  8561
# making new cascade
#
#
# OG Orders left:  8561
# Cascade length:  22
# New Orders left:  8539
# making new cascade
#
#
# OG Orders left:  8539
# Cascade length:  3
# New Orders left:  8536
# making new cascade
#
#
# OG Orders left:  8536
# Cascade length:  132
# New Orders left:  8404
# making new cascade
#
#
# OG Orders left:  8404
# Cascade length:  79
# New Orders left:  8325
# making new cascade
#
#
# OG Orders left:  8325
# Cascade length:  29
# New Orders left:  8296
# making new cascade
#
#
# OG Orders left:  8296
# Cascade length:  84
# New Orders left:  8212
# making new cascade
#
#
# OG Orders left:  8212
# Cascade length:  53
# New Orders left:  8159
# making new cascade
#
#
# OG Orders left:  8159
# Cascade length:  174
# New Orders left:  7985
# making new cascade
#
#
# OG Orders left:  7985
# Cascade length:  143
# New Orders left:  7842
# making new cascade
#
#
# OG Orders left:  7842
# Cascade length:  35
# New Orders left:  7807
# making new cascade
#
#
# OG Orders left:  7807
# Cascade length:  6
# New Orders left:  7801
# making new cascade
#
#
# OG Orders left:  7801
# Cascade length:  25
# New Orders left:  7776
# making new cascade
#
#
# OG Orders left:  7776
# Cascade length:  10
# New Orders left:  7766
# making new cascade
#
#
# OG Orders left:  7766
# Cascade length:  173
# New Orders left:  7593
# making new cascade
#
#
# OG Orders left:  7593
# Cascade length:  225
# New Orders left:  7368
# making new cascade
#
#
# OG Orders left:  7368
# Cascade length:  19
# New Orders left:  7349
# making new cascade
#
#
# OG Orders left:  7349
# Cascade length:  21
# New Orders left:  7328
# making new cascade
#
#
# OG Orders left:  7328
# Cascade length:  10
# New Orders left:  7318
# making new cascade
#
#
# OG Orders left:  7318
# Cascade length:  198
# New Orders left:  7120
# making new cascade
#
#
# OG Orders left:  7120
# Cascade length:  108
# New Orders left:  7012
# making new cascade
#
#
# OG Orders left:  7012
# Cascade length:  117
# New Orders left:  6895
# making new cascade
#
#
# OG Orders left:  6895
# Cascade length:  2
# New Orders left:  6893
# making new cascade
#
#
# OG Orders left:  6893
# Cascade length:  238
# New Orders left:  6655
# making new cascade
#
#
# OG Orders left:  6655
# Cascade length:  38
# New Orders left:  6617
# making new cascade
#
#
# OG Orders left:  6617
# Cascade length:  65
# New Orders left:  6552
# making new cascade
#
#
# OG Orders left:  6552
# Cascade length:  239
# New Orders left:  6313
# making new cascade
#
#
# OG Orders left:  6313
# Cascade length:  289
# New Orders left:  6024
# making new cascade
#
#
# OG Orders left:  6024
# Cascade length:  2
# New Orders left:  6022
# making new cascade
#
#
# OG Orders left:  6022
# Cascade length:  71
# New Orders left:  5951
# making new cascade
#
#
# OG Orders left:  5951
# Cascade length:  1
# New Orders left:  5950
# making new cascade
#
#
# OG Orders left:  5950
# Cascade length:  91
# New Orders left:  5859
# making new cascade
#
#
# OG Orders left:  5859
# Cascade length:  249
# New Orders left:  5610
# making new cascade
#
#
# OG Orders left:  5610
# Cascade length:  50
# New Orders left:  5560
# making new cascade
#
#
# OG Orders left:  5560
# Cascade length:  155
# New Orders left:  5405
# making new cascade
#
#
# OG Orders left:  5405
# Cascade length:  1
# New Orders left:  5404
# making new cascade
#
#
# OG Orders left:  5404
# Cascade length:  90
# New Orders left:  5314
# making new cascade
#
#
# OG Orders left:  5314
# Cascade length:  70
# New Orders left:  5244
# making new cascade
#
#
# OG Orders left:  5244
# Cascade length:  84
# New Orders left:  5160
# making new cascade
#
#
# OG Orders left:  5160
# Cascade length:  5
# New Orders left:  5155
# making new cascade
#
#
# OG Orders left:  5155
# Cascade length:  57
# New Orders left:  5098
# making new cascade
#
#
# OG Orders left:  5098
# Cascade length:  219
# New Orders left:  4879
# making new cascade
#
#
# OG Orders left:  4879
# Cascade length:  143
# New Orders left:  4736
# making new cascade
#
#
# OG Orders left:  4736
# Cascade length:  16
# New Orders left:  4720
# making new cascade
#
#
# OG Orders left:  4720
# Cascade length:  9
# New Orders left:  4711
# making new cascade
#
#
# OG Orders left:  4711
# Cascade length:  193
# New Orders left:  4518
# making new cascade
#
#
# OG Orders left:  4518
# Cascade length:  52
# New Orders left:  4466
# making new cascade
#
#
# OG Orders left:  4466
# Cascade length:  94
# New Orders left:  4372
# making new cascade
#
#
# OG Orders left:  4372
# Cascade length:  42
# New Orders left:  4330
# making new cascade
#
#
# OG Orders left:  4330
# Cascade length:  46
# New Orders left:  4284
# making new cascade
#
#
# OG Orders left:  4284
# Cascade length:  34
# New Orders left:  4250
# making new cascade
#
#
# OG Orders left:  4250
# Cascade length:  31
# New Orders left:  4219
# making new cascade
#
#
# OG Orders left:  4219
# Cascade length:  15
# New Orders left:  4204
# making new cascade
#
#
# OG Orders left:  4204
# Cascade length:  27
# New Orders left:  4177
# making new cascade
#
#
# OG Orders left:  4177
# Cascade length:  1
# New Orders left:  4176
# making new cascade
#
#
# OG Orders left:  4176
# Cascade length:  177
# New Orders left:  3999
# making new cascade
#
#
# OG Orders left:  3999
# Cascade length:  119
# New Orders left:  3880
# making new cascade
#
#
# OG Orders left:  3880
# Cascade length:  125
# New Orders left:  3755
# making new cascade
#
#
# OG Orders left:  3755
# Cascade length:  23
# New Orders left:  3732
# making new cascade
#
#
# OG Orders left:  3732
# Cascade length:  51
# New Orders left:  3681
# making new cascade
#
#
# OG Orders left:  3681
# Cascade length:  1
# New Orders left:  3680
# making new cascade
#
#
# OG Orders left:  3680
# Cascade length:  33
# New Orders left:  3647
# making new cascade
#
#
# OG Orders left:  3647
# Cascade length:  23
# New Orders left:  3624
# making new cascade
#
#
# OG Orders left:  3624
# Cascade length:  21
# New Orders left:  3603
# making new cascade
#
#
# OG Orders left:  3603
# Cascade length:  22
# New Orders left:  3581
# making new cascade
#
#
# OG Orders left:  3581
# Cascade length:  67
# New Orders left:  3514
# making new cascade
#
#
# OG Orders left:  3514
# Cascade length:  50
# New Orders left:  3464
# making new cascade
#
#
# OG Orders left:  3464
# Cascade length:  49
# New Orders left:  3415
# making new cascade
#
#
# OG Orders left:  3415
# Cascade length:  32
# New Orders left:  3383
# making new cascade
#
#
# OG Orders left:  3383
# Cascade length:  44
# New Orders left:  3339
# making new cascade
#
#
# OG Orders left:  3339
# Cascade length:  52
# New Orders left:  3287
# making new cascade
#
#
# OG Orders left:  3287
# Cascade length:  25
# New Orders left:  3262
# making new cascade
#
#
# OG Orders left:  3262
# Cascade length:  39
# New Orders left:  3223
# making new cascade
#
#
# OG Orders left:  3223
# Cascade length:  50
# New Orders left:  3173
# making new cascade
#
#
# OG Orders left:  3173
# Cascade length:  196
# New Orders left:  2977
# making new cascade
#
#
# OG Orders left:  2977
# Cascade length:  20
# New Orders left:  2957
# making new cascade
#
#
# OG Orders left:  2957
# Cascade length:  28
# New Orders left:  2929
# making new cascade
#
#
# OG Orders left:  2929
# Cascade length:  6
# New Orders left:  2923
# making new cascade
#
#
# OG Orders left:  2923
# Cascade length:  32
# New Orders left:  2891
# making new cascade
#
#
# OG Orders left:  2891
# Cascade length:  21
# New Orders left:  2870
# making new cascade
#
#
# OG Orders left:  2870
# Cascade length:  37
# New Orders left:  2833
# making new cascade
#
#
# OG Orders left:  2833
# Cascade length:  51
# New Orders left:  2782
# making new cascade
#
#
# OG Orders left:  2782
# Cascade length:  39
# New Orders left:  2743
# making new cascade
#
#
# OG Orders left:  2743
# Cascade length:  110
# New Orders left:  2633
# making new cascade
#
#
# OG Orders left:  2633
# Cascade length:  1
# New Orders left:  2632
# making new cascade
#
#
# OG Orders left:  2632
# Cascade length:  50
# New Orders left:  2582
# making new cascade
#
#
# OG Orders left:  2582
# Cascade length:  10
# New Orders left:  2572
# making new cascade
#
#
# OG Orders left:  2572
# Cascade length:  47
# New Orders left:  2525
# making new cascade
#
#
# OG Orders left:  2525
# Cascade length:  48
# New Orders left:  2477
# making new cascade
#
#
# OG Orders left:  2477
# Cascade length:  42
# New Orders left:  2435
# making new cascade
#
#
# OG Orders left:  2435
# Cascade length:  8
# New Orders left:  2427
# making new cascade
#
#
# OG Orders left:  2427
# Cascade length:  114
# New Orders left:  2313
# making new cascade
#
#
# OG Orders left:  2313
# Cascade length:  52
# New Orders left:  2261
# making new cascade
#
#
# OG Orders left:  2261
# Cascade length:  54
# New Orders left:  2207
# making new cascade
#
#
# OG Orders left:  2207
# Cascade length:  7
# New Orders left:  2200
# making new cascade
#
#
# OG Orders left:  2200
# Cascade length:  93
# New Orders left:  2107
# making new cascade
#
#
# OG Orders left:  2107
# Cascade length:  26
# New Orders left:  2081
# making new cascade
#
#
# OG Orders left:  2081
# Cascade length:  10
# New Orders left:  2071
# making new cascade
#
#
# OG Orders left:  2071
# Cascade length:  18
# New Orders left:  2053
# making new cascade
#
#
# OG Orders left:  2053
# Cascade length:  28
# New Orders left:  2025
# making new cascade
#
#
# OG Orders left:  2025
# Cascade length:  106
# New Orders left:  1919
# making new cascade
#
#
# OG Orders left:  1919
# Cascade length:  37
# New Orders left:  1882
# making new cascade
#
#
# OG Orders left:  1882
# Cascade length:  39
# New Orders left:  1843
# making new cascade
#
#
# OG Orders left:  1843
# Cascade length:  53
# New Orders left:  1790
# making new cascade
#
#
# OG Orders left:  1790
# Cascade length:  62
# New Orders left:  1728
# making new cascade
#
#
# OG Orders left:  1728
# Cascade length:  60
# New Orders left:  1668
# making new cascade
#
#
# OG Orders left:  1668
# Cascade length:  31
# New Orders left:  1637
# making new cascade
#
#
# OG Orders left:  1637
# Cascade length:  49
# New Orders left:  1588
# making new cascade
#
#
# OG Orders left:  1588
# Cascade length:  11
# New Orders left:  1577
# making new cascade
#
#
# OG Orders left:  1577
# Cascade length:  80
# New Orders left:  1497
# making new cascade
#
#
# OG Orders left:  1497
# Cascade length:  8
# New Orders left:  1489
# making new cascade
#
#
# OG Orders left:  1489
# Cascade length:  46
# New Orders left:  1443
# making new cascade
#
#
# OG Orders left:  1443
# Cascade length:  84
# New Orders left:  1359
# making new cascade
#
#
# OG Orders left:  1359
# Cascade length:  35
# New Orders left:  1324
# making new cascade
#
#
# OG Orders left:  1324
# Cascade length:  22
# New Orders left:  1302
# making new cascade
#
#
# OG Orders left:  1302
# Cascade length:  20
# New Orders left:  1282
# making new cascade
#
#
# OG Orders left:  1282
# Cascade length:  32
# New Orders left:  1250
# making new cascade
#
#
# OG Orders left:  1250
# Cascade length:  35
# New Orders left:  1215
# making new cascade
#
#
# OG Orders left:  1215
# Cascade length:  8
# New Orders left:  1207
# making new cascade
#
#
# OG Orders left:  1207
# Cascade length:  79
# New Orders left:  1128
# making new cascade
#
#
# OG Orders left:  1128
# Cascade length:  18
# New Orders left:  1110
# making new cascade
#
#
# OG Orders left:  1110
# Cascade length:  17
# New Orders left:  1093
# making new cascade
#
#
# OG Orders left:  1093
# Cascade length:  29
# New Orders left:  1064
# making new cascade
#
#
# OG Orders left:  1064
# Cascade length:  16
# New Orders left:  1048
# making new cascade
#
#
# OG Orders left:  1048
# Cascade length:  3
# New Orders left:  1045
# making new cascade
#
#
# OG Orders left:  1045
# Cascade length:  20
# New Orders left:  1025
# making new cascade
#
#
# OG Orders left:  1025
# Cascade length:  19
# New Orders left:  1006
# making new cascade
#
#
# OG Orders left:  1006
# Cascade length:  28
# New Orders left:  978
# making new cascade
#
#
# OG Orders left:  978
# Cascade length:  55
# New Orders left:  923
# making new cascade
#
#
# OG Orders left:  923
# Cascade length:  6
# New Orders left:  917
# making new cascade
#
#
# OG Orders left:  917
# Cascade length:  33
# New Orders left:  884
# making new cascade
#
#
# OG Orders left:  884
# Cascade length:  23
# New Orders left:  861
# making new cascade
#
#
# OG Orders left:  861
# Cascade length:  21
# New Orders left:  840
# making new cascade
#
#
# OG Orders left:  840
# Cascade length:  56
# New Orders left:  784
# making new cascade
#
#
# OG Orders left:  784
# Cascade length:  12
# New Orders left:  772
# making new cascade
#
#
# OG Orders left:  772
# Cascade length:  8
# New Orders left:  764
# making new cascade
#
#
# OG Orders left:  764
# Cascade length:  3
# New Orders left:  761
# making new cascade
#
#
# OG Orders left:  761
# Cascade length:  14
# New Orders left:  747
# making new cascade
#
#
# OG Orders left:  747
# Cascade length:  50
# New Orders left:  697
# making new cascade
#
#
# OG Orders left:  697
# Cascade length:  65
# New Orders left:  632
# making new cascade
#
#
# OG Orders left:  632
# Cascade length:  58
# New Orders left:  574
# making new cascade
#
#
# OG Orders left:  574
# Cascade length:  37
# New Orders left:  537
# making new cascade
#
#
# OG Orders left:  537
# Cascade length:  40
# New Orders left:  497
# making new cascade
#
#
# OG Orders left:  497
# Cascade length:  8
# New Orders left:  489
# making new cascade
#
#
# OG Orders left:  489
# Cascade length:  24
# New Orders left:  465
# making new cascade
#
#
# OG Orders left:  465
# Cascade length:  36
# New Orders left:  429
# making new cascade
#
#
# OG Orders left:  429
# Cascade length:  44
# New Orders left:  385
# making new cascade
#
#
# OG Orders left:  385
# Cascade length:  56
# New Orders left:  329
# making new cascade
#
#
# OG Orders left:  329
# Cascade length:  24
# New Orders left:  305
# making new cascade
#
#
# OG Orders left:  305
# Cascade length:  22
# New Orders left:  283
# making new cascade
#
#
# OG Orders left:  283
# Cascade length:  14
# New Orders left:  269
# making new cascade
#
#
# OG Orders left:  269
# Cascade length:  20
# New Orders left:  249
# making new cascade
#
#
# OG Orders left:  249
# Cascade length:  33
# New Orders left:  216
# making new cascade
#
#
# OG Orders left:  216
# Cascade length:  12
# New Orders left:  204
# making new cascade
#
#
# OG Orders left:  204
# Cascade length:  9
# New Orders left:  195
# making new cascade
#
#
# OG Orders left:  195
# Cascade length:  36
# New Orders left:  159
# making new cascade
#
#
# OG Orders left:  159
# Cascade length:  16
# New Orders left:  143
# making new cascade
#
#
# OG Orders left:  143
# Cascade length:  8
# New Orders left:  135
# making new cascade
#
#
# OG Orders left:  135
# Cascade length:  9
# New Orders left:  126
# making new cascade
#
#
# OG Orders left:  126
# Cascade length:  3
# New Orders left:  123
# making new cascade
#
#
# OG Orders left:  123
# Cascade length:  18
# New Orders left:  105
# making new cascade
#
#
# OG Orders left:  105
# Cascade length:  1
# New Orders left:  104
# making new cascade
#
#
# OG Orders left:  104
# Cascade length:  18
# New Orders left:  86
# making new cascade
#
#
# OG Orders left:  86
# Cascade length:  34
# New Orders left:  52
# making new cascade
#
#
# OG Orders left:  52
# Cascade length:  1
# New Orders left:  51
# making new cascade
#
#
# OG Orders left:  51
# Cascade length:  17
# New Orders left:  34
# making new cascade
#
#
# OG Orders left:  34
# Cascade length:  5
# New Orders left:  29
# making new cascade
#
#
# OG Orders left:  29
# Cascade length:  3
# New Orders left:  26
# making new cascade
#
#
# OG Orders left:  26
# Cascade length:  7
# New Orders left:  19
# making new cascade
#
#
# OG Orders left:  19
# Cascade length:  4
# New Orders left:  15
# making new cascade
#
#
# OG Orders left:  15
# Cascade length:  11
# New Orders left:  4
# making new cascade
#
#
# OG Orders left:  4
# Cascade length:  1
# New Orders left:  3
# making new cascade
#
#
# OG Orders left:  3
# Cascade length:  3
# New Orders left:  0
# making new cascade

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades12_npc_200_7200_100_5_10.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades11_npc_200_7200_100_5_10.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_500_7200_100_5_10_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_500_7200_100_5_10_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_npc_500_7200_100_5_10_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.85), '-.', label= "$x^{-0.85}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_5_10_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8)/5, '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_5_10_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8)/3, '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_5_10_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*5, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
