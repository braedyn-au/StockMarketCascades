# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_1000_5000_100_2_5.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_1000_5000_100_2_5.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_1000_5000_100_2_5.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_1000_5000_100_2_5.csv")

# %%
TtotalOrdersNPC
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 0   993     sniel     86    1.0
# 1                 0   993     yeqal     83   -1.0
# 2                 2   993     yeqal     85    2.0
# 3                 0   993     tcnoe     73    3.0
# 4                 1   993     tcnoe     74   -3.0
# ...             ...   ...       ...    ...    ...
# 2136648           2  5992     lekvh     62   16.0
# 2136649           0  5992     uesjc     42    5.0
# 2136650           3  5992     uesjc     50   -7.0
# 2136651           1  5992     vuemj     58    7.0
# 2136652           2  5992     vuemj     89   -3.0
#
# [2136653 rows x 5 columns]

# %%
type(TtotalOrdersNPC)
# Out:
# cudf.core.dataframe.DataFrame

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-8eb6452f45de> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     811                 return NotImplemented
#     812             else:
# --> 813                 return cudf_func(*args, **kwargs)
#     814
#     815         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    TtotalOrders = TtotalOrdersNPC
    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades22_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2136653
# Cascade length:  5629
# New Orders left:  2131024
# making new cascade
#
#
# OG Orders left:  2131024
# Cascade length:  5282
# New Orders left:  2125742
# making new cascade
#
#
# OG Orders left:  2125742
# Cascade length:  4954
# New Orders left:  2120788
# making new cascade
#
#
# OG Orders left:  2120788
# Cascade length:  3791
# New Orders left:  2116997
# making new cascade
#
#
# OG Orders left:  2116997
# Cascade length:  4684
# New Orders left:  2112313
# making new cascade
#
#
# OG Orders left:  2112313
# Cascade length:  1
# New Orders left:  2112312
# making new cascade
#
#
# OG Orders left:  2112312
# Cascade length:  4834
# New Orders left:  2107478
# making new cascade
#
#
# OG Orders left:  2107478
# Cascade length:  4511
# New Orders left:  2102967
# making new cascade
#
#
# OG Orders left:  2102967
# Cascade length:  4924
# New Orders left:  2098043
# making new cascade
#
#
# OG Orders left:  2098043
# Cascade length:  5129
# New Orders left:  2092914
# making new cascade
#
#
# OG Orders left:  2092914
# Cascade length:  5000
# New Orders left:  2087914
# making new cascade
#
#
# OG Orders left:  2087914
# Cascade length:  4320
# New Orders left:  2083594
# making new cascade
#
#
# OG Orders left:  2083594
# Cascade length:  4718
# New Orders left:  2078876
# making new cascade
#
#
# OG Orders left:  2078876
# Cascade length:  4517
# New Orders left:  2074359
# making new cascade
#
#
# OG Orders left:  2074359
# Cascade length:  4987
# New Orders left:  2069372
# making new cascade
#
#
# OG Orders left:  2069372
# Cascade length:  4205
# New Orders left:  2065167
# making new cascade
#
#
# OG Orders left:  2065167
# Cascade length:  4712
# New Orders left:  2060455
# making new cascade
#
#
# OG Orders left:  2060455
# Cascade length:  10
# New Orders left:  2060445
# making new cascade
#
#
# OG Orders left:  2060445
# Cascade length:  2
# New Orders left:  2060443
# making new cascade
#
#
# OG Orders left:  2060443
# Cascade length:  4604
# New Orders left:  2055839
# making new cascade
#
#
# OG Orders left:  2055839
# Cascade length:  5384
# New Orders left:  2050455
# making new cascade
#
#
# OG Orders left:  2050455
# Cascade length:  4019
# New Orders left:  2046436
# making new cascade
#
#
# OG Orders left:  2046436
# Cascade length:  25
# New Orders left:  2046411
# making new cascade
#
#
# OG Orders left:  2046411
# Cascade length:  4676
# New Orders left:  2041735
# making new cascade
#
#
# OG Orders left:  2041735
# Cascade length:  5273
# New Orders left:  2036462
# making new cascade
#
#
# OG Orders left:  2036462
# Cascade length:  5236
# New Orders left:  2031226
# making new cascade
#
#
# OG Orders left:  2031226
# Cascade length:  4461
# New Orders left:  2026765
# making new cascade
#
#
# OG Orders left:  2026765
# Cascade length:  2
# New Orders left:  2026763
# making new cascade
#
#
# OG Orders left:  2026763
# Cascade length:  5001
# New Orders left:  2021762
# making new cascade
#
#
# OG Orders left:  2021762
# Cascade length:  5026
# New Orders left:  2016736
# making new cascade
#
#
# OG Orders left:  2016736
# Cascade length:  4729
# New Orders left:  2012007
# making new cascade
#
#
# OG Orders left:  2012007
# Cascade length:  10
# New Orders left:  2011997
# making new cascade
#
#
# OG Orders left:  2011997
# Cascade length:  3538
# New Orders left:  2008459
# making new cascade
#
#
# OG Orders left:  2008459
# Cascade length:  4743
# New Orders left:  2003716
# making new cascade
#
#
# OG Orders left:  2003716
# Cascade length:  4261
# New Orders left:  1999455
# making new cascade
#
#
# OG Orders left:  1999455
# Cascade length:  4373
# New Orders left:  1995082
# making new cascade
#
#
# OG Orders left:  1995082
# Cascade length:  3109
# New Orders left:  1991973
# making new cascade
#
#
# OG Orders left:  1991973
# Cascade length:  3868
# New Orders left:  1988105
# making new cascade
#
#
# OG Orders left:  1988105
# Cascade length:  4086
# New Orders left:  1984019
# making new cascade
#
#
# OG Orders left:  1984019
# Cascade length:  3363
# New Orders left:  1980656
# making new cascade
#
#
# OG Orders left:  1980656
# Cascade length:  2
# New Orders left:  1980654
# making new cascade
#
#
# OG Orders left:  1980654
# Cascade length:  22
# New Orders left:  1980632
# making new cascade
#
#
# OG Orders left:  1980632
# Cascade length:  1
# New Orders left:  1980631
# making new cascade
#
#
# OG Orders left:  1980631
# Cascade length:  4423
# New Orders left:  1976208
# making new cascade
#
#
# OG Orders left:  1976208
# Cascade length:  3642
# New Orders left:  1972566
# making new cascade
#
#
# OG Orders left:  1972566
# Cascade length:  21
# New Orders left:  1972545
# making new cascade
#
#
# OG Orders left:  1972545
# Cascade length:  3132
# New Orders left:  1969413
# making new cascade
#
#
# OG Orders left:  1969413
# Cascade length:  4212
# New Orders left:  1965201
# making new cascade
#
#
# OG Orders left:  1965201
# Cascade length:  4424
# New Orders left:  1960777
# making new cascade
#
#
# OG Orders left:  1960777
# Cascade length:  4857
# New Orders left:  1955920
# making new cascade
#
#
# OG Orders left:  1955920
# Cascade length:  4216
# New Orders left:  1951704
# making new cascade
#
#
# OG Orders left:  1951704
# Cascade length:  3970
# New Orders left:  1947734
# making new cascade
#
#
# OG Orders left:  1947734
# Cascade length:  4270
# New Orders left:  1943464
# making new cascade
#
#
# OG Orders left:  1943464
# Cascade length:  3485
# New Orders left:  1939979
# making new cascade
#
#
# OG Orders left:  1939979
# Cascade length:  20
# New Orders left:  1939959
# making new cascade
#
#
# OG Orders left:  1939959
# Cascade length:  3794
# New Orders left:  1936165
# making new cascade
#
#
# OG Orders left:  1936165
# Cascade length:  4284
# New Orders left:  1931881
# making new cascade
#
#
# OG Orders left:  1931881
# Cascade length:  1
# New Orders left:  1931880
# making new cascade
#
#
# OG Orders left:  1931880
# Cascade length:  1
# New Orders left:  1931879
# making new cascade
#
#
# OG Orders left:  1931879
# Cascade length:  3717
# New Orders left:  1928162
# making new cascade
#
#
# OG Orders left:  1928162
# Cascade length:  3294
# New Orders left:  1924868
# making new cascade
#
#
# OG Orders left:  1924868
# Cascade length:  25
# New Orders left:  1924843
# making new cascade
#
#
# OG Orders left:  1924843
# Cascade length:  3
# New Orders left:  1924840
# making new cascade
#
#
# OG Orders left:  1924840
# Cascade length:  3329
# New Orders left:  1921511
# making new cascade
#
#
# OG Orders left:  1921511
# Cascade length:  5
# New Orders left:  1921506
# making new cascade
#
#
# OG Orders left:  1921506
# Cascade length:  2940
# New Orders left:  1918566
# making new cascade
#
#
# OG Orders left:  1918566
# Cascade length:  2917
# New Orders left:  1915649
# making new cascade
#
#
# OG Orders left:  1915649
# Cascade length:  3662
# New Orders left:  1911987
# making new cascade
#
#
# OG Orders left:  1911987
# Cascade length:  3132
# New Orders left:  1908855
# making new cascade
#
#
# OG Orders left:  1908855
# Cascade length:  3708
# New Orders left:  1905147
# making new cascade
#
#
# OG Orders left:  1905147
# Cascade length:  4282
# New Orders left:  1900865
# making new cascade
#
#
# OG Orders left:  1900865
# Cascade length:  2
# New Orders left:  1900863
# making new cascade
#
#
# OG Orders left:  1900863
# Cascade length:  2381
# New Orders left:  1898482
# making new cascade
#
#
# OG Orders left:  1898482
# Cascade length:  812
# New Orders left:  1897670
# making new cascade
#
#
# OG Orders left:  1897670
# Cascade length:  2645
# New Orders left:  1895025
# making new cascade
#
#
# OG Orders left:  1895025
# Cascade length:  3361
# New Orders left:  1891664
# making new cascade
#
#
# OG Orders left:  1891664
# Cascade length:  2
# New Orders left:  1891662
# making new cascade
#
#
# OG Orders left:  1891662
# Cascade length:  2756
# New Orders left:  1888906
# making new cascade
#
#
# OG Orders left:  1888906
# Cascade length:  39
# New Orders left:  1888867
# making new cascade
#
#
# OG Orders left:  1888867
# Cascade length:  2934
# New Orders left:  1885933
# making new cascade
#
#
# OG Orders left:  1885933
# Cascade length:  2
# New Orders left:  1885931
# making new cascade
#
#
# OG Orders left:  1885931
# Cascade length:  2763
# New Orders left:  1883168
# making new cascade
#
#
# OG Orders left:  1883168
# Cascade length:  1
# New Orders left:  1883167
# making new cascade
#
#
# OG Orders left:  1883167
# Cascade length:  16
# New Orders left:  1883151
# making new cascade
#
#
# OG Orders left:  1883151
# Cascade length:  3522
# New Orders left:  1879629
# making new cascade
#
#
# OG Orders left:  1879629
# Cascade length:  20
# New Orders left:  1879609
# making new cascade
#
#
# OG Orders left:  1879609
# Cascade length:  2581
# New Orders left:  1877028
# making new cascade
#
#
# OG Orders left:  1877028
# Cascade length:  3347
# New Orders left:  1873681
# making new cascade
#
#
# OG Orders left:  1873681
# Cascade length:  2248
# New Orders left:  1871433
# making new cascade
#
#
# OG Orders left:  1871433
# Cascade length:  24
# New Orders left:  1871409
# making new cascade
#
#
# OG Orders left:  1871409
# Cascade length:  21
# New Orders left:  1871388
# making new cascade
#
#
# OG Orders left:  1871388
# Cascade length:  3309
# New Orders left:  1868079
# making new cascade
#
#
# OG Orders left:  1868079
# Cascade length:  3490
# New Orders left:  1864589
# making new cascade
#
#
# OG Orders left:  1864589
# Cascade length:  2817
# New Orders left:  1861772
# making new cascade
#
#
# OG Orders left:  1861772
# Cascade length:  52
# New Orders left:  1861720
# making new cascade
#
#
# OG Orders left:  1861720
# Cascade length:  2166
# New Orders left:  1859554
# making new cascade
#
#
# OG Orders left:  1859554
# Cascade length:  3359
# New Orders left:  1856195
# making new cascade
#
#
# OG Orders left:  1856195
# Cascade length:  2
# New Orders left:  1856193
# making new cascade
#
#
# OG Orders left:  1856193
# Cascade length:  2
# New Orders left:  1856191
# making new cascade
#
#
# OG Orders left:  1856191
# Cascade length:  1
# New Orders left:  1856190
# making new cascade
#
#
# OG Orders left:  1856190
# Cascade length:  179
# New Orders left:  1856011
# making new cascade
#
#
# OG Orders left:  1856011
# Cascade length:  3035
# New Orders left:  1852976
# making new cascade
#
#
# OG Orders left:  1852976
# Cascade length:  725
# New Orders left:  1852251
# making new cascade
#
#
# OG Orders left:  1852251
# Cascade length:  10
# New Orders left:  1852241
# making new cascade
#
#
# OG Orders left:  1852241
# Cascade length:  2113
# New Orders left:  1850128
# making new cascade
#
#
# OG Orders left:  1850128
# Cascade length:  1981
# New Orders left:  1848147
# making new cascade
#
#
# OG Orders left:  1848147
# Cascade length:  8
# New Orders left:  1848139
# making new cascade
#
#
# OG Orders left:  1848139
# Cascade length:  42
# New Orders left:  1848097
# making new cascade
#
#
# OG Orders left:  1848097
# Cascade length:  2629
# New Orders left:  1845468
# making new cascade
#
#
# OG Orders left:  1845468
# Cascade length:  13
# New Orders left:  1845455
# making new cascade
#
#
# OG Orders left:  1845455
# Cascade length:  1732
# New Orders left:  1843723
# making new cascade
#
#
# OG Orders left:  1843723
# Cascade length:  9
# New Orders left:  1843714
# making new cascade
#
#
# OG Orders left:  1843714
# Cascade length:  1674
# New Orders left:  1842040
# making new cascade
#
#
# OG Orders left:  1842040
# Cascade length:  1
# New Orders left:  1842039
# making new cascade
#
#
# OG Orders left:  1842039
# Cascade length:  8
# New Orders left:  1842031
# making new cascade
#
#
# OG Orders left:  1842031
# Cascade length:  2340
# New Orders left:  1839691
# making new cascade
#
#
# OG Orders left:  1839691
# Cascade length:  37
# New Orders left:  1839654
# making new cascade
#
#
# OG Orders left:  1839654
# Cascade length:  2976
# New Orders left:  1836678
# making new cascade
#
#
# OG Orders left:  1836678
# Cascade length:  33
# New Orders left:  1836645
# making new cascade
#
#
# OG Orders left:  1836645
# Cascade length:  1571
# New Orders left:  1835074
# making new cascade
#
#
# OG Orders left:  1835074
# Cascade length:  2521
# New Orders left:  1832553
# making new cascade
#
#
# OG Orders left:  1832553
# Cascade length:  14
# New Orders left:  1832539
# making new cascade
#
#
# OG Orders left:  1832539
# Cascade length:  9
# New Orders left:  1832530
# making new cascade
#
#
# OG Orders left:  1832530
# Cascade length:  79
# New Orders left:  1832451
# making new cascade
#
#
# OG Orders left:  1832451
# Cascade length:  2538
# New Orders left:  1829913
# making new cascade
#
#
# OG Orders left:  1829913
# Cascade length:  2239
# New Orders left:  1827674
# making new cascade
#
#
# OG Orders left:  1827674
# Cascade length:  33
# New Orders left:  1827641
# making new cascade
#
#
# OG Orders left:  1827641
# Cascade length:  1672
# New Orders left:  1825969
# making new cascade
#
#
# OG Orders left:  1825969
# Cascade length:  2470
# New Orders left:  1823499
# making new cascade
#
#
# OG Orders left:  1823499
# Cascade length:  3055
# New Orders left:  1820444
# making new cascade
#
#
# OG Orders left:  1820444
# Cascade length:  2024
# New Orders left:  1818420
# making new cascade
#
#
# OG Orders left:  1818420
# Cascade length:  45
# New Orders left:  1818375
# making new cascade
#
#
# OG Orders left:  1818375
# Cascade length:  2735
# New Orders left:  1815640
# making new cascade
#
#
# OG Orders left:  1815640
# Cascade length:  4
# New Orders left:  1815636
# making new cascade
#
#
# OG Orders left:  1815636
# Cascade length:  2122
# New Orders left:  1813514
# making new cascade
#
#
# OG Orders left:  1813514
# Cascade length:  3122
# New Orders left:  1810392
# making new cascade
#
#
# OG Orders left:  1810392
# Cascade length:  3340
# New Orders left:  1807052
# making new cascade
#
#
# OG Orders left:  1807052
# Cascade length:  10
# New Orders left:  1807042
# making new cascade
#
#
# OG Orders left:  1807042
# Cascade length:  2723
# New Orders left:  1804319
# making new cascade
#
#
# OG Orders left:  1804319
# Cascade length:  2760
# New Orders left:  1801559
# making new cascade
#
#
# OG Orders left:  1801559
# Cascade length:  1970
# New Orders left:  1799589
# making new cascade
#
#
# OG Orders left:  1799589
# Cascade length:  2453
# New Orders left:  1797136
# making new cascade
#
#
# OG Orders left:  1797136
# Cascade length:  480
# New Orders left:  1796656
# making new cascade
#
#
# OG Orders left:  1796656
# Cascade length:  2
# New Orders left:  1796654
# making new cascade
#
#
# OG Orders left:  1796654
# Cascade length:  2448
# New Orders left:  1794206
# making new cascade
#
#
# OG Orders left:  1794206
# Cascade length:  2697
# New Orders left:  1791509
# making new cascade
#
#
# OG Orders left:  1791509
# Cascade length:  21
# New Orders left:  1791488
# making new cascade
#
#
# OG Orders left:  1791488
# Cascade length:  2357
# New Orders left:  1789131
# making new cascade
#
#
# OG Orders left:  1789131
# Cascade length:  22
# New Orders left:  1789109
# making new cascade
#
#
# OG Orders left:  1789109
# Cascade length:  2589
# New Orders left:  1786520
# making new cascade
#
#
# OG Orders left:  1786520
# Cascade length:  2303
# New Orders left:  1784217
# making new cascade
#
#
# OG Orders left:  1784217
# Cascade length:  72
# New Orders left:  1784145
# making new cascade
#
#
# OG Orders left:  1784145
# Cascade length:  40
# New Orders left:  1784105
# making new cascade
#
#
# OG Orders left:  1784105
# Cascade length:  129
# New Orders left:  1783976
# making new cascade
#
#
# OG Orders left:  1783976
# Cascade length:  31
# New Orders left:  1783945
# making new cascade
#
#
# OG Orders left:  1783945
# Cascade length:  26
# New Orders left:  1783919
# making new cascade
#
#
# OG Orders left:  1783919
# Cascade length:  22
# New Orders left:  1783897
# making new cascade
#
#
# OG Orders left:  1783897
# Cascade length:  2065
# New Orders left:  1781832
# making new cascade
#
#
# OG Orders left:  1781832
# Cascade length:  15
# New Orders left:  1781817
# making new cascade
#
#
# OG Orders left:  1781817
# Cascade length:  2390
# New Orders left:  1779427
# making new cascade
#
#
# OG Orders left:  1779427
# Cascade length:  4
# New Orders left:  1779423
# making new cascade
#
#
# OG Orders left:  1779423
# Cascade length:  2608
# New Orders left:  1776815
# making new cascade
#
#
# OG Orders left:  1776815
# Cascade length:  18
# New Orders left:  1776797
# making new cascade
#
#
# OG Orders left:  1776797
# Cascade length:  37
# New Orders left:  1776760
# making new cascade
#
#
# OG Orders left:  1776760
# Cascade length:  2508
# New Orders left:  1774252
# making new cascade
#
#
# OG Orders left:  1774252
# Cascade length:  2720
# New Orders left:  1771532
# making new cascade
#
#
# OG Orders left:  1771532
# Cascade length:  2048
# New Orders left:  1769484
# making new cascade
#
#
# OG Orders left:  1769484
# Cascade length:  1035
# New Orders left:  1768449
# making new cascade
#
#
# OG Orders left:  1768449
# Cascade length:  21
# New Orders left:  1768428
# making new cascade
#
#
# OG Orders left:  1768428
# Cascade length:  2274
# New Orders left:  1766154
# making new cascade
#
#
# OG Orders left:  1766154
# Cascade length:  1707
# New Orders left:  1764447
# making new cascade
#
#
# OG Orders left:  1764447
# Cascade length:  3120
# New Orders left:  1761327
# making new cascade
#
#
# OG Orders left:  1761327
# Cascade length:  2062
# New Orders left:  1759265
# making new cascade
#
#
# OG Orders left:  1759265
# Cascade length:  79
# New Orders left:  1759186
# making new cascade
#
#
# OG Orders left:  1759186
# Cascade length:  6
# New Orders left:  1759180
# making new cascade
#
#
# OG Orders left:  1759180
# Cascade length:  1268
# New Orders left:  1757912
# making new cascade
#
#
# OG Orders left:  1757912
# Cascade length:  2222
# New Orders left:  1755690
# making new cascade
#
#
# OG Orders left:  1755690
# Cascade length:  1606
# New Orders left:  1754084
# making new cascade
#
#
# OG Orders left:  1754084
# Cascade length:  2840
# New Orders left:  1751244
# making new cascade
#
#
# OG Orders left:  1751244
# Cascade length:  1
# New Orders left:  1751243
# making new cascade
#
#
# OG Orders left:  1751243
# Cascade length:  1
# New Orders left:  1751242
# making new cascade
#
#
# OG Orders left:  1751242
# Cascade length:  46
# New Orders left:  1751196
# making new cascade
#
#
# OG Orders left:  1751196
# Cascade length:  2204
# New Orders left:  1748992
# making new cascade
#
#
# OG Orders left:  1748992
# Cascade length:  1
# New Orders left:  1748991
# making new cascade
#
#
# OG Orders left:  1748991
# Cascade length:  1
# New Orders left:  1748990
# making new cascade
#
#
# OG Orders left:  1748990
# Cascade length:  2374
# New Orders left:  1746616
# making new cascade
#
#
# OG Orders left:  1746616
# Cascade length:  124
# New Orders left:  1746492
# making new cascade
#
#
# OG Orders left:  1746492
# Cascade length:  1072
# New Orders left:  1745420
# making new cascade
#
#
# OG Orders left:  1745420
# Cascade length:  2242
# New Orders left:  1743178
# making new cascade
#
#
# OG Orders left:  1743178
# Cascade length:  1249
# New Orders left:  1741929
# making new cascade
#
#
# OG Orders left:  1741929
# Cascade length:  1
# New Orders left:  1741928
# making new cascade
#
#
# OG Orders left:  1741928
# Cascade length:  8
# New Orders left:  1741920
# making new cascade
#
#
# OG Orders left:  1741920
# Cascade length:  39
# New Orders left:  1741881
# making new cascade
#
#
# OG Orders left:  1741881
# Cascade length:  22
# New Orders left:  1741859
# making new cascade
#
#
# OG Orders left:  1741859
# Cascade length:  1
# New Orders left:  1741858
# making new cascade
#
#
# OG Orders left:  1741858
# Cascade length:  2539
# New Orders left:  1739319
# making new cascade
#
#
# OG Orders left:  1739319
# Cascade length:  26
# New Orders left:  1739293
# making new cascade
#
#
# OG Orders left:  1739293
# Cascade length:  10
# New Orders left:  1739283
# making new cascade
#
#
# OG Orders left:  1739283
# Cascade length:  2274
# New Orders left:  1737009
# making new cascade
#
#
# OG Orders left:  1737009
# Cascade length:  1058
# New Orders left:  1735951
# making new cascade
#
#
# OG Orders left:  1735951
# Cascade length:  1
# New Orders left:  1735950
# making new cascade
#
#
# OG Orders left:  1735950
# Cascade length:  1
# New Orders left:  1735949
# making new cascade
#
#
# OG Orders left:  1735949
# Cascade length:  115
# New Orders left:  1735834
# making new cascade
#
#
# OG Orders left:  1735834
# Cascade length:  1779
# New Orders left:  1734055
# making new cascade
#
#
# OG Orders left:  1734055
# Cascade length:  2
# New Orders left:  1734053
# making new cascade
#
#
# OG Orders left:  1734053
# Cascade length:  35
# New Orders left:  1734018
# making new cascade
#
#
# OG Orders left:  1734018
# Cascade length:  45
# New Orders left:  1733973
# making new cascade
#
#
# OG Orders left:  1733973
# Cascade length:  20
# New Orders left:  1733953
# making new cascade
#
#
# OG Orders left:  1733953
# Cascade length:  1342
# New Orders left:  1732611
# making new cascade
#
#
# OG Orders left:  1732611
# Cascade length:  2070
# New Orders left:  1730541
# making new cascade
#
#
# OG Orders left:  1730541
# Cascade length:  306
# New Orders left:  1730235
# making new cascade
#
#
# OG Orders left:  1730235
# Cascade length:  10
# New Orders left:  1730225
# making new cascade
#
#
# OG Orders left:  1730225
# Cascade length:  1
# New Orders left:  1730224
# making new cascade
#
#
# OG Orders left:  1730224
# Cascade length:  2449
# New Orders left:  1727775
# making new cascade
#
#
# OG Orders left:  1727775
# Cascade length:  2100
# New Orders left:  1725675
# making new cascade
#
#
# OG Orders left:  1725675
# Cascade length:  1088
# New Orders left:  1724587
# making new cascade
#
#
# OG Orders left:  1724587
# Cascade length:  2
# New Orders left:  1724585
# making new cascade
#
#
# OG Orders left:  1724585
# Cascade length:  1074
# New Orders left:  1723511
# making new cascade
#
#
# OG Orders left:  1723511
# Cascade length:  106
# New Orders left:  1723405
# making new cascade
#
#
# OG Orders left:  1723405
# Cascade length:  82
# New Orders left:  1723323
# making new cascade
#
#
# OG Orders left:  1723323
# Cascade length:  1390
# New Orders left:  1721933
# making new cascade
#
#
# OG Orders left:  1721933
# Cascade length:  175
# New Orders left:  1721758
# making new cascade
#
#
# OG Orders left:  1721758
# Cascade length:  841
# New Orders left:  1720917
# making new cascade
#
#
# OG Orders left:  1720917
# Cascade length:  715
# New Orders left:  1720202
# making new cascade
#
#
# OG Orders left:  1720202
# Cascade length:  8
# New Orders left:  1720194
# making new cascade
#
#
# OG Orders left:  1720194
# Cascade length:  2304
# New Orders left:  1717890
# making new cascade
#
#
# OG Orders left:  1717890
# Cascade length:  2
# New Orders left:  1717888
# making new cascade
#
#
# OG Orders left:  1717888
# Cascade length:  88
# New Orders left:  1717800
# making new cascade
#
#
# OG Orders left:  1717800
# Cascade length:  485
# New Orders left:  1717315
# making new cascade
#
#
# OG Orders left:  1717315
# Cascade length:  6
# New Orders left:  1717309
# making new cascade
#
#
# OG Orders left:  1717309
# Cascade length:  44
# New Orders left:  1717265
# making new cascade
#
#
# OG Orders left:  1717265
# Cascade length:  451
# New Orders left:  1716814
# making new cascade
#
#
# OG Orders left:  1716814
# Cascade length:  115
# New Orders left:  1716699
# making new cascade
#
#
# OG Orders left:  1716699
# Cascade length:  37
# New Orders left:  1716662
# making new cascade
#
#
# OG Orders left:  1716662
# Cascade length:  2327
# New Orders left:  1714335
# making new cascade
#
#
# OG Orders left:  1714335
# Cascade length:  2917
# New Orders left:  1711418
# making new cascade
#
#
# OG Orders left:  1711418
# Cascade length:  668
# New Orders left:  1710750
# making new cascade
#
#
# OG Orders left:  1710750
# Cascade length:  937
# New Orders left:  1709813
# making new cascade
#
#
# OG Orders left:  1709813
# Cascade length:  17
# New Orders left:  1709796
# making new cascade
#
#
# OG Orders left:  1709796
# Cascade length:  163
# New Orders left:  1709633
# making new cascade
#
#
# OG Orders left:  1709633
# Cascade length:  1227
# New Orders left:  1708406
# making new cascade
#
#
# OG Orders left:  1708406
# Cascade length:  738
# New Orders left:  1707668
# making new cascade
#
#
# OG Orders left:  1707668
# Cascade length:  1377
# New Orders left:  1706291
# making new cascade
#
#
# OG Orders left:  1706291
# Cascade length:  524
# New Orders left:  1705767
# making new cascade
#
#
# OG Orders left:  1705767
# Cascade length:  1814
# New Orders left:  1703953
# making new cascade
#
#
# OG Orders left:  1703953
# Cascade length:  31
# New Orders left:  1703922
# making new cascade
#
#
# OG Orders left:  1703922
# Cascade length:  1140
# New Orders left:  1702782
# making new cascade
#
#
# OG Orders left:  1702782
# Cascade length:  1484
# New Orders left:  1701298
# making new cascade
#
#
# OG Orders left:  1701298
# Cascade length:  2
# New Orders left:  1701296
# making new cascade
#
#
# OG Orders left:  1701296
# Cascade length:  11
# New Orders left:  1701285
# making new cascade
#
#
# OG Orders left:  1701285
# Cascade length:  130
# New Orders left:  1701155
# making new cascade
#
#
# OG Orders left:  1701155
# Cascade length:  22
# New Orders left:  1701133
# making new cascade
#
#
# OG Orders left:  1701133
# Cascade length:  62
# New Orders left:  1701071
# making new cascade
#
#
# OG Orders left:  1701071
# Cascade length:  2009
# New Orders left:  1699062
# making new cascade
#
#
# OG Orders left:  1699062
# Cascade length:  1044
# New Orders left:  1698018
# making new cascade
#
#
# OG Orders left:  1698018
# Cascade length:  2
# New Orders left:  1698016
# making new cascade
#
#
# OG Orders left:  1698016
# Cascade length:  5
# New Orders left:  1698011
# making new cascade
#
#
# OG Orders left:  1698011
# Cascade length:  452
# New Orders left:  1697559
# making new cascade
#
#
# OG Orders left:  1697559
# Cascade length:  39
# New Orders left:  1697520
# making new cascade
#
#
# OG Orders left:  1697520
# Cascade length:  682
# New Orders left:  1696838
# making new cascade
#
#
# OG Orders left:  1696838
# Cascade length:  2
# New Orders left:  1696836
# making new cascade
#
#
# OG Orders left:  1696836
# Cascade length:  976
# New Orders left:  1695860
# making new cascade
#
#
# OG Orders left:  1695860
# Cascade length:  948
# New Orders left:  1694912
# making new cascade
#
#
# OG Orders left:  1694912
# Cascade length:  2749
# New Orders left:  1692163
# making new cascade
#
#
# OG Orders left:  1692163
# Cascade length:  535
# New Orders left:  1691628
# making new cascade
#
#
# OG Orders left:  1691628
# Cascade length:  25
# New Orders left:  1691603
# making new cascade
#
#
# OG Orders left:  1691603
# Cascade length:  67
# New Orders left:  1691536
# making new cascade
#
#
# OG Orders left:  1691536
# Cascade length:  9
# New Orders left:  1691527
# making new cascade
#
#
# OG Orders left:  1691527
# Cascade length:  2501
# New Orders left:  1689026
# making new cascade
#
#
# OG Orders left:  1689026
# Cascade length:  3182
# New Orders left:  1685844
# making new cascade
#
#
# OG Orders left:  1685844
# Cascade length:  37
# New Orders left:  1685807
# making new cascade
#
#
# OG Orders left:  1685807
# Cascade length:  195
# New Orders left:  1685612
# making new cascade
#
#
# OG Orders left:  1685612
# Cascade length:  60
# New Orders left:  1685552
# making new cascade
#
#
# OG Orders left:  1685552
# Cascade length:  481
# New Orders left:  1685071
# making new cascade
#
#
# OG Orders left:  1685071
# Cascade length:  2420
# New Orders left:  1682651
# making new cascade
#
#
# OG Orders left:  1682651
# Cascade length:  1594
# New Orders left:  1681057
# making new cascade
#
#
# OG Orders left:  1681057
# Cascade length:  30
# New Orders left:  1681027
# making new cascade
#
#
# OG Orders left:  1681027
# Cascade length:  2568
# New Orders left:  1678459
# making new cascade
#
#
# OG Orders left:  1678459
# Cascade length:  64
# New Orders left:  1678395
# making new cascade
#
#
# OG Orders left:  1678395
# Cascade length:  1547
# New Orders left:  1676848
# making new cascade
#
#
# OG Orders left:  1676848
# Cascade length:  2900
# New Orders left:  1673948
# making new cascade
#
#
# OG Orders left:  1673948
# Cascade length:  69
# New Orders left:  1673879
# making new cascade
#
#
# OG Orders left:  1673879
# Cascade length:  179
# New Orders left:  1673700
# making new cascade
#
#
# OG Orders left:  1673700
# Cascade length:  1223
# New Orders left:  1672477
# making new cascade
#
#
# OG Orders left:  1672477
# Cascade length:  128
# New Orders left:  1672349
# making new cascade
#
#
# OG Orders left:  1672349
# Cascade length:  50
# New Orders left:  1672299
# making new cascade
#
#
# OG Orders left:  1672299
# Cascade length:  8
# New Orders left:  1672291
# making new cascade
#
#
# OG Orders left:  1672291
# Cascade length:  60
# New Orders left:  1672231
# making new cascade
#
#
# OG Orders left:  1672231
# Cascade length:  8
# New Orders left:  1672223
# making new cascade
#
#
# OG Orders left:  1672223
# Cascade length:  1025
# New Orders left:  1671198
# making new cascade
#
#
# OG Orders left:  1671198
# Cascade length:  82
# New Orders left:  1671116
# making new cascade
#
#
# OG Orders left:  1671116
# Cascade length:  86
# New Orders left:  1671030
# making new cascade
#
#
# OG Orders left:  1671030
# Cascade length:  1622
# New Orders left:  1669408
# making new cascade
#
#
# OG Orders left:  1669408
# Cascade length:  2073
# New Orders left:  1667335
# making new cascade
#
#
# OG Orders left:  1667335
# Cascade length:  1188
# New Orders left:  1666147
# making new cascade
#
#
# OG Orders left:  1666147
# Cascade length:  93
# New Orders left:  1666054
# making new cascade
#
#
# OG Orders left:  1666054
# Cascade length:  11
# New Orders left:  1666043
# making new cascade
#
#
# OG Orders left:  1666043
# Cascade length:  57
# New Orders left:  1665986
# making new cascade
#
#
# OG Orders left:  1665986
# Cascade length:  1335
# New Orders left:  1664651
# making new cascade
#
#
# OG Orders left:  1664651
# Cascade length:  30
# New Orders left:  1664621
# making new cascade
#
#
# OG Orders left:  1664621
# Cascade length:  4
# New Orders left:  1664617
# making new cascade
#
#
# OG Orders left:  1664617
# Cascade length:  13
# New Orders left:  1664604
# making new cascade
#
#
# OG Orders left:  1664604
# Cascade length:  2554
# New Orders left:  1662050
# making new cascade
#
#
# OG Orders left:  1662050
# Cascade length:  986
# New Orders left:  1661064
# making new cascade
#
#
# OG Orders left:  1661064
# Cascade length:  149
# New Orders left:  1660915
# making new cascade
#
#
# OG Orders left:  1660915
# Cascade length:  33
# New Orders left:  1660882
# making new cascade
#
#
# OG Orders left:  1660882
# Cascade length:  1893
# New Orders left:  1658989
# making new cascade
#
#
# OG Orders left:  1658989
# Cascade length:  36
# New Orders left:  1658953
# making new cascade
#
#
# OG Orders left:  1658953
# Cascade length:  15
# New Orders left:  1658938
# making new cascade
#
#
# OG Orders left:  1658938
# Cascade length:  51
# New Orders left:  1658887
# making new cascade
#
#
# OG Orders left:  1658887
# Cascade length:  1247
# New Orders left:  1657640
# making new cascade
#
#
# OG Orders left:  1657640
# Cascade length:  737
# New Orders left:  1656903
# making new cascade
#
#
# OG Orders left:  1656903
# Cascade length:  209
# New Orders left:  1656694
# making new cascade
#
#
# OG Orders left:  1656694
# Cascade length:  45
# New Orders left:  1656649
# making new cascade
#
#
# OG Orders left:  1656649
# Cascade length:  39
# New Orders left:  1656610
# making new cascade
#
#
# OG Orders left:  1656610
# Cascade length:  1
# New Orders left:  1656609
# making new cascade
#
#
# OG Orders left:  1656609
# Cascade length:  1
# New Orders left:  1656608
# making new cascade
#
#
# OG Orders left:  1656608
# Cascade length:  1
# New Orders left:  1656607
# making new cascade
#
#
# OG Orders left:  1656607
# Cascade length:  8
# New Orders left:  1656599
# making new cascade
#
#
# OG Orders left:  1656599
# Cascade length:  1722
# New Orders left:  1654877
# making new cascade
#
#
# OG Orders left:  1654877
# Cascade length:  1746
# New Orders left:  1653131
# making new cascade
#
#
# OG Orders left:  1653131
# Cascade length:  26
# New Orders left:  1653105
# making new cascade
#
#
# OG Orders left:  1653105
# Cascade length:  6
# New Orders left:  1653099
# making new cascade
#
#
# OG Orders left:  1653099
# Cascade length:  583
# New Orders left:  1652516
# making new cascade
#
#
# OG Orders left:  1652516
# Cascade length:  8
# New Orders left:  1652508
# making new cascade
#
#
# OG Orders left:  1652508
# Cascade length:  238
# New Orders left:  1652270
# making new cascade
#
#
# OG Orders left:  1652270
# Cascade length:  874
# New Orders left:  1651396
# making new cascade
#
#
# OG Orders left:  1651396
# Cascade length:  73
# New Orders left:  1651323
# making new cascade
#
#
# OG Orders left:  1651323
# Cascade length:  2686
# New Orders left:  1648637
# making new cascade
#
#
# OG Orders left:  1648637
# Cascade length:  30
# New Orders left:  1648607
# making new cascade
#
#
# OG Orders left:  1648607
# Cascade length:  17
# New Orders left:  1648590
# making new cascade
#
#
# OG Orders left:  1648590
# Cascade length:  68
# New Orders left:  1648522
# making new cascade
#
#
# OG Orders left:  1648522
# Cascade length:  2668
# New Orders left:  1645854
# making new cascade
#
#
# OG Orders left:  1645854
# Cascade length:  15
# New Orders left:  1645839
# making new cascade
#
#
# OG Orders left:  1645839
# Cascade length:  2391
# New Orders left:  1643448
# making new cascade
#
#
# OG Orders left:  1643448
# Cascade length:  168
# New Orders left:  1643280
# making new cascade
#
#
# OG Orders left:  1643280
# Cascade length:  51
# New Orders left:  1643229
# making new cascade
#
#
# OG Orders left:  1643229
# Cascade length:  42
# New Orders left:  1643187
# making new cascade
#
#
# OG Orders left:  1643187
# Cascade length:  2435
# New Orders left:  1640752
# making new cascade
#
#
# OG Orders left:  1640752
# Cascade length:  1011
# New Orders left:  1639741
# making new cascade
#
#
# OG Orders left:  1639741
# Cascade length:  555
# New Orders left:  1639186
# making new cascade
#
#
# OG Orders left:  1639186
# Cascade length:  203
# New Orders left:  1638983
# making new cascade
#
#
# OG Orders left:  1638983
# Cascade length:  2787
# New Orders left:  1636196
# making new cascade
#
#
# OG Orders left:  1636196
# Cascade length:  238
# New Orders left:  1635958
# making new cascade
#
#
# OG Orders left:  1635958
# Cascade length:  1704
# New Orders left:  1634254
# making new cascade
#
#
# OG Orders left:  1634254
# Cascade length:  10
# New Orders left:  1634244
# making new cascade
#
#
# OG Orders left:  1634244
# Cascade length:  2548
# New Orders left:  1631696
# making new cascade
#
#
# OG Orders left:  1631696
# Cascade length:  35
# New Orders left:  1631661
# making new cascade
#
#
# OG Orders left:  1631661
# Cascade length:  1
# New Orders left:  1631660
# making new cascade
#
#
# OG Orders left:  1631660
# Cascade length:  105
# New Orders left:  1631555
# making new cascade
#
#
# OG Orders left:  1631555
# Cascade length:  6
# New Orders left:  1631549
# making new cascade
#
#
# OG Orders left:  1631549
# Cascade length:  1166
# New Orders left:  1630383
# making new cascade
#
#
# OG Orders left:  1630383
# Cascade length:  35
# New Orders left:  1630348
# making new cascade
#
#
# OG Orders left:  1630348
# Cascade length:  40
# New Orders left:  1630308
# making new cascade
#
#
# OG Orders left:  1630308
# Cascade length:  1259
# New Orders left:  1629049
# making new cascade
#
#
# OG Orders left:  1629049
# Cascade length:  35
# New Orders left:  1629014
# making new cascade
#
#
# OG Orders left:  1629014
# Cascade length:  2830
# New Orders left:  1626184
# making new cascade
#
#
# OG Orders left:  1626184
# Cascade length:  39
# New Orders left:  1626145
# making new cascade
#
#
# OG Orders left:  1626145
# Cascade length:  33
# New Orders left:  1626112
# making new cascade
#
#
# OG Orders left:  1626112
# Cascade length:  5
# New Orders left:  1626107
# making new cascade
#
#
# OG Orders left:  1626107
# Cascade length:  10
# New Orders left:  1626097
# making new cascade
#
#
# OG Orders left:  1626097
# Cascade length:  1705
# New Orders left:  1624392
# making new cascade
#
#
# OG Orders left:  1624392
# Cascade length:  82
# New Orders left:  1624310
# making new cascade
#
#
# OG Orders left:  1624310
# Cascade length:  763
# New Orders left:  1623547
# making new cascade
#
#
# OG Orders left:  1623547
# Cascade length:  33
# New Orders left:  1623514
# making new cascade
#
#
# OG Orders left:  1623514
# Cascade length:  85
# New Orders left:  1623429
# making new cascade
#
#
# OG Orders left:  1623429
# Cascade length:  48
# New Orders left:  1623381
# making new cascade
#
#
# OG Orders left:  1623381
# Cascade length:  57
# New Orders left:  1623324
# making new cascade
#
#
# OG Orders left:  1623324
# Cascade length:  3
# New Orders left:  1623321
# making new cascade
#
#
# OG Orders left:  1623321
# Cascade length:  482
# New Orders left:  1622839
# making new cascade
#
#
# OG Orders left:  1622839
# Cascade length:  1423
# New Orders left:  1621416
# making new cascade
#
#
# OG Orders left:  1621416
# Cascade length:  2776
# New Orders left:  1618640
# making new cascade
#
#
# OG Orders left:  1618640
# Cascade length:  1223
# New Orders left:  1617417
# making new cascade
#
#
# OG Orders left:  1617417
# Cascade length:  21
# New Orders left:  1617396
# making new cascade
#
#
# OG Orders left:  1617396
# Cascade length:  2000
# New Orders left:  1615396
# making new cascade
#
#
# OG Orders left:  1615396
# Cascade length:  1114
# New Orders left:  1614282
# making new cascade
#
#
# OG Orders left:  1614282
# Cascade length:  244
# New Orders left:  1614038
# making new cascade
#
#
# OG Orders left:  1614038
# Cascade length:  81
# New Orders left:  1613957
# making new cascade
#
#
# OG Orders left:  1613957
# Cascade length:  1
# New Orders left:  1613956
# making new cascade
#
#
# OG Orders left:  1613956
# Cascade length:  17
# New Orders left:  1613939
# making new cascade
#
#
# OG Orders left:  1613939
# Cascade length:  16
# New Orders left:  1613923
# making new cascade
#
#
# OG Orders left:  1613923
# Cascade length:  1194
# New Orders left:  1612729
# making new cascade
#
#
# OG Orders left:  1612729
# Cascade length:  2216
# New Orders left:  1610513
# making new cascade
#
#
# OG Orders left:  1610513
# Cascade length:  59
# New Orders left:  1610454
# making new cascade
#
#
# OG Orders left:  1610454
# Cascade length:  49
# New Orders left:  1610405
# making new cascade
#
#
# OG Orders left:  1610405
# Cascade length:  1
# New Orders left:  1610404
# making new cascade
#
#
# OG Orders left:  1610404
# Cascade length:  1404
# New Orders left:  1609000
# making new cascade
#
#
# OG Orders left:  1609000
# Cascade length:  53
# New Orders left:  1608947
# making new cascade
#
#
# OG Orders left:  1608947
# Cascade length:  134
# New Orders left:  1608813
# making new cascade
#
#
# OG Orders left:  1608813
# Cascade length:  8
# New Orders left:  1608805
# making new cascade
#
#
# OG Orders left:  1608805
# Cascade length:  26
# New Orders left:  1608779
# making new cascade
#
#
# OG Orders left:  1608779
# Cascade length:  1915
# New Orders left:  1606864
# making new cascade
#
#
# OG Orders left:  1606864
# Cascade length:  88
# New Orders left:  1606776
# making new cascade
#
#
# OG Orders left:  1606776
# Cascade length:  1
# New Orders left:  1606775
# making new cascade
#
#
# OG Orders left:  1606775
# Cascade length:  51
# New Orders left:  1606724
# making new cascade
#
#
# OG Orders left:  1606724
# Cascade length:  18
# New Orders left:  1606706
# making new cascade
#
#
# OG Orders left:  1606706
# Cascade length:  3
# New Orders left:  1606703
# making new cascade
#
#
# OG Orders left:  1606703
# Cascade length:  54
# New Orders left:  1606649
# making new cascade
#
#
# OG Orders left:  1606649
# Cascade length:  1332
# New Orders left:  1605317
# making new cascade
#
#
# OG Orders left:  1605317
# Cascade length:  1
# New Orders left:  1605316
# making new cascade
#
#
# OG Orders left:  1605316
# Cascade length:  2000
# New Orders left:  1603316
# making new cascade
#
#
# OG Orders left:  1603316
# Cascade length:  5
# New Orders left:  1603311
# making new cascade
#
#
# OG Orders left:  1603311
# Cascade length:  14
# New Orders left:  1603297
# making new cascade
#
#
# OG Orders left:  1603297
# Cascade length:  2683
# New Orders left:  1600614
# making new cascade
#
#
# OG Orders left:  1600614
# Cascade length:  2452
# New Orders left:  1598162
# making new cascade
#
#
# OG Orders left:  1598162
# Cascade length:  22
# New Orders left:  1598140
# making new cascade
#
#
# OG Orders left:  1598140
# Cascade length:  45
# New Orders left:  1598095
# making new cascade
#
#
# OG Orders left:  1598095
# Cascade length:  90
# New Orders left:  1598005
# making new cascade
#
#
# OG Orders left:  1598005
# Cascade length:  2
# New Orders left:  1598003
# making new cascade
#
#
# OG Orders left:  1598003
# Cascade length:  24
# New Orders left:  1597979
# making new cascade
#
#
# OG Orders left:  1597979
# Cascade length:  34
# New Orders left:  1597945
# making new cascade
#
#
# OG Orders left:  1597945
# Cascade length:  83
# New Orders left:  1597862
# making new cascade
#
#
# OG Orders left:  1597862
# Cascade length:  2079
# New Orders left:  1595783
# making new cascade
#
#
# OG Orders left:  1595783
# Cascade length:  5
# New Orders left:  1595778
# making new cascade
#
#
# OG Orders left:  1595778
# Cascade length:  41
# New Orders left:  1595737
# making new cascade
#
#
# OG Orders left:  1595737
# Cascade length:  107
# New Orders left:  1595630
# making new cascade
#
#
# OG Orders left:  1595630
# Cascade length:  71
# New Orders left:  1595559
# making new cascade
#
#
# OG Orders left:  1595559
# Cascade length:  123
# New Orders left:  1595436
# making new cascade
#
#
# OG Orders left:  1595436
# Cascade length:  1270
# New Orders left:  1594166
# making new cascade
#
#
# OG Orders left:  1594166
# Cascade length:  723
# New Orders left:  1593443
# making new cascade
#
#
# OG Orders left:  1593443
# Cascade length:  59
# New Orders left:  1593384
# making new cascade
#
#
# OG Orders left:  1593384
# Cascade length:  412
# New Orders left:  1592972
# making new cascade
#
#
# OG Orders left:  1592972
# Cascade length:  1
# New Orders left:  1592971
# making new cascade
#
#
# OG Orders left:  1592971
# Cascade length:  39
# New Orders left:  1592932
# making new cascade
#
#
# OG Orders left:  1592932
# Cascade length:  35
# New Orders left:  1592897
# making new cascade
#
#
# OG Orders left:  1592897
# Cascade length:  1532
# New Orders left:  1591365
# making new cascade
#
#
# OG Orders left:  1591365
# Cascade length:  78
# New Orders left:  1591287
# making new cascade
#
#
# OG Orders left:  1591287
# Cascade length:  4
# New Orders left:  1591283
# making new cascade
#
#
# OG Orders left:  1591283
# Cascade length:  91
# New Orders left:  1591192
# making new cascade
#
#
# OG Orders left:  1591192
# Cascade length:  37
# New Orders left:  1591155
# making new cascade
#
#
# OG Orders left:  1591155
# Cascade length:  125
# New Orders left:  1591030
# making new cascade
#
#
# OG Orders left:  1591030
# Cascade length:  14
# New Orders left:  1591016
# making new cascade
#
#
# OG Orders left:  1591016
# Cascade length:  30
# New Orders left:  1590986
# making new cascade
#
#
# OG Orders left:  1590986
# Cascade length:  30
# New Orders left:  1590956
# making new cascade
#
#
# OG Orders left:  1590956
# Cascade length:  82
# New Orders left:  1590874
# making new cascade
#
#
# OG Orders left:  1590874
# Cascade length:  34
# New Orders left:  1590840
# making new cascade
#
#
# OG Orders left:  1590840
# Cascade length:  22
# New Orders left:  1590818
# making new cascade
#
#
# OG Orders left:  1590818
# Cascade length:  58
# New Orders left:  1590760
# making new cascade
#
#
# OG Orders left:  1590760
# Cascade length:  1
# New Orders left:  1590759
# making new cascade
#
#
# OG Orders left:  1590759
# Cascade length:  52
# New Orders left:  1590707
# making new cascade
#
#
# OG Orders left:  1590707
# Cascade length:  44
# New Orders left:  1590663
# making new cascade
#
#
# OG Orders left:  1590663
# Cascade length:  95
# New Orders left:  1590568
# making new cascade
#
#
# OG Orders left:  1590568
# Cascade length:  41
# New Orders left:  1590527
# making new cascade
#
#
# OG Orders left:  1590527
# Cascade length:  1942
# New Orders left:  1588585
# making new cascade
#
#
# OG Orders left:  1588585
# Cascade length:  4
# New Orders left:  1588581
# making new cascade
#
#
# OG Orders left:  1588581
# Cascade length:  20
# New Orders left:  1588561
# making new cascade
#
#
# OG Orders left:  1588561
# Cascade length:  30
# New Orders left:  1588531
# making new cascade
#
#
# OG Orders left:  1588531
# Cascade length:  985
# New Orders left:  1587546
# making new cascade
#
#
# OG Orders left:  1587546
# Cascade length:  23
# New Orders left:  1587523
# making new cascade
#
#
# OG Orders left:  1587523
# Cascade length:  2043
# New Orders left:  1585480
# making new cascade
#
#
# OG Orders left:  1585480
# Cascade length:  131
# New Orders left:  1585349
# making new cascade
#
#
# OG Orders left:  1585349
# Cascade length:  2
# New Orders left:  1585347
# making new cascade
#
#
# OG Orders left:  1585347
# Cascade length:  1733
# New Orders left:  1583614
# making new cascade
#
#
# OG Orders left:  1583614
# Cascade length:  2885
# New Orders left:  1580729
# making new cascade
#
#
# OG Orders left:  1580729
# Cascade length:  62
# New Orders left:  1580667
# making new cascade
#
#
# OG Orders left:  1580667
# Cascade length:  2
# New Orders left:  1580665
# making new cascade
#
#
# OG Orders left:  1580665
# Cascade length:  1
# New Orders left:  1580664
# making new cascade
#
#
# OG Orders left:  1580664
# Cascade length:  1238
# New Orders left:  1579426
# making new cascade
#
#
# OG Orders left:  1579426
# Cascade length:  15
# New Orders left:  1579411
# making new cascade
#
#
# OG Orders left:  1579411
# Cascade length:  1547
# New Orders left:  1577864
# making new cascade
#
#
# OG Orders left:  1577864
# Cascade length:  2476
# New Orders left:  1575388
# making new cascade
#
#
# OG Orders left:  1575388
# Cascade length:  1298
# New Orders left:  1574090
# making new cascade
#
#
# OG Orders left:  1574090
# Cascade length:  28
# New Orders left:  1574062
# making new cascade
#
#
# OG Orders left:  1574062
# Cascade length:  690
# New Orders left:  1573372
# making new cascade
#
#
# OG Orders left:  1573372
# Cascade length:  1192
# New Orders left:  1572180
# making new cascade
#
#
# OG Orders left:  1572180
# Cascade length:  663
# New Orders left:  1571517
# making new cascade
#
#
# OG Orders left:  1571517
# Cascade length:  21
# New Orders left:  1571496
# making new cascade
#
#
# OG Orders left:  1571496
# Cascade length:  1836
# New Orders left:  1569660
# making new cascade
#
#
# OG Orders left:  1569660
# Cascade length:  39
# New Orders left:  1569621
# making new cascade
#
#
# OG Orders left:  1569621
# Cascade length:  5
# New Orders left:  1569616
# making new cascade
#
#
# OG Orders left:  1569616
# Cascade length:  1
# New Orders left:  1569615
# making new cascade
#
#
# OG Orders left:  1569615
# Cascade length:  24
# New Orders left:  1569591
# making new cascade
#
#
# OG Orders left:  1569591
# Cascade length:  54
# New Orders left:  1569537
# making new cascade
#
#
# OG Orders left:  1569537
# Cascade length:  2
# New Orders left:  1569535
# making new cascade
#
#
# OG Orders left:  1569535
# Cascade length:  36
# New Orders left:  1569499
# making new cascade
#
#
# OG Orders left:  1569499
# Cascade length:  105
# New Orders left:  1569394
# making new cascade
#
#
# OG Orders left:  1569394
# Cascade length:  1
# New Orders left:  1569393
# making new cascade
#
#
# OG Orders left:  1569393
# Cascade length:  1218
# New Orders left:  1568175
# making new cascade
#
#
# OG Orders left:  1568175
# Cascade length:  1321
# New Orders left:  1566854
# making new cascade
#
#
# OG Orders left:  1566854
# Cascade length:  16
# New Orders left:  1566838
# making new cascade
#
#
# OG Orders left:  1566838
# Cascade length:  776
# New Orders left:  1566062
# making new cascade
#
#
# OG Orders left:  1566062
# Cascade length:  1
# New Orders left:  1566061
# making new cascade
#
#
# OG Orders left:  1566061
# Cascade length:  722
# New Orders left:  1565339
# making new cascade
#
#
# OG Orders left:  1565339
# Cascade length:  549
# New Orders left:  1564790
# making new cascade
#
#
# OG Orders left:  1564790
# Cascade length:  10
# New Orders left:  1564780
# making new cascade
#
#
# OG Orders left:  1564780
# Cascade length:  1132
# New Orders left:  1563648
# making new cascade
#
#
# OG Orders left:  1563648
# Cascade length:  6
# New Orders left:  1563642
# making new cascade
#
#
# OG Orders left:  1563642
# Cascade length:  2426
# New Orders left:  1561216
# making new cascade
#
#
# OG Orders left:  1561216
# Cascade length:  10
# New Orders left:  1561206
# making new cascade
#
#
# OG Orders left:  1561206
# Cascade length:  1540
# New Orders left:  1559666
# making new cascade
#
#
# OG Orders left:  1559666
# Cascade length:  1145
# New Orders left:  1558521
# making new cascade
#
#
# OG Orders left:  1558521
# Cascade length:  92
# New Orders left:  1558429
# making new cascade
#
#
# OG Orders left:  1558429
# Cascade length:  1182
# New Orders left:  1557247
# making new cascade
#
#
# OG Orders left:  1557247
# Cascade length:  28
# New Orders left:  1557219
# making new cascade
#
#
# OG Orders left:  1557219
# Cascade length:  1
# New Orders left:  1557218
# making new cascade
#
#
# OG Orders left:  1557218
# Cascade length:  150
# New Orders left:  1557068
# making new cascade
#
#
# OG Orders left:  1557068
# Cascade length:  9
# New Orders left:  1557059
# making new cascade
#
#
# OG Orders left:  1557059
# Cascade length:  68
# New Orders left:  1556991
# making new cascade
#
#
# OG Orders left:  1556991
# Cascade length:  6
# New Orders left:  1556985
# making new cascade
#
#
# OG Orders left:  1556985
# Cascade length:  2052
# New Orders left:  1554933
# making new cascade
#
#
# OG Orders left:  1554933
# Cascade length:  1177
# New Orders left:  1553756
# making new cascade
#
#
# OG Orders left:  1553756
# Cascade length:  10
# New Orders left:  1553746
# making new cascade
#
#
# OG Orders left:  1553746
# Cascade length:  2
# New Orders left:  1553744
# making new cascade
#
#
# OG Orders left:  1553744
# Cascade length:  1825
# New Orders left:  1551919
# making new cascade
#
#
# OG Orders left:  1551919
# Cascade length:  2728
# New Orders left:  1549191
# making new cascade
#
#
# OG Orders left:  1549191
# Cascade length:  18
# New Orders left:  1549173
# making new cascade
#
#
# OG Orders left:  1549173
# Cascade length:  36
# New Orders left:  1549137
# making new cascade
#
#
# OG Orders left:  1549137
# Cascade length:  12
# New Orders left:  1549125
# making new cascade
#
#
# OG Orders left:  1549125
# Cascade length:  18
# New Orders left:  1549107
# making new cascade
#
#
# OG Orders left:  1549107
# Cascade length:  41
# New Orders left:  1549066
# making new cascade
#
#
# OG Orders left:  1549066
# Cascade length:  46
# New Orders left:  1549020
# making new cascade
#
#
# OG Orders left:  1549020
# Cascade length:  877
# New Orders left:  1548143
# making new cascade
#
#
# OG Orders left:  1548143
# Cascade length:  57
# New Orders left:  1548086
# making new cascade
#
#
# OG Orders left:  1548086
# Cascade length:  1852
# New Orders left:  1546234
# making new cascade
#
#
# OG Orders left:  1546234
# Cascade length:  2223
# New Orders left:  1544011
# making new cascade
#
#
# OG Orders left:  1544011
# Cascade length:  1
# New Orders left:  1544010
# making new cascade
#
#
# OG Orders left:  1544010
# Cascade length:  2619
# New Orders left:  1541391
# making new cascade
#
#
# OG Orders left:  1541391
# ...
#
#
# OG Orders left:  6971
# Cascade length:  2
# New Orders left:  6969
# making new cascade
#
#
# OG Orders left:  6969
# Cascade length:  20
# New Orders left:  6949
# making new cascade
#
#
# OG Orders left:  6949
# Cascade length:  13
# New Orders left:  6936
# making new cascade
#
#
# OG Orders left:  6936
# Cascade length:  4
# New Orders left:  6932
# making new cascade
#
#
# OG Orders left:  6932
# Cascade length:  8
# New Orders left:  6924
# making new cascade
#
#
# OG Orders left:  6924
# Cascade length:  55
# New Orders left:  6869
# making new cascade
#
#
# OG Orders left:  6869
# Cascade length:  171
# New Orders left:  6698
# making new cascade
#
#
# OG Orders left:  6698
# Cascade length:  26
# New Orders left:  6672
# making new cascade
#
#
# OG Orders left:  6672
# Cascade length:  181
# New Orders left:  6491
# making new cascade
#
#
# OG Orders left:  6491
# Cascade length:  4
# New Orders left:  6487
# making new cascade
#
#
# OG Orders left:  6487
# Cascade length:  7
# New Orders left:  6480
# making new cascade
#
#
# OG Orders left:  6480
# Cascade length:  43
# New Orders left:  6437
# making new cascade
#
#
# OG Orders left:  6437
# Cascade length:  65
# New Orders left:  6372
# making new cascade
#
#
# OG Orders left:  6372
# Cascade length:  61
# New Orders left:  6311
# making new cascade
#
#
# OG Orders left:  6311
# Cascade length:  121
# New Orders left:  6190
# making new cascade
#
#
# OG Orders left:  6190
# Cascade length:  64
# New Orders left:  6126
# making new cascade
#
#
# OG Orders left:  6126
# Cascade length:  1
# New Orders left:  6125
# making new cascade
#
#
# OG Orders left:  6125
# Cascade length:  36
# New Orders left:  6089
# making new cascade
#
#
# OG Orders left:  6089
# Cascade length:  48
# New Orders left:  6041
# making new cascade
#
#
# OG Orders left:  6041
# Cascade length:  3
# New Orders left:  6038
# making new cascade
#
#
# OG Orders left:  6038
# Cascade length:  1
# New Orders left:  6037
# making new cascade
#
#
# OG Orders left:  6037
# Cascade length:  3
# New Orders left:  6034
# making new cascade
#
#
# OG Orders left:  6034
# Cascade length:  84
# New Orders left:  5950
# making new cascade
#
#
# OG Orders left:  5950
# Cascade length:  11
# New Orders left:  5939
# making new cascade
#
#
# OG Orders left:  5939
# Cascade length:  105
# New Orders left:  5834
# making new cascade
#
#
# OG Orders left:  5834
# Cascade length:  1
# New Orders left:  5833
# making new cascade
#
#
# OG Orders left:  5833
# Cascade length:  15
# New Orders left:  5818
# making new cascade
#
#
# OG Orders left:  5818
# Cascade length:  5
# New Orders left:  5813
# making new cascade
#
#
# OG Orders left:  5813
# Cascade length:  78
# New Orders left:  5735
# making new cascade
#
#
# OG Orders left:  5735
# Cascade length:  24
# New Orders left:  5711
# making new cascade
#
#
# OG Orders left:  5711
# Cascade length:  110
# New Orders left:  5601
# making new cascade
#
#
# OG Orders left:  5601
# Cascade length:  2
# New Orders left:  5599
# making new cascade
#
#
# OG Orders left:  5599
# Cascade length:  84
# New Orders left:  5515
# making new cascade
#
#
# OG Orders left:  5515
# Cascade length:  28
# New Orders left:  5487
# making new cascade
#
#
# OG Orders left:  5487
# Cascade length:  9
# New Orders left:  5478
# making new cascade
#
#
# OG Orders left:  5478
# Cascade length:  1
# New Orders left:  5477
# making new cascade
#
#
# OG Orders left:  5477
# Cascade length:  180
# New Orders left:  5297
# making new cascade
#
#
# OG Orders left:  5297
# Cascade length:  17
# New Orders left:  5280
# making new cascade
#
#
# OG Orders left:  5280
# Cascade length:  110
# New Orders left:  5170
# making new cascade
#
#
# OG Orders left:  5170
# Cascade length:  136
# New Orders left:  5034
# making new cascade
#
#
# OG Orders left:  5034
# Cascade length:  24
# New Orders left:  5010
# making new cascade
#
#
# OG Orders left:  5010
# Cascade length:  36
# New Orders left:  4974
# making new cascade
#
#
# OG Orders left:  4974
# Cascade length:  88
# New Orders left:  4886
# making new cascade
#
#
# OG Orders left:  4886
# Cascade length:  38
# New Orders left:  4848
# making new cascade
#
#
# OG Orders left:  4848
# Cascade length:  40
# New Orders left:  4808
# making new cascade
#
#
# OG Orders left:  4808
# Cascade length:  32
# New Orders left:  4776
# making new cascade
#
#
# OG Orders left:  4776
# Cascade length:  2
# New Orders left:  4774
# making new cascade
#
#
# OG Orders left:  4774
# Cascade length:  93
# New Orders left:  4681
# making new cascade
#
#
# OG Orders left:  4681
# Cascade length:  38
# New Orders left:  4643
# making new cascade
#
#
# OG Orders left:  4643
# Cascade length:  120
# New Orders left:  4523
# making new cascade
#
#
# OG Orders left:  4523
# Cascade length:  1
# New Orders left:  4522
# making new cascade
#
#
# OG Orders left:  4522
# Cascade length:  46
# New Orders left:  4476
# making new cascade
#
#
# OG Orders left:  4476
# Cascade length:  4
# New Orders left:  4472
# making new cascade
#
#
# OG Orders left:  4472
# Cascade length:  22
# New Orders left:  4450
# making new cascade
#
#
# OG Orders left:  4450
# Cascade length:  49
# New Orders left:  4401
# making new cascade
#
#
# OG Orders left:  4401
# Cascade length:  7
# New Orders left:  4394
# making new cascade
#
#
# OG Orders left:  4394
# Cascade length:  40
# New Orders left:  4354
# making new cascade
#
#
# OG Orders left:  4354
# Cascade length:  4
# New Orders left:  4350
# making new cascade
#
#
# OG Orders left:  4350
# Cascade length:  13
# New Orders left:  4337
# making new cascade
#
#
# OG Orders left:  4337
# Cascade length:  56
# New Orders left:  4281
# making new cascade
#
#
# OG Orders left:  4281
# Cascade length:  38
# New Orders left:  4243
# making new cascade
#
#
# OG Orders left:  4243
# Cascade length:  60
# New Orders left:  4183
# making new cascade
#
#
# OG Orders left:  4183
# Cascade length:  4
# New Orders left:  4179
# making new cascade
#
#
# OG Orders left:  4179
# Cascade length:  60
# New Orders left:  4119
# making new cascade
#
#
# OG Orders left:  4119
# Cascade length:  64
# New Orders left:  4055
# making new cascade
#
#
# OG Orders left:  4055
# Cascade length:  49
# New Orders left:  4006
# making new cascade
#
#
# OG Orders left:  4006
# Cascade length:  5
# New Orders left:  4001
# making new cascade
#
#
# OG Orders left:  4001
# Cascade length:  215
# New Orders left:  3786
# making new cascade
#
#
# OG Orders left:  3786
# Cascade length:  2
# New Orders left:  3784
# making new cascade
#
#
# OG Orders left:  3784
# Cascade length:  47
# New Orders left:  3737
# making new cascade
#
#
# OG Orders left:  3737
# Cascade length:  2
# New Orders left:  3735
# making new cascade
#
#
# OG Orders left:  3735
# Cascade length:  30
# New Orders left:  3705
# making new cascade
#
#
# OG Orders left:  3705
# Cascade length:  24
# New Orders left:  3681
# making new cascade
#
#
# OG Orders left:  3681
# Cascade length:  25
# New Orders left:  3656
# making new cascade
#
#
# OG Orders left:  3656
# Cascade length:  92
# New Orders left:  3564
# making new cascade
#
#
# OG Orders left:  3564
# Cascade length:  74
# New Orders left:  3490
# making new cascade
#
#
# OG Orders left:  3490
# Cascade length:  52
# New Orders left:  3438
# making new cascade
#
#
# OG Orders left:  3438
# Cascade length:  51
# New Orders left:  3387
# making new cascade
#
#
# OG Orders left:  3387
# Cascade length:  78
# New Orders left:  3309
# making new cascade
#
#
# OG Orders left:  3309
# Cascade length:  30
# New Orders left:  3279
# making new cascade
#
#
# OG Orders left:  3279
# Cascade length:  151
# New Orders left:  3128
# making new cascade
#
#
# OG Orders left:  3128
# Cascade length:  6
# New Orders left:  3122
# making new cascade
#
#
# OG Orders left:  3122
# Cascade length:  61
# New Orders left:  3061
# making new cascade
#
#
# OG Orders left:  3061
# Cascade length:  115
# New Orders left:  2946
# making new cascade
#
#
# OG Orders left:  2946
# Cascade length:  8
# New Orders left:  2938
# making new cascade
#
#
# OG Orders left:  2938
# Cascade length:  1
# New Orders left:  2937
# making new cascade
#
#
# OG Orders left:  2937
# Cascade length:  4
# New Orders left:  2933
# making new cascade
#
#
# OG Orders left:  2933
# Cascade length:  45
# New Orders left:  2888
# making new cascade
#
#
# OG Orders left:  2888
# Cascade length:  8
# New Orders left:  2880
# making new cascade
#
#
# OG Orders left:  2880
# Cascade length:  34
# New Orders left:  2846
# making new cascade
#
#
# OG Orders left:  2846
# Cascade length:  14
# New Orders left:  2832
# making new cascade
#
#
# OG Orders left:  2832
# Cascade length:  72
# New Orders left:  2760
# making new cascade
#
#
# OG Orders left:  2760
# Cascade length:  9
# New Orders left:  2751
# making new cascade
#
#
# OG Orders left:  2751
# Cascade length:  54
# New Orders left:  2697
# making new cascade
#
#
# OG Orders left:  2697
# Cascade length:  9
# New Orders left:  2688
# making new cascade
#
#
# OG Orders left:  2688
# Cascade length:  74
# New Orders left:  2614
# making new cascade
#
#
# OG Orders left:  2614
# Cascade length:  2
# New Orders left:  2612
# making new cascade
#
#
# OG Orders left:  2612
# Cascade length:  153
# New Orders left:  2459
# making new cascade
#
#
# OG Orders left:  2459
# Cascade length:  55
# New Orders left:  2404
# making new cascade
#
#
# OG Orders left:  2404
# Cascade length:  39
# New Orders left:  2365
# making new cascade
#
#
# OG Orders left:  2365
# Cascade length:  50
# New Orders left:  2315
# making new cascade
#
#
# OG Orders left:  2315
# Cascade length:  62
# New Orders left:  2253
# making new cascade
#
#
# OG Orders left:  2253
# Cascade length:  38
# New Orders left:  2215
# making new cascade
#
#
# OG Orders left:  2215
# Cascade length:  19
# New Orders left:  2196
# making new cascade
#
#
# OG Orders left:  2196
# Cascade length:  15
# New Orders left:  2181
# making new cascade
#
#
# OG Orders left:  2181
# Cascade length:  9
# New Orders left:  2172
# making new cascade
#
#
# OG Orders left:  2172
# Cascade length:  116
# New Orders left:  2056
# making new cascade
#
#
# OG Orders left:  2056
# Cascade length:  46
# New Orders left:  2010
# making new cascade
#
#
# OG Orders left:  2010
# Cascade length:  9
# New Orders left:  2001
# making new cascade
#
#
# OG Orders left:  2001
# Cascade length:  83
# New Orders left:  1918
# making new cascade
#
#
# OG Orders left:  1918
# Cascade length:  7
# New Orders left:  1911
# making new cascade
#
#
# OG Orders left:  1911
# Cascade length:  21
# New Orders left:  1890
# making new cascade
#
#
# OG Orders left:  1890
# Cascade length:  24
# New Orders left:  1866
# making new cascade
#
#
# OG Orders left:  1866
# Cascade length:  29
# New Orders left:  1837
# making new cascade
#
#
# OG Orders left:  1837
# Cascade length:  22
# New Orders left:  1815
# making new cascade
#
#
# OG Orders left:  1815
# Cascade length:  69
# New Orders left:  1746
# making new cascade
#
#
# OG Orders left:  1746
# Cascade length:  3
# New Orders left:  1743
# making new cascade
#
#
# OG Orders left:  1743
# Cascade length:  2
# New Orders left:  1741
# making new cascade
#
#
# OG Orders left:  1741
# Cascade length:  49
# New Orders left:  1692
# making new cascade
#
#
# OG Orders left:  1692
# Cascade length:  25
# New Orders left:  1667
# making new cascade
#
#
# OG Orders left:  1667
# Cascade length:  5
# New Orders left:  1662
# making new cascade
#
#
# OG Orders left:  1662
# Cascade length:  46
# New Orders left:  1616
# making new cascade
#
#
# OG Orders left:  1616
# Cascade length:  32
# New Orders left:  1584
# making new cascade
#
#
# OG Orders left:  1584
# Cascade length:  1
# New Orders left:  1583
# making new cascade
#
#
# OG Orders left:  1583
# Cascade length:  80
# New Orders left:  1503
# making new cascade
#
#
# OG Orders left:  1503
# Cascade length:  1
# New Orders left:  1502
# making new cascade
#
#
# OG Orders left:  1502
# Cascade length:  10
# New Orders left:  1492
# making new cascade
#
#
# OG Orders left:  1492
# Cascade length:  39
# New Orders left:  1453
# making new cascade
#
#
# OG Orders left:  1453
# Cascade length:  30
# New Orders left:  1423
# making new cascade
#
#
# OG Orders left:  1423
# Cascade length:  14
# New Orders left:  1409
# making new cascade
#
#
# OG Orders left:  1409
# Cascade length:  44
# New Orders left:  1365
# making new cascade
#
#
# OG Orders left:  1365
# Cascade length:  5
# New Orders left:  1360
# making new cascade
#
#
# OG Orders left:  1360
# Cascade length:  88
# New Orders left:  1272
# making new cascade
#
#
# OG Orders left:  1272
# Cascade length:  6
# New Orders left:  1266
# making new cascade
#
#
# OG Orders left:  1266
# Cascade length:  97
# New Orders left:  1169
# making new cascade
#
#
# OG Orders left:  1169
# Cascade length:  7
# New Orders left:  1162
# making new cascade
#
#
# OG Orders left:  1162
# Cascade length:  115
# New Orders left:  1047
# making new cascade
#
#
# OG Orders left:  1047
# Cascade length:  25
# New Orders left:  1022
# making new cascade
#
#
# OG Orders left:  1022
# Cascade length:  2
# New Orders left:  1020
# making new cascade
#
#
# OG Orders left:  1020
# Cascade length:  16
# New Orders left:  1004
# making new cascade
#
#
# OG Orders left:  1004
# Cascade length:  54
# New Orders left:  950
# making new cascade
#
#
# OG Orders left:  950
# Cascade length:  1
# New Orders left:  949
# making new cascade
#
#
# OG Orders left:  949
# Cascade length:  17
# New Orders left:  932
# making new cascade
#
#
# OG Orders left:  932
# Cascade length:  100
# New Orders left:  832
# making new cascade
#
#
# OG Orders left:  832
# Cascade length:  25
# New Orders left:  807
# making new cascade
#
#
# OG Orders left:  807
# Cascade length:  28
# New Orders left:  779
# making new cascade
#
#
# OG Orders left:  779
# Cascade length:  79
# New Orders left:  700
# making new cascade
#
#
# OG Orders left:  700
# Cascade length:  1
# New Orders left:  699
# making new cascade
#
#
# OG Orders left:  699
# Cascade length:  16
# New Orders left:  683
# making new cascade
#
#
# OG Orders left:  683
# Cascade length:  35
# New Orders left:  648
# making new cascade
#
#
# OG Orders left:  648
# Cascade length:  39
# New Orders left:  609
# making new cascade
#
#
# OG Orders left:  609
# Cascade length:  30
# New Orders left:  579
# making new cascade
#
#
# OG Orders left:  579
# Cascade length:  67
# New Orders left:  512
# making new cascade
#
#
# OG Orders left:  512
# Cascade length:  50
# New Orders left:  462
# making new cascade
#
#
# OG Orders left:  462
# Cascade length:  8
# New Orders left:  454
# making new cascade
#
#
# OG Orders left:  454
# Cascade length:  23
# New Orders left:  431
# making new cascade
#
#
# OG Orders left:  431
# Cascade length:  9
# New Orders left:  422
# making new cascade
#
#
# OG Orders left:  422
# Cascade length:  49
# New Orders left:  373
# making new cascade
#
#
# OG Orders left:  373
# Cascade length:  6
# New Orders left:  367
# making new cascade
#
#
# OG Orders left:  367
# Cascade length:  6
# New Orders left:  361
# making new cascade
#
#
# OG Orders left:  361
# Cascade length:  23
# New Orders left:  338
# making new cascade
#
#
# OG Orders left:  338
# Cascade length:  2
# New Orders left:  336
# making new cascade
#
#
# OG Orders left:  336
# Cascade length:  71
# New Orders left:  265
# making new cascade
#
#
# OG Orders left:  265
# Cascade length:  5
# New Orders left:  260
# making new cascade
#
#
# OG Orders left:  260
# Cascade length:  6
# New Orders left:  254
# making new cascade
#
#
# OG Orders left:  254
# Cascade length:  23
# New Orders left:  231
# making new cascade
#
#
# OG Orders left:  231
# Cascade length:  15
# New Orders left:  216
# making new cascade
#
#
# OG Orders left:  216
# Cascade length:  19
# New Orders left:  197
# making new cascade
#
#
# OG Orders left:  197
# Cascade length:  2
# New Orders left:  195
# making new cascade
#
#
# OG Orders left:  195
# Cascade length:  6
# New Orders left:  189
# making new cascade
#
#
# OG Orders left:  189
# Cascade length:  54
# New Orders left:  135
# making new cascade
#
#
# OG Orders left:  135
# Cascade length:  8
# New Orders left:  127
# making new cascade
#
#
# OG Orders left:  127
# Cascade length:  24
# New Orders left:  103
# making new cascade
#
#
# OG Orders left:  103
# Cascade length:  5
# New Orders left:  98
# making new cascade
#
#
# OG Orders left:  98
# Cascade length:  6
# New Orders left:  92
# making new cascade
#
#
# OG Orders left:  92
# Cascade length:  12
# New Orders left:  80
# making new cascade
#
#
# OG Orders left:  80
# Cascade length:  10
# New Orders left:  70
# making new cascade
#
#
# OG Orders left:  70
# Cascade length:  6
# New Orders left:  64
# making new cascade
#
#
# OG Orders left:  64
# Cascade length:  6
# New Orders left:  58
# making new cascade
#
#
# OG Orders left:  58
# Cascade length:  10
# New Orders left:  48
# making new cascade
#
#
# OG Orders left:  48
# Cascade length:  14
# New Orders left:  34
# making new cascade
#
#
# OG Orders left:  34
# Cascade length:  4
# New Orders left:  30
# making new cascade
#
#
# OG Orders left:  30
# Cascade length:  10
# New Orders left:  20
# making new cascade
#
#
# OG Orders left:  20
# Cascade length:  1
# New Orders left:  19
# making new cascade
#
#
# OG Orders left:  19
# Cascade length:  8
# New Orders left:  11
# making new cascade
#
#
# OG Orders left:  11
# Cascade length:  4
# New Orders left:  7
# making new cascade
#
#
# OG Orders left:  7
# Cascade length:  4
# New Orders left:  3
# making new cascade
#
#
# OG Orders left:  3
# Cascade length:  3
# New Orders left:  0
# making new cascade

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades21_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades12_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades11_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*5, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
