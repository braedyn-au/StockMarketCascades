# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/2-4/traderIDs_501_5000_100_2_5.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/2-4/stockPool_501_5000_100_2_5.npy")
hurstPoolNPC = np.load("./results/nopricechange/2-4/hurstPool_501_5000_100_2_5.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/2-4/totalOrders_501_5000_100_2_5.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 2   993     pcaot      6    1.0
# 1                 0   993     vpneq     10    2.0
# 2                 3   993     vpneq     13   -1.0
# 3                 2   993     jzndk     14    1.0
# 4                 1   993     jwivu     13   -2.0
# ...             ...   ...       ...    ...    ...
# 2139960           2  5992     khrsl     62    4.0
# 2139961           0  5992     sujzt     75   -6.0
# 2139962           1  5992     sujzt     62    4.0
# 2139963           0  5992     gdnqf     75  -91.0
# 2139964           1  5992     gdnqf     62   67.0
#
# [2139965 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/2-4/causalCascades22_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2139965

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/2-4/causalCascades21_npc_501_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  995303
# Cascade length:  943
# New Orders left:  994360
# making new cascade
#
#
# OG Orders left:  994360
# Cascade length:  951
# New Orders left:  993409
# making new cascade
#
#
# OG Orders left:  993409
# Cascade length:  1139
# New Orders left:  992270
# making new cascade
#
#
# OG Orders left:  992270
# Cascade length:  600
# New Orders left:  991670
# making new cascade
#
#
# OG Orders left:  991670
# Cascade length:  726
# New Orders left:  990944
# making new cascade
#
#
# OG Orders left:  990944
# Cascade length:  850
# New Orders left:  990094
# making new cascade
#
#
# OG Orders left:  990094
# Cascade length:  548
# New Orders left:  989546
# making new cascade
#
#
# OG Orders left:  989546
# Cascade length:  1194
# New Orders left:  988352
# making new cascade
#
#
# OG Orders left:  988352
# Cascade length:  638
# New Orders left:  987714
# making new cascade
#
#
# OG Orders left:  987714
# Cascade length:  1
# New Orders left:  987713
# making new cascade
#
#
# OG Orders left:  987713
# Cascade length:  1035
# New Orders left:  986678
# making new cascade
#
#
# OG Orders left:  986678
# Cascade length:  829
# New Orders left:  985849
# making new cascade
#
#
# OG Orders left:  985849
# Cascade length:  868
# New Orders left:  984981
# making new cascade
#
#
# OG Orders left:  984981
# Cascade length:  949
# New Orders left:  984032
# making new cascade
#
#
# OG Orders left:  984032
# Cascade length:  861
# New Orders left:  983171
# making new cascade
#
#
# OG Orders left:  983171
# Cascade length:  984
# New Orders left:  982187
# making new cascade
#
#
# OG Orders left:  982187
# Cascade length:  568
# New Orders left:  981619
# making new cascade
#
#
# OG Orders left:  981619
# Cascade length:  1073
# New Orders left:  980546
# making new cascade
#
#
# OG Orders left:  980546
# Cascade length:  1
# New Orders left:  980545
# making new cascade
#
#
# OG Orders left:  980545
# Cascade length:  514
# New Orders left:  980031
# making new cascade
#
#
# OG Orders left:  980031
# Cascade length:  821
# New Orders left:  979210
# making new cascade
#
#
# OG Orders left:  979210
# Cascade length:  724
# New Orders left:  978486
# making new cascade
#
#
# OG Orders left:  978486
# Cascade length:  1078
# New Orders left:  977408
# making new cascade
#
#
# OG Orders left:  977408
# Cascade length:  7
# New Orders left:  977401
# making new cascade
#
#
# OG Orders left:  977401
# Cascade length:  5
# New Orders left:  977396
# making new cascade
#
#
# OG Orders left:  977396
# Cascade length:  499
# New Orders left:  976897
# making new cascade
#
#
# OG Orders left:  976897
# Cascade length:  1102
# New Orders left:  975795
# making new cascade
#
#
# OG Orders left:  975795
# Cascade length:  293
# New Orders left:  975502
# making new cascade
#
#
# OG Orders left:  975502
# Cascade length:  12
# New Orders left:  975490
# making new cascade
#
#
# OG Orders left:  975490
# Cascade length:  2
# New Orders left:  975488
# making new cascade
#
#
# OG Orders left:  975488
# Cascade length:  1168
# New Orders left:  974320
# making new cascade
#
#
# OG Orders left:  974320
# Cascade length:  9
# New Orders left:  974311
# making new cascade
#
#
# OG Orders left:  974311
# Cascade length:  481
# New Orders left:  973830
# making new cascade
#
#
# OG Orders left:  973830
# Cascade length:  468
# New Orders left:  973362
# making new cascade
#
#
# OG Orders left:  973362
# Cascade length:  712
# New Orders left:  972650
# making new cascade
#
#
# OG Orders left:  972650
# Cascade length:  3
# New Orders left:  972647
# making new cascade
#
#
# OG Orders left:  972647
# Cascade length:  1104
# New Orders left:  971543
# making new cascade
#
#
# OG Orders left:  971543
# Cascade length:  457
# New Orders left:  971086
# making new cascade
#
#
# OG Orders left:  971086
# Cascade length:  378
# New Orders left:  970708
# making new cascade
#
#
# OG Orders left:  970708
# Cascade length:  4
# New Orders left:  970704
# making new cascade
#
#
# OG Orders left:  970704
# Cascade length:  602
# New Orders left:  970102
# making new cascade
#
#
# OG Orders left:  970102
# Cascade length:  158
# New Orders left:  969944
# making new cascade
#
#
# OG Orders left:  969944
# Cascade length:  1045
# New Orders left:  968899
# making new cascade
#
#
# OG Orders left:  968899
# Cascade length:  180
# New Orders left:  968719
# making new cascade
#
#
# OG Orders left:  968719
# Cascade length:  736
# New Orders left:  967983
# making new cascade
#
#
# OG Orders left:  967983
# Cascade length:  382
# New Orders left:  967601
# making new cascade
#
#
# OG Orders left:  967601
# Cascade length:  796
# New Orders left:  966805
# making new cascade
#
#
# OG Orders left:  966805
# Cascade length:  514
# New Orders left:  966291
# making new cascade
#
#
# OG Orders left:  966291
# Cascade length:  2
# New Orders left:  966289
# making new cascade
#
#
# OG Orders left:  966289
# Cascade length:  568
# New Orders left:  965721
# making new cascade
#
#
# OG Orders left:  965721
# Cascade length:  1029
# New Orders left:  964692
# making new cascade
#
#
# OG Orders left:  964692
# Cascade length:  1098
# New Orders left:  963594
# making new cascade
#
#
# OG Orders left:  963594
# Cascade length:  405
# New Orders left:  963189
# making new cascade
#
#
# OG Orders left:  963189
# Cascade length:  4
# New Orders left:  963185
# making new cascade
#
#
# OG Orders left:  963185
# Cascade length:  1014
# New Orders left:  962171
# making new cascade
#
#
# OG Orders left:  962171
# Cascade length:  485
# New Orders left:  961686
# making new cascade
#
#
# OG Orders left:  961686
# Cascade length:  6
# New Orders left:  961680
# making new cascade
#
#
# OG Orders left:  961680
# Cascade length:  503
# New Orders left:  961177
# making new cascade
#
#
# OG Orders left:  961177
# Cascade length:  4
# New Orders left:  961173
# making new cascade
#
#
# OG Orders left:  961173
# Cascade length:  986
# New Orders left:  960187
# making new cascade
#
#
# OG Orders left:  960187
# Cascade length:  629
# New Orders left:  959558
# making new cascade
#
#
# OG Orders left:  959558
# Cascade length:  282
# New Orders left:  959276
# making new cascade
#
#
# OG Orders left:  959276
# Cascade length:  2
# New Orders left:  959274
# making new cascade
#
#
# OG Orders left:  959274
# Cascade length:  7
# New Orders left:  959267
# making new cascade
#
#
# OG Orders left:  959267
# Cascade length:  150
# New Orders left:  959117
# making new cascade
#
#
# OG Orders left:  959117
# Cascade length:  1003
# New Orders left:  958114
# making new cascade
#
#
# OG Orders left:  958114
# Cascade length:  761
# New Orders left:  957353
# making new cascade
#
#
# OG Orders left:  957353
# Cascade length:  235
# New Orders left:  957118
# making new cascade
#
#
# OG Orders left:  957118
# Cascade length:  110
# New Orders left:  957008
# making new cascade
#
#
# OG Orders left:  957008
# Cascade length:  7
# New Orders left:  957001
# making new cascade
#
#
# OG Orders left:  957001
# Cascade length:  1151
# New Orders left:  955850
# making new cascade
#
#
# OG Orders left:  955850
# Cascade length:  2
# New Orders left:  955848
# making new cascade
#
#
# OG Orders left:  955848
# Cascade length:  1
# New Orders left:  955847
# making new cascade
#
#
# OG Orders left:  955847
# Cascade length:  2
# New Orders left:  955845
# making new cascade
#
#
# OG Orders left:  955845
# Cascade length:  335
# New Orders left:  955510
# making new cascade
#
#
# OG Orders left:  955510
# Cascade length:  1
# New Orders left:  955509
# making new cascade
#
#
# OG Orders left:  955509
# Cascade length:  10
# New Orders left:  955499
# making new cascade
#
#
# OG Orders left:  955499
# Cascade length:  11
# New Orders left:  955488
# making new cascade
#
#
# OG Orders left:  955488
# Cascade length:  377
# New Orders left:  955111
# making new cascade
#
#
# OG Orders left:  955111
# Cascade length:  2
# New Orders left:  955109
# making new cascade
#
#
# OG Orders left:  955109
# Cascade length:  1161
# New Orders left:  953948
# making new cascade
#
#
# OG Orders left:  953948
# Cascade length:  875
# New Orders left:  953073
# making new cascade
#
#
# OG Orders left:  953073
# Cascade length:  2
# New Orders left:  953071
# making new cascade
#
#
# OG Orders left:  953071
# Cascade length:  11
# New Orders left:  953060
# making new cascade
#
#
# OG Orders left:  953060
# Cascade length:  505
# New Orders left:  952555
# making new cascade
#
#
# OG Orders left:  952555
# Cascade length:  1006
# New Orders left:  951549
# making new cascade
#
#
# OG Orders left:  951549
# Cascade length:  269
# New Orders left:  951280
# making new cascade
#
#
# OG Orders left:  951280
# Cascade length:  1
# New Orders left:  951279
# making new cascade
#
#
# OG Orders left:  951279
# Cascade length:  528
# New Orders left:  950751
# making new cascade
#
#
# OG Orders left:  950751
# Cascade length:  5
# New Orders left:  950746
# making new cascade
#
#
# OG Orders left:  950746
# Cascade length:  369
# New Orders left:  950377
# making new cascade
#
#
# OG Orders left:  950377
# Cascade length:  419
# New Orders left:  949958
# making new cascade
#
#
# OG Orders left:  949958
# Cascade length:  82
# New Orders left:  949876
# making new cascade
#
#
# OG Orders left:  949876
# Cascade length:  950
# New Orders left:  948926
# making new cascade
#
#
# OG Orders left:  948926
# Cascade length:  359
# New Orders left:  948567
# making new cascade
#
#
# OG Orders left:  948567
# Cascade length:  68
# New Orders left:  948499
# making new cascade
#
#
# OG Orders left:  948499
# Cascade length:  159
# New Orders left:  948340
# making new cascade
#
#
# OG Orders left:  948340
# Cascade length:  340
# New Orders left:  948000
# making new cascade
#
#
# OG Orders left:  948000
# Cascade length:  580
# New Orders left:  947420
# making new cascade
#
#
# OG Orders left:  947420
# Cascade length:  778
# New Orders left:  946642
# making new cascade
#
#
# OG Orders left:  946642
# Cascade length:  553
# New Orders left:  946089
# making new cascade
#
#
# OG Orders left:  946089
# Cascade length:  838
# New Orders left:  945251
# making new cascade
#
#
# OG Orders left:  945251
# Cascade length:  8
# New Orders left:  945243
# making new cascade
#
#
# OG Orders left:  945243
# Cascade length:  185
# New Orders left:  945058
# making new cascade
#
#
# OG Orders left:  945058
# Cascade length:  15
# New Orders left:  945043
# making new cascade
#
#
# OG Orders left:  945043
# Cascade length:  470
# New Orders left:  944573
# making new cascade
#
#
# OG Orders left:  944573
# Cascade length:  447
# New Orders left:  944126
# making new cascade
#
#
# OG Orders left:  944126
# Cascade length:  868
# New Orders left:  943258
# making new cascade
#
#
# OG Orders left:  943258
# Cascade length:  891
# New Orders left:  942367
# making new cascade
#
#
# OG Orders left:  942367
# Cascade length:  320
# New Orders left:  942047
# making new cascade
#
#
# OG Orders left:  942047
# Cascade length:  779
# New Orders left:  941268
# making new cascade
#
#
# OG Orders left:  941268
# Cascade length:  8
# New Orders left:  941260
# making new cascade
#
#
# OG Orders left:  941260
# Cascade length:  165
# New Orders left:  941095
# making new cascade
#
#
# OG Orders left:  941095
# Cascade length:  388
# New Orders left:  940707
# making new cascade
#
#
# OG Orders left:  940707
# Cascade length:  488
# New Orders left:  940219
# making new cascade
#
#
# OG Orders left:  940219
# Cascade length:  448
# New Orders left:  939771
# making new cascade
#
#
# OG Orders left:  939771
# Cascade length:  831
# New Orders left:  938940
# making new cascade
#
#
# OG Orders left:  938940
# Cascade length:  3
# New Orders left:  938937
# making new cascade
#
#
# OG Orders left:  938937
# Cascade length:  816
# New Orders left:  938121
# making new cascade
#
#
# OG Orders left:  938121
# Cascade length:  482
# New Orders left:  937639
# making new cascade
#
#
# OG Orders left:  937639
# Cascade length:  11
# New Orders left:  937628
# making new cascade
#
#
# OG Orders left:  937628
# Cascade length:  2
# New Orders left:  937626
# making new cascade
#
#
# OG Orders left:  937626
# Cascade length:  150
# New Orders left:  937476
# making new cascade
#
#
# OG Orders left:  937476
# Cascade length:  774
# New Orders left:  936702
# making new cascade
#
#
# OG Orders left:  936702
# Cascade length:  249
# New Orders left:  936453
# making new cascade
#
#
# OG Orders left:  936453
# Cascade length:  1
# New Orders left:  936452
# making new cascade
#
#
# OG Orders left:  936452
# Cascade length:  101
# New Orders left:  936351
# making new cascade
#
#
# OG Orders left:  936351
# Cascade length:  7
# New Orders left:  936344
# making new cascade
#
#
# OG Orders left:  936344
# Cascade length:  377
# New Orders left:  935967
# making new cascade
#
#
# OG Orders left:  935967
# Cascade length:  620
# New Orders left:  935347
# making new cascade
#
#
# OG Orders left:  935347
# Cascade length:  7
# New Orders left:  935340
# making new cascade
#
#
# OG Orders left:  935340
# Cascade length:  5
# New Orders left:  935335
# making new cascade
#
#
# OG Orders left:  935335
# Cascade length:  82
# New Orders left:  935253
# making new cascade
#
#
# OG Orders left:  935253
# Cascade length:  204
# New Orders left:  935049
# making new cascade
#
#
# OG Orders left:  935049
# Cascade length:  18
# New Orders left:  935031
# making new cascade
#
#
# OG Orders left:  935031
# Cascade length:  50
# New Orders left:  934981
# making new cascade
#
#
# OG Orders left:  934981
# Cascade length:  580
# New Orders left:  934401
# making new cascade
#
#
# OG Orders left:  934401
# Cascade length:  210
# New Orders left:  934191
# making new cascade
#
#
# OG Orders left:  934191
# Cascade length:  508
# New Orders left:  933683
# making new cascade
#
#
# OG Orders left:  933683
# Cascade length:  445
# New Orders left:  933238
# making new cascade
#
#
# OG Orders left:  933238
# Cascade length:  191
# New Orders left:  933047
# making new cascade
#
#
# OG Orders left:  933047
# Cascade length:  1
# New Orders left:  933046
# making new cascade
#
#
# OG Orders left:  933046
# Cascade length:  4
# New Orders left:  933042
# making new cascade
#
#
# OG Orders left:  933042
# Cascade length:  417
# New Orders left:  932625
# making new cascade
#
#
# OG Orders left:  932625
# Cascade length:  97
# New Orders left:  932528
# making new cascade
#
#
# OG Orders left:  932528
# Cascade length:  800
# New Orders left:  931728
# making new cascade
#
#
# OG Orders left:  931728
# Cascade length:  272
# New Orders left:  931456
# making new cascade
#
#
# OG Orders left:  931456
# Cascade length:  3
# New Orders left:  931453
# making new cascade
#
#
# OG Orders left:  931453
# Cascade length:  438
# New Orders left:  931015
# making new cascade
#
#
# OG Orders left:  931015
# Cascade length:  304
# New Orders left:  930711
# making new cascade
#
#
# OG Orders left:  930711
# Cascade length:  9
# New Orders left:  930702
# making new cascade
#
#
# OG Orders left:  930702
# Cascade length:  19
# New Orders left:  930683
# making new cascade
#
#
# OG Orders left:  930683
# Cascade length:  303
# New Orders left:  930380
# making new cascade
#
#
# OG Orders left:  930380
# Cascade length:  4
# New Orders left:  930376
# making new cascade
#
#
# OG Orders left:  930376
# Cascade length:  901
# New Orders left:  929475
# making new cascade
#
#
# OG Orders left:  929475
# Cascade length:  130
# New Orders left:  929345
# making new cascade
#
#
# OG Orders left:  929345
# Cascade length:  44
# New Orders left:  929301
# making new cascade
#
#
# OG Orders left:  929301
# Cascade length:  371
# New Orders left:  928930
# making new cascade
#
#
# OG Orders left:  928930
# Cascade length:  196
# New Orders left:  928734
# making new cascade
#
#
# OG Orders left:  928734
# Cascade length:  882
# New Orders left:  927852
# making new cascade
#
#
# OG Orders left:  927852
# Cascade length:  10
# New Orders left:  927842
# making new cascade
#
#
# OG Orders left:  927842
# Cascade length:  2
# New Orders left:  927840
# making new cascade
#
#
# OG Orders left:  927840
# Cascade length:  1
# New Orders left:  927839
# making new cascade
#
#
# OG Orders left:  927839
# Cascade length:  16
# New Orders left:  927823
# making new cascade
#
#
# OG Orders left:  927823
# Cascade length:  238
# New Orders left:  927585
# making new cascade
#
#
# OG Orders left:  927585
# Cascade length:  173
# New Orders left:  927412
# making new cascade
#
#
# OG Orders left:  927412
# Cascade length:  619
# New Orders left:  926793
# making new cascade
#
#
# OG Orders left:  926793
# Cascade length:  2
# New Orders left:  926791
# making new cascade
#
#
# OG Orders left:  926791
# Cascade length:  3
# New Orders left:  926788
# making new cascade
#
#
# OG Orders left:  926788
# Cascade length:  479
# New Orders left:  926309
# making new cascade
#
#
# OG Orders left:  926309
# Cascade length:  445
# New Orders left:  925864
# making new cascade
#
#
# OG Orders left:  925864
# Cascade length:  10
# New Orders left:  925854
# making new cascade
#
#
# OG Orders left:  925854
# Cascade length:  847
# New Orders left:  925007
# making new cascade
#
#
# OG Orders left:  925007
# Cascade length:  702
# New Orders left:  924305
# making new cascade
#
#
# OG Orders left:  924305
# Cascade length:  662
# New Orders left:  923643
# making new cascade
#
#
# OG Orders left:  923643
# Cascade length:  9
# New Orders left:  923634
# making new cascade
#
#
# OG Orders left:  923634
# Cascade length:  187
# New Orders left:  923447
# making new cascade
#
#
# OG Orders left:  923447
# Cascade length:  33
# New Orders left:  923414
# making new cascade
#
#
# OG Orders left:  923414
# Cascade length:  681
# New Orders left:  922733
# making new cascade
#
#
# OG Orders left:  922733
# Cascade length:  657
# New Orders left:  922076
# making new cascade
#
#
# OG Orders left:  922076
# Cascade length:  148
# New Orders left:  921928
# making new cascade
#
#
# OG Orders left:  921928
# Cascade length:  113
# New Orders left:  921815
# making new cascade
#
#
# OG Orders left:  921815
# Cascade length:  125
# New Orders left:  921690
# making new cascade
#
#
# OG Orders left:  921690
# Cascade length:  1
# New Orders left:  921689
# making new cascade
#
#
# OG Orders left:  921689
# Cascade length:  376
# New Orders left:  921313
# making new cascade
#
#
# OG Orders left:  921313
# Cascade length:  12
# New Orders left:  921301
# making new cascade
#
#
# OG Orders left:  921301
# Cascade length:  2
# New Orders left:  921299
# making new cascade
#
#
# OG Orders left:  921299
# Cascade length:  166
# New Orders left:  921133
# making new cascade
#
#
# OG Orders left:  921133
# Cascade length:  603
# New Orders left:  920530
# making new cascade
#
#
# OG Orders left:  920530
# Cascade length:  6
# New Orders left:  920524
# making new cascade
#
#
# OG Orders left:  920524
# Cascade length:  155
# New Orders left:  920369
# making new cascade
#
#
# OG Orders left:  920369
# Cascade length:  69
# New Orders left:  920300
# making new cascade
#
#
# OG Orders left:  920300
# Cascade length:  353
# New Orders left:  919947
# making new cascade
#
#
# OG Orders left:  919947
# Cascade length:  245
# New Orders left:  919702
# making new cascade
#
#
# OG Orders left:  919702
# Cascade length:  12
# New Orders left:  919690
# making new cascade
#
#
# OG Orders left:  919690
# Cascade length:  370
# New Orders left:  919320
# making new cascade
#
#
# OG Orders left:  919320
# Cascade length:  596
# New Orders left:  918724
# making new cascade
#
#
# OG Orders left:  918724
# Cascade length:  70
# New Orders left:  918654
# making new cascade
#
#
# OG Orders left:  918654
# Cascade length:  94
# New Orders left:  918560
# making new cascade
#
#
# OG Orders left:  918560
# Cascade length:  998
# New Orders left:  917562
# making new cascade
#
#
# OG Orders left:  917562
# Cascade length:  339
# New Orders left:  917223
# making new cascade
#
#
# OG Orders left:  917223
# Cascade length:  8
# New Orders left:  917215
# making new cascade
#
#
# OG Orders left:  917215
# Cascade length:  368
# New Orders left:  916847
# making new cascade
#
#
# OG Orders left:  916847
# Cascade length:  10
# New Orders left:  916837
# making new cascade
#
#
# OG Orders left:  916837
# Cascade length:  307
# New Orders left:  916530
# making new cascade
#
#
# OG Orders left:  916530
# Cascade length:  22
# New Orders left:  916508
# making new cascade
#
#
# OG Orders left:  916508
# Cascade length:  105
# New Orders left:  916403
# making new cascade
#
#
# OG Orders left:  916403
# Cascade length:  12
# New Orders left:  916391
# making new cascade
#
#
# OG Orders left:  916391
# Cascade length:  266
# New Orders left:  916125
# making new cascade
#
#
# OG Orders left:  916125
# Cascade length:  126
# New Orders left:  915999
# making new cascade
#
#
# OG Orders left:  915999
# Cascade length:  42
# New Orders left:  915957
# making new cascade
#
#
# OG Orders left:  915957
# Cascade length:  17
# New Orders left:  915940
# making new cascade
#
#
# OG Orders left:  915940
# Cascade length:  15
# New Orders left:  915925
# making new cascade
#
#
# OG Orders left:  915925
# Cascade length:  1
# New Orders left:  915924
# making new cascade
#
#
# OG Orders left:  915924
# Cascade length:  485
# New Orders left:  915439
# making new cascade
#
#
# OG Orders left:  915439
# Cascade length:  175
# New Orders left:  915264
# making new cascade
#
#
# OG Orders left:  915264
# Cascade length:  7
# New Orders left:  915257
# making new cascade
#
#
# OG Orders left:  915257
# Cascade length:  234
# New Orders left:  915023
# making new cascade
#
#
# OG Orders left:  915023
# Cascade length:  537
# New Orders left:  914486
# making new cascade
#
#
# OG Orders left:  914486
# Cascade length:  30
# New Orders left:  914456
# making new cascade
#
#
# OG Orders left:  914456
# Cascade length:  275
# New Orders left:  914181
# making new cascade
#
#
# OG Orders left:  914181
# Cascade length:  69
# New Orders left:  914112
# making new cascade
#
#
# OG Orders left:  914112
# Cascade length:  600
# New Orders left:  913512
# making new cascade
#
#
# OG Orders left:  913512
# Cascade length:  67
# New Orders left:  913445
# making new cascade
#
#
# OG Orders left:  913445
# Cascade length:  49
# New Orders left:  913396
# making new cascade
#
#
# OG Orders left:  913396
# Cascade length:  119
# New Orders left:  913277
# making new cascade
#
#
# OG Orders left:  913277
# Cascade length:  1
# New Orders left:  913276
# making new cascade
#
#
# OG Orders left:  913276
# Cascade length:  390
# New Orders left:  912886
# making new cascade
#
#
# OG Orders left:  912886
# Cascade length:  3
# New Orders left:  912883
# making new cascade
#
#
# OG Orders left:  912883
# Cascade length:  189
# New Orders left:  912694
# making new cascade
#
#
# OG Orders left:  912694
# Cascade length:  9
# New Orders left:  912685
# making new cascade
#
#
# OG Orders left:  912685
# Cascade length:  606
# New Orders left:  912079
# making new cascade
#
#
# OG Orders left:  912079
# Cascade length:  810
# New Orders left:  911269
# making new cascade
#
#
# OG Orders left:  911269
# Cascade length:  52
# New Orders left:  911217
# making new cascade
#
#
# OG Orders left:  911217
# Cascade length:  215
# New Orders left:  911002
# making new cascade
#
#
# OG Orders left:  911002
# Cascade length:  1
# New Orders left:  911001
# making new cascade
#
#
# OG Orders left:  911001
# Cascade length:  30
# New Orders left:  910971
# making new cascade
#
#
# OG Orders left:  910971
# Cascade length:  29
# New Orders left:  910942
# making new cascade
#
#
# OG Orders left:  910942
# Cascade length:  8
# New Orders left:  910934
# making new cascade
#
#
# OG Orders left:  910934
# Cascade length:  283
# New Orders left:  910651
# making new cascade
#
#
# OG Orders left:  910651
# Cascade length:  2
# New Orders left:  910649
# making new cascade
#
#
# OG Orders left:  910649
# Cascade length:  21
# New Orders left:  910628
# making new cascade
#
#
# OG Orders left:  910628
# Cascade length:  44
# New Orders left:  910584
# making new cascade
#
#
# OG Orders left:  910584
# Cascade length:  8
# New Orders left:  910576
# making new cascade
#
#
# OG Orders left:  910576
# Cascade length:  355
# New Orders left:  910221
# making new cascade
#
#
# OG Orders left:  910221
# Cascade length:  10
# New Orders left:  910211
# making new cascade
#
#
# OG Orders left:  910211
# Cascade length:  316
# New Orders left:  909895
# making new cascade
#
#
# OG Orders left:  909895
# Cascade length:  15
# New Orders left:  909880
# making new cascade
#
#
# OG Orders left:  909880
# Cascade length:  180
# New Orders left:  909700
# making new cascade
#
#
# OG Orders left:  909700
# Cascade length:  10
# New Orders left:  909690
# making new cascade
#
#
# OG Orders left:  909690
# Cascade length:  332
# New Orders left:  909358
# making new cascade
#
#
# OG Orders left:  909358
# Cascade length:  2
# New Orders left:  909356
# making new cascade
#
#
# OG Orders left:  909356
# Cascade length:  67
# New Orders left:  909289
# making new cascade
#
#
# OG Orders left:  909289
# Cascade length:  27
# New Orders left:  909262
# making new cascade
#
#
# OG Orders left:  909262
# Cascade length:  15
# New Orders left:  909247
# making new cascade
#
#
# OG Orders left:  909247
# Cascade length:  525
# New Orders left:  908722
# making new cascade
#
#
# OG Orders left:  908722
# Cascade length:  3
# New Orders left:  908719
# making new cascade
#
#
# OG Orders left:  908719
# Cascade length:  305
# New Orders left:  908414
# making new cascade
#
#
# OG Orders left:  908414
# Cascade length:  780
# New Orders left:  907634
# making new cascade
#
#
# OG Orders left:  907634
# Cascade length:  1
# New Orders left:  907633
# making new cascade
#
#
# OG Orders left:  907633
# Cascade length:  144
# New Orders left:  907489
# making new cascade
#
#
# OG Orders left:  907489
# Cascade length:  301
# New Orders left:  907188
# making new cascade
#
#
# OG Orders left:  907188
# Cascade length:  47
# New Orders left:  907141
# making new cascade
#
#
# OG Orders left:  907141
# Cascade length:  5
# New Orders left:  907136
# making new cascade
#
#
# OG Orders left:  907136
# Cascade length:  98
# New Orders left:  907038
# making new cascade
#
#
# OG Orders left:  907038
# Cascade length:  4
# New Orders left:  907034
# making new cascade
#
#
# OG Orders left:  907034
# Cascade length:  10
# New Orders left:  907024
# making new cascade
#
#
# OG Orders left:  907024
# Cascade length:  37
# New Orders left:  906987
# making new cascade
#
#
# OG Orders left:  906987
# Cascade length:  101
# New Orders left:  906886
# making new cascade
#
#
# OG Orders left:  906886
# Cascade length:  18
# New Orders left:  906868
# making new cascade
#
#
# OG Orders left:  906868
# Cascade length:  687
# New Orders left:  906181
# making new cascade
#
#
# OG Orders left:  906181
# Cascade length:  903
# New Orders left:  905278
# making new cascade
#
#
# OG Orders left:  905278
# Cascade length:  92
# New Orders left:  905186
# making new cascade
#
#
# OG Orders left:  905186
# Cascade length:  341
# New Orders left:  904845
# making new cascade
#
#
# OG Orders left:  904845
# Cascade length:  177
# New Orders left:  904668
# making new cascade
#
#
# OG Orders left:  904668
# Cascade length:  7
# New Orders left:  904661
# making new cascade
#
#
# OG Orders left:  904661
# Cascade length:  119
# New Orders left:  904542
# making new cascade
#
#
# OG Orders left:  904542
# Cascade length:  40
# New Orders left:  904502
# making new cascade
#
#
# OG Orders left:  904502
# Cascade length:  13
# New Orders left:  904489
# making new cascade
#
#
# OG Orders left:  904489
# Cascade length:  52
# New Orders left:  904437
# making new cascade
#
#
# OG Orders left:  904437
# Cascade length:  467
# New Orders left:  903970
# making new cascade
#
#
# OG Orders left:  903970
# Cascade length:  10
# New Orders left:  903960
# making new cascade
#
#
# OG Orders left:  903960
# Cascade length:  403
# New Orders left:  903557
# making new cascade
#
#
# OG Orders left:  903557
# Cascade length:  455
# New Orders left:  903102
# making new cascade
#
#
# OG Orders left:  903102
# Cascade length:  11
# New Orders left:  903091
# making new cascade
#
#
# OG Orders left:  903091
# Cascade length:  69
# New Orders left:  903022
# making new cascade
#
#
# OG Orders left:  903022
# Cascade length:  180
# New Orders left:  902842
# making new cascade
#
#
# OG Orders left:  902842
# Cascade length:  205
# New Orders left:  902637
# making new cascade
#
#
# OG Orders left:  902637
# Cascade length:  93
# New Orders left:  902544
# making new cascade
#
#
# OG Orders left:  902544
# Cascade length:  5
# New Orders left:  902539
# making new cascade
#
#
# OG Orders left:  902539
# Cascade length:  127
# New Orders left:  902412
# making new cascade
#
#
# OG Orders left:  902412
# Cascade length:  12
# New Orders left:  902400
# making new cascade
#
#
# OG Orders left:  902400
# Cascade length:  4
# New Orders left:  902396
# making new cascade
#
#
# OG Orders left:  902396
# Cascade length:  14
# New Orders left:  902382
# making new cascade
#
#
# OG Orders left:  902382
# Cascade length:  93
# New Orders left:  902289
# making new cascade
#
#
# OG Orders left:  902289
# Cascade length:  1
# New Orders left:  902288
# making new cascade
#
#
# OG Orders left:  902288
# Cascade length:  1
# New Orders left:  902287
# making new cascade
#
#
# OG Orders left:  902287
# Cascade length:  123
# New Orders left:  902164
# making new cascade
#
#
# OG Orders left:  902164
# Cascade length:  24
# New Orders left:  902140
# making new cascade
#
#
# OG Orders left:  902140
# Cascade length:  16
# New Orders left:  902124
# making new cascade
#
#
# OG Orders left:  902124
# Cascade length:  97
# New Orders left:  902027
# making new cascade
#
#
# OG Orders left:  902027
# Cascade length:  322
# New Orders left:  901705
# making new cascade
#
#
# OG Orders left:  901705
# Cascade length:  66
# New Orders left:  901639
# making new cascade
#
#
# OG Orders left:  901639
# Cascade length:  346
# New Orders left:  901293
# making new cascade
#
#
# OG Orders left:  901293
# Cascade length:  102
# New Orders left:  901191
# making new cascade
#
#
# OG Orders left:  901191
# Cascade length:  9
# New Orders left:  901182
# making new cascade
#
#
# OG Orders left:  901182
# Cascade length:  303
# New Orders left:  900879
# making new cascade
#
#
# OG Orders left:  900879
# Cascade length:  93
# New Orders left:  900786
# making new cascade
#
#
# OG Orders left:  900786
# Cascade length:  34
# New Orders left:  900752
# making new cascade
#
#
# OG Orders left:  900752
# Cascade length:  7
# New Orders left:  900745
# making new cascade
#
#
# OG Orders left:  900745
# Cascade length:  3
# New Orders left:  900742
# making new cascade
#
#
# OG Orders left:  900742
# Cascade length:  156
# New Orders left:  900586
# making new cascade
#
#
# OG Orders left:  900586
# Cascade length:  1
# New Orders left:  900585
# making new cascade
#
#
# OG Orders left:  900585
# Cascade length:  58
# New Orders left:  900527
# making new cascade
#
#
# OG Orders left:  900527
# Cascade length:  16
# New Orders left:  900511
# making new cascade
#
#
# OG Orders left:  900511
# Cascade length:  413
# New Orders left:  900098
# making new cascade
#
#
# OG Orders left:  900098
# Cascade length:  52
# New Orders left:  900046
# making new cascade
#
#
# OG Orders left:  900046
# Cascade length:  8
# New Orders left:  900038
# making new cascade
#
#
# OG Orders left:  900038
# Cascade length:  84
# New Orders left:  899954
# making new cascade
#
#
# OG Orders left:  899954
# Cascade length:  12
# New Orders left:  899942
# making new cascade
#
#
# OG Orders left:  899942
# Cascade length:  6
# New Orders left:  899936
# making new cascade
#
#
# OG Orders left:  899936
# Cascade length:  20
# New Orders left:  899916
# making new cascade
#
#
# OG Orders left:  899916
# Cascade length:  4
# New Orders left:  899912
# making new cascade
#
#
# OG Orders left:  899912
# Cascade length:  23
# New Orders left:  899889
# making new cascade
#
#
# OG Orders left:  899889
# Cascade length:  1
# New Orders left:  899888
# making new cascade
#
#
# OG Orders left:  899888
# Cascade length:  89
# New Orders left:  899799
# making new cascade
#
#
# OG Orders left:  899799
# Cascade length:  1
# New Orders left:  899798
# making new cascade
#
#
# OG Orders left:  899798
# Cascade length:  46
# New Orders left:  899752
# making new cascade
#
#
# OG Orders left:  899752
# Cascade length:  57
# New Orders left:  899695
# making new cascade
#
#
# OG Orders left:  899695
# Cascade length:  8
# New Orders left:  899687
# making new cascade
#
#
# OG Orders left:  899687
# Cascade length:  102
# New Orders left:  899585
# making new cascade
#
#
# OG Orders left:  899585
# Cascade length:  250
# New Orders left:  899335
# making new cascade
#
#
# OG Orders left:  899335
# Cascade length:  69
# New Orders left:  899266
# making new cascade
#
#
# OG Orders left:  899266
# Cascade length:  115
# New Orders left:  899151
# making new cascade
#
#
# OG Orders left:  899151
# Cascade length:  9
# New Orders left:  899142
# making new cascade
#
#
# OG Orders left:  899142
# Cascade length:  812
# New Orders left:  898330
# making new cascade
#
#
# OG Orders left:  898330
# Cascade length:  11
# New Orders left:  898319
# making new cascade
#
#
# OG Orders left:  898319
# Cascade length:  291
# New Orders left:  898028
# making new cascade
#
#
# OG Orders left:  898028
# Cascade length:  82
# New Orders left:  897946
# making new cascade
#
#
# OG Orders left:  897946
# Cascade length:  56
# New Orders left:  897890
# making new cascade
#
#
# OG Orders left:  897890
# Cascade length:  297
# New Orders left:  897593
# making new cascade
#
#
# OG Orders left:  897593
# Cascade length:  84
# New Orders left:  897509
# making new cascade
#
#
# OG Orders left:  897509
# Cascade length:  109
# New Orders left:  897400
# making new cascade
#
#
# OG Orders left:  897400
# Cascade length:  27
# New Orders left:  897373
# making new cascade
#
#
# OG Orders left:  897373
# Cascade length:  30
# New Orders left:  897343
# making new cascade
#
#
# OG Orders left:  897343
# Cascade length:  61
# New Orders left:  897282
# making new cascade
#
#
# OG Orders left:  897282
# Cascade length:  79
# New Orders left:  897203
# making new cascade
#
#
# OG Orders left:  897203
# Cascade length:  125
# New Orders left:  897078
# making new cascade
#
#
# OG Orders left:  897078
# Cascade length:  19
# New Orders left:  897059
# making new cascade
#
#
# OG Orders left:  897059
# Cascade length:  7
# New Orders left:  897052
# making new cascade
#
#
# OG Orders left:  897052
# Cascade length:  270
# New Orders left:  896782
# making new cascade
#
#
# OG Orders left:  896782
# Cascade length:  46
# New Orders left:  896736
# making new cascade
#
#
# OG Orders left:  896736
# Cascade length:  168
# New Orders left:  896568
# making new cascade
#
#
# OG Orders left:  896568
# Cascade length:  6
# New Orders left:  896562
# making new cascade
#
#
# OG Orders left:  896562
# Cascade length:  57
# New Orders left:  896505
# making new cascade
#
#
# OG Orders left:  896505
# Cascade length:  473
# New Orders left:  896032
# making new cascade
#
#
# OG Orders left:  896032
# Cascade length:  10
# New Orders left:  896022
# making new cascade
#
#
# OG Orders left:  896022
# Cascade length:  2
# New Orders left:  896020
# making new cascade
#
#
# OG Orders left:  896020
# Cascade length:  331
# New Orders left:  895689
# making new cascade
#
#
# OG Orders left:  895689
# Cascade length:  55
# New Orders left:  895634
# making new cascade
#
#
# OG Orders left:  895634
# Cascade length:  78
# New Orders left:  895556
# making new cascade
#
#
# OG Orders left:  895556
# Cascade length:  430
# New Orders left:  895126
# making new cascade
#
#
# OG Orders left:  895126
# Cascade length:  481
# New Orders left:  894645
# making new cascade
#
#
# OG Orders left:  894645
# Cascade length:  146
# New Orders left:  894499
# making new cascade
#
#
# OG Orders left:  894499
# Cascade length:  75
# New Orders left:  894424
# making new cascade
#
#
# OG Orders left:  894424
# Cascade length:  1
# New Orders left:  894423
# making new cascade
#
#
# OG Orders left:  894423
# Cascade length:  77
# New Orders left:  894346
# making new cascade
#
#
# OG Orders left:  894346
# Cascade length:  25
# New Orders left:  894321
# making new cascade
#
#
# OG Orders left:  894321
# Cascade length:  5
# New Orders left:  894316
# making new cascade
#
#
# OG Orders left:  894316
# Cascade length:  83
# New Orders left:  894233
# making new cascade
#
#
# OG Orders left:  894233
# Cascade length:  563
# New Orders left:  893670
# making new cascade
#
#
# OG Orders left:  893670
# Cascade length:  185
# New Orders left:  893485
# making new cascade
#
#
# OG Orders left:  893485
# Cascade length:  88
# New Orders left:  893397
# making new cascade
#
#
# OG Orders left:  893397
# Cascade length:  21
# New Orders left:  893376
# making new cascade
#
#
# OG Orders left:  893376
# Cascade length:  149
# New Orders left:  893227
# making new cascade
#
#
# OG Orders left:  893227
# Cascade length:  38
# New Orders left:  893189
# making new cascade
#
#
# OG Orders left:  893189
# Cascade length:  85
# New Orders left:  893104
# making new cascade
#
#
# OG Orders left:  893104
# Cascade length:  170
# New Orders left:  892934
# making new cascade
#
#
# OG Orders left:  892934
# Cascade length:  32
# New Orders left:  892902
# making new cascade
#
#
# OG Orders left:  892902
# Cascade length:  102
# New Orders left:  892800
# making new cascade
#
#
# OG Orders left:  892800
# Cascade length:  129
# New Orders left:  892671
# making new cascade
#
#
# OG Orders left:  892671
# Cascade length:  68
# New Orders left:  892603
# making new cascade
#
#
# OG Orders left:  892603
# Cascade length:  10
# New Orders left:  892593
# making new cascade
#
#
# OG Orders left:  892593
# Cascade length:  200
# New Orders left:  892393
# making new cascade
#
#
# OG Orders left:  892393
# Cascade length:  2
# New Orders left:  892391
# making new cascade
#
#
# OG Orders left:  892391
# Cascade length:  48
# New Orders left:  892343
# making new cascade
#
#
# OG Orders left:  892343
# Cascade length:  51
# New Orders left:  892292
# making new cascade
#
#
# OG Orders left:  892292
# Cascade length:  33
# New Orders left:  892259
# making new cascade
#
#
# OG Orders left:  892259
# Cascade length:  49
# New Orders left:  892210
# making new cascade
#
#
# OG Orders left:  892210
# Cascade length:  43
# New Orders left:  892167
# making new cascade
#
#
# OG Orders left:  892167
# Cascade length:  42
# New Orders left:  892125
# making new cascade
#
#
# OG Orders left:  892125
# Cascade length:  7
# New Orders left:  892118
# making new cascade
#
#
# OG Orders left:  892118
# Cascade length:  328
# New Orders left:  891790
# making new cascade
#
#
# OG Orders left:  891790
# Cascade length:  111
# New Orders left:  891679
# making new cascade
#
#
# OG Orders left:  891679
# Cascade length:  61
# New Orders left:  891618
# making new cascade
#
#
# OG Orders left:  891618
# Cascade length:  175
# New Orders left:  891443
# making new cascade
#
#
# OG Orders left:  891443
# Cascade length:  216
# New Orders left:  891227
# making new cascade
#
#
# OG Orders left:  891227
# Cascade length:  2
# New Orders left:  891225
# making new cascade
#
#
# OG Orders left:  891225
# Cascade length:  114
# New Orders left:  891111
# making new cascade
#
#
# OG Orders left:  891111
# Cascade length:  425
# New Orders left:  890686
# making new cascade
#
#
# OG Orders left:  890686
# Cascade length:  43
# New Orders left:  890643
# making new cascade
#
#
# OG Orders left:  890643
# Cascade length:  31
# New Orders left:  890612
# making new cascade
#
#
# OG Orders left:  890612
# Cascade length:  113
# New Orders left:  890499
# making new cascade
#
#
# OG Orders left:  890499
# Cascade length:  1
# New Orders left:  890498
# making new cascade
#
#
# OG Orders left:  890498
# Cascade length:  1
# New Orders left:  890497
# making new cascade
#
#
# OG Orders left:  890497
# Cascade length:  319
# New Orders left:  890178
# making new cascade
#
#
# OG Orders left:  890178
# Cascade length:  60
# New Orders left:  890118
# making new cascade
#
#
# OG Orders left:  890118
# Cascade length:  146
# New Orders left:  889972
# making new cascade
#
#
# OG Orders left:  889972
# Cascade length:  550
# New Orders left:  889422
# making new cascade
#
#
# OG Orders left:  889422
# Cascade length:  7
# New Orders left:  889415
# making new cascade
#
#
# OG Orders left:  889415
# Cascade length:  22
# New Orders left:  889393
# making new cascade
#
#
# OG Orders left:  889393
# Cascade length:  27
# New Orders left:  889366
# making new cascade
#
#
# OG Orders left:  889366
# Cascade length:  115
# New Orders left:  889251
# making new cascade
#
#
# OG Orders left:  889251
# Cascade length:  243
# New Orders left:  889008
# making new cascade
#
#
# OG Orders left:  889008
# Cascade length:  183
# New Orders left:  888825
# making new cascade
#
#
# OG Orders left:  888825
# Cascade length:  38
# New Orders left:  888787
# making new cascade
#
#
# OG Orders left:  888787
# Cascade length:  33
# New Orders left:  888754
# making new cascade
#
#
# OG Orders left:  888754
# Cascade length:  480
# New Orders left:  888274
# making new cascade
#
#
# OG Orders left:  888274
# Cascade length:  114
# New Orders left:  888160
# making new cascade
#
#
# OG Orders left:  888160
# Cascade length:  302
# New Orders left:  887858
# making new cascade
#
#
# OG Orders left:  887858
# Cascade length:  46
# New Orders left:  887812
# making new cascade
#
#
# OG Orders left:  887812
# Cascade length:  112
# New Orders left:  887700
# making new cascade
#
#
# OG Orders left:  887700
# Cascade length:  2
# New Orders left:  887698
# making new cascade
#
#
# OG Orders left:  887698
# Cascade length:  10
# New Orders left:  887688
# making new cascade
#
#
# OG Orders left:  887688
# Cascade length:  136
# New Orders left:  887552
# making new cascade
#
#
# OG Orders left:  887552
# Cascade length:  33
# New Orders left:  887519
# making new cascade
#
#
# OG Orders left:  887519
# Cascade length:  44
# New Orders left:  887475
# making new cascade
#
#
# OG Orders left:  887475
# Cascade length:  4
# New Orders left:  887471
# making new cascade
#
#
# OG Orders left:  887471
# Cascade length:  38
# New Orders left:  887433
# making new cascade
#
#
# OG Orders left:  887433
# Cascade length:  44
# New Orders left:  887389
# making new cascade
#
#
# OG Orders left:  887389
# Cascade length:  686
# New Orders left:  886703
# making new cascade
#
#
# OG Orders left:  886703
# Cascade length:  296
# New Orders left:  886407
# making new cascade
#
#
# OG Orders left:  886407
# Cascade length:  1
# New Orders left:  886406
# making new cascade
#
#
# OG Orders left:  886406
# Cascade length:  14
# New Orders left:  886392
# making new cascade
#
#
# OG Orders left:  886392
# Cascade length:  2
# New Orders left:  886390
# making new cascade
#
#
# OG Orders left:  886390
# Cascade length:  55
# New Orders left:  886335
# making new cascade
#
#
# OG Orders left:  886335
# Cascade length:  6
# New Orders left:  886329
# making new cascade
#
#
# OG Orders left:  886329
# Cascade length:  74
# New Orders left:  886255
# making new cascade
#
#
# OG Orders left:  886255
# Cascade length:  212
# New Orders left:  886043
# making new cascade
#
#
# OG Orders left:  886043
# Cascade length:  39
# New Orders left:  886004
# making new cascade
#
#
# OG Orders left:  886004
# Cascade length:  8
# New Orders left:  885996
# making new cascade
#
#
# OG Orders left:  885996
# Cascade length:  17
# New Orders left:  885979
# making new cascade
#
#
# OG Orders left:  885979
# Cascade length:  61
# New Orders left:  885918
# making new cascade
#
#
# OG Orders left:  885918
# Cascade length:  58
# New Orders left:  885860
# making new cascade
#
#
# OG Orders left:  885860
# Cascade length:  40
# New Orders left:  885820
# making new cascade
#
#
# OG Orders left:  885820
# Cascade length:  176
# New Orders left:  885644
# making new cascade
#
#
# OG Orders left:  885644
# Cascade length:  18
# New Orders left:  885626
# making new cascade
#
#
# OG Orders left:  885626
# Cascade length:  4
# New Orders left:  885622
# making new cascade
#
#
# OG Orders left:  885622
# Cascade length:  319
# New Orders left:  885303
# making new cascade
#
#
# OG Orders left:  885303
# Cascade length:  4
# New Orders left:  885299
# making new cascade
#
#
# OG Orders left:  885299
# Cascade length:  4
# New Orders left:  885295
# making new cascade
#
#
# OG Orders left:  885295
# Cascade length:  435
# New Orders left:  884860
# making new cascade
#
#
# OG Orders left:  884860
# Cascade length:  442
# New Orders left:  884418
# making new cascade
#
#
# OG Orders left:  884418
# Cascade length:  205
# New Orders left:  884213
# making new cascade
#
#
# OG Orders left:  884213
# Cascade length:  156
# New Orders left:  884057
# making new cascade
#
#
# OG Orders left:  884057
# Cascade length:  15
# New Orders left:  884042
# making new cascade
#
#
# OG Orders left:  884042
# Cascade length:  350
# New Orders left:  883692
# making new cascade
#
#
# OG Orders left:  883692
# Cascade length:  5
# New Orders left:  883687
# making new cascade
#
#
# OG Orders left:  883687
# Cascade length:  40
# New Orders left:  883647
# making new cascade
#
#
# OG Orders left:  883647
# Cascade length:  137
# New Orders left:  883510
# making new cascade
#
#
# OG Orders left:  883510
# Cascade length:  16
# New Orders left:  883494
# making new cascade
#
#
# OG Orders left:  883494
# Cascade length:  8
# New Orders left:  883486
# making new cascade
#
#
# OG Orders left:  883486
# Cascade length:  20
# New Orders left:  883466
# making new cascade
#
#
# OG Orders left:  883466
# Cascade length:  7
# New Orders left:  883459
# making new cascade
#
#
# OG Orders left:  883459
# Cascade length:  443
# New Orders left:  883016
# making new cascade
#
#
# OG Orders left:  883016
# Cascade length:  4
# New Orders left:  883012
# making new cascade
#
#
# OG Orders left:  883012
# Cascade length:  1
# New Orders left:  883011
# making new cascade
#
#
# OG Orders left:  883011
# Cascade length:  1
# New Orders left:  883010
# making new cascade
#
#
# OG Orders left:  883010
# Cascade length:  27
# New Orders left:  882983
# making new cascade
#
#
# OG Orders left:  882983
# Cascade length:  340
# New Orders left:  882643
# making new cascade
#
#
# OG Orders left:  882643
# Cascade length:  53
# New Orders left:  882590
# making new cascade
#
#
# OG Orders left:  882590
# Cascade length:  66
# New Orders left:  882524
# making new cascade
#
#
# OG Orders left:  882524
# Cascade length:  18
# New Orders left:  882506
# making new cascade
#
#
# OG Orders left:  882506
# Cascade length:  291
# New Orders left:  882215
# making new cascade
#
#
# OG Orders left:  882215
# Cascade length:  9
# New Orders left:  882206
# making new cascade
#
#
# OG Orders left:  882206
# Cascade length:  146
# New Orders left:  882060
# making new cascade
#
#
# OG Orders left:  882060
# Cascade length:  55
# New Orders left:  882005
# making new cascade
#
#
# OG Orders left:  882005
# Cascade length:  331
# New Orders left:  881674
# making new cascade
#
#
# OG Orders left:  881674
# Cascade length:  91
# New Orders left:  881583
# making new cascade
#
#
# OG Orders left:  881583
# Cascade length:  4
# New Orders left:  881579
# making new cascade
#
#
# OG Orders left:  881579
# Cascade length:  63
# New Orders left:  881516
# making new cascade
#
#
# OG Orders left:  881516
# Cascade length:  22
# New Orders left:  881494
# making new cascade
#
#
# OG Orders left:  881494
# Cascade length:  28
# New Orders left:  881466
# making new cascade
#
#
# OG Orders left:  881466
# Cascade length:  5
# New Orders left:  881461
# making new cascade
#
#
# OG Orders left:  881461
# Cascade length:  81
# New Orders left:  881380
# making new cascade
#
#
# OG Orders left:  881380
# Cascade length:  43
# New Orders left:  881337
# making new cascade
#
#
# OG Orders left:  881337
# Cascade length:  10
# New Orders left:  881327
# making new cascade
#
#
# OG Orders left:  881327
# Cascade length:  25
# New Orders left:  881302
# making new cascade
#
#
# OG Orders left:  881302
# Cascade length:  27
# New Orders left:  881275
# making new cascade
#
#
# OG Orders left:  881275
# Cascade length:  19
# New Orders left:  881256
# making new cascade
#
#
# OG Orders left:  881256
# Cascade length:  266
# New Orders left:  880990
# making new cascade
#
#
# OG Orders left:  880990
# Cascade length:  331
# New Orders left:  880659
# making new cascade
#
#
# OG Orders left:  880659
# Cascade length:  432
# New Orders left:  880227
# making new cascade
#
#
# OG Orders left:  880227
# Cascade length:  63
# New Orders left:  880164
# making new cascade
#
#
# OG Orders left:  880164
# Cascade length:  48
# New Orders left:  880116
# making new cascade
#
#
# OG Orders left:  880116
# Cascade length:  32
# New Orders left:  880084
# making new cascade
#
#
# OG Orders left:  880084
# Cascade length:  53
# New Orders left:  880031
# making new cascade
#
#
# OG Orders left:  880031
# Cascade length:  21
# New Orders left:  880010
# making new cascade
#
#
# OG Orders left:  880010
# Cascade length:  36
# New Orders left:  879974
# making new cascade
#
#
# OG Orders left:  879974
# Cascade length:  530
# New Orders left:  879444
# making new cascade
#
#
# OG Orders left:  879444
# Cascade length:  45
# New Orders left:  879399
# making new cascade
#
#
# OG Orders left:  879399
# Cascade length:  13
# New Orders left:  879386
# making new cascade
#
#
# OG Orders left:  879386
# Cascade length:  107
# New Orders left:  879279
# making new cascade
#
#
# OG Orders left:  879279
# Cascade length:  52
# New Orders left:  879227
# making new cascade
#
#
# OG Orders left:  879227
# Cascade length:  20
# New Orders left:  879207
# making new cascade
#
#
# OG Orders left:  879207
# Cascade length:  8
# New Orders left:  879199
# making new cascade
#
#
# OG Orders left:  879199
# Cascade length:  359
# New Orders left:  878840
# making new cascade
#
#
# OG Orders left:  878840
# Cascade length:  1
# New Orders left:  878839
# making new cascade
#
#
# OG Orders left:  878839
# Cascade length:  23
# New Orders left:  878816
# making new cascade
#
#
# OG Orders left:  878816
# Cascade length:  437
# New Orders left:  878379
# making new cascade
#
#
# OG Orders left:  878379
# Cascade length:  53
# New Orders left:  878326
# making new cascade
#
#
# OG Orders left:  878326
# Cascade length:  41
# New Orders left:  878285
# making new cascade
#
#
# OG Orders left:  878285
# Cascade length:  61
# New Orders left:  878224
# making new cascade
#
#
# OG Orders left:  878224
# Cascade length:  101
# New Orders left:  878123
# making new cascade
#
#
# OG Orders left:  878123
# Cascade length:  4
# New Orders left:  878119
# making new cascade
#
#
# OG Orders left:  878119
# Cascade length:  68
# New Orders left:  878051
# making new cascade
#
#
# OG Orders left:  878051
# Cascade length:  3
# New Orders left:  878048
# making new cascade
#
#
# OG Orders left:  878048
# Cascade length:  18
# New Orders left:  878030
# making new cascade
#
#
# OG Orders left:  878030
# Cascade length:  64
# New Orders left:  877966
# making new cascade
#
#
# OG Orders left:  877966
# Cascade length:  6
# New Orders left:  877960
# making new cascade
#
#
# OG Orders left:  877960
# Cascade length:  1
# New Orders left:  877959
# making new cascade
#
#
# OG Orders left:  877959
# Cascade length:  76
# New Orders left:  877883
# making new cascade
#
#
# OG Orders left:  877883
# Cascade length:  319
# New Orders left:  877564
# making new cascade
#
#
# OG Orders left:  877564
# Cascade length:  146
# New Orders left:  877418
# making new cascade
#
#
# OG Orders left:  877418
# Cascade length:  29
# New Orders left:  877389
# making new cascade
#
#
# OG Orders left:  877389
# Cascade length:  28
# New Orders left:  877361
# making new cascade
#
#
# OG Orders left:  877361
# Cascade length:  160
# New Orders left:  877201
# making new cascade
#
#
# OG Orders left:  877201
# Cascade length:  280
# New Orders left:  876921
# making new cascade
#
#
# OG Orders left:  876921
# Cascade length:  169
# New Orders left:  876752
# making new cascade
#
#
# OG Orders left:  876752
# Cascade length:  8
# New Orders left:  876744
# making new cascade
#
#
# OG Orders left:  876744
# Cascade length:  76
# New Orders left:  876668
# making new cascade
#
#
# OG Orders left:  876668
# Cascade length:  1
# ...
# making new cascade
#
#
# OG Orders left:  4655
# Cascade length:  3
# New Orders left:  4652
# making new cascade
#
#
# OG Orders left:  4652
# Cascade length:  44
# New Orders left:  4608
# making new cascade
#
#
# OG Orders left:  4608
# Cascade length:  79
# New Orders left:  4529
# making new cascade
#
#
# OG Orders left:  4529
# Cascade length:  104
# New Orders left:  4425
# making new cascade
#
#
# OG Orders left:  4425
# Cascade length:  3
# New Orders left:  4422
# making new cascade
#
#
# OG Orders left:  4422
# Cascade length:  12
# New Orders left:  4410
# making new cascade
#
#
# OG Orders left:  4410
# Cascade length:  62
# New Orders left:  4348
# making new cascade
#
#
# OG Orders left:  4348
# Cascade length:  8
# New Orders left:  4340
# making new cascade
#
#
# OG Orders left:  4340
# Cascade length:  31
# New Orders left:  4309
# making new cascade
#
#
# OG Orders left:  4309
# Cascade length:  65
# New Orders left:  4244
# making new cascade
#
#
# OG Orders left:  4244
# Cascade length:  63
# New Orders left:  4181
# making new cascade
#
#
# OG Orders left:  4181
# Cascade length:  10
# New Orders left:  4171
# making new cascade
#
#
# OG Orders left:  4171
# Cascade length:  25
# New Orders left:  4146
# making new cascade
#
#
# OG Orders left:  4146
# Cascade length:  77
# New Orders left:  4069
# making new cascade
#
#
# OG Orders left:  4069
# Cascade length:  113
# New Orders left:  3956
# making new cascade
#
#
# OG Orders left:  3956
# Cascade length:  16
# New Orders left:  3940
# making new cascade
#
#
# OG Orders left:  3940
# Cascade length:  17
# New Orders left:  3923
# making new cascade
#
#
# OG Orders left:  3923
# Cascade length:  94
# New Orders left:  3829
# making new cascade
#
#
# OG Orders left:  3829
# Cascade length:  38
# New Orders left:  3791
# making new cascade
#
#
# OG Orders left:  3791
# Cascade length:  13
# New Orders left:  3778
# making new cascade
#
#
# OG Orders left:  3778
# Cascade length:  72
# New Orders left:  3706
# making new cascade
#
#
# OG Orders left:  3706
# Cascade length:  30
# New Orders left:  3676
# making new cascade
#
#
# OG Orders left:  3676
# Cascade length:  14
# New Orders left:  3662
# making new cascade
#
#
# OG Orders left:  3662
# Cascade length:  46
# New Orders left:  3616
# making new cascade
#
#
# OG Orders left:  3616
# Cascade length:  16
# New Orders left:  3600
# making new cascade
#
#
# OG Orders left:  3600
# Cascade length:  53
# New Orders left:  3547
# making new cascade
#
#
# OG Orders left:  3547
# Cascade length:  50
# New Orders left:  3497
# making new cascade
#
#
# OG Orders left:  3497
# Cascade length:  77
# New Orders left:  3420
# making new cascade
#
#
# OG Orders left:  3420
# Cascade length:  45
# New Orders left:  3375
# making new cascade
#
#
# OG Orders left:  3375
# Cascade length:  10
# New Orders left:  3365
# making new cascade
#
#
# OG Orders left:  3365
# Cascade length:  73
# New Orders left:  3292
# making new cascade
#
#
# OG Orders left:  3292
# Cascade length:  10
# New Orders left:  3282
# making new cascade
#
#
# OG Orders left:  3282
# Cascade length:  57
# New Orders left:  3225
# making new cascade
#
#
# OG Orders left:  3225
# Cascade length:  16
# New Orders left:  3209
# making new cascade
#
#
# OG Orders left:  3209
# Cascade length:  4
# New Orders left:  3205
# making new cascade
#
#
# OG Orders left:  3205
# Cascade length:  20
# New Orders left:  3185
# making new cascade
#
#
# OG Orders left:  3185
# Cascade length:  30
# New Orders left:  3155
# making new cascade
#
#
# OG Orders left:  3155
# Cascade length:  69
# New Orders left:  3086
# making new cascade
#
#
# OG Orders left:  3086
# Cascade length:  57
# New Orders left:  3029
# making new cascade
#
#
# OG Orders left:  3029
# Cascade length:  34
# New Orders left:  2995
# making new cascade
#
#
# OG Orders left:  2995
# Cascade length:  10
# New Orders left:  2985
# making new cascade
#
#
# OG Orders left:  2985
# Cascade length:  59
# New Orders left:  2926
# making new cascade
#
#
# OG Orders left:  2926
# Cascade length:  15
# New Orders left:  2911
# making new cascade
#
#
# OG Orders left:  2911
# Cascade length:  11
# New Orders left:  2900
# making new cascade
#
#
# OG Orders left:  2900
# Cascade length:  26
# New Orders left:  2874
# making new cascade
#
#
# OG Orders left:  2874
# Cascade length:  22
# New Orders left:  2852
# making new cascade
#
#
# OG Orders left:  2852
# Cascade length:  65
# New Orders left:  2787
# making new cascade
#
#
# OG Orders left:  2787
# Cascade length:  29
# New Orders left:  2758
# making new cascade
#
#
# OG Orders left:  2758
# Cascade length:  37
# New Orders left:  2721
# making new cascade
#
#
# OG Orders left:  2721
# Cascade length:  9
# New Orders left:  2712
# making new cascade
#
#
# OG Orders left:  2712
# Cascade length:  13
# New Orders left:  2699
# making new cascade
#
#
# OG Orders left:  2699
# Cascade length:  4
# New Orders left:  2695
# making new cascade
#
#
# OG Orders left:  2695
# Cascade length:  56
# New Orders left:  2639
# making new cascade
#
#
# OG Orders left:  2639
# Cascade length:  4
# New Orders left:  2635
# making new cascade
#
#
# OG Orders left:  2635
# Cascade length:  29
# New Orders left:  2606
# making new cascade
#
#
# OG Orders left:  2606
# Cascade length:  13
# New Orders left:  2593
# making new cascade
#
#
# OG Orders left:  2593
# Cascade length:  5
# New Orders left:  2588
# making new cascade
#
#
# OG Orders left:  2588
# Cascade length:  19
# New Orders left:  2569
# making new cascade
#
#
# OG Orders left:  2569
# Cascade length:  40
# New Orders left:  2529
# making new cascade
#
#
# OG Orders left:  2529
# Cascade length:  23
# New Orders left:  2506
# making new cascade
#
#
# OG Orders left:  2506
# Cascade length:  83
# New Orders left:  2423
# making new cascade
#
#
# OG Orders left:  2423
# Cascade length:  12
# New Orders left:  2411
# making new cascade
#
#
# OG Orders left:  2411
# Cascade length:  2
# New Orders left:  2409
# making new cascade
#
#
# OG Orders left:  2409
# Cascade length:  8
# New Orders left:  2401
# making new cascade
#
#
# OG Orders left:  2401
# Cascade length:  20
# New Orders left:  2381
# making new cascade
#
#
# OG Orders left:  2381
# Cascade length:  1
# New Orders left:  2380
# making new cascade
#
#
# OG Orders left:  2380
# Cascade length:  33
# New Orders left:  2347
# making new cascade
#
#
# OG Orders left:  2347
# Cascade length:  18
# New Orders left:  2329
# making new cascade
#
#
# OG Orders left:  2329
# Cascade length:  11
# New Orders left:  2318
# making new cascade
#
#
# OG Orders left:  2318
# Cascade length:  73
# New Orders left:  2245
# making new cascade
#
#
# OG Orders left:  2245
# Cascade length:  15
# New Orders left:  2230
# making new cascade
#
#
# OG Orders left:  2230
# Cascade length:  23
# New Orders left:  2207
# making new cascade
#
#
# OG Orders left:  2207
# Cascade length:  41
# New Orders left:  2166
# making new cascade
#
#
# OG Orders left:  2166
# Cascade length:  35
# New Orders left:  2131
# making new cascade
#
#
# OG Orders left:  2131
# Cascade length:  7
# New Orders left:  2124
# making new cascade
#
#
# OG Orders left:  2124
# Cascade length:  40
# New Orders left:  2084
# making new cascade
#
#
# OG Orders left:  2084
# Cascade length:  17
# New Orders left:  2067
# making new cascade
#
#
# OG Orders left:  2067
# Cascade length:  4
# New Orders left:  2063
# making new cascade
#
#
# OG Orders left:  2063
# Cascade length:  7
# New Orders left:  2056
# making new cascade
#
#
# OG Orders left:  2056
# Cascade length:  37
# New Orders left:  2019
# making new cascade
#
#
# OG Orders left:  2019
# Cascade length:  8
# New Orders left:  2011
# making new cascade
#
#
# OG Orders left:  2011
# Cascade length:  33
# New Orders left:  1978
# making new cascade
#
#
# OG Orders left:  1978
# Cascade length:  14
# New Orders left:  1964
# making new cascade
#
#
# OG Orders left:  1964
# Cascade length:  56
# New Orders left:  1908
# making new cascade
#
#
# OG Orders left:  1908
# Cascade length:  22
# New Orders left:  1886
# making new cascade
#
#
# OG Orders left:  1886
# Cascade length:  17
# New Orders left:  1869
# making new cascade
#
#
# OG Orders left:  1869
# Cascade length:  11
# New Orders left:  1858
# making new cascade
#
#
# OG Orders left:  1858
# Cascade length:  22
# New Orders left:  1836
# making new cascade
#
#
# OG Orders left:  1836
# Cascade length:  50
# New Orders left:  1786
# making new cascade
#
#
# OG Orders left:  1786
# Cascade length:  34
# New Orders left:  1752
# making new cascade
#
#
# OG Orders left:  1752
# Cascade length:  4
# New Orders left:  1748
# making new cascade
#
#
# OG Orders left:  1748
# Cascade length:  8
# New Orders left:  1740
# making new cascade
#
#
# OG Orders left:  1740
# Cascade length:  16
# New Orders left:  1724
# making new cascade
#
#
# OG Orders left:  1724
# Cascade length:  50
# New Orders left:  1674
# making new cascade
#
#
# OG Orders left:  1674
# Cascade length:  6
# New Orders left:  1668
# making new cascade
#
#
# OG Orders left:  1668
# Cascade length:  13
# New Orders left:  1655
# making new cascade
#
#
# OG Orders left:  1655
# Cascade length:  20
# New Orders left:  1635
# making new cascade
#
#
# OG Orders left:  1635
# Cascade length:  45
# New Orders left:  1590
# making new cascade
#
#
# OG Orders left:  1590
# Cascade length:  34
# New Orders left:  1556
# making new cascade
#
#
# OG Orders left:  1556
# Cascade length:  59
# New Orders left:  1497
# making new cascade
#
#
# OG Orders left:  1497
# Cascade length:  18
# New Orders left:  1479
# making new cascade
#
#
# OG Orders left:  1479
# Cascade length:  24
# New Orders left:  1455
# making new cascade
#
#
# OG Orders left:  1455
# Cascade length:  11
# New Orders left:  1444
# making new cascade
#
#
# OG Orders left:  1444
# Cascade length:  3
# New Orders left:  1441
# making new cascade
#
#
# OG Orders left:  1441
# Cascade length:  1
# New Orders left:  1440
# making new cascade
#
#
# OG Orders left:  1440
# Cascade length:  17
# New Orders left:  1423
# making new cascade
#
#
# OG Orders left:  1423
# Cascade length:  18
# New Orders left:  1405
# making new cascade
#
#
# OG Orders left:  1405
# Cascade length:  1
# New Orders left:  1404
# making new cascade
#
#
# OG Orders left:  1404
# Cascade length:  22
# New Orders left:  1382
# making new cascade
#
#
# OG Orders left:  1382
# Cascade length:  20
# New Orders left:  1362
# making new cascade
#
#
# OG Orders left:  1362
# Cascade length:  16
# New Orders left:  1346
# making new cascade
#
#
# OG Orders left:  1346
# Cascade length:  42
# New Orders left:  1304
# making new cascade
#
#
# OG Orders left:  1304
# Cascade length:  8
# New Orders left:  1296
# making new cascade
#
#
# OG Orders left:  1296
# Cascade length:  39
# New Orders left:  1257
# making new cascade
#
#
# OG Orders left:  1257
# Cascade length:  28
# New Orders left:  1229
# making new cascade
#
#
# OG Orders left:  1229
# Cascade length:  8
# New Orders left:  1221
# making new cascade
#
#
# OG Orders left:  1221
# Cascade length:  21
# New Orders left:  1200
# making new cascade
#
#
# OG Orders left:  1200
# Cascade length:  18
# New Orders left:  1182
# making new cascade
#
#
# OG Orders left:  1182
# Cascade length:  3
# New Orders left:  1179
# making new cascade
#
#
# OG Orders left:  1179
# Cascade length:  3
# New Orders left:  1176
# making new cascade
#
#
# OG Orders left:  1176
# Cascade length:  70
# New Orders left:  1106
# making new cascade
#
#
# OG Orders left:  1106
# Cascade length:  44
# New Orders left:  1062
# making new cascade
#
#
# OG Orders left:  1062
# Cascade length:  1
# New Orders left:  1061
# making new cascade
#
#
# OG Orders left:  1061
# Cascade length:  18
# New Orders left:  1043
# making new cascade
#
#
# OG Orders left:  1043
# Cascade length:  17
# New Orders left:  1026
# making new cascade
#
#
# OG Orders left:  1026
# Cascade length:  17
# New Orders left:  1009
# making new cascade
#
#
# OG Orders left:  1009
# Cascade length:  14
# New Orders left:  995
# making new cascade
#
#
# OG Orders left:  995
# Cascade length:  24
# New Orders left:  971
# making new cascade
#
#
# OG Orders left:  971
# Cascade length:  8
# New Orders left:  963
# making new cascade
#
#
# OG Orders left:  963
# Cascade length:  81
# New Orders left:  882
# making new cascade
#
#
# OG Orders left:  882
# Cascade length:  20
# New Orders left:  862
# making new cascade
#
#
# OG Orders left:  862
# Cascade length:  28
# New Orders left:  834
# making new cascade
#
#
# OG Orders left:  834
# Cascade length:  22
# New Orders left:  812
# making new cascade
#
#
# OG Orders left:  812
# Cascade length:  8
# New Orders left:  804
# making new cascade
#
#
# OG Orders left:  804
# Cascade length:  6
# New Orders left:  798
# making new cascade
#
#
# OG Orders left:  798
# Cascade length:  22
# New Orders left:  776
# making new cascade
#
#
# OG Orders left:  776
# Cascade length:  23
# New Orders left:  753
# making new cascade
#
#
# OG Orders left:  753
# Cascade length:  66
# New Orders left:  687
# making new cascade
#
#
# OG Orders left:  687
# Cascade length:  15
# New Orders left:  672
# making new cascade
#
#
# OG Orders left:  672
# Cascade length:  16
# New Orders left:  656
# making new cascade
#
#
# OG Orders left:  656
# Cascade length:  12
# New Orders left:  644
# making new cascade
#
#
# OG Orders left:  644
# Cascade length:  8
# New Orders left:  636
# making new cascade
#
#
# OG Orders left:  636
# Cascade length:  27
# New Orders left:  609
# making new cascade
#
#
# OG Orders left:  609
# Cascade length:  15
# New Orders left:  594
# making new cascade
#
#
# OG Orders left:  594
# Cascade length:  2
# New Orders left:  592
# making new cascade
#
#
# OG Orders left:  592
# Cascade length:  67
# New Orders left:  525
# making new cascade
#
#
# OG Orders left:  525
# Cascade length:  1
# New Orders left:  524
# making new cascade
#
#
# OG Orders left:  524
# Cascade length:  18
# New Orders left:  506
# making new cascade
#
#
# OG Orders left:  506
# Cascade length:  4
# New Orders left:  502
# making new cascade
#
#
# OG Orders left:  502
# Cascade length:  20
# New Orders left:  482
# making new cascade
#
#
# OG Orders left:  482
# Cascade length:  32
# New Orders left:  450
# making new cascade
#
#
# OG Orders left:  450
# Cascade length:  17
# New Orders left:  433
# making new cascade
#
#
# OG Orders left:  433
# Cascade length:  1
# New Orders left:  432
# making new cascade
#
#
# OG Orders left:  432
# Cascade length:  1
# New Orders left:  431
# making new cascade
#
#
# OG Orders left:  431
# Cascade length:  43
# New Orders left:  388
# making new cascade
#
#
# OG Orders left:  388
# Cascade length:  19
# New Orders left:  369
# making new cascade
#
#
# OG Orders left:  369
# Cascade length:  2
# New Orders left:  367
# making new cascade
#
#
# OG Orders left:  367
# Cascade length:  48
# New Orders left:  319
# making new cascade
#
#
# OG Orders left:  319
# Cascade length:  3
# New Orders left:  316
# making new cascade
#
#
# OG Orders left:  316
# Cascade length:  9
# New Orders left:  307
# making new cascade
#
#
# OG Orders left:  307
# Cascade length:  4
# New Orders left:  303
# making new cascade
#
#
# OG Orders left:  303
# Cascade length:  14
# New Orders left:  289
# making new cascade
#
#
# OG Orders left:  289
# Cascade length:  28
# New Orders left:  261
# making new cascade
#
#
# OG Orders left:  261
# Cascade length:  14
# New Orders left:  247
# making new cascade
#
#
# OG Orders left:  247
# Cascade length:  29
# New Orders left:  218
# making new cascade
#
#
# OG Orders left:  218
# Cascade length:  29
# New Orders left:  189
# making new cascade
#
#
# OG Orders left:  189
# Cascade length:  1
# New Orders left:  188
# making new cascade
#
#
# OG Orders left:  188
# Cascade length:  9
# New Orders left:  179
# making new cascade
#
#
# OG Orders left:  179
# Cascade length:  45
# New Orders left:  134
# making new cascade
#
#
# OG Orders left:  134
# Cascade length:  4
# New Orders left:  130
# making new cascade
#
#
# OG Orders left:  130
# Cascade length:  1
# New Orders left:  129
# making new cascade
#
#
# OG Orders left:  129
# Cascade length:  7
# New Orders left:  122
# making new cascade
#
#
# OG Orders left:  122
# Cascade length:  12
# New Orders left:  110
# making new cascade
#
#
# OG Orders left:  110
# Cascade length:  1
# New Orders left:  109
# making new cascade
#
#
# OG Orders left:  109
# Cascade length:  4
# New Orders left:  105
# making new cascade
#
#
# OG Orders left:  105
# Cascade length:  8
# New Orders left:  97
# making new cascade
#
#
# OG Orders left:  97
# Cascade length:  7
# New Orders left:  90
# making new cascade
#
#
# OG Orders left:  90
# Cascade length:  22
# New Orders left:  68
# making new cascade
#
#
# OG Orders left:  68
# Cascade length:  12
# New Orders left:  56
# making new cascade
#
#
# OG Orders left:  56
# Cascade length:  23
# New Orders left:  33
# making new cascade
#
#
# OG Orders left:  33
# Cascade length:  6
# New Orders left:  27
# making new cascade
#
#
# OG Orders left:  27
# Cascade length:  1
# New Orders left:  26
# making new cascade
#
#
# OG Orders left:  26
# Cascade length:  2
# New Orders left:  24
# making new cascade
#
#
# OG Orders left:  24
# Cascade length:  11
# New Orders left:  13
# making new cascade
#
#
# OG Orders left:  13
# Cascade length:  3
# New Orders left:  10
# making new cascade
#
#
# OG Orders left:  10
# Cascade length:  4
# New Orders left:  6
# making new cascade
#
#
# OG Orders left:  6
# Cascade length:  4
# New Orders left:  2
# making new cascade
#
#
# OG Orders left:  2
# Cascade length:  2
# New Orders left:  0
# making new cascade

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/2-4/causalCascades12_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/2-4/causalCascades11_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1)*1, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.9), '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*5, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
