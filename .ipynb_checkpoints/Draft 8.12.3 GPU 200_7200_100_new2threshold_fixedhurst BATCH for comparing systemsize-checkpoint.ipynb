# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_200_7200_100_new2threshold_fixedhurst.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_200_7200_100_new2threshold_fixedhurst.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_200_7200_100_new2threshold_fixedhurst.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_200_7200_100_new2threshold_fixedhurst.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 1   993     yshfc      1   -1.0
# 1                 2   993     yshfc      2   -2.0
# 2                10   993     yshfc     10    1.0
# 3                11   993     yshfc     11    1.0
# 4                13   993     yshfc     13   -1.0
# ...             ...   ...       ...    ...    ...
# 3836251           7  8192     xbcot     35    1.0
# 3836252           9  8192     xbcot     42    1.0
# 3836253           2  8192     jmeyl     76    1.0
# 3836254           3  8192     jmeyl     43   -1.0
# 3836255          16  8192     jmeyl     66   -1.0
#
# [3836256 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades22_npc_200_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1911853

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades21_npc_200_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1911853

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades12_npc_200_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1911853
# Cascade length:  13378
# New Orders left:  1898475
# making new cascade
#
#
# OG Orders left:  1898475
# Cascade length:  11110
# New Orders left:  1887365
# making new cascade
#
#
# OG Orders left:  1887365
# Cascade length:  7915
# New Orders left:  1879450
# making new cascade
#
#
# OG Orders left:  1879450
# Cascade length:  2
# New Orders left:  1879448
# making new cascade
#
#
# OG Orders left:  1879448
# Cascade length:  8917
# New Orders left:  1870531
# making new cascade
#
#
# OG Orders left:  1870531
# Cascade length:  4
# New Orders left:  1870527
# making new cascade
#
#
# OG Orders left:  1870527
# Cascade length:  5621
# New Orders left:  1864906
# making new cascade
#
#
# OG Orders left:  1864906
# Cascade length:  7143
# New Orders left:  1857763
# making new cascade
#
#
# OG Orders left:  1857763
# Cascade length:  3287
# New Orders left:  1854476
# making new cascade
#
#
# OG Orders left:  1854476
# Cascade length:  7953
# New Orders left:  1846523
# making new cascade
#
#
# OG Orders left:  1846523
# Cascade length:  4699
# New Orders left:  1841824
# making new cascade
#
#
# OG Orders left:  1841824
# Cascade length:  2
# New Orders left:  1841822
# making new cascade
#
#
# OG Orders left:  1841822
# Cascade length:  3
# New Orders left:  1841819
# making new cascade
#
#
# OG Orders left:  1841819
# Cascade length:  6
# New Orders left:  1841813
# making new cascade
#
#
# OG Orders left:  1841813
# Cascade length:  2471
# New Orders left:  1839342
# making new cascade
#
#
# OG Orders left:  1839342
# Cascade length:  11
# New Orders left:  1839331
# making new cascade
#
#
# OG Orders left:  1839331
# Cascade length:  2
# New Orders left:  1839329
# making new cascade
#
#
# OG Orders left:  1839329
# Cascade length:  4822
# New Orders left:  1834507
# making new cascade
#
#
# OG Orders left:  1834507
# Cascade length:  2142
# New Orders left:  1832365
# making new cascade
#
#
# OG Orders left:  1832365
# Cascade length:  6022
# New Orders left:  1826343
# making new cascade
#
#
# OG Orders left:  1826343
# Cascade length:  2889
# New Orders left:  1823454
# making new cascade
#
#
# OG Orders left:  1823454
# Cascade length:  65
# New Orders left:  1823389
# making new cascade
#
#
# OG Orders left:  1823389
# Cascade length:  2442
# New Orders left:  1820947
# making new cascade
#
#
# OG Orders left:  1820947
# Cascade length:  2654
# New Orders left:  1818293
# making new cascade
#
#
# OG Orders left:  1818293
# Cascade length:  4631
# New Orders left:  1813662
# making new cascade
#
#
# OG Orders left:  1813662
# Cascade length:  13
# New Orders left:  1813649
# making new cascade
#
#
# OG Orders left:  1813649
# Cascade length:  3641
# New Orders left:  1810008
# making new cascade
#
#
# OG Orders left:  1810008
# Cascade length:  42
# New Orders left:  1809966
# making new cascade
#
#
# OG Orders left:  1809966
# Cascade length:  2037
# New Orders left:  1807929
# making new cascade
#
#
# OG Orders left:  1807929
# Cascade length:  1764
# New Orders left:  1806165
# making new cascade
#
#
# OG Orders left:  1806165
# Cascade length:  2893
# New Orders left:  1803272
# making new cascade
#
#
# OG Orders left:  1803272
# Cascade length:  1790
# New Orders left:  1801482
# making new cascade
#
#
# OG Orders left:  1801482
# Cascade length:  2996
# New Orders left:  1798486
# making new cascade
#
#
# OG Orders left:  1798486
# Cascade length:  4020
# New Orders left:  1794466
# making new cascade
#
#
# OG Orders left:  1794466
# Cascade length:  2431
# New Orders left:  1792035
# making new cascade
#
#
# OG Orders left:  1792035
# Cascade length:  83
# New Orders left:  1791952
# making new cascade
#
#
# OG Orders left:  1791952
# Cascade length:  2315
# New Orders left:  1789637
# making new cascade
#
#
# OG Orders left:  1789637
# Cascade length:  2192
# New Orders left:  1787445
# making new cascade
#
#
# OG Orders left:  1787445
# Cascade length:  1
# New Orders left:  1787444
# making new cascade
#
#
# OG Orders left:  1787444
# Cascade length:  3078
# New Orders left:  1784366
# making new cascade
#
#
# OG Orders left:  1784366
# Cascade length:  2497
# New Orders left:  1781869
# making new cascade
#
#
# OG Orders left:  1781869
# Cascade length:  1879
# New Orders left:  1779990
# making new cascade
#
#
# OG Orders left:  1779990
# Cascade length:  2380
# New Orders left:  1777610
# making new cascade
#
#
# OG Orders left:  1777610
# Cascade length:  2238
# New Orders left:  1775372
# making new cascade
#
#
# OG Orders left:  1775372
# Cascade length:  1500
# New Orders left:  1773872
# making new cascade
#
#
# OG Orders left:  1773872
# Cascade length:  1583
# New Orders left:  1772289
# making new cascade
#
#
# OG Orders left:  1772289
# Cascade length:  2404
# New Orders left:  1769885
# making new cascade
#
#
# OG Orders left:  1769885
# Cascade length:  9
# New Orders left:  1769876
# making new cascade
#
#
# OG Orders left:  1769876
# Cascade length:  3069
# New Orders left:  1766807
# making new cascade
#
#
# OG Orders left:  1766807
# Cascade length:  1745
# New Orders left:  1765062
# making new cascade
#
#
# OG Orders left:  1765062
# Cascade length:  2016
# New Orders left:  1763046
# making new cascade
#
#
# OG Orders left:  1763046
# Cascade length:  632
# New Orders left:  1762414
# making new cascade
#
#
# OG Orders left:  1762414
# Cascade length:  1183
# New Orders left:  1761231
# making new cascade
#
#
# OG Orders left:  1761231
# Cascade length:  1292
# New Orders left:  1759939
# making new cascade
#
#
# OG Orders left:  1759939
# Cascade length:  1861
# New Orders left:  1758078
# making new cascade
#
#
# OG Orders left:  1758078
# Cascade length:  1643
# New Orders left:  1756435
# making new cascade
#
#
# OG Orders left:  1756435
# Cascade length:  1831
# New Orders left:  1754604
# making new cascade
#
#
# OG Orders left:  1754604
# Cascade length:  2008
# New Orders left:  1752596
# making new cascade
#
#
# OG Orders left:  1752596
# Cascade length:  1482
# New Orders left:  1751114
# making new cascade
#
#
# OG Orders left:  1751114
# Cascade length:  4
# New Orders left:  1751110
# making new cascade
#
#
# OG Orders left:  1751110
# Cascade length:  1507
# New Orders left:  1749603
# making new cascade
#
#
# OG Orders left:  1749603
# Cascade length:  1834
# New Orders left:  1747769
# making new cascade
#
#
# OG Orders left:  1747769
# Cascade length:  2205
# New Orders left:  1745564
# making new cascade
#
#
# OG Orders left:  1745564
# Cascade length:  1731
# New Orders left:  1743833
# making new cascade
#
#
# OG Orders left:  1743833
# Cascade length:  1406
# New Orders left:  1742427
# making new cascade
#
#
# OG Orders left:  1742427
# Cascade length:  3967
# New Orders left:  1738460
# making new cascade
#
#
# OG Orders left:  1738460
# Cascade length:  9
# New Orders left:  1738451
# making new cascade
#
#
# OG Orders left:  1738451
# Cascade length:  2408
# New Orders left:  1736043
# making new cascade
#
#
# OG Orders left:  1736043
# Cascade length:  2949
# New Orders left:  1733094
# making new cascade
#
#
# OG Orders left:  1733094
# Cascade length:  1409
# New Orders left:  1731685
# making new cascade
#
#
# OG Orders left:  1731685
# Cascade length:  1777
# New Orders left:  1729908
# making new cascade
#
#
# OG Orders left:  1729908
# Cascade length:  3
# New Orders left:  1729905
# making new cascade
#
#
# OG Orders left:  1729905
# Cascade length:  1842
# New Orders left:  1728063
# making new cascade
#
#
# OG Orders left:  1728063
# Cascade length:  13
# New Orders left:  1728050
# making new cascade
#
#
# OG Orders left:  1728050
# Cascade length:  1089
# New Orders left:  1726961
# making new cascade
#
#
# OG Orders left:  1726961
# Cascade length:  1
# New Orders left:  1726960
# making new cascade
#
#
# OG Orders left:  1726960
# Cascade length:  2391
# New Orders left:  1724569
# making new cascade
#
#
# OG Orders left:  1724569
# Cascade length:  22
# New Orders left:  1724547
# making new cascade
#
#
# OG Orders left:  1724547
# Cascade length:  2013
# New Orders left:  1722534
# making new cascade
#
#
# OG Orders left:  1722534
# Cascade length:  1493
# New Orders left:  1721041
# making new cascade
#
#
# OG Orders left:  1721041
# Cascade length:  11
# New Orders left:  1721030
# making new cascade
#
#
# OG Orders left:  1721030
# Cascade length:  9
# New Orders left:  1721021
# making new cascade
#
#
# OG Orders left:  1721021
# Cascade length:  2141
# New Orders left:  1718880
# making new cascade
#
#
# OG Orders left:  1718880
# Cascade length:  1084
# New Orders left:  1717796
# making new cascade
#
#
# OG Orders left:  1717796
# Cascade length:  1523
# New Orders left:  1716273
# making new cascade
#
#
# OG Orders left:  1716273
# Cascade length:  11
# New Orders left:  1716262
# making new cascade
#
#
# OG Orders left:  1716262
# Cascade length:  1751
# New Orders left:  1714511
# making new cascade
#
#
# OG Orders left:  1714511
# Cascade length:  1276
# New Orders left:  1713235
# making new cascade
#
#
# OG Orders left:  1713235
# Cascade length:  1103
# New Orders left:  1712132
# making new cascade
#
#
# OG Orders left:  1712132
# Cascade length:  1882
# New Orders left:  1710250
# making new cascade
#
#
# OG Orders left:  1710250
# Cascade length:  1529
# New Orders left:  1708721
# making new cascade
#
#
# OG Orders left:  1708721
# Cascade length:  2203
# New Orders left:  1706518
# making new cascade
#
#
# OG Orders left:  1706518
# Cascade length:  1230
# New Orders left:  1705288
# making new cascade
#
#
# OG Orders left:  1705288
# Cascade length:  2855
# New Orders left:  1702433
# making new cascade
#
#
# OG Orders left:  1702433
# Cascade length:  2927
# New Orders left:  1699506
# making new cascade
#
#
# OG Orders left:  1699506
# Cascade length:  211
# New Orders left:  1699295
# making new cascade
#
#
# OG Orders left:  1699295
# Cascade length:  974
# New Orders left:  1698321
# making new cascade
#
#
# OG Orders left:  1698321
# Cascade length:  12
# New Orders left:  1698309
# making new cascade
#
#
# OG Orders left:  1698309
# Cascade length:  2561
# New Orders left:  1695748
# making new cascade
#
#
# OG Orders left:  1695748
# Cascade length:  3734
# New Orders left:  1692014
# making new cascade
#
#
# OG Orders left:  1692014
# Cascade length:  8
# New Orders left:  1692006
# making new cascade
#
#
# OG Orders left:  1692006
# Cascade length:  1310
# New Orders left:  1690696
# making new cascade
#
#
# OG Orders left:  1690696
# Cascade length:  1315
# New Orders left:  1689381
# making new cascade
#
#
# OG Orders left:  1689381
# Cascade length:  28
# New Orders left:  1689353
# making new cascade
#
#
# OG Orders left:  1689353
# Cascade length:  35
# New Orders left:  1689318
# making new cascade
#
#
# OG Orders left:  1689318
# Cascade length:  3967
# New Orders left:  1685351
# making new cascade
#
#
# OG Orders left:  1685351
# Cascade length:  1
# New Orders left:  1685350
# making new cascade
#
#
# OG Orders left:  1685350
# Cascade length:  890
# New Orders left:  1684460
# making new cascade
#
#
# OG Orders left:  1684460
# Cascade length:  3335
# New Orders left:  1681125
# making new cascade
#
#
# OG Orders left:  1681125
# Cascade length:  1291
# New Orders left:  1679834
# making new cascade
#
#
# OG Orders left:  1679834
# Cascade length:  1429
# New Orders left:  1678405
# making new cascade
#
#
# OG Orders left:  1678405
# Cascade length:  653
# New Orders left:  1677752
# making new cascade
#
#
# OG Orders left:  1677752
# Cascade length:  2018
# New Orders left:  1675734
# making new cascade
#
#
# OG Orders left:  1675734
# Cascade length:  1775
# New Orders left:  1673959
# making new cascade
#
#
# OG Orders left:  1673959
# Cascade length:  1469
# New Orders left:  1672490
# making new cascade
#
#
# OG Orders left:  1672490
# Cascade length:  1214
# New Orders left:  1671276
# making new cascade
#
#
# OG Orders left:  1671276
# Cascade length:  1
# New Orders left:  1671275
# making new cascade
#
#
# OG Orders left:  1671275
# Cascade length:  1312
# New Orders left:  1669963
# making new cascade
#
#
# OG Orders left:  1669963
# Cascade length:  18
# New Orders left:  1669945
# making new cascade
#
#
# OG Orders left:  1669945
# Cascade length:  6
# New Orders left:  1669939
# making new cascade
#
#
# OG Orders left:  1669939
# Cascade length:  1851
# New Orders left:  1668088
# making new cascade
#
#
# OG Orders left:  1668088
# Cascade length:  1056
# New Orders left:  1667032
# making new cascade
#
#
# OG Orders left:  1667032
# Cascade length:  2
# New Orders left:  1667030
# making new cascade
#
#
# OG Orders left:  1667030
# Cascade length:  5
# New Orders left:  1667025
# making new cascade
#
#
# OG Orders left:  1667025
# Cascade length:  2187
# New Orders left:  1664838
# making new cascade
#
#
# OG Orders left:  1664838
# Cascade length:  1295
# New Orders left:  1663543
# making new cascade
#
#
# OG Orders left:  1663543
# Cascade length:  12
# New Orders left:  1663531
# making new cascade
#
#
# OG Orders left:  1663531
# Cascade length:  45
# New Orders left:  1663486
# making new cascade
#
#
# OG Orders left:  1663486
# Cascade length:  2044
# New Orders left:  1661442
# making new cascade
#
#
# OG Orders left:  1661442
# Cascade length:  95
# New Orders left:  1661347
# making new cascade
#
#
# OG Orders left:  1661347
# Cascade length:  1992
# New Orders left:  1659355
# making new cascade
#
#
# OG Orders left:  1659355
# Cascade length:  1080
# New Orders left:  1658275
# making new cascade
#
#
# OG Orders left:  1658275
# Cascade length:  815
# New Orders left:  1657460
# making new cascade
#
#
# OG Orders left:  1657460
# Cascade length:  27
# New Orders left:  1657433
# making new cascade
#
#
# OG Orders left:  1657433
# Cascade length:  2330
# New Orders left:  1655103
# making new cascade
#
#
# OG Orders left:  1655103
# Cascade length:  5434
# New Orders left:  1649669
# making new cascade
#
#
# OG Orders left:  1649669
# Cascade length:  631
# New Orders left:  1649038
# making new cascade
#
#
# OG Orders left:  1649038
# Cascade length:  107
# New Orders left:  1648931
# making new cascade
#
#
# OG Orders left:  1648931
# Cascade length:  6
# New Orders left:  1648925
# making new cascade
#
#
# OG Orders left:  1648925
# Cascade length:  13
# New Orders left:  1648912
# making new cascade
#
#
# OG Orders left:  1648912
# Cascade length:  2445
# New Orders left:  1646467
# making new cascade
#
#
# OG Orders left:  1646467
# Cascade length:  1620
# New Orders left:  1644847
# making new cascade
#
#
# OG Orders left:  1644847
# Cascade length:  1922
# New Orders left:  1642925
# making new cascade
#
#
# OG Orders left:  1642925
# Cascade length:  18
# New Orders left:  1642907
# making new cascade
#
#
# OG Orders left:  1642907
# Cascade length:  21
# New Orders left:  1642886
# making new cascade
#
#
# OG Orders left:  1642886
# Cascade length:  1505
# New Orders left:  1641381
# making new cascade
#
#
# OG Orders left:  1641381
# Cascade length:  120
# New Orders left:  1641261
# making new cascade
#
#
# OG Orders left:  1641261
# Cascade length:  1026
# New Orders left:  1640235
# making new cascade
#
#
# OG Orders left:  1640235
# Cascade length:  3
# New Orders left:  1640232
# making new cascade
#
#
# OG Orders left:  1640232
# Cascade length:  12
# New Orders left:  1640220
# making new cascade
#
#
# OG Orders left:  1640220
# Cascade length:  3697
# New Orders left:  1636523
# making new cascade
#
#
# OG Orders left:  1636523
# Cascade length:  3
# New Orders left:  1636520
# making new cascade
#
#
# OG Orders left:  1636520
# Cascade length:  47
# New Orders left:  1636473
# making new cascade
#
#
# OG Orders left:  1636473
# Cascade length:  7
# New Orders left:  1636466
# making new cascade
#
#
# OG Orders left:  1636466
# Cascade length:  1252
# New Orders left:  1635214
# making new cascade
#
#
# OG Orders left:  1635214
# Cascade length:  3
# New Orders left:  1635211
# making new cascade
#
#
# OG Orders left:  1635211
# Cascade length:  19
# New Orders left:  1635192
# making new cascade
#
#
# OG Orders left:  1635192
# Cascade length:  3857
# New Orders left:  1631335
# making new cascade
#
#
# OG Orders left:  1631335
# Cascade length:  12
# New Orders left:  1631323
# making new cascade
#
#
# OG Orders left:  1631323
# Cascade length:  1
# New Orders left:  1631322
# making new cascade
#
#
# OG Orders left:  1631322
# Cascade length:  182
# New Orders left:  1631140
# making new cascade
#
#
# OG Orders left:  1631140
# Cascade length:  2
# New Orders left:  1631138
# making new cascade
#
#
# OG Orders left:  1631138
# Cascade length:  2204
# New Orders left:  1628934
# making new cascade
#
#
# OG Orders left:  1628934
# Cascade length:  1633
# New Orders left:  1627301
# making new cascade
#
#
# OG Orders left:  1627301
# Cascade length:  2225
# New Orders left:  1625076
# making new cascade
#
#
# OG Orders left:  1625076
# Cascade length:  977
# New Orders left:  1624099
# making new cascade
#
#
# OG Orders left:  1624099
# Cascade length:  1008
# New Orders left:  1623091
# making new cascade
#
#
# OG Orders left:  1623091
# Cascade length:  1987
# New Orders left:  1621104
# making new cascade
#
#
# OG Orders left:  1621104
# Cascade length:  970
# New Orders left:  1620134
# making new cascade
#
#
# OG Orders left:  1620134
# Cascade length:  395
# New Orders left:  1619739
# making new cascade
#
#
# OG Orders left:  1619739
# Cascade length:  1941
# New Orders left:  1617798
# making new cascade
#
#
# OG Orders left:  1617798
# Cascade length:  2074
# New Orders left:  1615724
# making new cascade
#
#
# OG Orders left:  1615724
# Cascade length:  8
# New Orders left:  1615716
# making new cascade
#
#
# OG Orders left:  1615716
# Cascade length:  1363
# New Orders left:  1614353
# making new cascade
#
#
# OG Orders left:  1614353
# Cascade length:  80
# New Orders left:  1614273
# making new cascade
#
#
# OG Orders left:  1614273
# Cascade length:  1237
# New Orders left:  1613036
# making new cascade
#
#
# OG Orders left:  1613036
# Cascade length:  279
# New Orders left:  1612757
# making new cascade
#
#
# OG Orders left:  1612757
# Cascade length:  789
# New Orders left:  1611968
# making new cascade
#
#
# OG Orders left:  1611968
# Cascade length:  1961
# New Orders left:  1610007
# making new cascade
#
#
# OG Orders left:  1610007
# Cascade length:  161
# New Orders left:  1609846
# making new cascade
#
#
# OG Orders left:  1609846
# Cascade length:  856
# New Orders left:  1608990
# making new cascade
#
#
# OG Orders left:  1608990
# Cascade length:  1688
# New Orders left:  1607302
# making new cascade
#
#
# OG Orders left:  1607302
# Cascade length:  100
# New Orders left:  1607202
# making new cascade
#
#
# OG Orders left:  1607202
# Cascade length:  2678
# New Orders left:  1604524
# making new cascade
#
#
# OG Orders left:  1604524
# Cascade length:  25
# New Orders left:  1604499
# making new cascade
#
#
# OG Orders left:  1604499
# Cascade length:  39
# New Orders left:  1604460
# making new cascade
#
#
# OG Orders left:  1604460
# Cascade length:  1224
# New Orders left:  1603236
# making new cascade
#
#
# OG Orders left:  1603236
# Cascade length:  1232
# New Orders left:  1602004
# making new cascade
#
#
# OG Orders left:  1602004
# Cascade length:  637
# New Orders left:  1601367
# making new cascade
#
#
# OG Orders left:  1601367
# Cascade length:  147
# New Orders left:  1601220
# making new cascade
#
#
# OG Orders left:  1601220
# Cascade length:  15
# New Orders left:  1601205
# making new cascade
#
#
# OG Orders left:  1601205
# Cascade length:  1499
# New Orders left:  1599706
# making new cascade
#
#
# OG Orders left:  1599706
# Cascade length:  52
# New Orders left:  1599654
# making new cascade
#
#
# OG Orders left:  1599654
# Cascade length:  26
# New Orders left:  1599628
# making new cascade
#
#
# OG Orders left:  1599628
# Cascade length:  108
# New Orders left:  1599520
# making new cascade
#
#
# OG Orders left:  1599520
# Cascade length:  1298
# New Orders left:  1598222
# making new cascade
#
#
# OG Orders left:  1598222
# Cascade length:  1
# New Orders left:  1598221
# making new cascade
#
#
# OG Orders left:  1598221
# Cascade length:  1
# New Orders left:  1598220
# making new cascade
#
#
# OG Orders left:  1598220
# Cascade length:  1611
# New Orders left:  1596609
# making new cascade
#
#
# OG Orders left:  1596609
# Cascade length:  19
# New Orders left:  1596590
# making new cascade
#
#
# OG Orders left:  1596590
# Cascade length:  3
# New Orders left:  1596587
# making new cascade
#
#
# OG Orders left:  1596587
# Cascade length:  1354
# New Orders left:  1595233
# making new cascade
#
#
# OG Orders left:  1595233
# Cascade length:  546
# New Orders left:  1594687
# making new cascade
#
#
# OG Orders left:  1594687
# Cascade length:  578
# New Orders left:  1594109
# making new cascade
#
#
# OG Orders left:  1594109
# Cascade length:  8
# New Orders left:  1594101
# making new cascade
#
#
# OG Orders left:  1594101
# Cascade length:  37
# New Orders left:  1594064
# making new cascade
#
#
# OG Orders left:  1594064
# Cascade length:  4
# New Orders left:  1594060
# making new cascade
#
#
# OG Orders left:  1594060
# Cascade length:  22
# New Orders left:  1594038
# making new cascade
#
#
# OG Orders left:  1594038
# Cascade length:  885
# New Orders left:  1593153
# making new cascade
#
#
# OG Orders left:  1593153
# Cascade length:  788
# New Orders left:  1592365
# making new cascade
#
#
# OG Orders left:  1592365
# Cascade length:  12
# New Orders left:  1592353
# making new cascade
#
#
# OG Orders left:  1592353
# Cascade length:  15
# New Orders left:  1592338
# making new cascade
#
#
# OG Orders left:  1592338
# Cascade length:  1375
# New Orders left:  1590963
# making new cascade
#
#
# OG Orders left:  1590963
# Cascade length:  1
# New Orders left:  1590962
# making new cascade
#
#
# OG Orders left:  1590962
# Cascade length:  955
# New Orders left:  1590007
# making new cascade
#
#
# OG Orders left:  1590007
# Cascade length:  8
# New Orders left:  1589999
# making new cascade
#
#
# OG Orders left:  1589999
# Cascade length:  2253
# New Orders left:  1587746
# making new cascade
#
#
# OG Orders left:  1587746
# Cascade length:  647
# New Orders left:  1587099
# making new cascade
#
#
# OG Orders left:  1587099
# Cascade length:  1059
# New Orders left:  1586040
# making new cascade
#
#
# OG Orders left:  1586040
# Cascade length:  2360
# New Orders left:  1583680
# making new cascade
#
#
# OG Orders left:  1583680
# Cascade length:  6
# New Orders left:  1583674
# making new cascade
#
#
# OG Orders left:  1583674
# Cascade length:  69
# New Orders left:  1583605
# making new cascade
#
#
# OG Orders left:  1583605
# Cascade length:  1
# New Orders left:  1583604
# making new cascade
#
#
# OG Orders left:  1583604
# Cascade length:  271
# New Orders left:  1583333
# making new cascade
#
#
# OG Orders left:  1583333
# Cascade length:  441
# New Orders left:  1582892
# making new cascade
#
#
# OG Orders left:  1582892
# Cascade length:  16
# New Orders left:  1582876
# making new cascade
#
#
# OG Orders left:  1582876
# Cascade length:  2
# New Orders left:  1582874
# making new cascade
#
#
# OG Orders left:  1582874
# Cascade length:  1543
# New Orders left:  1581331
# making new cascade
#
#
# OG Orders left:  1581331
# Cascade length:  26
# New Orders left:  1581305
# making new cascade
#
#
# OG Orders left:  1581305
# Cascade length:  2195
# New Orders left:  1579110
# making new cascade
#
#
# OG Orders left:  1579110
# Cascade length:  1964
# New Orders left:  1577146
# making new cascade
#
#
# OG Orders left:  1577146
# Cascade length:  2
# New Orders left:  1577144
# making new cascade
#
#
# OG Orders left:  1577144
# Cascade length:  33
# New Orders left:  1577111
# making new cascade
#
#
# OG Orders left:  1577111
# Cascade length:  28
# New Orders left:  1577083
# making new cascade
#
#
# OG Orders left:  1577083
# Cascade length:  8
# New Orders left:  1577075
# making new cascade
#
#
# OG Orders left:  1577075
# Cascade length:  2
# New Orders left:  1577073
# making new cascade
#
#
# OG Orders left:  1577073
# Cascade length:  1812
# New Orders left:  1575261
# making new cascade
#
#
# OG Orders left:  1575261
# Cascade length:  1012
# New Orders left:  1574249
# making new cascade
#
#
# OG Orders left:  1574249
# Cascade length:  2
# New Orders left:  1574247
# making new cascade
#
#
# OG Orders left:  1574247
# Cascade length:  7
# New Orders left:  1574240
# making new cascade
#
#
# OG Orders left:  1574240
# Cascade length:  1
# New Orders left:  1574239
# making new cascade
#
#
# OG Orders left:  1574239
# Cascade length:  1
# New Orders left:  1574238
# making new cascade
#
#
# OG Orders left:  1574238
# Cascade length:  23
# New Orders left:  1574215
# making new cascade
#
#
# OG Orders left:  1574215
# Cascade length:  1958
# New Orders left:  1572257
# making new cascade
#
#
# OG Orders left:  1572257
# Cascade length:  20
# New Orders left:  1572237
# making new cascade
#
#
# OG Orders left:  1572237
# Cascade length:  829
# New Orders left:  1571408
# making new cascade
#
#
# OG Orders left:  1571408
# Cascade length:  50
# New Orders left:  1571358
# making new cascade
#
#
# OG Orders left:  1571358
# Cascade length:  2581
# New Orders left:  1568777
# making new cascade
#
#
# OG Orders left:  1568777
# Cascade length:  1
# New Orders left:  1568776
# making new cascade
#
#
# OG Orders left:  1568776
# Cascade length:  3
# New Orders left:  1568773
# making new cascade
#
#
# OG Orders left:  1568773
# Cascade length:  2
# New Orders left:  1568771
# making new cascade
#
#
# OG Orders left:  1568771
# Cascade length:  2456
# New Orders left:  1566315
# making new cascade
#
#
# OG Orders left:  1566315
# Cascade length:  35
# New Orders left:  1566280
# making new cascade
#
#
# OG Orders left:  1566280
# Cascade length:  8
# New Orders left:  1566272
# making new cascade
#
#
# OG Orders left:  1566272
# Cascade length:  23
# New Orders left:  1566249
# making new cascade
#
#
# OG Orders left:  1566249
# Cascade length:  4
# New Orders left:  1566245
# making new cascade
#
#
# OG Orders left:  1566245
# Cascade length:  2290
# New Orders left:  1563955
# making new cascade
#
#
# OG Orders left:  1563955
# Cascade length:  141
# New Orders left:  1563814
# making new cascade
#
#
# OG Orders left:  1563814
# Cascade length:  3
# New Orders left:  1563811
# making new cascade
#
#
# OG Orders left:  1563811
# Cascade length:  16
# New Orders left:  1563795
# making new cascade
#
#
# OG Orders left:  1563795
# Cascade length:  1635
# New Orders left:  1562160
# making new cascade
#
#
# OG Orders left:  1562160
# Cascade length:  1707
# New Orders left:  1560453
# making new cascade
#
#
# OG Orders left:  1560453
# Cascade length:  3
# New Orders left:  1560450
# making new cascade
#
#
# OG Orders left:  1560450
# Cascade length:  2
# New Orders left:  1560448
# making new cascade
#
#
# OG Orders left:  1560448
# Cascade length:  1
# New Orders left:  1560447
# making new cascade
#
#
# OG Orders left:  1560447
# Cascade length:  60
# New Orders left:  1560387
# making new cascade
#
#
# OG Orders left:  1560387
# Cascade length:  950
# New Orders left:  1559437
# making new cascade
#
#
# OG Orders left:  1559437
# Cascade length:  2
# New Orders left:  1559435
# making new cascade
#
#
# OG Orders left:  1559435
# Cascade length:  6
# New Orders left:  1559429
# making new cascade
#
#
# OG Orders left:  1559429
# Cascade length:  855
# New Orders left:  1558574
# making new cascade
#
#
# OG Orders left:  1558574
# Cascade length:  2581
# New Orders left:  1555993
# making new cascade
#
#
# OG Orders left:  1555993
# Cascade length:  4
# New Orders left:  1555989
# making new cascade
#
#
# OG Orders left:  1555989
# Cascade length:  1480
# New Orders left:  1554509
# making new cascade
#
#
# OG Orders left:  1554509
# Cascade length:  9
# New Orders left:  1554500
# making new cascade
#
#
# OG Orders left:  1554500
# Cascade length:  1395
# New Orders left:  1553105
# making new cascade
#
#
# OG Orders left:  1553105
# Cascade length:  2
# New Orders left:  1553103
# making new cascade
#
#
# OG Orders left:  1553103
# Cascade length:  2
# New Orders left:  1553101
# making new cascade
#
#
# OG Orders left:  1553101
# Cascade length:  23
# New Orders left:  1553078
# making new cascade
#
#
# OG Orders left:  1553078
# Cascade length:  12
# New Orders left:  1553066
# making new cascade
#
#
# OG Orders left:  1553066
# Cascade length:  9
# New Orders left:  1553057
# making new cascade
#
#
# OG Orders left:  1553057
# Cascade length:  16
# New Orders left:  1553041
# making new cascade
#
#
# OG Orders left:  1553041
# Cascade length:  6
# New Orders left:  1553035
# making new cascade
#
#
# OG Orders left:  1553035
# Cascade length:  2
# New Orders left:  1553033
# making new cascade
#
#
# OG Orders left:  1553033
# Cascade length:  1900
# New Orders left:  1551133
# making new cascade
#
#
# OG Orders left:  1551133
# Cascade length:  693
# New Orders left:  1550440
# making new cascade
#
#
# OG Orders left:  1550440
# Cascade length:  217
# New Orders left:  1550223
# making new cascade
#
#
# OG Orders left:  1550223
# Cascade length:  1
# New Orders left:  1550222
# making new cascade
#
#
# OG Orders left:  1550222
# Cascade length:  6
# New Orders left:  1550216
# making new cascade
#
#
# OG Orders left:  1550216
# Cascade length:  41
# New Orders left:  1550175
# making new cascade
#
#
# OG Orders left:  1550175
# Cascade length:  9
# New Orders left:  1550166
# making new cascade
#
#
# OG Orders left:  1550166
# Cascade length:  2
# New Orders left:  1550164
# making new cascade
#
#
# OG Orders left:  1550164
# Cascade length:  1868
# New Orders left:  1548296
# making new cascade
#
#
# OG Orders left:  1548296
# Cascade length:  87
# New Orders left:  1548209
# making new cascade
#
#
# OG Orders left:  1548209
# Cascade length:  4
# New Orders left:  1548205
# making new cascade
#
#
# OG Orders left:  1548205
# Cascade length:  1927
# New Orders left:  1546278
# making new cascade
#
#
# OG Orders left:  1546278
# Cascade length:  26
# New Orders left:  1546252
# making new cascade
#
#
# OG Orders left:  1546252
# Cascade length:  13
# New Orders left:  1546239
# making new cascade
#
#
# OG Orders left:  1546239
# Cascade length:  48
# New Orders left:  1546191
# making new cascade
#
#
# OG Orders left:  1546191
# Cascade length:  13
# New Orders left:  1546178
# making new cascade
#
#
# OG Orders left:  1546178
# Cascade length:  7
# New Orders left:  1546171
# making new cascade
#
#
# OG Orders left:  1546171
# Cascade length:  1381
# New Orders left:  1544790
# making new cascade
#
#
# OG Orders left:  1544790
# Cascade length:  6
# New Orders left:  1544784
# making new cascade
#
#
# OG Orders left:  1544784
# Cascade length:  2
# New Orders left:  1544782
# making new cascade
#
#
# OG Orders left:  1544782
# Cascade length:  1
# New Orders left:  1544781
# making new cascade
#
#
# OG Orders left:  1544781
# Cascade length:  5
# New Orders left:  1544776
# making new cascade
#
#
# OG Orders left:  1544776
# Cascade length:  2079
# New Orders left:  1542697
# making new cascade
#
#
# OG Orders left:  1542697
# Cascade length:  21
# New Orders left:  1542676
# making new cascade
#
#
# OG Orders left:  1542676
# Cascade length:  1
# New Orders left:  1542675
# making new cascade
#
#
# OG Orders left:  1542675
# Cascade length:  1970
# New Orders left:  1540705
# making new cascade
#
#
# OG Orders left:  1540705
# Cascade length:  51
# New Orders left:  1540654
# making new cascade
#
#
# OG Orders left:  1540654
# Cascade length:  1
# New Orders left:  1540653
# making new cascade
#
#
# OG Orders left:  1540653
# Cascade length:  14
# New Orders left:  1540639
# making new cascade
#
#
# OG Orders left:  1540639
# Cascade length:  2
# New Orders left:  1540637
# making new cascade
#
#
# OG Orders left:  1540637
# Cascade length:  17
# New Orders left:  1540620
# making new cascade
#
#
# OG Orders left:  1540620
# Cascade length:  5126
# New Orders left:  1535494
# making new cascade
#
#
# OG Orders left:  1535494
# Cascade length:  333
# New Orders left:  1535161
# making new cascade
#
#
# OG Orders left:  1535161
# Cascade length:  6
# New Orders left:  1535155
# making new cascade
#
#
# OG Orders left:  1535155
# Cascade length:  1261
# New Orders left:  1533894
# making new cascade
#
#
# OG Orders left:  1533894
# Cascade length:  1
# New Orders left:  1533893
# making new cascade
#
#
# OG Orders left:  1533893
# Cascade length:  3
# New Orders left:  1533890
# making new cascade
#
#
# OG Orders left:  1533890
# Cascade length:  2623
# New Orders left:  1531267
# making new cascade
#
#
# OG Orders left:  1531267
# Cascade length:  32
# New Orders left:  1531235
# making new cascade
#
#
# OG Orders left:  1531235
# Cascade length:  2
# New Orders left:  1531233
# making new cascade
#
#
# OG Orders left:  1531233
# Cascade length:  41
# New Orders left:  1531192
# making new cascade
#
#
# OG Orders left:  1531192
# Cascade length:  1571
# New Orders left:  1529621
# making new cascade
#
#
# OG Orders left:  1529621
# Cascade length:  2289
# New Orders left:  1527332
# making new cascade
#
#
# OG Orders left:  1527332
# Cascade length:  1313
# New Orders left:  1526019
# making new cascade
#
#
# OG Orders left:  1526019
# Cascade length:  4229
# New Orders left:  1521790
# making new cascade
#
#
# OG Orders left:  1521790
# Cascade length:  12
# New Orders left:  1521778
# making new cascade
#
#
# OG Orders left:  1521778
# Cascade length:  2925
# New Orders left:  1518853
# making new cascade
#
#
# OG Orders left:  1518853
# Cascade length:  25
# New Orders left:  1518828
# making new cascade
#
#
# OG Orders left:  1518828
# Cascade length:  11
# New Orders left:  1518817
# making new cascade
#
#
# OG Orders left:  1518817
# Cascade length:  1717
# New Orders left:  1517100
# making new cascade
#
#
# OG Orders left:  1517100
# Cascade length:  65
# New Orders left:  1517035
# making new cascade
#
#
# OG Orders left:  1517035
# Cascade length:  1
# New Orders left:  1517034
# making new cascade
#
#
# OG Orders left:  1517034
# Cascade length:  1101
# New Orders left:  1515933
# making new cascade
#
#
# OG Orders left:  1515933
# Cascade length:  1004
# New Orders left:  1514929
# making new cascade
#
#
# OG Orders left:  1514929
# Cascade length:  1182
# New Orders left:  1513747
# making new cascade
#
#
# OG Orders left:  1513747
# Cascade length:  2
# New Orders left:  1513745
# making new cascade
#
#
# OG Orders left:  1513745
# Cascade length:  8
# New Orders left:  1513737
# making new cascade
#
#
# OG Orders left:  1513737
# Cascade length:  15
# New Orders left:  1513722
# making new cascade
#
#
# OG Orders left:  1513722
# Cascade length:  21
# New Orders left:  1513701
# making new cascade
#
#
# OG Orders left:  1513701
# Cascade length:  136
# New Orders left:  1513565
# making new cascade
#
#
# OG Orders left:  1513565
# Cascade length:  1388
# New Orders left:  1512177
# making new cascade
#
#
# OG Orders left:  1512177
# Cascade length:  1253
# New Orders left:  1510924
# making new cascade
#
#
# OG Orders left:  1510924
# Cascade length:  16
# New Orders left:  1510908
# making new cascade
#
#
# OG Orders left:  1510908
# Cascade length:  105
# New Orders left:  1510803
# making new cascade
#
#
# OG Orders left:  1510803
# Cascade length:  92
# New Orders left:  1510711
# making new cascade
#
#
# OG Orders left:  1510711
# Cascade length:  3613
# New Orders left:  1507098
# making new cascade
#
#
# OG Orders left:  1507098
# Cascade length:  2441
# New Orders left:  1504657
# making new cascade
#
#
# OG Orders left:  1504657
# Cascade length:  34
# New Orders left:  1504623
# making new cascade
#
#
# OG Orders left:  1504623
# Cascade length:  23
# New Orders left:  1504600
# making new cascade
#
#
# OG Orders left:  1504600
# Cascade length:  3131
# New Orders left:  1501469
# making new cascade
#
#
# OG Orders left:  1501469
# Cascade length:  75
# New Orders left:  1501394
# making new cascade
#
#
# OG Orders left:  1501394
# Cascade length:  1401
# New Orders left:  1499993
# making new cascade
#
#
# OG Orders left:  1499993
# Cascade length:  1413
# New Orders left:  1498580
# making new cascade
#
#
# OG Orders left:  1498580
# Cascade length:  10
# New Orders left:  1498570
# making new cascade
#
#
# OG Orders left:  1498570
# Cascade length:  66
# New Orders left:  1498504
# making new cascade
#
#
# OG Orders left:  1498504
# Cascade length:  1131
# New Orders left:  1497373
# making new cascade
#
#
# OG Orders left:  1497373
# Cascade length:  4074
# New Orders left:  1493299
# making new cascade
#
#
# OG Orders left:  1493299
# Cascade length:  42
# New Orders left:  1493257
# making new cascade
#
#
# OG Orders left:  1493257
# Cascade length:  52
# New Orders left:  1493205
# making new cascade
#
#
# OG Orders left:  1493205
# Cascade length:  2462
# New Orders left:  1490743
# making new cascade
#
#
# OG Orders left:  1490743
# Cascade length:  1
# New Orders left:  1490742
# making new cascade
#
#
# OG Orders left:  1490742
# Cascade length:  1024
# New Orders left:  1489718
# making new cascade
#
#
# OG Orders left:  1489718
# Cascade length:  382
# New Orders left:  1489336
# making new cascade
#
#
# OG Orders left:  1489336
# Cascade length:  33
# New Orders left:  1489303
# making new cascade
#
#
# OG Orders left:  1489303
# Cascade length:  2011
# New Orders left:  1487292
# making new cascade
#
#
# OG Orders left:  1487292
# Cascade length:  19
# New Orders left:  1487273
# making new cascade
#
#
# OG Orders left:  1487273
# Cascade length:  5366
# New Orders left:  1481907
# making new cascade
#
#
# OG Orders left:  1481907
# Cascade length:  107
# New Orders left:  1481800
# making new cascade
#
#
# OG Orders left:  1481800
# Cascade length:  1840
# New Orders left:  1479960
# making new cascade
#
#
# OG Orders left:  1479960
# Cascade length:  1152
# New Orders left:  1478808
# making new cascade
#
#
# OG Orders left:  1478808
# Cascade length:  16
# New Orders left:  1478792
# making new cascade
#
#
# OG Orders left:  1478792
# Cascade length:  19
# New Orders left:  1478773
# making new cascade
#
#
# OG Orders left:  1478773
# Cascade length:  1615
# New Orders left:  1477158
# making new cascade
#
#
# OG Orders left:  1477158
# Cascade length:  1
# New Orders left:  1477157
# making new cascade
#
#
# OG Orders left:  1477157
# Cascade length:  820
# New Orders left:  1476337
# making new cascade
#
#
# OG Orders left:  1476337
# Cascade length:  2988
# New Orders left:  1473349
# making new cascade
#
#
# OG Orders left:  1473349
# Cascade length:  1289
# New Orders left:  1472060
# making new cascade
#
#
# OG Orders left:  1472060
# Cascade length:  6
# New Orders left:  1472054
# making new cascade
#
#
# OG Orders left:  1472054
# Cascade length:  44
# New Orders left:  1472010
# making new cascade
#
#
# OG Orders left:  1472010
# Cascade length:  56
# New Orders left:  1471954
# making new cascade
#
#
# OG Orders left:  1471954
# Cascade length:  3694
# New Orders left:  1468260
# making new cascade
#
#
# OG Orders left:  1468260
# Cascade length:  1406
# New Orders left:  1466854
# making new cascade
#
#
# OG Orders left:  1466854
# Cascade length:  1
# New Orders left:  1466853
# making new cascade
#
#
# OG Orders left:  1466853
# Cascade length:  19
# New Orders left:  1466834
# making new cascade
#
#
# OG Orders left:  1466834
# Cascade length:  4
# New Orders left:  1466830
# making new cascade
#
#
# OG Orders left:  1466830
# Cascade length:  6
# New Orders left:  1466824
# making new cascade
#
#
# OG Orders left:  1466824
# Cascade length:  4
# New Orders left:  1466820
# making new cascade
#
#
# OG Orders left:  1466820
# Cascade length:  15
# New Orders left:  1466805
# making new cascade
#
#
# OG Orders left:  1466805
# Cascade length:  7
# New Orders left:  1466798
# making new cascade
#
#
# OG Orders left:  1466798
# Cascade length:  4
# New Orders left:  1466794
# making new cascade
#
#
# OG Orders left:  1466794
# Cascade length:  2
# New Orders left:  1466792
# making new cascade
#
#
# OG Orders left:  1466792
# Cascade length:  17
# New Orders left:  1466775
# making new cascade
#
#
# OG Orders left:  1466775
# Cascade length:  140
# New Orders left:  1466635
# making new cascade
#
#
# OG Orders left:  1466635
# Cascade length:  8
# New Orders left:  1466627
# making new cascade
#
#
# OG Orders left:  1466627
# Cascade length:  20
# New Orders left:  1466607
# making new cascade
#
#
# OG Orders left:  1466607
# Cascade length:  15
# New Orders left:  1466592
# making new cascade
#
#
# OG Orders left:  1466592
# Cascade length:  809
# New Orders left:  1465783
# making new cascade
#
#
# OG Orders left:  1465783
# Cascade length:  6
# New Orders left:  1465777
# making new cascade
#
#
# OG Orders left:  1465777
# Cascade length:  44
# New Orders left:  1465733
# making new cascade
#
#
# OG Orders left:  1465733
# Cascade length:  7551
# New Orders left:  1458182
# making new cascade
#
#
# OG Orders left:  1458182
# Cascade length:  2
# New Orders left:  1458180
# making new cascade
#
#
# OG Orders left:  1458180
# Cascade length:  15
# New Orders left:  1458165
# making new cascade
#
#
# OG Orders left:  1458165
# Cascade length:  2739
# New Orders left:  1455426
# making new cascade
#
#
# OG Orders left:  1455426
# Cascade length:  1260
# New Orders left:  1454166
# making new cascade
#
#
# OG Orders left:  1454166
# Cascade length:  1359
# New Orders left:  1452807
# making new cascade
#
#
# OG Orders left:  1452807
# Cascade length:  2
# New Orders left:  1452805
# making new cascade
#
#
# OG Orders left:  1452805
# Cascade length:  15
# New Orders left:  1452790
# making new cascade
#
#
# OG Orders left:  1452790
# Cascade length:  1
# New Orders left:  1452789
# making new cascade
#
#
# OG Orders left:  1452789
# Cascade length:  14
# New Orders left:  1452775
# making new cascade
#
#
# OG Orders left:  1452775
# Cascade length:  4503
# New Orders left:  1448272
# making new cascade
#
#
# OG Orders left:  1448272
# Cascade length:  1228
# New Orders left:  1447044
# making new cascade
#
#
# OG Orders left:  1447044
# Cascade length:  134
# New Orders left:  1446910
# making new cascade
#
#
# OG Orders left:  1446910
# Cascade length:  28
# New Orders left:  1446882
# making new cascade
#
#
# OG Orders left:  1446882
# Cascade length:  9
# New Orders left:  1446873
# making new cascade
#
#
# OG Orders left:  1446873
# Cascade length:  1155
# New Orders left:  1445718
# making new cascade
#
#
# OG Orders left:  1445718
# Cascade length:  137
# New Orders left:  1445581
# making new cascade
#
#
# OG Orders left:  1445581
# Cascade length:  39
# New Orders left:  1445542
# making new cascade
#
#
# OG Orders left:  1445542
# Cascade length:  24
# New Orders left:  1445518
# making new cascade
#
#
# OG Orders left:  1445518
# Cascade length:  1162
# New Orders left:  1444356
# making new cascade
#
#
# OG Orders left:  1444356
# Cascade length:  1
# New Orders left:  1444355
# making new cascade
#
#
# OG Orders left:  1444355
# Cascade length:  38
# New Orders left:  1444317
# making new cascade
#
#
# OG Orders left:  1444317
# Cascade length:  3010
# New Orders left:  1441307
# making new cascade
#
#
# OG Orders left:  1441307
# Cascade length:  7
# New Orders left:  1441300
# making new cascade
#
#
# OG Orders left:  1441300
# Cascade length:  3
# New Orders left:  1441297
# making new cascade
#
#
# OG Orders left:  1441297
# Cascade length:  3934
# New Orders left:  1437363
# making new cascade
#
#
# OG Orders left:  1437363
# Cascade length:  19
# New Orders left:  1437344
# making new cascade
#
#
# OG Orders left:  1437344
# Cascade length:  82
# New Orders left:  1437262
# making new cascade
#
#
# OG Orders left:  1437262
# Cascade length:  2362
# New Orders left:  1434900
# making new cascade
#
#
# OG Orders left:  1434900
# Cascade length:  15
# New Orders left:  1434885
# making new cascade
#
#
# OG Orders left:  1434885
# Cascade length:  1194
# New Orders left:  1433691
# making new cascade
#
#
# OG Orders left:  1433691
# Cascade length:  427
# New Orders left:  1433264
# making new cascade
#
#
# OG Orders left:  1433264
# Cascade length:  39
# New Orders left:  1433225
# making new cascade
#
#
# OG Orders left:  1433225
# Cascade length:  26
# New Orders left:  1433199
# making new cascade
#
#
# OG Orders left:  1433199
# Cascade length:  139
# New Orders left:  1433060
# making new cascade
#
#
# OG Orders left:  1433060
# Cascade length:  28
# New Orders left:  1433032
# making new cascade
#
#
# OG Orders left:  1433032
# Cascade length:  5
# New Orders left:  1433027
# making new cascade
#
#
# OG Orders left:  1433027
# Cascade length:  3976
# New Orders left:  1429051
# making new cascade
#
#
# OG Orders left:  1429051
# Cascade length:  15
# New Orders left:  1429036
# making new cascade
#
#
# OG Orders left:  1429036
# Cascade length:  4
# New Orders left:  1429032
# making new cascade
#
#
# OG Orders left:  1429032
# Cascade length:  20
# New Orders left:  1429012
# making new cascade
#
#
# OG Orders left:  1429012
# Cascade length:  391
# New Orders left:  1428621
# making new cascade
#
#
# OG Orders left:  1428621
# Cascade length:  33
# New Orders left:  1428588
# making new cascade
#
#
# OG Orders left:  1428588
# Cascade length:  3215
# New Orders left:  1425373
# making new cascade
#
#
# OG Orders left:  1425373
# Cascade length:  53
# New Orders left:  1425320
# making new cascade
#
#
# OG Orders left:  1425320
# Cascade length:  2194
# New Orders left:  1423126
# making new cascade
#
#
# OG Orders left:  1423126
# Cascade length:  70
# New Orders left:  1423056
# making new cascade
#
#
# OG Orders left:  1423056
# Cascade length:  1426
# New Orders left:  1421630
# making new cascade
#
#
# OG Orders left:  1421630
# Cascade length:  45
# New Orders left:  1421585
# making new cascade
#
#
# OG Orders left:  1421585
# Cascade length:  16
# New Orders left:  1421569
# making new cascade
#
#
# OG Orders left:  1421569
# Cascade length:  2025
# New Orders left:  1419544
# making new cascade
#
#
# OG Orders left:  1419544
# Cascade length:  10
# New Orders left:  1419534
# making new cascade
#
#
# OG Orders left:  1419534
# Cascade length:  7
# New Orders left:  1419527
# making new cascade
#
#
# OG Orders left:  1419527
# Cascade length:  2374
# New Orders left:  1417153
# making new cascade
#
#
# OG Orders left:  1417153
# Cascade length:  42
# New Orders left:  1417111
# making new cascade
#
#
# OG Orders left:  1417111
# Cascade length:  3819
# New Orders left:  1413292
# making new cascade
#
#
# OG Orders left:  1413292
# Cascade length:  2804
# New Orders left:  1410488
# making new cascade
#
#
# OG Orders left:  1410488
# Cascade length:  1325
# New Orders left:  1409163
# making new cascade
#
#
# OG Orders left:  1409163
# Cascade length:  1772
# New Orders left:  1407391
# making new cascade
#
#
# OG Orders left:  1407391
# Cascade length:  18
# New Orders left:  1407373
# making new cascade
#
#
# OG Orders left:  1407373
# Cascade length:  1679
# New Orders left:  1405694
# making new cascade
#
#
# OG Orders left:  1405694
# Cascade length:  1014
# New Orders left:  1404680
# making new cascade
#
#
# OG Orders left:  1404680
# Cascade length:  983
# New Orders left:  1403697
# making new cascade
#
#
# OG Orders left:  1403697
# Cascade length:  3
# New Orders left:  1403694
# making new cascade
#
#
# OG Orders left:  1403694
# Cascade length:  2151
# New Orders left:  1401543
# making new cascade
#
#
# OG Orders left:  1401543
# Cascade length:  19
# New Orders left:  1401524
# making new cascade
#
#
# OG Orders left:  1401524
# Cascade length:  767
# New Orders left:  1400757
# making new cascade
#
#
# OG Orders left:  1400757
# Cascade length:  2878
# New Orders left:  1397879
# making new cascade
#
#
# OG Orders left:  1397879
# Cascade length:  38
# New Orders left:  1397841
# making new cascade
#
#
# OG Orders left:  1397841
# Cascade length:  33
# New Orders left:  1397808
# making new cascade
#
#
# OG Orders left:  1397808
# Cascade length:  799
# New Orders left:  1397009
# making new cascade
#
#
# OG Orders left:  1397009
# Cascade length:  2741
# New Orders left:  1394268
# making new cascade
#
#
# OG Orders left:  1394268
# Cascade length:  9
# New Orders left:  1394259
# making new cascade
#
#
# OG Orders left:  1394259
# Cascade length:  18
# New Orders left:  1394241
# making new cascade
#
#
# OG Orders left:  1394241
# Cascade length:  652
# New Orders left:  1393589
# making new cascade
#
#
# OG Orders left:  1393589
# Cascade length:  3146
# New Orders left:  1390443
# making new cascade
#
#
# OG Orders left:  1390443
# Cascade length:  134
# New Orders left:  1390309
# making new cascade
#
#
# OG Orders left:  1390309
# Cascade length:  22
# New Orders left:  1390287
# making new cascade
#
#
# OG Orders left:  1390287
# Cascade length:  1565
# New Orders left:  1388722
# making new cascade
#
#
# OG Orders left:  1388722
# Cascade length:  33
# New Orders left:  1388689
# making new cascade
#
#
# OG Orders left:  1388689
# Cascade length:  3777
# New Orders left:  1384912
# making new cascade
#
#
# OG Orders left:  1384912
# Cascade length:  2457
# New Orders left:  1382455
# making new cascade
#
#
# OG Orders left:  1382455
# Cascade length:  1022
# New Orders left:  1381433
# making new cascade
#
#
# OG Orders left:  1381433
# Cascade length:  36
# New Orders left:  1381397
# making new cascade
#
#
# OG Orders left:  1381397
# Cascade length:  4
# New Orders left:  1381393
# making new cascade
#
#
# OG Orders left:  1381393
# Cascade length:  1971
# New Orders left:  1379422
# making new cascade
#
#
# OG Orders left:  1379422
# Cascade length:  3400
# New Orders left:  1376022
# making new cascade
#
#
# OG Orders left:  1376022
# Cascade length:  14
# New Orders left:  1376008
# making new cascade
#
#
# OG Orders left:  1376008
# Cascade length:  6
# New Orders left:  1376002
# making new cascade
#
#
# OG Orders left:  1376002
# Cascade length:  131
# New Orders left:  1375871
# making new cascade
#
#
# OG Orders left:  1375871
# Cascade length:  1
# New Orders left:  1375870
# making new cascade
#
#
# OG Orders left:  1375870
# Cascade length:  3
# New Orders left:  1375867
# making new cascade
#
#
# OG Orders left:  1375867
# Cascade length:  23
# New Orders left:  1375844
# making new cascade
#
#
# OG Orders left:  1375844
# Cascade length:  1997
# New Orders left:  1373847
# making new cascade
#
#
# OG Orders left:  1373847
# Cascade length:  10
# New Orders left:  1373837
# making new cascade
#
#
# OG Orders left:  1373837
# Cascade length:  1090
# New Orders left:  1372747
# making new cascade
#
#
# OG Orders left:  1372747
# Cascade length:  1953
# New Orders left:  1370794
# making new cascade
#
#
# OG Orders left:  1370794
# Cascade length:  3
# New Orders left:  1370791
# making new cascade
#
#
# OG Orders left:  1370791
# Cascade length:  35
# New Orders left:  1370756
# making new cascade
#
#
# OG Orders left:  1370756
# Cascade length:  3098
# New Orders left:  1367658
# making new cascade
#
#
# OG Orders left:  1367658
# Cascade length:  4
# New Orders left:  1367654
# making new cascade
#
#
# OG Orders left:  1367654
# Cascade length:  38
# New Orders left:  1367616
# making new cascade
#
#
# OG Orders left:  1367616
# Cascade length:  27
# New Orders left:  1367589
# making new cascade
#
#
# OG Orders left:  1367589
# Cascade length:  90
# New Orders left:  1367499
# making new cascade
#
#
# OG Orders left:  1367499
# Cascade length:  410
# New Orders left:  1367089
# making new cascade
#
#
# OG Orders left:  1367089
# Cascade length:  917
# New Orders left:  1366172
# making new cascade
#
#
# OG Orders left:  1366172
# Cascade length:  783
# New Orders left:  1365389
# making new cascade
#
#
# OG Orders left:  1365389
# Cascade length:  4573
# New Orders left:  1360816
# making new cascade
#
#
# OG Orders left:  1360816
# Cascade length:  191
# New Orders left:  1360625
# making new cascade
#
#
# OG Orders left:  1360625
# Cascade length:  2
# New Orders left:  1360623
# making new cascade
#
#
# OG Orders left:  1360623
# Cascade length:  12
# New Orders left:  1360611
# making new cascade
#
#
# OG Orders left:  1360611
# Cascade length:  17
# New Orders left:  1360594
# making new cascade
#
#
# OG Orders left:  1360594
# Cascade length:  775
# New Orders left:  1359819
# making new cascade
#
#
# OG Orders left:  1359819
# Cascade length:  946
# New Orders left:  1358873
# making new cascade
#
#
# OG Orders left:  1358873
# Cascade length:  2558
# New Orders left:  1356315
# making new cascade
#
#
# OG Orders left:  1356315
# Cascade length:  6
# ...
# New Orders left:  116628
# making new cascade
#
#
# OG Orders left:  116628
# Cascade length:  1892
# New Orders left:  114736
# making new cascade
#
#
# OG Orders left:  114736
# Cascade length:  2089
# New Orders left:  112647
# making new cascade
#
#
# OG Orders left:  112647
# Cascade length:  9
# New Orders left:  112638
# making new cascade
#
#
# OG Orders left:  112638
# Cascade length:  68
# New Orders left:  112570
# making new cascade
#
#
# OG Orders left:  112570
# Cascade length:  1496
# New Orders left:  111074
# making new cascade
#
#
# OG Orders left:  111074
# Cascade length:  2507
# New Orders left:  108567
# making new cascade
#
#
# OG Orders left:  108567
# Cascade length:  13
# New Orders left:  108554
# making new cascade
#
#
# OG Orders left:  108554
# Cascade length:  1342
# New Orders left:  107212
# making new cascade
#
#
# OG Orders left:  107212
# Cascade length:  1528
# New Orders left:  105684
# making new cascade
#
#
# OG Orders left:  105684
# Cascade length:  72
# New Orders left:  105612
# making new cascade
#
#
# OG Orders left:  105612
# Cascade length:  2102
# New Orders left:  103510
# making new cascade
#
#
# OG Orders left:  103510
# Cascade length:  758
# New Orders left:  102752
# making new cascade
#
#
# OG Orders left:  102752
# Cascade length:  1879
# New Orders left:  100873
# making new cascade
#
#
# OG Orders left:  100873
# Cascade length:  1451
# New Orders left:  99422
# making new cascade
#
#
# OG Orders left:  99422
# Cascade length:  551
# New Orders left:  98871
# making new cascade
#
#
# OG Orders left:  98871
# Cascade length:  1134
# New Orders left:  97737
# making new cascade
#
#
# OG Orders left:  97737
# Cascade length:  3361
# New Orders left:  94376
# making new cascade
#
#
# OG Orders left:  94376
# Cascade length:  230
# New Orders left:  94146
# making new cascade
#
#
# OG Orders left:  94146
# Cascade length:  900
# New Orders left:  93246
# making new cascade
#
#
# OG Orders left:  93246
# Cascade length:  833
# New Orders left:  92413
# making new cascade
#
#
# OG Orders left:  92413
# Cascade length:  11
# New Orders left:  92402
# making new cascade
#
#
# OG Orders left:  92402
# Cascade length:  313
# New Orders left:  92089
# making new cascade
#
#
# OG Orders left:  92089
# Cascade length:  552
# New Orders left:  91537
# making new cascade
#
#
# OG Orders left:  91537
# Cascade length:  1353
# New Orders left:  90184
# making new cascade
#
#
# OG Orders left:  90184
# Cascade length:  18
# New Orders left:  90166
# making new cascade
#
#
# OG Orders left:  90166
# Cascade length:  869
# New Orders left:  89297
# making new cascade
#
#
# OG Orders left:  89297
# Cascade length:  2380
# New Orders left:  86917
# making new cascade
#
#
# OG Orders left:  86917
# Cascade length:  34
# New Orders left:  86883
# making new cascade
#
#
# OG Orders left:  86883
# Cascade length:  1948
# New Orders left:  84935
# making new cascade
#
#
# OG Orders left:  84935
# Cascade length:  2209
# New Orders left:  82726
# making new cascade
#
#
# OG Orders left:  82726
# Cascade length:  1647
# New Orders left:  81079
# making new cascade
#
#
# OG Orders left:  81079
# Cascade length:  1427
# New Orders left:  79652
# making new cascade
#
#
# OG Orders left:  79652
# Cascade length:  1726
# New Orders left:  77926
# making new cascade
#
#
# OG Orders left:  77926
# Cascade length:  44
# New Orders left:  77882
# making new cascade
#
#
# OG Orders left:  77882
# Cascade length:  15
# New Orders left:  77867
# making new cascade
#
#
# OG Orders left:  77867
# Cascade length:  2392
# New Orders left:  75475
# making new cascade
#
#
# OG Orders left:  75475
# Cascade length:  1540
# New Orders left:  73935
# making new cascade
#
#
# OG Orders left:  73935
# Cascade length:  1
# New Orders left:  73934
# making new cascade
#
#
# OG Orders left:  73934
# Cascade length:  7
# New Orders left:  73927
# making new cascade
#
#
# OG Orders left:  73927
# Cascade length:  2004
# New Orders left:  71923
# making new cascade
#
#
# OG Orders left:  71923
# Cascade length:  555
# New Orders left:  71368
# making new cascade
#
#
# OG Orders left:  71368
# Cascade length:  2
# New Orders left:  71366
# making new cascade
#
#
# OG Orders left:  71366
# Cascade length:  1579
# New Orders left:  69787
# making new cascade
#
#
# OG Orders left:  69787
# Cascade length:  1243
# New Orders left:  68544
# making new cascade
#
#
# OG Orders left:  68544
# Cascade length:  2419
# New Orders left:  66125
# making new cascade
#
#
# OG Orders left:  66125
# Cascade length:  231
# New Orders left:  65894
# making new cascade
#
#
# OG Orders left:  65894
# Cascade length:  288
# New Orders left:  65606
# making new cascade
#
#
# OG Orders left:  65606
# Cascade length:  1405
# New Orders left:  64201
# making new cascade
#
#
# OG Orders left:  64201
# Cascade length:  2693
# New Orders left:  61508
# making new cascade
#
#
# OG Orders left:  61508
# Cascade length:  2159
# New Orders left:  59349
# making new cascade
#
#
# OG Orders left:  59349
# Cascade length:  19
# New Orders left:  59330
# making new cascade
#
#
# OG Orders left:  59330
# Cascade length:  12
# New Orders left:  59318
# making new cascade
#
#
# OG Orders left:  59318
# Cascade length:  2291
# New Orders left:  57027
# making new cascade
#
#
# OG Orders left:  57027
# Cascade length:  1622
# New Orders left:  55405
# making new cascade
#
#
# OG Orders left:  55405
# Cascade length:  31
# New Orders left:  55374
# making new cascade
#
#
# OG Orders left:  55374
# Cascade length:  2054
# New Orders left:  53320
# making new cascade
#
#
# OG Orders left:  53320
# Cascade length:  265
# New Orders left:  53055
# making new cascade
#
#
# OG Orders left:  53055
# Cascade length:  937
# New Orders left:  52118
# making new cascade
#
#
# OG Orders left:  52118
# Cascade length:  1369
# New Orders left:  50749
# making new cascade
#
#
# OG Orders left:  50749
# Cascade length:  175
# New Orders left:  50574
# making new cascade
#
#
# OG Orders left:  50574
# Cascade length:  134
# New Orders left:  50440
# making new cascade
#
#
# OG Orders left:  50440
# Cascade length:  34
# New Orders left:  50406
# making new cascade
#
#
# OG Orders left:  50406
# Cascade length:  581
# New Orders left:  49825
# making new cascade
#
#
# OG Orders left:  49825
# Cascade length:  15
# New Orders left:  49810
# making new cascade
#
#
# OG Orders left:  49810
# Cascade length:  18
# New Orders left:  49792
# making new cascade
#
#
# OG Orders left:  49792
# Cascade length:  10
# New Orders left:  49782
# making new cascade
#
#
# OG Orders left:  49782
# Cascade length:  321
# New Orders left:  49461
# making new cascade
#
#
# OG Orders left:  49461
# Cascade length:  2
# New Orders left:  49459
# making new cascade
#
#
# OG Orders left:  49459
# Cascade length:  686
# New Orders left:  48773
# making new cascade
#
#
# OG Orders left:  48773
# Cascade length:  9
# New Orders left:  48764
# making new cascade
#
#
# OG Orders left:  48764
# Cascade length:  41
# New Orders left:  48723
# making new cascade
#
#
# OG Orders left:  48723
# Cascade length:  472
# New Orders left:  48251
# making new cascade
#
#
# OG Orders left:  48251
# Cascade length:  12
# New Orders left:  48239
# making new cascade
#
#
# OG Orders left:  48239
# Cascade length:  2049
# New Orders left:  46190
# making new cascade
#
#
# OG Orders left:  46190
# Cascade length:  52
# New Orders left:  46138
# making new cascade
#
#
# OG Orders left:  46138
# Cascade length:  716
# New Orders left:  45422
# making new cascade
#
#
# OG Orders left:  45422
# Cascade length:  140
# New Orders left:  45282
# making new cascade
#
#
# OG Orders left:  45282
# Cascade length:  1891
# New Orders left:  43391
# making new cascade
#
#
# OG Orders left:  43391
# Cascade length:  1525
# New Orders left:  41866
# making new cascade
#
#
# OG Orders left:  41866
# Cascade length:  1170
# New Orders left:  40696
# making new cascade
#
#
# OG Orders left:  40696
# Cascade length:  1351
# New Orders left:  39345
# making new cascade
#
#
# OG Orders left:  39345
# Cascade length:  571
# New Orders left:  38774
# making new cascade
#
#
# OG Orders left:  38774
# Cascade length:  77
# New Orders left:  38697
# making new cascade
#
#
# OG Orders left:  38697
# Cascade length:  62
# New Orders left:  38635
# making new cascade
#
#
# OG Orders left:  38635
# Cascade length:  1
# New Orders left:  38634
# making new cascade
#
#
# OG Orders left:  38634
# Cascade length:  2
# New Orders left:  38632
# making new cascade
#
#
# OG Orders left:  38632
# Cascade length:  943
# New Orders left:  37689
# making new cascade
#
#
# OG Orders left:  37689
# Cascade length:  1
# New Orders left:  37688
# making new cascade
#
#
# OG Orders left:  37688
# Cascade length:  182
# New Orders left:  37506
# making new cascade
#
#
# OG Orders left:  37506
# Cascade length:  74
# New Orders left:  37432
# making new cascade
#
#
# OG Orders left:  37432
# Cascade length:  26
# New Orders left:  37406
# making new cascade
#
#
# OG Orders left:  37406
# Cascade length:  1644
# New Orders left:  35762
# making new cascade
#
#
# OG Orders left:  35762
# Cascade length:  19
# New Orders left:  35743
# making new cascade
#
#
# OG Orders left:  35743
# Cascade length:  1255
# New Orders left:  34488
# making new cascade
#
#
# OG Orders left:  34488
# Cascade length:  809
# New Orders left:  33679
# making new cascade
#
#
# OG Orders left:  33679
# Cascade length:  658
# New Orders left:  33021
# making new cascade
#
#
# OG Orders left:  33021
# Cascade length:  1806
# New Orders left:  31215
# making new cascade
#
#
# OG Orders left:  31215
# Cascade length:  5
# New Orders left:  31210
# making new cascade
#
#
# OG Orders left:  31210
# Cascade length:  2074
# New Orders left:  29136
# making new cascade
#
#
# OG Orders left:  29136
# Cascade length:  1
# New Orders left:  29135
# making new cascade
#
#
# OG Orders left:  29135
# Cascade length:  141
# New Orders left:  28994
# making new cascade
#
#
# OG Orders left:  28994
# Cascade length:  2698
# New Orders left:  26296
# making new cascade
#
#
# OG Orders left:  26296
# Cascade length:  670
# New Orders left:  25626
# making new cascade
#
#
# OG Orders left:  25626
# Cascade length:  764
# New Orders left:  24862
# making new cascade
#
#
# OG Orders left:  24862
# Cascade length:  374
# New Orders left:  24488
# making new cascade
#
#
# OG Orders left:  24488
# Cascade length:  932
# New Orders left:  23556
# making new cascade
#
#
# OG Orders left:  23556
# Cascade length:  832
# New Orders left:  22724
# making new cascade
#
#
# OG Orders left:  22724
# Cascade length:  285
# New Orders left:  22439
# making new cascade
#
#
# OG Orders left:  22439
# Cascade length:  1029
# New Orders left:  21410
# making new cascade
#
#
# OG Orders left:  21410
# Cascade length:  1016
# New Orders left:  20394
# making new cascade
#
#
# OG Orders left:  20394
# Cascade length:  1088
# New Orders left:  19306
# making new cascade
#
#
# OG Orders left:  19306
# Cascade length:  6
# New Orders left:  19300
# making new cascade
#
#
# OG Orders left:  19300
# Cascade length:  1184
# New Orders left:  18116
# making new cascade
#
#
# OG Orders left:  18116
# Cascade length:  542
# New Orders left:  17574
# making new cascade
#
#
# OG Orders left:  17574
# Cascade length:  11
# New Orders left:  17563
# making new cascade
#
#
# OG Orders left:  17563
# Cascade length:  1025
# New Orders left:  16538
# making new cascade
#
#
# OG Orders left:  16538
# Cascade length:  1193
# New Orders left:  15345
# making new cascade
#
#
# OG Orders left:  15345
# Cascade length:  657
# New Orders left:  14688
# making new cascade
#
#
# OG Orders left:  14688
# Cascade length:  2
# New Orders left:  14686
# making new cascade
#
#
# OG Orders left:  14686
# Cascade length:  14
# New Orders left:  14672
# making new cascade
#
#
# OG Orders left:  14672
# Cascade length:  789
# New Orders left:  13883
# making new cascade
#
#
# OG Orders left:  13883
# Cascade length:  1
# New Orders left:  13882
# making new cascade
#
#
# OG Orders left:  13882
# Cascade length:  1176
# New Orders left:  12706
# making new cascade
#
#
# OG Orders left:  12706
# Cascade length:  358
# New Orders left:  12348
# making new cascade
#
#
# OG Orders left:  12348
# Cascade length:  12
# New Orders left:  12336
# making new cascade
#
#
# OG Orders left:  12336
# Cascade length:  980
# New Orders left:  11356
# making new cascade
#
#
# OG Orders left:  11356
# Cascade length:  591
# New Orders left:  10765
# making new cascade
#
#
# OG Orders left:  10765
# Cascade length:  619
# New Orders left:  10146
# making new cascade
#
#
# OG Orders left:  10146
# Cascade length:  54
# New Orders left:  10092
# making new cascade
#
#
# OG Orders left:  10092
# Cascade length:  1
# New Orders left:  10091
# making new cascade
#
#
# OG Orders left:  10091
# Cascade length:  733
# New Orders left:  9358
# making new cascade
#
#
# OG Orders left:  9358
# Cascade length:  459
# New Orders left:  8899
# making new cascade
#
#
# OG Orders left:  8899
# Cascade length:  17
# New Orders left:  8882
# making new cascade
#
#
# OG Orders left:  8882
# Cascade length:  318
# New Orders left:  8564
# making new cascade
#
#
# OG Orders left:  8564
# Cascade length:  662
# New Orders left:  7902
# making new cascade
#
#
# OG Orders left:  7902
# Cascade length:  1
# New Orders left:  7901
# making new cascade
#
#
# OG Orders left:  7901
# Cascade length:  2
# New Orders left:  7899
# making new cascade
#
#
# OG Orders left:  7899
# Cascade length:  66
# New Orders left:  7833
# making new cascade
#
#
# OG Orders left:  7833
# Cascade length:  532
# New Orders left:  7301
# making new cascade
#
#
# OG Orders left:  7301
# Cascade length:  640
# New Orders left:  6661
# making new cascade
#
#
# OG Orders left:  6661
# Cascade length:  475
# New Orders left:  6186
# making new cascade
#
#
# OG Orders left:  6186
# Cascade length:  108
# New Orders left:  6078
# making new cascade
#
#
# OG Orders left:  6078
# Cascade length:  262
# New Orders left:  5816
# making new cascade
#
#
# OG Orders left:  5816
# Cascade length:  156
# New Orders left:  5660
# making new cascade
#
#
# OG Orders left:  5660
# Cascade length:  330
# New Orders left:  5330
# making new cascade
#
#
# OG Orders left:  5330
# Cascade length:  409
# New Orders left:  4921
# making new cascade
#
#
# OG Orders left:  4921
# Cascade length:  5
# New Orders left:  4916
# making new cascade
#
#
# OG Orders left:  4916
# Cascade length:  493
# New Orders left:  4423
# making new cascade
#
#
# OG Orders left:  4423
# Cascade length:  490
# New Orders left:  3933
# making new cascade
#
#
# OG Orders left:  3933
# Cascade length:  1
# New Orders left:  3932
# making new cascade
#
#
# OG Orders left:  3932
# Cascade length:  634
# New Orders left:  3298
# making new cascade
#
#
# OG Orders left:  3298
# Cascade length:  223
# New Orders left:  3075
# making new cascade
#
#
# OG Orders left:  3075
# Cascade length:  171
# New Orders left:  2904
# making new cascade
#
#
# OG Orders left:  2904
# Cascade length:  196
# New Orders left:  2708
# making new cascade
#
#
# OG Orders left:  2708
# Cascade length:  271
# New Orders left:  2437
# making new cascade
#
#
# OG Orders left:  2437
# Cascade length:  55
# New Orders left:  2382
# making new cascade
#
#
# OG Orders left:  2382
# Cascade length:  269
# New Orders left:  2113
# making new cascade
#
#
# OG Orders left:  2113
# Cascade length:  337
# New Orders left:  1776
# making new cascade
#
#
# OG Orders left:  1776
# Cascade length:  182
# New Orders left:  1594
# making new cascade
#
#
# OG Orders left:  1594
# Cascade length:  83
# New Orders left:  1511
# making new cascade
#
#
# OG Orders left:  1511
# Cascade length:  173
# New Orders left:  1338
# making new cascade
#
#
# OG Orders left:  1338
# Cascade length:  63
# New Orders left:  1275
# making new cascade
#
#
# OG Orders left:  1275
# Cascade length:  140
# New Orders left:  1135
# making new cascade
#
#
# OG Orders left:  1135
# Cascade length:  27
# New Orders left:  1108
# making new cascade
#
#
# OG Orders left:  1108
# Cascade length:  1
# New Orders left:  1107
# making new cascade
#
#
# OG Orders left:  1107
# Cascade length:  148
# New Orders left:  959
# making new cascade
#
#
# OG Orders left:  959
# Cascade length:  117
# New Orders left:  842
# making new cascade
#
#
# OG Orders left:  842
# Cascade length:  284
# New Orders left:  558
# making new cascade
#
#
# OG Orders left:  558
# Cascade length:  60
# New Orders left:  498
# making new cascade
#
#
# OG Orders left:  498
# Cascade length:  22
# New Orders left:  476
# making new cascade
#
#
# OG Orders left:  476
# Cascade length:  82
# New Orders left:  394
# making new cascade
#
#
# OG Orders left:  394
# Cascade length:  32
# New Orders left:  362
# making new cascade
#
#
# OG Orders left:  362
# Cascade length:  80
# New Orders left:  282
# making new cascade
#
#
# OG Orders left:  282
# Cascade length:  57
# New Orders left:  225
# making new cascade
#
#
# OG Orders left:  225
# Cascade length:  62
# New Orders left:  163
# making new cascade
#
#
# OG Orders left:  163
# Cascade length:  30
# New Orders left:  133
# making new cascade
#
#
# OG Orders left:  133
# Cascade length:  64
# New Orders left:  69
# making new cascade
#
#
# OG Orders left:  69
# Cascade length:  40
# New Orders left:  29
# making new cascade
#
#
# OG Orders left:  29
# Cascade length:  6
# New Orders left:  23
# making new cascade
#
#
# OG Orders left:  23
# Cascade length:  11
# New Orders left:  12
# making new cascade
#
#
# OG Orders left:  12
# Cascade length:  12
# New Orders left:  0
# making new cascade

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades11_npc_200_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.9)*2, '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8)/10, '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.65)/5, '-.', label= "$x^{-0.65}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
