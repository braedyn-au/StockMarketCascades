# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_501_1000_100_new2threshold_fixedhurst.pkl', 'rb') as f:
    traderIDs = pickle.load(f)

# %%
stockPool = np.load("./results/nopricechange/7-9/stockPool_501_1000_100_new2threshold_fixedhurst.npy")
hurstPool = np.load("./results/nopricechange/7-9/hurstPool_501_1000_100_new2threshold_fixedhurst.npy")
Ttransactions = pd.read_csv("./results/nopricechange/7-9/transactions_501_1000_100_new2threshold_fixedhurst.csv")
TtotalOrders = pd.read_csv("./results/nopricechange/7-9/totalOrders_501_1000_100_new2threshold_fixedhurst.csv")

# %% [markdown]
# # Cascades with time limit

# %%
def findPortfOrderCascades(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold)
    input TtotalOrders, the portfolio, and minimum time
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]
    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        #print(sep)
        #print(max(sep))
        keySep = np.where(sep>maxSep)[0]
        #print(keySep)
        if len(keySep)>0:
            endtime = ToS[keySep[0]] #end of this cascade
        else:
            endtime = ToS[-1]
        portfCascade = portfOrders[portfOrders['time']<=endtime]
        return portfCascade
    else:
        return pd.DataFrame()

# %%
cascades = {}
numCascade = 0
cascadeStocks = {}
cascadePortfs = {}
cascadeTime = {}
cascadeTf = {}
cascades = {}
maxtimeeff = 1
while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
    print("OG Orders left: ", len(TtotalOrders))
    seed = (TtotalOrders.iloc[0]['portfolio'])
    t0 = TtotalOrders.iloc[0]['time']
    seedCascade = findPortfOrderCascades(TtotalOrders, seed, t0, maxSep = 1)
    cascadeStocks[numCascade] = np.asarray(seedCascade['stock'])
    cascadePortfs[numCascade] = np.asarray(seed)
    cascadeTime[numCascade] = t0
    cascades[numCascade] = seedCascade
    stockTimes = {}
    for row in seedCascade.iterrows():
        stockTimes[row[1]['stock']] = row[1]['time'] + abs(row[1]['order'])*maxtimeeff
    assert len(seedCascade) > 0
    TtotalOrders = TtotalOrders[~TtotalOrders.isin(seedCascade)].dropna()
    # NEW VERSION (PORTFOLIO PERSPECTIVE)
    for childPortf in list(TtotalOrders['portfolio'].unique()):
        match = False
        if any(np.isin(cascadeStocks[numCascade],traderIDs[childPortf].stocks)):
#             print("match: ", childPortf)
            if childPortf not in cascadePortfs[numCascade]:
                childPortfCascade = findPortfOrderCascades(TtotalOrders,childPortf,t0, maxSep = 1)
                for row in childPortfCascade.iterrows():
                    if row[1]['stock'] in stockTimes:
                        if row[1]['time'] <= stockTimes[row[1]['stock']]:
                            match = True
                            break 
                if match == True:        
                    cascadePortfs[numCascade] = np.append(cascadePortfs[numCascade], childPortf)
                    cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                    TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
#                     for childStock in list(childPortfCascade['stock'].unique()):
#                         if childStock not in cascadeStocks[numCascade]:
#                             cascadeStocks[numCascade] = np.append(cascadeStocks[numCascade], childStock)
                    for row in childPortfCascade.iterrows():
                        if row[1]['stock'] in stockTimes:
                            stockTimes[row[1]['stock']] += abs(row[1]['order'])*maxtimeeff
                        else:
                            stockTimes[row[1]['stock']] = row[1]['time'] + abs(row[1]['order'])*maxtimeeff
                            cascadeStocks[numCascade] = np.append(cascadeStocks[numCascade], row[1]['stock'])
    print("Cascade length: ",len(cascades[numCascade]))
    print("New Orders left: ", len(TtotalOrders))
    cascadeTf[numCascade] = cascades[numCascade]['time'].max()
    print("making new cascade")
    numCascade += 1
    


    
print(cascadeStocks)
print(cascadePortfs)
print(cascadeTime)
# Out:
# OG Orders left:  909907
# Cascade length:  7379
# New Orders left:  902528
# making new cascade
# OG Orders left:  902528
# Cascade length:  7285
# New Orders left:  895243
# making new cascade
# OG Orders left:  895243
# Cascade length:  7257
# New Orders left:  887986
# making new cascade
# OG Orders left:  887986
# Cascade length:  8
# New Orders left:  887978
# making new cascade
# OG Orders left:  887978
# Cascade length:  7556
# New Orders left:  880422
# making new cascade
# OG Orders left:  880422
# Cascade length:  6633
# New Orders left:  873789
# making new cascade
# OG Orders left:  873789
# Cascade length:  6994
# New Orders left:  866795
# making new cascade
# OG Orders left:  866795
# Cascade length:  6894
# New Orders left:  859901
# making new cascade
# OG Orders left:  859901
# Cascade length:  6884
# New Orders left:  853017
# making new cascade
# OG Orders left:  853017
# Cascade length:  4
# New Orders left:  853013
# making new cascade
# OG Orders left:  853013
# Cascade length:  6802
# New Orders left:  846211
# making new cascade
# OG Orders left:  846211
# Cascade length:  6323
# New Orders left:  839888
# making new cascade
# OG Orders left:  839888
# Cascade length:  6817
# New Orders left:  833071
# making new cascade
# OG Orders left:  833071
# Cascade length:  2
# New Orders left:  833069
# making new cascade
# OG Orders left:  833069
# Cascade length:  6356
# New Orders left:  826713
# making new cascade
# OG Orders left:  826713
# Cascade length:  7
# New Orders left:  826706
# making new cascade
# OG Orders left:  826706
# Cascade length:  5894
# New Orders left:  820812
# making new cascade
# OG Orders left:  820812
# Cascade length:  6053
# New Orders left:  814759
# making new cascade
# OG Orders left:  814759
# Cascade length:  1
# New Orders left:  814758
# making new cascade
# OG Orders left:  814758
# Cascade length:  3
# New Orders left:  814755
# making new cascade
# OG Orders left:  814755
# Cascade length:  3
# New Orders left:  814752
# making new cascade
# OG Orders left:  814752
# Cascade length:  6237
# New Orders left:  808515
# making new cascade
# OG Orders left:  808515
# Cascade length:  3
# New Orders left:  808512
# making new cascade
# OG Orders left:  808512
# Cascade length:  5970
# New Orders left:  802542
# making new cascade
# OG Orders left:  802542
# Cascade length:  6249
# New Orders left:  796293
# making new cascade
# OG Orders left:  796293
# Cascade length:  6
# New Orders left:  796287
# making new cascade
# OG Orders left:  796287
# Cascade length:  4
# New Orders left:  796283
# making new cascade
# OG Orders left:  796283
# Cascade length:  6476
# New Orders left:  789807
# making new cascade
# OG Orders left:  789807
# Cascade length:  3
# New Orders left:  789804
# making new cascade
# OG Orders left:  789804
# Cascade length:  6356
# New Orders left:  783448
# making new cascade
# OG Orders left:  783448
# Cascade length:  6
# New Orders left:  783442
# making new cascade
# OG Orders left:  783442
# Cascade length:  6
# New Orders left:  783436
# making new cascade
# OG Orders left:  783436
# Cascade length:  6279
# New Orders left:  777157
# making new cascade
# OG Orders left:  777157
# Cascade length:  7337
# New Orders left:  769820
# making new cascade
# OG Orders left:  769820
# Cascade length:  6544
# New Orders left:  763276
# making new cascade
# OG Orders left:  763276
# Cascade length:  6100
# New Orders left:  757176
# making new cascade
# OG Orders left:  757176
# Cascade length:  3
# New Orders left:  757173
# making new cascade
# OG Orders left:  757173
# Cascade length:  6295
# New Orders left:  750878
# making new cascade
# OG Orders left:  750878
# Cascade length:  6387
# New Orders left:  744491
# making new cascade
# OG Orders left:  744491
# Cascade length:  6402
# New Orders left:  738089
# making new cascade
# OG Orders left:  738089
# Cascade length:  5842
# New Orders left:  732247
# making new cascade
# OG Orders left:  732247
# Cascade length:  7022
# New Orders left:  725225
# making new cascade
# OG Orders left:  725225
# Cascade length:  5674
# New Orders left:  719551
# making new cascade
# OG Orders left:  719551
# Cascade length:  5649
# New Orders left:  713902
# making new cascade
# OG Orders left:  713902
# Cascade length:  5614
# New Orders left:  708288
# making new cascade
# OG Orders left:  708288
# Cascade length:  5839
# New Orders left:  702449
# making new cascade
# OG Orders left:  702449
# Cascade length:  7
# New Orders left:  702442
# making new cascade
# OG Orders left:  702442
# Cascade length:  8
# New Orders left:  702434
# making new cascade
# OG Orders left:  702434
# Cascade length:  6339
# New Orders left:  696095
# making new cascade
# OG Orders left:  696095
# Cascade length:  16
# New Orders left:  696079
# making new cascade
# OG Orders left:  696079
# Cascade length:  5572
# New Orders left:  690507
# making new cascade
# OG Orders left:  690507
# Cascade length:  14
# New Orders left:  690493
# making new cascade
# OG Orders left:  690493
# Cascade length:  5559
# New Orders left:  684934
# making new cascade
# OG Orders left:  684934
# Cascade length:  2
# New Orders left:  684932
# making new cascade
# OG Orders left:  684932
# Cascade length:  5173
# New Orders left:  679759
# making new cascade
# OG Orders left:  679759
# Cascade length:  10
# New Orders left:  679749
# making new cascade
# OG Orders left:  679749
# Cascade length:  5344
# New Orders left:  674405
# making new cascade
# OG Orders left:  674405
# Cascade length:  11
# New Orders left:  674394
# making new cascade
# OG Orders left:  674394
# Cascade length:  5162
# New Orders left:  669232
# making new cascade
# OG Orders left:  669232
# Cascade length:  2
# New Orders left:  669230
# making new cascade
# OG Orders left:  669230
# Cascade length:  6282
# New Orders left:  662948
# making new cascade
# OG Orders left:  662948
# Cascade length:  2
# New Orders left:  662946
# making new cascade
# OG Orders left:  662946
# Cascade length:  5
# New Orders left:  662941
# making new cascade
# OG Orders left:  662941
# Cascade length:  7
# New Orders left:  662934
# making new cascade
# OG Orders left:  662934
# Cascade length:  1
# New Orders left:  662933
# making new cascade
# OG Orders left:  662933
# Cascade length:  9
# New Orders left:  662924
# making new cascade
# OG Orders left:  662924
# Cascade length:  7
# New Orders left:  662917
# making new cascade
# OG Orders left:  662917
# Cascade length:  5715
# New Orders left:  657202
# making new cascade
# OG Orders left:  657202
# Cascade length:  2
# New Orders left:  657200
# making new cascade
# OG Orders left:  657200
# Cascade length:  34
# New Orders left:  657166
# making new cascade
# OG Orders left:  657166
# Cascade length:  8
# New Orders left:  657158
# making new cascade
# OG Orders left:  657158
# Cascade length:  2
# New Orders left:  657156
# making new cascade
# OG Orders left:  657156
# Cascade length:  10
# New Orders left:  657146
# making new cascade
# OG Orders left:  657146
# Cascade length:  4
# New Orders left:  657142
# making new cascade
# OG Orders left:  657142
# Cascade length:  16
# New Orders left:  657126
# making new cascade
# OG Orders left:  657126
# Cascade length:  3
# New Orders left:  657123
# making new cascade
# OG Orders left:  657123
# Cascade length:  3
# New Orders left:  657120
# making new cascade
# OG Orders left:  657120
# Cascade length:  7
# New Orders left:  657113
# making new cascade
# OG Orders left:  657113
# Cascade length:  3
# New Orders left:  657110
# making new cascade
# OG Orders left:  657110
# Cascade length:  3
# New Orders left:  657107
# making new cascade
# OG Orders left:  657107
# Cascade length:  2
# New Orders left:  657105
# making new cascade
# OG Orders left:  657105
# Cascade length:  3
# New Orders left:  657102
# making new cascade
# OG Orders left:  657102
# Cascade length:  14
# New Orders left:  657088
# making new cascade
# OG Orders left:  657088
# Cascade length:  5583
# New Orders left:  651505
# making new cascade
# OG Orders left:  651505
# Cascade length:  5991
# New Orders left:  645514
# making new cascade
# OG Orders left:  645514
# Cascade length:  19
# New Orders left:  645495
# making new cascade
# OG Orders left:  645495
# Cascade length:  4
# New Orders left:  645491
# making new cascade
# OG Orders left:  645491
# Cascade length:  9
# New Orders left:  645482
# making new cascade
# OG Orders left:  645482
# Cascade length:  20
# New Orders left:  645462
# making new cascade
# OG Orders left:  645462
# Cascade length:  5089
# New Orders left:  640373
# making new cascade
# OG Orders left:  640373
# Cascade length:  14
# New Orders left:  640359
# making new cascade
# OG Orders left:  640359
# Cascade length:  16
# New Orders left:  640343
# making new cascade
# OG Orders left:  640343
# Cascade length:  3
# New Orders left:  640340
# making new cascade
# OG Orders left:  640340
# Cascade length:  1
# New Orders left:  640339
# making new cascade
# OG Orders left:  640339
# Cascade length:  5442
# New Orders left:  634897
# making new cascade
# OG Orders left:  634897
# Cascade length:  5297
# New Orders left:  629600
# making new cascade
# OG Orders left:  629600
# Cascade length:  13
# New Orders left:  629587
# making new cascade
# OG Orders left:  629587
# Cascade length:  5
# New Orders left:  629582
# making new cascade
# OG Orders left:  629582
# Cascade length:  9
# New Orders left:  629573
# making new cascade
# OG Orders left:  629573
# Cascade length:  2
# New Orders left:  629571
# making new cascade
# OG Orders left:  629571
# Cascade length:  15
# New Orders left:  629556
# making new cascade
# OG Orders left:  629556
# Cascade length:  2
# New Orders left:  629554
# making new cascade
# OG Orders left:  629554
# Cascade length:  10
# New Orders left:  629544
# making new cascade
# OG Orders left:  629544
# Cascade length:  3
# New Orders left:  629541
# making new cascade
# OG Orders left:  629541
# Cascade length:  1
# New Orders left:  629540
# making new cascade
# OG Orders left:  629540
# Cascade length:  3
# New Orders left:  629537
# making new cascade
# OG Orders left:  629537
# Cascade length:  4988
# New Orders left:  624549
# making new cascade
# OG Orders left:  624549
# Cascade length:  5431
# New Orders left:  619118
# making new cascade
# OG Orders left:  619118
# Cascade length:  4
# New Orders left:  619114
# making new cascade
# OG Orders left:  619114
# Cascade length:  5587
# New Orders left:  613527
# making new cascade
# OG Orders left:  613527
# Cascade length:  2
# New Orders left:  613525
# making new cascade
# OG Orders left:  613525
# Cascade length:  11
# New Orders left:  613514
# making new cascade
# OG Orders left:  613514
# Cascade length:  1
# New Orders left:  613513
# making new cascade
# OG Orders left:  613513
# Cascade length:  5
# New Orders left:  613508
# making new cascade
# OG Orders left:  613508
# Cascade length:  4835
# New Orders left:  608673
# making new cascade
# OG Orders left:  608673
# Cascade length:  16
# New Orders left:  608657
# making new cascade
# OG Orders left:  608657
# Cascade length:  5161
# New Orders left:  603496
# making new cascade
# OG Orders left:  603496
# Cascade length:  4960
# New Orders left:  598536
# making new cascade
# OG Orders left:  598536
# Cascade length:  11
# New Orders left:  598525
# making new cascade
# OG Orders left:  598525
# Cascade length:  6
# New Orders left:  598519
# making new cascade
# OG Orders left:  598519
# Cascade length:  9
# New Orders left:  598510
# making new cascade
# OG Orders left:  598510
# Cascade length:  2
# New Orders left:  598508
# making new cascade
# OG Orders left:  598508
# Cascade length:  4
# New Orders left:  598504
# making new cascade
# OG Orders left:  598504
# Cascade length:  2
# New Orders left:  598502
# making new cascade
# OG Orders left:  598502
# Cascade length:  3
# New Orders left:  598499
# making new cascade
# OG Orders left:  598499
# Cascade length:  5254
# New Orders left:  593245
# making new cascade
# OG Orders left:  593245
# Cascade length:  7
# New Orders left:  593238
# making new cascade
# OG Orders left:  593238
# Cascade length:  6
# New Orders left:  593232
# making new cascade
# OG Orders left:  593232
# Cascade length:  4715
# New Orders left:  588517
# making new cascade
# OG Orders left:  588517
# Cascade length:  16
# New Orders left:  588501
# making new cascade
# OG Orders left:  588501
# Cascade length:  11
# New Orders left:  588490
# making new cascade
# OG Orders left:  588490
# Cascade length:  3
# New Orders left:  588487
# making new cascade
# OG Orders left:  588487
# Cascade length:  4809
# New Orders left:  583678
# making new cascade
# OG Orders left:  583678
# Cascade length:  3
# New Orders left:  583675
# making new cascade
# OG Orders left:  583675
# Cascade length:  8
# New Orders left:  583667
# making new cascade
# OG Orders left:  583667
# Cascade length:  12
# New Orders left:  583655
# making new cascade
# OG Orders left:  583655
# Cascade length:  13
# New Orders left:  583642
# making new cascade
# OG Orders left:  583642
# Cascade length:  14
# New Orders left:  583628
# making new cascade
# OG Orders left:  583628
# Cascade length:  5
# New Orders left:  583623
# making new cascade
# OG Orders left:  583623
# Cascade length:  4211
# New Orders left:  579412
# making new cascade
# OG Orders left:  579412
# Cascade length:  4
# New Orders left:  579408
# making new cascade
# OG Orders left:  579408
# Cascade length:  3
# New Orders left:  579405
# making new cascade
# OG Orders left:  579405
# Cascade length:  4723
# New Orders left:  574682
# making new cascade
# OG Orders left:  574682
# Cascade length:  7
# New Orders left:  574675
# making new cascade
# OG Orders left:  574675
# Cascade length:  11
# New Orders left:  574664
# making new cascade
# OG Orders left:  574664
# Cascade length:  4538
# New Orders left:  570126
# making new cascade
# OG Orders left:  570126
# Cascade length:  18
# New Orders left:  570108
# making new cascade
# OG Orders left:  570108
# Cascade length:  4488
# New Orders left:  565620
# making new cascade
# OG Orders left:  565620
# Cascade length:  10
# New Orders left:  565610
# making new cascade
# OG Orders left:  565610
# Cascade length:  4528
# New Orders left:  561082
# making new cascade
# OG Orders left:  561082
# Cascade length:  5
# New Orders left:  561077
# making new cascade
# OG Orders left:  561077
# Cascade length:  2
# New Orders left:  561075
# making new cascade
# OG Orders left:  561075
# Cascade length:  1
# New Orders left:  561074
# making new cascade
# OG Orders left:  561074
# Cascade length:  4464
# New Orders left:  556610
# making new cascade
# OG Orders left:  556610
# Cascade length:  9
# New Orders left:  556601
# making new cascade
# OG Orders left:  556601
# Cascade length:  18
# New Orders left:  556583
# making new cascade
# OG Orders left:  556583
# Cascade length:  22
# New Orders left:  556561
# making new cascade
# OG Orders left:  556561
# Cascade length:  1
# New Orders left:  556560
# making new cascade
# OG Orders left:  556560
# Cascade length:  4667
# New Orders left:  551893
# making new cascade
# OG Orders left:  551893
# Cascade length:  18
# New Orders left:  551875
# making new cascade
# OG Orders left:  551875
# Cascade length:  39
# New Orders left:  551836
# making new cascade
# OG Orders left:  551836
# Cascade length:  27
# New Orders left:  551809
# making new cascade
# OG Orders left:  551809
# Cascade length:  22
# New Orders left:  551787
# making new cascade
# OG Orders left:  551787
# Cascade length:  29
# New Orders left:  551758
# making new cascade
# OG Orders left:  551758
# Cascade length:  4736
# New Orders left:  547022
# making new cascade
# OG Orders left:  547022
# Cascade length:  8
# New Orders left:  547014
# making new cascade
# OG Orders left:  547014
# Cascade length:  4357
# New Orders left:  542657
# making new cascade
# OG Orders left:  542657
# Cascade length:  2
# New Orders left:  542655
# making new cascade
# OG Orders left:  542655
# Cascade length:  15
# New Orders left:  542640
# making new cascade
# OG Orders left:  542640
# Cascade length:  11
# New Orders left:  542629
# making new cascade
# OG Orders left:  542629
# Cascade length:  14
# New Orders left:  542615
# making new cascade
# OG Orders left:  542615
# Cascade length:  39
# New Orders left:  542576
# making new cascade
# OG Orders left:  542576
# Cascade length:  21
# New Orders left:  542555
# making new cascade
# OG Orders left:  542555
# Cascade length:  4073
# New Orders left:  538482
# making new cascade
# OG Orders left:  538482
# Cascade length:  12
# New Orders left:  538470
# making new cascade
# OG Orders left:  538470
# Cascade length:  4214
# New Orders left:  534256
# making new cascade
# OG Orders left:  534256
# Cascade length:  3771
# New Orders left:  530485
# making new cascade
# OG Orders left:  530485
# Cascade length:  3
# New Orders left:  530482
# making new cascade
# OG Orders left:  530482
# Cascade length:  4557
# New Orders left:  525925
# making new cascade
# OG Orders left:  525925
# Cascade length:  4150
# New Orders left:  521775
# making new cascade
# OG Orders left:  521775
# Cascade length:  4485
# New Orders left:  517290
# making new cascade
# OG Orders left:  517290
# Cascade length:  15
# New Orders left:  517275
# making new cascade
# OG Orders left:  517275
# Cascade length:  10
# New Orders left:  517265
# making new cascade
# OG Orders left:  517265
# Cascade length:  4050
# New Orders left:  513215
# making new cascade
# OG Orders left:  513215
# Cascade length:  2
# New Orders left:  513213
# making new cascade
# OG Orders left:  513213
# Cascade length:  3
# New Orders left:  513210
# making new cascade
# OG Orders left:  513210
# Cascade length:  3779
# New Orders left:  509431
# making new cascade
# OG Orders left:  509431
# Cascade length:  12
# New Orders left:  509419
# making new cascade
# OG Orders left:  509419
# Cascade length:  105
# New Orders left:  509314
# making new cascade
# OG Orders left:  509314
# Cascade length:  3782
# New Orders left:  505532
# making new cascade
# OG Orders left:  505532
# Cascade length:  4084
# New Orders left:  501448
# making new cascade
# OG Orders left:  501448
# Cascade length:  10
# New Orders left:  501438
# making new cascade
# OG Orders left:  501438
# Cascade length:  20
# New Orders left:  501418
# making new cascade
# OG Orders left:  501418
# Cascade length:  13
# New Orders left:  501405
# making new cascade
# OG Orders left:  501405
# Cascade length:  3694
# New Orders left:  497711
# making new cascade
# OG Orders left:  497711
# Cascade length:  4013
# New Orders left:  493698
# making new cascade
# OG Orders left:  493698
# Cascade length:  2
# New Orders left:  493696
# making new cascade
# OG Orders left:  493696
# Cascade length:  22
# New Orders left:  493674
# making new cascade
# OG Orders left:  493674
# Cascade length:  4650
# New Orders left:  489024
# making new cascade
# OG Orders left:  489024
# Cascade length:  7
# New Orders left:  489017
# making new cascade
# OG Orders left:  489017
# Cascade length:  9
# New Orders left:  489008
# making new cascade
# OG Orders left:  489008
# Cascade length:  10
# New Orders left:  488998
# making new cascade
# OG Orders left:  488998
# Cascade length:  4027
# New Orders left:  484971
# making new cascade
# OG Orders left:  484971
# Cascade length:  8
# New Orders left:  484963
# making new cascade
# OG Orders left:  484963
# Cascade length:  13
# New Orders left:  484950
# making new cascade
# OG Orders left:  484950
# Cascade length:  7
# New Orders left:  484943
# making new cascade
# OG Orders left:  484943
# Cascade length:  3781
# New Orders left:  481162
# making new cascade
# OG Orders left:  481162
# Cascade length:  15
# New Orders left:  481147
# making new cascade
# OG Orders left:  481147
# Cascade length:  2
# New Orders left:  481145
# making new cascade
# OG Orders left:  481145
# Cascade length:  4202
# New Orders left:  476943
# making new cascade
# OG Orders left:  476943
# Cascade length:  4122
# New Orders left:  472821
# making new cascade
# OG Orders left:  472821
# Cascade length:  19
# New Orders left:  472802
# making new cascade
# OG Orders left:  472802
# Cascade length:  22
# New Orders left:  472780
# making new cascade
# OG Orders left:  472780
# Cascade length:  3930
# New Orders left:  468850
# making new cascade
# OG Orders left:  468850
# Cascade length:  34
# New Orders left:  468816
# making new cascade
# OG Orders left:  468816
# Cascade length:  48
# New Orders left:  468768
# making new cascade
# OG Orders left:  468768
# Cascade length:  3993
# New Orders left:  464775
# making new cascade
# OG Orders left:  464775
# Cascade length:  16
# New Orders left:  464759
# making new cascade
# OG Orders left:  464759
# Cascade length:  4021
# New Orders left:  460738
# making new cascade
# OG Orders left:  460738
# Cascade length:  4028
# New Orders left:  456710
# making new cascade
# OG Orders left:  456710
# Cascade length:  41
# New Orders left:  456669
# making new cascade
# OG Orders left:  456669
# Cascade length:  4
# New Orders left:  456665
# making new cascade
# OG Orders left:  456665
# Cascade length:  8
# New Orders left:  456657
# making new cascade
# OG Orders left:  456657
# Cascade length:  4026
# New Orders left:  452631
# making new cascade
# OG Orders left:  452631
# Cascade length:  43
# New Orders left:  452588
# making new cascade
# OG Orders left:  452588
# Cascade length:  4
# New Orders left:  452584
# making new cascade
# OG Orders left:  452584
# Cascade length:  4
# New Orders left:  452580
# making new cascade
# OG Orders left:  452580
# Cascade length:  4239
# New Orders left:  448341
# making new cascade
# OG Orders left:  448341
# Cascade length:  35
# New Orders left:  448306
# making new cascade
# OG Orders left:  448306
# Cascade length:  4146
# New Orders left:  444160
# making new cascade
# OG Orders left:  444160
# Cascade length:  49
# New Orders left:  444111
# making new cascade
# OG Orders left:  444111
# Cascade length:  3832
# New Orders left:  440279
# making new cascade
# OG Orders left:  440279
# Cascade length:  3945
# New Orders left:  436334
# making new cascade
# OG Orders left:  436334
# Cascade length:  1
# New Orders left:  436333
# making new cascade
# OG Orders left:  436333
# Cascade length:  3703
# New Orders left:  432630
# making new cascade
# OG Orders left:  432630
# Cascade length:  2
# New Orders left:  432628
# making new cascade
# OG Orders left:  432628
# Cascade length:  2
# New Orders left:  432626
# making new cascade
# OG Orders left:  432626
# Cascade length:  1
# New Orders left:  432625
# making new cascade
# OG Orders left:  432625
# Cascade length:  3
# New Orders left:  432622
# making new cascade
# OG Orders left:  432622
# Cascade length:  3965
# New Orders left:  428657
# making new cascade
# OG Orders left:  428657
# Cascade length:  3619
# New Orders left:  425038
# making new cascade
# OG Orders left:  425038
# Cascade length:  6
# New Orders left:  425032
# making new cascade
# OG Orders left:  425032
# Cascade length:  4167
# New Orders left:  420865
# making new cascade
# OG Orders left:  420865
# Cascade length:  5
# New Orders left:  420860
# making new cascade
# OG Orders left:  420860
# Cascade length:  3759
# New Orders left:  417101
# making new cascade
# OG Orders left:  417101
# Cascade length:  3617
# New Orders left:  413484
# making new cascade
# OG Orders left:  413484
# Cascade length:  3579
# New Orders left:  409905
# making new cascade
# OG Orders left:  409905
# Cascade length:  47
# New Orders left:  409858
# making new cascade
# OG Orders left:  409858
# Cascade length:  8
# New Orders left:  409850
# making new cascade
# OG Orders left:  409850
# Cascade length:  3550
# New Orders left:  406300
# making new cascade
# OG Orders left:  406300
# Cascade length:  9
# New Orders left:  406291
# making new cascade
# OG Orders left:  406291
# Cascade length:  3264
# New Orders left:  403027
# making new cascade
# OG Orders left:  403027
# Cascade length:  40
# New Orders left:  402987
# making new cascade
# OG Orders left:  402987
# Cascade length:  4
# New Orders left:  402983
# making new cascade
# OG Orders left:  402983
# Cascade length:  3268
# New Orders left:  399715
# making new cascade
# OG Orders left:  399715
# Cascade length:  48
# New Orders left:  399667
# making new cascade
# OG Orders left:  399667
# Cascade length:  8
# New Orders left:  399659
# making new cascade
# OG Orders left:  399659
# Cascade length:  3278
# New Orders left:  396381
# making new cascade
# OG Orders left:  396381
# Cascade length:  1
# New Orders left:  396380
# making new cascade
# OG Orders left:  396380
# Cascade length:  3057
# New Orders left:  393323
# making new cascade
# OG Orders left:  393323
# Cascade length:  3242
# New Orders left:  390081
# making new cascade
# OG Orders left:  390081
# Cascade length:  13
# New Orders left:  390068
# making new cascade
# OG Orders left:  390068
# Cascade length:  15
# New Orders left:  390053
# making new cascade
# OG Orders left:  390053
# Cascade length:  4
# New Orders left:  390049
# making new cascade
# OG Orders left:  390049
# Cascade length:  2780
# New Orders left:  387269
# making new cascade
# OG Orders left:  387269
# Cascade length:  17
# New Orders left:  387252
# making new cascade
# OG Orders left:  387252
# Cascade length:  2
# New Orders left:  387250
# making new cascade
# OG Orders left:  387250
# Cascade length:  3411
# New Orders left:  383839
# making new cascade
# OG Orders left:  383839
# Cascade length:  1
# New Orders left:  383838
# making new cascade
# OG Orders left:  383838
# Cascade length:  25
# New Orders left:  383813
# making new cascade
# OG Orders left:  383813
# Cascade length:  2876
# New Orders left:  380937
# making new cascade
# OG Orders left:  380937
# Cascade length:  5
# New Orders left:  380932
# making new cascade
# OG Orders left:  380932
# Cascade length:  3045
# New Orders left:  377887
# making new cascade
# OG Orders left:  377887
# Cascade length:  20
# New Orders left:  377867
# making new cascade
# OG Orders left:  377867
# Cascade length:  2831
# New Orders left:  375036
# making new cascade
# OG Orders left:  375036
# Cascade length:  28
# New Orders left:  375008
# making new cascade
# OG Orders left:  375008
# Cascade length:  2943
# New Orders left:  372065
# making new cascade
# OG Orders left:  372065
# Cascade length:  14
# New Orders left:  372051
# making new cascade
# OG Orders left:  372051
# Cascade length:  1
# New Orders left:  372050
# making new cascade
# OG Orders left:  372050
# Cascade length:  146
# New Orders left:  371904
# making new cascade
# OG Orders left:  371904
# Cascade length:  3198
# New Orders left:  368706
# making new cascade
# OG Orders left:  368706
# Cascade length:  2252
# New Orders left:  366454
# making new cascade
# OG Orders left:  366454
# Cascade length:  15
# New Orders left:  366439
# making new cascade
# OG Orders left:  366439
# Cascade length:  2793
# New Orders left:  363646
# making new cascade
# OG Orders left:  363646
# Cascade length:  1
# New Orders left:  363645
# making new cascade
# OG Orders left:  363645
# Cascade length:  2950
# New Orders left:  360695
# making new cascade
# OG Orders left:  360695
# Cascade length:  2
# New Orders left:  360693
# making new cascade
# OG Orders left:  360693
# Cascade length:  2617
# New Orders left:  358076
# making new cascade
# OG Orders left:  358076
# Cascade length:  1
# New Orders left:  358075
# making new cascade
# OG Orders left:  358075
# Cascade length:  2999
# New Orders left:  355076
# making new cascade
# OG Orders left:  355076
# Cascade length:  2761
# New Orders left:  352315
# making new cascade
# OG Orders left:  352315
# Cascade length:  20
# New Orders left:  352295
# making new cascade
# OG Orders left:  352295
# Cascade length:  8
# New Orders left:  352287
# making new cascade
# OG Orders left:  352287
# Cascade length:  6
# New Orders left:  352281
# making new cascade
# OG Orders left:  352281
# Cascade length:  2933
# New Orders left:  349348
# making new cascade
# OG Orders left:  349348
# Cascade length:  7
# New Orders left:  349341
# making new cascade
# OG Orders left:  349341
# Cascade length:  4
# New Orders left:  349337
# making new cascade
# OG Orders left:  349337
# Cascade length:  2846
# New Orders left:  346491
# making new cascade
# OG Orders left:  346491
# Cascade length:  2704
# New Orders left:  343787
# making new cascade
# OG Orders left:  343787
# Cascade length:  3
# New Orders left:  343784
# making new cascade
# OG Orders left:  343784
# Cascade length:  11
# New Orders left:  343773
# making new cascade
# OG Orders left:  343773
# Cascade length:  10
# New Orders left:  343763
# making new cascade
# OG Orders left:  343763
# Cascade length:  65
# New Orders left:  343698
# making new cascade
# OG Orders left:  343698
# Cascade length:  2
# New Orders left:  343696
# making new cascade
# OG Orders left:  343696
# Cascade length:  2356
# New Orders left:  341340
# making new cascade
# OG Orders left:  341340
# Cascade length:  48
# New Orders left:  341292
# making new cascade
# OG Orders left:  341292
# Cascade length:  15
# New Orders left:  341277
# making new cascade
# OG Orders left:  341277
# Cascade length:  12
# New Orders left:  341265
# making new cascade
# OG Orders left:  341265
# Cascade length:  25
# New Orders left:  341240
# making new cascade
# OG Orders left:  341240
# Cascade length:  33
# New Orders left:  341207
# making new cascade
# OG Orders left:  341207
# Cascade length:  6
# New Orders left:  341201
# making new cascade
# OG Orders left:  341201
# Cascade length:  2
# New Orders left:  341199
# making new cascade
# OG Orders left:  341199
# Cascade length:  6
# New Orders left:  341193
# making new cascade
# OG Orders left:  341193
# Cascade length:  2
# New Orders left:  341191
# making new cascade
# OG Orders left:  341191
# Cascade length:  38
# New Orders left:  341153
# making new cascade
# OG Orders left:  341153
# Cascade length:  2
# New Orders left:  341151
# making new cascade
# OG Orders left:  341151
# Cascade length:  24
# New Orders left:  341127
# making new cascade
# OG Orders left:  341127
# Cascade length:  15
# New Orders left:  341112
# making new cascade
# OG Orders left:  341112
# Cascade length:  2812
# New Orders left:  338300
# making new cascade
# OG Orders left:  338300
# Cascade length:  5
# New Orders left:  338295
# making new cascade
# OG Orders left:  338295
# Cascade length:  2
# New Orders left:  338293
# making new cascade
# OG Orders left:  338293
# Cascade length:  2
# New Orders left:  338291
# making new cascade
# OG Orders left:  338291
# Cascade length:  2
# New Orders left:  338289
# making new cascade
# OG Orders left:  338289
# Cascade length:  2731
# New Orders left:  335558
# making new cascade
# OG Orders left:  335558
# Cascade length:  2168
# New Orders left:  333390
# making new cascade
# OG Orders left:  333390
# Cascade length:  14
# New Orders left:  333376
# making new cascade
# OG Orders left:  333376
# Cascade length:  11
# New Orders left:  333365
# making new cascade
# OG Orders left:  333365
# Cascade length:  2479
# New Orders left:  330886
# making new cascade
# OG Orders left:  330886
# Cascade length:  2082
# New Orders left:  328804
# making new cascade
# OG Orders left:  328804
# Cascade length:  21
# New Orders left:  328783
# making new cascade
# OG Orders left:  328783
# Cascade length:  1975
# New Orders left:  326808
# making new cascade
# OG Orders left:  326808
# Cascade length:  32
# New Orders left:  326776
# making new cascade
# OG Orders left:  326776
# Cascade length:  1980
# New Orders left:  324796
# making new cascade
# OG Orders left:  324796
# Cascade length:  8
# New Orders left:  324788
# making new cascade
# OG Orders left:  324788
# Cascade length:  2855
# New Orders left:  321933
# making new cascade
# OG Orders left:  321933
# Cascade length:  1877
# New Orders left:  320056
# making new cascade
# OG Orders left:  320056
# Cascade length:  74
# New Orders left:  319982
# making new cascade
# OG Orders left:  319982
# Cascade length:  1
# New Orders left:  319981
# making new cascade
# OG Orders left:  319981
# Cascade length:  2924
# New Orders left:  317057
# making new cascade
# OG Orders left:  317057
# Cascade length:  2934
# New Orders left:  314123
# making new cascade
# OG Orders left:  314123
# Cascade length:  28
# New Orders left:  314095
# making new cascade
# OG Orders left:  314095
# Cascade length:  2616
# New Orders left:  311479
# making new cascade
# OG Orders left:  311479
# Cascade length:  108
# New Orders left:  311371
# making new cascade
# OG Orders left:  311371
# Cascade length:  26
# New Orders left:  311345
# making new cascade
# OG Orders left:  311345
# Cascade length:  175
# New Orders left:  311170
# making new cascade
# OG Orders left:  311170
# Cascade length:  18
# New Orders left:  311152
# making new cascade
# OG Orders left:  311152
# Cascade length:  2621
# New Orders left:  308531
# making new cascade
# OG Orders left:  308531
# Cascade length:  2696
# New Orders left:  305835
# making new cascade
# OG Orders left:  305835
# Cascade length:  2012
# New Orders left:  303823
# making new cascade
# OG Orders left:  303823
# Cascade length:  5
# New Orders left:  303818
# making new cascade
# OG Orders left:  303818
# Cascade length:  101
# New Orders left:  303717
# making new cascade
# OG Orders left:  303717
# Cascade length:  5
# New Orders left:  303712
# making new cascade
# OG Orders left:  303712
# Cascade length:  23
# New Orders left:  303689
# making new cascade
# OG Orders left:  303689
# Cascade length:  2674
# New Orders left:  301015
# making new cascade
# OG Orders left:  301015
# Cascade length:  8
# New Orders left:  301007
# making new cascade
# OG Orders left:  301007
# Cascade length:  2406
# New Orders left:  298601
# making new cascade
# OG Orders left:  298601
# Cascade length:  2851
# New Orders left:  295750
# making new cascade
# OG Orders left:  295750
# Cascade length:  10
# New Orders left:  295740
# making new cascade
# OG Orders left:  295740
# Cascade length:  1
# New Orders left:  295739
# making new cascade
# OG Orders left:  295739
# Cascade length:  2346
# New Orders left:  293393
# making new cascade
# OG Orders left:  293393
# Cascade length:  2694
# New Orders left:  290699
# making new cascade
# OG Orders left:  290699
# Cascade length:  2494
# New Orders left:  288205
# making new cascade
# OG Orders left:  288205
# Cascade length:  13
# New Orders left:  288192
# making new cascade
# OG Orders left:  288192
# Cascade length:  3
# New Orders left:  288189
# making new cascade
# OG Orders left:  288189
# Cascade length:  4
# New Orders left:  288185
# making new cascade
# OG Orders left:  288185
# Cascade length:  3
# New Orders left:  288182
# making new cascade
# OG Orders left:  288182
# Cascade length:  67
# New Orders left:  288115
# making new cascade
# OG Orders left:  288115
# Cascade length:  18
# New Orders left:  288097
# making new cascade
# OG Orders left:  288097
# Cascade length:  28
# New Orders left:  288069
# making new cascade
# OG Orders left:  288069
# Cascade length:  53
# New Orders left:  288016
# making new cascade
# OG Orders left:  288016
# Cascade length:  6
# New Orders left:  288010
# making new cascade
# OG Orders left:  288010
# Cascade length:  4
# New Orders left:  288006
# making new cascade
# OG Orders left:  288006
# Cascade length:  10
# New Orders left:  287996
# making new cascade
# OG Orders left:  287996
# Cascade length:  2
# New Orders left:  287994
# making new cascade
# OG Orders left:  287994
# Cascade length:  28
# New Orders left:  287966
# making new cascade
# OG Orders left:  287966
# Cascade length:  2783
# New Orders left:  285183
# making new cascade
# OG Orders left:  285183
# Cascade length:  11
# New Orders left:  285172
# making new cascade
# OG Orders left:  285172
# Cascade length:  2386
# New Orders left:  282786
# making new cascade
# OG Orders left:  282786
# Cascade length:  2
# New Orders left:  282784
# making new cascade
# OG Orders left:  282784
# Cascade length:  3
# New Orders left:  282781
# making new cascade
# OG Orders left:  282781
# Cascade length:  45
# New Orders left:  282736
# making new cascade
# OG Orders left:  282736
# Cascade length:  9
# New Orders left:  282727
# making new cascade
# OG Orders left:  282727
# Cascade length:  2904
# New Orders left:  279823
# making new cascade
# OG Orders left:  279823
# Cascade length:  17
# New Orders left:  279806
# making new cascade
# OG Orders left:  279806
# Cascade length:  3
# New Orders left:  279803
# making new cascade
# OG Orders left:  279803
# Cascade length:  2800
# New Orders left:  277003
# making new cascade
# OG Orders left:  277003
# Cascade length:  9
# New Orders left:  276994
# making new cascade
# OG Orders left:  276994
# Cascade length:  2580
# New Orders left:  274414
# making new cascade
# OG Orders left:  274414
# Cascade length:  24
# New Orders left:  274390
# making new cascade
# OG Orders left:  274390
# Cascade length:  2800
# New Orders left:  271590
# making new cascade
# OG Orders left:  271590
# Cascade length:  2774
# New Orders left:  268816
# making new cascade
# OG Orders left:  268816
# Cascade length:  4
# New Orders left:  268812
# making new cascade
# OG Orders left:  268812
# Cascade length:  2584
# New Orders left:  266228
# making new cascade
# OG Orders left:  266228
# Cascade length:  2896
# New Orders left:  263332
# making new cascade
# OG Orders left:  263332
# Cascade length:  1
# New Orders left:  263331
# making new cascade
# OG Orders left:  263331
# Cascade length:  10
# New Orders left:  263321
# making new cascade
# OG Orders left:  263321
# Cascade length:  1
# New Orders left:  263320
# making new cascade
# OG Orders left:  263320
# Cascade length:  2034
# New Orders left:  261286
# making new cascade
# OG Orders left:  261286
# Cascade length:  13
# New Orders left:  261273
# making new cascade
# OG Orders left:  261273
# Cascade length:  2730
# New Orders left:  258543
# making new cascade
# OG Orders left:  258543
# Cascade length:  9
# New Orders left:  258534
# making new cascade
# OG Orders left:  258534
# Cascade length:  2664
# New Orders left:  255870
# making new cascade
# OG Orders left:  255870
# Cascade length:  3
# New Orders left:  255867
# making new cascade
# OG Orders left:  255867
# Cascade length:  2290
# New Orders left:  253577
# making new cascade
# OG Orders left:  253577
# Cascade length:  18
# New Orders left:  253559
# making new cascade
# OG Orders left:  253559
# Cascade length:  36
# New Orders left:  253523
# making new cascade
# OG Orders left:  253523
# Cascade length:  2461
# New Orders left:  251062
# making new cascade
# OG Orders left:  251062
# Cascade length:  1940
# New Orders left:  249122
# making new cascade
# OG Orders left:  249122
# Cascade length:  103
# New Orders left:  249019
# making new cascade
# OG Orders left:  249019
# Cascade length:  2
# New Orders left:  249017
# making new cascade
# OG Orders left:  249017
# Cascade length:  85
# New Orders left:  248932
# making new cascade
# OG Orders left:  248932
# Cascade length:  26
# New Orders left:  248906
# making new cascade
# OG Orders left:  248906
# Cascade length:  43
# New Orders left:  248863
# making new cascade
# OG Orders left:  248863
# Cascade length:  34
# New Orders left:  248829
# making new cascade
# OG Orders left:  248829
# Cascade length:  3
# New Orders left:  248826
# making new cascade
# OG Orders left:  248826
# Cascade length:  39
# New Orders left:  248787
# making new cascade
# OG Orders left:  248787
# Cascade length:  126
# New Orders left:  248661
# making new cascade
# OG Orders left:  248661
# Cascade length:  4
# New Orders left:  248657
# making new cascade
# OG Orders left:  248657
# Cascade length:  13
# New Orders left:  248644
# making new cascade
# OG Orders left:  248644
# Cascade length:  44
# New Orders left:  248600
# making new cascade
# OG Orders left:  248600
# Cascade length:  2151
# New Orders left:  246449
# making new cascade
# OG Orders left:  246449
# Cascade length:  8
# New Orders left:  246441
# making new cascade
# OG Orders left:  246441
# Cascade length:  1822
# New Orders left:  244619
# making new cascade
# OG Orders left:  244619
# Cascade length:  119
# New Orders left:  244500
# making new cascade
# OG Orders left:  244500
# Cascade length:  10
# New Orders left:  244490
# making new cascade
# OG Orders left:  244490
# Cascade length:  4
# New Orders left:  244486
# making new cascade
# OG Orders left:  244486
# Cascade length:  1831
# New Orders left:  242655
# making new cascade
# OG Orders left:  242655
# Cascade length:  2658
# New Orders left:  239997
# making new cascade
# OG Orders left:  239997
# Cascade length:  2497
# New Orders left:  237500
# making new cascade
# OG Orders left:  237500
# Cascade length:  9
# New Orders left:  237491
# making new cascade
# OG Orders left:  237491
# Cascade length:  4
# New Orders left:  237487
# making new cascade
# OG Orders left:  237487
# Cascade length:  8
# New Orders left:  237479
# making new cascade
# OG Orders left:  237479
# Cascade length:  1826
# New Orders left:  235653
# making new cascade
# OG Orders left:  235653
# Cascade length:  193
# New Orders left:  235460
# making new cascade
# OG Orders left:  235460
# Cascade length:  4
# New Orders left:  235456
# making new cascade
# OG Orders left:  235456
# Cascade length:  2975
# New Orders left:  232481
# making new cascade
# OG Orders left:  232481
# Cascade length:  80
# New Orders left:  232401
# making new cascade
# OG Orders left:  232401
# Cascade length:  13
# New Orders left:  232388
# making new cascade
# OG Orders left:  232388
# Cascade length:  44
# New Orders left:  232344
# making new cascade
# OG Orders left:  232344
# Cascade length:  2
# New Orders left:  232342
# making new cascade
# OG Orders left:  232342
# Cascade length:  34
# New Orders left:  232308
# making new cascade
# OG Orders left:  232308
# Cascade length:  6
# New Orders left:  232302
# making new cascade
# OG Orders left:  232302
# Cascade length:  1
# New Orders left:  232301
# making new cascade
# OG Orders left:  232301
# Cascade length:  24
# New Orders left:  232277
# making new cascade
# OG Orders left:  232277
# Cascade length:  29
# New Orders left:  232248
# making new cascade
# OG Orders left:  232248
# Cascade length:  8
# New Orders left:  232240
# making new cascade
# OG Orders left:  232240
# Cascade length:  1844
# New Orders left:  230396
# making new cascade
# OG Orders left:  230396
# Cascade length:  24
# New Orders left:  230372
# making new cascade
# OG Orders left:  230372
# Cascade length:  16
# New Orders left:  230356
# making new cascade
# OG Orders left:  230356
# Cascade length:  3
# New Orders left:  230353
# making new cascade
# OG Orders left:  230353
# Cascade length:  43
# New Orders left:  230310
# making new cascade
# OG Orders left:  230310
# Cascade length:  2183
# New Orders left:  228127
# making new cascade
# OG Orders left:  228127
# Cascade length:  19
# New Orders left:  228108
# making new cascade
# OG Orders left:  228108
# Cascade length:  2104
# New Orders left:  226004
# making new cascade
# OG Orders left:  226004
# Cascade length:  6
# New Orders left:  225998
# making new cascade
# OG Orders left:  225998
# Cascade length:  1253
# New Orders left:  224745
# making new cascade
# OG Orders left:  224745
# Cascade length:  6
# New Orders left:  224739
# making new cascade
# OG Orders left:  224739
# Cascade length:  2012
# New Orders left:  222727
# making new cascade
# OG Orders left:  222727
# Cascade length:  5
# New Orders left:  222722
# making new cascade
# OG Orders left:  222722
# Cascade length:  1276
# New Orders left:  221446
# making new cascade
# OG Orders left:  221446
# Cascade length:  16
# New Orders left:  221430
# making new cascade
# OG Orders left:  221430
# Cascade length:  14
# New Orders left:  221416
# making new cascade
# OG Orders left:  221416
# Cascade length:  2360
# New Orders left:  219056
# making new cascade
# OG Orders left:  219056
# Cascade length:  2
# New Orders left:  219054
# making new cascade
# OG Orders left:  219054
# Cascade length:  2453
# New Orders left:  216601
# making new cascade
# OG Orders left:  216601
# Cascade length:  23
# New Orders left:  216578
# making new cascade
# OG Orders left:  216578
# Cascade length:  6
# New Orders left:  216572
# making new cascade
# OG Orders left:  216572
# Cascade length:  4
# New Orders left:  216568
# making new cascade
# OG Orders left:  216568
# Cascade length:  3
# New Orders left:  216565
# making new cascade
# OG Orders left:  216565
# Cascade length:  2
# New Orders left:  216563
# making new cascade
# OG Orders left:  216563
# Cascade length:  20
# New Orders left:  216543
# making new cascade
# OG Orders left:  216543
# Cascade length:  11
# New Orders left:  216532
# making new cascade
# OG Orders left:  216532
# Cascade length:  60
# New Orders left:  216472
# making new cascade
# OG Orders left:  216472
# Cascade length:  2
# New Orders left:  216470
# making new cascade
# OG Orders left:  216470
# Cascade length:  17
# New Orders left:  216453
# making new cascade
# OG Orders left:  216453
# Cascade length:  1
# New Orders left:  216452
# making new cascade
# OG Orders left:  216452
# Cascade length:  4
# New Orders left:  216448
# making new cascade
# OG Orders left:  216448
# Cascade length:  2065
# New Orders left:  214383
# making new cascade
# OG Orders left:  214383
# Cascade length:  2
# New Orders left:  214381
# making new cascade
# OG Orders left:  214381
# Cascade length:  133
# New Orders left:  214248
# making new cascade
# OG Orders left:  214248
# Cascade length:  19
# New Orders left:  214229
# making new cascade
# OG Orders left:  214229
# Cascade length:  6
# New Orders left:  214223
# making new cascade
# OG Orders left:  214223
# Cascade length:  2680
# New Orders left:  211543
# making new cascade
# OG Orders left:  211543
# Cascade length:  2333
# New Orders left:  209210
# making new cascade
# OG Orders left:  209210
# Cascade length:  6
# New Orders left:  209204
# making new cascade
# OG Orders left:  209204
# Cascade length:  4
# New Orders left:  209200
# making new cascade
# OG Orders left:  209200
# Cascade length:  9
# New Orders left:  209191
# making new cascade
# OG Orders left:  209191
# Cascade length:  2662
# New Orders left:  206529
# making new cascade
# OG Orders left:  206529
# Cascade length:  18
# New Orders left:  206511
# making new cascade
# OG Orders left:  206511
# Cascade length:  4
# New Orders left:  206507
# making new cascade
# OG Orders left:  206507
# Cascade length:  1447
# New Orders left:  205060
# making new cascade
# OG Orders left:  205060
# Cascade length:  1723
# New Orders left:  203337
# making new cascade
# OG Orders left:  203337
# Cascade length:  115
# New Orders left:  203222
# making new cascade
# OG Orders left:  203222
# Cascade length:  9
# New Orders left:  203213
# making new cascade
# OG Orders left:  203213
# Cascade length:  20
# New Orders left:  203193
# making new cascade
# OG Orders left:  203193
# Cascade length:  2105
# New Orders left:  201088
# making new cascade
# OG Orders left:  201088
# Cascade length:  1
# New Orders left:  201087
# making new cascade
# OG Orders left:  201087
# Cascade length:  10
# New Orders left:  201077
# making new cascade
# OG Orders left:  201077
# Cascade length:  2
# New Orders left:  201075
# making new cascade
# OG Orders left:  201075
# Cascade length:  3
# New Orders left:  201072
# making new cascade
# OG Orders left:  201072
# Cascade length:  1964
# New Orders left:  199108
# making new cascade
# OG Orders left:  199108
# Cascade length:  37
# New Orders left:  199071
# making new cascade
# OG Orders left:  199071
# Cascade length:  4
# New Orders left:  199067
# making new cascade
# OG Orders left:  199067
# Cascade length:  4
# New Orders left:  199063
# making new cascade
# OG Orders left:  199063
# Cascade length:  4
# New Orders left:  199059
# making new cascade
# OG Orders left:  199059
# Cascade length:  2
# New Orders left:  199057
# making new cascade
# OG Orders left:  199057
# Cascade length:  101
# New Orders left:  198956
# making new cascade
# OG Orders left:  198956
# Cascade length:  1424
# New Orders left:  197532
# making new cascade
# OG Orders left:  197532
# Cascade length:  15
# New Orders left:  197517
# making new cascade
# OG Orders left:  197517
# Cascade length:  3
# New Orders left:  197514
# making new cascade
# OG Orders left:  197514
# Cascade length:  1764
# New Orders left:  195750
# making new cascade
# OG Orders left:  195750
# Cascade length:  4
# New Orders left:  195746
# making new cascade
# OG Orders left:  195746
# Cascade length:  2084
# New Orders left:  193662
# making new cascade
# OG Orders left:  193662
# Cascade length:  10
# New Orders left:  193652
# making new cascade
# OG Orders left:  193652
# Cascade length:  2
# New Orders left:  193650
# making new cascade
# OG Orders left:  193650
# Cascade length:  1730
# New Orders left:  191920
# making new cascade
# OG Orders left:  191920
# Cascade length:  2070
# New Orders left:  189850
# making new cascade
# OG Orders left:  189850
# Cascade length:  65
# New Orders left:  189785
# making new cascade
# OG Orders left:  189785
# Cascade length:  11
# New Orders left:  189774
# making new cascade
# OG Orders left:  189774
# Cascade length:  7
# New Orders left:  189767
# making new cascade
# OG Orders left:  189767
# Cascade length:  15
# New Orders left:  189752
# making new cascade
# OG Orders left:  189752
# Cascade length:  3
# New Orders left:  189749
# making new cascade
# OG Orders left:  189749
# Cascade length:  1489
# New Orders left:  188260
# making new cascade
# OG Orders left:  188260
# Cascade length:  2
# New Orders left:  188258
# making new cascade
# OG Orders left:  188258
# Cascade length:  8
# New Orders left:  188250
# making new cascade
# OG Orders left:  188250
# Cascade length:  13
# New Orders left:  188237
# making new cascade
# OG Orders left:  188237
# Cascade length:  2216
# New Orders left:  186021
# making new cascade
# OG Orders left:  186021
# Cascade length:  12
# New Orders left:  186009
# making new cascade
# OG Orders left:  186009
# Cascade length:  2
# New Orders left:  186007
# making new cascade
# OG Orders left:  186007
# Cascade length:  4
# New Orders left:  186003
# making new cascade
# OG Orders left:  186003
# Cascade length:  1788
# New Orders left:  184215
# making new cascade
# OG Orders left:  184215
# Cascade length:  6
# New Orders left:  184209
# making new cascade
# OG Orders left:  184209
# Cascade length:  1
# New Orders left:  184208
# making new cascade
# OG Orders left:  184208
# Cascade length:  1329
# New Orders left:  182879
# making new cascade
# OG Orders left:  182879
# Cascade length:  2583
# New Orders left:  180296
# making new cascade
# OG Orders left:  180296
# Cascade length:  2
# New Orders left:  180294
# making new cascade
# OG Orders left:  180294
# Cascade length:  6
# New Orders left:  180288
# making new cascade
# OG Orders left:  180288
# Cascade length:  8
# New Orders left:  180280
# making new cascade
# OG Orders left:  180280
# Cascade length:  1268
# New Orders left:  179012
# making new cascade
# OG Orders left:  179012
# Cascade length:  1281
# New Orders left:  177731
# making new cascade
# OG Orders left:  177731
# Cascade length:  10
# New Orders left:  177721
# making new cascade
# OG Orders left:  177721
# Cascade length:  3
# New Orders left:  177718
# making new cascade
# OG Orders left:  177718
# Cascade length:  14
# New Orders left:  177704
# making new cascade
# ...
#        'ljvdp', 'xutnf', 'xldwc', 'dlhjw', 'tksjg', 'crumb', 'jzhps',
#        'eufmt', 'bvnif', 'rucla', 'trmsu', 'rudvg', 'bpgef', 'mdtlz'],
#       dtype='<U5'), 1274: array(['lesva', 'vfnew', 'rjybo', 'ynzck', 'ultqn', 'qjoly', 'arfqy',
#        'vrpod', 'wxapb', 'amrzp', 'ymdaz', 'fwdxa', 'wcjda', 'rpziq',
#        'stdpk', 'emtra', 'sktfl', 'ulcbq', 'gbwna', 'apogn', 'khnsu',
#        'aiubl', 'hvksz', 'pgzva', 'actum', 'pflkb', 'apuys', 'phwmi',
#        'dlhjw', 'jzhps', 'crumb', 'tksjg', 'eufmt', 'niqru', 'ozwgq',
#        'bvnif', 'rucla', 'trmsu', 'bpgef', 'rudvg'], dtype='<U5'), 1275: array('zuptq', dtype='<U5'), 1276: array('dojns', dtype='<U5'), 1277: array(['jbmig', 'arfqy'], dtype='<U5'), 1278: array('zuptq', dtype='<U5'), 1279: array(['lesva', 'vfnew', 'qjoly', 'wxapb', 'gqzpm', 'wcjda', 'rpziq',
#        'gneoi', 'emtra', 'apogn', 'ulcbq', 'aiubl', 'hvksz', 'cvmzs',
#        'actum', 'ljvdp', 'phwmi', 'pflkb', 'xutnf', 'jzhps', 'dlhjw',
#        'tksjg', 'eufmt', 'niqru', 'ozwgq', 'trmsu', 'bvnif', 'rucla'],
#       dtype='<U5'), 1280: array(['dojns', 'rjybo'], dtype='<U5'), 1281: array(['lesva', 'vfnew', 'qjoly', 'ymdaz', 'ultqn', 'gqzpm', 'wxapb',
#        'fwdxa', 'rpziq', 'emtra', 'ulcbq', 'rqnyu', 'pflkb', 'apuys',
#        'tksjg', 'eufmt', 'crumb', 'niqru', 'imxkt', 'pgzva', 'bvnif'],
#       dtype='<U5'), 1282: array(['tpags', 'ynzck', 'ymdaz', 'ultqn', 'fwdxa', 'wcjda', 'stdpk'],
#       dtype='<U5'), 1283: array(['jbmig', 'arfqy'], dtype='<U5'), 1284: array('dojns', dtype='<U5'), 1285: array(['lesva', 'amrzp', 'qjoly', 'vfnew', 'vrpod', 'wxapb', 'ymdaz',
#        'ultqn', 'fwdxa', 'wcjda', 'rpziq', 'sktfl', 'gneoi', 'emtra',
#        'apogn', 'khnsu', 'aiubl', 'hvksz', 'ulcbq', 'actum', 'ljvdp',
#        'pflkb', 'cvmzs', 'apuys', 'xutnf', 'phwmi', 'dlhjw', 'ozwgq',
#        'crumb'], dtype='<U5'), 1286: array(['ynzck', 'rjybo', 'tpags', 'dojns', 'arfqy', 'hprkz', 'ymdaz',
#        'ultqn', 'uvndz', 'sktfl', 'xmyis', 'gneoi', 'gbwna', 'iocjm',
#        'rqnyu', 'ljvdp', 'cvmzs', 'tksjg', 'eufmt', 'imxkt'], dtype='<U5'), 1287: array(['ynzck', 'tpags', 'arfqy', 'hprkz', 'ymdaz', 'uvndz', 'fwdxa',
#        'wcjda'], dtype='<U5'), 1288: array(['lesva', 'amrzp', 'qjoly', 'vfnew', 'wxapb', 'wcjda', 'rpziq',
#        'uvndz', 'sktfl', 'emtra', 'apogn', 'aiubl', 'hvksz', 'cvmzs',
#        'jzhps'], dtype='<U5'), 1289: array(['rjybo', 'xivsl', 'ynzck', 'dojns', 'tpags', 'hprkz', 'ultqn',
#        'xmyis', 'wcjda', 'gneoi', 'uvndz', 'juzrt', 'iocjm', 'cvmzs'],
#       dtype='<U5'), 1290: array('zuptq', dtype='<U5'), 1291: array(['jbmig', 'ofpeq', 'ultqn', 'sktfl', 'wcjda', 'rpziq', 'uvndz',
#        'emtra', 'apogn', 'juzrt', 'iocjm', 'aiubl', 'ulcbq', 'ljvdp',
#        'pflkb', 'hvksz', 'cvmzs', 'jzhps', 'tksjg', 'niqru'], dtype='<U5'), 1292: array(['lesva', 'amrzp', 'gqzpm', 'qjoly', 'vfnew', 'wxapb', 'rpziq',
#        'emtra', 'apogn', 'aiubl', 'ulcbq', 'ljvdp', 'pflkb', 'apuys'],
#       dtype='<U5'), 1293: array('zuptq', dtype='<U5'), 1294: array(['dojns', 'rjybo'], dtype='<U5'), 1295: array(['lesva', 'amrzp', 'gqzpm', 'qjoly', 'vfnew', 'wxapb', 'ymdaz',
#        'wcjda', 'hvksz', 'cvmzs'], dtype='<U5'), 1296: array(['tpags', 'ynzck', 'rjybo', 'dojns', 'xivsl'], dtype='<U5'), 1297: array('jbmig', dtype='<U5'), 1298: array(['lesva', 'gqzpm', 'qjoly', 'amrzp', 'hprkz', 'vfnew', 'ymdaz',
#        'wxapb', 'stdpk', 'fwdxa', 'emtra', 'wcjda', 'rqnyu', 'apogn',
#        'aiubl', 'hvksz', 'ljvdp', 'pflkb', 'apuys', 'ulcbq'], dtype='<U5'), 1299: array(['zuptq', 'vrpod'], dtype='<U5'), 1300: array('jbmig', dtype='<U5'), 1301: array(['vrpod', 'zuptq'], dtype='<U5'), 1302: array(['tpags', 'hprkz', 'fwdxa', 'stdpk', 'xmyis', 'iocjm', 'rqnyu',
#        'apogn', 'hvksz', 'ljvdp'], dtype='<U5'), 1303: array('dojns', dtype='<U5'), 1304: array(['jbmig', 'ofpeq', 'xmyis', 'gbwna', 'sktfl', 'khnsu', 'uvndz',
#        'rpziq', 'apogn'], dtype='<U5'), 1305: array(['lesva', 'amrzp', 'qjoly', 'gqzpm', 'vfnew', 'hprkz', 'ymdaz',
#        'wxapb', 'ofpeq', 'stdpk', 'fwdxa', 'xmyis', 'gbwna', 'rpziq',
#        'wcjda', 'emtra', 'iocjm', 'rqnyu', 'xldwc', 'apogn', 'aiubl',
#        'xutnf', 'apuys'], dtype='<U5'), 1306: array('arfqy', dtype='<U5'), 1307: array(['ynzck', 'dojns'], dtype='<U5'), 1308: array(['tpags', 'ynzck', 'arfqy', 'dojns', 'rjybo', 'kpamj', 'meldx'],
#       dtype='<U5'), 1309: array(['vrpod', 'zuptq', 'kpamj', 'meldx', 'dojns'], dtype='<U5'), 1310: array(['jbmig', 'hprkz', 'amrzp', 'gqzpm', 'ofpeq', 'dojns', 'apogn'],
#       dtype='<U5'), 1311: array('xivsl', dtype='<U5'), 1312: array(['vrpod', 'zuptq'], dtype='<U5'), 1313: array(['jbmig', 'arfqy', 'ofpeq', 'dojns', 'stdpk', 'fwdxa', 'ultqn'],
#       dtype='<U5'), 1314: array(['vrpod', 'ynzck', 'rjybo', 'zuptq', 'hprkz', 'amrzp', 'gqzpm',
#        'ofpeq', 'fwdxa', 'sktfl', 'gbwna', 'dojns', 'uvndz'], dtype='<U5'), 1315: array(['tpags', 'ynzck', 'vrpod', 'zuptq', 'rjybo', 'meldx', 'kpamj',
#        'fwdxa', 'wcjda'], dtype='<U5'), 1316: array(['lesva', 'qjoly', 'ynzck', 'vfnew', 'vrpod', 'rjybo', 'hprkz',
#        'ymdaz', 'meldx', 'wxapb', 'kpamj', 'amrzp', 'gqzpm', 'ofpeq',
#        'xmyis', 'stdpk', 'ultqn', 'khnsu', 'gbwna', 'dojns', 'rpziq',
#        'uvndz', 'sktfl', 'emtra', 'iocjm', 'rqnyu', 'xldwc', 'xutnf'],
#       dtype='<U5'), 1317: array(['jbmig', 'arfqy'], dtype='<U5'), 1318: array(['tpags', 'arfqy'], dtype='<U5'), 1319: array(['lesva', 'qjoly', 'vfnew', 'rjybo', 'wxapb', 'kpamj', 'amrzp',
#        'ymdaz', 'meldx', 'gqzpm', 'ofpeq', 'xmyis', 'stdpk', 'juzrt',
#        'khnsu', 'rpziq', 'dojns', 'ultqn', 'gbwna', 'fwdxa', 'ynfbq',
#        'yncqb', 'uvndz', 'wcjda', 'emtra', 'iocjm', 'rqnyu', 'xldwc',
#        'apogn', 'actum', 'phwmi', 'trmsu', 'xutnf'], dtype='<U5'), 1320: array('jbmig', dtype='<U5'), 1321: array('tpags', dtype='<U5'), 1322: array(['lesva', 'qjoly', 'vfnew', 'rjybo', 'wxapb', 'ymdaz', 'gqzpm',
#        'ofpeq', 'stdpk', 'juzrt', 'rpziq', 'sktfl', 'xivsl', 'ultqn',
#        'ynfbq', 'yncqb', 'wcjda', 'emtra', 'uvndz', 'iocjm', 'xldwc',
#        'fwdxa', 'apogn', 'trmsu'], dtype='<U5'), 1323: array('ynzck', dtype='<U5'), 1324: array(['vrpod', 'hprkz', 'amrzp', 'rjybo', 'vfnew', 'qjoly', 'ymdaz',
#        'gqzpm', 'ofpeq', 'stdpk', 'dojns', 'rpziq', 'yncqb', 'emtra',
#        'rqnyu', 'uvndz', 'iocjm', 'xldwc'], dtype='<U5'), 1325: array(['jbmig', 'arfqy', 'hprkz', 'amrzp', 'ofpeq', 'rpziq', 'dojns',
#        'wcjda', 'yncqb', 'emtra', 'ultqn', 'uvndz', 'iocjm', 'apogn',
#        'xldwc'], dtype='<U5'), 1326: array(['lesva', 'vfnew', 'rjybo', 'kpamj', 'ymdaz', 'meldx', 'qjoly',
#        'juzrt', 'wcjda'], dtype='<U5'), 1327: array('vrpod', dtype='<U5'), 1328: array(['ynzck', 'tpags', 'arfqy', 'ymdaz', 'wcjda', 'yncqb', 'rqnyu',
#        'emtra', 'actum', 'fwdxa', 'phwmi', 'ultqn', 'uvndz', 'iocjm'],
#       dtype='<U5'), 1329: array(['jbmig', 'hprkz', 'vrpod', 'arfqy', 'vfnew', 'rjybo', 'kpamj',
#        'meldx', 'qjoly', 'amrzp', 'xmyis', 'gqzpm', 'khnsu', 'esrkg',
#        'stdpk', 'sktfl', 'gbwna', 'xivsl', 'ofpeq', 'rpziq', 'rqnyu',
#        'yncqb', 'emtra', 'phwmi', 'uvndz'], dtype='<U5'), 1330: array(['ynzck', 'tpags', 'hprkz', 'vrpod', 'vfnew', 'rjybo', 'qjoly',
#        'ymdaz', 'amrzp', 'khnsu', 'sktfl', 'juzrt', 'xivsl', 'fwdxa'],
#       dtype='<U5'), 1331: array('lesva', dtype='<U5'), 1332: array(['jbmig', 'arfqy'], dtype='<U5'), 1333: array('lesva', dtype='<U5'), 1334: array(['tpags', 'ynzck', 'hprkz', 'vrpod', 'kpamj', 'rjybo', 'xmyis',
#        'amrzp', 'meldx', 'khnsu', 'gqzpm', 'gbwna', 'ofpeq', 'rpziq',
#        'rqnyu'], dtype='<U5'), 1335: array(['jbmig', 'arfqy'], dtype='<U5'), 1336: array(['lesva', 'vfnew', 'qjoly', 'stdpk', 'meldx', 'zuptq', 'juzrt',
#        'rpziq', 'ofpeq'], dtype='<U5'), 1337: array(['jbmig', 'hprkz', 'vrpod', 'vfnew', 'kpamj', 'qjoly', 'rjybo',
#        'amrzp', 'khnsu', 'gqzpm', 'stdpk', 'gbwna', 'meldx', 'zuptq',
#        'juzrt', 'wcjda', 'rpziq', 'actum', 'yncqb'], dtype='<U5'), 1338: array(['tpags', 'ynzck', 'arfqy', 'ymdaz', 'vfnew', 'rjybo', 'amrzp',
#        'kpamj', 'sktfl', 'khnsu', 'xivsl', 'gbwna', 'zuptq', 'wcjda',
#        'actum'], dtype='<U5'), 1339: array('wxapb', dtype='<U5'), 1340: array('lesva', dtype='<U5'), 1341: array('gneoi', dtype='<U5'), 1342: array(['tpags', 'arfqy'], dtype='<U5'), 1343: array(['wxapb', 'qjoly', 'gqzpm', 'gbwna', 'wcjda', 'rpziq'], dtype='<U5'), 1344: array('epwmi', dtype='<U5'), 1345: array(['gneoi', 'jbmig', 'xmyis', 'sktfl', 'khnsu', 'xivsl', 'ofpeq'],
#       dtype='<U5'), 1346: array('ynzck', dtype='<U5'), 1347: array(['wxapb', 'qjoly', 'gqzpm', 'gbwna'], dtype='<U5'), 1348: array(['hprkz', 'ynzck', 'tpags', 'jbmig', 'arfqy', 'esrkg', 'ymdaz',
#        'xmyis'], dtype='<U5'), 1349: array('epwmi', dtype='<U5'), 1350: array(['lesva', 'gneoi', 'qjoly', 'gqzpm', 'wcjda'], dtype='<U5'), 1351: array(['hprkz', 'vrpod', 'ynzck', 'jbmig', 'esrkg', 'amrzp', 'xmyis',
#        'rjybo', 'meldx', 'khnsu', 'zuptq', 'sktfl', 'xivsl'], dtype='<U5'), 1352: array(['wxapb', 'qjoly'], dtype='<U5'), 1353: array('tpags', dtype='<U5'), 1354: array(['wxapb', 'qjoly'], dtype='<U5'), 1355: array(['epwmi', 'lesva', 'gneoi', 'arfqy', 'vfnew', 'rjybo'], dtype='<U5'), 1356: array(['tpags', 'ynzck'], dtype='<U5'), 1357: array('wxapb', dtype='<U5'), 1358: array(['vrpod', 'hprkz', 'jbmig', 'esrkg', 'amrzp', 'xmyis', 'vfnew',
#        'juzrt', 'khnsu', 'rjybo', 'zuptq', 'ofpeq', 'xivsl', 'meldx',
#        'sktfl'], dtype='<U5'), 1359: array(['tpags', 'ynzck'], dtype='<U5'), 1360: array(['lesva', 'epwmi', 'arfqy'], dtype='<U5'), 1361: array('wxapb', dtype='<U5'), 1362: array('gneoi', dtype='<U5'), 1363: array(['hprkz', 'vrpod', 'ynzck', 'stdpk', 'kpamj', 'amrzp', 'xmyis',
#        'khnsu', 'rjybo', 'ofpeq', 'zuptq', 'xivsl', 'sktfl'], dtype='<U5'), 1364: array(['lesva', 'epwmi', 'arfqy', 'kjcuf', 'vfnew', 'juzrt'], dtype='<U5'), 1365: array(['tpags', 'ynzck', 'ymdaz'], dtype='<U5'), 1366: array('wxapb', dtype='<U5'), 1367: array(['gneoi', 'jbmig', 'esrkg'], dtype='<U5'), 1368: array(['lesva', 'gneoi', 'jbmig', 'esrkg', 'kjcuf', 'xmyis'], dtype='<U5'), 1369: array(['tpags', 'ynzck', 'stdpk', 'kpamj'], dtype='<U5'), 1370: array(['hprkz', 'vrpod', 'jbmig', 'arfqy', 'ynzck', 'esrkg', 'amrzp',
#        'kjcuf', 'khnsu', 'xmyis'], dtype='<U5'), 1371: array('wxapb', dtype='<U5'), 1372: array(['lesva', 'vfnew', 'ynzck'], dtype='<U5'), 1373: array('epwmi', dtype='<U5'), 1374: array('wxapb', dtype='<U5'), 1375: array(['hprkz', 'vrpod', 'jbmig', 'esrkg'], dtype='<U5'), 1376: array(['tpags', 'stdpk', 'vrpod', 'arfqy', 'juzrt', 'kpamj', 'epwmi',
#        'ynzck', 'vfnew', 'esrkg'], dtype='<U5'), 1377: array('ynfbq', dtype='<U5'), 1378: array('gneoi', dtype='<U5'), 1379: array('lesva', dtype='<U5'), 1380: array(['tpags', 'arfqy', 'epwmi'], dtype='<U5'), 1381: array('wxapb', dtype='<U5'), 1382: array(['gneoi', 'jbmig', 'hprkz', 'vrpod', 'stdpk', 'juzrt'], dtype='<U5'), 1383: array('dojns', dtype='<U5'), 1384: array('wxapb', dtype='<U5'), 1385: array('ynfbq', dtype='<U5'), 1386: array('dojns', dtype='<U5'), 1387: array('tpags', dtype='<U5'), 1388: array('wxapb', dtype='<U5'), 1389: array(['ymdaz', 'ynfbq'], dtype='<U5'), 1390: array('lesva', dtype='<U5'), 1391: array('dojns', dtype='<U5'), 1392: array('wxapb', dtype='<U5'), 1393: array(['jbmig', 'gneoi', 'hprkz', 'dojns', 'lesva', 'vrpod', 'stdpk'],
#       dtype='<U5'), 1394: array(['ymdaz', 'tpags', 'ynfbq', 'amrzp', 'stdpk'], dtype='<U5'), 1395: array('wxapb', dtype='<U5'), 1396: array(['tpags', 'ymdaz'], dtype='<U5'), 1397: array('wxapb', dtype='<U5'), 1398: array(['hprkz', 'jbmig', 'gneoi', 'dojns', 'ymdaz'], dtype='<U5'), 1399: array('lesva', dtype='<U5'), 1400: array('ynfbq', dtype='<U5'), 1401: array('tpags', dtype='<U5'), 1402: array('kpamj', dtype='<U5'), 1403: array('wxapb', dtype='<U5'), 1404: array('jbmig', dtype='<U5'), 1405: array('lesva', dtype='<U5'), 1406: array('kpamj', dtype='<U5'), 1407: array('tpags', dtype='<U5'), 1408: array('wxapb', dtype='<U5')}
# {0: 993, 1: 993.0, 2: 995.0, 3: 995.0, 4: 997.0, 5: 998.0, 6: 1001.0, 7: 1004.0, 8: 1004.0, 9: 1005.0, 10: 1008.0, 11: 1010.0, 12: 1012.0, 13: 1017.0, 14: 1018.0, 15: 1019.0, 16: 1020.0, 17: 1022.0, 18: 1025.0, 19: 1025.0, 20: 1025.0, 21: 1027.0, 22: 1028.0, 23: 1029.0, 24: 1029.0, 25: 1031.0, 26: 1032.0, 27: 1032.0, 28: 1035.0, 29: 1035.0, 30: 1037.0, 31: 1039.0, 32: 1040.0, 33: 1042.0, 34: 1042.0, 35: 1046.0, 36: 1048.0, 37: 1049.0, 38: 1051.0, 39: 1052.0, 40: 1052.0, 41: 1057.0, 42: 1060.0, 43: 1062.0, 44: 1063.0, 45: 1065.0, 46: 1067.0, 47: 1068.0, 48: 1068.0, 49: 1069.0, 50: 1071.0, 51: 1072.0, 52: 1074.0, 53: 1076.0, 54: 1076.0, 55: 1077.0, 56: 1078.0, 57: 1079.0, 58: 1079.0, 59: 1079.0, 60: 1081.0, 61: 1082.0, 62: 1082.0, 63: 1083.0, 64: 1084.0, 65: 1084.0, 66: 1085.0, 67: 1085.0, 68: 1086.0, 69: 1087.0, 70: 1087.0, 71: 1088.0, 72: 1088.0, 73: 1090.0, 74: 1091.0, 75: 1091.0, 76: 1092.0, 77: 1092.0, 78: 1093.0, 79: 1095.0, 80: 1095.0, 81: 1096.0, 82: 1096.0, 83: 1097.0, 84: 1097.0, 85: 1098.0, 86: 1099.0, 87: 1099.0, 88: 1100.0, 89: 1100.0, 90: 1100.0, 91: 1101.0, 92: 1102.0, 93: 1103.0, 94: 1104.0, 95: 1105.0, 96: 1105.0, 97: 1106.0, 98: 1106.0, 99: 1106.0, 100: 1107.0, 101: 1109.0, 102: 1109.0, 103: 1109.0, 104: 1111.0, 105: 1111.0, 106: 1112.0, 107: 1113.0, 108: 1113.0, 109: 1113.0, 110: 1114.0, 111: 1115.0, 112: 1116.0, 113: 1116.0, 114: 1116.0, 115: 1117.0, 116: 1118.0, 117: 1118.0, 118: 1120.0, 119: 1120.0, 120: 1121.0, 121: 1122.0, 122: 1123.0, 123: 1124.0, 124: 1124.0, 125: 1124.0, 126: 1126.0, 127: 1126.0, 128: 1127.0, 129: 1128.0, 130: 1129.0, 131: 1129.0, 132: 1130.0, 133: 1131.0, 134: 1131.0, 135: 1132.0, 136: 1133.0, 137: 1133.0, 138: 1134.0, 139: 1135.0, 140: 1136.0, 141: 1136.0, 142: 1137.0, 143: 1137.0, 144: 1138.0, 145: 1139.0, 146: 1140.0, 147: 1141.0, 148: 1141.0, 149: 1143.0, 150: 1144.0, 151: 1144.0, 152: 1145.0, 153: 1145.0, 154: 1146.0, 155: 1146.0, 156: 1146.0, 157: 1147.0, 158: 1148.0, 159: 1150.0, 160: 1150.0, 161: 1153.0, 162: 1154.0, 163: 1154.0, 164: 1155.0, 165: 1155.0, 166: 1156.0, 167: 1158.0, 168: 1158.0, 169: 1159.0, 170: 1159.0, 171: 1159.0, 172: 1162.0, 173: 1162.0, 174: 1163.0, 175: 1164.0, 176: 1164.0, 177: 1164.0, 178: 1166.0, 179: 1167.0, 180: 1167.0, 181: 1167.0, 182: 1169.0, 183: 1171.0, 184: 1172.0, 185: 1173.0, 186: 1174.0, 187: 1175.0, 188: 1176.0, 189: 1176.0, 190: 1176.0, 191: 1178.0, 192: 1179.0, 193: 1180.0, 194: 1181.0, 195: 1182.0, 196: 1184.0, 197: 1184.0, 198: 1184.0, 199: 1185.0, 200: 1186.0, 201: 1186.0, 202: 1186.0, 203: 1187.0, 204: 1188.0, 205: 1190.0, 206: 1190.0, 207: 1190.0, 208: 1191.0, 209: 1193.0, 210: 1193.0, 211: 1194.0, 212: 1196.0, 213: 1198.0, 214: 1199.0, 215: 1201.0, 216: 1202.0, 217: 1203.0, 218: 1204.0, 219: 1206.0, 220: 1207.0, 221: 1208.0, 222: 1210.0, 223: 1211.0, 224: 1212.0, 225: 1213.0, 226: 1216.0, 227: 1216.0, 228: 1217.0, 229: 1221.0, 230: 1222.0, 231: 1223.0, 232: 1224.0, 233: 1227.0, 234: 1229.0, 235: 1229.0, 236: 1230.0, 237: 1231.0, 238: 1232.0, 239: 1232.0, 240: 1233.0, 241: 1235.0, 242: 1236.0, 243: 1237.0, 244: 1238.0, 245: 1239.0, 246: 1241.0, 247: 1244.0, 248: 1245.0, 249: 1247.0, 250: 1247.0, 251: 1251.0, 252: 1251.0, 253: 1252.0, 254: 1254.0, 255: 1255.0, 256: 1256.0, 257: 1256.0, 258: 1260.0, 259: 1260.0, 260: 1260.0, 261: 1262.0, 262: 1263.0, 263: 1264.0, 264: 1266.0, 265: 1266.0, 266: 1267.0, 267: 1269.0, 268: 1269.0, 269: 1269.0, 270: 1270.0, 271: 1272.0, 272: 1273.0, 273: 1274.0, 274: 1276.0, 275: 1276.0, 276: 1278.0, 277: 1278.0, 278: 1279.0, 279: 1279.0, 280: 1280.0, 281: 1282.0, 282: 1282.0, 283: 1286.0, 284: 1286.0, 285: 1286.0, 286: 1288.0, 287: 1288.0, 288: 1291.0, 289: 1291.0, 290: 1291.0, 291: 1291.0, 292: 1294.0, 293: 1294.0, 294: 1295.0, 295: 1295.0, 296: 1296.0, 297: 1297.0, 298: 1298.0, 299: 1298.0, 300: 1298.0, 301: 1300.0, 302: 1300.0, 303: 1301.0, 304: 1302.0, 305: 1303.0, 306: 1303.0, 307: 1304.0, 308: 1305.0, 309: 1305.0, 310: 1305.0, 311: 1306.0, 312: 1307.0, 313: 1308.0, 314: 1308.0, 315: 1308.0, 316: 1308 ...

# %%
# with open('./results/nopricechange/7-9/cascades_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
#     pickle.dump(cascades, f, pickle.HIGHEST_PROTOCOL)
# with open('./results/nopricechange/7-9/cascadesTime_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
#     pickle.dump(cascadeTime, f, pickle.HIGHEST_PROTOCOL)
# with open('./results/nopricechange/7-9/cascadeStocks_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
#     pickle.dump(cascadeStocks, f, pickle.HIGHEST_PROTOCOL)
# with open('./results/nopricechange/7-9/cascadePortf_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
#     pickle.dump(cascadePortfs, f, pickle.HIGHEST_PROTOCOL)
# with open('./results/nopricechange/7-9/cascadeTf_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
#     pickle.dump(cascadeTf, f, pickle.HIGHEST_PROTOCOL)    
    
#cascades = pickle.load(f)

with open('./results/nopricechange/7-9/cascades_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
    cascades = pickle.load(f)
with open('./results/nopricechange/7-9/cascadesTime_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
    cascadesTime = pickle.load(f)
with open('./results/nopricechange/7-9/cascadeStocks_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
    cascadesStocks = pickle.load(f)
with open('./results/nopricechange/7-9/cascadePortf_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
    cascadesPortf = pickle.load(f)
with open('./results/nopricechange/7-9/cascadeTf_maxsep1_maxeff1_501_1000_100_nopricechange.pkl', 'wb') as f:
    cascadesTf = pickle.load(f)
