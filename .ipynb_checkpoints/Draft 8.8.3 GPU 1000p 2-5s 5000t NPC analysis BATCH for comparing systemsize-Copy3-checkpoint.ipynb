# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_1000_5000_100_2_5.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_1000_5000_100_2_5.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_1000_5000_100_2_5.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_1000_5000_100_2_5.csv")

# %%
TtotalOrdersNPC
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 0   993     sniel     86    1.0
# 1                 0   993     yeqal     83   -1.0
# 2                 2   993     yeqal     85    2.0
# 3                 0   993     tcnoe     73    3.0
# 4                 1   993     tcnoe     74   -3.0
# ...             ...   ...       ...    ...    ...
# 2136648           2  5992     lekvh     62   16.0
# 2136649           0  5992     uesjc     42    5.0
# 2136650           3  5992     uesjc     50   -7.0
# 2136651           1  5992     vuemj     58    7.0
# 2136652           2  5992     vuemj     89   -3.0
#
# [2136653 rows x 5 columns]

# %%
type(TtotalOrdersNPC)
# Out:
# cudf.core.dataframe.DataFrame

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-8eb6452f45de> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     811                 return NotImplemented
#     812             else:
# --> 813                 return cudf_func(*args, **kwargs)
#     814
#     815         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    TtotalOrders = TtotalOrdersNPC
    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades22_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2136653
# Cascade length:  5629
# New Orders left:  2131024
# making new cascade
#
#
# OG Orders left:  2131024
# Cascade length:  5282
# New Orders left:  2125742
# making new cascade
#
#
# OG Orders left:  2125742
# Cascade length:  4954
# New Orders left:  2120788
# making new cascade
#
#
# OG Orders left:  2120788
# Cascade length:  3791
# New Orders left:  2116997
# making new cascade
#
#
# OG Orders left:  2116997
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e9bfa8d439f1> in <module>
# ----> 1 causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
#       2 npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
#       3 with open('../causalCascades/7-9/causalCascades22_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
#       4     pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
#
# <ipython-input-6-2da9571d3e2e> in findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep)
#      64                         for row in np.asarray(childPortfCascade.index):
#      65                             row = row.item()
# ---> 66                             stock = childPortfCascade['stock'].loc[row]
#      67                             time = childPortfCascade['time'].loc[row]
#      68                             order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     414         replaced = self.copy()
#     415         to_replace_col, replacement_col, replaced = numeric_normalize_types(
# --> 416             to_replace_col, replacement_col, replaced
#     417         )
#     418         return libcudf.replace.replace(
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in numeric_normalize_types(*args)
#     104     """
#     105     dtype = np.result_type(*[a.dtype for a in args])
# --> 106     return [a.astype(dtype) for a in args]
#     107
#     108
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in <listcomp>(.0)
#     104     """
#     105     dtype = np.result_type(*[a.dtype for a in args])
# --> 106     return [a.astype(dtype) for a in args]
#     107
#     108
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in astype(self, dtype, **kwargs)
#     979         }:
#     980             return self.as_string_column(dtype, **kwargs)
# --> 981         elif is_list_dtype(dtype):
#     982             if not self.dtype == dtype:
#     983                 raise NotImplementedError(
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_list_dtype(obj)
#     187         or type(obj) is cudf.core.column.ListColumn
#     188         or obj is cudf.core.column.ListColumn
# --> 189         or (isinstance(obj, str) and obj == cudf.core.dtypes.ListDtype.name)
#     190         or (hasattr(obj, "dtype") and is_list_dtype(obj.dtype))
#     191     )
#
# KeyboardInterrupt:

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades21_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades12_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2136653
# Cascade length:  5481
# New Orders left:  2131172
# making new cascade
#
#
# OG Orders left:  2131172
# Cascade length:  5000
# New Orders left:  2126172
# making new cascade
#
#
# OG Orders left:  2126172
# Cascade length:  4594
# New Orders left:  2121578
# making new cascade
#
#
# OG Orders left:  2121578
# Cascade length:  950
# New Orders left:  2120628
# making new cascade
#
#
# OG Orders left:  2120628
# Cascade length:  3327
# New Orders left:  2117301
# making new cascade
#
#
# OG Orders left:  2117301
# Cascade length:  1
# New Orders left:  2117300
# making new cascade
#
#
# OG Orders left:  2117300
# Cascade length:  4528
# New Orders left:  2112772
# making new cascade
#
#
# OG Orders left:  2112772
# Cascade length:  4
# New Orders left:  2112768
# making new cascade
#
#
# OG Orders left:  2112768
# Cascade length:  4367
# New Orders left:  2108401
# making new cascade
#
#
# OG Orders left:  2108401
# Cascade length:  4298
# New Orders left:  2104103
# making new cascade
#
#
# OG Orders left:  2104103
# Cascade length:  4528
# New Orders left:  2099575
# making new cascade
#
#
# OG Orders left:  2099575
# Cascade length:  4265
# New Orders left:  2095310
# making new cascade
#
#
# OG Orders left:  2095310
# Cascade length:  2
# New Orders left:  2095308
# making new cascade
#
#
# OG Orders left:  2095308
# Cascade length:  4038
# New Orders left:  2091270
# making new cascade
#
#
# OG Orders left:  2091270
# Cascade length:  51
# New Orders left:  2091219
# making new cascade
#
#
# OG Orders left:  2091219
# Cascade length:  4926
# New Orders left:  2086293
# making new cascade
#
#
# OG Orders left:  2086293
# Cascade length:  3940
# New Orders left:  2082353
# making new cascade
#
#
# OG Orders left:  2082353
# Cascade length:  3925
# New Orders left:  2078428
# making new cascade
#
#
# OG Orders left:  2078428
# Cascade length:  4123
# New Orders left:  2074305
# making new cascade
#
#
# OG Orders left:  2074305
# Cascade length:  3
# New Orders left:  2074302
# making new cascade
#
#
# OG Orders left:  2074302
# Cascade length:  2
# New Orders left:  2074300
# making new cascade
#
#
# OG Orders left:  2074300
# Cascade length:  10
# New Orders left:  2074290
# making new cascade
#
#
# OG Orders left:  2074290
# Cascade length:  2
# New Orders left:  2074288
# making new cascade
#
#
# OG Orders left:  2074288
# Cascade length:  4490
# New Orders left:  2069798
# making new cascade
#
#
# OG Orders left:  2069798
# Cascade length:  4044
# New Orders left:  2065754
# making new cascade
#
#
# OG Orders left:  2065754
# Cascade length:  3657
# New Orders left:  2062097
# making new cascade
#
#
# OG Orders left:  2062097
# Cascade length:  3487
# New Orders left:  2058610
# making new cascade
#
#
# OG Orders left:  2058610
# Cascade length:  3368
# New Orders left:  2055242
# making new cascade
#
#
# OG Orders left:  2055242
# Cascade length:  18
# New Orders left:  2055224
# making new cascade
#
#
# OG Orders left:  2055224
# Cascade length:  3937
# New Orders left:  2051287
# making new cascade
#
#
# OG Orders left:  2051287
# Cascade length:  3440
# New Orders left:  2047847
# making new cascade
#
#
# OG Orders left:  2047847
# Cascade length:  4514
# New Orders left:  2043333
# making new cascade
#
#
# OG Orders left:  2043333
# Cascade length:  3510
# New Orders left:  2039823
# making new cascade
#
#
# OG Orders left:  2039823
# Cascade length:  2
# New Orders left:  2039821
# making new cascade
#
#
# OG Orders left:  2039821
# Cascade length:  4561
# New Orders left:  2035260
# making new cascade
#
#
# OG Orders left:  2035260
# Cascade length:  4745
# New Orders left:  2030515
# making new cascade
#
#
# OG Orders left:  2030515
# Cascade length:  4757
# New Orders left:  2025758
# making new cascade
#
#
# OG Orders left:  2025758
# Cascade length:  4155
# New Orders left:  2021603
# making new cascade
#
#
# OG Orders left:  2021603
# Cascade length:  2860
# New Orders left:  2018743
# making new cascade
#
#
# OG Orders left:  2018743
# Cascade length:  14
# New Orders left:  2018729
# making new cascade
#
#
# OG Orders left:  2018729
# Cascade length:  4424
# New Orders left:  2014305
# making new cascade
#
#
# OG Orders left:  2014305
# Cascade length:  2267
# New Orders left:  2012038
# making new cascade
#
#
# OG Orders left:  2012038
# Cascade length:  4282
# New Orders left:  2007756
# making new cascade
#
#
# OG Orders left:  2007756
# Cascade length:  30
# New Orders left:  2007726
# making new cascade
#
#
# OG Orders left:  2007726
# Cascade length:  3819
# New Orders left:  2003907
# making new cascade
#
#
# OG Orders left:  2003907
# Cascade length:  3278
# New Orders left:  2000629
# making new cascade
#
#
# OG Orders left:  2000629
# Cascade length:  30
# New Orders left:  2000599
# making new cascade
#
#
# OG Orders left:  2000599
# Cascade length:  2
# New Orders left:  2000597
# making new cascade
#
#
# OG Orders left:  2000597
# Cascade length:  2
# New Orders left:  2000595
# making new cascade
#
#
# OG Orders left:  2000595
# Cascade length:  1
# New Orders left:  2000594
# making new cascade
#
#
# OG Orders left:  2000594
# Cascade length:  3956
# New Orders left:  1996638
# making new cascade
#
#
# OG Orders left:  1996638
# Cascade length:  7
# New Orders left:  1996631
# making new cascade
#
#
# OG Orders left:  1996631
# Cascade length:  2816
# New Orders left:  1993815
# making new cascade
#
#
# OG Orders left:  1993815
# Cascade length:  17
# New Orders left:  1993798
# making new cascade
#
#
# OG Orders left:  1993798
# Cascade length:  3
# New Orders left:  1993795
# making new cascade
#
#
# OG Orders left:  1993795
# Cascade length:  3136
# New Orders left:  1990659
# making new cascade
#
#
# OG Orders left:  1990659
# Cascade length:  3190
# New Orders left:  1987469
# making new cascade
#
#
# OG Orders left:  1987469
# Cascade length:  2253
# New Orders left:  1985216
# making new cascade
#
#
# OG Orders left:  1985216
# Cascade length:  3765
# New Orders left:  1981451
# making new cascade
#
#
# OG Orders left:  1981451
# Cascade length:  4056
# New Orders left:  1977395
# making new cascade
#
#
# OG Orders left:  1977395
# Cascade length:  9
# New Orders left:  1977386
# making new cascade
#
#
# OG Orders left:  1977386
# Cascade length:  17
# New Orders left:  1977369
# making new cascade
#
#
# OG Orders left:  1977369
# Cascade length:  3064
# New Orders left:  1974305
# making new cascade
#
#
# OG Orders left:  1974305
# Cascade length:  18
# New Orders left:  1974287
# making new cascade
#
#
# OG Orders left:  1974287
# Cascade length:  1
# New Orders left:  1974286
# making new cascade
#
#
# OG Orders left:  1974286
# Cascade length:  14
# New Orders left:  1974272
# making new cascade
#
#
# OG Orders left:  1974272
# Cascade length:  2352
# New Orders left:  1971920
# making new cascade
#
#
# OG Orders left:  1971920
# Cascade length:  3561
# New Orders left:  1968359
# making new cascade
#
#
# OG Orders left:  1968359
# Cascade length:  44
# New Orders left:  1968315
# making new cascade
#
#
# OG Orders left:  1968315
# Cascade length:  1924
# New Orders left:  1966391
# making new cascade
#
#
# OG Orders left:  1966391
# Cascade length:  33
# New Orders left:  1966358
# making new cascade
#
#
# OG Orders left:  1966358
# Cascade length:  3
# New Orders left:  1966355
# making new cascade
#
#
# OG Orders left:  1966355
# Cascade length:  11
# New Orders left:  1966344
# making new cascade
#
#
# OG Orders left:  1966344
# Cascade length:  2248
# New Orders left:  1964096
# making new cascade
#
#
# OG Orders left:  1964096
# Cascade length:  3468
# New Orders left:  1960628
# making new cascade
#
#
# OG Orders left:  1960628
# Cascade length:  1872
# New Orders left:  1958756
# making new cascade
#
#
# OG Orders left:  1958756
# Cascade length:  4
# New Orders left:  1958752
# making new cascade
#
#
# OG Orders left:  1958752
# Cascade length:  2010
# New Orders left:  1956742
# making new cascade
#
#
# OG Orders left:  1956742
# Cascade length:  2491
# New Orders left:  1954251
# making new cascade
#
#
# OG Orders left:  1954251
# Cascade length:  2749
# New Orders left:  1951502
# making new cascade
#
#
# OG Orders left:  1951502
# Cascade length:  2858
# New Orders left:  1948644
# making new cascade
#
#
# OG Orders left:  1948644
# Cascade length:  1497
# New Orders left:  1947147
# making new cascade
#
#
# OG Orders left:  1947147
# Cascade length:  32
# New Orders left:  1947115
# making new cascade
#
#
# OG Orders left:  1947115
# Cascade length:  7
# New Orders left:  1947108
# making new cascade
#
#
# OG Orders left:  1947108
# Cascade length:  2
# New Orders left:  1947106
# making new cascade
#
#
# OG Orders left:  1947106
# Cascade length:  15
# New Orders left:  1947091
# making new cascade
#
#
# OG Orders left:  1947091
# Cascade length:  2720
# New Orders left:  1944371
# making new cascade
#
#
# OG Orders left:  1944371
# Cascade length:  1529
# New Orders left:  1942842
# making new cascade
#
#
# OG Orders left:  1942842
# Cascade length:  3966
# New Orders left:  1938876
# making new cascade
#
#
# OG Orders left:  1938876
# Cascade length:  2
# New Orders left:  1938874
# making new cascade
#
#
# OG Orders left:  1938874
# Cascade length:  2
# New Orders left:  1938872
# making new cascade
#
#
# OG Orders left:  1938872
# Cascade length:  2622
# New Orders left:  1936250
# making new cascade
#
#
# OG Orders left:  1936250
# Cascade length:  1
# New Orders left:  1936249
# making new cascade
#
#
# OG Orders left:  1936249
# Cascade length:  97
# New Orders left:  1936152
# making new cascade
#
#
# OG Orders left:  1936152
# Cascade length:  10
# New Orders left:  1936142
# making new cascade
#
#
# OG Orders left:  1936142
# Cascade length:  3
# New Orders left:  1936139
# making new cascade
#
#
# OG Orders left:  1936139
# Cascade length:  2798
# New Orders left:  1933341
# making new cascade
#
#
# OG Orders left:  1933341
# Cascade length:  3
# New Orders left:  1933338
# making new cascade
#
#
# OG Orders left:  1933338
# Cascade length:  2
# New Orders left:  1933336
# making new cascade
#
#
# OG Orders left:  1933336
# Cascade length:  2150
# New Orders left:  1931186
# making new cascade
#
#
# OG Orders left:  1931186
# Cascade length:  13
# New Orders left:  1931173
# making new cascade
#
#
# OG Orders left:  1931173
# Cascade length:  2081
# New Orders left:  1929092
# making new cascade
#
#
# OG Orders left:  1929092
# Cascade length:  21
# New Orders left:  1929071
# making new cascade
#
#
# OG Orders left:  1929071
# Cascade length:  2350
# New Orders left:  1926721
# making new cascade
#
#
# OG Orders left:  1926721
# Cascade length:  172
# New Orders left:  1926549
# making new cascade
#
#
# OG Orders left:  1926549
# Cascade length:  15
# New Orders left:  1926534
# making new cascade
#
#
# OG Orders left:  1926534
# Cascade length:  13
# New Orders left:  1926521
# making new cascade
#
#
# OG Orders left:  1926521
# Cascade length:  13
# New Orders left:  1926508
# making new cascade
#
#
# OG Orders left:  1926508
# Cascade length:  2799
# New Orders left:  1923709
# making new cascade
#
#
# OG Orders left:  1923709
# Cascade length:  2
# New Orders left:  1923707
# making new cascade
#
#
# OG Orders left:  1923707
# Cascade length:  24
# New Orders left:  1923683
# making new cascade
#
#
# OG Orders left:  1923683
# Cascade length:  2
# New Orders left:  1923681
# making new cascade
#
#
# OG Orders left:  1923681
# Cascade length:  1
# New Orders left:  1923680
# making new cascade
#
#
# OG Orders left:  1923680
# Cascade length:  18
# New Orders left:  1923662
# making new cascade
#
#
# OG Orders left:  1923662
# Cascade length:  27
# New Orders left:  1923635
# making new cascade
#
#
# OG Orders left:  1923635
# Cascade length:  4
# New Orders left:  1923631
# making new cascade
#
#
# OG Orders left:  1923631
# Cascade length:  2
# New Orders left:  1923629
# making new cascade
#
#
# OG Orders left:  1923629
# Cascade length:  2710
# New Orders left:  1920919
# making new cascade
#
#
# OG Orders left:  1920919
# Cascade length:  3309
# New Orders left:  1917610
# making new cascade
#
#
# OG Orders left:  1917610
# Cascade length:  9
# New Orders left:  1917601
# making new cascade
#
#
# OG Orders left:  1917601
# Cascade length:  1167
# New Orders left:  1916434
# making new cascade
#
#
# OG Orders left:  1916434
# Cascade length:  2350
# New Orders left:  1914084
# making new cascade
#
#
# OG Orders left:  1914084
# Cascade length:  20
# New Orders left:  1914064
# making new cascade
#
#
# OG Orders left:  1914064
# Cascade length:  10
# New Orders left:  1914054
# making new cascade
#
#
# OG Orders left:  1914054
# Cascade length:  33
# New Orders left:  1914021
# making new cascade
#
#
# OG Orders left:  1914021
# Cascade length:  6
# New Orders left:  1914015
# making new cascade
#
#
# OG Orders left:  1914015
# Cascade length:  9
# New Orders left:  1914006
# making new cascade
#
#
# OG Orders left:  1914006
# Cascade length:  1867
# New Orders left:  1912139
# making new cascade
#
#
# OG Orders left:  1912139
# Cascade length:  9
# New Orders left:  1912130
# making new cascade
#
#
# OG Orders left:  1912130
# Cascade length:  72
# New Orders left:  1912058
# making new cascade
#
#
# OG Orders left:  1912058
# Cascade length:  6
# New Orders left:  1912052
# making new cascade
#
#
# OG Orders left:  1912052
# Cascade length:  1633
# New Orders left:  1910419
# making new cascade
#
#
# OG Orders left:  1910419
# Cascade length:  3317
# New Orders left:  1907102
# making new cascade
#
#
# OG Orders left:  1907102
# Cascade length:  2
# New Orders left:  1907100
# making new cascade
#
#
# OG Orders left:  1907100
# Cascade length:  1652
# New Orders left:  1905448
# making new cascade
#
#
# OG Orders left:  1905448
# Cascade length:  66
# New Orders left:  1905382
# making new cascade
#
#
# OG Orders left:  1905382
# Cascade length:  1407
# New Orders left:  1903975
# making new cascade
#
#
# OG Orders left:  1903975
# Cascade length:  3175
# New Orders left:  1900800
# making new cascade
#
#
# OG Orders left:  1900800
# Cascade length:  16
# New Orders left:  1900784
# making new cascade
#
#
# OG Orders left:  1900784
# Cascade length:  4
# New Orders left:  1900780
# making new cascade
#
#
# OG Orders left:  1900780
# Cascade length:  60
# New Orders left:  1900720
# making new cascade
#
#
# OG Orders left:  1900720
# Cascade length:  20
# New Orders left:  1900700
# making new cascade
#
#
# OG Orders left:  1900700
# Cascade length:  2408
# New Orders left:  1898292
# making new cascade
#
#
# OG Orders left:  1898292
# Cascade length:  5
# New Orders left:  1898287
# making new cascade
#
#
# OG Orders left:  1898287
# Cascade length:  171
# New Orders left:  1898116
# making new cascade
#
#
# OG Orders left:  1898116
# Cascade length:  133
# New Orders left:  1897983
# making new cascade
#
#
# OG Orders left:  1897983
# Cascade length:  32
# New Orders left:  1897951
# making new cascade
#
#
# OG Orders left:  1897951
# Cascade length:  1681
# New Orders left:  1896270
# making new cascade
#
#
# OG Orders left:  1896270
# Cascade length:  1770
# New Orders left:  1894500
# making new cascade
#
#
# OG Orders left:  1894500
# Cascade length:  15
# New Orders left:  1894485
# making new cascade
#
#
# OG Orders left:  1894485
# Cascade length:  1518
# New Orders left:  1892967
# making new cascade
#
#
# OG Orders left:  1892967
# Cascade length:  2
# New Orders left:  1892965
# making new cascade
#
#
# OG Orders left:  1892965
# Cascade length:  2784
# New Orders left:  1890181
# making new cascade
#
#
# OG Orders left:  1890181
# Cascade length:  4
# New Orders left:  1890177
# making new cascade
#
#
# OG Orders left:  1890177
# Cascade length:  2113
# New Orders left:  1888064
# making new cascade
#
#
# OG Orders left:  1888064
# Cascade length:  2
# New Orders left:  1888062
# making new cascade
#
#
# OG Orders left:  1888062
# Cascade length:  2
# New Orders left:  1888060
# making new cascade
#
#
# OG Orders left:  1888060
# Cascade length:  2476
# New Orders left:  1885584
# making new cascade
#
#
# OG Orders left:  1885584
# Cascade length:  1689
# New Orders left:  1883895
# making new cascade
#
#
# OG Orders left:  1883895
# Cascade length:  1313
# New Orders left:  1882582
# making new cascade
#
#
# OG Orders left:  1882582
# Cascade length:  1849
# New Orders left:  1880733
# making new cascade
#
#
# OG Orders left:  1880733
# Cascade length:  27
# New Orders left:  1880706
# making new cascade
#
#
# OG Orders left:  1880706
# Cascade length:  1129
# New Orders left:  1879577
# making new cascade
#
#
# OG Orders left:  1879577
# Cascade length:  10
# New Orders left:  1879567
# making new cascade
#
#
# OG Orders left:  1879567
# Cascade length:  1103
# New Orders left:  1878464
# making new cascade
#
#
# OG Orders left:  1878464
# Cascade length:  1062
# New Orders left:  1877402
# making new cascade
#
#
# OG Orders left:  1877402
# Cascade length:  35
# New Orders left:  1877367
# making new cascade
#
#
# OG Orders left:  1877367
# Cascade length:  2297
# New Orders left:  1875070
# making new cascade
#
#
# OG Orders left:  1875070
# Cascade length:  37
# New Orders left:  1875033
# making new cascade
#
#
# OG Orders left:  1875033
# Cascade length:  4
# New Orders left:  1875029
# making new cascade
#
#
# OG Orders left:  1875029
# Cascade length:  2769
# New Orders left:  1872260
# making new cascade
#
#
# OG Orders left:  1872260
# Cascade length:  11
# New Orders left:  1872249
# making new cascade
#
#
# OG Orders left:  1872249
# Cascade length:  75
# New Orders left:  1872174
# making new cascade
#
#
# OG Orders left:  1872174
# Cascade length:  1191
# New Orders left:  1870983
# making new cascade
#
#
# OG Orders left:  1870983
# Cascade length:  39
# New Orders left:  1870944
# making new cascade
#
#
# OG Orders left:  1870944
# Cascade length:  763
# New Orders left:  1870181
# making new cascade
#
#
# OG Orders left:  1870181
# Cascade length:  1066
# New Orders left:  1869115
# making new cascade
#
#
# OG Orders left:  1869115
# Cascade length:  25
# New Orders left:  1869090
# making new cascade
#
#
# OG Orders left:  1869090
# Cascade length:  117
# New Orders left:  1868973
# making new cascade
#
#
# OG Orders left:  1868973
# Cascade length:  1470
# New Orders left:  1867503
# making new cascade
#
#
# OG Orders left:  1867503
# Cascade length:  2186
# New Orders left:  1865317
# making new cascade
#
#
# OG Orders left:  1865317
# Cascade length:  1781
# New Orders left:  1863536
# making new cascade
#
#
# OG Orders left:  1863536
# Cascade length:  59
# New Orders left:  1863477
# making new cascade
#
#
# OG Orders left:  1863477
# Cascade length:  2
# New Orders left:  1863475
# making new cascade
#
#
# OG Orders left:  1863475
# Cascade length:  1743
# New Orders left:  1861732
# making new cascade
#
#
# OG Orders left:  1861732
# Cascade length:  16
# New Orders left:  1861716
# making new cascade
#
#
# OG Orders left:  1861716
# Cascade length:  45
# New Orders left:  1861671
# making new cascade
#
#
# OG Orders left:  1861671
# Cascade length:  2000
# New Orders left:  1859671
# making new cascade
#
#
# OG Orders left:  1859671
# Cascade length:  1735
# New Orders left:  1857936
# making new cascade
#
#
# OG Orders left:  1857936
# Cascade length:  21
# New Orders left:  1857915
# making new cascade
#
#
# OG Orders left:  1857915
# Cascade length:  240
# New Orders left:  1857675
# making new cascade
#
#
# OG Orders left:  1857675
# Cascade length:  15
# New Orders left:  1857660
# making new cascade
#
#
# OG Orders left:  1857660
# Cascade length:  12
# New Orders left:  1857648
# making new cascade
#
#
# OG Orders left:  1857648
# Cascade length:  4
# New Orders left:  1857644
# making new cascade
#
#
# OG Orders left:  1857644
# Cascade length:  10
# New Orders left:  1857634
# making new cascade
#
#
# OG Orders left:  1857634
# Cascade length:  552
# New Orders left:  1857082
# making new cascade
#
#
# OG Orders left:  1857082
# Cascade length:  46
# New Orders left:  1857036
# making new cascade
#
#
# OG Orders left:  1857036
# Cascade length:  5
# New Orders left:  1857031
# making new cascade
#
#
# OG Orders left:  1857031
# Cascade length:  2188
# New Orders left:  1854843
# making new cascade
#
#
# OG Orders left:  1854843
# Cascade length:  1447
# New Orders left:  1853396
# making new cascade
#
#
# OG Orders left:  1853396
# Cascade length:  3
# New Orders left:  1853393
# making new cascade
#
#
# OG Orders left:  1853393
# Cascade length:  878
# New Orders left:  1852515
# making new cascade
#
#
# OG Orders left:  1852515
# Cascade length:  1
# New Orders left:  1852514
# making new cascade
#
#
# OG Orders left:  1852514
# Cascade length:  60
# New Orders left:  1852454
# making new cascade
#
#
# OG Orders left:  1852454
# Cascade length:  1573
# New Orders left:  1850881
# making new cascade
#
#
# OG Orders left:  1850881
# Cascade length:  1
# New Orders left:  1850880
# making new cascade
#
#
# OG Orders left:  1850880
# Cascade length:  1
# New Orders left:  1850879
# making new cascade
#
#
# OG Orders left:  1850879
# Cascade length:  54
# New Orders left:  1850825
# making new cascade
#
#
# OG Orders left:  1850825
# Cascade length:  1
# New Orders left:  1850824
# making new cascade
#
#
# OG Orders left:  1850824
# Cascade length:  2
# New Orders left:  1850822
# making new cascade
#
#
# OG Orders left:  1850822
# Cascade length:  2942
# New Orders left:  1847880
# making new cascade
#
#
# OG Orders left:  1847880
# Cascade length:  35
# New Orders left:  1847845
# making new cascade
#
#
# OG Orders left:  1847845
# Cascade length:  1
# New Orders left:  1847844
# making new cascade
#
#
# OG Orders left:  1847844
# Cascade length:  726
# New Orders left:  1847118
# making new cascade
#
#
# OG Orders left:  1847118
# Cascade length:  7
# New Orders left:  1847111
# making new cascade
#
#
# OG Orders left:  1847111
# Cascade length:  332
# New Orders left:  1846779
# making new cascade
#
#
# OG Orders left:  1846779
# Cascade length:  6
# New Orders left:  1846773
# making new cascade
#
#
# OG Orders left:  1846773
# Cascade length:  123
# New Orders left:  1846650
# making new cascade
#
#
# OG Orders left:  1846650
# Cascade length:  1
# New Orders left:  1846649
# making new cascade
#
#
# OG Orders left:  1846649
# Cascade length:  14
# New Orders left:  1846635
# making new cascade
#
#
# OG Orders left:  1846635
# Cascade length:  199
# New Orders left:  1846436
# making new cascade
#
#
# OG Orders left:  1846436
# Cascade length:  1
# New Orders left:  1846435
# making new cascade
#
#
# OG Orders left:  1846435
# Cascade length:  2160
# New Orders left:  1844275
# making new cascade
#
#
# OG Orders left:  1844275
# Cascade length:  5
# New Orders left:  1844270
# making new cascade
#
#
# OG Orders left:  1844270
# Cascade length:  37
# New Orders left:  1844233
# making new cascade
#
#
# OG Orders left:  1844233
# Cascade length:  14
# New Orders left:  1844219
# making new cascade
#
#
# OG Orders left:  1844219
# Cascade length:  2
# New Orders left:  1844217
# making new cascade
#
#
# OG Orders left:  1844217
# Cascade length:  2578
# New Orders left:  1841639
# making new cascade
#
#
# OG Orders left:  1841639
# Cascade length:  791
# New Orders left:  1840848
# making new cascade
#
#
# OG Orders left:  1840848
# Cascade length:  1
# New Orders left:  1840847
# making new cascade
#
#
# OG Orders left:  1840847
# Cascade length:  1
# New Orders left:  1840846
# making new cascade
#
#
# OG Orders left:  1840846
# Cascade length:  2
# New Orders left:  1840844
# making new cascade
#
#
# OG Orders left:  1840844
# Cascade length:  23
# New Orders left:  1840821
# making new cascade
#
#
# OG Orders left:  1840821
# Cascade length:  674
# New Orders left:  1840147
# making new cascade
#
#
# OG Orders left:  1840147
# Cascade length:  27
# New Orders left:  1840120
# making new cascade
#
#
# OG Orders left:  1840120
# Cascade length:  1642
# New Orders left:  1838478
# making new cascade
#
#
# OG Orders left:  1838478
# Cascade length:  2031
# New Orders left:  1836447
# making new cascade
#
#
# OG Orders left:  1836447
# Cascade length:  1461
# New Orders left:  1834986
# making new cascade
#
#
# OG Orders left:  1834986
# Cascade length:  20
# New Orders left:  1834966
# making new cascade
#
#
# OG Orders left:  1834966
# Cascade length:  2
# New Orders left:  1834964
# making new cascade
#
#
# OG Orders left:  1834964
# Cascade length:  131
# New Orders left:  1834833
# making new cascade
#
#
# OG Orders left:  1834833
# Cascade length:  781
# New Orders left:  1834052
# making new cascade
#
#
# OG Orders left:  1834052
# Cascade length:  7
# New Orders left:  1834045
# making new cascade
#
#
# OG Orders left:  1834045
# Cascade length:  1
# New Orders left:  1834044
# making new cascade
#
#
# OG Orders left:  1834044
# Cascade length:  76
# New Orders left:  1833968
# making new cascade
#
#
# OG Orders left:  1833968
# Cascade length:  454
# New Orders left:  1833514
# making new cascade
#
#
# OG Orders left:  1833514
# Cascade length:  2795
# New Orders left:  1830719
# making new cascade
#
#
# OG Orders left:  1830719
# Cascade length:  12
# New Orders left:  1830707
# making new cascade
#
#
# OG Orders left:  1830707
# Cascade length:  517
# New Orders left:  1830190
# making new cascade
#
#
# OG Orders left:  1830190
# Cascade length:  61
# New Orders left:  1830129
# making new cascade
#
#
# OG Orders left:  1830129
# Cascade length:  2
# New Orders left:  1830127
# making new cascade
#
#
# OG Orders left:  1830127
# Cascade length:  2
# New Orders left:  1830125
# making new cascade
#
#
# OG Orders left:  1830125
# Cascade length:  110
# New Orders left:  1830015
# making new cascade
#
#
# OG Orders left:  1830015
# Cascade length:  45
# New Orders left:  1829970
# making new cascade
#
#
# OG Orders left:  1829970
# Cascade length:  4
# New Orders left:  1829966
# making new cascade
#
#
# OG Orders left:  1829966
# Cascade length:  78
# New Orders left:  1829888
# making new cascade
#
#
# OG Orders left:  1829888
# Cascade length:  100
# New Orders left:  1829788
# making new cascade
#
#
# OG Orders left:  1829788
# Cascade length:  37
# New Orders left:  1829751
# making new cascade
#
#
# OG Orders left:  1829751
# Cascade length:  362
# New Orders left:  1829389
# making new cascade
#
#
# OG Orders left:  1829389
# Cascade length:  620
# New Orders left:  1828769
# making new cascade
#
#
# OG Orders left:  1828769
# Cascade length:  2
# New Orders left:  1828767
# making new cascade
#
#
# OG Orders left:  1828767
# Cascade length:  15
# New Orders left:  1828752
# making new cascade
#
#
# OG Orders left:  1828752
# Cascade length:  10
# New Orders left:  1828742
# making new cascade
#
#
# OG Orders left:  1828742
# Cascade length:  1659
# New Orders left:  1827083
# making new cascade
#
#
# OG Orders left:  1827083
# Cascade length:  2
# New Orders left:  1827081
# making new cascade
#
#
# OG Orders left:  1827081
# Cascade length:  179
# New Orders left:  1826902
# making new cascade
#
#
# OG Orders left:  1826902
# Cascade length:  176
# New Orders left:  1826726
# making new cascade
#
#
# OG Orders left:  1826726
# Cascade length:  652
# New Orders left:  1826074
# making new cascade
#
#
# OG Orders left:  1826074
# Cascade length:  39
# New Orders left:  1826035
# making new cascade
#
#
# OG Orders left:  1826035
# Cascade length:  932
# New Orders left:  1825103
# making new cascade
#
#
# OG Orders left:  1825103
# Cascade length:  113
# New Orders left:  1824990
# making new cascade
#
#
# OG Orders left:  1824990
# Cascade length:  3
# New Orders left:  1824987
# making new cascade
#
#
# OG Orders left:  1824987
# Cascade length:  29
# New Orders left:  1824958
# making new cascade
#
#
# OG Orders left:  1824958
# Cascade length:  134
# New Orders left:  1824824
# making new cascade
#
#
# OG Orders left:  1824824
# Cascade length:  396
# New Orders left:  1824428
# making new cascade
#
#
# OG Orders left:  1824428
# Cascade length:  109
# New Orders left:  1824319
# making new cascade
#
#
# OG Orders left:  1824319
# Cascade length:  3
# New Orders left:  1824316
# making new cascade
#
#
# OG Orders left:  1824316
# Cascade length:  210
# New Orders left:  1824106
# making new cascade
#
#
# OG Orders left:  1824106
# Cascade length:  29
# New Orders left:  1824077
# making new cascade
#
#
# OG Orders left:  1824077
# Cascade length:  1192
# New Orders left:  1822885
# making new cascade
#
#
# OG Orders left:  1822885
# Cascade length:  74
# New Orders left:  1822811
# making new cascade
#
#
# OG Orders left:  1822811
# Cascade length:  244
# New Orders left:  1822567
# making new cascade
#
#
# OG Orders left:  1822567
# Cascade length:  68
# New Orders left:  1822499
# making new cascade
#
#
# OG Orders left:  1822499
# Cascade length:  180
# New Orders left:  1822319
# making new cascade
#
#
# OG Orders left:  1822319
# Cascade length:  7
# New Orders left:  1822312
# making new cascade
#
#
# OG Orders left:  1822312
# Cascade length:  49
# New Orders left:  1822263
# making new cascade
#
#
# OG Orders left:  1822263
# Cascade length:  2
# New Orders left:  1822261
# making new cascade
#
#
# OG Orders left:  1822261
# Cascade length:  3
# New Orders left:  1822258
# making new cascade
#
#
# OG Orders left:  1822258
# Cascade length:  689
# New Orders left:  1821569
# making new cascade
#
#
# OG Orders left:  1821569
# Cascade length:  34
# New Orders left:  1821535
# making new cascade
#
#
# OG Orders left:  1821535
# Cascade length:  8
# New Orders left:  1821527
# making new cascade
#
#
# OG Orders left:  1821527
# Cascade length:  14
# New Orders left:  1821513
# making new cascade
#
#
# OG Orders left:  1821513
# Cascade length:  181
# New Orders left:  1821332
# making new cascade
#
#
# OG Orders left:  1821332
# Cascade length:  2
# New Orders left:  1821330
# making new cascade
#
#
# OG Orders left:  1821330
# Cascade length:  471
# New Orders left:  1820859
# making new cascade
#
#
# OG Orders left:  1820859
# Cascade length:  120
# New Orders left:  1820739
# making new cascade
#
#
# OG Orders left:  1820739
# Cascade length:  2
# New Orders left:  1820737
# making new cascade
#
#
# OG Orders left:  1820737
# Cascade length:  105
# New Orders left:  1820632
# making new cascade
#
#
# OG Orders left:  1820632
# Cascade length:  3
# New Orders left:  1820629
# making new cascade
#
#
# OG Orders left:  1820629
# Cascade length:  315
# New Orders left:  1820314
# making new cascade
#
#
# OG Orders left:  1820314
# Cascade length:  12
# New Orders left:  1820302
# making new cascade
#
#
# OG Orders left:  1820302
# Cascade length:  775
# New Orders left:  1819527
# making new cascade
#
#
# OG Orders left:  1819527
# Cascade length:  37
# New Orders left:  1819490
# making new cascade
#
#
# OG Orders left:  1819490
# Cascade length:  2
# New Orders left:  1819488
# making new cascade
#
#
# OG Orders left:  1819488
# Cascade length:  724
# New Orders left:  1818764
# making new cascade
#
#
# OG Orders left:  1818764
# Cascade length:  16
# New Orders left:  1818748
# making new cascade
#
#
# OG Orders left:  1818748
# Cascade length:  105
# New Orders left:  1818643
# making new cascade
#
#
# OG Orders left:  1818643
# Cascade length:  2
# New Orders left:  1818641
# making new cascade
#
#
# OG Orders left:  1818641
# Cascade length:  661
# New Orders left:  1817980
# making new cascade
#
#
# OG Orders left:  1817980
# Cascade length:  95
# New Orders left:  1817885
# making new cascade
#
#
# OG Orders left:  1817885
# Cascade length:  23
# New Orders left:  1817862
# making new cascade
#
#
# OG Orders left:  1817862
# Cascade length:  46
# New Orders left:  1817816
# making new cascade
#
#
# OG Orders left:  1817816
# Cascade length:  1007
# New Orders left:  1816809
# making new cascade
#
#
# OG Orders left:  1816809
# Cascade length:  129
# New Orders left:  1816680
# making new cascade
#
#
# OG Orders left:  1816680
# Cascade length:  52
# New Orders left:  1816628
# making new cascade
#
#
# OG Orders left:  1816628
# Cascade length:  934
# New Orders left:  1815694
# making new cascade
#
#
# OG Orders left:  1815694
# Cascade length:  287
# New Orders left:  1815407
# making new cascade
#
#
# OG Orders left:  1815407
# Cascade length:  799
# New Orders left:  1814608
# making new cascade
#
#
# OG Orders left:  1814608
# Cascade length:  348
# New Orders left:  1814260
# making new cascade
#
#
# OG Orders left:  1814260
# Cascade length:  17
# New Orders left:  1814243
# making new cascade
#
#
# OG Orders left:  1814243
# Cascade length:  519
# New Orders left:  1813724
# making new cascade
#
#
# OG Orders left:  1813724
# Cascade length:  87
# New Orders left:  1813637
# making new cascade
#
#
# OG Orders left:  1813637
# Cascade length:  477
# New Orders left:  1813160
# making new cascade
#
#
# OG Orders left:  1813160
# Cascade length:  30
# New Orders left:  1813130
# making new cascade
#
#
# OG Orders left:  1813130
# Cascade length:  2037
# New Orders left:  1811093
# making new cascade
#
#
# OG Orders left:  1811093
# Cascade length:  1480
# New Orders left:  1809613
# making new cascade
#
#
# OG Orders left:  1809613
# Cascade length:  162
# New Orders left:  1809451
# making new cascade
#
#
# OG Orders left:  1809451
# Cascade length:  142
# New Orders left:  1809309
# making new cascade
#
#
# OG Orders left:  1809309
# Cascade length:  1466
# New Orders left:  1807843
# making new cascade
#
#
# OG Orders left:  1807843
# Cascade length:  76
# New Orders left:  1807767
# making new cascade
#
#
# OG Orders left:  1807767
# Cascade length:  1451
# New Orders left:  1806316
# making new cascade
#
#
# OG Orders left:  1806316
# Cascade length:  83
# New Orders left:  1806233
# making new cascade
#
#
# OG Orders left:  1806233
# Cascade length:  4
# New Orders left:  1806229
# making new cascade
#
#
# OG Orders left:  1806229
# Cascade length:  5
# New Orders left:  1806224
# making new cascade
#
#
# OG Orders left:  1806224
# Cascade length:  8
# New Orders left:  1806216
# making new cascade
#
#
# OG Orders left:  1806216
# Cascade length:  859
# New Orders left:  1805357
# making new cascade
#
#
# OG Orders left:  1805357
# Cascade length:  1273
# New Orders left:  1804084
# making new cascade
#
#
# OG Orders left:  1804084
# Cascade length:  20
# New Orders left:  1804064
# making new cascade
#
#
# OG Orders left:  1804064
# Cascade length:  500
# New Orders left:  1803564
# making new cascade
#
#
# OG Orders left:  1803564
# Cascade length:  4
# New Orders left:  1803560
# making new cascade
#
#
# OG Orders left:  1803560
# Cascade length:  168
# New Orders left:  1803392
# making new cascade
#
#
# OG Orders left:  1803392
# Cascade length:  63
# New Orders left:  1803329
# making new cascade
#
#
# OG Orders left:  1803329
# Cascade length:  8
# New Orders left:  1803321
# making new cascade
#
#
# OG Orders left:  1803321
# Cascade length:  73
# New Orders left:  1803248
# making new cascade
#
#
# OG Orders left:  1803248
# Cascade length:  40
# New Orders left:  1803208
# making new cascade
#
#
# OG Orders left:  1803208
# Cascade length:  14
# New Orders left:  1803194
# making new cascade
#
#
# OG Orders left:  1803194
# Cascade length:  11
# New Orders left:  1803183
# making new cascade
#
#
# OG Orders left:  1803183
# Cascade length:  41
# New Orders left:  1803142
# making new cascade
#
#
# OG Orders left:  1803142
# Cascade length:  550
# New Orders left:  1802592
# making new cascade
#
#
# OG Orders left:  1802592
# Cascade length:  1681
# New Orders left:  1800911
# making new cascade
#
#
# OG Orders left:  1800911
# Cascade length:  2
# New Orders left:  1800909
# making new cascade
#
#
# OG Orders left:  1800909
# Cascade length:  4
# New Orders left:  1800905
# making new cascade
#
#
# OG Orders left:  1800905
# Cascade length:  2041
# New Orders left:  1798864
# making new cascade
#
#
# OG Orders left:  1798864
# Cascade length:  1569
# New Orders left:  1797295
# making new cascade
#
#
# OG Orders left:  1797295
# Cascade length:  54
# New Orders left:  1797241
# making new cascade
#
#
# OG Orders left:  1797241
# Cascade length:  97
# New Orders left:  1797144
# making new cascade
#
#
# OG Orders left:  1797144
# Cascade length:  54
# New Orders left:  1797090
# making new cascade
#
#
# OG Orders left:  1797090
# Cascade length:  725
# New Orders left:  1796365
# making new cascade
#
#
# OG Orders left:  1796365
# Cascade length:  4
# New Orders left:  1796361
# making new cascade
#
#
# OG Orders left:  1796361
# Cascade length:  3
# New Orders left:  1796358
# making new cascade
#
#
# OG Orders left:  1796358
# Cascade length:  45
# New Orders left:  1796313
# making new cascade
#
#
# OG Orders left:  1796313
# Cascade length:  95
# New Orders left:  1796218
# making new cascade
#
#
# OG Orders left:  1796218
# Cascade length:  105
# New Orders left:  1796113
# making new cascade
#
#
# OG Orders left:  1796113
# Cascade length:  14
# New Orders left:  1796099
# making new cascade
#
#
# OG Orders left:  1796099
# Cascade length:  1099
# New Orders left:  1795000
# making new cascade
#
#
# OG Orders left:  1795000
# Cascade length:  6
# New Orders left:  1794994
# making new cascade
#
#
# OG Orders left:  1794994
# Cascade length:  1
# New Orders left:  1794993
# making new cascade
#
#
# OG Orders left:  1794993
# Cascade length:  1
# New Orders left:  1794992
# making new cascade
#
#
# OG Orders left:  1794992
# Cascade length:  1157
# New Orders left:  1793835
# making new cascade
#
#
# OG Orders left:  1793835
# Cascade length:  1
# New Orders left:  1793834
# making new cascade
#
#
# OG Orders left:  1793834
# Cascade length:  4
# New Orders left:  1793830
# making new cascade
#
#
# OG Orders left:  1793830
# Cascade length:  66
# New Orders left:  1793764
# making new cascade
#
#
# OG Orders left:  1793764
# Cascade length:  10
# New Orders left:  1793754
# making new cascade
#
#
# OG Orders left:  1793754
# Cascade length:  277
# New Orders left:  1793477
# making new cascade
#
#
# OG Orders left:  1793477
# Cascade length:  4
# New Orders left:  1793473
# making new cascade
#
#
# OG Orders left:  1793473
# Cascade length:  57
# New Orders left:  1793416
# making new cascade
#
#
# OG Orders left:  1793416
# Cascade length:  2
# New Orders left:  1793414
# making new cascade
#
#
# OG Orders left:  1793414
# Cascade length:  1439
# New Orders left:  1791975
# making new cascade
#
#
# OG Orders left:  1791975
# Cascade length:  2
# New Orders left:  1791973
# making new cascade
#
#
# OG Orders left:  1791973
# Cascade length:  73
# New Orders left:  1791900
# making new cascade
#
#
# OG Orders left:  1791900
# Cascade length:  873
# New Orders left:  1791027
# making new cascade
#
#
# OG Orders left:  1791027
# Cascade length:  53
# New Orders left:  1790974
# making new cascade
#
#
# OG Orders left:  1790974
# Cascade length:  1529
# New Orders left:  1789445
# making new cascade
#
#
# OG Orders left:  1789445
# Cascade length:  84
# New Orders left:  1789361
# making new cascade
#
#
# OG Orders left:  1789361
# Cascade length:  1
# New Orders left:  1789360
# making new cascade
#
#
# OG Orders left:  1789360
# Cascade length:  1523
# New Orders left:  1787837
# making new cascade
#
#
# OG Orders left:  1787837
# Cascade length:  1101
# New Orders left:  1786736
# making new cascade
#
#
# OG Orders left:  1786736
# Cascade length:  9
# New Orders left:  1786727
# making new cascade
#
#
# OG Orders left:  1786727
# Cascade length:  6
# New Orders left:  1786721
# making new cascade
#
#
# OG Orders left:  1786721
# Cascade length:  72
# New Orders left:  1786649
# making new cascade
#
#
# OG Orders left:  1786649
# Cascade length:  122
# New Orders left:  1786527
# making new cascade
#
#
# OG Orders left:  1786527
# Cascade length:  1958
# New Orders left:  1784569
# making new cascade
#
#
# OG Orders left:  1784569
# Cascade length:  203
# New Orders left:  1784366
# making new cascade
#
#
# OG Orders left:  1784366
# Cascade length:  135
# New Orders left:  1784231
# making new cascade
#
#
# OG Orders left:  1784231
# Cascade length:  5
# New Orders left:  1784226
# making new cascade
#
#
# OG Orders left:  1784226
# Cascade length:  23
# New Orders left:  1784203
# making new cascade
#
#
# OG Orders left:  1784203
# Cascade length:  61
# New Orders left:  1784142
# making new cascade
#
#
# OG Orders left:  1784142
# Cascade length:  551
# New Orders left:  1783591
# making new cascade
#
#
# OG Orders left:  1783591
# Cascade length:  224
# New Orders left:  1783367
# making new cascade
#
#
# OG Orders left:  1783367
# Cascade length:  2692
# New Orders left:  1780675
# making new cascade
#
#
# OG Orders left:  1780675
# Cascade length:  24
# New Orders left:  1780651
# making new cascade
#
#
# OG Orders left:  1780651
# Cascade length:  363
# New Orders left:  1780288
# making new cascade
#
#
# OG Orders left:  1780288
# Cascade length:  38
# New Orders left:  1780250
# making new cascade
#
#
# OG Orders left:  1780250
# Cascade length:  1
# New Orders left:  1780249
# making new cascade
#
#
# OG Orders left:  1780249
# Cascade length:  61
# New Orders left:  1780188
# making new cascade
#
#
# OG Orders left:  1780188
# Cascade length:  29
# New Orders left:  1780159
# making new cascade
#
#
# OG Orders left:  1780159
# Cascade length:  26
# New Orders left:  1780133
# making new cascade
#
#
# OG Orders left:  1780133
# Cascade length:  33
# New Orders left:  1780100
# making new cascade
#
#
# OG Orders left:  1780100
# Cascade length:  296
# New Orders left:  1779804
# making new cascade
#
#
# OG Orders left:  1779804
# Cascade length:  9
# New Orders left:  1779795
# making new cascade
#
#
# OG Orders left:  1779795
# Cascade length:  32
# New Orders left:  1779763
# making new cascade
#
#
# OG Orders left:  1779763
# Cascade length:  93
# New Orders left:  1779670
# making new cascade
#
#
# OG Orders left:  1779670
# Cascade length:  1165
# New Orders left:  1778505
# making new cascade
#
#
# OG Orders left:  1778505
# Cascade length:  2
# New Orders left:  1778503
# making new cascade
#
#
# OG Orders left:  1778503
# Cascade length:  6
# New Orders left:  1778497
# making new cascade
#
#
# OG Orders left:  1778497
# Cascade length:  2
# New Orders left:  1778495
# making new cascade
#
#
# OG Orders left:  1778495
# Cascade length:  562
# New Orders left:  1777933
# making new cascade
#
#
# OG Orders left:  1777933
# Cascade length:  8
# New Orders left:  1777925
# making new cascade
#
#
# OG Orders left:  1777925
# Cascade length:  106
# New Orders left:  1777819
# making new cascade
#
#
# OG Orders left:  1777819
# Cascade length:  101
# New Orders left:  1777718
# making new cascade
#
#
# OG Orders left:  1777718
# Cascade length:  1484
# New Orders left:  1776234
# making new cascade
#
#
# OG Orders left:  1776234
# Cascade length:  2
# New Orders left:  1776232
# making new cascade
#
#
# OG Orders left:  1776232
# Cascade length:  57
# New Orders left:  1776175
# making new cascade
#
#
# OG Orders left:  1776175
# Cascade length:  76
# New Orders left:  1776099
# making new cascade
#
#
# OG Orders left:  1776099
# Cascade length:  4
# New Orders left:  1776095
# making new cascade
#
#
# OG Orders left:  1776095
# Cascade length:  3
# New Orders left:  1776092
# making new cascade
#
#
# OG Orders left:  1776092
# Cascade length:  71
# New Orders left:  1776021
# making new cascade
#
#
# OG Orders left:  1776021
# Cascade length:  40
# New Orders left:  1775981
# making new cascade
#
#
# OG Orders left:  1775981
# Cascade length:  21
# New Orders left:  1775960
# making new cascade
#
#
# OG Orders left:  1775960
# Cascade length:  112
# New Orders left:  1775848
# making new cascade
#
#
# OG Orders left:  1775848
# Cascade length:  1180
# New Orders left:  1774668
# making new cascade
#
#
# OG Orders left:  1774668
# Cascade length:  85
# New Orders left:  1774583
# making new cascade
#
#
# OG Orders left:  1774583
# Cascade length:  545
# New Orders left:  1774038
# making new cascade
#
#
# OG Orders left:  1774038
# Cascade length:  404
# New Orders left:  1773634
# making new cascade
#
#
# OG Orders left:  1773634
# Cascade length:  5
# New Orders left:  1773629
# making new cascade
#
#
# OG Orders left:  1773629
# Cascade length:  4
# New Orders left:  1773625
# making new cascade
#
#
# OG Orders left:  1773625
# Cascade length:  31
# New Orders left:  1773594
# making new cascade
#
#
# OG Orders left:  1773594
# Cascade length:  3
# New Orders left:  1773591
# making new cascade
#
#
# OG Orders left:  1773591
# Cascade length:  3
# New Orders left:  1773588
# making new cascade
#
#
# OG Orders left:  1773588
# Cascade length:  10
# New Orders left:  1773578
# making new cascade
#
#
# OG Orders left:  1773578
# Cascade length:  559
# New Orders left:  1773019
# making new cascade
#
#
# OG Orders left:  1773019
# Cascade length:  16
# New Orders left:  1773003
# making new cascade
#
#
# OG Orders left:  1773003
# Cascade length:  1023
# New Orders left:  1771980
# making new cascade
#
#
# OG Orders left:  1771980
# Cascade length:  79
# New Orders left:  1771901
# making new cascade
#
#
# OG Orders left:  1771901
# Cascade length:  4
# New Orders left:  1771897
# making new cascade
#
#
# OG Orders left:  1771897
# Cascade length:  7
# New Orders left:  1771890
# making new cascade
#
#
# OG Orders left:  1771890
# Cascade length:  16
# New Orders left:  1771874
# making new cascade
#
#
# OG Orders left:  1771874
# Cascade length:  5
# New Orders left:  1771869
# making new cascade
#
#
# OG Orders left:  1771869
# Cascade length:  2
# New Orders left:  1771867
# making new cascade
#
#
# OG Orders left:  1771867
# Cascade length:  2919
# New Orders left:  1768948
# making new cascade
#
#
# OG Orders left:  1768948
# Cascade length:  18
# New Orders left:  1768930
# making new cascade
#
#
# OG Orders left:  1768930
# Cascade length:  32
# New Orders left:  1768898
# making new cascade
#
#
# OG Orders left:  1768898
# Cascade length:  10
# New Orders left:  1768888
# making new cascade
#
#
# OG Orders left:  1768888
# Cascade length:  16
# New Orders left:  1768872
# making new cascade
#
#
# OG Orders left:  1768872
# Cascade length:  18
# New Orders left:  1768854
# making new cascade
#
#
# OG Orders left:  1768854
# Cascade length:  389
# New Orders left:  1768465
# making new cascade
#
#
# OG Orders left:  1768465
# Cascade length:  2461
# New Orders left:  1766004
# making new cascade
#
#
# OG Orders left:  1766004
# Cascade length:  1
# New Orders left:  1766003
# making new cascade
#
#
# OG Orders left:  1766003
# Cascade length:  52
# New Orders left:  1765951
# making new cascade
#
#
# OG Orders left:  1765951
# Cascade length:  114
# New Orders left:  1765837
# making new cascade
#
#
# OG Orders left:  1765837
# Cascade length:  22
# New Orders left:  1765815
# making new cascade
#
#
# OG Orders left:  1765815
# Cascade length:  3
# New Orders left:  1765812
# making new cascade
#
#
# OG Orders left:  1765812
# Cascade length:  791
# New Orders left:  1765021
# making new cascade
#
#
# OG Orders left:  1765021
# Cascade length:  2209
# New Orders left:  1762812
# making new cascade
#
#
# OG Orders left:  1762812
# Cascade length:  97
# New Orders left:  1762715
# making new cascade
#
#
# OG Orders left:  1762715
# Cascade length:  70
# New Orders left:  1762645
# making new cascade
#
#
# OG Orders left:  1762645
# Cascade length:  1
# New Orders left:  1762644
# making new cascade
#
#
# OG Orders left:  1762644
# Cascade length:  4
# New Orders left:  1762640
# making new cascade
#
#
# OG Orders left:  1762640
# Cascade length:  2871
# New Orders left:  1759769
# making new cascade
#
#
# OG Orders left:  1759769
# Cascade length:  804
# New Orders left:  1758965
# making new cascade
#
#
# OG Orders left:  1758965
# Cascade length:  142
# New Orders left:  1758823
# making new cascade
#
#
# OG Orders left:  1758823
# Cascade length:  99
# New Orders left:  1758724
# making new cascade
#
#
# OG Orders left:  1758724
# Cascade length:  2
# New Orders left:  1758722
# making new cascade
#
#
# OG Orders left:  1758722
# Cascade length:  1
# New Orders left:  1758721
# making new cascade
#
#
# OG Orders left:  1758721
# Cascade length:  22
# New Orders left:  1758699
# making new cascade
#
#
# OG Orders left:  1758699
# Cascade length:  73
# New Orders left:  1758626
# making new cascade
#
#
# OG Orders left:  1758626
# Cascade length:  25
# New Orders left:  1758601
# making new cascade
#
#
# OG Orders left:  1758601
# Cascade length:  7
# New Orders left:  1758594
# making new cascade
#
#
# OG Orders left:  1758594
# Cascade length:  9
# New Orders left:  1758585
# making new cascade
#
#
# OG Orders left:  1758585
# Cascade length:  5
# New Orders left:  1758580
# making new cascade
#
#
# OG Orders left:  1758580
# Cascade length:  1553
# New Orders left:  1757027
# making new cascade
#
#
# OG Orders left:  1757027
# Cascade length:  25
# New Orders left:  1757002
# making new cascade
#
#
# OG Orders left:  1757002
# Cascade length:  27
# New Orders left:  1756975
# making new cascade
#
#
# OG Orders left:  1756975
# Cascade length:  99
# New Orders left:  1756876
# making new cascade
#
#
# OG Orders left:  1756876
# Cascade length:  64
# New Orders left:  1756812
# making new cascade
#
#
# OG Orders left:  1756812
# Cascade length:  1344
# New Orders left:  1755468
# making new cascade
#
#
# OG Orders left:  1755468
# Cascade length:  40
# New Orders left:  1755428
# making new cascade
#
#
# OG Orders left:  1755428
# Cascade length:  159
# New Orders left:  1755269
# making new cascade
#
#
# OG Orders left:  1755269
# Cascade length:  18
# New Orders left:  1755251
# making new cascade
#
#
# OG Orders left:  1755251
# Cascade length:  61
# New Orders left:  1755190
# making new cascade
#
#
# OG Orders left:  1755190
# Cascade length:  332
# New Orders left:  1754858
# making new cascade
#
#
# OG Orders left:  1754858
# Cascade length:  744
# New Orders left:  1754114
# making new cascade
#
#
# OG Orders left:  1754114
# Cascade length:  1018
# New Orders left:  1753096
# making new cascade
#
#
# OG Orders left:  1753096
# Cascade length:  75
# New Orders left:  1753021
# making new cascade
#
#
# OG Orders left:  1753021
# Cascade length:  349
# New Orders left:  1752672
# making new cascade
#
#
# OG Orders left:  1752672
# Cascade length:  7
# New Orders left:  1752665
# making new cascade
#
#
# OG Orders left:  1752665
# Cascade length:  1
# New Orders left:  1752664
# making new cascade
#
#
# OG Orders left:  1752664
# Cascade length:  61
# New Orders left:  1752603
# making new cascade
#
#
# OG Orders left:  1752603
# Cascade length:  46
# New Orders left:  1752557
# making new cascade
#
#
# OG Orders left:  1752557
# Cascade length:  30
# New Orders left:  1752527
# making new cascade
#
#
# OG Orders left:  1752527
# Cascade length:  4
# New Orders left:  1752523
# making new cascade
#
#
# OG Orders left:  1752523
# Cascade length:  26
# New Orders left:  1752497
# making new cascade
#
#
# OG Orders left:  1752497
# Cascade length:  15
# New Orders left:  1752482
# making new cascade
#
#
# OG Orders left:  1752482
# Cascade length:  100
# New Orders left:  1752382
# making new cascade
#
#
# OG Orders left:  1752382
# Cascade length:  11
# New Orders left:  1752371
# making new cascade
#
#
# OG Orders left:  1752371
# Cascade length:  28
# New Orders left:  1752343
# making new cascade
#
#
# OG Orders left:  1752343
# Cascade length:  10
# New Orders left:  1752333
# making new cascade
#
#
# OG Orders left:  1752333
# Cascade length:  158
# New Orders left:  1752175
# making new cascade
#
#
# OG Orders left:  1752175
# Cascade length:  92
# New Orders left:  1752083
# making new cascade
#
#
# OG Orders left:  1752083
# Cascade length:  90
# New Orders left:  1751993
# making new cascade
#
#
# OG Orders left:  1751993
# Cascade length:  65
# New Orders left:  1751928
# making new cascade
#
#
# OG Orders left:  1751928
# Cascade length:  4
# New Orders left:  1751924
# making new cascade
#
#
# OG Orders left:  1751924
# Cascade length:  9
# New Orders left:  1751915
# making new cascade
#
#
# OG Orders left:  1751915
# Cascade length:  578
# New Orders left:  1751337
# making new cascade
#
#
# OG Orders left:  1751337
# Cascade length:  108
# New Orders left:  1751229
# making new cascade
#
#
# OG Orders left:  1751229
# Cascade length:  25
# New Orders left:  1751204
# making new cascade
#
#
# OG Orders left:  1751204
# Cascade length:  50
# New Orders left:  1751154
# making new cascade
#
#
# OG Orders left:  1751154
# Cascade length:  2
# New Orders left:  1751152
# making new cascade
#
#
# OG Orders left:  1751152
# Cascade length:  3
# New Orders left:  1751149
# making new cascade
#
#
# OG Orders left:  1751149
# ...
#
#
# OG Orders left:  8265
# Cascade length:  6
# New Orders left:  8259
# making new cascade
#
#
# OG Orders left:  8259
# Cascade length:  25
# New Orders left:  8234
# making new cascade
#
#
# OG Orders left:  8234
# Cascade length:  129
# New Orders left:  8105
# making new cascade
#
#
# OG Orders left:  8105
# Cascade length:  1
# New Orders left:  8104
# making new cascade
#
#
# OG Orders left:  8104
# Cascade length:  102
# New Orders left:  8002
# making new cascade
#
#
# OG Orders left:  8002
# Cascade length:  179
# New Orders left:  7823
# making new cascade
#
#
# OG Orders left:  7823
# Cascade length:  1
# New Orders left:  7822
# making new cascade
#
#
# OG Orders left:  7822
# Cascade length:  128
# New Orders left:  7694
# making new cascade
#
#
# OG Orders left:  7694
# Cascade length:  79
# New Orders left:  7615
# making new cascade
#
#
# OG Orders left:  7615
# Cascade length:  122
# New Orders left:  7493
# making new cascade
#
#
# OG Orders left:  7493
# Cascade length:  315
# New Orders left:  7178
# making new cascade
#
#
# OG Orders left:  7178
# Cascade length:  91
# New Orders left:  7087
# making new cascade
#
#
# OG Orders left:  7087
# Cascade length:  15
# New Orders left:  7072
# making new cascade
#
#
# OG Orders left:  7072
# Cascade length:  2
# New Orders left:  7070
# making new cascade
#
#
# OG Orders left:  7070
# Cascade length:  6
# New Orders left:  7064
# making new cascade
#
#
# OG Orders left:  7064
# Cascade length:  11
# New Orders left:  7053
# making new cascade
#
#
# OG Orders left:  7053
# Cascade length:  221
# New Orders left:  6832
# making new cascade
#
#
# OG Orders left:  6832
# Cascade length:  88
# New Orders left:  6744
# making new cascade
#
#
# OG Orders left:  6744
# Cascade length:  37
# New Orders left:  6707
# making new cascade
#
#
# OG Orders left:  6707
# Cascade length:  33
# New Orders left:  6674
# making new cascade
#
#
# OG Orders left:  6674
# Cascade length:  39
# New Orders left:  6635
# making new cascade
#
#
# OG Orders left:  6635
# Cascade length:  51
# New Orders left:  6584
# making new cascade
#
#
# OG Orders left:  6584
# Cascade length:  22
# New Orders left:  6562
# making new cascade
#
#
# OG Orders left:  6562
# Cascade length:  160
# New Orders left:  6402
# making new cascade
#
#
# OG Orders left:  6402
# Cascade length:  74
# New Orders left:  6328
# making new cascade
#
#
# OG Orders left:  6328
# Cascade length:  54
# New Orders left:  6274
# making new cascade
#
#
# OG Orders left:  6274
# Cascade length:  4
# New Orders left:  6270
# making new cascade
#
#
# OG Orders left:  6270
# Cascade length:  23
# New Orders left:  6247
# making new cascade
#
#
# OG Orders left:  6247
# Cascade length:  30
# New Orders left:  6217
# making new cascade
#
#
# OG Orders left:  6217
# Cascade length:  2
# New Orders left:  6215
# making new cascade
#
#
# OG Orders left:  6215
# Cascade length:  62
# New Orders left:  6153
# making new cascade
#
#
# OG Orders left:  6153
# Cascade length:  147
# New Orders left:  6006
# making new cascade
#
#
# OG Orders left:  6006
# Cascade length:  1
# New Orders left:  6005
# making new cascade
#
#
# OG Orders left:  6005
# Cascade length:  164
# New Orders left:  5841
# making new cascade
#
#
# OG Orders left:  5841
# Cascade length:  3
# New Orders left:  5838
# making new cascade
#
#
# OG Orders left:  5838
# Cascade length:  17
# New Orders left:  5821
# making new cascade
#
#
# OG Orders left:  5821
# Cascade length:  4
# New Orders left:  5817
# making new cascade
#
#
# OG Orders left:  5817
# Cascade length:  39
# New Orders left:  5778
# making new cascade
#
#
# OG Orders left:  5778
# Cascade length:  50
# New Orders left:  5728
# making new cascade
#
#
# OG Orders left:  5728
# Cascade length:  11
# New Orders left:  5717
# making new cascade
#
#
# OG Orders left:  5717
# Cascade length:  117
# New Orders left:  5600
# making new cascade
#
#
# OG Orders left:  5600
# Cascade length:  5
# New Orders left:  5595
# making new cascade
#
#
# OG Orders left:  5595
# Cascade length:  85
# New Orders left:  5510
# making new cascade
#
#
# OG Orders left:  5510
# Cascade length:  87
# New Orders left:  5423
# making new cascade
#
#
# OG Orders left:  5423
# Cascade length:  24
# New Orders left:  5399
# making new cascade
#
#
# OG Orders left:  5399
# Cascade length:  41
# New Orders left:  5358
# making new cascade
#
#
# OG Orders left:  5358
# Cascade length:  128
# New Orders left:  5230
# making new cascade
#
#
# OG Orders left:  5230
# Cascade length:  92
# New Orders left:  5138
# making new cascade
#
#
# OG Orders left:  5138
# Cascade length:  2
# New Orders left:  5136
# making new cascade
#
#
# OG Orders left:  5136
# Cascade length:  4
# New Orders left:  5132
# making new cascade
#
#
# OG Orders left:  5132
# Cascade length:  98
# New Orders left:  5034
# making new cascade
#
#
# OG Orders left:  5034
# Cascade length:  2
# New Orders left:  5032
# making new cascade
#
#
# OG Orders left:  5032
# Cascade length:  3
# New Orders left:  5029
# making new cascade
#
#
# OG Orders left:  5029
# Cascade length:  279
# New Orders left:  4750
# making new cascade
#
#
# OG Orders left:  4750
# Cascade length:  124
# New Orders left:  4626
# making new cascade
#
#
# OG Orders left:  4626
# Cascade length:  58
# New Orders left:  4568
# making new cascade
#
#
# OG Orders left:  4568
# Cascade length:  119
# New Orders left:  4449
# making new cascade
#
#
# OG Orders left:  4449
# Cascade length:  25
# New Orders left:  4424
# making new cascade
#
#
# OG Orders left:  4424
# Cascade length:  4
# New Orders left:  4420
# making new cascade
#
#
# OG Orders left:  4420
# Cascade length:  2
# New Orders left:  4418
# making new cascade
#
#
# OG Orders left:  4418
# Cascade length:  170
# New Orders left:  4248
# making new cascade
#
#
# OG Orders left:  4248
# Cascade length:  44
# New Orders left:  4204
# making new cascade
#
#
# OG Orders left:  4204
# Cascade length:  75
# New Orders left:  4129
# making new cascade
#
#
# OG Orders left:  4129
# Cascade length:  70
# New Orders left:  4059
# making new cascade
#
#
# OG Orders left:  4059
# Cascade length:  73
# New Orders left:  3986
# making new cascade
#
#
# OG Orders left:  3986
# Cascade length:  301
# New Orders left:  3685
# making new cascade
#
#
# OG Orders left:  3685
# Cascade length:  79
# New Orders left:  3606
# making new cascade
#
#
# OG Orders left:  3606
# Cascade length:  8
# New Orders left:  3598
# making new cascade
#
#
# OG Orders left:  3598
# Cascade length:  23
# New Orders left:  3575
# making new cascade
#
#
# OG Orders left:  3575
# Cascade length:  63
# New Orders left:  3512
# making new cascade
#
#
# OG Orders left:  3512
# Cascade length:  1
# New Orders left:  3511
# making new cascade
#
#
# OG Orders left:  3511
# Cascade length:  18
# New Orders left:  3493
# making new cascade
#
#
# OG Orders left:  3493
# Cascade length:  6
# New Orders left:  3487
# making new cascade
#
#
# OG Orders left:  3487
# Cascade length:  34
# New Orders left:  3453
# making new cascade
#
#
# OG Orders left:  3453
# Cascade length:  2
# New Orders left:  3451
# making new cascade
#
#
# OG Orders left:  3451
# Cascade length:  113
# New Orders left:  3338
# making new cascade
#
#
# OG Orders left:  3338
# Cascade length:  69
# New Orders left:  3269
# making new cascade
#
#
# OG Orders left:  3269
# Cascade length:  2
# New Orders left:  3267
# making new cascade
#
#
# OG Orders left:  3267
# Cascade length:  66
# New Orders left:  3201
# making new cascade
#
#
# OG Orders left:  3201
# Cascade length:  4
# New Orders left:  3197
# making new cascade
#
#
# OG Orders left:  3197
# Cascade length:  24
# New Orders left:  3173
# making new cascade
#
#
# OG Orders left:  3173
# Cascade length:  55
# New Orders left:  3118
# making new cascade
#
#
# OG Orders left:  3118
# Cascade length:  7
# New Orders left:  3111
# making new cascade
#
#
# OG Orders left:  3111
# Cascade length:  2
# New Orders left:  3109
# making new cascade
#
#
# OG Orders left:  3109
# Cascade length:  113
# New Orders left:  2996
# making new cascade
#
#
# OG Orders left:  2996
# Cascade length:  77
# New Orders left:  2919
# making new cascade
#
#
# OG Orders left:  2919
# Cascade length:  57
# New Orders left:  2862
# making new cascade
#
#
# OG Orders left:  2862
# Cascade length:  16
# New Orders left:  2846
# making new cascade
#
#
# OG Orders left:  2846
# Cascade length:  2
# New Orders left:  2844
# making new cascade
#
#
# OG Orders left:  2844
# Cascade length:  91
# New Orders left:  2753
# making new cascade
#
#
# OG Orders left:  2753
# Cascade length:  38
# New Orders left:  2715
# making new cascade
#
#
# OG Orders left:  2715
# Cascade length:  78
# New Orders left:  2637
# making new cascade
#
#
# OG Orders left:  2637
# Cascade length:  7
# New Orders left:  2630
# making new cascade
#
#
# OG Orders left:  2630
# Cascade length:  25
# New Orders left:  2605
# making new cascade
#
#
# OG Orders left:  2605
# Cascade length:  8
# New Orders left:  2597
# making new cascade
#
#
# OG Orders left:  2597
# Cascade length:  4
# New Orders left:  2593
# making new cascade
#
#
# OG Orders left:  2593
# Cascade length:  84
# New Orders left:  2509
# making new cascade
#
#
# OG Orders left:  2509
# Cascade length:  62
# New Orders left:  2447
# making new cascade
#
#
# OG Orders left:  2447
# Cascade length:  9
# New Orders left:  2438
# making new cascade
#
#
# OG Orders left:  2438
# Cascade length:  57
# New Orders left:  2381
# making new cascade
#
#
# OG Orders left:  2381
# Cascade length:  62
# New Orders left:  2319
# making new cascade
#
#
# OG Orders left:  2319
# Cascade length:  5
# New Orders left:  2314
# making new cascade
#
#
# OG Orders left:  2314
# Cascade length:  6
# New Orders left:  2308
# making new cascade
#
#
# OG Orders left:  2308
# Cascade length:  1
# New Orders left:  2307
# making new cascade
#
#
# OG Orders left:  2307
# Cascade length:  24
# New Orders left:  2283
# making new cascade
#
#
# OG Orders left:  2283
# Cascade length:  2
# New Orders left:  2281
# making new cascade
#
#
# OG Orders left:  2281
# Cascade length:  36
# New Orders left:  2245
# making new cascade
#
#
# OG Orders left:  2245
# Cascade length:  60
# New Orders left:  2185
# making new cascade
#
#
# OG Orders left:  2185
# Cascade length:  59
# New Orders left:  2126
# making new cascade
#
#
# OG Orders left:  2126
# Cascade length:  2
# New Orders left:  2124
# making new cascade
#
#
# OG Orders left:  2124
# Cascade length:  92
# New Orders left:  2032
# making new cascade
#
#
# OG Orders left:  2032
# Cascade length:  128
# New Orders left:  1904
# making new cascade
#
#
# OG Orders left:  1904
# Cascade length:  23
# New Orders left:  1881
# making new cascade
#
#
# OG Orders left:  1881
# Cascade length:  6
# New Orders left:  1875
# making new cascade
#
#
# OG Orders left:  1875
# Cascade length:  55
# New Orders left:  1820
# making new cascade
#
#
# OG Orders left:  1820
# Cascade length:  1
# New Orders left:  1819
# making new cascade
#
#
# OG Orders left:  1819
# Cascade length:  1
# New Orders left:  1818
# making new cascade
#
#
# OG Orders left:  1818
# Cascade length:  2
# New Orders left:  1816
# making new cascade
#
#
# OG Orders left:  1816
# Cascade length:  30
# New Orders left:  1786
# making new cascade
#
#
# OG Orders left:  1786
# Cascade length:  4
# New Orders left:  1782
# making new cascade
#
#
# OG Orders left:  1782
# Cascade length:  63
# New Orders left:  1719
# making new cascade
#
#
# OG Orders left:  1719
# Cascade length:  3
# New Orders left:  1716
# making new cascade
#
#
# OG Orders left:  1716
# Cascade length:  26
# New Orders left:  1690
# making new cascade
#
#
# OG Orders left:  1690
# Cascade length:  5
# New Orders left:  1685
# making new cascade
#
#
# OG Orders left:  1685
# Cascade length:  117
# New Orders left:  1568
# making new cascade
#
#
# OG Orders left:  1568
# Cascade length:  4
# New Orders left:  1564
# making new cascade
#
#
# OG Orders left:  1564
# Cascade length:  25
# New Orders left:  1539
# making new cascade
#
#
# OG Orders left:  1539
# Cascade length:  27
# New Orders left:  1512
# making new cascade
#
#
# OG Orders left:  1512
# Cascade length:  40
# New Orders left:  1472
# making new cascade
#
#
# OG Orders left:  1472
# Cascade length:  74
# New Orders left:  1398
# making new cascade
#
#
# OG Orders left:  1398
# Cascade length:  20
# New Orders left:  1378
# making new cascade
#
#
# OG Orders left:  1378
# Cascade length:  9
# New Orders left:  1369
# making new cascade
#
#
# OG Orders left:  1369
# Cascade length:  7
# New Orders left:  1362
# making new cascade
#
#
# OG Orders left:  1362
# Cascade length:  105
# New Orders left:  1257
# making new cascade
#
#
# OG Orders left:  1257
# Cascade length:  42
# New Orders left:  1215
# making new cascade
#
#
# OG Orders left:  1215
# Cascade length:  2
# New Orders left:  1213
# making new cascade
#
#
# OG Orders left:  1213
# Cascade length:  1
# New Orders left:  1212
# making new cascade
#
#
# OG Orders left:  1212
# Cascade length:  38
# New Orders left:  1174
# making new cascade
#
#
# OG Orders left:  1174
# Cascade length:  71
# New Orders left:  1103
# making new cascade
#
#
# OG Orders left:  1103
# Cascade length:  25
# New Orders left:  1078
# making new cascade
#
#
# OG Orders left:  1078
# Cascade length:  4
# New Orders left:  1074
# making new cascade
#
#
# OG Orders left:  1074
# Cascade length:  38
# New Orders left:  1036
# making new cascade
#
#
# OG Orders left:  1036
# Cascade length:  2
# New Orders left:  1034
# making new cascade
#
#
# OG Orders left:  1034
# Cascade length:  95
# New Orders left:  939
# making new cascade
#
#
# OG Orders left:  939
# Cascade length:  26
# New Orders left:  913
# making new cascade
#
#
# OG Orders left:  913
# Cascade length:  103
# New Orders left:  810
# making new cascade
#
#
# OG Orders left:  810
# Cascade length:  1
# New Orders left:  809
# making new cascade
#
#
# OG Orders left:  809
# Cascade length:  54
# New Orders left:  755
# making new cascade
#
#
# OG Orders left:  755
# Cascade length:  20
# New Orders left:  735
# making new cascade
#
#
# OG Orders left:  735
# Cascade length:  38
# New Orders left:  697
# making new cascade
#
#
# OG Orders left:  697
# Cascade length:  12
# New Orders left:  685
# making new cascade
#
#
# OG Orders left:  685
# Cascade length:  34
# New Orders left:  651
# making new cascade
#
#
# OG Orders left:  651
# Cascade length:  62
# New Orders left:  589
# making new cascade
#
#
# OG Orders left:  589
# Cascade length:  8
# New Orders left:  581
# making new cascade
#
#
# OG Orders left:  581
# Cascade length:  130
# New Orders left:  451
# making new cascade
#
#
# OG Orders left:  451
# Cascade length:  4
# New Orders left:  447
# making new cascade
#
#
# OG Orders left:  447
# Cascade length:  6
# New Orders left:  441
# making new cascade
#
#
# OG Orders left:  441
# Cascade length:  30
# New Orders left:  411
# making new cascade
#
#
# OG Orders left:  411
# Cascade length:  73
# New Orders left:  338
# making new cascade
#
#
# OG Orders left:  338
# Cascade length:  4
# New Orders left:  334
# making new cascade
#
#
# OG Orders left:  334
# Cascade length:  2
# New Orders left:  332
# making new cascade
#
#
# OG Orders left:  332
# Cascade length:  13
# New Orders left:  319
# making new cascade
#
#
# OG Orders left:  319
# Cascade length:  5
# New Orders left:  314
# making new cascade
#
#
# OG Orders left:  314
# Cascade length:  69
# New Orders left:  245
# making new cascade
#
#
# OG Orders left:  245
# Cascade length:  18
# New Orders left:  227
# making new cascade
#
#
# OG Orders left:  227
# Cascade length:  9
# New Orders left:  218
# making new cascade
#
#
# OG Orders left:  218
# Cascade length:  2
# New Orders left:  216
# making new cascade
#
#
# OG Orders left:  216
# Cascade length:  6
# New Orders left:  210
# making new cascade
#
#
# OG Orders left:  210
# Cascade length:  4
# New Orders left:  206
# making new cascade
#
#
# OG Orders left:  206
# Cascade length:  19
# New Orders left:  187
# making new cascade
#
#
# OG Orders left:  187
# Cascade length:  2
# New Orders left:  185
# making new cascade
#
#
# OG Orders left:  185
# Cascade length:  58
# New Orders left:  127
# making new cascade
#
#
# OG Orders left:  127
# Cascade length:  5
# New Orders left:  122
# making new cascade
#
#
# OG Orders left:  122
# Cascade length:  4
# New Orders left:  118
# making new cascade
#
#
# OG Orders left:  118
# Cascade length:  6
# New Orders left:  112
# making new cascade
#
#
# OG Orders left:  112
# Cascade length:  16
# New Orders left:  96
# making new cascade
#
#
# OG Orders left:  96
# Cascade length:  4
# New Orders left:  92
# making new cascade
#
#
# OG Orders left:  92
# Cascade length:  6
# New Orders left:  86
# making new cascade
#
#
# OG Orders left:  86
# Cascade length:  11
# New Orders left:  75
# making new cascade
#
#
# OG Orders left:  75
# Cascade length:  19
# New Orders left:  56
# making new cascade
#
#
# OG Orders left:  56
# Cascade length:  6
# New Orders left:  50
# making new cascade
#
#
# OG Orders left:  50
# Cascade length:  13
# New Orders left:  37
# making new cascade
#
#
# OG Orders left:  37
# Cascade length:  5
# New Orders left:  32
# making new cascade
#
#
# OG Orders left:  32
# Cascade length:  16
# New Orders left:  16
# making new cascade
#
#
# OG Orders left:  16
# Cascade length:  9
# New Orders left:  7
# making new cascade
#
#
# OG Orders left:  7
# Cascade length:  1
# New Orders left:  6
# making new cascade
#
#
# OG Orders left:  6
# Cascade length:  4
# New Orders left:  2
# making new cascade
#
#
# OG Orders left:  2
# Cascade length:  2
# New Orders left:  0
# making new cascade

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades11_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.9)*3, '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*3, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*2, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
