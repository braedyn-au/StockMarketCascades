# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_200_7200_100_10_20.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_200_7200_100_10_20.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_200_7200_100_10_20.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_200_7200_100_10_20.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 1   993     yshfc      1   -1.0
# 1                 2   993     yshfc      2   -2.0
# 2                10   993     yshfc     10    1.0
# 3                11   993     yshfc     11    1.0
# 4                13   993     yshfc     13   -1.0
# ...             ...   ...       ...    ...    ...
# 3836251           7  8192     xbcot     35    1.0
# 3836252           9  8192     xbcot     42    1.0
# 3836253           2  8192     jmeyl     76    1.0
# 3836254           3  8192     jmeyl     43   -1.0
# 3836255          16  8192     jmeyl     66   -1.0
#
# [3836256 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades22_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  3836256

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades21_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5192], traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5192)
with open('../causalCascades/7-9/causalCascades12_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2217038
# Cascade length:  30769
# New Orders left:  2186269
# making new cascade
#
#
# OG Orders left:  2186269
# Cascade length:  6
# New Orders left:  2186263
# making new cascade
#
#
# OG Orders left:  2186263
# Cascade length:  17105
# New Orders left:  2169158
# making new cascade
#
#
# OG Orders left:  2169158
# Cascade length:  16388
# New Orders left:  2152770
# making new cascade
#
#
# OG Orders left:  2152770
# Cascade length:  11810
# New Orders left:  2140960
# making new cascade
#
#
# OG Orders left:  2140960
# Cascade length:  15994
# New Orders left:  2124966
# making new cascade
#
#
# OG Orders left:  2124966
# Cascade length:  619
# New Orders left:  2124347
# making new cascade
#
#
# OG Orders left:  2124347
# Cascade length:  4800
# New Orders left:  2119547
# making new cascade
#
#
# OG Orders left:  2119547
# Cascade length:  5156
# New Orders left:  2114391
# making new cascade
#
#
# OG Orders left:  2114391
# Cascade length:  10480
# New Orders left:  2103911
# making new cascade
#
#
# OG Orders left:  2103911
# Cascade length:  3565
# New Orders left:  2100346
# making new cascade
#
#
# OG Orders left:  2100346
# Cascade length:  3108
# New Orders left:  2097238
# making new cascade
#
#
# OG Orders left:  2097238
# Cascade length:  7183
# New Orders left:  2090055
# making new cascade
#
#
# OG Orders left:  2090055
# Cascade length:  4607
# New Orders left:  2085448
# making new cascade
#
#
# OG Orders left:  2085448
# Cascade length:  7108
# New Orders left:  2078340
# making new cascade
#
#
# OG Orders left:  2078340
# Cascade length:  3338
# New Orders left:  2075002
# making new cascade
#
#
# OG Orders left:  2075002
# Cascade length:  2532
# New Orders left:  2072470
# making new cascade
#
#
# OG Orders left:  2072470
# Cascade length:  3090
# New Orders left:  2069380
# making new cascade
#
#
# OG Orders left:  2069380
# Cascade length:  3961
# New Orders left:  2065419
# making new cascade
#
#
# OG Orders left:  2065419
# Cascade length:  3105
# New Orders left:  2062314
# making new cascade
#
#
# OG Orders left:  2062314
# Cascade length:  2959
# New Orders left:  2059355
# making new cascade
#
#
# OG Orders left:  2059355
# Cascade length:  3062
# New Orders left:  2056293
# making new cascade
#
#
# OG Orders left:  2056293
# Cascade length:  4288
# New Orders left:  2052005
# making new cascade
#
#
# OG Orders left:  2052005
# Cascade length:  2475
# New Orders left:  2049530
# making new cascade
#
#
# OG Orders left:  2049530
# Cascade length:  3825
# New Orders left:  2045705
# making new cascade
#
#
# OG Orders left:  2045705
# Cascade length:  3804
# New Orders left:  2041901
# making new cascade
#
#
# OG Orders left:  2041901
# Cascade length:  4979
# New Orders left:  2036922
# making new cascade
#
#
# OG Orders left:  2036922
# Cascade length:  3272
# New Orders left:  2033650
# making new cascade
#
#
# OG Orders left:  2033650
# Cascade length:  5838
# New Orders left:  2027812
# making new cascade
#
#
# OG Orders left:  2027812
# Cascade length:  2757
# New Orders left:  2025055
# making new cascade
#
#
# OG Orders left:  2025055
# Cascade length:  3219
# New Orders left:  2021836
# making new cascade
#
#
# OG Orders left:  2021836
# Cascade length:  3309
# New Orders left:  2018527
# making new cascade
#
#
# OG Orders left:  2018527
# Cascade length:  3637
# New Orders left:  2014890
# making new cascade
#
#
# OG Orders left:  2014890
# Cascade length:  1439
# New Orders left:  2013451
# making new cascade
#
#
# OG Orders left:  2013451
# Cascade length:  4180
# New Orders left:  2009271
# making new cascade
#
#
# OG Orders left:  2009271
# Cascade length:  4770
# New Orders left:  2004501
# making new cascade
#
#
# OG Orders left:  2004501
# Cascade length:  1830
# New Orders left:  2002671
# making new cascade
#
#
# OG Orders left:  2002671
# Cascade length:  3185
# New Orders left:  1999486
# making new cascade
#
#
# OG Orders left:  1999486
# Cascade length:  2748
# New Orders left:  1996738
# making new cascade
#
#
# OG Orders left:  1996738
# Cascade length:  3111
# New Orders left:  1993627
# making new cascade
#
#
# OG Orders left:  1993627
# Cascade length:  3885
# New Orders left:  1989742
# making new cascade
#
#
# OG Orders left:  1989742
# Cascade length:  3653
# New Orders left:  1986089
# making new cascade
#
#
# OG Orders left:  1986089
# Cascade length:  5492
# New Orders left:  1980597
# making new cascade
#
#
# OG Orders left:  1980597
# Cascade length:  2993
# New Orders left:  1977604
# making new cascade
#
#
# OG Orders left:  1977604
# Cascade length:  3261
# New Orders left:  1974343
# making new cascade
#
#
# OG Orders left:  1974343
# Cascade length:  2783
# New Orders left:  1971560
# making new cascade
#
#
# OG Orders left:  1971560
# Cascade length:  21
# New Orders left:  1971539
# making new cascade
#
#
# OG Orders left:  1971539
# Cascade length:  7342
# New Orders left:  1964197
# making new cascade
#
#
# OG Orders left:  1964197
# Cascade length:  3893
# New Orders left:  1960304
# making new cascade
#
#
# OG Orders left:  1960304
# Cascade length:  2161
# New Orders left:  1958143
# making new cascade
#
#
# OG Orders left:  1958143
# Cascade length:  3390
# New Orders left:  1954753
# making new cascade
#
#
# OG Orders left:  1954753
# Cascade length:  4833
# New Orders left:  1949920
# making new cascade
#
#
# OG Orders left:  1949920
# Cascade length:  3120
# New Orders left:  1946800
# making new cascade
#
#
# OG Orders left:  1946800
# Cascade length:  2514
# New Orders left:  1944286
# making new cascade
#
#
# OG Orders left:  1944286
# Cascade length:  2906
# New Orders left:  1941380
# making new cascade
#
#
# OG Orders left:  1941380
# Cascade length:  2646
# New Orders left:  1938734
# making new cascade
#
#
# OG Orders left:  1938734
# Cascade length:  1513
# New Orders left:  1937221
# making new cascade
#
#
# OG Orders left:  1937221
# Cascade length:  7415
# New Orders left:  1929806
# making new cascade
#
#
# OG Orders left:  1929806
# Cascade length:  2731
# New Orders left:  1927075
# making new cascade
#
#
# OG Orders left:  1927075
# Cascade length:  8553
# New Orders left:  1918522
# making new cascade
#
#
# OG Orders left:  1918522
# Cascade length:  3088
# New Orders left:  1915434
# making new cascade
#
#
# OG Orders left:  1915434
# Cascade length:  9683
# New Orders left:  1905751
# making new cascade
#
#
# OG Orders left:  1905751
# Cascade length:  4949
# New Orders left:  1900802
# making new cascade
#
#
# OG Orders left:  1900802
# Cascade length:  2255
# New Orders left:  1898547
# making new cascade
#
#
# OG Orders left:  1898547
# Cascade length:  2088
# New Orders left:  1896459
# making new cascade
#
#
# OG Orders left:  1896459
# Cascade length:  2112
# New Orders left:  1894347
# making new cascade
#
#
# OG Orders left:  1894347
# Cascade length:  1866
# New Orders left:  1892481
# making new cascade
#
#
# OG Orders left:  1892481
# Cascade length:  2143
# New Orders left:  1890338
# making new cascade
#
#
# OG Orders left:  1890338
# Cascade length:  3395
# New Orders left:  1886943
# making new cascade
#
#
# OG Orders left:  1886943
# Cascade length:  1984
# New Orders left:  1884959
# making new cascade
#
#
# OG Orders left:  1884959
# Cascade length:  2648
# New Orders left:  1882311
# making new cascade
#
#
# OG Orders left:  1882311
# Cascade length:  2146
# New Orders left:  1880165
# making new cascade
#
#
# OG Orders left:  1880165
# Cascade length:  2263
# New Orders left:  1877902
# making new cascade
#
#
# OG Orders left:  1877902
# Cascade length:  1662
# New Orders left:  1876240
# making new cascade
#
#
# OG Orders left:  1876240
# Cascade length:  2219
# New Orders left:  1874021
# making new cascade
#
#
# OG Orders left:  1874021
# Cascade length:  1902
# New Orders left:  1872119
# making new cascade
#
#
# OG Orders left:  1872119
# Cascade length:  1946
# New Orders left:  1870173
# making new cascade
#
#
# OG Orders left:  1870173
# Cascade length:  4194
# New Orders left:  1865979
# making new cascade
#
#
# OG Orders left:  1865979
# Cascade length:  2846
# New Orders left:  1863133
# making new cascade
#
#
# OG Orders left:  1863133
# Cascade length:  5971
# New Orders left:  1857162
# making new cascade
#
#
# OG Orders left:  1857162
# Cascade length:  2682
# New Orders left:  1854480
# making new cascade
#
#
# OG Orders left:  1854480
# Cascade length:  1290
# New Orders left:  1853190
# making new cascade
#
#
# OG Orders left:  1853190
# Cascade length:  1781
# New Orders left:  1851409
# making new cascade
#
#
# OG Orders left:  1851409
# Cascade length:  2148
# New Orders left:  1849261
# making new cascade
#
#
# OG Orders left:  1849261
# Cascade length:  1594
# New Orders left:  1847667
# making new cascade
#
#
# OG Orders left:  1847667
# Cascade length:  2842
# New Orders left:  1844825
# making new cascade
#
#
# OG Orders left:  1844825
# Cascade length:  1347
# New Orders left:  1843478
# making new cascade
#
#
# OG Orders left:  1843478
# Cascade length:  1661
# New Orders left:  1841817
# making new cascade
#
#
# OG Orders left:  1841817
# Cascade length:  2562
# New Orders left:  1839255
# making new cascade
#
#
# OG Orders left:  1839255
# Cascade length:  2725
# New Orders left:  1836530
# making new cascade
#
#
# OG Orders left:  1836530
# Cascade length:  4823
# New Orders left:  1831707
# making new cascade
#
#
# OG Orders left:  1831707
# Cascade length:  6262
# New Orders left:  1825445
# making new cascade
#
#
# OG Orders left:  1825445
# Cascade length:  7379
# New Orders left:  1818066
# making new cascade
#
#
# OG Orders left:  1818066
# Cascade length:  2472
# New Orders left:  1815594
# making new cascade
#
#
# OG Orders left:  1815594
# Cascade length:  6188
# New Orders left:  1809406
# making new cascade
#
#
# OG Orders left:  1809406
# Cascade length:  1778
# New Orders left:  1807628
# making new cascade
#
#
# OG Orders left:  1807628
# Cascade length:  5362
# New Orders left:  1802266
# making new cascade
#
#
# OG Orders left:  1802266
# Cascade length:  5800
# New Orders left:  1796466
# making new cascade
#
#
# OG Orders left:  1796466
# Cascade length:  2654
# New Orders left:  1793812
# making new cascade
#
#
# OG Orders left:  1793812
# Cascade length:  8
# New Orders left:  1793804
# making new cascade
#
#
# OG Orders left:  1793804
# Cascade length:  3856
# New Orders left:  1789948
# making new cascade
#
#
# OG Orders left:  1789948
# Cascade length:  3200
# New Orders left:  1786748
# making new cascade
#
#
# OG Orders left:  1786748
# Cascade length:  4640
# New Orders left:  1782108
# making new cascade
#
#
# OG Orders left:  1782108
# Cascade length:  2643
# New Orders left:  1779465
# making new cascade
#
#
# OG Orders left:  1779465
# Cascade length:  1500
# New Orders left:  1777965
# making new cascade
#
#
# OG Orders left:  1777965
# Cascade length:  2580
# New Orders left:  1775385
# making new cascade
#
#
# OG Orders left:  1775385
# Cascade length:  2758
# New Orders left:  1772627
# making new cascade
#
#
# OG Orders left:  1772627
# Cascade length:  1801
# New Orders left:  1770826
# making new cascade
#
#
# OG Orders left:  1770826
# Cascade length:  3363
# New Orders left:  1767463
# making new cascade
#
#
# OG Orders left:  1767463
# Cascade length:  9913
# New Orders left:  1757550
# making new cascade
#
#
# OG Orders left:  1757550
# Cascade length:  5249
# New Orders left:  1752301
# making new cascade
#
#
# OG Orders left:  1752301
# Cascade length:  4848
# New Orders left:  1747453
# making new cascade
#
#
# OG Orders left:  1747453
# Cascade length:  2418
# New Orders left:  1745035
# making new cascade
#
#
# OG Orders left:  1745035
# Cascade length:  1576
# New Orders left:  1743459
# making new cascade
#
#
# OG Orders left:  1743459
# Cascade length:  1667
# New Orders left:  1741792
# making new cascade
#
#
# OG Orders left:  1741792
# Cascade length:  3228
# New Orders left:  1738564
# making new cascade
#
#
# OG Orders left:  1738564
# Cascade length:  2675
# New Orders left:  1735889
# making new cascade
#
#
# OG Orders left:  1735889
# Cascade length:  1973
# New Orders left:  1733916
# making new cascade
#
#
# OG Orders left:  1733916
# Cascade length:  5417
# New Orders left:  1728499
# making new cascade
#
#
# OG Orders left:  1728499
# Cascade length:  2042
# New Orders left:  1726457
# making new cascade
#
#
# OG Orders left:  1726457
# Cascade length:  3757
# New Orders left:  1722700
# making new cascade
#
#
# OG Orders left:  1722700
# Cascade length:  11510
# New Orders left:  1711190
# making new cascade
#
#
# OG Orders left:  1711190
# Cascade length:  2886
# New Orders left:  1708304
# making new cascade
#
#
# OG Orders left:  1708304
# Cascade length:  4590
# New Orders left:  1703714
# making new cascade
#
#
# OG Orders left:  1703714
# Cascade length:  2257
# New Orders left:  1701457
# making new cascade
#
#
# OG Orders left:  1701457
# Cascade length:  2948
# New Orders left:  1698509
# making new cascade
#
#
# OG Orders left:  1698509
# Cascade length:  3950
# New Orders left:  1694559
# making new cascade
#
#
# OG Orders left:  1694559
# Cascade length:  2546
# New Orders left:  1692013
# making new cascade
#
#
# OG Orders left:  1692013
# Cascade length:  16634
# New Orders left:  1675379
# making new cascade
#
#
# OG Orders left:  1675379
# Cascade length:  2122
# New Orders left:  1673257
# making new cascade
#
#
# OG Orders left:  1673257
# Cascade length:  1690
# New Orders left:  1671567
# making new cascade
#
#
# OG Orders left:  1671567
# Cascade length:  11333
# New Orders left:  1660234
# making new cascade
#
#
# OG Orders left:  1660234
# Cascade length:  2879
# New Orders left:  1657355
# making new cascade
#
#
# OG Orders left:  1657355
# Cascade length:  3168
# New Orders left:  1654187
# making new cascade
#
#
# OG Orders left:  1654187
# Cascade length:  2626
# New Orders left:  1651561
# making new cascade
#
#
# OG Orders left:  1651561
# Cascade length:  1698
# New Orders left:  1649863
# making new cascade
#
#
# OG Orders left:  1649863
# Cascade length:  2414
# New Orders left:  1647449
# making new cascade
#
#
# OG Orders left:  1647449
# Cascade length:  2820
# New Orders left:  1644629
# making new cascade
#
#
# OG Orders left:  1644629
# Cascade length:  2048
# New Orders left:  1642581
# making new cascade
#
#
# OG Orders left:  1642581
# Cascade length:  8387
# New Orders left:  1634194
# making new cascade
#
#
# OG Orders left:  1634194
# Cascade length:  2288
# New Orders left:  1631906
# making new cascade
#
#
# OG Orders left:  1631906
# Cascade length:  1961
# New Orders left:  1629945
# making new cascade
#
#
# OG Orders left:  1629945
# Cascade length:  1265
# New Orders left:  1628680
# making new cascade
#
#
# OG Orders left:  1628680
# Cascade length:  6645
# New Orders left:  1622035
# making new cascade
#
#
# OG Orders left:  1622035
# Cascade length:  2379
# New Orders left:  1619656
# making new cascade
#
#
# OG Orders left:  1619656
# Cascade length:  2699
# New Orders left:  1616957
# making new cascade
#
#
# OG Orders left:  1616957
# Cascade length:  5612
# New Orders left:  1611345
# making new cascade
#
#
# OG Orders left:  1611345
# Cascade length:  2690
# New Orders left:  1608655
# making new cascade
#
#
# OG Orders left:  1608655
# Cascade length:  1776
# New Orders left:  1606879
# making new cascade
#
#
# OG Orders left:  1606879
# Cascade length:  2877
# New Orders left:  1604002
# making new cascade
#
#
# OG Orders left:  1604002
# Cascade length:  3220
# New Orders left:  1600782
# making new cascade
#
#
# OG Orders left:  1600782
# Cascade length:  2016
# New Orders left:  1598766
# making new cascade
#
#
# OG Orders left:  1598766
# Cascade length:  2284
# New Orders left:  1596482
# making new cascade
#
#
# OG Orders left:  1596482
# Cascade length:  2787
# New Orders left:  1593695
# making new cascade
#
#
# OG Orders left:  1593695
# Cascade length:  3830
# New Orders left:  1589865
# making new cascade
#
#
# OG Orders left:  1589865
# Cascade length:  3169
# New Orders left:  1586696
# making new cascade
#
#
# OG Orders left:  1586696
# Cascade length:  2845
# New Orders left:  1583851
# making new cascade
#
#
# OG Orders left:  1583851
# Cascade length:  2640
# New Orders left:  1581211
# making new cascade
#
#
# OG Orders left:  1581211
# Cascade length:  3018
# New Orders left:  1578193
# making new cascade
#
#
# OG Orders left:  1578193
# Cascade length:  2067
# New Orders left:  1576126
# making new cascade
#
#
# OG Orders left:  1576126
# Cascade length:  4100
# New Orders left:  1572026
# making new cascade
#
#
# OG Orders left:  1572026
# Cascade length:  2158
# New Orders left:  1569868
# making new cascade
#
#
# OG Orders left:  1569868
# Cascade length:  4258
# New Orders left:  1565610
# making new cascade
#
#
# OG Orders left:  1565610
# Cascade length:  2228
# New Orders left:  1563382
# making new cascade
#
#
# OG Orders left:  1563382
# Cascade length:  3036
# New Orders left:  1560346
# making new cascade
#
#
# OG Orders left:  1560346
# Cascade length:  3856
# New Orders left:  1556490
# making new cascade
#
#
# OG Orders left:  1556490
# Cascade length:  2749
# New Orders left:  1553741
# making new cascade
#
#
# OG Orders left:  1553741
# Cascade length:  3423
# New Orders left:  1550318
# making new cascade
#
#
# OG Orders left:  1550318
# Cascade length:  5190
# New Orders left:  1545128
# making new cascade
#
#
# OG Orders left:  1545128
# Cascade length:  5108
# New Orders left:  1540020
# making new cascade
#
#
# OG Orders left:  1540020
# Cascade length:  2932
# New Orders left:  1537088
# making new cascade
#
#
# OG Orders left:  1537088
# Cascade length:  2424
# New Orders left:  1534664
# making new cascade
#
#
# OG Orders left:  1534664
# Cascade length:  2599
# New Orders left:  1532065
# making new cascade
#
#
# OG Orders left:  1532065
# Cascade length:  2400
# New Orders left:  1529665
# making new cascade
#
#
# OG Orders left:  1529665
# Cascade length:  2690
# New Orders left:  1526975
# making new cascade
#
#
# OG Orders left:  1526975
# Cascade length:  2989
# New Orders left:  1523986
# making new cascade
#
#
# OG Orders left:  1523986
# Cascade length:  3285
# New Orders left:  1520701
# making new cascade
#
#
# OG Orders left:  1520701
# Cascade length:  5362
# New Orders left:  1515339
# making new cascade
#
#
# OG Orders left:  1515339
# Cascade length:  2383
# New Orders left:  1512956
# making new cascade
#
#
# OG Orders left:  1512956
# Cascade length:  5826
# New Orders left:  1507130
# making new cascade
#
#
# OG Orders left:  1507130
# Cascade length:  5228
# New Orders left:  1501902
# making new cascade
#
#
# OG Orders left:  1501902
# Cascade length:  4309
# New Orders left:  1497593
# making new cascade
#
#
# OG Orders left:  1497593
# Cascade length:  11761
# New Orders left:  1485832
# making new cascade
#
#
# OG Orders left:  1485832
# Cascade length:  2616
# New Orders left:  1483216
# making new cascade
#
#
# OG Orders left:  1483216
# Cascade length:  1666
# New Orders left:  1481550
# making new cascade
#
#
# OG Orders left:  1481550
# Cascade length:  10040
# New Orders left:  1471510
# making new cascade
#
#
# OG Orders left:  1471510
# Cascade length:  2759
# New Orders left:  1468751
# making new cascade
#
#
# OG Orders left:  1468751
# Cascade length:  2512
# New Orders left:  1466239
# making new cascade
#
#
# OG Orders left:  1466239
# Cascade length:  7234
# New Orders left:  1459005
# making new cascade
#
#
# OG Orders left:  1459005
# Cascade length:  2269
# New Orders left:  1456736
# making new cascade
#
#
# OG Orders left:  1456736
# Cascade length:  2597
# New Orders left:  1454139
# making new cascade
#
#
# OG Orders left:  1454139
# Cascade length:  2487
# New Orders left:  1451652
# making new cascade
#
#
# OG Orders left:  1451652
# Cascade length:  11969
# New Orders left:  1439683
# making new cascade
#
#
# OG Orders left:  1439683
# Cascade length:  4657
# New Orders left:  1435026
# making new cascade
#
#
# OG Orders left:  1435026
# Cascade length:  2740
# New Orders left:  1432286
# making new cascade
#
#
# OG Orders left:  1432286
# Cascade length:  2384
# New Orders left:  1429902
# making new cascade
#
#
# OG Orders left:  1429902
# Cascade length:  2098
# New Orders left:  1427804
# making new cascade
#
#
# OG Orders left:  1427804
# Cascade length:  5403
# New Orders left:  1422401
# making new cascade
#
#
# OG Orders left:  1422401
# Cascade length:  1
# New Orders left:  1422400
# making new cascade
#
#
# OG Orders left:  1422400
# Cascade length:  2648
# New Orders left:  1419752
# making new cascade
#
#
# OG Orders left:  1419752
# Cascade length:  2823
# New Orders left:  1416929
# making new cascade
#
#
# OG Orders left:  1416929
# Cascade length:  2291
# New Orders left:  1414638
# making new cascade
#
#
# OG Orders left:  1414638
# Cascade length:  2492
# New Orders left:  1412146
# making new cascade
#
#
# OG Orders left:  1412146
# Cascade length:  2807
# New Orders left:  1409339
# making new cascade
#
#
# OG Orders left:  1409339
# Cascade length:  1264
# New Orders left:  1408075
# making new cascade
#
#
# OG Orders left:  1408075
# Cascade length:  4583
# New Orders left:  1403492
# making new cascade
#
#
# OG Orders left:  1403492
# Cascade length:  3510
# New Orders left:  1399982
# making new cascade
#
#
# OG Orders left:  1399982
# Cascade length:  3968
# New Orders left:  1396014
# making new cascade
#
#
# OG Orders left:  1396014
# Cascade length:  4447
# New Orders left:  1391567
# making new cascade
#
#
# OG Orders left:  1391567
# Cascade length:  3304
# New Orders left:  1388263
# making new cascade
#
#
# OG Orders left:  1388263
# Cascade length:  2701
# New Orders left:  1385562
# making new cascade
#
#
# OG Orders left:  1385562
# Cascade length:  2928
# New Orders left:  1382634
# making new cascade
#
#
# OG Orders left:  1382634
# Cascade length:  739
# New Orders left:  1381895
# making new cascade
#
#
# OG Orders left:  1381895
# Cascade length:  2268
# New Orders left:  1379627
# making new cascade
#
#
# OG Orders left:  1379627
# Cascade length:  2658
# New Orders left:  1376969
# making new cascade
#
#
# OG Orders left:  1376969
# Cascade length:  2269
# New Orders left:  1374700
# making new cascade
#
#
# OG Orders left:  1374700
# Cascade length:  3215
# New Orders left:  1371485
# making new cascade
#
#
# OG Orders left:  1371485
# Cascade length:  2737
# New Orders left:  1368748
# making new cascade
#
#
# OG Orders left:  1368748
# Cascade length:  10568
# New Orders left:  1358180
# making new cascade
#
#
# OG Orders left:  1358180
# Cascade length:  5368
# New Orders left:  1352812
# making new cascade
#
#
# OG Orders left:  1352812
# Cascade length:  2276
# New Orders left:  1350536
# making new cascade
#
#
# OG Orders left:  1350536
# Cascade length:  9720
# New Orders left:  1340816
# making new cascade
#
#
# OG Orders left:  1340816
# Cascade length:  1997
# New Orders left:  1338819
# making new cascade
#
#
# OG Orders left:  1338819
# Cascade length:  3057
# New Orders left:  1335762
# making new cascade
#
#
# OG Orders left:  1335762
# Cascade length:  10
# New Orders left:  1335752
# making new cascade
#
#
# OG Orders left:  1335752
# Cascade length:  2805
# New Orders left:  1332947
# making new cascade
#
#
# OG Orders left:  1332947
# Cascade length:  1885
# New Orders left:  1331062
# making new cascade
#
#
# OG Orders left:  1331062
# Cascade length:  2614
# New Orders left:  1328448
# making new cascade
#
#
# OG Orders left:  1328448
# Cascade length:  2039
# New Orders left:  1326409
# making new cascade
#
#
# OG Orders left:  1326409
# Cascade length:  1946
# New Orders left:  1324463
# making new cascade
#
#
# OG Orders left:  1324463
# Cascade length:  3128
# New Orders left:  1321335
# making new cascade
#
#
# OG Orders left:  1321335
# Cascade length:  2684
# New Orders left:  1318651
# making new cascade
#
#
# OG Orders left:  1318651
# Cascade length:  2462
# New Orders left:  1316189
# making new cascade
#
#
# OG Orders left:  1316189
# Cascade length:  2817
# New Orders left:  1313372
# making new cascade
#
#
# OG Orders left:  1313372
# Cascade length:  3558
# New Orders left:  1309814
# making new cascade
#
#
# OG Orders left:  1309814
# Cascade length:  8725
# New Orders left:  1301089
# making new cascade
#
#
# OG Orders left:  1301089
# Cascade length:  3339
# New Orders left:  1297750
# making new cascade
#
#
# OG Orders left:  1297750
# Cascade length:  4727
# New Orders left:  1293023
# making new cascade
#
#
# OG Orders left:  1293023
# Cascade length:  4977
# New Orders left:  1288046
# making new cascade
#
#
# OG Orders left:  1288046
# Cascade length:  3554
# New Orders left:  1284492
# making new cascade
#
#
# OG Orders left:  1284492
# Cascade length:  2558
# New Orders left:  1281934
# making new cascade
#
#
# OG Orders left:  1281934
# Cascade length:  4397
# New Orders left:  1277537
# making new cascade
#
#
# OG Orders left:  1277537
# Cascade length:  2926
# New Orders left:  1274611
# making new cascade
#
#
# OG Orders left:  1274611
# Cascade length:  162
# New Orders left:  1274449
# making new cascade
#
#
# OG Orders left:  1274449
# Cascade length:  2546
# New Orders left:  1271903
# making new cascade
#
#
# OG Orders left:  1271903
# Cascade length:  3325
# New Orders left:  1268578
# making new cascade
#
#
# OG Orders left:  1268578
# Cascade length:  6111
# New Orders left:  1262467
# making new cascade
#
#
# OG Orders left:  1262467
# Cascade length:  2566
# New Orders left:  1259901
# making new cascade
#
#
# OG Orders left:  1259901
# Cascade length:  2532
# New Orders left:  1257369
# making new cascade
#
#
# OG Orders left:  1257369
# Cascade length:  3803
# New Orders left:  1253566
# making new cascade
#
#
# OG Orders left:  1253566
# Cascade length:  2236
# New Orders left:  1251330
# making new cascade
#
#
# OG Orders left:  1251330
# Cascade length:  4543
# New Orders left:  1246787
# making new cascade
#
#
# OG Orders left:  1246787
# Cascade length:  6945
# New Orders left:  1239842
# making new cascade
#
#
# OG Orders left:  1239842
# Cascade length:  2757
# New Orders left:  1237085
# making new cascade
#
#
# OG Orders left:  1237085
# Cascade length:  2044
# New Orders left:  1235041
# making new cascade
#
#
# OG Orders left:  1235041
# Cascade length:  1944
# New Orders left:  1233097
# making new cascade
#
#
# OG Orders left:  1233097
# Cascade length:  2706
# New Orders left:  1230391
# making new cascade
#
#
# OG Orders left:  1230391
# Cascade length:  2706
# New Orders left:  1227685
# making new cascade
#
#
# OG Orders left:  1227685
# Cascade length:  2651
# New Orders left:  1225034
# making new cascade
#
#
# OG Orders left:  1225034
# Cascade length:  1874
# New Orders left:  1223160
# making new cascade
#
#
# OG Orders left:  1223160
# Cascade length:  2304
# New Orders left:  1220856
# making new cascade
#
#
# OG Orders left:  1220856
# Cascade length:  7267
# New Orders left:  1213589
# making new cascade
#
#
# OG Orders left:  1213589
# Cascade length:  2374
# New Orders left:  1211215
# making new cascade
#
#
# OG Orders left:  1211215
# Cascade length:  2971
# New Orders left:  1208244
# making new cascade
#
#
# OG Orders left:  1208244
# Cascade length:  1685
# New Orders left:  1206559
# making new cascade
#
#
# OG Orders left:  1206559
# Cascade length:  2211
# New Orders left:  1204348
# making new cascade
#
#
# OG Orders left:  1204348
# Cascade length:  2229
# New Orders left:  1202119
# making new cascade
#
#
# OG Orders left:  1202119
# Cascade length:  2575
# New Orders left:  1199544
# making new cascade
#
#
# OG Orders left:  1199544
# Cascade length:  1776
# New Orders left:  1197768
# making new cascade
#
#
# OG Orders left:  1197768
# Cascade length:  1953
# New Orders left:  1195815
# making new cascade
#
#
# OG Orders left:  1195815
# Cascade length:  1368
# New Orders left:  1194447
# making new cascade
#
#
# OG Orders left:  1194447
# Cascade length:  4487
# New Orders left:  1189960
# making new cascade
#
#
# OG Orders left:  1189960
# Cascade length:  3068
# New Orders left:  1186892
# making new cascade
#
#
# OG Orders left:  1186892
# Cascade length:  2629
# New Orders left:  1184263
# making new cascade
#
#
# OG Orders left:  1184263
# Cascade length:  955
# New Orders left:  1183308
# making new cascade
#
#
# OG Orders left:  1183308
# Cascade length:  224
# New Orders left:  1183084
# making new cascade
#
#
# OG Orders left:  1183084
# Cascade length:  3726
# New Orders left:  1179358
# making new cascade
#
#
# OG Orders left:  1179358
# Cascade length:  1544
# New Orders left:  1177814
# making new cascade
#
#
# OG Orders left:  1177814
# Cascade length:  1675
# New Orders left:  1176139
# making new cascade
#
#
# OG Orders left:  1176139
# Cascade length:  2462
# New Orders left:  1173677
# making new cascade
#
#
# OG Orders left:  1173677
# Cascade length:  2608
# New Orders left:  1171069
# making new cascade
#
#
# OG Orders left:  1171069
# Cascade length:  2012
# New Orders left:  1169057
# making new cascade
#
#
# OG Orders left:  1169057
# Cascade length:  1057
# New Orders left:  1168000
# making new cascade
#
#
# OG Orders left:  1168000
# Cascade length:  3295
# New Orders left:  1164705
# making new cascade
#
#
# OG Orders left:  1164705
# Cascade length:  24
# New Orders left:  1164681
# making new cascade
#
#
# OG Orders left:  1164681
# Cascade length:  3213
# New Orders left:  1161468
# making new cascade
#
#
# OG Orders left:  1161468
# Cascade length:  15703
# New Orders left:  1145765
# making new cascade
#
#
# OG Orders left:  1145765
# Cascade length:  2973
# New Orders left:  1142792
# making new cascade
#
#
# OG Orders left:  1142792
# Cascade length:  776
# New Orders left:  1142016
# making new cascade
#
#
# OG Orders left:  1142016
# Cascade length:  2405
# New Orders left:  1139611
# making new cascade
#
#
# OG Orders left:  1139611
# Cascade length:  2252
# New Orders left:  1137359
# making new cascade
#
#
# OG Orders left:  1137359
# Cascade length:  3113
# New Orders left:  1134246
# making new cascade
#
#
# OG Orders left:  1134246
# Cascade length:  2325
# New Orders left:  1131921
# making new cascade
#
#
# OG Orders left:  1131921
# Cascade length:  2101
# New Orders left:  1129820
# making new cascade
#
#
# OG Orders left:  1129820
# Cascade length:  2642
# New Orders left:  1127178
# making new cascade
#
#
# OG Orders left:  1127178
# Cascade length:  15
# New Orders left:  1127163
# making new cascade
#
#
# OG Orders left:  1127163
# Cascade length:  3984
# New Orders left:  1123179
# making new cascade
#
#
# OG Orders left:  1123179
# Cascade length:  3282
# New Orders left:  1119897
# making new cascade
#
#
# OG Orders left:  1119897
# Cascade length:  2100
# New Orders left:  1117797
# making new cascade
#
#
# OG Orders left:  1117797
# Cascade length:  2209
# New Orders left:  1115588
# making new cascade
#
#
# OG Orders left:  1115588
# Cascade length:  3628
# New Orders left:  1111960
# making new cascade
#
#
# OG Orders left:  1111960
# Cascade length:  2695
# New Orders left:  1109265
# making new cascade
#
#
# OG Orders left:  1109265
# Cascade length:  14505
# New Orders left:  1094760
# making new cascade
#
#
# OG Orders left:  1094760
# Cascade length:  5559
# New Orders left:  1089201
# making new cascade
#
#
# OG Orders left:  1089201
# Cascade length:  2346
# New Orders left:  1086855
# making new cascade
#
#
# OG Orders left:  1086855
# Cascade length:  678
# New Orders left:  1086177
# making new cascade
#
#
# OG Orders left:  1086177
# Cascade length:  8277
# New Orders left:  1077900
# making new cascade
#
#
# OG Orders left:  1077900
# Cascade length:  16
# New Orders left:  1077884
# making new cascade
#
#
# OG Orders left:  1077884
# Cascade length:  2208
# New Orders left:  1075676
# making new cascade
#
#
# OG Orders left:  1075676
# Cascade length:  4636
# New Orders left:  1071040
# making new cascade
#
#
# OG Orders left:  1071040
# Cascade length:  2255
# New Orders left:  1068785
# making new cascade
#
#
# OG Orders left:  1068785
# Cascade length:  6
# New Orders left:  1068779
# making new cascade
#
#
# OG Orders left:  1068779
# Cascade length:  3878
# New Orders left:  1064901
# making new cascade
#
#
# OG Orders left:  1064901
# Cascade length:  1082
# New Orders left:  1063819
# making new cascade
#
#
# OG Orders left:  1063819
# Cascade length:  2899
# New Orders left:  1060920
# making new cascade
#
#
# OG Orders left:  1060920
# Cascade length:  2760
# New Orders left:  1058160
# making new cascade
#
#
# OG Orders left:  1058160
# Cascade length:  3260
# New Orders left:  1054900
# making new cascade
#
#
# OG Orders left:  1054900
# Cascade length:  3732
# New Orders left:  1051168
# making new cascade
#
#
# OG Orders left:  1051168
# Cascade length:  3057
# New Orders left:  1048111
# making new cascade
#
#
# OG Orders left:  1048111
# Cascade length:  5474
# New Orders left:  1042637
# making new cascade
#
#
# OG Orders left:  1042637
# Cascade length:  2469
# New Orders left:  1040168
# making new cascade
#
#
# OG Orders left:  1040168
# Cascade length:  2398
# New Orders left:  1037770
# making new cascade
#
#
# OG Orders left:  1037770
# Cascade length:  3953
# New Orders left:  1033817
# making new cascade
#
#
# OG Orders left:  1033817
# Cascade length:  1951
# New Orders left:  1031866
# making new cascade
#
#
# OG Orders left:  1031866
# Cascade length:  2394
# New Orders left:  1029472
# making new cascade
#
#
# OG Orders left:  1029472
# Cascade length:  2776
# New Orders left:  1026696
# making new cascade
#
#
# OG Orders left:  1026696
# Cascade length:  1767
# New Orders left:  1024929
# making new cascade
#
#
# OG Orders left:  1024929
# Cascade length:  2579
# New Orders left:  1022350
# making new cascade
#
#
# OG Orders left:  1022350
# Cascade length:  1585
# New Orders left:  1020765
# making new cascade
#
#
# OG Orders left:  1020765
# Cascade length:  2044
# New Orders left:  1018721
# making new cascade
#
#
# OG Orders left:  1018721
# Cascade length:  1945
# New Orders left:  1016776
# making new cascade
#
#
# OG Orders left:  1016776
# Cascade length:  3848
# New Orders left:  1012928
# making new cascade
#
#
# OG Orders left:  1012928
# Cascade length:  39
# New Orders left:  1012889
# making new cascade
#
#
# OG Orders left:  1012889
# Cascade length:  4819
# New Orders left:  1008070
# making new cascade
#
#
# OG Orders left:  1008070
# Cascade length:  2164
# New Orders left:  1005906
# making new cascade
#
#
# OG Orders left:  1005906
# Cascade length:  1072
# New Orders left:  1004834
# making new cascade
#
#
# OG Orders left:  1004834
# Cascade length:  1975
# New Orders left:  1002859
# making new cascade
#
#
# OG Orders left:  1002859
# Cascade length:  3302
# New Orders left:  999557
# making new cascade
#
#
# OG Orders left:  999557
# Cascade length:  7643
# New Orders left:  991914
# making new cascade
#
#
# OG Orders left:  991914
# Cascade length:  16
# New Orders left:  991898
# making new cascade
#
#
# OG Orders left:  991898
# Cascade length:  2714
# New Orders left:  989184
# making new cascade
#
#
# OG Orders left:  989184
# Cascade length:  2749
# New Orders left:  986435
# making new cascade
#
#
# OG Orders left:  986435
# Cascade length:  2153
# New Orders left:  984282
# making new cascade
#
#
# OG Orders left:  984282
# Cascade length:  9253
# New Orders left:  975029
# making new cascade
#
#
# OG Orders left:  975029
# Cascade length:  2791
# New Orders left:  972238
# making new cascade
#
#
# OG Orders left:  972238
# Cascade length:  2591
# New Orders left:  969647
# making new cascade
#
#
# OG Orders left:  969647
# Cascade length:  10312
# New Orders left:  959335
# making new cascade
#
#
# OG Orders left:  959335
# Cascade length:  879
# New Orders left:  958456
# making new cascade
#
#
# OG Orders left:  958456
# Cascade length:  3782
# New Orders left:  954674
# making new cascade
#
#
# OG Orders left:  954674
# Cascade length:  2231
# New Orders left:  952443
# making new cascade
#
#
# OG Orders left:  952443
# Cascade length:  3141
# New Orders left:  949302
# making new cascade
#
#
# OG Orders left:  949302
# Cascade length:  2910
# New Orders left:  946392
# making new cascade
#
#
# OG Orders left:  946392
# Cascade length:  2392
# New Orders left:  944000
# making new cascade
#
#
# OG Orders left:  944000
# Cascade length:  2277
# New Orders left:  941723
# making new cascade
#
#
# OG Orders left:  941723
# Cascade length:  4481
# New Orders left:  937242
# making new cascade
#
#
# OG Orders left:  937242
# Cascade length:  2950
# New Orders left:  934292
# making new cascade
#
#
# OG Orders left:  934292
# Cascade length:  2653
# New Orders left:  931639
# making new cascade
#
#
# OG Orders left:  931639
# Cascade length:  5100
# New Orders left:  926539
# making new cascade
#
#
# OG Orders left:  926539
# Cascade length:  5540
# New Orders left:  920999
# making new cascade
#
#
# OG Orders left:  920999
# Cascade length:  4825
# New Orders left:  916174
# making new cascade
#
#
# OG Orders left:  916174
# Cascade length:  2891
# New Orders left:  913283
# making new cascade
#
#
# OG Orders left:  913283
# Cascade length:  4080
# New Orders left:  909203
# making new cascade
#
#
# OG Orders left:  909203
# Cascade length:  4272
# New Orders left:  904931
# making new cascade
#
#
# OG Orders left:  904931
# Cascade length:  3655
# New Orders left:  901276
# making new cascade
#
#
# OG Orders left:  901276
# Cascade length:  7162
# New Orders left:  894114
# making new cascade
#
#
# OG Orders left:  894114
# Cascade length:  3617
# New Orders left:  890497
# making new cascade
#
#
# OG Orders left:  890497
# Cascade length:  2897
# New Orders left:  887600
# making new cascade
#
#
# OG Orders left:  887600
# Cascade length:  2346
# New Orders left:  885254
# making new cascade
#
#
# OG Orders left:  885254
# Cascade length:  2906
# New Orders left:  882348
# making new cascade
#
#
# OG Orders left:  882348
# Cascade length:  79
# New Orders left:  882269
# making new cascade
#
#
# OG Orders left:  882269
# Cascade length:  15003
# New Orders left:  867266
# making new cascade
#
#
# OG Orders left:  867266
# Cascade length:  4387
# New Orders left:  862879
# making new cascade
#
#
# OG Orders left:  862879
# Cascade length:  3895
# New Orders left:  858984
# making new cascade
#
#
# OG Orders left:  858984
# Cascade length:  51
# New Orders left:  858933
# making new cascade
#
#
# OG Orders left:  858933
# Cascade length:  3002
# New Orders left:  855931
# making new cascade
#
#
# OG Orders left:  855931
# Cascade length:  3540
# New Orders left:  852391
# making new cascade
#
#
# OG Orders left:  852391
# Cascade length:  4988
# New Orders left:  847403
# making new cascade
#
#
# OG Orders left:  847403
# Cascade length:  2776
# New Orders left:  844627
# making new cascade
#
#
# OG Orders left:  844627
# Cascade length:  2086
# New Orders left:  842541
# making new cascade
#
#
# OG Orders left:  842541
# Cascade length:  3996
# New Orders left:  838545
# making new cascade
#
#
# OG Orders left:  838545
# Cascade length:  2987
# New Orders left:  835558
# making new cascade
#
#
# OG Orders left:  835558
# Cascade length:  15181
# New Orders left:  820377
# making new cascade
#
#
# OG Orders left:  820377
# Cascade length:  3198
# New Orders left:  817179
# making new cascade
#
#
# OG Orders left:  817179
# Cascade length:  2355
# New Orders left:  814824
# making new cascade
#
#
# OG Orders left:  814824
# Cascade length:  4161
# New Orders left:  810663
# making new cascade
#
#
# OG Orders left:  810663
# Cascade length:  4192
# New Orders left:  806471
# making new cascade
#
#
# OG Orders left:  806471
# Cascade length:  1925
# New Orders left:  804546
# making new cascade
#
#
# OG Orders left:  804546
# Cascade length:  2927
# New Orders left:  801619
# making new cascade
#
#
# OG Orders left:  801619
# Cascade length:  2414
# New Orders left:  799205
# making new cascade
#
#
# OG Orders left:  799205
# Cascade length:  12226
# New Orders left:  786979
# making new cascade
#
#
# OG Orders left:  786979
# Cascade length:  2589
# New Orders left:  784390
# making new cascade
#
#
# OG Orders left:  784390
# Cascade length:  4586
# New Orders left:  779804
# making new cascade
#
#
# OG Orders left:  779804
# Cascade length:  3472
# New Orders left:  776332
# making new cascade
#
#
# OG Orders left:  776332
# Cascade length:  2543
# New Orders left:  773789
# making new cascade
#
#
# OG Orders left:  773789
# Cascade length:  3232
# New Orders left:  770557
# making new cascade
#
#
# OG Orders left:  770557
# Cascade length:  1919
# New Orders left:  768638
# making new cascade
#
#
# OG Orders left:  768638
# Cascade length:  2886
# New Orders left:  765752
# making new cascade
#
#
# OG Orders left:  765752
# Cascade length:  2076
# New Orders left:  763676
# making new cascade
#
#
# OG Orders left:  763676
# Cascade length:  2421
# New Orders left:  761255
# making new cascade
#
#
# OG Orders left:  761255
# Cascade length:  5412
# New Orders left:  755843
# making new cascade
#
#
# OG Orders left:  755843
# Cascade length:  2305
# New Orders left:  753538
# making new cascade
#
#
# OG Orders left:  753538
# Cascade length:  1
# New Orders left:  753537
# making new cascade
#
#
# OG Orders left:  753537
# Cascade length:  4341
# New Orders left:  749196
# making new cascade
#
#
# OG Orders left:  749196
# Cascade length:  3227
# New Orders left:  745969
# making new cascade
#
#
# OG Orders left:  745969
# Cascade length:  2605
# New Orders left:  743364
# making new cascade
#
#
# OG Orders left:  743364
# Cascade length:  10907
# New Orders left:  732457
# making new cascade
#
#
# OG Orders left:  732457
# Cascade length:  2945
# New Orders left:  729512
# making new cascade
#
#
# OG Orders left:  729512
# Cascade length:  3739
# New Orders left:  725773
# making new cascade
#
#
# OG Orders left:  725773
# Cascade length:  2747
# New Orders left:  723026
# making new cascade
#
#
# OG Orders left:  723026
# Cascade length:  1548
# New Orders left:  721478
# making new cascade
#
#
# OG Orders left:  721478
# Cascade length:  2340
# New Orders left:  719138
# making new cascade
#
#
# OG Orders left:  719138
# Cascade length:  3665
# New Orders left:  715473
# making new cascade
#
#
# OG Orders left:  715473
# Cascade length:  3331
# New Orders left:  712142
# making new cascade
#
#
# OG Orders left:  712142
# Cascade length:  3022
# New Orders left:  709120
# making new cascade
#
#
# OG Orders left:  709120
# Cascade length:  3846
# New Orders left:  705274
# making new cascade
#
#
# OG Orders left:  705274
# Cascade length:  2908
# New Orders left:  702366
# making new cascade
#
#
# OG Orders left:  702366
# Cascade length:  2093
# New Orders left:  700273
# making new cascade
#
#
# OG Orders left:  700273
# Cascade length:  1758
# New Orders left:  698515
# making new cascade
#
#
# OG Orders left:  698515
# Cascade length:  4695
# New Orders left:  693820
# making new cascade
#
#
# OG Orders left:  693820
# Cascade length:  1947
# New Orders left:  691873
# making new cascade
#
#
# OG Orders left:  691873
# Cascade length:  1940
# New Orders left:  689933
# making new cascade
#
#
# OG Orders left:  689933
# Cascade length:  7148
# New Orders left:  682785
# making new cascade
#
#
# OG Orders left:  682785
# Cascade length:  2776
# New Orders left:  680009
# making new cascade
#
#
# OG Orders left:  680009
# Cascade length:  6763
# New Orders left:  673246
# making new cascade
#
#
# OG Orders left:  673246
# Cascade length:  331
# New Orders left:  672915
# making new cascade
#
#
# OG Orders left:  672915
# Cascade length:  2999
# New Orders left:  669916
# making new cascade
#
#
# OG Orders left:  669916
# Cascade length:  2483
# New Orders left:  667433
# making new cascade
#
#
# OG Orders left:  667433
# Cascade length:  3401
# New Orders left:  664032
# making new cascade
#
#
# OG Orders left:  664032
# Cascade length:  50
# New Orders left:  663982
# making new cascade
#
#
# OG Orders left:  663982
# Cascade length:  3798
# New Orders left:  660184
# making new cascade
#
#
# OG Orders left:  660184
# Cascade length:  1886
# New Orders left:  658298
# making new cascade
#
#
# OG Orders left:  658298
# Cascade length:  2637
# New Orders left:  655661
# making new cascade
#
#
# OG Orders left:  655661
# Cascade length:  3148
# New Orders left:  652513
# making new cascade
#
#
# OG Orders left:  652513
# Cascade length:  2235
# New Orders left:  650278
# making new cascade
#
#
# OG Orders left:  650278
# Cascade length:  3409
# New Orders left:  646869
# making new cascade
#
#
# OG Orders left:  646869
# Cascade length:  2862
# New Orders left:  644007
# making new cascade
#
#
# OG Orders left:  644007
# Cascade length:  7580
# New Orders left:  636427
# making new cascade
#
#
# OG Orders left:  636427
# Cascade length:  3730
# New Orders left:  632697
# making new cascade
#
#
# OG Orders left:  632697
# Cascade length:  4978
# New Orders left:  627719
# making new cascade
#
#
# OG Orders left:  627719
# Cascade length:  3129
# New Orders left:  624590
# making new cascade
#
#
# OG Orders left:  624590
# Cascade length:  2469
# New Orders left:  622121
# making new cascade
#
#
# OG Orders left:  622121
# Cascade length:  10181
# New Orders left:  611940
# making new cascade
#
#
# OG Orders left:  611940
# Cascade length:  2794
# New Orders left:  609146
# making new cascade
#
#
# OG Orders left:  609146
# Cascade length:  2852
# New Orders left:  606294
# making new cascade
#
#
# OG Orders left:  606294
# Cascade length:  13801
# New Orders left:  592493
# making new cascade
#
#
# OG Orders left:  592493
# Cascade length:  2023
# New Orders left:  590470
# making new cascade
#
#
# OG Orders left:  590470
# Cascade length:  2472
# New Orders left:  587998
# making new cascade
#
#
# OG Orders left:  587998
# Cascade length:  2988
# New Orders left:  585010
# making new cascade
#
#
# OG Orders left:  585010
# Cascade length:  8992
# New Orders left:  576018
# making new cascade
#
#
# OG Orders left:  576018
# Cascade length:  4878
# New Orders left:  571140
# making new cascade
#
#
# OG Orders left:  571140
# Cascade length:  2250
# New Orders left:  568890
# making new cascade
#
#
# OG Orders left:  568890
# Cascade length:  2626
# New Orders left:  566264
# making new cascade
#
#
# OG Orders left:  566264
# Cascade length:  2056
# New Orders left:  564208
# making new cascade
#
#
# OG Orders left:  564208
# Cascade length:  4031
# New Orders left:  560177
# making new cascade
#
#
# OG Orders left:  560177
# Cascade length:  4795
# New Orders left:  555382
# making new cascade
#
#
# OG Orders left:  555382
# Cascade length:  2317
# New Orders left:  553065
# making new cascade
#
#
# OG Orders left:  553065
# Cascade length:  3847
# New Orders left:  549218
# making new cascade
#
#
# OG Orders left:  549218
# Cascade length:  5096
# New Orders left:  544122
# making new cascade
#
#
# OG Orders left:  544122
# Cascade length:  2556
# New Orders left:  541566
# making new cascade
#
#
# OG Orders left:  541566
# Cascade length:  8259
# New Orders left:  533307
# making new cascade
#
#
# OG Orders left:  533307
# Cascade length:  2284
# New Orders left:  531023
# making new cascade
#
#
# OG Orders left:  531023
# Cascade length:  2719
# New Orders left:  528304
# making new cascade
#
#
# OG Orders left:  528304
# Cascade length:  2991
# New Orders left:  525313
# making new cascade
#
#
# OG Orders left:  525313
# Cascade length:  2779
# New Orders left:  522534
# making new cascade
#
#
# OG Orders left:  522534
# Cascade length:  1827
# New Orders left:  520707
# making new cascade
#
#
# OG Orders left:  520707
# Cascade length:  5311
# New Orders left:  515396
# making new cascade
#
#
# OG Orders left:  515396
# Cascade length:  5674
# New Orders left:  509722
# making new cascade
#
#
# OG Orders left:  509722
# Cascade length:  7178
# New Orders left:  502544
# making new cascade
#
#
# OG Orders left:  502544
# Cascade length:  7470
# New Orders left:  495074
# making new cascade
#
#
# OG Orders left:  495074
# Cascade length:  2270
# New Orders left:  492804
# making new cascade
#
#
# OG Orders left:  492804
# Cascade length:  2212
# New Orders left:  490592
# making new cascade
#
#
# OG Orders left:  490592
# Cascade length:  21031
# New Orders left:  469561
# making new cascade
#
#
# OG Orders left:  469561
# Cascade length:  2545
# New Orders left:  467016
# making new cascade
#
#
# OG Orders left:  467016
# Cascade length:  5038
# New Orders left:  461978
# making new cascade
#
#
# OG Orders left:  461978
# Cascade length:  8
# New Orders left:  461970
# making new cascade
#
#
# OG Orders left:  461970
# Cascade length:  2324
# New Orders left:  459646
# making new cascade
#
#
# OG Orders left:  459646
# Cascade length:  29
# New Orders left:  459617
# making new cascade
#
#
# OG Orders left:  459617
# Cascade length:  2201
# New Orders left:  457416
# making new cascade
#
#
# OG Orders left:  457416
# Cascade length:  3921
# New Orders left:  453495
# making new cascade
#
#
# OG Orders left:  453495
# Cascade length:  1993
# New Orders left:  451502
# making new cascade
#
#
# OG Orders left:  451502
# Cascade length:  5
# New Orders left:  451497
# making new cascade
#
#
# OG Orders left:  451497
# Cascade length:  2569
# New Orders left:  448928
# making new cascade
#
#
# OG Orders left:  448928
# Cascade length:  2858
# New Orders left:  446070
# making new cascade
#
#
# OG Orders left:  446070
# Cascade length:  2770
# New Orders left:  443300
# making new cascade
#
#
# OG Orders left:  443300
# Cascade length:  3442
# New Orders left:  439858
# making new cascade
#
#
# OG Orders left:  439858
# Cascade length:  3425
# New Orders left:  436433
# making new cascade
#
#
# OG Orders left:  436433
# Cascade length:  2629
# New Orders left:  433804
# making new cascade
#
#
# OG Orders left:  433804
# Cascade length:  2865
# New Orders left:  430939
# making new cascade
#
#
# OG Orders left:  430939
# Cascade length:  4660
# New Orders left:  426279
# making new cascade
#
#
# OG Orders left:  426279
# Cascade length:  1933
# New Orders left:  424346
# making new cascade
#
#
# OG Orders left:  424346
# Cascade length:  2009
# New Orders left:  422337
# making new cascade
#
#
# OG Orders left:  422337
# Cascade length:  2920
# New Orders left:  419417
# making new cascade
#
#
# OG Orders left:  419417
# Cascade length:  3735
# New Orders left:  415682
# making new cascade
#
#
# OG Orders left:  415682
# Cascade length:  2615
# New Orders left:  413067
# making new cascade
#
#
# OG Orders left:  413067
# Cascade length:  2446
# New Orders left:  410621
# making new cascade
#
#
# OG Orders left:  410621
# Cascade length:  2144
# New Orders left:  408477
# making new cascade
#
#
# OG Orders left:  408477
# Cascade length:  1940
# New Orders left:  406537
# making new cascade
#
#
# OG Orders left:  406537
# Cascade length:  5191
# New Orders left:  401346
# making new cascade
#
#
# OG Orders left:  401346
# Cascade length:  3036
# New Orders left:  398310
# making new cascade
#
#
# OG Orders left:  398310
# Cascade length:  3365
# New Orders left:  394945
# making new cascade
#
#
# OG Orders left:  394945
# Cascade length:  2465
# New Orders left:  392480
# making new cascade
#
#
# OG Orders left:  392480
# Cascade length:  2706
# New Orders left:  389774
# making new cascade
#
#
# OG Orders left:  389774
# Cascade length:  2335
# New Orders left:  387439
# making new cascade
#
#
# OG Orders left:  387439
# Cascade length:  8090
# New Orders left:  379349
# making new cascade
#
#
# OG Orders left:  379349
# Cascade length:  3071
# New Orders left:  376278
# making new cascade
#
#
# OG Orders left:  376278
# Cascade length:  4552
# New Orders left:  371726
# making new cascade
#
#
# OG Orders left:  371726
# Cascade length:  3717
# New Orders left:  368009
# making new cascade
#
#
# OG Orders left:  368009
# Cascade length:  2403
# New Orders left:  365606
# making new cascade
#
#
# OG Orders left:  365606
# Cascade length:  2893
# New Orders left:  362713
# making new cascade
#
#
# OG Orders left:  362713
# Cascade length:  13920
# New Orders left:  348793
# making new cascade
#
#
# OG Orders left:  348793
# Cascade length:  2170
# New Orders left:  346623
# making new cascade
#
#
# OG Orders left:  346623
# Cascade length:  1883
# New Orders left:  344740
# making new cascade
#
#
# OG Orders left:  344740
# Cascade length:  1622
# New Orders left:  343118
# making new cascade
#
#
# OG Orders left:  343118
# Cascade length:  3232
# New Orders left:  339886
# making new cascade
#
#
# OG Orders left:  339886
# Cascade length:  6260
# New Orders left:  333626
# making new cascade
#
#
# OG Orders left:  333626
# Cascade length:  3270
# New Orders left:  330356
# making new cascade
#
#
# OG Orders left:  330356
# Cascade length:  1993
# New Orders left:  328363
# making new cascade
#
#
# OG Orders left:  328363
# Cascade length:  2891
# New Orders left:  325472
# making new cascade
#
#
# OG Orders left:  325472
# Cascade length:  1678
# New Orders left:  323794
# making new cascade
#
#
# OG Orders left:  323794
# Cascade length:  2770
# New Orders left:  321024
# making new cascade
#
#
# OG Orders left:  321024
# Cascade length:  249
# New Orders left:  320775
# making new cascade
#
#
# OG Orders left:  320775
# Cascade length:  2506
# New Orders left:  318269
# making new cascade
#
#
# OG Orders left:  318269
# Cascade length:  2971
# New Orders left:  315298
# making new cascade
#
#
# OG Orders left:  315298
# Cascade length:  1653
# New Orders left:  313645
# making new cascade
#
#
# OG Orders left:  313645
# Cascade length:  6276
# New Orders left:  307369
# making new cascade
#
#
# OG Orders left:  307369
# Cascade length:  1973
# New Orders left:  305396
# making new cascade
#
#
# OG Orders left:  305396
# Cascade length:  1678
# New Orders left:  303718
# making new cascade
#
#
# OG Orders left:  303718
# Cascade length:  1566
# New Orders left:  302152
# making new cascade
#
#
# OG Orders left:  302152
# Cascade length:  2081
# New Orders left:  300071
# making new cascade
#
#
# OG Orders left:  300071
# Cascade length:  2289
# New Orders left:  297782
# making new cascade
#
#
# OG Orders left:  297782
# Cascade length:  2347
# New Orders left:  295435
# making new cascade
#
#
# OG Orders left:  295435
# Cascade length:  2668
# New Orders left:  292767
# making new cascade
#
#
# OG Orders left:  292767
# Cascade length:  3571
# New Orders left:  289196
# making new cascade
#
#
# OG Orders left:  289196
# Cascade length:  2548
# New Orders left:  286648
# making new cascade
#
#
# OG Orders left:  286648
# Cascade length:  2215
# New Orders left:  284433
# making new cascade
#
#
# OG Orders left:  284433
# Cascade length:  2235
# New Orders left:  282198
# making new cascade
#
#
# OG Orders left:  282198
# Cascade length:  8232
# New Orders left:  273966
# making new cascade
#
#
# OG Orders left:  273966
# Cascade length:  2196
# New Orders left:  271770
# making new cascade
#
#
# OG Orders left:  271770
# Cascade length:  844
# New Orders left:  270926
# making new cascade
#
#
# OG Orders left:  270926
# Cascade length:  2157
# New Orders left:  268769
# making new cascade
#
#
# OG Orders left:  268769
# Cascade length:  1461
# New Orders left:  267308
# making new cascade
#
#
# OG Orders left:  267308
# Cascade length:  2730
# New Orders left:  264578
# making new cascade
#
#
# OG Orders left:  264578
# Cascade length:  2327
# New Orders left:  262251
# making new cascade
#
#
# OG Orders left:  262251
# Cascade length:  1428
# New Orders left:  260823
# making new cascade
#
#
# OG Orders left:  260823
# Cascade length:  2475
# New Orders left:  258348
# making new cascade
#
#
# OG Orders left:  258348
# Cascade length:  2387
# New Orders left:  255961
# making new cascade
#
#
# OG Orders left:  255961
# Cascade length:  1664
# New Orders left:  254297
# making new cascade
#
#
# OG Orders left:  254297
# Cascade length:  10425
# New Orders left:  243872
# making new cascade
#
#
# OG Orders left:  243872
# Cascade length:  2232
# New Orders left:  241640
# making new cascade
#
#
# OG Orders left:  241640
# Cascade length:  1322
# New Orders left:  240318
# making new cascade
#
#
# OG Orders left:  240318
# Cascade length:  7552
# New Orders left:  232766
# making new cascade
#
#
# OG Orders left:  232766
# Cascade length:  4789
# New Orders left:  227977
# making new cascade
#
#
# OG Orders left:  227977
# Cascade length:  2265
# New Orders left:  225712
# making new cascade
#
#
# OG Orders left:  225712
# Cascade length:  7605
# New Orders left:  218107
# making new cascade
#
#
# OG Orders left:  218107
# Cascade length:  755
# New Orders left:  217352
# making new cascade
#
#
# OG Orders left:  217352
# Cascade length:  2755
# New Orders left:  214597
# making new cascade
#
#
# OG Orders left:  214597
# Cascade length:  1539
# New Orders left:  213058
# making new cascade
#
#
# OG Orders left:  213058
# Cascade length:  1639
# New Orders left:  211419
# making new cascade
#
#
# OG Orders left:  211419
# Cascade length:  3218
# New Orders left:  208201
# making new cascade
#
#
# OG Orders left:  208201
# Cascade length:  3699
# New Orders left:  204502
# making new cascade
#
#
# OG Orders left:  204502
# Cascade length:  5806
# New Orders left:  198696
# making new cascade
#
#
# OG Orders left:  198696
# Cascade length:  130
# New Orders left:  198566
# making new cascade
#
#
# OG Orders left:  198566
# Cascade length:  2356
# New Orders left:  196210
# making new cascade
#
#
# OG Orders left:  196210
# Cascade length:  2630
# New Orders left:  193580
# making new cascade
#
#
# OG Orders left:  193580
# Cascade length:  2306
# New Orders left:  191274
# making new cascade
#
#
# OG Orders left:  191274
# Cascade length:  4086
# New Orders left:  187188
# making new cascade
#
#
# OG Orders left:  187188
# Cascade length:  2362
# New Orders left:  184826
# making new cascade
#
#
# OG Orders left:  184826
# Cascade length:  5981
# New Orders left:  178845
# making new cascade
#
#
# OG Orders left:  178845
# Cascade length:  8
# New Orders left:  178837
# making new cascade
#
#
# OG Orders left:  178837
# Cascade length:  6974
# New Orders left:  171863
# making new cascade
#
#
# OG Orders left:  171863
# Cascade length:  3337
# New Orders left:  168526
# making new cascade
#
#
# OG Orders left:  168526
# Cascade length:  5047
# New Orders left:  163479
# making new cascade
#
#
# OG Orders left:  163479
# Cascade length:  2497
# New Orders left:  160982
# making new cascade
#
#
# OG Orders left:  160982
# Cascade length:  512
# New Orders left:  160470
# making new cascade
#
#
# OG Orders left:  160470
# Cascade length:  3379
# New Orders left:  157091
# making new cascade
#
#
# OG Orders left:  157091
# Cascade length:  3052
# New Orders left:  154039
# making new cascade
#
#
# OG Orders left:  154039
# Cascade length:  3274
# New Orders left:  150765
# making new cascade
#
#
# OG Orders left:  150765
# Cascade length:  3067
# New Orders left:  147698
# making new cascade
#
#
# OG Orders left:  147698
# Cascade length:  4631
# New Orders left:  143067
# making new cascade
#
#
# OG Orders left:  143067
# Cascade length:  1808
# New Orders left:  141259
# making new cascade
#
#
# OG Orders left:  141259
# Cascade length:  2809
# New Orders left:  138450
# making new cascade
#
#
# OG Orders left:  138450
# Cascade length:  4561
# New Orders left:  133889
# making new cascade
#
#
# OG Orders left:  133889
# Cascade length:  2626
# New Orders left:  131263
# making new cascade
#
#
# OG Orders left:  131263
# Cascade length:  2549
# New Orders left:  128714
# making new cascade
#
#
# OG Orders left:  128714
# Cascade length:  2913
# New Orders left:  125801
# making new cascade
#
#
# OG Orders left:  125801
# Cascade length:  2950
# New Orders left:  122851
# making new cascade
#
#
# OG Orders left:  122851
# Cascade length:  2371
# New Orders left:  120480
# making new cascade
#
#
# OG Orders left:  120480
# Cascade length:  2514
# New Orders left:  117966
# making new cascade
#
#
# OG Orders left:  117966
# Cascade length:  2709
# New Orders left:  115257
# making new cascade
#
#
# OG Orders left:  115257
# Cascade length:  1859
# New Orders left:  113398
# making new cascade
#
#
# OG Orders left:  113398
# Cascade length:  3756
# New Orders left:  109642
# making new cascade
#
#
# OG Orders left:  109642
# Cascade length:  2886
# New Orders left:  106756
# making new cascade
#
#
# OG Orders left:  106756
# Cascade length:  3997
# New Orders left:  102759
# making new cascade
#
#
# OG Orders left:  102759
# Cascade length:  3953
# New Orders left:  98806
# making new cascade
#
#
# OG Orders left:  98806
# Cascade length:  2774
# New Orders left:  96032
# making new cascade
#
#
# OG Orders left:  96032
# Cascade length:  5293
# New Orders left:  90739
# making new cascade
#
#
# OG Orders left:  90739
# Cascade length:  4092
# New Orders left:  86647
# making new cascade
#
#
# OG Orders left:  86647
# Cascade length:  2400
# New Orders left:  84247
# making new cascade
#
#
# OG Orders left:  84247
# Cascade length:  3821
# New Orders left:  80426
# making new cascade
#
#
# OG Orders left:  80426
# Cascade length:  2569
# New Orders left:  77857
# making new cascade
#
#
# OG Orders left:  77857
# Cascade length:  2259
# New Orders left:  75598
# making new cascade
#
#
# OG Orders left:  75598
# Cascade length:  3180
# New Orders left:  72418
# making new cascade
#
#
# OG Orders left:  72418
# Cascade length:  2449
# New Orders left:  69969
# making new cascade
#
#
# OG Orders left:  69969
# Cascade length:  2596
# New Orders left:  67373
# making new cascade
#
#
# OG Orders left:  67373
# Cascade length:  2458
# New Orders left:  64915
# making new cascade
#
#
# OG Orders left:  64915
# Cascade length:  4640
# New Orders left:  60275
# making new cascade
#
#
# OG Orders left:  60275
# Cascade length:  2202
# New Orders left:  58073
# making new cascade
#
#
# OG Orders left:  58073
# Cascade length:  2562
# New Orders left:  55511
# making new cascade
#
#
# OG Orders left:  55511
# Cascade length:  3103
# New Orders left:  52408
# making new cascade
#
#
# OG Orders left:  52408
# Cascade length:  3120
# New Orders left:  49288
# making new cascade
#
#
# OG Orders left:  49288
# Cascade length:  1795
# New Orders left:  47493
# making new cascade
#
#
# OG Orders left:  47493
# Cascade length:  1944
# New Orders left:  45549
# making new cascade
#
#
# OG Orders left:  45549
# Cascade length:  2195
# New Orders left:  43354
# making new cascade
#
#
# OG Orders left:  43354
# Cascade length:  1813
# New Orders left:  41541
# making new cascade
#
#
# OG Orders left:  41541
# Cascade length:  1980
# New Orders left:  39561
# making new cascade
#
#
# OG Orders left:  39561
# Cascade length:  2091
# New Orders left:  37470
# making new cascade
#
#
# OG Orders left:  37470
# Cascade length:  2450
# New Orders left:  35020
# making new cascade
#
#
# OG Orders left:  35020
# Cascade length:  1817
# New Orders left:  33203
# making new cascade
#
#
# OG Orders left:  33203
# Cascade length:  1582
# New Orders left:  31621
# making new cascade
#
#
# OG Orders left:  31621
# Cascade length:  1928
# New Orders left:  29693
# making new cascade
#
#
# OG Orders left:  29693
# Cascade length:  2249
# New Orders left:  27444
# making new cascade
#
#
# OG Orders left:  27444
# Cascade length:  2157
# New Orders left:  25287
# making new cascade
#
#
# OG Orders left:  25287
# Cascade length:  1363
# New Orders left:  23924
# making new cascade
#
#
# OG Orders left:  23924
# Cascade length:  1442
# New Orders left:  22482
# making new cascade
#
#
# OG Orders left:  22482
# Cascade length:  2101
# New Orders left:  20381
# making new cascade
#
#
# OG Orders left:  20381
# Cascade length:  2121
# New Orders left:  18260
# making new cascade
#
#
# OG Orders left:  18260
# Cascade length:  2025
# New Orders left:  16235
# making new cascade
#
#
# OG Orders left:  16235
# Cascade length:  1006
# New Orders left:  15229
# making new cascade
#
#
# OG Orders left:  15229
# Cascade length:  1061
# New Orders left:  14168
# making new cascade
#
#
# OG Orders left:  14168
# Cascade length:  1149
# New Orders left:  13019
# making new cascade
#
#
# OG Orders left:  13019
# Cascade length:  961
# New Orders left:  12058
# making new cascade
#
#
# OG Orders left:  12058
# Cascade length:  1047
# New Orders left:  11011
# making new cascade
#
#
# OG Orders left:  11011
# Cascade length:  938
# New Orders left:  10073
# making new cascade
#
#
# OG Orders left:  10073
# Cascade length:  1171
# New Orders left:  8902
# making new cascade
#
#
# OG Orders left:  8902
# Cascade length:  943
# New Orders left:  7959
# making new cascade
#
#
# OG Orders left:  7959
# Cascade length:  1038
# New Orders left:  6921
# making new cascade
#
#
# OG Orders left:  6921
# Cascade length:  915
# New Orders left:  6006
# making new cascade
#
#
# OG Orders left:  6006
# Cascade length:  809
# New Orders left:  5197
# making new cascade
#
#
# OG Orders left:  5197
# Cascade length:  866
# New Orders left:  4331
# making new cascade
#
#
# OG Orders left:  4331
# Cascade length:  568
# New Orders left:  3763
# making new cascade
#
#
# OG Orders left:  3763
# Cascade length:  701
# New Orders left:  3062
# making new cascade
#
#
# OG Orders left:  3062
# Cascade length:  789
# New Orders left:  2273
# making new cascade
#
#
# OG Orders left:  2273
# Cascade length:  676
# New Orders left:  1597
# making new cascade
#
#
# OG Orders left:  1597
# Cascade length:  443
# New Orders left:  1154
# making new cascade
#
#
# OG Orders left:  1154
# Cascade length:  381
# New Orders left:  773
# making new cascade
#
#
# OG Orders left:  773
# Cascade length:  265
# New Orders left:  508
# making new cascade
#
#
# OG Orders left:  508
# Cascade length:  290
# New Orders left:  218
# making new cascade
#
#
# OG Orders left:  218
# Cascade length:  119
# New Orders left:  99
# making new cascade
#
#
# OG Orders left:  99
# Cascade length:  90
# New Orders left:  9
# making new cascade
#
#
# OG Orders left:  9
# Cascade length:  7
# New Orders left:  2
# making new cascade
#
#
# OG Orders left:  2
# Cascade length:  2
# New Orders left:  0
# making new cascade

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades11_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_10_20_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_10_20_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_10_20_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
