# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_500_7200_100_5_10.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_500_7200_100_5_10.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_500_7200_100_5_10.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_500_7200_100_5_10.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 1   993     yshfc      1   -1.0
# 1                 2   993     yshfc      2   -2.0
# 2                10   993     yshfc     10    1.0
# 3                11   993     yshfc     11    1.0
# 4                13   993     yshfc     13   -1.0
# ...             ...   ...       ...    ...    ...
# 3836251           7  8192     xbcot     35    1.0
# 3836252           9  8192     xbcot     42    1.0
# 3836253           2  8192     jmeyl     76    1.0
# 3836254           3  8192     jmeyl     43   -1.0
# 3836255          16  8192     jmeyl     66   -1.0
#
# [3836256 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
len(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5192])
# Out:
# 2217038

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5192], traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5192)
with open('../causalCascades/7-9/causalCascades22_npc_500_7200_100_5_10.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2217038
# Cascade length:  30769
# New Orders left:  2186269
# making new cascade
#
#
# OG Orders left:  2186269
# Cascade length:  18190
# New Orders left:  2168079
# making new cascade
#
#
# OG Orders left:  2168079
# Cascade length:  20342
# New Orders left:  2147737
# making new cascade
#
#
# OG Orders left:  2147737
# Cascade length:  14429
# New Orders left:  2133308
# making new cascade
#
#
# OG Orders left:  2133308
# Cascade length:  16219
# New Orders left:  2117089
# making new cascade
#
#
# OG Orders left:  2117089
# Cascade length:  3099
# New Orders left:  2113990
# making new cascade
#
#
# OG Orders left:  2113990
# Cascade length:  7267
# New Orders left:  2106723
# making new cascade
#
#
# OG Orders left:  2106723
# Cascade length:  5967
# New Orders left:  2100756
# making new cascade
#
#
# OG Orders left:  2100756
# Cascade length:  14627
# New Orders left:  2086129
# making new cascade
#
#
# OG Orders left:  2086129
# Cascade length:  7161
# New Orders left:  2078968
# making new cascade
#
#
# OG Orders left:  2078968
# Cascade length:  5688
# New Orders left:  2073280
# making new cascade
#
#
# OG Orders left:  2073280
# Cascade length:  5792
# New Orders left:  2067488
# making new cascade
#
#
# OG Orders left:  2067488
# Cascade length:  15530
# New Orders left:  2051958
# making new cascade
#
#
# OG Orders left:  2051958
# Cascade length:  4139
# New Orders left:  2047819
# making new cascade
#
#
# OG Orders left:  2047819
# Cascade length:  4450
# New Orders left:  2043369
# making new cascade
#
#
# OG Orders left:  2043369
# Cascade length:  4726
# New Orders left:  2038643
# making new cascade
#
#
# OG Orders left:  2038643
# Cascade length:  3445
# New Orders left:  2035198
# making new cascade
#
#
# OG Orders left:  2035198
# Cascade length:  4577
# New Orders left:  2030621
# making new cascade
#
#
# OG Orders left:  2030621
# Cascade length:  3373
# New Orders left:  2027248
# making new cascade
#
#
# OG Orders left:  2027248
# Cascade length:  1663
# New Orders left:  2025585
# making new cascade
#
#
# OG Orders left:  2025585
# Cascade length:  4893
# New Orders left:  2020692
# making new cascade
#
#
# OG Orders left:  2020692
# Cascade length:  3427
# New Orders left:  2017265
# making new cascade
#
#
# OG Orders left:  2017265
# Cascade length:  5193
# New Orders left:  2012072
# making new cascade
#
#
# OG Orders left:  2012072
# Cascade length:  5525
# New Orders left:  2006547
# making new cascade
#
#
# OG Orders left:  2006547
# Cascade length:  3371
# New Orders left:  2003176
# making new cascade
#
#
# OG Orders left:  2003176
# Cascade length:  3301
# New Orders left:  1999875
# making new cascade
#
#
# OG Orders left:  1999875
# Cascade length:  3595
# New Orders left:  1996280
# making new cascade
#
#
# OG Orders left:  1996280
# Cascade length:  2594
# New Orders left:  1993686
# making new cascade
#
#
# OG Orders left:  1993686
# Cascade length:  4621
# New Orders left:  1989065
# making new cascade
#
#
# OG Orders left:  1989065
# Cascade length:  3644
# New Orders left:  1985421
# making new cascade
#
#
# OG Orders left:  1985421
# Cascade length:  4392
# New Orders left:  1981029
# making new cascade
#
#
# OG Orders left:  1981029
# Cascade length:  3715
# New Orders left:  1977314
# making new cascade
#
#
# OG Orders left:  1977314
# Cascade length:  4860
# New Orders left:  1972454
# making new cascade
#
#
# OG Orders left:  1972454
# Cascade length:  3377
# New Orders left:  1969077
# making new cascade
#
#
# OG Orders left:  1969077
# Cascade length:  4297
# New Orders left:  1964780
# making new cascade
#
#
# OG Orders left:  1964780
# Cascade length:  7270
# New Orders left:  1957510
# making new cascade
#
#
# OG Orders left:  1957510
# Cascade length:  2893
# New Orders left:  1954617
# making new cascade
#
#
# OG Orders left:  1954617
# Cascade length:  2907
# New Orders left:  1951710
# making new cascade
#
#
# OG Orders left:  1951710
# Cascade length:  3820
# New Orders left:  1947890
# making new cascade
#
#
# OG Orders left:  1947890
# Cascade length:  5388
# New Orders left:  1942502
# making new cascade
#
#
# OG Orders left:  1942502
# Cascade length:  4347
# New Orders left:  1938155
# making new cascade
#
#
# OG Orders left:  1938155
# Cascade length:  4496
# New Orders left:  1933659
# making new cascade
#
#
# OG Orders left:  1933659
# Cascade length:  7632
# New Orders left:  1926027
# making new cascade
#
#
# OG Orders left:  1926027
# Cascade length:  10010
# New Orders left:  1916017
# making new cascade
#
#
# OG Orders left:  1916017
# Cascade length:  3901
# New Orders left:  1912116
# making new cascade
#
#
# OG Orders left:  1912116
# Cascade length:  9160
# New Orders left:  1902956
# making new cascade
#
#
# OG Orders left:  1902956
# Cascade length:  3261
# New Orders left:  1899695
# making new cascade
#
#
# OG Orders left:  1899695
# Cascade length:  4378
# New Orders left:  1895317
# making new cascade
#
#
# OG Orders left:  1895317
# Cascade length:  2668
# New Orders left:  1892649
# making new cascade
#
#
# OG Orders left:  1892649
# Cascade length:  7914
# New Orders left:  1884735
# making new cascade
#
#
# OG Orders left:  1884735
# Cascade length:  6815
# New Orders left:  1877920
# making new cascade
#
#
# OG Orders left:  1877920
# Cascade length:  2616
# New Orders left:  1875304
# making new cascade
#
#
# OG Orders left:  1875304
# Cascade length:  2259
# New Orders left:  1873045
# making new cascade
#
#
# OG Orders left:  1873045
# Cascade length:  3302
# New Orders left:  1869743
# making new cascade
#
#
# OG Orders left:  1869743
# Cascade length:  5248
# New Orders left:  1864495
# making new cascade
#
#
# OG Orders left:  1864495
# Cascade length:  2558
# New Orders left:  1861937
# making new cascade
#
#
# OG Orders left:  1861937
# Cascade length:  2655
# New Orders left:  1859282
# making new cascade
#
#
# OG Orders left:  1859282
# Cascade length:  3119
# New Orders left:  1856163
# making new cascade
#
#
# OG Orders left:  1856163
# Cascade length:  7506
# New Orders left:  1848657
# making new cascade
#
#
# OG Orders left:  1848657
# Cascade length:  3919
# New Orders left:  1844738
# making new cascade
#
#
# OG Orders left:  1844738
# Cascade length:  3847
# New Orders left:  1840891
# making new cascade
#
#
# OG Orders left:  1840891
# Cascade length:  4818
# New Orders left:  1836073
# making new cascade
#
#
# OG Orders left:  1836073
# Cascade length:  2337
# New Orders left:  1833736
# making new cascade
#
#
# OG Orders left:  1833736
# Cascade length:  2632
# New Orders left:  1831104
# making new cascade
#
#
# OG Orders left:  1831104
# Cascade length:  3188
# New Orders left:  1827916
# making new cascade
#
#
# OG Orders left:  1827916
# Cascade length:  3156
# New Orders left:  1824760
# making new cascade
#
#
# OG Orders left:  1824760
# Cascade length:  2632
# New Orders left:  1822128
# making new cascade
#
#
# OG Orders left:  1822128
# Cascade length:  2603
# New Orders left:  1819525
# making new cascade
#
#
# OG Orders left:  1819525
# Cascade length:  5118
# New Orders left:  1814407
# making new cascade
#
#
# OG Orders left:  1814407
# Cascade length:  4821
# New Orders left:  1809586
# making new cascade
#
#
# OG Orders left:  1809586
# Cascade length:  2662
# New Orders left:  1806924
# making new cascade
#
#
# OG Orders left:  1806924
# Cascade length:  5565
# New Orders left:  1801359
# making new cascade
#
#
# OG Orders left:  1801359
# Cascade length:  2632
# New Orders left:  1798727
# making new cascade
#
#
# OG Orders left:  1798727
# Cascade length:  1728
# New Orders left:  1796999
# making new cascade
#
#
# OG Orders left:  1796999
# Cascade length:  1825
# New Orders left:  1795174
# making new cascade
#
#
# OG Orders left:  1795174
# Cascade length:  4708
# New Orders left:  1790466
# making new cascade
#
#
# OG Orders left:  1790466
# Cascade length:  1876
# New Orders left:  1788590
# making new cascade
#
#
# OG Orders left:  1788590
# Cascade length:  10978
# New Orders left:  1777612
# making new cascade
#
#
# OG Orders left:  1777612
# Cascade length:  2582
# New Orders left:  1775030
# making new cascade
#
#
# OG Orders left:  1775030
# Cascade length:  1831
# New Orders left:  1773199
# making new cascade
#
#
# OG Orders left:  1773199
# Cascade length:  6481
# New Orders left:  1766718
# making new cascade
#
#
# OG Orders left:  1766718
# Cascade length:  1919
# New Orders left:  1764799
# making new cascade
#
#
# OG Orders left:  1764799
# Cascade length:  1756
# New Orders left:  1763043
# making new cascade
#
#
# OG Orders left:  1763043
# Cascade length:  3364
# New Orders left:  1759679
# making new cascade
#
#
# OG Orders left:  1759679
# Cascade length:  2103
# New Orders left:  1757576
# making new cascade
#
#
# OG Orders left:  1757576
# Cascade length:  1399
# New Orders left:  1756177
# making new cascade
#
#
# OG Orders left:  1756177
# Cascade length:  10961
# New Orders left:  1745216
# making new cascade
#
#
# OG Orders left:  1745216
# Cascade length:  4319
# New Orders left:  1740897
# making new cascade
#
#
# OG Orders left:  1740897
# Cascade length:  5199
# New Orders left:  1735698
# making new cascade
#
#
# OG Orders left:  1735698
# Cascade length:  4463
# New Orders left:  1731235
# making new cascade
#
#
# OG Orders left:  1731235
# Cascade length:  3603
# New Orders left:  1727632
# making new cascade
#
#
# OG Orders left:  1727632
# Cascade length:  2838
# New Orders left:  1724794
# making new cascade
#
#
# OG Orders left:  1724794
# Cascade length:  6155
# New Orders left:  1718639
# making new cascade
#
#
# OG Orders left:  1718639
# Cascade length:  3265
# New Orders left:  1715374
# making new cascade
#
#
# OG Orders left:  1715374
# Cascade length:  9646
# New Orders left:  1705728
# making new cascade
#
#
# OG Orders left:  1705728
# Cascade length:  2189
# New Orders left:  1703539
# making new cascade
#
#
# OG Orders left:  1703539
# Cascade length:  7786
# New Orders left:  1695753
# making new cascade
#
#
# OG Orders left:  1695753
# Cascade length:  12881
# New Orders left:  1682872
# making new cascade
#
#
# OG Orders left:  1682872
# Cascade length:  8383
# New Orders left:  1674489
# making new cascade
#
#
# OG Orders left:  1674489
# Cascade length:  1714
# New Orders left:  1672775
# making new cascade
#
#
# OG Orders left:  1672775
# Cascade length:  1699
# New Orders left:  1671076
# making new cascade
#
#
# OG Orders left:  1671076
# Cascade length:  2595
# New Orders left:  1668481
# making new cascade
#
#
# OG Orders left:  1668481
# Cascade length:  2463
# New Orders left:  1666018
# making new cascade
#
#
# OG Orders left:  1666018
# Cascade length:  3295
# New Orders left:  1662723
# making new cascade
#
#
# OG Orders left:  1662723
# Cascade length:  2474
# New Orders left:  1660249
# making new cascade
#
#
# OG Orders left:  1660249
# Cascade length:  2053
# New Orders left:  1658196
# making new cascade
#
#
# OG Orders left:  1658196
# Cascade length:  2979
# New Orders left:  1655217
# making new cascade
#
#
# OG Orders left:  1655217
# Cascade length:  2111
# New Orders left:  1653106
# making new cascade
#
#
# OG Orders left:  1653106
# Cascade length:  1667
# New Orders left:  1651439
# making new cascade
#
#
# OG Orders left:  1651439
# Cascade length:  2338
# New Orders left:  1649101
# making new cascade
#
#
# OG Orders left:  1649101
# Cascade length:  1651
# New Orders left:  1647450
# making new cascade
#
#
# OG Orders left:  1647450
# Cascade length:  2788
# New Orders left:  1644662
# making new cascade
#
#
# OG Orders left:  1644662
# Cascade length:  3191
# New Orders left:  1641471
# making new cascade
#
#
# OG Orders left:  1641471
# Cascade length:  6744
# New Orders left:  1634727
# making new cascade
#
#
# OG Orders left:  1634727
# Cascade length:  1601
# New Orders left:  1633126
# making new cascade
#
#
# OG Orders left:  1633126
# Cascade length:  9047
# New Orders left:  1624079
# making new cascade
#
#
# OG Orders left:  1624079
# Cascade length:  3265
# New Orders left:  1620814
# making new cascade
#
#
# OG Orders left:  1620814
# Cascade length:  5707
# New Orders left:  1615107
# making new cascade
#
#
# OG Orders left:  1615107
# Cascade length:  2669
# New Orders left:  1612438
# making new cascade
#
#
# OG Orders left:  1612438
# Cascade length:  2235
# New Orders left:  1610203
# making new cascade
#
#
# OG Orders left:  1610203
# Cascade length:  3774
# New Orders left:  1606429
# making new cascade
#
#
# OG Orders left:  1606429
# Cascade length:  11007
# New Orders left:  1595422
# making new cascade
#
#
# OG Orders left:  1595422
# Cascade length:  1842
# New Orders left:  1593580
# making new cascade
#
#
# OG Orders left:  1593580
# Cascade length:  2254
# New Orders left:  1591326
# making new cascade
#
#
# OG Orders left:  1591326
# Cascade length:  8864
# New Orders left:  1582462
# making new cascade
#
#
# OG Orders left:  1582462
# Cascade length:  9424
# New Orders left:  1573038
# making new cascade
#
#
# OG Orders left:  1573038
# Cascade length:  1951
# New Orders left:  1571087
# making new cascade
#
#
# OG Orders left:  1571087
# Cascade length:  2099
# New Orders left:  1568988
# making new cascade
#
#
# OG Orders left:  1568988
# Cascade length:  4032
# New Orders left:  1564956
# making new cascade
#
#
# OG Orders left:  1564956
# Cascade length:  2490
# New Orders left:  1562466
# making new cascade
#
#
# OG Orders left:  1562466
# Cascade length:  2699
# New Orders left:  1559767
# making new cascade
#
#
# OG Orders left:  1559767
# Cascade length:  2017
# New Orders left:  1557750
# making new cascade
#
#
# OG Orders left:  1557750
# Cascade length:  2294
# New Orders left:  1555456
# making new cascade
#
#
# OG Orders left:  1555456
# Cascade length:  2179
# New Orders left:  1553277
# making new cascade
#
#
# OG Orders left:  1553277
# Cascade length:  8548
# New Orders left:  1544729
# making new cascade
#
#
# OG Orders left:  1544729
# Cascade length:  2453
# New Orders left:  1542276
# making new cascade
#
#
# OG Orders left:  1542276
# Cascade length:  1951
# New Orders left:  1540325
# making new cascade
#
#
# OG Orders left:  1540325
# Cascade length:  2188
# New Orders left:  1538137
# making new cascade
#
#
# OG Orders left:  1538137
# Cascade length:  4207
# New Orders left:  1533930
# making new cascade
#
#
# OG Orders left:  1533930
# Cascade length:  2002
# New Orders left:  1531928
# making new cascade
#
#
# OG Orders left:  1531928
# Cascade length:  2419
# New Orders left:  1529509
# making new cascade
#
#
# OG Orders left:  1529509
# Cascade length:  2929
# New Orders left:  1526580
# making new cascade
#
#
# OG Orders left:  1526580
# Cascade length:  2333
# New Orders left:  1524247
# making new cascade
#
#
# OG Orders left:  1524247
# Cascade length:  2897
# New Orders left:  1521350
# making new cascade
#
#
# OG Orders left:  1521350
# Cascade length:  2345
# New Orders left:  1519005
# making new cascade
#
#
# OG Orders left:  1519005
# Cascade length:  2577
# New Orders left:  1516428
# making new cascade
#
#
# OG Orders left:  1516428
# Cascade length:  2169
# New Orders left:  1514259
# making new cascade
#
#
# OG Orders left:  1514259
# Cascade length:  1909
# New Orders left:  1512350
# making new cascade
#
#
# OG Orders left:  1512350
# Cascade length:  1870
# New Orders left:  1510480
# making new cascade
#
#
# OG Orders left:  1510480
# Cascade length:  2185
# New Orders left:  1508295
# making new cascade
#
#
# OG Orders left:  1508295
# Cascade length:  3042
# New Orders left:  1505253
# making new cascade
#
#
# OG Orders left:  1505253
# Cascade length:  3906
# New Orders left:  1501347
# making new cascade
#
#
# OG Orders left:  1501347
# Cascade length:  2836
# New Orders left:  1498511
# making new cascade
#
#
# OG Orders left:  1498511
# Cascade length:  11034
# New Orders left:  1487477
# making new cascade
#
#
# OG Orders left:  1487477
# Cascade length:  5478
# New Orders left:  1481999
# making new cascade
#
#
# OG Orders left:  1481999
# Cascade length:  3367
# New Orders left:  1478632
# making new cascade
#
#
# OG Orders left:  1478632
# Cascade length:  3042
# New Orders left:  1475590
# making new cascade
#
#
# OG Orders left:  1475590
# Cascade length:  1107
# New Orders left:  1474483
# making new cascade
#
#
# OG Orders left:  1474483
# Cascade length:  2583
# New Orders left:  1471900
# making new cascade
#
#
# OG Orders left:  1471900
# Cascade length:  2115
# New Orders left:  1469785
# making new cascade
#
#
# OG Orders left:  1469785
# Cascade length:  12769
# New Orders left:  1457016
# making new cascade
#
#
# OG Orders left:  1457016
# Cascade length:  9300
# New Orders left:  1447716
# making new cascade
#
#
# OG Orders left:  1447716
# Cascade length:  2198
# New Orders left:  1445518
# making new cascade
#
#
# OG Orders left:  1445518
# Cascade length:  5019
# New Orders left:  1440499
# making new cascade
#
#
# OG Orders left:  1440499
# Cascade length:  2320
# New Orders left:  1438179
# making new cascade
#
#
# OG Orders left:  1438179
# Cascade length:  3769
# New Orders left:  1434410
# making new cascade
#
#
# OG Orders left:  1434410
# Cascade length:  2206
# New Orders left:  1432204
# making new cascade
#
#
# OG Orders left:  1432204
# Cascade length:  4014
# New Orders left:  1428190
# making new cascade
#
#
# OG Orders left:  1428190
# Cascade length:  5133
# New Orders left:  1423057
# making new cascade
#
#
# OG Orders left:  1423057
# Cascade length:  2877
# New Orders left:  1420180
# making new cascade
#
#
# OG Orders left:  1420180
# Cascade length:  1968
# New Orders left:  1418212
# making new cascade
#
#
# OG Orders left:  1418212
# Cascade length:  2618
# New Orders left:  1415594
# making new cascade
#
#
# OG Orders left:  1415594
# Cascade length:  2604
# New Orders left:  1412990
# making new cascade
#
#
# OG Orders left:  1412990
# Cascade length:  9197
# New Orders left:  1403793
# making new cascade
#
#
# OG Orders left:  1403793
# Cascade length:  2746
# New Orders left:  1401047
# making new cascade
#
#
# OG Orders left:  1401047
# Cascade length:  2627
# New Orders left:  1398420
# making new cascade
#
#
# OG Orders left:  1398420
# Cascade length:  2692
# New Orders left:  1395728
# making new cascade
#
#
# OG Orders left:  1395728
# Cascade length:  3795
# New Orders left:  1391933
# making new cascade
#
#
# OG Orders left:  1391933
# Cascade length:  3107
# New Orders left:  1388826
# making new cascade
#
#
# OG Orders left:  1388826
# Cascade length:  3030
# New Orders left:  1385796
# making new cascade
#
#
# OG Orders left:  1385796
# Cascade length:  4403
# New Orders left:  1381393
# making new cascade
#
#
# OG Orders left:  1381393
# Cascade length:  4246
# New Orders left:  1377147
# making new cascade
#
#
# OG Orders left:  1377147
# Cascade length:  3053
# New Orders left:  1374094
# making new cascade
#
#
# OG Orders left:  1374094
# Cascade length:  6367
# New Orders left:  1367727
# making new cascade
#
#
# OG Orders left:  1367727
# Cascade length:  6120
# New Orders left:  1361607
# making new cascade
#
#
# OG Orders left:  1361607
# Cascade length:  3347
# New Orders left:  1358260
# making new cascade
#
#
# OG Orders left:  1358260
# Cascade length:  2628
# New Orders left:  1355632
# making new cascade
#
#
# OG Orders left:  1355632
# Cascade length:  3657
# New Orders left:  1351975
# making new cascade
#
#
# OG Orders left:  1351975
# Cascade length:  5702
# New Orders left:  1346273
# making new cascade
#
#
# OG Orders left:  1346273
# Cascade length:  1
# New Orders left:  1346272
# making new cascade
#
#
# OG Orders left:  1346272
# Cascade length:  7
# New Orders left:  1346265
# making new cascade
#
#
# OG Orders left:  1346265
# Cascade length:  3075
# New Orders left:  1343190
# making new cascade
#
#
# OG Orders left:  1343190
# Cascade length:  3233
# New Orders left:  1339957
# making new cascade
#
#
# OG Orders left:  1339957
# Cascade length:  2640
# New Orders left:  1337317
# making new cascade
#
#
# OG Orders left:  1337317
# Cascade length:  3139
# New Orders left:  1334178
# making new cascade
#
#
# OG Orders left:  1334178
# Cascade length:  2201
# New Orders left:  1331977
# making new cascade
#
#
# OG Orders left:  1331977
# Cascade length:  6398
# New Orders left:  1325579
# making new cascade
#
#
# OG Orders left:  1325579
# Cascade length:  3046
# New Orders left:  1322533
# making new cascade
#
#
# OG Orders left:  1322533
# Cascade length:  2165
# New Orders left:  1320368
# making new cascade
#
#
# OG Orders left:  1320368
# Cascade length:  2571
# New Orders left:  1317797
# making new cascade
#
#
# OG Orders left:  1317797
# Cascade length:  3054
# New Orders left:  1314743
# making new cascade
#
#
# OG Orders left:  1314743
# Cascade length:  5803
# New Orders left:  1308940
# making new cascade
#
#
# OG Orders left:  1308940
# Cascade length:  4539
# New Orders left:  1304401
# making new cascade
#
#
# OG Orders left:  1304401
# Cascade length:  2977
# New Orders left:  1301424
# making new cascade
#
#
# OG Orders left:  1301424
# Cascade length:  2839
# New Orders left:  1298585
# making new cascade
#
#
# OG Orders left:  1298585
# Cascade length:  9158
# New Orders left:  1289427
# making new cascade
#
#
# OG Orders left:  1289427
# Cascade length:  4991
# New Orders left:  1284436
# making new cascade
#
#
# OG Orders left:  1284436
# Cascade length:  3079
# New Orders left:  1281357
# making new cascade
#
#
# OG Orders left:  1281357
# Cascade length:  2085
# New Orders left:  1279272
# making new cascade
#
#
# OG Orders left:  1279272
# Cascade length:  3404
# New Orders left:  1275868
# making new cascade
#
#
# OG Orders left:  1275868
# Cascade length:  2547
# New Orders left:  1273321
# making new cascade
#
#
# OG Orders left:  1273321
# Cascade length:  3452
# New Orders left:  1269869
# making new cascade
#
#
# OG Orders left:  1269869
# Cascade length:  2456
# New Orders left:  1267413
# making new cascade
#
#
# OG Orders left:  1267413
# Cascade length:  2441
# New Orders left:  1264972
# making new cascade
#
#
# OG Orders left:  1264972
# Cascade length:  5848
# New Orders left:  1259124
# making new cascade
#
#
# OG Orders left:  1259124
# Cascade length:  1969
# New Orders left:  1257155
# making new cascade
#
#
# OG Orders left:  1257155
# Cascade length:  3211
# New Orders left:  1253944
# making new cascade
#
#
# OG Orders left:  1253944
# Cascade length:  2720
# New Orders left:  1251224
# making new cascade
#
#
# OG Orders left:  1251224
# Cascade length:  2917
# New Orders left:  1248307
# making new cascade
#
#
# OG Orders left:  1248307
# Cascade length:  2831
# New Orders left:  1245476
# making new cascade
#
#
# OG Orders left:  1245476
# Cascade length:  2807
# New Orders left:  1242669
# making new cascade
#
#
# OG Orders left:  1242669
# Cascade length:  2410
# New Orders left:  1240259
# making new cascade
#
#
# OG Orders left:  1240259
# Cascade length:  4230
# New Orders left:  1236029
# making new cascade
#
#
# OG Orders left:  1236029
# Cascade length:  6936
# New Orders left:  1229093
# making new cascade
#
#
# OG Orders left:  1229093
# Cascade length:  9118
# New Orders left:  1219975
# making new cascade
#
#
# OG Orders left:  1219975
# Cascade length:  7534
# New Orders left:  1212441
# making new cascade
#
#
# OG Orders left:  1212441
# Cascade length:  4159
# New Orders left:  1208282
# making new cascade
#
#
# OG Orders left:  1208282
# Cascade length:  2314
# New Orders left:  1205968
# making new cascade
#
#
# OG Orders left:  1205968
# Cascade length:  3403
# New Orders left:  1202565
# making new cascade
#
#
# OG Orders left:  1202565
# Cascade length:  2524
# New Orders left:  1200041
# making new cascade
#
#
# OG Orders left:  1200041
# Cascade length:  5799
# New Orders left:  1194242
# making new cascade
#
#
# OG Orders left:  1194242
# Cascade length:  3221
# New Orders left:  1191021
# making new cascade
#
#
# OG Orders left:  1191021
# Cascade length:  2286
# New Orders left:  1188735
# making new cascade
#
#
# OG Orders left:  1188735
# Cascade length:  5976
# New Orders left:  1182759
# making new cascade
#
#
# OG Orders left:  1182759
# Cascade length:  2359
# New Orders left:  1180400
# making new cascade
#
#
# OG Orders left:  1180400
# Cascade length:  2464
# New Orders left:  1177936
# making new cascade
#
#
# OG Orders left:  1177936
# Cascade length:  3063
# New Orders left:  1174873
# making new cascade
#
#
# OG Orders left:  1174873
# Cascade length:  8808
# New Orders left:  1166065
# making new cascade
#
#
# OG Orders left:  1166065
# Cascade length:  3682
# New Orders left:  1162383
# making new cascade
#
#
# OG Orders left:  1162383
# Cascade length:  2787
# New Orders left:  1159596
# making new cascade
#
#
# OG Orders left:  1159596
# Cascade length:  2898
# New Orders left:  1156698
# making new cascade
#
#
# OG Orders left:  1156698
# Cascade length:  2248
# New Orders left:  1154450
# making new cascade
#
#
# OG Orders left:  1154450
# Cascade length:  3295
# New Orders left:  1151155
# making new cascade
#
#
# OG Orders left:  1151155
# Cascade length:  2003
# New Orders left:  1149152
# making new cascade
#
#
# OG Orders left:  1149152
# Cascade length:  2971
# New Orders left:  1146181
# making new cascade
#
#
# OG Orders left:  1146181
# Cascade length:  2427
# New Orders left:  1143754
# making new cascade
#
#
# OG Orders left:  1143754
# Cascade length:  2387
# New Orders left:  1141367
# making new cascade
#
#
# OG Orders left:  1141367
# Cascade length:  4320
# New Orders left:  1137047
# making new cascade
#
#
# OG Orders left:  1137047
# Cascade length:  2062
# New Orders left:  1134985
# making new cascade
#
#
# OG Orders left:  1134985
# Cascade length:  2112
# New Orders left:  1132873
# making new cascade
#
#
# OG Orders left:  1132873
# Cascade length:  3666
# New Orders left:  1129207
# making new cascade
#
#
# OG Orders left:  1129207
# Cascade length:  2333
# New Orders left:  1126874
# making new cascade
#
#
# OG Orders left:  1126874
# Cascade length:  2115
# New Orders left:  1124759
# making new cascade
#
#
# OG Orders left:  1124759
# Cascade length:  2508
# New Orders left:  1122251
# making new cascade
#
#
# OG Orders left:  1122251
# Cascade length:  3067
# New Orders left:  1119184
# making new cascade
#
#
# OG Orders left:  1119184
# Cascade length:  2683
# New Orders left:  1116501
# making new cascade
#
#
# OG Orders left:  1116501
# Cascade length:  2609
# New Orders left:  1113892
# making new cascade
#
#
# OG Orders left:  1113892
# Cascade length:  2663
# New Orders left:  1111229
# making new cascade
#
#
# OG Orders left:  1111229
# Cascade length:  2334
# New Orders left:  1108895
# making new cascade
#
#
# OG Orders left:  1108895
# Cascade length:  3030
# New Orders left:  1105865
# making new cascade
#
#
# OG Orders left:  1105865
# Cascade length:  1894
# New Orders left:  1103971
# making new cascade
#
#
# OG Orders left:  1103971
# Cascade length:  2539
# New Orders left:  1101432
# making new cascade
#
#
# OG Orders left:  1101432
# Cascade length:  1888
# New Orders left:  1099544
# making new cascade
#
#
# OG Orders left:  1099544
# Cascade length:  2116
# New Orders left:  1097428
# making new cascade
#
#
# OG Orders left:  1097428
# Cascade length:  2885
# New Orders left:  1094543
# making new cascade
#
#
# OG Orders left:  1094543
# Cascade length:  2155
# New Orders left:  1092388
# making new cascade
#
#
# OG Orders left:  1092388
# Cascade length:  1955
# New Orders left:  1090433
# making new cascade
#
#
# OG Orders left:  1090433
# Cascade length:  2565
# New Orders left:  1087868
# making new cascade
#
#
# OG Orders left:  1087868
# Cascade length:  2121
# New Orders left:  1085747
# making new cascade
#
#
# OG Orders left:  1085747
# Cascade length:  2966
# New Orders left:  1082781
# making new cascade
#
#
# OG Orders left:  1082781
# Cascade length:  2612
# New Orders left:  1080169
# making new cascade
#
#
# OG Orders left:  1080169
# Cascade length:  1345
# New Orders left:  1078824
# making new cascade
#
#
# OG Orders left:  1078824
# Cascade length:  5191
# New Orders left:  1073633
# making new cascade
#
#
# OG Orders left:  1073633
# Cascade length:  2722
# New Orders left:  1070911
# making new cascade
#
#
# OG Orders left:  1070911
# Cascade length:  2327
# New Orders left:  1068584
# making new cascade
#
#
# OG Orders left:  1068584
# Cascade length:  2104
# New Orders left:  1066480
# making new cascade
#
#
# OG Orders left:  1066480
# Cascade length:  5542
# New Orders left:  1060938
# making new cascade
#
#
# OG Orders left:  1060938
# Cascade length:  2549
# New Orders left:  1058389
# making new cascade
#
#
# OG Orders left:  1058389
# Cascade length:  2637
# New Orders left:  1055752
# making new cascade
#
#
# OG Orders left:  1055752
# Cascade length:  3348
# New Orders left:  1052404
# making new cascade
#
#
# OG Orders left:  1052404
# Cascade length:  2195
# New Orders left:  1050209
# making new cascade
#
#
# OG Orders left:  1050209
# Cascade length:  2689
# New Orders left:  1047520
# making new cascade
#
#
# OG Orders left:  1047520
# Cascade length:  3969
# New Orders left:  1043551
# making new cascade
#
#
# OG Orders left:  1043551
# Cascade length:  2553
# New Orders left:  1040998
# making new cascade
#
#
# OG Orders left:  1040998
# Cascade length:  3586
# New Orders left:  1037412
# making new cascade
#
#
# OG Orders left:  1037412
# Cascade length:  2354
# New Orders left:  1035058
# making new cascade
#
#
# OG Orders left:  1035058
# Cascade length:  3363
# New Orders left:  1031695
# making new cascade
#
#
# OG Orders left:  1031695
# Cascade length:  2750
# New Orders left:  1028945
# making new cascade
#
#
# OG Orders left:  1028945
# Cascade length:  3416
# New Orders left:  1025529
# making new cascade
#
#
# OG Orders left:  1025529
# Cascade length:  3613
# New Orders left:  1021916
# making new cascade
#
#
# OG Orders left:  1021916
# Cascade length:  2674
# New Orders left:  1019242
# making new cascade
#
#
# OG Orders left:  1019242
# Cascade length:  3657
# New Orders left:  1015585
# making new cascade
#
#
# OG Orders left:  1015585
# Cascade length:  3965
# New Orders left:  1011620
# making new cascade
#
#
# OG Orders left:  1011620
# Cascade length:  2352
# New Orders left:  1009268
# making new cascade
#
#
# OG Orders left:  1009268
# Cascade length:  2312
# New Orders left:  1006956
# making new cascade
#
#
# OG Orders left:  1006956
# Cascade length:  2580
# New Orders left:  1004376
# making new cascade
#
#
# OG Orders left:  1004376
# Cascade length:  2600
# New Orders left:  1001776
# making new cascade
#
#
# OG Orders left:  1001776
# Cascade length:  4153
# New Orders left:  997623
# making new cascade
#
#
# OG Orders left:  997623
# Cascade length:  1943
# New Orders left:  995680
# making new cascade
#
#
# OG Orders left:  995680
# Cascade length:  2460
# New Orders left:  993220
# making new cascade
#
#
# OG Orders left:  993220
# Cascade length:  2339
# New Orders left:  990881
# making new cascade
#
#
# OG Orders left:  990881
# Cascade length:  2513
# New Orders left:  988368
# making new cascade
#
#
# OG Orders left:  988368
# Cascade length:  9567
# New Orders left:  978801
# making new cascade
#
#
# OG Orders left:  978801
# Cascade length:  2286
# New Orders left:  976515
# making new cascade
#
#
# OG Orders left:  976515
# Cascade length:  2714
# New Orders left:  973801
# making new cascade
#
#
# OG Orders left:  973801
# Cascade length:  2168
# New Orders left:  971633
# making new cascade
#
#
# OG Orders left:  971633
# Cascade length:  2845
# New Orders left:  968788
# making new cascade
#
#
# OG Orders left:  968788
# Cascade length:  3004
# New Orders left:  965784
# making new cascade
#
#
# OG Orders left:  965784
# Cascade length:  3917
# New Orders left:  961867
# making new cascade
#
#
# OG Orders left:  961867
# Cascade length:  2367
# New Orders left:  959500
# making new cascade
#
#
# OG Orders left:  959500
# Cascade length:  3429
# New Orders left:  956071
# making new cascade
#
#
# OG Orders left:  956071
# Cascade length:  2008
# New Orders left:  954063
# making new cascade
#
#
# OG Orders left:  954063
# Cascade length:  3351
# New Orders left:  950712
# making new cascade
#
#
# OG Orders left:  950712
# Cascade length:  1638
# New Orders left:  949074
# making new cascade
#
#
# OG Orders left:  949074
# Cascade length:  2910
# New Orders left:  946164
# making new cascade
#
#
# OG Orders left:  946164
# Cascade length:  7012
# New Orders left:  939152
# making new cascade
#
#
# OG Orders left:  939152
# Cascade length:  3049
# New Orders left:  936103
# making new cascade
#
#
# OG Orders left:  936103
# Cascade length:  2708
# New Orders left:  933395
# making new cascade
#
#
# OG Orders left:  933395
# Cascade length:  2423
# New Orders left:  930972
# making new cascade
#
#
# OG Orders left:  930972
# Cascade length:  3320
# New Orders left:  927652
# making new cascade
#
#
# OG Orders left:  927652
# Cascade length:  3461
# New Orders left:  924191
# making new cascade
#
#
# OG Orders left:  924191
# Cascade length:  16
# New Orders left:  924175
# making new cascade
#
#
# OG Orders left:  924175
# Cascade length:  3838
# New Orders left:  920337
# making new cascade
#
#
# OG Orders left:  920337
# Cascade length:  2537
# New Orders left:  917800
# making new cascade
#
#
# OG Orders left:  917800
# Cascade length:  3268
# New Orders left:  914532
# making new cascade
#
#
# OG Orders left:  914532
# Cascade length:  2800
# New Orders left:  911732
# making new cascade
#
#
# OG Orders left:  911732
# Cascade length:  2904
# New Orders left:  908828
# making new cascade
#
#
# OG Orders left:  908828
# Cascade length:  3132
# New Orders left:  905696
# making new cascade
#
#
# OG Orders left:  905696
# Cascade length:  3776
# New Orders left:  901920
# making new cascade
#
#
# OG Orders left:  901920
# Cascade length:  2862
# New Orders left:  899058
# making new cascade
#
#
# OG Orders left:  899058
# Cascade length:  10872
# New Orders left:  888186
# making new cascade
#
#
# OG Orders left:  888186
# Cascade length:  2925
# New Orders left:  885261
# making new cascade
#
#
# OG Orders left:  885261
# Cascade length:  3916
# New Orders left:  881345
# making new cascade
#
#
# OG Orders left:  881345
# Cascade length:  3800
# New Orders left:  877545
# making new cascade
#
#
# OG Orders left:  877545
# Cascade length:  3791
# New Orders left:  873754
# making new cascade
#
#
# OG Orders left:  873754
# Cascade length:  2391
# New Orders left:  871363
# making new cascade
#
#
# OG Orders left:  871363
# Cascade length:  4127
# New Orders left:  867236
# making new cascade
#
#
# OG Orders left:  867236
# Cascade length:  2575
# New Orders left:  864661
# making new cascade
#
#
# OG Orders left:  864661
# Cascade length:  2722
# New Orders left:  861939
# making new cascade
#
#
# OG Orders left:  861939
# Cascade length:  3515
# New Orders left:  858424
# making new cascade
#
#
# OG Orders left:  858424
# Cascade length:  2437
# New Orders left:  855987
# making new cascade
#
#
# OG Orders left:  855987
# Cascade length:  12256
# New Orders left:  843731
# making new cascade
#
#
# OG Orders left:  843731
# Cascade length:  3969
# New Orders left:  839762
# making new cascade
#
#
# OG Orders left:  839762
# Cascade length:  2610
# New Orders left:  837152
# making new cascade
#
#
# OG Orders left:  837152
# Cascade length:  2399
# New Orders left:  834753
# making new cascade
#
#
# OG Orders left:  834753
# Cascade length:  4144
# New Orders left:  830609
# making new cascade
#
#
# OG Orders left:  830609
# Cascade length:  3786
# New Orders left:  826823
# making new cascade
#
#
# OG Orders left:  826823
# Cascade length:  10685
# New Orders left:  816138
# making new cascade
#
#
# OG Orders left:  816138
# Cascade length:  3377
# New Orders left:  812761
# making new cascade
#
#
# OG Orders left:  812761
# Cascade length:  3478
# New Orders left:  809283
# making new cascade
#
#
# OG Orders left:  809283
# Cascade length:  2773
# New Orders left:  806510
# making new cascade
#
#
# OG Orders left:  806510
# Cascade length:  3568
# New Orders left:  802942
# making new cascade
#
#
# OG Orders left:  802942
# Cascade length:  2534
# New Orders left:  800408
# making new cascade
#
#
# OG Orders left:  800408
# Cascade length:  13550
# New Orders left:  786858
# making new cascade
#
#
# OG Orders left:  786858
# Cascade length:  5417
# New Orders left:  781441
# making new cascade
#
#
# OG Orders left:  781441
# Cascade length:  3133
# New Orders left:  778308
# making new cascade
#
#
# OG Orders left:  778308
# Cascade length:  4225
# New Orders left:  774083
# making new cascade
#
#
# OG Orders left:  774083
# Cascade length:  4304
# New Orders left:  769779
# making new cascade
#
#
# OG Orders left:  769779
# Cascade length:  7226
# New Orders left:  762553
# making new cascade
#
#
# OG Orders left:  762553
# Cascade length:  4116
# New Orders left:  758437
# making new cascade
#
#
# OG Orders left:  758437
# Cascade length:  2654
# New Orders left:  755783
# making new cascade
#
#
# OG Orders left:  755783
# Cascade length:  3236
# New Orders left:  752547
# making new cascade
#
#
# OG Orders left:  752547
# Cascade length:  2652
# New Orders left:  749895
# making new cascade
#
#
# OG Orders left:  749895
# Cascade length:  5000
# New Orders left:  744895
# making new cascade
#
#
# OG Orders left:  744895
# Cascade length:  2364
# New Orders left:  742531
# making new cascade
#
#
# OG Orders left:  742531
# Cascade length:  5050
# New Orders left:  737481
# making new cascade
#
#
# OG Orders left:  737481
# Cascade length:  3152
# New Orders left:  734329
# making new cascade
#
#
# OG Orders left:  734329
# Cascade length:  2557
# New Orders left:  731772
# making new cascade
#
#
# OG Orders left:  731772
# Cascade length:  3058
# New Orders left:  728714
# making new cascade
#
#
# OG Orders left:  728714
# Cascade length:  14329
# New Orders left:  714385
# making new cascade
#
#
# OG Orders left:  714385
# Cascade length:  12735
# New Orders left:  701650
# making new cascade
#
#
# OG Orders left:  701650
# Cascade length:  2905
# New Orders left:  698745
# making new cascade
#
#
# OG Orders left:  698745
# Cascade length:  2300
# New Orders left:  696445
# making new cascade
#
#
# OG Orders left:  696445
# Cascade length:  2264
# New Orders left:  694181
# making new cascade
#
#
# OG Orders left:  694181
# Cascade length:  4698
# New Orders left:  689483
# making new cascade
#
#
# OG Orders left:  689483
# Cascade length:  3491
# New Orders left:  685992
# making new cascade
#
#
# OG Orders left:  685992
# Cascade length:  5245
# New Orders left:  680747
# making new cascade
#
#
# OG Orders left:  680747
# Cascade length:  3210
# New Orders left:  677537
# making new cascade
#
#
# OG Orders left:  677537
# Cascade length:  2386
# New Orders left:  675151
# making new cascade
#
#
# OG Orders left:  675151
# Cascade length:  1
# New Orders left:  675150
# making new cascade
#
#
# OG Orders left:  675150
# Cascade length:  3292
# New Orders left:  671858
# making new cascade
#
#
# OG Orders left:  671858
# Cascade length:  3967
# New Orders left:  667891
# making new cascade
#
#
# OG Orders left:  667891
# Cascade length:  2686
# New Orders left:  665205
# making new cascade
#
#
# OG Orders left:  665205
# Cascade length:  6027
# New Orders left:  659178
# making new cascade
#
#
# OG Orders left:  659178
# Cascade length:  13877
# New Orders left:  645301
# making new cascade
#
#
# OG Orders left:  645301
# Cascade length:  4521
# New Orders left:  640780
# making new cascade
#
#
# OG Orders left:  640780
# Cascade length:  2396
# New Orders left:  638384
# making new cascade
#
#
# OG Orders left:  638384
# Cascade length:  2301
# New Orders left:  636083
# making new cascade
#
#
# OG Orders left:  636083
# Cascade length:  7513
# New Orders left:  628570
# making new cascade
#
#
# OG Orders left:  628570
# Cascade length:  2430
# New Orders left:  626140
# making new cascade
#
#
# OG Orders left:  626140
# Cascade length:  2625
# New Orders left:  623515
# making new cascade
#
#
# OG Orders left:  623515
# Cascade length:  2744
# New Orders left:  620771
# making new cascade
#
#
# OG Orders left:  620771
# Cascade length:  2218
# New Orders left:  618553
# making new cascade
#
#
# OG Orders left:  618553
# Cascade length:  2150
# New Orders left:  616403
# making new cascade
#
#
# OG Orders left:  616403
# Cascade length:  2782
# New Orders left:  613621
# making new cascade
#
#
# OG Orders left:  613621
# Cascade length:  2806
# New Orders left:  610815
# making new cascade
#
#
# OG Orders left:  610815
# Cascade length:  1941
# New Orders left:  608874
# making new cascade
#
#
# OG Orders left:  608874
# Cascade length:  2089
# New Orders left:  606785
# making new cascade
#
#
# OG Orders left:  606785
# Cascade length:  2240
# New Orders left:  604545
# making new cascade
#
#
# OG Orders left:  604545
# Cascade length:  3754
# New Orders left:  600791
# making new cascade
#
#
# OG Orders left:  600791
# Cascade length:  2370
# New Orders left:  598421
# making new cascade
#
#
# OG Orders left:  598421
# Cascade length:  2429
# New Orders left:  595992
# making new cascade
#
#
# OG Orders left:  595992
# Cascade length:  13464
# New Orders left:  582528
# making new cascade
#
#
# OG Orders left:  582528
# Cascade length:  2632
# New Orders left:  579896
# making new cascade
#
#
# OG Orders left:  579896
# Cascade length:  3297
# New Orders left:  576599
# making new cascade
#
#
# OG Orders left:  576599
# Cascade length:  3171
# New Orders left:  573428
# making new cascade
#
#
# OG Orders left:  573428
# Cascade length:  1502
# New Orders left:  571926
# making new cascade
#
#
# OG Orders left:  571926
# Cascade length:  5511
# New Orders left:  566415
# making new cascade
#
#
# OG Orders left:  566415
# Cascade length:  2630
# New Orders left:  563785
# making new cascade
#
#
# OG Orders left:  563785
# Cascade length:  2852
# New Orders left:  560933
# making new cascade
#
#
# OG Orders left:  560933
# Cascade length:  4846
# New Orders left:  556087
# making new cascade
#
#
# OG Orders left:  556087
# Cascade length:  2192
# New Orders left:  553895
# making new cascade
#
#
# OG Orders left:  553895
# Cascade length:  17220
# New Orders left:  536675
# making new cascade
#
#
# OG Orders left:  536675
# Cascade length:  4556
# New Orders left:  532119
# making new cascade
#
#
# OG Orders left:  532119
# Cascade length:  9466
# New Orders left:  522653
# making new cascade
#
#
# OG Orders left:  522653
# Cascade length:  2198
# New Orders left:  520455
# making new cascade
#
#
# OG Orders left:  520455
# Cascade length:  2670
# New Orders left:  517785
# making new cascade
#
#
# OG Orders left:  517785
# Cascade length:  2495
# New Orders left:  515290
# making new cascade
#
#
# OG Orders left:  515290
# Cascade length:  2478
# New Orders left:  512812
# making new cascade
#
#
# OG Orders left:  512812
# Cascade length:  2654
# New Orders left:  510158
# making new cascade
#
#
# OG Orders left:  510158
# Cascade length:  3558
# New Orders left:  506600
# making new cascade
#
#
# OG Orders left:  506600
# Cascade length:  3497
# New Orders left:  503103
# making new cascade
#
#
# OG Orders left:  503103
# Cascade length:  6781
# New Orders left:  496322
# making new cascade
#
#
# OG Orders left:  496322
# Cascade length:  4205
# New Orders left:  492117
# making new cascade
#
#
# OG Orders left:  492117
# Cascade length:  1995
# New Orders left:  490122
# making new cascade
#
#
# OG Orders left:  490122
# Cascade length:  2669
# New Orders left:  487453
# making new cascade
#
#
# OG Orders left:  487453
# Cascade length:  2332
# New Orders left:  485121
# making new cascade
#
#
# OG Orders left:  485121
# Cascade length:  2240
# New Orders left:  482881
# making new cascade
#
#
# OG Orders left:  482881
# Cascade length:  7224
# New Orders left:  475657
# making new cascade
#
#
# OG Orders left:  475657
# Cascade length:  3235
# New Orders left:  472422
# making new cascade
#
#
# OG Orders left:  472422
# Cascade length:  3872
# New Orders left:  468550
# making new cascade
#
#
# OG Orders left:  468550
# Cascade length:  3283
# New Orders left:  465267
# making new cascade
#
#
# OG Orders left:  465267
# Cascade length:  2635
# New Orders left:  462632
# making new cascade
#
#
# OG Orders left:  462632
# Cascade length:  6269
# New Orders left:  456363
# making new cascade
#
#
# OG Orders left:  456363
# Cascade length:  6857
# New Orders left:  449506
# making new cascade
#
#
# OG Orders left:  449506
# Cascade length:  2799
# New Orders left:  446707
# making new cascade
#
#
# OG Orders left:  446707
# Cascade length:  3127
# New Orders left:  443580
# making new cascade
#
#
# OG Orders left:  443580
# Cascade length:  2702
# New Orders left:  440878
# making new cascade
#
#
# OG Orders left:  440878
# Cascade length:  2171
# New Orders left:  438707
# making new cascade
#
#
# OG Orders left:  438707
# Cascade length:  3909
# New Orders left:  434798
# making new cascade
#
#
# OG Orders left:  434798
# Cascade length:  2621
# New Orders left:  432177
# making new cascade
#
#
# OG Orders left:  432177
# Cascade length:  2275
# New Orders left:  429902
# making new cascade
#
#
# OG Orders left:  429902
# Cascade length:  2729
# New Orders left:  427173
# making new cascade
#
#
# OG Orders left:  427173
# Cascade length:  2540
# New Orders left:  424633
# making new cascade
#
#
# OG Orders left:  424633
# Cascade length:  2684
# New Orders left:  421949
# making new cascade
#
#
# OG Orders left:  421949
# Cascade length:  8278
# New Orders left:  413671
# making new cascade
#
#
# OG Orders left:  413671
# Cascade length:  3395
# New Orders left:  410276
# making new cascade
#
#
# OG Orders left:  410276
# Cascade length:  5788
# New Orders left:  404488
# making new cascade
#
#
# OG Orders left:  404488
# Cascade length:  2545
# New Orders left:  401943
# making new cascade
#
#
# OG Orders left:  401943
# Cascade length:  3237
# New Orders left:  398706
# making new cascade
#
#
# OG Orders left:  398706
# Cascade length:  118
# New Orders left:  398588
# making new cascade
#
#
# OG Orders left:  398588
# Cascade length:  2077
# New Orders left:  396511
# making new cascade
#
#
# OG Orders left:  396511
# Cascade length:  3151
# New Orders left:  393360
# making new cascade
#
#
# OG Orders left:  393360
# Cascade length:  2577
# New Orders left:  390783
# making new cascade
#
#
# OG Orders left:  390783
# Cascade length:  1
# New Orders left:  390782
# making new cascade
#
#
# OG Orders left:  390782
# Cascade length:  2872
# New Orders left:  387910
# making new cascade
#
#
# OG Orders left:  387910
# Cascade length:  2190
# New Orders left:  385720
# making new cascade
#
#
# OG Orders left:  385720
# Cascade length:  3125
# New Orders left:  382595
# making new cascade
#
#
# OG Orders left:  382595
# Cascade length:  5398
# New Orders left:  377197
# making new cascade
#
#
# OG Orders left:  377197
# Cascade length:  2357
# New Orders left:  374840
# making new cascade
#
#
# OG Orders left:  374840
# Cascade length:  2717
# New Orders left:  372123
# making new cascade
#
#
# OG Orders left:  372123
# Cascade length:  2886
# New Orders left:  369237
# making new cascade
#
#
# OG Orders left:  369237
# Cascade length:  2033
# New Orders left:  367204
# making new cascade
#
#
# OG Orders left:  367204
# Cascade length:  4065
# New Orders left:  363139
# making new cascade
#
#
# OG Orders left:  363139
# Cascade length:  2510
# New Orders left:  360629
# making new cascade
#
#
# OG Orders left:  360629
# Cascade length:  2648
# New Orders left:  357981
# making new cascade
#
#
# OG Orders left:  357981
# Cascade length:  3947
# New Orders left:  354034
# making new cascade
#
#
# OG Orders left:  354034
# Cascade length:  6357
# New Orders left:  347677
# making new cascade
#
#
# OG Orders left:  347677
# Cascade length:  2522
# New Orders left:  345155
# making new cascade
#
#
# OG Orders left:  345155
# Cascade length:  2917
# New Orders left:  342238
# making new cascade
#
#
# OG Orders left:  342238
# Cascade length:  7113
# New Orders left:  335125
# making new cascade
#
#
# OG Orders left:  335125
# Cascade length:  2483
# New Orders left:  332642
# making new cascade
#
#
# OG Orders left:  332642
# Cascade length:  2406
# New Orders left:  330236
# making new cascade
#
#
# OG Orders left:  330236
# Cascade length:  2845
# New Orders left:  327391
# making new cascade
#
#
# OG Orders left:  327391
# Cascade length:  2268
# New Orders left:  325123
# making new cascade
#
#
# OG Orders left:  325123
# Cascade length:  2966
# New Orders left:  322157
# making new cascade
#
#
# OG Orders left:  322157
# Cascade length:  7449
# New Orders left:  314708
# making new cascade
#
#
# OG Orders left:  314708
# Cascade length:  2404
# New Orders left:  312304
# making new cascade
#
#
# OG Orders left:  312304
# Cascade length:  4176
# New Orders left:  308128
# making new cascade
#
#
# OG Orders left:  308128
# Cascade length:  4010
# New Orders left:  304118
# making new cascade
#
#
# OG Orders left:  304118
# Cascade length:  3347
# New Orders left:  300771
# making new cascade
#
#
# OG Orders left:  300771
# Cascade length:  2841
# New Orders left:  297930
# making new cascade
#
#
# OG Orders left:  297930
# Cascade length:  8072
# New Orders left:  289858
# making new cascade
#
#
# OG Orders left:  289858
# Cascade length:  6462
# New Orders left:  283396
# making new cascade
#
#
# OG Orders left:  283396
# Cascade length:  2786
# New Orders left:  280610
# making new cascade
#
#
# OG Orders left:  280610
# Cascade length:  2502
# New Orders left:  278108
# making new cascade
#
#
# OG Orders left:  278108
# Cascade length:  1932
# New Orders left:  276176
# making new cascade
#
#
# OG Orders left:  276176
# Cascade length:  2370
# New Orders left:  273806
# making new cascade
#
#
# OG Orders left:  273806
# Cascade length:  2419
# New Orders left:  271387
# making new cascade
#
#
# OG Orders left:  271387
# Cascade length:  1904
# New Orders left:  269483
# making new cascade
#
#
# OG Orders left:  269483
# Cascade length:  2830
# New Orders left:  266653
# making new cascade
#
#
# OG Orders left:  266653
# Cascade length:  6983
# New Orders left:  259670
# making new cascade
#
#
# OG Orders left:  259670
# Cascade length:  2198
# New Orders left:  257472
# making new cascade
#
#
# OG Orders left:  257472
# Cascade length:  1759
# New Orders left:  255713
# making new cascade
#
#
# OG Orders left:  255713
# Cascade length:  1764
# New Orders left:  253949
# making new cascade
#
#
# OG Orders left:  253949
# Cascade length:  2101
# New Orders left:  251848
# making new cascade
#
#
# OG Orders left:  251848
# Cascade length:  1740
# New Orders left:  250108
# making new cascade
#
#
# OG Orders left:  250108
# Cascade length:  2662
# New Orders left:  247446
# making new cascade
#
#
# OG Orders left:  247446
# Cascade length:  2345
# New Orders left:  245101
# making new cascade
#
#
# OG Orders left:  245101
# Cascade length:  1910
# New Orders left:  243191
# making new cascade
#
#
# OG Orders left:  243191
# Cascade length:  1586
# New Orders left:  241605
# making new cascade
#
#
# OG Orders left:  241605
# Cascade length:  2062
# New Orders left:  239543
# making new cascade
#
#
# OG Orders left:  239543
# Cascade length:  2208
# New Orders left:  237335
# making new cascade
#
#
# OG Orders left:  237335
# Cascade length:  2677
# New Orders left:  234658
# making new cascade
#
#
# OG Orders left:  234658
# Cascade length:  3007
# New Orders left:  231651
# making new cascade
#
#
# OG Orders left:  231651
# Cascade length:  5019
# New Orders left:  226632
# making new cascade
#
#
# OG Orders left:  226632
# Cascade length:  1776
# New Orders left:  224856
# making new cascade
#
#
# OG Orders left:  224856
# Cascade length:  3619
# New Orders left:  221237
# making new cascade
#
#
# OG Orders left:  221237
# Cascade length:  2060
# New Orders left:  219177
# making new cascade
#
#
# OG Orders left:  219177
# Cascade length:  1987
# New Orders left:  217190
# making new cascade
#
#
# OG Orders left:  217190
# Cascade length:  2762
# New Orders left:  214428
# making new cascade
#
#
# OG Orders left:  214428
# Cascade length:  2177
# New Orders left:  212251
# making new cascade
#
#
# OG Orders left:  212251
# Cascade length:  1806
# New Orders left:  210445
# making new cascade
#
#
# OG Orders left:  210445
# Cascade length:  2497
# New Orders left:  207948
# making new cascade
#
#
# OG Orders left:  207948
# Cascade length:  3362
# New Orders left:  204586
# making new cascade
#
#
# OG Orders left:  204586
# Cascade length:  1958
# New Orders left:  202628
# making new cascade
#
#
# OG Orders left:  202628
# Cascade length:  2037
# New Orders left:  200591
# making new cascade
#
#
# OG Orders left:  200591
# Cascade length:  2094
# New Orders left:  198497
# making new cascade
#
#
# OG Orders left:  198497
# Cascade length:  1857
# New Orders left:  196640
# making new cascade
#
#
# OG Orders left:  196640
# Cascade length:  2313
# New Orders left:  194327
# making new cascade
#
#
# OG Orders left:  194327
# Cascade length:  2398
# New Orders left:  191929
# making new cascade
#
#
# OG Orders left:  191929
# Cascade length:  2411
# New Orders left:  189518
# making new cascade
#
#
# OG Orders left:  189518
# Cascade length:  3263
# New Orders left:  186255
# making new cascade
#
#
# OG Orders left:  186255
# Cascade length:  4648
# New Orders left:  181607
# making new cascade
#
#
# OG Orders left:  181607
# Cascade length:  2500
# New Orders left:  179107
# making new cascade
#
#
# OG Orders left:  179107
# Cascade length:  2346
# New Orders left:  176761
# making new cascade
#
#
# OG Orders left:  176761
# Cascade length:  3943
# New Orders left:  172818
# making new cascade
#
#
# OG Orders left:  172818
# Cascade length:  4792
# New Orders left:  168026
# making new cascade
#
#
# OG Orders left:  168026
# Cascade length:  2294
# New Orders left:  165732
# making new cascade
#
#
# OG Orders left:  165732
# Cascade length:  358
# New Orders left:  165374
# making new cascade
#
#
# OG Orders left:  165374
# Cascade length:  2635
# New Orders left:  162739
# making new cascade
#
#
# OG Orders left:  162739
# Cascade length:  1842
# New Orders left:  160897
# making new cascade
#
#
# OG Orders left:  160897
# Cascade length:  2023
# New Orders left:  158874
# making new cascade
#
#
# OG Orders left:  158874
# Cascade length:  3863
# New Orders left:  155011
# making new cascade
#
#
# OG Orders left:  155011
# Cascade length:  2692
# New Orders left:  152319
# making new cascade
#
#
# OG Orders left:  152319
# Cascade length:  2680
# New Orders left:  149639
# making new cascade
#
#
# OG Orders left:  149639
# Cascade length:  2325
# New Orders left:  147314
# making new cascade
#
#
# OG Orders left:  147314
# Cascade length:  2846
# New Orders left:  144468
# making new cascade
#
#
# OG Orders left:  144468
# Cascade length:  2319
# New Orders left:  142149
# making new cascade
#
#
# OG Orders left:  142149
# Cascade length:  2570
# New Orders left:  139579
# making new cascade
#
#
# OG Orders left:  139579
# Cascade length:  4058
# New Orders left:  135521
# making new cascade
#
#
# OG Orders left:  135521
# Cascade length:  4732
# New Orders left:  130789
# making new cascade
#
#
# OG Orders left:  130789
# Cascade length:  2459
# New Orders left:  128330
# making new cascade
#
#
# OG Orders left:  128330
# Cascade length:  2901
# New Orders left:  125429
# making new cascade
#
#
# OG Orders left:  125429
# Cascade length:  2042
# New Orders left:  123387
# making new cascade
#
#
# OG Orders left:  123387
# Cascade length:  2625
# New Orders left:  120762
# making new cascade
#
#
# OG Orders left:  120762
# Cascade length:  5476
# New Orders left:  115286
# making new cascade
#
#
# OG Orders left:  115286
# Cascade length:  2889
# New Orders left:  112397
# making new cascade
#
#
# OG Orders left:  112397
# Cascade length:  1741
# New Orders left:  110656
# making new cascade
#
#
# OG Orders left:  110656
# Cascade length:  3700
# New Orders left:  106956
# making new cascade
#
#
# OG Orders left:  106956
# Cascade length:  2113
# New Orders left:  104843
# making new cascade
#
#
# OG Orders left:  104843
# Cascade length:  2910
# New Orders left:  101933
# making new cascade
#
#
# OG Orders left:  101933
# Cascade length:  2137
# New Orders left:  99796
# making new cascade
#
#
# OG Orders left:  99796
# Cascade length:  2891
# New Orders left:  96905
# making new cascade
#
#
# OG Orders left:  96905
# Cascade length:  2980
# New Orders left:  93925
# making new cascade
#
#
# OG Orders left:  93925
# Cascade length:  2367
# New Orders left:  91558
# making new cascade
#
#
# OG Orders left:  91558
# Cascade length:  2458
# New Orders left:  89100
# making new cascade
#
#
# OG Orders left:  89100
# Cascade length:  1903
# New Orders left:  87197
# making new cascade
#
#
# OG Orders left:  87197
# Cascade length:  4919
# New Orders left:  82278
# making new cascade
#
#
# OG Orders left:  82278
# Cascade length:  2562
# New Orders left:  79716
# making new cascade
#
#
# OG Orders left:  79716
# Cascade length:  2082
# New Orders left:  77634
# making new cascade
#
#
# OG Orders left:  77634
# Cascade length:  2226
# New Orders left:  75408
# making new cascade
#
#
# OG Orders left:  75408
# Cascade length:  2324
# New Orders left:  73084
# making new cascade
#
#
# OG Orders left:  73084
# Cascade length:  3593
# New Orders left:  69491
# making new cascade
#
#
# OG Orders left:  69491
# Cascade length:  1908
# New Orders left:  67583
# making new cascade
#
#
# OG Orders left:  67583
# Cascade length:  3530
# New Orders left:  64053
# making new cascade
#
#
# OG Orders left:  64053
# Cascade length:  2183
# New Orders left:  61870
# making new cascade
#
#
# OG Orders left:  61870
# Cascade length:  1973
# New Orders left:  59897
# making new cascade
#
#
# OG Orders left:  59897
# Cascade length:  2215
# New Orders left:  57682
# making new cascade
#
#
# OG Orders left:  57682
# Cascade length:  2478
# New Orders left:  55204
# making new cascade
#
#
# OG Orders left:  55204
# Cascade length:  2232
# New Orders left:  52972
# making new cascade
#
#
# OG Orders left:  52972
# Cascade length:  2001
# New Orders left:  50971
# making new cascade
#
#
# OG Orders left:  50971
# Cascade length:  2190
# New Orders left:  48781
# making new cascade
#
#
# OG Orders left:  48781
# Cascade length:  1873
# New Orders left:  46908
# making new cascade
#
#
# OG Orders left:  46908
# Cascade length:  1816
# New Orders left:  45092
# making new cascade
#
#
# OG Orders left:  45092
# Cascade length:  2299
# New Orders left:  42793
# making new cascade
#
#
# OG Orders left:  42793
# Cascade length:  1659
# New Orders left:  41134
# making new cascade
#
#
# OG Orders left:  41134
# Cascade length:  1820
# New Orders left:  39314
# making new cascade
#
#
# OG Orders left:  39314
# Cascade length:  1981
# New Orders left:  37333
# making new cascade
#
#
# OG Orders left:  37333
# Cascade length:  1716
# New Orders left:  35617
# making new cascade
#
#
# OG Orders left:  35617
# Cascade length:  1854
# New Orders left:  33763
# making new cascade
#
#
# OG Orders left:  33763
# Cascade length:  1598
# New Orders left:  32165
# making new cascade
#
#
# OG Orders left:  32165
# Cascade length:  1763
# New Orders left:  30402
# making new cascade
#
#
# OG Orders left:  30402
# Cascade length:  1431
# New Orders left:  28971
# making new cascade
#
#
# OG Orders left:  28971
# Cascade length:  1273
# New Orders left:  27698
# making new cascade
#
#
# OG Orders left:  27698
# Cascade length:  2196
# New Orders left:  25502
# making new cascade
#
#
# OG Orders left:  25502
# Cascade length:  1380
# New Orders left:  24122
# making new cascade
#
#
# OG Orders left:  24122
# Cascade length:  1273
# New Orders left:  22849
# making new cascade
#
#
# OG Orders left:  22849
# Cascade length:  1252
# New Orders left:  21597
# making new cascade
#
#
# OG Orders left:  21597
# Cascade length:  1729
# New Orders left:  19868
# making new cascade
#
#
# OG Orders left:  19868
# Cascade length:  1505
# New Orders left:  18363
# making new cascade
#
#
# OG Orders left:  18363
# Cascade length:  1068
# New Orders left:  17295
# making new cascade
#
#
# OG Orders left:  17295
# Cascade length:  1532
# New Orders left:  15763
# making new cascade
#
#
# OG Orders left:  15763
# Cascade length:  1603
# New Orders left:  14160
# making new cascade
#
#
# OG Orders left:  14160
# Cascade length:  1075
# New Orders left:  13085
# making new cascade
#
#
# OG Orders left:  13085
# Cascade length:  1192
# New Orders left:  11893
# making new cascade
#
#
# OG Orders left:  11893
# Cascade length:  1223
# New Orders left:  10670
# making new cascade
#
#
# OG Orders left:  10670
# Cascade length:  787
# New Orders left:  9883
# making new cascade
#
#
# OG Orders left:  9883
# Cascade length:  696
# New Orders left:  9187
# making new cascade
#
#
# OG Orders left:  9187
# Cascade length:  750
# New Orders left:  8437
# making new cascade
#
#
# OG Orders left:  8437
# Cascade length:  775
# New Orders left:  7662
# making new cascade
#
#
# OG Orders left:  7662
# Cascade length:  766
# New Orders left:  6896
# making new cascade
#
#
# OG Orders left:  6896
# Cascade length:  963
# New Orders left:  5933
# making new cascade
#
#
# OG Orders left:  5933
# Cascade length:  679
# New Orders left:  5254
# making new cascade
#
#
# OG Orders left:  5254
# Cascade length:  624
# New Orders left:  4630
# making new cascade
#
#
# OG Orders left:  4630
# Cascade length:  555
# New Orders left:  4075
# making new cascade
#
#
# OG Orders left:  4075
# Cascade length:  592
# New Orders left:  3483
# making new cascade
#
#
# OG Orders left:  3483
# Cascade length:  468
# New Orders left:  3015
# making new cascade
#
#
# OG Orders left:  3015
# Cascade length:  592
# New Orders left:  2423
# making new cascade
#
#
# OG Orders left:  2423
# Cascade length:  534
# New Orders left:  1889
# making new cascade
#
#
# OG Orders left:  1889
# Cascade length:  430
# New Orders left:  1459
# making new cascade
#
#
# OG Orders left:  1459
# Cascade length:  358
# New Orders left:  1101
# making new cascade
#
#
# OG Orders left:  1101
# Cascade length:  349
# New Orders left:  752
# making new cascade
#
#
# OG Orders left:  752
# Cascade length:  235
# New Orders left:  517
# making new cascade
#
#
# OG Orders left:  517
# Cascade length:  271
# New Orders left:  246
# making new cascade
#
#
# OG Orders left:  246
# Cascade length:  17
# New Orders left:  229
# making new cascade
#
#
# OG Orders left:  229
# Cascade length:  107
# New Orders left:  122
# making new cascade
#
#
# OG Orders left:  122
# Cascade length:  83
# New Orders left:  39
# making new cascade
#
#
# OG Orders left:  39
# Cascade length:  33
# New Orders left:  6
# making new cascade
#
#
# OG Orders left:  6
# Cascade length:  6
# New Orders left:  0
# making new cascade

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5192], traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5192)
with open('../causalCascades/7-9/causalCascades21_npc_500_7200_100_5_10.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2856341

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5192], traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5192)
with open('../causalCascades/7-9/causalCascades12_npc_500_7200_100_5_10.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2856341
# Cascade length:  10960
# New Orders left:  2845381
# making new cascade
#
#
# OG Orders left:  2845381
# Cascade length:  12343
# New Orders left:  2833038
# making new cascade
#
#
# OG Orders left:  2833038
# Cascade length:  9242
# New Orders left:  2823796
# making new cascade
#
#
# OG Orders left:  2823796
# Cascade length:  13284
# New Orders left:  2810512
# making new cascade
#
#
# OG Orders left:  2810512
# Cascade length:  12763
# New Orders left:  2797749
# making new cascade
#
#
# OG Orders left:  2797749
# Cascade length:  11639
# New Orders left:  2786110
# making new cascade
#
#
# OG Orders left:  2786110
# Cascade length:  3
# New Orders left:  2786107
# making new cascade
#
#
# OG Orders left:  2786107
# Cascade length:  9735
# New Orders left:  2776372
# making new cascade
#
#
# OG Orders left:  2776372
# Cascade length:  11900
# New Orders left:  2764472
# making new cascade
#
#
# OG Orders left:  2764472
# Cascade length:  9995
# New Orders left:  2754477
# making new cascade
#
#
# OG Orders left:  2754477
# Cascade length:  8684
# New Orders left:  2745793
# making new cascade
#
#
# OG Orders left:  2745793
# Cascade length:  8899
# New Orders left:  2736894
# making new cascade
#
#
# OG Orders left:  2736894
# Cascade length:  7482
# New Orders left:  2729412
# making new cascade
#
#
# OG Orders left:  2729412
# Cascade length:  26
# New Orders left:  2729386
# making new cascade
#
#
# OG Orders left:  2729386
# Cascade length:  6836
# New Orders left:  2722550
# making new cascade
#
#
# OG Orders left:  2722550
# Cascade length:  7
# New Orders left:  2722543
# making new cascade
#
#
# OG Orders left:  2722543
# Cascade length:  9057
# New Orders left:  2713486
# making new cascade
#
#
# OG Orders left:  2713486
# Cascade length:  6995
# New Orders left:  2706491
# making new cascade
#
#
# OG Orders left:  2706491
# Cascade length:  6427
# New Orders left:  2700064
# making new cascade
#
#
# OG Orders left:  2700064
# Cascade length:  4987
# New Orders left:  2695077
# making new cascade
#
#
# OG Orders left:  2695077
# Cascade length:  6747
# New Orders left:  2688330
# making new cascade
#
#
# OG Orders left:  2688330
# Cascade length:  8221
# New Orders left:  2680109
# making new cascade
#
#
# OG Orders left:  2680109
# Cascade length:  7017
# New Orders left:  2673092
# making new cascade
#
#
# OG Orders left:  2673092
# Cascade length:  6443
# New Orders left:  2666649
# making new cascade
#
#
# OG Orders left:  2666649
# Cascade length:  6393
# New Orders left:  2660256
# making new cascade
#
#
# OG Orders left:  2660256
# Cascade length:  8413
# New Orders left:  2651843
# making new cascade
#
#
# OG Orders left:  2651843
# Cascade length:  5326
# New Orders left:  2646517
# making new cascade
#
#
# OG Orders left:  2646517
# Cascade length:  6524
# New Orders left:  2639993
# making new cascade
#
#
# OG Orders left:  2639993
# Cascade length:  6315
# New Orders left:  2633678
# making new cascade
#
#
# OG Orders left:  2633678
# Cascade length:  4912
# New Orders left:  2628766
# making new cascade
#
#
# OG Orders left:  2628766
# Cascade length:  6727
# New Orders left:  2622039
# making new cascade
#
#
# OG Orders left:  2622039
# Cascade length:  6056
# New Orders left:  2615983
# making new cascade
#
#
# OG Orders left:  2615983
# Cascade length:  5075
# New Orders left:  2610908
# making new cascade
#
#
# OG Orders left:  2610908
# Cascade length:  5036
# New Orders left:  2605872
# making new cascade
#
#
# OG Orders left:  2605872
# Cascade length:  3742
# New Orders left:  2602130
# making new cascade
#
#
# OG Orders left:  2602130
# Cascade length:  5392
# New Orders left:  2596738
# making new cascade
#
#
# OG Orders left:  2596738
# Cascade length:  4819
# New Orders left:  2591919
# making new cascade
#
#
# OG Orders left:  2591919
# Cascade length:  41
# New Orders left:  2591878
# making new cascade
#
#
# OG Orders left:  2591878
# Cascade length:  4970
# New Orders left:  2586908
# making new cascade
#
#
# OG Orders left:  2586908
# Cascade length:  20
# New Orders left:  2586888
# making new cascade
#
#
# OG Orders left:  2586888
# Cascade length:  4612
# New Orders left:  2582276
# making new cascade
#
#
# OG Orders left:  2582276
# Cascade length:  4523
# New Orders left:  2577753
# making new cascade
#
#
# OG Orders left:  2577753
# Cascade length:  4472
# New Orders left:  2573281
# making new cascade
#
#
# OG Orders left:  2573281
# Cascade length:  3500
# New Orders left:  2569781
# making new cascade
#
#
# OG Orders left:  2569781
# Cascade length:  5295
# New Orders left:  2564486
# making new cascade
#
#
# OG Orders left:  2564486
# Cascade length:  4258
# New Orders left:  2560228
# making new cascade
#
#
# OG Orders left:  2560228
# Cascade length:  4984
# New Orders left:  2555244
# making new cascade
#
#
# OG Orders left:  2555244
# Cascade length:  4568
# New Orders left:  2550676
# making new cascade
#
#
# OG Orders left:  2550676
# Cascade length:  5163
# New Orders left:  2545513
# making new cascade
#
#
# OG Orders left:  2545513
# Cascade length:  5431
# New Orders left:  2540082
# making new cascade
#
#
# OG Orders left:  2540082
# Cascade length:  4032
# New Orders left:  2536050
# making new cascade
#
#
# OG Orders left:  2536050
# Cascade length:  1472
# New Orders left:  2534578
# making new cascade
#
#
# OG Orders left:  2534578
# Cascade length:  746
# New Orders left:  2533832
# making new cascade
#
#
# OG Orders left:  2533832
# Cascade length:  4092
# New Orders left:  2529740
# making new cascade
#
#
# OG Orders left:  2529740
# Cascade length:  5564
# New Orders left:  2524176
# making new cascade
#
#
# OG Orders left:  2524176
# Cascade length:  3517
# New Orders left:  2520659
# making new cascade
#
#
# OG Orders left:  2520659
# Cascade length:  4449
# New Orders left:  2516210
# making new cascade
#
#
# OG Orders left:  2516210
# Cascade length:  4280
# New Orders left:  2511930
# making new cascade
#
#
# OG Orders left:  2511930
# Cascade length:  4437
# New Orders left:  2507493
# making new cascade
#
#
# OG Orders left:  2507493
# Cascade length:  6039
# New Orders left:  2501454
# making new cascade
#
#
# OG Orders left:  2501454
# Cascade length:  1
# New Orders left:  2501453
# making new cascade
#
#
# OG Orders left:  2501453
# Cascade length:  4
# New Orders left:  2501449
# making new cascade
#
#
# OG Orders left:  2501449
# Cascade length:  4983
# New Orders left:  2496466
# making new cascade
#
#
# OG Orders left:  2496466
# Cascade length:  4502
# New Orders left:  2491964
# making new cascade
#
#
# OG Orders left:  2491964
# Cascade length:  134
# New Orders left:  2491830
# making new cascade
#
#
# OG Orders left:  2491830
# Cascade length:  3593
# New Orders left:  2488237
# making new cascade
#
#
# OG Orders left:  2488237
# Cascade length:  1
# New Orders left:  2488236
# making new cascade
#
#
# OG Orders left:  2488236
# Cascade length:  12
# New Orders left:  2488224
# making new cascade
#
#
# OG Orders left:  2488224
# Cascade length:  10
# New Orders left:  2488214
# making new cascade
#
#
# OG Orders left:  2488214
# Cascade length:  3798
# New Orders left:  2484416
# making new cascade
#
#
# OG Orders left:  2484416
# Cascade length:  2
# New Orders left:  2484414
# making new cascade
#
#
# OG Orders left:  2484414
# Cascade length:  4762
# New Orders left:  2479652
# making new cascade
#
#
# OG Orders left:  2479652
# Cascade length:  4187
# New Orders left:  2475465
# making new cascade
#
#
# OG Orders left:  2475465
# Cascade length:  3949
# New Orders left:  2471516
# making new cascade
#
#
# OG Orders left:  2471516
# Cascade length:  4021
# New Orders left:  2467495
# making new cascade
#
#
# OG Orders left:  2467495
# Cascade length:  2668
# New Orders left:  2464827
# making new cascade
#
#
# OG Orders left:  2464827
# Cascade length:  28
# New Orders left:  2464799
# making new cascade
#
#
# OG Orders left:  2464799
# Cascade length:  2368
# New Orders left:  2462431
# making new cascade
#
#
# OG Orders left:  2462431
# Cascade length:  3050
# New Orders left:  2459381
# making new cascade
#
#
# OG Orders left:  2459381
# Cascade length:  40
# New Orders left:  2459341
# making new cascade
#
#
# OG Orders left:  2459341
# Cascade length:  3662
# New Orders left:  2455679
# making new cascade
#
#
# OG Orders left:  2455679
# Cascade length:  1879
# New Orders left:  2453800
# making new cascade
#
#
# OG Orders left:  2453800
# Cascade length:  7
# New Orders left:  2453793
# making new cascade
#
#
# OG Orders left:  2453793
# Cascade length:  21
# New Orders left:  2453772
# making new cascade
#
#
# OG Orders left:  2453772
# Cascade length:  18
# New Orders left:  2453754
# making new cascade
#
#
# OG Orders left:  2453754
# Cascade length:  929
# New Orders left:  2452825
# making new cascade
#
#
# OG Orders left:  2452825
# Cascade length:  4059
# New Orders left:  2448766
# making new cascade
#
#
# OG Orders left:  2448766
# Cascade length:  2879
# New Orders left:  2445887
# making new cascade
#
#
# OG Orders left:  2445887
# Cascade length:  3
# New Orders left:  2445884
# making new cascade
#
#
# OG Orders left:  2445884
# Cascade length:  42
# New Orders left:  2445842
# making new cascade
#
#
# OG Orders left:  2445842
# Cascade length:  2464
# New Orders left:  2443378
# making new cascade
#
#
# OG Orders left:  2443378
# Cascade length:  2730
# New Orders left:  2440648
# making new cascade
#
#
# OG Orders left:  2440648
# Cascade length:  8
# New Orders left:  2440640
# making new cascade
#
#
# OG Orders left:  2440640
# Cascade length:  2
# New Orders left:  2440638
# making new cascade
#
#
# OG Orders left:  2440638
# Cascade length:  174
# New Orders left:  2440464
# making new cascade
#
#
# OG Orders left:  2440464
# Cascade length:  3326
# New Orders left:  2437138
# making new cascade
#
#
# OG Orders left:  2437138
# Cascade length:  3336
# New Orders left:  2433802
# making new cascade
#
#
# OG Orders left:  2433802
# Cascade length:  1943
# New Orders left:  2431859
# making new cascade
#
#
# OG Orders left:  2431859
# Cascade length:  1127
# New Orders left:  2430732
# making new cascade
#
#
# OG Orders left:  2430732
# Cascade length:  27
# New Orders left:  2430705
# making new cascade
#
#
# OG Orders left:  2430705
# Cascade length:  64
# New Orders left:  2430641
# making new cascade
#
#
# OG Orders left:  2430641
# Cascade length:  2738
# New Orders left:  2427903
# making new cascade
#
#
# OG Orders left:  2427903
# Cascade length:  3445
# New Orders left:  2424458
# making new cascade
#
#
# OG Orders left:  2424458
# Cascade length:  2
# New Orders left:  2424456
# making new cascade
#
#
# OG Orders left:  2424456
# Cascade length:  113
# New Orders left:  2424343
# making new cascade
#
#
# OG Orders left:  2424343
# Cascade length:  6
# New Orders left:  2424337
# making new cascade
#
#
# OG Orders left:  2424337
# Cascade length:  1918
# New Orders left:  2422419
# making new cascade
#
#
# OG Orders left:  2422419
# Cascade length:  2852
# New Orders left:  2419567
# making new cascade
#
#
# OG Orders left:  2419567
# Cascade length:  3219
# New Orders left:  2416348
# making new cascade
#
#
# OG Orders left:  2416348
# Cascade length:  1
# New Orders left:  2416347
# making new cascade
#
#
# OG Orders left:  2416347
# Cascade length:  1
# New Orders left:  2416346
# making new cascade
#
#
# OG Orders left:  2416346
# Cascade length:  5
# New Orders left:  2416341
# making new cascade
#
#
# OG Orders left:  2416341
# Cascade length:  12
# New Orders left:  2416329
# making new cascade
#
#
# OG Orders left:  2416329
# Cascade length:  173
# New Orders left:  2416156
# making new cascade
#
#
# OG Orders left:  2416156
# Cascade length:  27
# New Orders left:  2416129
# making new cascade
#
#
# OG Orders left:  2416129
# Cascade length:  2
# New Orders left:  2416127
# making new cascade
#
#
# OG Orders left:  2416127
# Cascade length:  3
# New Orders left:  2416124
# making new cascade
#
#
# OG Orders left:  2416124
# Cascade length:  4
# New Orders left:  2416120
# making new cascade
#
#
# OG Orders left:  2416120
# Cascade length:  3718
# New Orders left:  2412402
# making new cascade
#
#
# OG Orders left:  2412402
# Cascade length:  3725
# New Orders left:  2408677
# making new cascade
#
#
# OG Orders left:  2408677
# Cascade length:  4
# New Orders left:  2408673
# making new cascade
#
#
# OG Orders left:  2408673
# Cascade length:  1560
# New Orders left:  2407113
# making new cascade
#
#
# OG Orders left:  2407113
# Cascade length:  13
# New Orders left:  2407100
# making new cascade
#
#
# OG Orders left:  2407100
# Cascade length:  4
# New Orders left:  2407096
# making new cascade
#
#
# OG Orders left:  2407096
# Cascade length:  6
# New Orders left:  2407090
# making new cascade
#
#
# OG Orders left:  2407090
# Cascade length:  8
# New Orders left:  2407082
# making new cascade
#
#
# OG Orders left:  2407082
# Cascade length:  34
# New Orders left:  2407048
# making new cascade
#
#
# OG Orders left:  2407048
# Cascade length:  37
# New Orders left:  2407011
# making new cascade
#
#
# OG Orders left:  2407011
# Cascade length:  3103
# New Orders left:  2403908
# making new cascade
#
#
# OG Orders left:  2403908
# Cascade length:  115
# New Orders left:  2403793
# making new cascade
#
#
# OG Orders left:  2403793
# Cascade length:  2637
# New Orders left:  2401156
# making new cascade
#
#
# OG Orders left:  2401156
# Cascade length:  2660
# New Orders left:  2398496
# making new cascade
#
#
# OG Orders left:  2398496
# Cascade length:  192
# New Orders left:  2398304
# making new cascade
#
#
# OG Orders left:  2398304
# Cascade length:  4
# New Orders left:  2398300
# making new cascade
#
#
# OG Orders left:  2398300
# Cascade length:  7
# New Orders left:  2398293
# making new cascade
#
#
# OG Orders left:  2398293
# Cascade length:  165
# New Orders left:  2398128
# making new cascade
#
#
# OG Orders left:  2398128
# Cascade length:  18
# New Orders left:  2398110
# making new cascade
#
#
# OG Orders left:  2398110
# Cascade length:  2508
# New Orders left:  2395602
# making new cascade
#
#
# OG Orders left:  2395602
# Cascade length:  2
# New Orders left:  2395600
# making new cascade
#
#
# OG Orders left:  2395600
# Cascade length:  27
# New Orders left:  2395573
# making new cascade
#
#
# OG Orders left:  2395573
# Cascade length:  6
# New Orders left:  2395567
# making new cascade
#
#
# OG Orders left:  2395567
# Cascade length:  3
# New Orders left:  2395564
# making new cascade
#
#
# OG Orders left:  2395564
# Cascade length:  3305
# New Orders left:  2392259
# making new cascade
#
#
# OG Orders left:  2392259
# Cascade length:  3
# New Orders left:  2392256
# making new cascade
#
#
# OG Orders left:  2392256
# Cascade length:  1
# New Orders left:  2392255
# making new cascade
#
#
# OG Orders left:  2392255
# Cascade length:  2621
# New Orders left:  2389634
# making new cascade
#
#
# OG Orders left:  2389634
# Cascade length:  44
# New Orders left:  2389590
# making new cascade
#
#
# OG Orders left:  2389590
# Cascade length:  6
# New Orders left:  2389584
# making new cascade
#
#
# OG Orders left:  2389584
# Cascade length:  112
# New Orders left:  2389472
# making new cascade
#
#
# OG Orders left:  2389472
# Cascade length:  40
# New Orders left:  2389432
# making new cascade
#
#
# OG Orders left:  2389432
# Cascade length:  776
# New Orders left:  2388656
# making new cascade
#
#
# OG Orders left:  2388656
# Cascade length:  3674
# New Orders left:  2384982
# making new cascade
#
#
# OG Orders left:  2384982
# Cascade length:  3047
# New Orders left:  2381935
# making new cascade
#
#
# OG Orders left:  2381935
# Cascade length:  2518
# New Orders left:  2379417
# making new cascade
#
#
# OG Orders left:  2379417
# Cascade length:  14
# New Orders left:  2379403
# making new cascade
#
#
# OG Orders left:  2379403
# Cascade length:  39
# New Orders left:  2379364
# making new cascade
#
#
# OG Orders left:  2379364
# Cascade length:  9
# New Orders left:  2379355
# making new cascade
#
#
# OG Orders left:  2379355
# Cascade length:  2012
# New Orders left:  2377343
# making new cascade
#
#
# OG Orders left:  2377343
# Cascade length:  2117
# New Orders left:  2375226
# making new cascade
#
#
# OG Orders left:  2375226
# Cascade length:  2773
# New Orders left:  2372453
# making new cascade
#
#
# OG Orders left:  2372453
# Cascade length:  43
# New Orders left:  2372410
# making new cascade
#
#
# OG Orders left:  2372410
# Cascade length:  1501
# New Orders left:  2370909
# making new cascade
#
#
# OG Orders left:  2370909
# Cascade length:  1781
# New Orders left:  2369128
# making new cascade
#
#
# OG Orders left:  2369128
# Cascade length:  2736
# New Orders left:  2366392
# making new cascade
#
#
# OG Orders left:  2366392
# Cascade length:  116
# New Orders left:  2366276
# making new cascade
#
#
# OG Orders left:  2366276
# Cascade length:  6
# New Orders left:  2366270
# making new cascade
#
#
# OG Orders left:  2366270
# Cascade length:  3311
# New Orders left:  2362959
# making new cascade
#
#
# OG Orders left:  2362959
# Cascade length:  9
# New Orders left:  2362950
# making new cascade
#
#
# OG Orders left:  2362950
# Cascade length:  2645
# New Orders left:  2360305
# making new cascade
#
#
# OG Orders left:  2360305
# Cascade length:  10
# New Orders left:  2360295
# making new cascade
#
#
# OG Orders left:  2360295
# Cascade length:  2195
# New Orders left:  2358100
# making new cascade
#
#
# OG Orders left:  2358100
# Cascade length:  3044
# New Orders left:  2355056
# making new cascade
#
#
# OG Orders left:  2355056
# Cascade length:  4
# New Orders left:  2355052
# making new cascade
#
#
# OG Orders left:  2355052
# Cascade length:  4
# New Orders left:  2355048
# making new cascade
#
#
# OG Orders left:  2355048
# Cascade length:  84
# New Orders left:  2354964
# making new cascade
#
#
# OG Orders left:  2354964
# Cascade length:  91
# New Orders left:  2354873
# making new cascade
#
#
# OG Orders left:  2354873
# Cascade length:  6
# New Orders left:  2354867
# making new cascade
#
#
# OG Orders left:  2354867
# Cascade length:  1244
# New Orders left:  2353623
# making new cascade
#
#
# OG Orders left:  2353623
# Cascade length:  2649
# New Orders left:  2350974
# making new cascade
#
#
# OG Orders left:  2350974
# Cascade length:  3705
# New Orders left:  2347269
# making new cascade
#
#
# OG Orders left:  2347269
# Cascade length:  2
# New Orders left:  2347267
# making new cascade
#
#
# OG Orders left:  2347267
# Cascade length:  16
# New Orders left:  2347251
# making new cascade
#
#
# OG Orders left:  2347251
# Cascade length:  10
# New Orders left:  2347241
# making new cascade
#
#
# OG Orders left:  2347241
# Cascade length:  2
# New Orders left:  2347239
# making new cascade
#
#
# OG Orders left:  2347239
# Cascade length:  3
# New Orders left:  2347236
# making new cascade
#
#
# OG Orders left:  2347236
# Cascade length:  2533
# New Orders left:  2344703
# making new cascade
#
#
# OG Orders left:  2344703
# Cascade length:  3323
# New Orders left:  2341380
# making new cascade
#
#
# OG Orders left:  2341380
# Cascade length:  3116
# New Orders left:  2338264
# making new cascade
#
#
# OG Orders left:  2338264
# Cascade length:  2582
# New Orders left:  2335682
# making new cascade
#
#
# OG Orders left:  2335682
# Cascade length:  20
# New Orders left:  2335662
# making new cascade
#
#
# OG Orders left:  2335662
# Cascade length:  3
# New Orders left:  2335659
# making new cascade
#
#
# OG Orders left:  2335659
# Cascade length:  36
# New Orders left:  2335623
# making new cascade
#
#
# OG Orders left:  2335623
# Cascade length:  3542
# New Orders left:  2332081
# making new cascade
#
#
# OG Orders left:  2332081
# Cascade length:  60
# New Orders left:  2332021
# making new cascade
#
#
# OG Orders left:  2332021
# Cascade length:  50
# New Orders left:  2331971
# making new cascade
#
#
# OG Orders left:  2331971
# Cascade length:  18
# New Orders left:  2331953
# making new cascade
#
#
# OG Orders left:  2331953
# Cascade length:  7
# New Orders left:  2331946
# making new cascade
#
#
# OG Orders left:  2331946
# Cascade length:  1628
# New Orders left:  2330318
# making new cascade
#
#
# OG Orders left:  2330318
# Cascade length:  9
# New Orders left:  2330309
# making new cascade
#
#
# OG Orders left:  2330309
# Cascade length:  2
# New Orders left:  2330307
# making new cascade
#
#
# OG Orders left:  2330307
# Cascade length:  14
# New Orders left:  2330293
# making new cascade
#
#
# OG Orders left:  2330293
# Cascade length:  13
# New Orders left:  2330280
# making new cascade
#
#
# OG Orders left:  2330280
# Cascade length:  1732
# New Orders left:  2328548
# making new cascade
#
#
# OG Orders left:  2328548
# Cascade length:  5
# New Orders left:  2328543
# making new cascade
#
#
# OG Orders left:  2328543
# Cascade length:  71
# New Orders left:  2328472
# making new cascade
#
#
# OG Orders left:  2328472
# Cascade length:  2735
# New Orders left:  2325737
# making new cascade
#
#
# OG Orders left:  2325737
# Cascade length:  1
# New Orders left:  2325736
# making new cascade
#
#
# OG Orders left:  2325736
# Cascade length:  3436
# New Orders left:  2322300
# making new cascade
#
#
# OG Orders left:  2322300
# Cascade length:  2766
# New Orders left:  2319534
# making new cascade
#
#
# OG Orders left:  2319534
# Cascade length:  2210
# New Orders left:  2317324
# making new cascade
#
#
# OG Orders left:  2317324
# Cascade length:  19
# New Orders left:  2317305
# making new cascade
#
#
# OG Orders left:  2317305
# Cascade length:  42
# New Orders left:  2317263
# making new cascade
#
#
# OG Orders left:  2317263
# Cascade length:  12
# New Orders left:  2317251
# making new cascade
#
#
# OG Orders left:  2317251
# Cascade length:  2
# New Orders left:  2317249
# making new cascade
#
#
# OG Orders left:  2317249
# Cascade length:  3105
# New Orders left:  2314144
# making new cascade
#
#
# OG Orders left:  2314144
# Cascade length:  3470
# New Orders left:  2310674
# making new cascade
#
#
# OG Orders left:  2310674
# Cascade length:  8
# New Orders left:  2310666
# making new cascade
#
#
# OG Orders left:  2310666
# Cascade length:  1
# New Orders left:  2310665
# making new cascade
#
#
# OG Orders left:  2310665
# Cascade length:  3394
# New Orders left:  2307271
# making new cascade
#
#
# OG Orders left:  2307271
# Cascade length:  27
# New Orders left:  2307244
# making new cascade
#
#
# OG Orders left:  2307244
# Cascade length:  8
# New Orders left:  2307236
# making new cascade
#
#
# OG Orders left:  2307236
# Cascade length:  2738
# New Orders left:  2304498
# making new cascade
#
#
# OG Orders left:  2304498
# Cascade length:  816
# New Orders left:  2303682
# making new cascade
#
#
# OG Orders left:  2303682
# Cascade length:  2281
# New Orders left:  2301401
# making new cascade
#
#
# OG Orders left:  2301401
# Cascade length:  35
# New Orders left:  2301366
# making new cascade
#
#
# OG Orders left:  2301366
# Cascade length:  230
# New Orders left:  2301136
# making new cascade
#
#
# OG Orders left:  2301136
# Cascade length:  1
# New Orders left:  2301135
# making new cascade
#
#
# OG Orders left:  2301135
# Cascade length:  7
# New Orders left:  2301128
# making new cascade
#
#
# OG Orders left:  2301128
# Cascade length:  18
# New Orders left:  2301110
# making new cascade
#
#
# OG Orders left:  2301110
# Cascade length:  1107
# New Orders left:  2300003
# making new cascade
#
#
# OG Orders left:  2300003
# Cascade length:  3423
# New Orders left:  2296580
# making new cascade
#
#
# OG Orders left:  2296580
# Cascade length:  2479
# New Orders left:  2294101
# making new cascade
#
#
# OG Orders left:  2294101
# Cascade length:  68
# New Orders left:  2294033
# making new cascade
#
#
# OG Orders left:  2294033
# Cascade length:  8
# New Orders left:  2294025
# making new cascade
#
#
# OG Orders left:  2294025
# Cascade length:  2520
# New Orders left:  2291505
# making new cascade
#
#
# OG Orders left:  2291505
# Cascade length:  2
# New Orders left:  2291503
# making new cascade
#
#
# OG Orders left:  2291503
# Cascade length:  1441
# New Orders left:  2290062
# making new cascade
#
#
# OG Orders left:  2290062
# Cascade length:  2
# New Orders left:  2290060
# making new cascade
#
#
# OG Orders left:  2290060
# Cascade length:  3
# New Orders left:  2290057
# making new cascade
#
#
# OG Orders left:  2290057
# Cascade length:  812
# New Orders left:  2289245
# making new cascade
#
#
# OG Orders left:  2289245
# Cascade length:  1907
# New Orders left:  2287338
# making new cascade
#
#
# OG Orders left:  2287338
# Cascade length:  23
# New Orders left:  2287315
# making new cascade
#
#
# OG Orders left:  2287315
# Cascade length:  47
# New Orders left:  2287268
# making new cascade
#
#
# OG Orders left:  2287268
# Cascade length:  2743
# New Orders left:  2284525
# making new cascade
#
#
# OG Orders left:  2284525
# Cascade length:  3163
# New Orders left:  2281362
# making new cascade
#
#
# OG Orders left:  2281362
# Cascade length:  118
# New Orders left:  2281244
# making new cascade
#
#
# OG Orders left:  2281244
# Cascade length:  21
# New Orders left:  2281223
# making new cascade
#
#
# OG Orders left:  2281223
# Cascade length:  3082
# New Orders left:  2278141
# making new cascade
#
#
# OG Orders left:  2278141
# Cascade length:  3091
# New Orders left:  2275050
# making new cascade
#
#
# OG Orders left:  2275050
# Cascade length:  12
# New Orders left:  2275038
# making new cascade
#
#
# OG Orders left:  2275038
# Cascade length:  1
# New Orders left:  2275037
# making new cascade
#
#
# OG Orders left:  2275037
# Cascade length:  2914
# New Orders left:  2272123
# making new cascade
#
#
# OG Orders left:  2272123
# Cascade length:  4
# New Orders left:  2272119
# making new cascade
#
#
# OG Orders left:  2272119
# Cascade length:  27
# New Orders left:  2272092
# making new cascade
#
#
# OG Orders left:  2272092
# Cascade length:  38
# New Orders left:  2272054
# making new cascade
#
#
# OG Orders left:  2272054
# Cascade length:  74
# New Orders left:  2271980
# making new cascade
#
#
# OG Orders left:  2271980
# Cascade length:  1
# New Orders left:  2271979
# making new cascade
#
#
# OG Orders left:  2271979
# Cascade length:  2039
# New Orders left:  2269940
# making new cascade
#
#
# OG Orders left:  2269940
# Cascade length:  2
# New Orders left:  2269938
# making new cascade
#
#
# OG Orders left:  2269938
# Cascade length:  5
# New Orders left:  2269933
# making new cascade
#
#
# OG Orders left:  2269933
# Cascade length:  2
# New Orders left:  2269931
# making new cascade
#
#
# OG Orders left:  2269931
# Cascade length:  2555
# New Orders left:  2267376
# making new cascade
#
#
# OG Orders left:  2267376
# Cascade length:  39
# New Orders left:  2267337
# making new cascade
#
#
# OG Orders left:  2267337
# Cascade length:  10
# New Orders left:  2267327
# making new cascade
#
#
# OG Orders left:  2267327
# Cascade length:  4817
# New Orders left:  2262510
# making new cascade
#
#
# OG Orders left:  2262510
# Cascade length:  6
# New Orders left:  2262504
# making new cascade
#
#
# OG Orders left:  2262504
# Cascade length:  8
# New Orders left:  2262496
# making new cascade
#
#
# OG Orders left:  2262496
# Cascade length:  2
# New Orders left:  2262494
# making new cascade
#
#
# OG Orders left:  2262494
# Cascade length:  1816
# New Orders left:  2260678
# making new cascade
#
#
# OG Orders left:  2260678
# Cascade length:  17
# New Orders left:  2260661
# making new cascade
#
#
# OG Orders left:  2260661
# Cascade length:  1978
# New Orders left:  2258683
# making new cascade
#
#
# OG Orders left:  2258683
# Cascade length:  1
# New Orders left:  2258682
# making new cascade
#
#
# OG Orders left:  2258682
# Cascade length:  22
# New Orders left:  2258660
# making new cascade
#
#
# OG Orders left:  2258660
# Cascade length:  3768
# New Orders left:  2254892
# making new cascade
#
#
# OG Orders left:  2254892
# Cascade length:  22
# New Orders left:  2254870
# making new cascade
#
#
# OG Orders left:  2254870
# Cascade length:  30
# New Orders left:  2254840
# making new cascade
#
#
# OG Orders left:  2254840
# Cascade length:  26
# New Orders left:  2254814
# making new cascade
#
#
# OG Orders left:  2254814
# Cascade length:  41
# New Orders left:  2254773
# making new cascade
#
#
# OG Orders left:  2254773
# Cascade length:  30
# New Orders left:  2254743
# making new cascade
#
#
# OG Orders left:  2254743
# Cascade length:  34
# New Orders left:  2254709
# making new cascade
#
#
# OG Orders left:  2254709
# Cascade length:  2
# New Orders left:  2254707
# making new cascade
#
#
# OG Orders left:  2254707
# Cascade length:  12
# New Orders left:  2254695
# making new cascade
#
#
# OG Orders left:  2254695
# Cascade length:  4399
# New Orders left:  2250296
# making new cascade
#
#
# OG Orders left:  2250296
# Cascade length:  19
# New Orders left:  2250277
# making new cascade
#
#
# OG Orders left:  2250277
# Cascade length:  2
# New Orders left:  2250275
# making new cascade
#
#
# OG Orders left:  2250275
# Cascade length:  26
# New Orders left:  2250249
# making new cascade
#
#
# OG Orders left:  2250249
# Cascade length:  8
# New Orders left:  2250241
# making new cascade
#
#
# OG Orders left:  2250241
# Cascade length:  10
# New Orders left:  2250231
# making new cascade
#
#
# OG Orders left:  2250231
# Cascade length:  4
# New Orders left:  2250227
# making new cascade
#
#
# OG Orders left:  2250227
# Cascade length:  2
# New Orders left:  2250225
# making new cascade
#
#
# OG Orders left:  2250225
# Cascade length:  3075
# New Orders left:  2247150
# making new cascade
#
#
# OG Orders left:  2247150
# Cascade length:  29
# New Orders left:  2247121
# making new cascade
#
#
# OG Orders left:  2247121
# Cascade length:  2128
# New Orders left:  2244993
# making new cascade
#
#
# OG Orders left:  2244993
# Cascade length:  49
# New Orders left:  2244944
# making new cascade
#
#
# OG Orders left:  2244944
# Cascade length:  13
# New Orders left:  2244931
# making new cascade
#
#
# OG Orders left:  2244931
# Cascade length:  11
# New Orders left:  2244920
# making new cascade
#
#
# OG Orders left:  2244920
# Cascade length:  4
# New Orders left:  2244916
# making new cascade
#
#
# OG Orders left:  2244916
# Cascade length:  21
# New Orders left:  2244895
# making new cascade
#
#
# OG Orders left:  2244895
# Cascade length:  2
# New Orders left:  2244893
# making new cascade
#
#
# OG Orders left:  2244893
# Cascade length:  1691
# New Orders left:  2243202
# making new cascade
#
#
# OG Orders left:  2243202
# Cascade length:  2
# New Orders left:  2243200
# making new cascade
#
#
# OG Orders left:  2243200
# Cascade length:  4710
# New Orders left:  2238490
# making new cascade
#
#
# OG Orders left:  2238490
# Cascade length:  16
# New Orders left:  2238474
# making new cascade
#
#
# OG Orders left:  2238474
# Cascade length:  4051
# New Orders left:  2234423
# making new cascade
#
#
# OG Orders left:  2234423
# Cascade length:  1904
# New Orders left:  2232519
# making new cascade
#
#
# OG Orders left:  2232519
# Cascade length:  4
# New Orders left:  2232515
# making new cascade
#
#
# OG Orders left:  2232515
# Cascade length:  6
# New Orders left:  2232509
# making new cascade
#
#
# OG Orders left:  2232509
# Cascade length:  68
# New Orders left:  2232441
# making new cascade
#
#
# OG Orders left:  2232441
# Cascade length:  31
# New Orders left:  2232410
# making new cascade
#
#
# OG Orders left:  2232410
# Cascade length:  4638
# New Orders left:  2227772
# making new cascade
#
#
# OG Orders left:  2227772
# Cascade length:  365
# New Orders left:  2227407
# making new cascade
#
#
# OG Orders left:  2227407
# Cascade length:  4
# New Orders left:  2227403
# making new cascade
#
#
# OG Orders left:  2227403
# Cascade length:  2210
# New Orders left:  2225193
# making new cascade
#
#
# OG Orders left:  2225193
# Cascade length:  2999
# New Orders left:  2222194
# making new cascade
#
#
# OG Orders left:  2222194
# Cascade length:  1
# New Orders left:  2222193
# making new cascade
#
#
# OG Orders left:  2222193
# Cascade length:  66
# New Orders left:  2222127
# making new cascade
#
#
# OG Orders left:  2222127
# Cascade length:  1
# New Orders left:  2222126
# making new cascade
#
#
# OG Orders left:  2222126
# Cascade length:  12
# New Orders left:  2222114
# making new cascade
#
#
# OG Orders left:  2222114
# Cascade length:  530
# New Orders left:  2221584
# making new cascade
#
#
# OG Orders left:  2221584
# Cascade length:  4
# New Orders left:  2221580
# making new cascade
#
#
# OG Orders left:  2221580
# Cascade length:  2820
# New Orders left:  2218760
# making new cascade
#
#
# OG Orders left:  2218760
# Cascade length:  7
# New Orders left:  2218753
# making new cascade
#
#
# OG Orders left:  2218753
# Cascade length:  24
# New Orders left:  2218729
# making new cascade
#
#
# OG Orders left:  2218729
# Cascade length:  2405
# New Orders left:  2216324
# making new cascade
#
#
# OG Orders left:  2216324
# Cascade length:  2898
# New Orders left:  2213426
# making new cascade
#
#
# OG Orders left:  2213426
# Cascade length:  27
# New Orders left:  2213399
# making new cascade
#
#
# OG Orders left:  2213399
# Cascade length:  3
# New Orders left:  2213396
# making new cascade
#
#
# OG Orders left:  2213396
# Cascade length:  44
# New Orders left:  2213352
# making new cascade
#
#
# OG Orders left:  2213352
# Cascade length:  27
# New Orders left:  2213325
# making new cascade
#
#
# OG Orders left:  2213325
# Cascade length:  3
# New Orders left:  2213322
# making new cascade
#
#
# OG Orders left:  2213322
# Cascade length:  2408
# New Orders left:  2210914
# making new cascade
#
#
# OG Orders left:  2210914
# Cascade length:  29
# New Orders left:  2210885
# making new cascade
#
#
# OG Orders left:  2210885
# Cascade length:  22
# New Orders left:  2210863
# making new cascade
#
#
# OG Orders left:  2210863
# Cascade length:  2
# New Orders left:  2210861
# making new cascade
#
#
# OG Orders left:  2210861
# Cascade length:  2718
# New Orders left:  2208143
# making new cascade
#
#
# OG Orders left:  2208143
# Cascade length:  2
# New Orders left:  2208141
# making new cascade
#
#
# OG Orders left:  2208141
# Cascade length:  1
# New Orders left:  2208140
# making new cascade
#
#
# OG Orders left:  2208140
# Cascade length:  19
# New Orders left:  2208121
# making new cascade
#
#
# OG Orders left:  2208121
# Cascade length:  11
# New Orders left:  2208110
# making new cascade
#
#
# OG Orders left:  2208110
# Cascade length:  2
# New Orders left:  2208108
# making new cascade
#
#
# OG Orders left:  2208108
# Cascade length:  4207
# New Orders left:  2203901
# making new cascade
#
#
# OG Orders left:  2203901
# Cascade length:  1
# New Orders left:  2203900
# making new cascade
#
#
# OG Orders left:  2203900
# Cascade length:  11
# New Orders left:  2203889
# making new cascade
#
#
# OG Orders left:  2203889
# Cascade length:  2
# New Orders left:  2203887
# making new cascade
#
#
# OG Orders left:  2203887
# Cascade length:  46
# New Orders left:  2203841
# making new cascade
#
#
# OG Orders left:  2203841
# Cascade length:  1027
# New Orders left:  2202814
# making new cascade
#
#
# OG Orders left:  2202814
# Cascade length:  40
# New Orders left:  2202774
# making new cascade
#
#
# OG Orders left:  2202774
# Cascade length:  47
# New Orders left:  2202727
# making new cascade
#
#
# OG Orders left:  2202727
# Cascade length:  4090
# New Orders left:  2198637
# making new cascade
#
#
# OG Orders left:  2198637
# Cascade length:  503
# New Orders left:  2198134
# making new cascade
#
#
# OG Orders left:  2198134
# Cascade length:  4119
# New Orders left:  2194015
# making new cascade
#
#
# OG Orders left:  2194015
# Cascade length:  140
# New Orders left:  2193875
# making new cascade
#
#
# OG Orders left:  2193875
# Cascade length:  11
# New Orders left:  2193864
# making new cascade
#
#
# OG Orders left:  2193864
# Cascade length:  4892
# New Orders left:  2188972
# making new cascade
#
#
# OG Orders left:  2188972
# Cascade length:  3
# New Orders left:  2188969
# making new cascade
#
#
# OG Orders left:  2188969
# Cascade length:  2
# New Orders left:  2188967
# making new cascade
#
#
# OG Orders left:  2188967
# Cascade length:  3933
# New Orders left:  2185034
# making new cascade
#
#
# OG Orders left:  2185034
# Cascade length:  75
# New Orders left:  2184959
# making new cascade
#
#
# OG Orders left:  2184959
# Cascade length:  39
# New Orders left:  2184920
# making new cascade
#
#
# OG Orders left:  2184920
# Cascade length:  2224
# New Orders left:  2182696
# making new cascade
#
#
# OG Orders left:  2182696
# Cascade length:  1
# New Orders left:  2182695
# making new cascade
#
#
# OG Orders left:  2182695
# Cascade length:  1175
# New Orders left:  2181520
# making new cascade
#
#
# OG Orders left:  2181520
# Cascade length:  9
# New Orders left:  2181511
# making new cascade
#
#
# OG Orders left:  2181511
# Cascade length:  4243
# New Orders left:  2177268
# making new cascade
#
#
# OG Orders left:  2177268
# Cascade length:  1
# New Orders left:  2177267
# making new cascade
#
#
# OG Orders left:  2177267
# Cascade length:  43
# New Orders left:  2177224
# making new cascade
#
#
# OG Orders left:  2177224
# Cascade length:  3249
# New Orders left:  2173975
# making new cascade
#
#
# OG Orders left:  2173975
# Cascade length:  16
# New Orders left:  2173959
# making new cascade
#
#
# OG Orders left:  2173959
# Cascade length:  6
# New Orders left:  2173953
# making new cascade
#
#
# OG Orders left:  2173953
# Cascade length:  2979
# New Orders left:  2170974
# making new cascade
#
#
# OG Orders left:  2170974
# Cascade length:  2334
# New Orders left:  2168640
# making new cascade
#
#
# OG Orders left:  2168640
# Cascade length:  5
# New Orders left:  2168635
# making new cascade
#
#
# OG Orders left:  2168635
# Cascade length:  163
# New Orders left:  2168472
# making new cascade
#
#
# OG Orders left:  2168472
# Cascade length:  3506
# New Orders left:  2164966
# making new cascade
#
#
# OG Orders left:  2164966
# Cascade length:  488
# New Orders left:  2164478
# making new cascade
#
#
# OG Orders left:  2164478
# Cascade length:  2966
# New Orders left:  2161512
# making new cascade
#
#
# OG Orders left:  2161512
# Cascade length:  23
# New Orders left:  2161489
# making new cascade
#
#
# OG Orders left:  2161489
# Cascade length:  11
# New Orders left:  2161478
# making new cascade
#
#
# OG Orders left:  2161478
# Cascade length:  3029
# New Orders left:  2158449
# making new cascade
#
#
# OG Orders left:  2158449
# Cascade length:  3
# New Orders left:  2158446
# making new cascade
#
#
# OG Orders left:  2158446
# Cascade length:  2
# New Orders left:  2158444
# making new cascade
#
#
# OG Orders left:  2158444
# Cascade length:  33
# New Orders left:  2158411
# making new cascade
#
#
# OG Orders left:  2158411
# Cascade length:  3673
# New Orders left:  2154738
# making new cascade
#
#
# OG Orders left:  2154738
# Cascade length:  3756
# New Orders left:  2150982
# making new cascade
#
#
# OG Orders left:  2150982
# Cascade length:  13
# New Orders left:  2150969
# making new cascade
#
#
# OG Orders left:  2150969
# Cascade length:  6
# New Orders left:  2150963
# making new cascade
#
#
# OG Orders left:  2150963
# Cascade length:  28
# New Orders left:  2150935
# making new cascade
#
#
# OG Orders left:  2150935
# Cascade length:  396
# New Orders left:  2150539
# making new cascade
#
#
# OG Orders left:  2150539
# Cascade length:  10
# New Orders left:  2150529
# making new cascade
#
#
# OG Orders left:  2150529
# Cascade length:  251
# New Orders left:  2150278
# making new cascade
#
#
# OG Orders left:  2150278
# Cascade length:  6
# New Orders left:  2150272
# making new cascade
#
#
# OG Orders left:  2150272
# Cascade length:  2792
# New Orders left:  2147480
# making new cascade
#
#
# OG Orders left:  2147480
# Cascade length:  4
# New Orders left:  2147476
# making new cascade
#
#
# OG Orders left:  2147476
# Cascade length:  18
# New Orders left:  2147458
# making new cascade
#
#
# OG Orders left:  2147458
# Cascade length:  5169
# New Orders left:  2142289
# making new cascade
#
#
# OG Orders left:  2142289
# Cascade length:  2437
# New Orders left:  2139852
# making new cascade
#
#
# OG Orders left:  2139852
# Cascade length:  5
# New Orders left:  2139847
# making new cascade
#
#
# OG Orders left:  2139847
# Cascade length:  4
# New Orders left:  2139843
# making new cascade
#
#
# OG Orders left:  2139843
# Cascade length:  41
# New Orders left:  2139802
# making new cascade
#
#
# OG Orders left:  2139802
# Cascade length:  1
# New Orders left:  2139801
# making new cascade
#
#
# OG Orders left:  2139801
# Cascade length:  1044
# New Orders left:  2138757
# making new cascade
#
#
# OG Orders left:  2138757
# Cascade length:  136
# New Orders left:  2138621
# making new cascade
#
#
# OG Orders left:  2138621
# Cascade length:  3040
# New Orders left:  2135581
# making new cascade
#
#
# OG Orders left:  2135581
# Cascade length:  3391
# New Orders left:  2132190
# making new cascade
#
#
# OG Orders left:  2132190
# Cascade length:  1869
# New Orders left:  2130321
# making new cascade
#
#
# OG Orders left:  2130321
# Cascade length:  2
# New Orders left:  2130319
# making new cascade
#
#
# OG Orders left:  2130319
# Cascade length:  55
# New Orders left:  2130264
# making new cascade
#
#
# OG Orders left:  2130264
# Cascade length:  3532
# New Orders left:  2126732
# making new cascade
#
#
# OG Orders left:  2126732
# Cascade length:  1
# New Orders left:  2126731
# making new cascade
#
#
# OG Orders left:  2126731
# Cascade length:  12
# New Orders left:  2126719
# making new cascade
#
#
# OG Orders left:  2126719
# Cascade length:  2596
# New Orders left:  2124123
# making new cascade
#
#
# OG Orders left:  2124123
# Cascade length:  7
# New Orders left:  2124116
# making new cascade
#
#
# OG Orders left:  2124116
# Cascade length:  1680
# New Orders left:  2122436
# making new cascade
#
#
# OG Orders left:  2122436
# Cascade length:  187
# New Orders left:  2122249
# making new cascade
#
#
# OG Orders left:  2122249
# Cascade length:  1
# New Orders left:  2122248
# making new cascade
#
#
# OG Orders left:  2122248
# Cascade length:  3261
# New Orders left:  2118987
# making new cascade
#
#
# OG Orders left:  2118987
# Cascade length:  2264
# New Orders left:  2116723
# making new cascade
#
#
# OG Orders left:  2116723
# Cascade length:  2
# New Orders left:  2116721
# making new cascade
#
#
# OG Orders left:  2116721
# Cascade length:  1
# New Orders left:  2116720
# making new cascade
#
#
# OG Orders left:  2116720
# Cascade length:  2
# New Orders left:  2116718
# making new cascade
#
#
# OG Orders left:  2116718
# Cascade length:  1
# New Orders left:  2116717
# making new cascade
#
#
# OG Orders left:  2116717
# Cascade length:  63
# New Orders left:  2116654
# making new cascade
#
#
# OG Orders left:  2116654
# Cascade length:  108
# New Orders left:  2116546
# making new cascade
#
#
# OG Orders left:  2116546
# Cascade length:  12
# New Orders left:  2116534
# making new cascade
#
#
# OG Orders left:  2116534
# Cascade length:  2
# New Orders left:  2116532
# making new cascade
#
#
# OG Orders left:  2116532
# Cascade length:  17
# New Orders left:  2116515
# making new cascade
#
#
# OG Orders left:  2116515
# Cascade length:  1
# New Orders left:  2116514
# making new cascade
#
#
# OG Orders left:  2116514
# Cascade length:  3
# New Orders left:  2116511
# making new cascade
#
#
# OG Orders left:  2116511
# Cascade length:  6
# New Orders left:  2116505
# making new cascade
#
#
# OG Orders left:  2116505
# Cascade length:  3
# New Orders left:  2116502
# making new cascade
#
#
# OG Orders left:  2116502
# Cascade length:  2427
# New Orders left:  2114075
# making new cascade
#
#
# OG Orders left:  2114075
# Cascade length:  3
# New Orders left:  2114072
# making new cascade
#
#
# OG Orders left:  2114072
# Cascade length:  9
# New Orders left:  2114063
# making new cascade
#
#
# OG Orders left:  2114063
# Cascade length:  3366
# New Orders left:  2110697
# making new cascade
#
#
# OG Orders left:  2110697
# Cascade length:  4
# New Orders left:  2110693
# making new cascade
#
#
# OG Orders left:  2110693
# Cascade length:  3
# New Orders left:  2110690
# making new cascade
#
#
# OG Orders left:  2110690
# Cascade length:  2
# New Orders left:  2110688
# making new cascade
#
#
# OG Orders left:  2110688
# Cascade length:  48
# New Orders left:  2110640
# making new cascade
#
#
# OG Orders left:  2110640
# Cascade length:  24
# New Orders left:  2110616
# making new cascade
#
#
# OG Orders left:  2110616
# Cascade length:  3
# New Orders left:  2110613
# making new cascade
#
#
# OG Orders left:  2110613
# Cascade length:  1
# New Orders left:  2110612
# making new cascade
#
#
# OG Orders left:  2110612
# Cascade length:  3
# New Orders left:  2110609
# making new cascade
#
#
# OG Orders left:  2110609
# Cascade length:  3478
# New Orders left:  2107131
# making new cascade
#
#
# OG Orders left:  2107131
# Cascade length:  3702
# New Orders left:  2103429
# making new cascade
#
#
# OG Orders left:  2103429
# Cascade length:  3260
# New Orders left:  2100169
# making new cascade
#
#
# OG Orders left:  2100169
# Cascade length:  85
# New Orders left:  2100084
# making new cascade
#
#
# OG Orders left:  2100084
# Cascade length:  1
# New Orders left:  2100083
# making new cascade
#
#
# OG Orders left:  2100083
# Cascade length:  2701
# New Orders left:  2097382
# making new cascade
#
#
# OG Orders left:  2097382
# Cascade length:  25
# New Orders left:  2097357
# making new cascade
#
#
# OG Orders left:  2097357
# Cascade length:  1
# New Orders left:  2097356
# making new cascade
#
#
# OG Orders left:  2097356
# Cascade length:  3621
# New Orders left:  2093735
# making new cascade
#
#
# OG Orders left:  2093735
# Cascade length:  10
# New Orders left:  2093725
# making new cascade
#
#
# OG Orders left:  2093725
# Cascade length:  4672
# New Orders left:  2089053
# making new cascade
#
#
# OG Orders left:  2089053
# Cascade length:  8
# New Orders left:  2089045
# making new cascade
#
#
# OG Orders left:  2089045
# Cascade length:  7
# New Orders left:  2089038
# making new cascade
#
#
# OG Orders left:  2089038
# Cascade length:  4299
# New Orders left:  2084739
# making new cascade
#
#
# OG Orders left:  2084739
# Cascade length:  8
# New Orders left:  2084731
# making new cascade
#
#
# OG Orders left:  2084731
# Cascade length:  2
# New Orders left:  2084729
# making new cascade
#
#
# OG Orders left:  2084729
# Cascade length:  1509
# New Orders left:  2083220
# making new cascade
#
#
# OG Orders left:  2083220
# Cascade length:  3157
# New Orders left:  2080063
# making new cascade
#
#
# OG Orders left:  2080063
# Cascade length:  5
# New Orders left:  2080058
# making new cascade
#
#
# OG Orders left:  2080058
# Cascade length:  3
# New Orders left:  2080055
# making new cascade
#
#
# OG Orders left:  2080055
# Cascade length:  1126
# New Orders left:  2078929
# making new cascade
#
#
# OG Orders left:  2078929
# Cascade length:  7
# New Orders left:  2078922
# making new cascade
#
#
# OG Orders left:  2078922
# Cascade length:  15
# New Orders left:  2078907
# making new cascade
#
#
# OG Orders left:  2078907
# Cascade length:  1
# New Orders left:  2078906
# making new cascade
#
#
# OG Orders left:  2078906
# Cascade length:  4491
# New Orders left:  2074415
# making new cascade
#
#
# OG Orders left:  2074415
# Cascade length:  4945
# New Orders left:  2069470
# making new cascade
#
#
# OG Orders left:  2069470
# Cascade length:  5116
# New Orders left:  2064354
# making new cascade
#
#
# OG Orders left:  2064354
# Cascade length:  4
# New Orders left:  2064350
# making new cascade
#
#
# OG Orders left:  2064350
# Cascade length:  15
# New Orders left:  2064335
# making new cascade
#
#
# OG Orders left:  2064335
# Cascade length:  5
# New Orders left:  2064330
# making new cascade
#
#
# OG Orders left:  2064330
# Cascade length:  15
# New Orders left:  2064315
# making new cascade
#
#
# OG Orders left:  2064315
# Cascade length:  5420
# New Orders left:  2058895
# making new cascade
#
#
# OG Orders left:  2058895
# Cascade length:  4
# New Orders left:  2058891
# making new cascade
#
#
# OG Orders left:  2058891
# Cascade length:  3395
# New Orders left:  2055496
# making new cascade
#
#
# OG Orders left:  2055496
# Cascade length:  4075
# New Orders left:  2051421
# making new cascade
#
#
# OG Orders left:  2051421
# Cascade length:  8
# New Orders left:  2051413
# making new cascade
#
#
# OG Orders left:  2051413
# Cascade length:  10
# New Orders left:  2051403
# making new cascade
#
#
# OG Orders left:  2051403
# Cascade length:  149
# New Orders left:  2051254
# making new cascade
#
#
# OG Orders left:  2051254
# Cascade length:  85
# New Orders left:  2051169
# making new cascade
#
#
# OG Orders left:  2051169
# Cascade length:  7
# New Orders left:  2051162
# making new cascade
#
#
# OG Orders left:  2051162
# Cascade length:  3532
# New Orders left:  2047630
# making new cascade
#
#
# OG Orders left:  2047630
# Cascade length:  4333
# New Orders left:  2043297
# making new cascade
#
#
# OG Orders left:  2043297
# Cascade length:  4
# New Orders left:  2043293
# making new cascade
#
#
# OG Orders left:  2043293
# Cascade length:  1
# New Orders left:  2043292
# making new cascade
#
#
# OG Orders left:  2043292
# Cascade length:  5
# New Orders left:  2043287
# making new cascade
#
#
# OG Orders left:  2043287
# Cascade length:  2
# New Orders left:  2043285
# making new cascade
#
#
# OG Orders left:  2043285
# Cascade length:  2
# New Orders left:  2043283
# making new cascade
#
#
# OG Orders left:  2043283
# Cascade length:  3048
# New Orders left:  2040235
# making new cascade
#
#
# OG Orders left:  2040235
# Cascade length:  8
# New Orders left:  2040227
# making new cascade
#
#
# OG Orders left:  2040227
# Cascade length:  8
# New Orders left:  2040219
# making new cascade
#
#
# OG Orders left:  2040219
# Cascade length:  4963
# New Orders left:  2035256
# making new cascade
#
#
# OG Orders left:  2035256
# Cascade length:  2
# New Orders left:  2035254
# making new cascade
#
#
# OG Orders left:  2035254
# Cascade length:  3
# New Orders left:  2035251
# making new cascade
#
#
# OG Orders left:  2035251
# Cascade length:  6
# New Orders left:  2035245
# making new cascade
#
#
# OG Orders left:  2035245
# Cascade length:  3808
# New Orders left:  2031437
# making new cascade
#
#
# OG Orders left:  2031437
# Cascade length:  5
# New Orders left:  2031432
# making new cascade
#
#
# OG Orders left:  2031432
# Cascade length:  4
# New Orders left:  2031428
# making new cascade
#
#
# OG Orders left:  2031428
# Cascade length:  1542
# New Orders left:  2029886
# making new cascade
#
#
# OG Orders left:  2029886
# Cascade length:  69
# New Orders left:  2029817
# making new cascade
#
#
# OG Orders left:  2029817
# Cascade length:  2
# New Orders left:  2029815
# making new cascade
#
#
# OG Orders left:  2029815
# Cascade length:  9
# New Orders left:  2029806
# making new cascade
#
#
# OG Orders left:  2029806
# Cascade length:  4307
# New Orders left:  2025499
# making new cascade
#
#
# OG Orders left:  2025499
# Cascade length:  43
# New Orders left:  2025456
# making new cascade
#
#
# OG Orders left:  2025456
# Cascade length:  2
# New Orders left:  2025454
# making new cascade
#
#
# OG Orders left:  2025454
# Cascade length:  4059
# New Orders left:  2021395
# making new cascade
#
#
# OG Orders left:  2021395
# Cascade length:  2
# New Orders left:  2021393
# making new cascade
#
#
# OG Orders left:  2021393
# Cascade length:  17
# New Orders left:  2021376
# making new cascade
#
#
# OG Orders left:  2021376
# Cascade length:  3
# New Orders left:  2021373
# making new cascade
#
#
# OG Orders left:  2021373
# Cascade length:  49
# New Orders left:  2021324
# making new cascade
#
#
# OG Orders left:  2021324
# Cascade length:  2501
# New Orders left:  2018823
# making new cascade
#
#
# OG Orders left:  2018823
# Cascade length:  4
# New Orders left:  2018819
# making new cascade
#
#
# OG Orders left:  2018819
# Cascade length:  3315
# New Orders left:  2015504
# making new cascade
#
#
# OG Orders left:  2015504
# Cascade length:  1
# New Orders left:  2015503
# making new cascade
#
#
# OG Orders left:  2015503
# Cascade length:  53
# New Orders left:  2015450
# making new cascade
#
#
# OG Orders left:  2015450
# Cascade length:  33
# New Orders left:  2015417
# making new cascade
#
#
# OG Orders left:  2015417
# Cascade length:  2783
# New Orders left:  2012634
# making new cascade
#
#
# OG Orders left:  2012634
# Cascade length:  23
# ...
# New Orders left:  35718
# making new cascade
#
#
# OG Orders left:  35718
# Cascade length:  1117
# New Orders left:  34601
# making new cascade
#
#
# OG Orders left:  34601
# Cascade length:  49
# New Orders left:  34552
# making new cascade
#
#
# OG Orders left:  34552
# Cascade length:  1
# New Orders left:  34551
# making new cascade
#
#
# OG Orders left:  34551
# Cascade length:  8
# New Orders left:  34543
# making new cascade
#
#
# OG Orders left:  34543
# Cascade length:  13
# New Orders left:  34530
# making new cascade
#
#
# OG Orders left:  34530
# Cascade length:  8
# New Orders left:  34522
# making new cascade
#
#
# OG Orders left:  34522
# Cascade length:  367
# New Orders left:  34155
# making new cascade
#
#
# OG Orders left:  34155
# Cascade length:  71
# New Orders left:  34084
# making new cascade
#
#
# OG Orders left:  34084
# Cascade length:  1
# New Orders left:  34083
# making new cascade
#
#
# OG Orders left:  34083
# Cascade length:  15
# New Orders left:  34068
# making new cascade
#
#
# OG Orders left:  34068
# Cascade length:  2
# New Orders left:  34066
# making new cascade
#
#
# OG Orders left:  34066
# Cascade length:  711
# New Orders left:  33355
# making new cascade
#
#
# OG Orders left:  33355
# Cascade length:  30
# New Orders left:  33325
# making new cascade
#
#
# OG Orders left:  33325
# Cascade length:  594
# New Orders left:  32731
# making new cascade
#
#
# OG Orders left:  32731
# Cascade length:  307
# New Orders left:  32424
# making new cascade
#
#
# OG Orders left:  32424
# Cascade length:  9
# New Orders left:  32415
# making new cascade
#
#
# OG Orders left:  32415
# Cascade length:  28
# New Orders left:  32387
# making new cascade
#
#
# OG Orders left:  32387
# Cascade length:  368
# New Orders left:  32019
# making new cascade
#
#
# OG Orders left:  32019
# Cascade length:  935
# New Orders left:  31084
# making new cascade
#
#
# OG Orders left:  31084
# Cascade length:  68
# New Orders left:  31016
# making new cascade
#
#
# OG Orders left:  31016
# Cascade length:  554
# New Orders left:  30462
# making new cascade
#
#
# OG Orders left:  30462
# Cascade length:  1007
# New Orders left:  29455
# making new cascade
#
#
# OG Orders left:  29455
# Cascade length:  414
# New Orders left:  29041
# making new cascade
#
#
# OG Orders left:  29041
# Cascade length:  1065
# New Orders left:  27976
# making new cascade
#
#
# OG Orders left:  27976
# Cascade length:  193
# New Orders left:  27783
# making new cascade
#
#
# OG Orders left:  27783
# Cascade length:  38
# New Orders left:  27745
# making new cascade
#
#
# OG Orders left:  27745
# Cascade length:  60
# New Orders left:  27685
# making new cascade
#
#
# OG Orders left:  27685
# Cascade length:  60
# New Orders left:  27625
# making new cascade
#
#
# OG Orders left:  27625
# Cascade length:  4
# New Orders left:  27621
# making new cascade
#
#
# OG Orders left:  27621
# Cascade length:  1836
# New Orders left:  25785
# making new cascade
#
#
# OG Orders left:  25785
# Cascade length:  48
# New Orders left:  25737
# making new cascade
#
#
# OG Orders left:  25737
# Cascade length:  190
# New Orders left:  25547
# making new cascade
#
#
# OG Orders left:  25547
# Cascade length:  13
# New Orders left:  25534
# making new cascade
#
#
# OG Orders left:  25534
# Cascade length:  1025
# New Orders left:  24509
# making new cascade
#
#
# OG Orders left:  24509
# Cascade length:  15
# New Orders left:  24494
# making new cascade
#
#
# OG Orders left:  24494
# Cascade length:  508
# New Orders left:  23986
# making new cascade
#
#
# OG Orders left:  23986
# Cascade length:  51
# New Orders left:  23935
# making new cascade
#
#
# OG Orders left:  23935
# Cascade length:  18
# New Orders left:  23917
# making new cascade
#
#
# OG Orders left:  23917
# Cascade length:  1257
# New Orders left:  22660
# making new cascade
#
#
# OG Orders left:  22660
# Cascade length:  29
# New Orders left:  22631
# making new cascade
#
#
# OG Orders left:  22631
# Cascade length:  8
# New Orders left:  22623
# making new cascade
#
#
# OG Orders left:  22623
# Cascade length:  23
# New Orders left:  22600
# making new cascade
#
#
# OG Orders left:  22600
# Cascade length:  10
# New Orders left:  22590
# making new cascade
#
#
# OG Orders left:  22590
# Cascade length:  1320
# New Orders left:  21270
# making new cascade
#
#
# OG Orders left:  21270
# Cascade length:  245
# New Orders left:  21025
# making new cascade
#
#
# OG Orders left:  21025
# Cascade length:  71
# New Orders left:  20954
# making new cascade
#
#
# OG Orders left:  20954
# Cascade length:  6
# New Orders left:  20948
# making new cascade
#
#
# OG Orders left:  20948
# Cascade length:  169
# New Orders left:  20779
# making new cascade
#
#
# OG Orders left:  20779
# Cascade length:  10
# New Orders left:  20769
# making new cascade
#
#
# OG Orders left:  20769
# Cascade length:  4
# New Orders left:  20765
# making new cascade
#
#
# OG Orders left:  20765
# Cascade length:  2
# New Orders left:  20763
# making new cascade
#
#
# OG Orders left:  20763
# Cascade length:  2
# New Orders left:  20761
# making new cascade
#
#
# OG Orders left:  20761
# Cascade length:  18
# New Orders left:  20743
# making new cascade
#
#
# OG Orders left:  20743
# Cascade length:  1145
# New Orders left:  19598
# making new cascade
#
#
# OG Orders left:  19598
# Cascade length:  28
# New Orders left:  19570
# making new cascade
#
#
# OG Orders left:  19570
# Cascade length:  721
# New Orders left:  18849
# making new cascade
#
#
# OG Orders left:  18849
# Cascade length:  2
# New Orders left:  18847
# making new cascade
#
#
# OG Orders left:  18847
# Cascade length:  816
# New Orders left:  18031
# making new cascade
#
#
# OG Orders left:  18031
# Cascade length:  12
# New Orders left:  18019
# making new cascade
#
#
# OG Orders left:  18019
# Cascade length:  325
# New Orders left:  17694
# making new cascade
#
#
# OG Orders left:  17694
# Cascade length:  12
# New Orders left:  17682
# making new cascade
#
#
# OG Orders left:  17682
# Cascade length:  1080
# New Orders left:  16602
# making new cascade
#
#
# OG Orders left:  16602
# Cascade length:  17
# New Orders left:  16585
# making new cascade
#
#
# OG Orders left:  16585
# Cascade length:  36
# New Orders left:  16549
# making new cascade
#
#
# OG Orders left:  16549
# Cascade length:  166
# New Orders left:  16383
# making new cascade
#
#
# OG Orders left:  16383
# Cascade length:  882
# New Orders left:  15501
# making new cascade
#
#
# OG Orders left:  15501
# Cascade length:  781
# New Orders left:  14720
# making new cascade
#
#
# OG Orders left:  14720
# Cascade length:  1
# New Orders left:  14719
# making new cascade
#
#
# OG Orders left:  14719
# Cascade length:  2
# New Orders left:  14717
# making new cascade
#
#
# OG Orders left:  14717
# Cascade length:  34
# New Orders left:  14683
# making new cascade
#
#
# OG Orders left:  14683
# Cascade length:  5
# New Orders left:  14678
# making new cascade
#
#
# OG Orders left:  14678
# Cascade length:  673
# New Orders left:  14005
# making new cascade
#
#
# OG Orders left:  14005
# Cascade length:  3
# New Orders left:  14002
# making new cascade
#
#
# OG Orders left:  14002
# Cascade length:  8
# New Orders left:  13994
# making new cascade
#
#
# OG Orders left:  13994
# Cascade length:  558
# New Orders left:  13436
# making new cascade
#
#
# OG Orders left:  13436
# Cascade length:  143
# New Orders left:  13293
# making new cascade
#
#
# OG Orders left:  13293
# Cascade length:  6
# New Orders left:  13287
# making new cascade
#
#
# OG Orders left:  13287
# Cascade length:  527
# New Orders left:  12760
# making new cascade
#
#
# OG Orders left:  12760
# Cascade length:  11
# New Orders left:  12749
# making new cascade
#
#
# OG Orders left:  12749
# Cascade length:  1001
# New Orders left:  11748
# making new cascade
#
#
# OG Orders left:  11748
# Cascade length:  1
# New Orders left:  11747
# making new cascade
#
#
# OG Orders left:  11747
# Cascade length:  4
# New Orders left:  11743
# making new cascade
#
#
# OG Orders left:  11743
# Cascade length:  2
# New Orders left:  11741
# making new cascade
#
#
# OG Orders left:  11741
# Cascade length:  459
# New Orders left:  11282
# making new cascade
#
#
# OG Orders left:  11282
# Cascade length:  38
# New Orders left:  11244
# making new cascade
#
#
# OG Orders left:  11244
# Cascade length:  381
# New Orders left:  10863
# making new cascade
#
#
# OG Orders left:  10863
# Cascade length:  18
# New Orders left:  10845
# making new cascade
#
#
# OG Orders left:  10845
# Cascade length:  282
# New Orders left:  10563
# making new cascade
#
#
# OG Orders left:  10563
# Cascade length:  354
# New Orders left:  10209
# making new cascade
#
#
# OG Orders left:  10209
# Cascade length:  5
# New Orders left:  10204
# making new cascade
#
#
# OG Orders left:  10204
# Cascade length:  1
# New Orders left:  10203
# making new cascade
#
#
# OG Orders left:  10203
# Cascade length:  563
# New Orders left:  9640
# making new cascade
#
#
# OG Orders left:  9640
# Cascade length:  59
# New Orders left:  9581
# making new cascade
#
#
# OG Orders left:  9581
# Cascade length:  4
# New Orders left:  9577
# making new cascade
#
#
# OG Orders left:  9577
# Cascade length:  541
# New Orders left:  9036
# making new cascade
#
#
# OG Orders left:  9036
# Cascade length:  143
# New Orders left:  8893
# making new cascade
#
#
# OG Orders left:  8893
# Cascade length:  330
# New Orders left:  8563
# making new cascade
#
#
# OG Orders left:  8563
# Cascade length:  3
# New Orders left:  8560
# making new cascade
#
#
# OG Orders left:  8560
# Cascade length:  276
# New Orders left:  8284
# making new cascade
#
#
# OG Orders left:  8284
# Cascade length:  4
# New Orders left:  8280
# making new cascade
#
#
# OG Orders left:  8280
# Cascade length:  5
# New Orders left:  8275
# making new cascade
#
#
# OG Orders left:  8275
# Cascade length:  536
# New Orders left:  7739
# making new cascade
#
#
# OG Orders left:  7739
# Cascade length:  2
# New Orders left:  7737
# making new cascade
#
#
# OG Orders left:  7737
# Cascade length:  185
# New Orders left:  7552
# making new cascade
#
#
# OG Orders left:  7552
# Cascade length:  331
# New Orders left:  7221
# making new cascade
#
#
# OG Orders left:  7221
# Cascade length:  189
# New Orders left:  7032
# making new cascade
#
#
# OG Orders left:  7032
# Cascade length:  340
# New Orders left:  6692
# making new cascade
#
#
# OG Orders left:  6692
# Cascade length:  171
# New Orders left:  6521
# making new cascade
#
#
# OG Orders left:  6521
# Cascade length:  1
# New Orders left:  6520
# making new cascade
#
#
# OG Orders left:  6520
# Cascade length:  1
# New Orders left:  6519
# making new cascade
#
#
# OG Orders left:  6519
# Cascade length:  4
# New Orders left:  6515
# making new cascade
#
#
# OG Orders left:  6515
# Cascade length:  126
# New Orders left:  6389
# making new cascade
#
#
# OG Orders left:  6389
# Cascade length:  280
# New Orders left:  6109
# making new cascade
#
#
# OG Orders left:  6109
# Cascade length:  67
# New Orders left:  6042
# making new cascade
#
#
# OG Orders left:  6042
# Cascade length:  601
# New Orders left:  5441
# making new cascade
#
#
# OG Orders left:  5441
# Cascade length:  64
# New Orders left:  5377
# making new cascade
#
#
# OG Orders left:  5377
# Cascade length:  2
# New Orders left:  5375
# making new cascade
#
#
# OG Orders left:  5375
# Cascade length:  2
# New Orders left:  5373
# making new cascade
#
#
# OG Orders left:  5373
# Cascade length:  1
# New Orders left:  5372
# making new cascade
#
#
# OG Orders left:  5372
# Cascade length:  326
# New Orders left:  5046
# making new cascade
#
#
# OG Orders left:  5046
# Cascade length:  1
# New Orders left:  5045
# making new cascade
#
#
# OG Orders left:  5045
# Cascade length:  6
# New Orders left:  5039
# making new cascade
#
#
# OG Orders left:  5039
# Cascade length:  179
# New Orders left:  4860
# making new cascade
#
#
# OG Orders left:  4860
# Cascade length:  5
# New Orders left:  4855
# making new cascade
#
#
# OG Orders left:  4855
# Cascade length:  463
# New Orders left:  4392
# making new cascade
#
#
# OG Orders left:  4392
# Cascade length:  326
# New Orders left:  4066
# making new cascade
#
#
# OG Orders left:  4066
# Cascade length:  11
# New Orders left:  4055
# making new cascade
#
#
# OG Orders left:  4055
# Cascade length:  415
# New Orders left:  3640
# making new cascade
#
#
# OG Orders left:  3640
# Cascade length:  175
# New Orders left:  3465
# making new cascade
#
#
# OG Orders left:  3465
# Cascade length:  80
# New Orders left:  3385
# making new cascade
#
#
# OG Orders left:  3385
# Cascade length:  16
# New Orders left:  3369
# making new cascade
#
#
# OG Orders left:  3369
# Cascade length:  309
# New Orders left:  3060
# making new cascade
#
#
# OG Orders left:  3060
# Cascade length:  290
# New Orders left:  2770
# making new cascade
#
#
# OG Orders left:  2770
# Cascade length:  120
# New Orders left:  2650
# making new cascade
#
#
# OG Orders left:  2650
# Cascade length:  91
# New Orders left:  2559
# making new cascade
#
#
# OG Orders left:  2559
# Cascade length:  165
# New Orders left:  2394
# making new cascade
#
#
# OG Orders left:  2394
# Cascade length:  97
# New Orders left:  2297
# making new cascade
#
#
# OG Orders left:  2297
# Cascade length:  35
# New Orders left:  2262
# making new cascade
#
#
# OG Orders left:  2262
# Cascade length:  218
# New Orders left:  2044
# making new cascade
#
#
# OG Orders left:  2044
# Cascade length:  186
# New Orders left:  1858
# making new cascade
#
#
# OG Orders left:  1858
# Cascade length:  65
# New Orders left:  1793
# making new cascade
#
#
# OG Orders left:  1793
# Cascade length:  51
# New Orders left:  1742
# making new cascade
#
#
# OG Orders left:  1742
# Cascade length:  163
# New Orders left:  1579
# making new cascade
#
#
# OG Orders left:  1579
# Cascade length:  2
# New Orders left:  1577
# making new cascade
#
#
# OG Orders left:  1577
# Cascade length:  2
# New Orders left:  1575
# making new cascade
#
#
# OG Orders left:  1575
# Cascade length:  62
# New Orders left:  1513
# making new cascade
#
#
# OG Orders left:  1513
# Cascade length:  210
# New Orders left:  1303
# making new cascade
#
#
# OG Orders left:  1303
# Cascade length:  231
# New Orders left:  1072
# making new cascade
#
#
# OG Orders left:  1072
# Cascade length:  3
# New Orders left:  1069
# making new cascade
#
#
# OG Orders left:  1069
# Cascade length:  4
# New Orders left:  1065
# making new cascade
#
#
# OG Orders left:  1065
# Cascade length:  3
# New Orders left:  1062
# making new cascade
#
#
# OG Orders left:  1062
# Cascade length:  9
# New Orders left:  1053
# making new cascade
#
#
# OG Orders left:  1053
# Cascade length:  112
# New Orders left:  941
# making new cascade
#
#
# OG Orders left:  941
# Cascade length:  183
# New Orders left:  758
# making new cascade
#
#
# OG Orders left:  758
# Cascade length:  2
# New Orders left:  756
# making new cascade
#
#
# OG Orders left:  756
# Cascade length:  17
# New Orders left:  739
# making new cascade
#
#
# OG Orders left:  739
# Cascade length:  14
# New Orders left:  725
# making new cascade
#
#
# OG Orders left:  725
# Cascade length:  48
# New Orders left:  677
# making new cascade
#
#
# OG Orders left:  677
# Cascade length:  2
# New Orders left:  675
# making new cascade
#
#
# OG Orders left:  675
# Cascade length:  48
# New Orders left:  627
# making new cascade
#
#
# OG Orders left:  627
# Cascade length:  35
# New Orders left:  592
# making new cascade
#
#
# OG Orders left:  592
# Cascade length:  2
# New Orders left:  590
# making new cascade
#
#
# OG Orders left:  590
# Cascade length:  73
# New Orders left:  517
# making new cascade
#
#
# OG Orders left:  517
# Cascade length:  7
# New Orders left:  510
# making new cascade
#
#
# OG Orders left:  510
# Cascade length:  20
# New Orders left:  490
# making new cascade
#
#
# OG Orders left:  490
# Cascade length:  3
# New Orders left:  487
# making new cascade
#
#
# OG Orders left:  487
# Cascade length:  56
# New Orders left:  431
# making new cascade
#
#
# OG Orders left:  431
# Cascade length:  8
# New Orders left:  423
# making new cascade
#
#
# OG Orders left:  423
# Cascade length:  7
# New Orders left:  416
# making new cascade
#
#
# OG Orders left:  416
# Cascade length:  50
# New Orders left:  366
# making new cascade
#
#
# OG Orders left:  366
# Cascade length:  46
# New Orders left:  320
# making new cascade
#
#
# OG Orders left:  320
# Cascade length:  92
# New Orders left:  228
# making new cascade
#
#
# OG Orders left:  228
# Cascade length:  1
# New Orders left:  227
# making new cascade
#
#
# OG Orders left:  227
# Cascade length:  40
# New Orders left:  187
# making new cascade
#
#
# OG Orders left:  187
# Cascade length:  34
# New Orders left:  153
# making new cascade
#
#
# OG Orders left:  153
# Cascade length:  35
# New Orders left:  118
# making new cascade
#
#
# OG Orders left:  118
# Cascade length:  34
# New Orders left:  84
# making new cascade
#
#
# OG Orders left:  84
# Cascade length:  47
# New Orders left:  37
# making new cascade
#
#
# OG Orders left:  37
# Cascade length:  6
# New Orders left:  31
# making new cascade
#
#
# OG Orders left:  31
# Cascade length:  7
# New Orders left:  24
# making new cascade
#
#
# OG Orders left:  24
# Cascade length:  6
# New Orders left:  18
# making new cascade
#
#
# OG Orders left:  18
# Cascade length:  11
# New Orders left:  7
# making new cascade
#
#
# OG Orders left:  7
# Cascade length:  4
# New Orders left:  3
# making new cascade
#
#
# OG Orders left:  3
# Cascade length:  3
# New Orders left:  0
# making new cascade

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades11_npc_500_7200_100_5_10.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*2, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_500_7200_100_5_10_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_500_7200_100_5_10_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*2, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_500_7200_100_5_10_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
