# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_501_7200_100_new2threshold_fixedhurst.pkl', 'rb') as f:
    traderIDs = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPool = np.load("./results/nopricechange/7-9/stockPool_501_7200_100_new2threshold_fixedhurst.npy")
hurstPool = np.load("./results/nopricechange/7-9/hurstPool_501_7200_100_new2threshold_fixedhurst.npy")
Ttransactions = pd.read_csv("./results/nopricechange/7-9/transactions_501_7200_100_new2threshold_fixedhurst.csv")
TtotalOrders = pd.read_csv("./results/nopricechange/7-9/totalOrders_501_7200_100_new2threshold_fixedhurst.csv")

# %% [markdown]
# # Cascades with time limit

# %%
def findPortfOrderCascades(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold)
    input TtotalOrders, the portfolio, and minimum time
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]
    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        #print(sep)
        #print(max(sep))
        keySep = np.where(sep>maxSep)[0]
        #print(keySep)
        if len(keySep)>0:
            endtime = ToS[keySep[0]] #end of this cascade
        else:
            endtime = ToS[-1]
        portfCascade = portfOrders[portfOrders['time']<=endtime]
        return portfCascade
    else:
        return pd.DataFrame()

# %%
cascades = {}
numCascade = 0
cascadeStocks = {}
cascadePortfs = {}
cascadeTime = {}
cascadeTf = {}
cascades = {}
maxtimeeff = 2
while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
    print("OG Orders left: ", len(TtotalOrders))
    seed = (TtotalOrders.iloc[0]['portfolio'])
    t0 = TtotalOrders.iloc[0]['time']
    seedCascade = findPortfOrderCascades(TtotalOrders, seed, t0, maxSep = 1)
    cascadeStocks[numCascade] = np.asarray(seedCascade['stock'])
    cascadePortfs[numCascade] = np.asarray(seed)
    cascadeTime[numCascade] = t0
    cascades[numCascade] = seedCascade
    stockTimes = {}
    for row in seedCascade.iterrows():
        stockTimes[row[1]['stock']] = row[1]['time'] + abs(row[1]['order'])*maxtimeeff
    assert len(seedCascade) > 0
    TtotalOrders = TtotalOrders[~TtotalOrders.isin(seedCascade)].dropna()
    # NEW VERSION (PORTFOLIO PERSPECTIVE)
    for childPortf in list(TtotalOrders['portfolio'].unique()):
        match = False
        if any(np.isin(cascadeStocks[numCascade],traderIDs[childPortf].stocks)):
#             print("match: ", childPortf)
            if childPortf not in cascadePortfs[numCascade]:
                childPortfCascade = findPortfOrderCascades(TtotalOrders,childPortf,t0, maxSep = 1)
                for row in childPortfCascade.iterrows():
                    if row[1]['stock'] in stockTimes:
                        if row[1]['time'] <= stockTimes[row[1]['stock']]:
                            match = True
                            break 
                if match == True:        
                    cascadePortfs[numCascade] = np.append(cascadePortfs[numCascade], childPortf)
                    cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                    TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
#                     for childStock in list(childPortfCascade['stock'].unique()):
#                         if childStock not in cascadeStocks[numCascade]:
#                             cascadeStocks[numCascade] = np.append(cascadeStocks[numCascade], childStock)
                    for row in childPortfCascade.iterrows():
                        if row[1]['stock'] in stockTimes:
                            stockTimes[row[1]['stock']] += abs(row[1]['order'])*maxtimeeff
                        else:
                            stockTimes[row[1]['stock']] = row[1]['time'] + abs(row[1]['order'])*maxtimeeff
                            cascadeStocks[numCascade] = np.append(cascadeStocks[numCascade], row[1]['stock'])
    print("Cascade length: ",len(cascades[numCascade]))
    print("New Orders left: ", len(TtotalOrders))
    cascadeTf[numCascade] = cascades[numCascade]['time'].max()
    print("making new cascade")
    numCascade += 1
    


    
print(cascadeStocks)
print(cascadePortfs)
print(cascadeTime)
# Out:
# OG Orders left:  7088505
# Cascade length:  7101
# New Orders left:  7081404
# making new cascade
# OG Orders left:  7081404
# Cascade length:  7416
# New Orders left:  7073988
# making new cascade
# OG Orders left:  7073988
# Cascade length:  6969
# New Orders left:  7067019
# making new cascade
# OG Orders left:  7067019
# Cascade length:  6771
# New Orders left:  7060248
# making new cascade
# OG Orders left:  7060248
# Cascade length:  2
# New Orders left:  7060246
# making new cascade
# OG Orders left:  7060246
# Cascade length:  6664
# New Orders left:  7053582
# making new cascade
# OG Orders left:  7053582
# Cascade length:  6545
# New Orders left:  7047037
# making new cascade
# OG Orders left:  7047037
# Cascade length:  1
# New Orders left:  7047036
# making new cascade
# OG Orders left:  7047036
# Cascade length:  6819
# New Orders left:  7040217
# making new cascade
# OG Orders left:  7040217
# Cascade length:  20
# New Orders left:  7040197
# making new cascade
# OG Orders left:  7040197
# Cascade length:  6582
# New Orders left:  7033615
# making new cascade
# OG Orders left:  7033615
# Cascade length:  6675
# New Orders left:  7026940
# making new cascade
# OG Orders left:  7026940
# Cascade length:  6033
# New Orders left:  7020907
# making new cascade
# OG Orders left:  7020907
# Cascade length:  6468
# New Orders left:  7014439
# making new cascade
# OG Orders left:  7014439
# Cascade length:  6026
# New Orders left:  7008413
# making new cascade
# OG Orders left:  7008413
# Cascade length:  6503
# New Orders left:  7001910
# making new cascade
# OG Orders left:  7001910
# Cascade length:  6027
# New Orders left:  6995883
# making new cascade
# OG Orders left:  6995883
# Cascade length:  7224
# New Orders left:  6988659
# making new cascade
# OG Orders left:  6988659
# Cascade length:  6884
# New Orders left:  6981775
# making new cascade
# OG Orders left:  6981775
# Cascade length:  6421
# New Orders left:  6975354
# making new cascade
# OG Orders left:  6975354
# Cascade length:  6649
# New Orders left:  6968705
# making new cascade
# OG Orders left:  6968705
# Cascade length:  6866
# New Orders left:  6961839
# making new cascade
# OG Orders left:  6961839
# Cascade length:  7271
# New Orders left:  6954568
# making new cascade
# OG Orders left:  6954568
# Cascade length:  2
# New Orders left:  6954566
# making new cascade
# OG Orders left:  6954566
# Cascade length:  6
# New Orders left:  6954560
# making new cascade
# OG Orders left:  6954560
# Cascade length:  6759
# New Orders left:  6947801
# making new cascade
# OG Orders left:  6947801
# Cascade length:  6802
# New Orders left:  6940999
# making new cascade
# OG Orders left:  6940999
# Cascade length:  6154
# New Orders left:  6934845
# making new cascade
# OG Orders left:  6934845
# Cascade length:  3
# New Orders left:  6934842
# making new cascade
# OG Orders left:  6934842
# Cascade length:  6666
# New Orders left:  6928176
# making new cascade
# OG Orders left:  6928176
# Cascade length:  6538
# New Orders left:  6921638
# making new cascade
# OG Orders left:  6921638
# Cascade length:  6716
# New Orders left:  6914922
# making new cascade
# OG Orders left:  6914922
# Cascade length:  9
# New Orders left:  6914913
# making new cascade
# OG Orders left:  6914913
# Cascade length:  10
# New Orders left:  6914903
# making new cascade
# OG Orders left:  6914903
# Cascade length:  14
# New Orders left:  6914889
# making new cascade
# OG Orders left:  6914889
# Cascade length:  6505
# New Orders left:  6908384
# making new cascade
# OG Orders left:  6908384
# Cascade length:  16
# New Orders left:  6908368
# making new cascade
# OG Orders left:  6908368
# Cascade length:  27
# New Orders left:  6908341
# making new cascade
# OG Orders left:  6908341
# Cascade length:  6792
# New Orders left:  6901549
# making new cascade
# OG Orders left:  6901549
# Cascade length:  9
# New Orders left:  6901540
# making new cascade
# OG Orders left:  6901540
# Cascade length:  5864
# New Orders left:  6895676
# making new cascade
# OG Orders left:  6895676
# Cascade length:  6
# New Orders left:  6895670
# making new cascade
# OG Orders left:  6895670
# Cascade length:  6009
# New Orders left:  6889661
# making new cascade
# OG Orders left:  6889661
# Cascade length:  6514
# New Orders left:  6883147
# making new cascade
# OG Orders left:  6883147
# Cascade length:  14
# New Orders left:  6883133
# making new cascade
# OG Orders left:  6883133
# Cascade length:  12
# New Orders left:  6883121
# making new cascade
# OG Orders left:  6883121
# Cascade length:  13
# New Orders left:  6883108
# making new cascade
# OG Orders left:  6883108
# Cascade length:  6265
# New Orders left:  6876843
# making new cascade
# OG Orders left:  6876843
# Cascade length:  6564
# New Orders left:  6870279
# making new cascade
# OG Orders left:  6870279
# Cascade length:  14
# New Orders left:  6870265
# making new cascade
# OG Orders left:  6870265
# Cascade length:  6443
# New Orders left:  6863822
# making new cascade
# OG Orders left:  6863822
# Cascade length:  5861
# New Orders left:  6857961
# making new cascade
# OG Orders left:  6857961
# Cascade length:  5571
# New Orders left:  6852390
# making new cascade
# OG Orders left:  6852390
# Cascade length:  6265
# New Orders left:  6846125
# making new cascade
# OG Orders left:  6846125
# Cascade length:  7
# New Orders left:  6846118
# making new cascade
# OG Orders left:  6846118
# Cascade length:  5900
# New Orders left:  6840218
# making new cascade
# OG Orders left:  6840218
# Cascade length:  5778
# New Orders left:  6834440
# making new cascade
# OG Orders left:  6834440
# Cascade length:  13
# New Orders left:  6834427
# making new cascade
# OG Orders left:  6834427
# Cascade length:  5378
# New Orders left:  6829049
# making new cascade
# OG Orders left:  6829049
# Cascade length:  5649
# New Orders left:  6823400
# making new cascade
# OG Orders left:  6823400
# Cascade length:  5838
# New Orders left:  6817562
# making new cascade
# OG Orders left:  6817562
# Cascade length:  26
# New Orders left:  6817536
# making new cascade
# OG Orders left:  6817536
# Cascade length:  5637
# New Orders left:  6811899
# making new cascade
# OG Orders left:  6811899
# Cascade length:  1
# New Orders left:  6811898
# making new cascade
# OG Orders left:  6811898
# Cascade length:  5752
# New Orders left:  6806146
# making new cascade
# OG Orders left:  6806146
# Cascade length:  14
# New Orders left:  6806132
# making new cascade
# OG Orders left:  6806132
# Cascade length:  19
# New Orders left:  6806113
# making new cascade
# OG Orders left:  6806113
# Cascade length:  5075
# New Orders left:  6801038
# making new cascade
# OG Orders left:  6801038
# Cascade length:  5242
# New Orders left:  6795796
# making new cascade
# OG Orders left:  6795796
# Cascade length:  5474
# New Orders left:  6790322
# making new cascade
# OG Orders left:  6790322
# Cascade length:  4934
# New Orders left:  6785388
# making new cascade
# OG Orders left:  6785388
# Cascade length:  4904
# New Orders left:  6780484
# making new cascade
# OG Orders left:  6780484
# Cascade length:  5120
# New Orders left:  6775364
# making new cascade
# OG Orders left:  6775364
# Cascade length:  11
# New Orders left:  6775353
# making new cascade
# OG Orders left:  6775353
# Cascade length:  4
# New Orders left:  6775349
# making new cascade
# OG Orders left:  6775349
# Cascade length:  62
# New Orders left:  6775287
# making new cascade
# OG Orders left:  6775287
# Cascade length:  4703
# New Orders left:  6770584
# making new cascade
# OG Orders left:  6770584
# Cascade length:  4516
# New Orders left:  6766068
# making new cascade
# OG Orders left:  6766068
# Cascade length:  9
# New Orders left:  6766059
# making new cascade
# OG Orders left:  6766059
# Cascade length:  5169
# New Orders left:  6760890
# making new cascade
# OG Orders left:  6760890
# Cascade length:  4869
# New Orders left:  6756021
# making new cascade
# OG Orders left:  6756021
# Cascade length:  9
# New Orders left:  6756012
# making new cascade
# OG Orders left:  6756012
# Cascade length:  4393
# New Orders left:  6751619
# making new cascade
# OG Orders left:  6751619
# Cascade length:  11
# New Orders left:  6751608
# making new cascade
# OG Orders left:  6751608
# Cascade length:  41
# New Orders left:  6751567
# making new cascade
# OG Orders left:  6751567
# Cascade length:  6
# New Orders left:  6751561
# making new cascade
# OG Orders left:  6751561
# Cascade length:  4649
# New Orders left:  6746912
# making new cascade
# OG Orders left:  6746912
# Cascade length:  4602
# New Orders left:  6742310
# making new cascade
# OG Orders left:  6742310
# Cascade length:  10
# New Orders left:  6742300
# making new cascade
# OG Orders left:  6742300
# Cascade length:  11
# New Orders left:  6742289
# making new cascade
# OG Orders left:  6742289
# Cascade length:  4
# New Orders left:  6742285
# making new cascade
# OG Orders left:  6742285
# Cascade length:  4273
# New Orders left:  6738012
# making new cascade
# OG Orders left:  6738012
# Cascade length:  4
# New Orders left:  6738008
# making new cascade
# OG Orders left:  6738008
# Cascade length:  7
# New Orders left:  6738001
# making new cascade
# OG Orders left:  6738001
# Cascade length:  35
# New Orders left:  6737966
# making new cascade
# OG Orders left:  6737966
# Cascade length:  12
# New Orders left:  6737954
# making new cascade
# OG Orders left:  6737954
# Cascade length:  34
# New Orders left:  6737920
# making new cascade
# OG Orders left:  6737920
# Cascade length:  4833
# New Orders left:  6733087
# making new cascade
# OG Orders left:  6733087
# Cascade length:  1
# New Orders left:  6733086
# making new cascade
# OG Orders left:  6733086
# Cascade length:  4430
# New Orders left:  6728656
# making new cascade
# OG Orders left:  6728656
# Cascade length:  9
# New Orders left:  6728647
# making new cascade
# OG Orders left:  6728647
# Cascade length:  4479
# New Orders left:  6724168
# making new cascade
# OG Orders left:  6724168
# Cascade length:  10
# New Orders left:  6724158
# making new cascade
# OG Orders left:  6724158
# Cascade length:  4386
# New Orders left:  6719772
# making new cascade
# OG Orders left:  6719772
# Cascade length:  4541
# New Orders left:  6715231
# making new cascade
# OG Orders left:  6715231
# Cascade length:  4397
# New Orders left:  6710834
# making new cascade
# OG Orders left:  6710834
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-634701230115> in <module>
#      38                     cascadePortfs[numCascade] = np.append(cascadePortfs[numCascade], childPortf)
#      39                     cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
# ---> 40                     TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
#      41 #                     for childStock in list(childPortfCascade['stock'].unique()):
#      42 #                         if childStock not in cascadeStocks[numCascade]:
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4860                 agg_obj = self.take(indices, axis=agg_axis)
#    4861
# -> 4862             count = agg_obj.count(axis=agg_axis)
#    4863
#    4864             if thresh is not None:
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/frame.py in count(self, axis, level, numeric_only)
#    7841                 # the or any_extension_types is really only hit for single-
#    7842                 # column frames with an extension array
# -> 7843                 result = notna(frame).sum(axis=axis)
#    7844             else:
#    7845                 # GH13407
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in notna(obj)
#     365     Name: 1, dtype: bool
#     366     """
# --> 367     res = isna(obj)
#     368     if is_scalar(res):
#     369         return not res
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     120     Name: 1, dtype: bool
#     121     """
# --> 122     return _isna(obj)
#     123
#     124
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#     147         return _isna_ndarraylike(obj)
#     148     elif isinstance(obj, ABCGeneric):
# --> 149         return obj._constructor(obj._data.isna(func=isna))
#     150     elif isinstance(obj, list):
#     151         return _isna_ndarraylike(np.asarray(obj, dtype=object))
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/internals/managers.py in isna(self, func, **kwargs)
#     552
#     553     def isna(self, func, **kwargs):
# --> 554         return self.apply("apply", func=func, **kwargs)
#     555
#     556     def where(self, **kwargs):
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     392         """
#     393         with np.errstate(all="ignore"):
# --> 394             result = func(self.values, **kwargs)
#     395         if not isinstance(result, Block):
#     396             result = self.make_block(values=_block_shape(result, ndim=self.ndim))
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     120     Name: 1, dtype: bool
#     121     """
# --> 122     return _isna(obj)
#     123
#     124
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#     145         ),
#     146     ):
# --> 147         return _isna_ndarraylike(obj)
#     148     elif isinstance(obj, ABCGeneric):
#     149         return obj._constructor(obj._data.isna(func=isna))
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj)
#     247             # object array of non-strings
#     248             result = np.empty(shape, dtype=bool)
# --> 249             vec = libmissing.isnaobj(values.ravel())
#     250             result[...] = vec.reshape(shape)
#     251
#
# KeyboardInterrupt:
