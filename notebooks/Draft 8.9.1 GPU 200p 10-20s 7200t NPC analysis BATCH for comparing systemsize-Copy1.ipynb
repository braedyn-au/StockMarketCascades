# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_200_7200_100_10_20.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_200_7200_100_10_20.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_200_7200_100_10_20.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_200_7200_100_10_20.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 1   993     yshfc      1   -1.0
# 1                 2   993     yshfc      2   -2.0
# 2                10   993     yshfc     10    1.0
# 3                11   993     yshfc     11    1.0
# 4                13   993     yshfc     13   -1.0
# ...             ...   ...       ...    ...    ...
# 3836251           7  8192     xbcot     35    1.0
# 3836252           9  8192     xbcot     42    1.0
# 3836253           2  8192     jmeyl     76    1.0
# 3836254           3  8192     jmeyl     43   -1.0
# 3836255          16  8192     jmeyl     66   -1.0
#
# [3836256 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades22_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  3836256

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5192], traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5192)
with open('../causalCascades/7-9/causalCascades21_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2217038
# Cascade length:  4082
# New Orders left:  2212956
# making new cascade
#
#
# OG Orders left:  2212956
# Cascade length:  4249
# New Orders left:  2208707
# making new cascade
#
#
# OG Orders left:  2208707
# Cascade length:  4093
# New Orders left:  2204614
# making new cascade
#
#
# OG Orders left:  2204614
# Cascade length:  4807
# New Orders left:  2199807
# making new cascade
#
#
# OG Orders left:  2199807
# Cascade length:  4589
# New Orders left:  2195218
# making new cascade
#
#
# OG Orders left:  2195218
# Cascade length:  3410
# New Orders left:  2191808
# making new cascade
#
#
# OG Orders left:  2191808
# Cascade length:  4004
# New Orders left:  2187804
# making new cascade
#
#
# OG Orders left:  2187804
# Cascade length:  4742
# New Orders left:  2183062
# making new cascade
#
#
# OG Orders left:  2183062
# Cascade length:  3784
# New Orders left:  2179278
# making new cascade
#
#
# OG Orders left:  2179278
# Cascade length:  4249
# New Orders left:  2175029
# making new cascade
#
#
# OG Orders left:  2175029
# Cascade length:  3515
# New Orders left:  2171514
# making new cascade
#
#
# OG Orders left:  2171514
# Cascade length:  4041
# New Orders left:  2167473
# making new cascade
#
#
# OG Orders left:  2167473
# Cascade length:  3751
# New Orders left:  2163722
# making new cascade
#
#
# OG Orders left:  2163722
# Cascade length:  5764
# New Orders left:  2157958
# making new cascade
#
#
# OG Orders left:  2157958
# Cascade length:  3771
# New Orders left:  2154187
# making new cascade
#
#
# OG Orders left:  2154187
# Cascade length:  4112
# New Orders left:  2150075
# making new cascade
#
#
# OG Orders left:  2150075
# Cascade length:  4653
# New Orders left:  2145422
# making new cascade
#
#
# OG Orders left:  2145422
# Cascade length:  3200
# New Orders left:  2142222
# making new cascade
#
#
# OG Orders left:  2142222
# Cascade length:  3451
# New Orders left:  2138771
# making new cascade
#
#
# OG Orders left:  2138771
# Cascade length:  4272
# New Orders left:  2134499
# making new cascade
#
#
# OG Orders left:  2134499
# Cascade length:  2860
# New Orders left:  2131639
# making new cascade
#
#
# OG Orders left:  2131639
# Cascade length:  3665
# New Orders left:  2127974
# making new cascade
#
#
# OG Orders left:  2127974
# Cascade length:  3380
# New Orders left:  2124594
# making new cascade
#
#
# OG Orders left:  2124594
# Cascade length:  3089
# New Orders left:  2121505
# making new cascade
#
#
# OG Orders left:  2121505
# Cascade length:  2705
# New Orders left:  2118800
# making new cascade
#
#
# OG Orders left:  2118800
# Cascade length:  2418
# New Orders left:  2116382
# making new cascade
#
#
# OG Orders left:  2116382
# Cascade length:  2687
# New Orders left:  2113695
# making new cascade
#
#
# OG Orders left:  2113695
# Cascade length:  3739
# New Orders left:  2109956
# making new cascade
#
#
# OG Orders left:  2109956
# Cascade length:  3616
# New Orders left:  2106340
# making new cascade
#
#
# OG Orders left:  2106340
# Cascade length:  2721
# New Orders left:  2103619
# making new cascade
#
#
# OG Orders left:  2103619
# Cascade length:  2295
# New Orders left:  2101324
# making new cascade
#
#
# OG Orders left:  2101324
# Cascade length:  2634
# New Orders left:  2098690
# making new cascade
#
#
# OG Orders left:  2098690
# Cascade length:  3858
# New Orders left:  2094832
# making new cascade
#
#
# OG Orders left:  2094832
# Cascade length:  2619
# New Orders left:  2092213
# making new cascade
#
#
# OG Orders left:  2092213
# Cascade length:  2721
# New Orders left:  2089492
# making new cascade
#
#
# OG Orders left:  2089492
# Cascade length:  3308
# New Orders left:  2086184
# making new cascade
#
#
# OG Orders left:  2086184
# Cascade length:  2902
# New Orders left:  2083282
# making new cascade
#
#
# OG Orders left:  2083282
# Cascade length:  2450
# New Orders left:  2080832
# making new cascade
#
#
# OG Orders left:  2080832
# Cascade length:  2337
# New Orders left:  2078495
# making new cascade
#
#
# OG Orders left:  2078495
# Cascade length:  2324
# New Orders left:  2076171
# making new cascade
#
#
# OG Orders left:  2076171
# Cascade length:  2531
# New Orders left:  2073640
# making new cascade
#
#
# OG Orders left:  2073640
# Cascade length:  2394
# New Orders left:  2071246
# making new cascade
#
#
# OG Orders left:  2071246
# Cascade length:  1894
# New Orders left:  2069352
# making new cascade
#
#
# OG Orders left:  2069352
# Cascade length:  1849
# New Orders left:  2067503
# making new cascade
#
#
# OG Orders left:  2067503
# Cascade length:  2505
# New Orders left:  2064998
# making new cascade
#
#
# OG Orders left:  2064998
# Cascade length:  2418
# New Orders left:  2062580
# making new cascade
#
#
# OG Orders left:  2062580
# Cascade length:  2685
# New Orders left:  2059895
# making new cascade
#
#
# OG Orders left:  2059895
# Cascade length:  2690
# New Orders left:  2057205
# making new cascade
#
#
# OG Orders left:  2057205
# Cascade length:  2987
# New Orders left:  2054218
# making new cascade
#
#
# OG Orders left:  2054218
# Cascade length:  2862
# New Orders left:  2051356
# making new cascade
#
#
# OG Orders left:  2051356
# Cascade length:  2628
# New Orders left:  2048728
# making new cascade
#
#
# OG Orders left:  2048728
# Cascade length:  2813
# New Orders left:  2045915
# making new cascade
#
#
# OG Orders left:  2045915
# Cascade length:  2416
# New Orders left:  2043499
# making new cascade
#
#
# OG Orders left:  2043499
# Cascade length:  2153
# New Orders left:  2041346
# making new cascade
#
#
# OG Orders left:  2041346
# Cascade length:  2718
# New Orders left:  2038628
# making new cascade
#
#
# OG Orders left:  2038628
# Cascade length:  2701
# New Orders left:  2035927
# making new cascade
#
#
# OG Orders left:  2035927
# Cascade length:  2616
# New Orders left:  2033311
# making new cascade
#
#
# OG Orders left:  2033311
# Cascade length:  2403
# New Orders left:  2030908
# making new cascade
#
#
# OG Orders left:  2030908
# Cascade length:  2138
# New Orders left:  2028770
# making new cascade
#
#
# OG Orders left:  2028770
# Cascade length:  2617
# New Orders left:  2026153
# making new cascade
#
#
# OG Orders left:  2026153
# Cascade length:  1869
# New Orders left:  2024284
# making new cascade
#
#
# OG Orders left:  2024284
# Cascade length:  2326
# New Orders left:  2021958
# making new cascade
#
#
# OG Orders left:  2021958
# Cascade length:  2526
# New Orders left:  2019432
# making new cascade
#
#
# OG Orders left:  2019432
# Cascade length:  1732
# New Orders left:  2017700
# making new cascade
#
#
# OG Orders left:  2017700
# Cascade length:  2279
# New Orders left:  2015421
# making new cascade
#
#
# OG Orders left:  2015421
# Cascade length:  2135
# New Orders left:  2013286
# making new cascade
#
#
# OG Orders left:  2013286
# Cascade length:  2476
# New Orders left:  2010810
# making new cascade
#
#
# OG Orders left:  2010810
# Cascade length:  2252
# New Orders left:  2008558
# making new cascade
#
#
# OG Orders left:  2008558
# Cascade length:  2798
# New Orders left:  2005760
# making new cascade
#
#
# OG Orders left:  2005760
# Cascade length:  2087
# New Orders left:  2003673
# making new cascade
#
#
# OG Orders left:  2003673
# Cascade length:  2037
# New Orders left:  2001636
# making new cascade
#
#
# OG Orders left:  2001636
# Cascade length:  3056
# New Orders left:  1998580
# making new cascade
#
#
# OG Orders left:  1998580
# Cascade length:  2411
# New Orders left:  1996169
# making new cascade
#
#
# OG Orders left:  1996169
# Cascade length:  1515
# New Orders left:  1994654
# making new cascade
#
#
# OG Orders left:  1994654
# Cascade length:  1994
# New Orders left:  1992660
# making new cascade
#
#
# OG Orders left:  1992660
# Cascade length:  2532
# New Orders left:  1990128
# making new cascade
#
#
# OG Orders left:  1990128
# Cascade length:  2424
# New Orders left:  1987704
# making new cascade
#
#
# OG Orders left:  1987704
# Cascade length:  2499
# New Orders left:  1985205
# making new cascade
#
#
# OG Orders left:  1985205
# Cascade length:  2274
# New Orders left:  1982931
# making new cascade
#
#
# OG Orders left:  1982931
# Cascade length:  2039
# New Orders left:  1980892
# making new cascade
#
#
# OG Orders left:  1980892
# Cascade length:  1905
# New Orders left:  1978987
# making new cascade
#
#
# OG Orders left:  1978987
# Cascade length:  2013
# New Orders left:  1976974
# making new cascade
#
#
# OG Orders left:  1976974
# Cascade length:  2075
# New Orders left:  1974899
# making new cascade
#
#
# OG Orders left:  1974899
# Cascade length:  2086
# New Orders left:  1972813
# making new cascade
#
#
# OG Orders left:  1972813
# Cascade length:  2035
# New Orders left:  1970778
# making new cascade
#
#
# OG Orders left:  1970778
# Cascade length:  2210
# New Orders left:  1968568
# making new cascade
#
#
# OG Orders left:  1968568
# Cascade length:  1926
# New Orders left:  1966642
# making new cascade
#
#
# OG Orders left:  1966642
# Cascade length:  1872
# New Orders left:  1964770
# making new cascade
#
#
# OG Orders left:  1964770
# Cascade length:  2255
# New Orders left:  1962515
# making new cascade
#
#
# OG Orders left:  1962515
# Cascade length:  2435
# New Orders left:  1960080
# making new cascade
#
#
# OG Orders left:  1960080
# Cascade length:  2043
# New Orders left:  1958037
# making new cascade
#
#
# OG Orders left:  1958037
# Cascade length:  2034
# New Orders left:  1956003
# making new cascade
#
#
# OG Orders left:  1956003
# Cascade length:  1833
# New Orders left:  1954170
# making new cascade
#
#
# OG Orders left:  1954170
# Cascade length:  1668
# New Orders left:  1952502
# making new cascade
#
#
# OG Orders left:  1952502
# Cascade length:  2413
# New Orders left:  1950089
# making new cascade
#
#
# OG Orders left:  1950089
# Cascade length:  1568
# New Orders left:  1948521
# making new cascade
#
#
# OG Orders left:  1948521
# Cascade length:  1992
# New Orders left:  1946529
# making new cascade
#
#
# OG Orders left:  1946529
# Cascade length:  2343
# New Orders left:  1944186
# making new cascade
#
#
# OG Orders left:  1944186
# Cascade length:  2591
# New Orders left:  1941595
# making new cascade
#
#
# OG Orders left:  1941595
# Cascade length:  1768
# New Orders left:  1939827
# making new cascade
#
#
# OG Orders left:  1939827
# Cascade length:  1826
# New Orders left:  1938001
# making new cascade
#
#
# OG Orders left:  1938001
# Cascade length:  2045
# New Orders left:  1935956
# making new cascade
#
#
# OG Orders left:  1935956
# Cascade length:  1851
# New Orders left:  1934105
# making new cascade
#
#
# OG Orders left:  1934105
# Cascade length:  2144
# New Orders left:  1931961
# making new cascade
#
#
# OG Orders left:  1931961
# Cascade length:  1114
# New Orders left:  1930847
# making new cascade
#
#
# OG Orders left:  1930847
# Cascade length:  1587
# New Orders left:  1929260
# making new cascade
#
#
# OG Orders left:  1929260
# Cascade length:  1896
# New Orders left:  1927364
# making new cascade
#
#
# OG Orders left:  1927364
# Cascade length:  1852
# New Orders left:  1925512
# making new cascade
#
#
# OG Orders left:  1925512
# Cascade length:  1969
# New Orders left:  1923543
# making new cascade
#
#
# OG Orders left:  1923543
# Cascade length:  2266
# New Orders left:  1921277
# making new cascade
#
#
# OG Orders left:  1921277
# Cascade length:  2198
# New Orders left:  1919079
# making new cascade
#
#
# OG Orders left:  1919079
# Cascade length:  2562
# New Orders left:  1916517
# making new cascade
#
#
# OG Orders left:  1916517
# Cascade length:  1477
# New Orders left:  1915040
# making new cascade
#
#
# OG Orders left:  1915040
# Cascade length:  1385
# New Orders left:  1913655
# making new cascade
#
#
# OG Orders left:  1913655
# Cascade length:  2346
# New Orders left:  1911309
# making new cascade
#
#
# OG Orders left:  1911309
# Cascade length:  1637
# New Orders left:  1909672
# making new cascade
#
#
# OG Orders left:  1909672
# Cascade length:  2167
# New Orders left:  1907505
# making new cascade
#
#
# OG Orders left:  1907505
# Cascade length:  1807
# New Orders left:  1905698
# making new cascade
#
#
# OG Orders left:  1905698
# Cascade length:  1601
# New Orders left:  1904097
# making new cascade
#
#
# OG Orders left:  1904097
# Cascade length:  1764
# New Orders left:  1902333
# making new cascade
#
#
# OG Orders left:  1902333
# Cascade length:  1584
# New Orders left:  1900749
# making new cascade
#
#
# OG Orders left:  1900749
# Cascade length:  1700
# New Orders left:  1899049
# making new cascade
#
#
# OG Orders left:  1899049
# Cascade length:  1300
# New Orders left:  1897749
# making new cascade
#
#
# OG Orders left:  1897749
# Cascade length:  2068
# New Orders left:  1895681
# making new cascade
#
#
# OG Orders left:  1895681
# Cascade length:  1472
# New Orders left:  1894209
# making new cascade
#
#
# OG Orders left:  1894209
# Cascade length:  1461
# New Orders left:  1892748
# making new cascade
#
#
# OG Orders left:  1892748
# Cascade length:  1532
# New Orders left:  1891216
# making new cascade
#
#
# OG Orders left:  1891216
# Cascade length:  1243
# New Orders left:  1889973
# making new cascade
#
#
# OG Orders left:  1889973
# Cascade length:  1676
# New Orders left:  1888297
# making new cascade
#
#
# OG Orders left:  1888297
# Cascade length:  2191
# New Orders left:  1886106
# making new cascade
#
#
# OG Orders left:  1886106
# Cascade length:  1264
# New Orders left:  1884842
# making new cascade
#
#
# OG Orders left:  1884842
# Cascade length:  1705
# New Orders left:  1883137
# making new cascade
#
#
# OG Orders left:  1883137
# Cascade length:  1673
# New Orders left:  1881464
# making new cascade
#
#
# OG Orders left:  1881464
# Cascade length:  1773
# New Orders left:  1879691
# making new cascade
#
#
# OG Orders left:  1879691
# Cascade length:  2128
# New Orders left:  1877563
# making new cascade
#
#
# OG Orders left:  1877563
# Cascade length:  1498
# New Orders left:  1876065
# making new cascade
#
#
# OG Orders left:  1876065
# Cascade length:  1319
# New Orders left:  1874746
# making new cascade
#
#
# OG Orders left:  1874746
# Cascade length:  1253
# New Orders left:  1873493
# making new cascade
#
#
# OG Orders left:  1873493
# Cascade length:  1667
# New Orders left:  1871826
# making new cascade
#
#
# OG Orders left:  1871826
# Cascade length:  1511
# New Orders left:  1870315
# making new cascade
#
#
# OG Orders left:  1870315
# Cascade length:  1118
# New Orders left:  1869197
# making new cascade
#
#
# OG Orders left:  1869197
# Cascade length:  1356
# New Orders left:  1867841
# making new cascade
#
#
# OG Orders left:  1867841
# Cascade length:  783
# New Orders left:  1867058
# making new cascade
#
#
# OG Orders left:  1867058
# Cascade length:  1310
# New Orders left:  1865748
# making new cascade
#
#
# OG Orders left:  1865748
# Cascade length:  2162
# New Orders left:  1863586
# making new cascade
#
#
# OG Orders left:  1863586
# Cascade length:  1808
# New Orders left:  1861778
# making new cascade
#
#
# OG Orders left:  1861778
# Cascade length:  1998
# New Orders left:  1859780
# making new cascade
#
#
# OG Orders left:  1859780
# Cascade length:  1455
# New Orders left:  1858325
# making new cascade
#
#
# OG Orders left:  1858325
# Cascade length:  1687
# New Orders left:  1856638
# making new cascade
#
#
# OG Orders left:  1856638
# Cascade length:  1412
# New Orders left:  1855226
# making new cascade
#
#
# OG Orders left:  1855226
# Cascade length:  1387
# New Orders left:  1853839
# making new cascade
#
#
# OG Orders left:  1853839
# Cascade length:  1733
# New Orders left:  1852106
# making new cascade
#
#
# OG Orders left:  1852106
# Cascade length:  1655
# New Orders left:  1850451
# making new cascade
#
#
# OG Orders left:  1850451
# Cascade length:  1598
# New Orders left:  1848853
# making new cascade
#
#
# OG Orders left:  1848853
# Cascade length:  1254
# New Orders left:  1847599
# making new cascade
#
#
# OG Orders left:  1847599
# Cascade length:  1493
# New Orders left:  1846106
# making new cascade
#
#
# OG Orders left:  1846106
# Cascade length:  1790
# New Orders left:  1844316
# making new cascade
#
#
# OG Orders left:  1844316
# Cascade length:  1561
# New Orders left:  1842755
# making new cascade
#
#
# OG Orders left:  1842755
# Cascade length:  1972
# New Orders left:  1840783
# making new cascade
#
#
# OG Orders left:  1840783
# Cascade length:  1995
# New Orders left:  1838788
# making new cascade
#
#
# OG Orders left:  1838788
# Cascade length:  1953
# New Orders left:  1836835
# making new cascade
#
#
# OG Orders left:  1836835
# Cascade length:  2030
# New Orders left:  1834805
# making new cascade
#
#
# OG Orders left:  1834805
# Cascade length:  1715
# New Orders left:  1833090
# making new cascade
#
#
# OG Orders left:  1833090
# Cascade length:  1626
# New Orders left:  1831464
# making new cascade
#
#
# OG Orders left:  1831464
# Cascade length:  1861
# New Orders left:  1829603
# making new cascade
#
#
# OG Orders left:  1829603
# Cascade length:  1875
# New Orders left:  1827728
# making new cascade
#
#
# OG Orders left:  1827728
# Cascade length:  1781
# New Orders left:  1825947
# making new cascade
#
#
# OG Orders left:  1825947
# Cascade length:  51
# New Orders left:  1825896
# making new cascade
#
#
# OG Orders left:  1825896
# Cascade length:  1519
# New Orders left:  1824377
# making new cascade
#
#
# OG Orders left:  1824377
# Cascade length:  1269
# New Orders left:  1823108
# making new cascade
#
#
# OG Orders left:  1823108
# Cascade length:  1260
# New Orders left:  1821848
# making new cascade
#
#
# OG Orders left:  1821848
# Cascade length:  1709
# New Orders left:  1820139
# making new cascade
#
#
# OG Orders left:  1820139
# Cascade length:  2014
# New Orders left:  1818125
# making new cascade
#
#
# OG Orders left:  1818125
# Cascade length:  1685
# New Orders left:  1816440
# making new cascade
#
#
# OG Orders left:  1816440
# Cascade length:  1333
# New Orders left:  1815107
# making new cascade
#
#
# OG Orders left:  1815107
# Cascade length:  1422
# New Orders left:  1813685
# making new cascade
#
#
# OG Orders left:  1813685
# Cascade length:  1762
# New Orders left:  1811923
# making new cascade
#
#
# OG Orders left:  1811923
# Cascade length:  1821
# New Orders left:  1810102
# making new cascade
#
#
# OG Orders left:  1810102
# Cascade length:  2729
# New Orders left:  1807373
# making new cascade
#
#
# OG Orders left:  1807373
# Cascade length:  1593
# New Orders left:  1805780
# making new cascade
#
#
# OG Orders left:  1805780
# Cascade length:  1626
# New Orders left:  1804154
# making new cascade
#
#
# OG Orders left:  1804154
# Cascade length:  1672
# New Orders left:  1802482
# making new cascade
#
#
# OG Orders left:  1802482
# Cascade length:  1795
# New Orders left:  1800687
# making new cascade
#
#
# OG Orders left:  1800687
# Cascade length:  2217
# New Orders left:  1798470
# making new cascade
#
#
# OG Orders left:  1798470
# Cascade length:  1846
# New Orders left:  1796624
# making new cascade
#
#
# OG Orders left:  1796624
# Cascade length:  1902
# New Orders left:  1794722
# making new cascade
#
#
# OG Orders left:  1794722
# Cascade length:  1882
# New Orders left:  1792840
# making new cascade
#
#
# OG Orders left:  1792840
# Cascade length:  1544
# New Orders left:  1791296
# making new cascade
#
#
# OG Orders left:  1791296
# Cascade length:  1781
# New Orders left:  1789515
# making new cascade
#
#
# OG Orders left:  1789515
# Cascade length:  2295
# New Orders left:  1787220
# making new cascade
#
#
# OG Orders left:  1787220
# Cascade length:  1636
# New Orders left:  1785584
# making new cascade
#
#
# OG Orders left:  1785584
# Cascade length:  1805
# New Orders left:  1783779
# making new cascade
#
#
# OG Orders left:  1783779
# Cascade length:  1749
# New Orders left:  1782030
# making new cascade
#
#
# OG Orders left:  1782030
# Cascade length:  1957
# New Orders left:  1780073
# making new cascade
#
#
# OG Orders left:  1780073
# Cascade length:  1768
# New Orders left:  1778305
# making new cascade
#
#
# OG Orders left:  1778305
# Cascade length:  1933
# New Orders left:  1776372
# making new cascade
#
#
# OG Orders left:  1776372
# Cascade length:  2687
# New Orders left:  1773685
# making new cascade
#
#
# OG Orders left:  1773685
# Cascade length:  1801
# New Orders left:  1771884
# making new cascade
#
#
# OG Orders left:  1771884
# Cascade length:  1737
# New Orders left:  1770147
# making new cascade
#
#
# OG Orders left:  1770147
# Cascade length:  1771
# New Orders left:  1768376
# making new cascade
#
#
# OG Orders left:  1768376
# Cascade length:  2620
# New Orders left:  1765756
# making new cascade
#
#
# OG Orders left:  1765756
# Cascade length:  1737
# New Orders left:  1764019
# making new cascade
#
#
# OG Orders left:  1764019
# Cascade length:  1737
# New Orders left:  1762282
# making new cascade
#
#
# OG Orders left:  1762282
# Cascade length:  2015
# New Orders left:  1760267
# making new cascade
#
#
# OG Orders left:  1760267
# Cascade length:  1748
# New Orders left:  1758519
# making new cascade
#
#
# OG Orders left:  1758519
# Cascade length:  2095
# New Orders left:  1756424
# making new cascade
#
#
# OG Orders left:  1756424
# Cascade length:  2118
# New Orders left:  1754306
# making new cascade
#
#
# OG Orders left:  1754306
# Cascade length:  1447
# New Orders left:  1752859
# making new cascade
#
#
# OG Orders left:  1752859
# Cascade length:  2358
# New Orders left:  1750501
# making new cascade
#
#
# OG Orders left:  1750501
# Cascade length:  1852
# New Orders left:  1748649
# making new cascade
#
#
# OG Orders left:  1748649
# Cascade length:  1526
# New Orders left:  1747123
# making new cascade
#
#
# OG Orders left:  1747123
# Cascade length:  2
# New Orders left:  1747121
# making new cascade
#
#
# OG Orders left:  1747121
# Cascade length:  1955
# New Orders left:  1745166
# making new cascade
#
#
# OG Orders left:  1745166
# Cascade length:  2098
# New Orders left:  1743068
# making new cascade
#
#
# OG Orders left:  1743068
# Cascade length:  2406
# New Orders left:  1740662
# making new cascade
#
#
# OG Orders left:  1740662
# Cascade length:  1848
# New Orders left:  1738814
# making new cascade
#
#
# OG Orders left:  1738814
# Cascade length:  2250
# New Orders left:  1736564
# making new cascade
#
#
# OG Orders left:  1736564
# Cascade length:  2326
# New Orders left:  1734238
# making new cascade
#
#
# OG Orders left:  1734238
# Cascade length:  237
# New Orders left:  1734001
# making new cascade
#
#
# OG Orders left:  1734001
# Cascade length:  3152
# New Orders left:  1730849
# making new cascade
#
#
# OG Orders left:  1730849
# Cascade length:  2590
# New Orders left:  1728259
# making new cascade
#
#
# OG Orders left:  1728259
# Cascade length:  2813
# New Orders left:  1725446
# making new cascade
#
#
# OG Orders left:  1725446
# Cascade length:  1979
# New Orders left:  1723467
# making new cascade
#
#
# OG Orders left:  1723467
# Cascade length:  2096
# New Orders left:  1721371
# making new cascade
#
#
# OG Orders left:  1721371
# Cascade length:  1774
# New Orders left:  1719597
# making new cascade
#
#
# OG Orders left:  1719597
# Cascade length:  1464
# New Orders left:  1718133
# making new cascade
#
#
# OG Orders left:  1718133
# Cascade length:  2234
# New Orders left:  1715899
# making new cascade
#
#
# OG Orders left:  1715899
# Cascade length:  2832
# New Orders left:  1713067
# making new cascade
#
#
# OG Orders left:  1713067
# Cascade length:  2896
# New Orders left:  1710171
# making new cascade
#
#
# OG Orders left:  1710171
# Cascade length:  2151
# New Orders left:  1708020
# making new cascade
#
#
# OG Orders left:  1708020
# Cascade length:  1987
# New Orders left:  1706033
# making new cascade
#
#
# OG Orders left:  1706033
# Cascade length:  1
# New Orders left:  1706032
# making new cascade
#
#
# OG Orders left:  1706032
# Cascade length:  1940
# New Orders left:  1704092
# making new cascade
#
#
# OG Orders left:  1704092
# Cascade length:  2297
# New Orders left:  1701795
# making new cascade
#
#
# OG Orders left:  1701795
# Cascade length:  3048
# New Orders left:  1698747
# making new cascade
#
#
# OG Orders left:  1698747
# Cascade length:  2133
# New Orders left:  1696614
# making new cascade
#
#
# OG Orders left:  1696614
# Cascade length:  2071
# New Orders left:  1694543
# making new cascade
#
#
# OG Orders left:  1694543
# Cascade length:  1908
# New Orders left:  1692635
# making new cascade
#
#
# OG Orders left:  1692635
# Cascade length:  2699
# New Orders left:  1689936
# making new cascade
#
#
# OG Orders left:  1689936
# Cascade length:  2186
# New Orders left:  1687750
# making new cascade
#
#
# OG Orders left:  1687750
# Cascade length:  2233
# New Orders left:  1685517
# making new cascade
#
#
# OG Orders left:  1685517
# Cascade length:  1940
# New Orders left:  1683577
# making new cascade
#
#
# OG Orders left:  1683577
# Cascade length:  1644
# New Orders left:  1681933
# making new cascade
#
#
# OG Orders left:  1681933
# Cascade length:  1917
# New Orders left:  1680016
# making new cascade
#
#
# OG Orders left:  1680016
# Cascade length:  2311
# New Orders left:  1677705
# making new cascade
#
#
# OG Orders left:  1677705
# Cascade length:  3335
# New Orders left:  1674370
# making new cascade
#
#
# OG Orders left:  1674370
# Cascade length:  2326
# New Orders left:  1672044
# making new cascade
#
#
# OG Orders left:  1672044
# Cascade length:  2590
# New Orders left:  1669454
# making new cascade
#
#
# OG Orders left:  1669454
# Cascade length:  1872
# New Orders left:  1667582
# making new cascade
#
#
# OG Orders left:  1667582
# Cascade length:  2774
# New Orders left:  1664808
# making new cascade
#
#
# OG Orders left:  1664808
# Cascade length:  1811
# New Orders left:  1662997
# making new cascade
#
#
# OG Orders left:  1662997
# Cascade length:  1222
# New Orders left:  1661775
# making new cascade
#
#
# OG Orders left:  1661775
# Cascade length:  2019
# New Orders left:  1659756
# making new cascade
#
#
# OG Orders left:  1659756
# Cascade length:  1964
# New Orders left:  1657792
# making new cascade
#
#
# OG Orders left:  1657792
# Cascade length:  3436
# New Orders left:  1654356
# making new cascade
#
#
# OG Orders left:  1654356
# Cascade length:  2036
# New Orders left:  1652320
# making new cascade
#
#
# OG Orders left:  1652320
# Cascade length:  1793
# New Orders left:  1650527
# making new cascade
#
#
# OG Orders left:  1650527
# Cascade length:  2062
# New Orders left:  1648465
# making new cascade
#
#
# OG Orders left:  1648465
# Cascade length:  2645
# New Orders left:  1645820
# making new cascade
#
#
# OG Orders left:  1645820
# Cascade length:  2293
# New Orders left:  1643527
# making new cascade
#
#
# OG Orders left:  1643527
# Cascade length:  2692
# New Orders left:  1640835
# making new cascade
#
#
# OG Orders left:  1640835
# Cascade length:  2054
# New Orders left:  1638781
# making new cascade
#
#
# OG Orders left:  1638781
# Cascade length:  2260
# New Orders left:  1636521
# making new cascade
#
#
# OG Orders left:  1636521
# Cascade length:  1896
# New Orders left:  1634625
# making new cascade
#
#
# OG Orders left:  1634625
# Cascade length:  2684
# New Orders left:  1631941
# making new cascade
#
#
# OG Orders left:  1631941
# Cascade length:  1980
# New Orders left:  1629961
# making new cascade
#
#
# OG Orders left:  1629961
# Cascade length:  2421
# New Orders left:  1627540
# making new cascade
#
#
# OG Orders left:  1627540
# Cascade length:  2847
# New Orders left:  1624693
# making new cascade
#
#
# OG Orders left:  1624693
# Cascade length:  3223
# New Orders left:  1621470
# making new cascade
#
#
# OG Orders left:  1621470
# Cascade length:  2698
# New Orders left:  1618772
# making new cascade
#
#
# OG Orders left:  1618772
# Cascade length:  2355
# New Orders left:  1616417
# making new cascade
#
#
# OG Orders left:  1616417
# Cascade length:  2638
# New Orders left:  1613779
# making new cascade
#
#
# OG Orders left:  1613779
# Cascade length:  2375
# New Orders left:  1611404
# making new cascade
#
#
# OG Orders left:  1611404
# Cascade length:  3338
# New Orders left:  1608066
# making new cascade
#
#
# OG Orders left:  1608066
# Cascade length:  1479
# New Orders left:  1606587
# making new cascade
#
#
# OG Orders left:  1606587
# Cascade length:  2338
# New Orders left:  1604249
# making new cascade
#
#
# OG Orders left:  1604249
# Cascade length:  2525
# New Orders left:  1601724
# making new cascade
#
#
# OG Orders left:  1601724
# Cascade length:  2400
# New Orders left:  1599324
# making new cascade
#
#
# OG Orders left:  1599324
# Cascade length:  1774
# New Orders left:  1597550
# making new cascade
#
#
# OG Orders left:  1597550
# Cascade length:  1908
# New Orders left:  1595642
# making new cascade
#
#
# OG Orders left:  1595642
# Cascade length:  1888
# New Orders left:  1593754
# making new cascade
#
#
# OG Orders left:  1593754
# Cascade length:  1809
# New Orders left:  1591945
# making new cascade
#
#
# OG Orders left:  1591945
# Cascade length:  2315
# New Orders left:  1589630
# making new cascade
#
#
# OG Orders left:  1589630
# Cascade length:  2116
# New Orders left:  1587514
# making new cascade
#
#
# OG Orders left:  1587514
# Cascade length:  2642
# New Orders left:  1584872
# making new cascade
#
#
# OG Orders left:  1584872
# Cascade length:  2265
# New Orders left:  1582607
# making new cascade
#
#
# OG Orders left:  1582607
# Cascade length:  2306
# New Orders left:  1580301
# making new cascade
#
#
# OG Orders left:  1580301
# Cascade length:  2538
# New Orders left:  1577763
# making new cascade
#
#
# OG Orders left:  1577763
# Cascade length:  1691
# New Orders left:  1576072
# making new cascade
#
#
# OG Orders left:  1576072
# Cascade length:  2165
# New Orders left:  1573907
# making new cascade
#
#
# OG Orders left:  1573907
# Cascade length:  2285
# New Orders left:  1571622
# making new cascade
#
#
# OG Orders left:  1571622
# Cascade length:  2348
# New Orders left:  1569274
# making new cascade
#
#
# OG Orders left:  1569274
# Cascade length:  2527
# New Orders left:  1566747
# making new cascade
#
#
# OG Orders left:  1566747
# Cascade length:  2082
# New Orders left:  1564665
# making new cascade
#
#
# OG Orders left:  1564665
# Cascade length:  2567
# New Orders left:  1562098
# making new cascade
#
#
# OG Orders left:  1562098
# Cascade length:  1820
# New Orders left:  1560278
# making new cascade
#
#
# OG Orders left:  1560278
# Cascade length:  2263
# New Orders left:  1558015
# making new cascade
#
#
# OG Orders left:  1558015
# Cascade length:  2083
# New Orders left:  1555932
# making new cascade
#
#
# OG Orders left:  1555932
# Cascade length:  2762
# New Orders left:  1553170
# making new cascade
#
#
# OG Orders left:  1553170
# Cascade length:  2082
# New Orders left:  1551088
# making new cascade
#
#
# OG Orders left:  1551088
# Cascade length:  2341
# New Orders left:  1548747
# making new cascade
#
#
# OG Orders left:  1548747
# Cascade length:  2346
# New Orders left:  1546401
# making new cascade
#
#
# OG Orders left:  1546401
# Cascade length:  1260
# New Orders left:  1545141
# making new cascade
#
#
# OG Orders left:  1545141
# Cascade length:  1587
# New Orders left:  1543554
# making new cascade
#
#
# OG Orders left:  1543554
# Cascade length:  2380
# New Orders left:  1541174
# making new cascade
#
#
# OG Orders left:  1541174
# Cascade length:  1707
# New Orders left:  1539467
# making new cascade
#
#
# OG Orders left:  1539467
# Cascade length:  1628
# New Orders left:  1537839
# making new cascade
#
#
# OG Orders left:  1537839
# Cascade length:  2089
# New Orders left:  1535750
# making new cascade
#
#
# OG Orders left:  1535750
# Cascade length:  1675
# New Orders left:  1534075
# making new cascade
#
#
# OG Orders left:  1534075
# Cascade length:  2003
# New Orders left:  1532072
# making new cascade
#
#
# OG Orders left:  1532072
# Cascade length:  1442
# New Orders left:  1530630
# making new cascade
#
#
# OG Orders left:  1530630
# Cascade length:  1492
# New Orders left:  1529138
# making new cascade
#
#
# OG Orders left:  1529138
# Cascade length:  2176
# New Orders left:  1526962
# making new cascade
#
#
# OG Orders left:  1526962
# Cascade length:  1505
# New Orders left:  1525457
# making new cascade
#
#
# OG Orders left:  1525457
# Cascade length:  1727
# New Orders left:  1523730
# making new cascade
#
#
# OG Orders left:  1523730
# Cascade length:  2618
# New Orders left:  1521112
# making new cascade
#
#
# OG Orders left:  1521112
# Cascade length:  1631
# New Orders left:  1519481
# making new cascade
#
#
# OG Orders left:  1519481
# Cascade length:  1393
# New Orders left:  1518088
# making new cascade
#
#
# OG Orders left:  1518088
# Cascade length:  1359
# New Orders left:  1516729
# making new cascade
#
#
# OG Orders left:  1516729
# Cascade length:  1845
# New Orders left:  1514884
# making new cascade
#
#
# OG Orders left:  1514884
# Cascade length:  1600
# New Orders left:  1513284
# making new cascade
#
#
# OG Orders left:  1513284
# Cascade length:  1699
# New Orders left:  1511585
# making new cascade
#
#
# OG Orders left:  1511585
# Cascade length:  1933
# New Orders left:  1509652
# making new cascade
#
#
# OG Orders left:  1509652
# Cascade length:  1406
# New Orders left:  1508246
# making new cascade
#
#
# OG Orders left:  1508246
# Cascade length:  1398
# New Orders left:  1506848
# making new cascade
#
#
# OG Orders left:  1506848
# Cascade length:  1738
# New Orders left:  1505110
# making new cascade
#
#
# OG Orders left:  1505110
# Cascade length:  2065
# New Orders left:  1503045
# making new cascade
#
#
# OG Orders left:  1503045
# Cascade length:  1604
# New Orders left:  1501441
# making new cascade
#
#
# OG Orders left:  1501441
# Cascade length:  2281
# New Orders left:  1499160
# making new cascade
#
#
# OG Orders left:  1499160
# Cascade length:  1644
# New Orders left:  1497516
# making new cascade
#
#
# OG Orders left:  1497516
# Cascade length:  1
# New Orders left:  1497515
# making new cascade
#
#
# OG Orders left:  1497515
# Cascade length:  1818
# New Orders left:  1495697
# making new cascade
#
#
# OG Orders left:  1495697
# Cascade length:  2333
# New Orders left:  1493364
# making new cascade
#
#
# OG Orders left:  1493364
# Cascade length:  2133
# New Orders left:  1491231
# making new cascade
#
#
# OG Orders left:  1491231
# Cascade length:  2515
# New Orders left:  1488716
# making new cascade
#
#
# OG Orders left:  1488716
# Cascade length:  1825
# New Orders left:  1486891
# making new cascade
#
#
# OG Orders left:  1486891
# Cascade length:  2294
# New Orders left:  1484597
# making new cascade
#
#
# OG Orders left:  1484597
# Cascade length:  1
# New Orders left:  1484596
# making new cascade
#
#
# OG Orders left:  1484596
# Cascade length:  2403
# New Orders left:  1482193
# making new cascade
#
#
# OG Orders left:  1482193
# Cascade length:  2139
# New Orders left:  1480054
# making new cascade
#
#
# OG Orders left:  1480054
# Cascade length:  1
# New Orders left:  1480053
# making new cascade
#
#
# OG Orders left:  1480053
# Cascade length:  1906
# New Orders left:  1478147
# making new cascade
#
#
# OG Orders left:  1478147
# Cascade length:  1682
# New Orders left:  1476465
# making new cascade
#
#
# OG Orders left:  1476465
# Cascade length:  1728
# New Orders left:  1474737
# making new cascade
#
#
# OG Orders left:  1474737
# Cascade length:  1939
# New Orders left:  1472798
# making new cascade
#
#
# OG Orders left:  1472798
# Cascade length:  2012
# New Orders left:  1470786
# making new cascade
#
#
# OG Orders left:  1470786
# Cascade length:  3196
# New Orders left:  1467590
# making new cascade
#
#
# OG Orders left:  1467590
# Cascade length:  2524
# New Orders left:  1465066
# making new cascade
#
#
# OG Orders left:  1465066
# Cascade length:  1734
# New Orders left:  1463332
# making new cascade
#
#
# OG Orders left:  1463332
# Cascade length:  2155
# New Orders left:  1461177
# making new cascade
#
#
# OG Orders left:  1461177
# Cascade length:  2682
# New Orders left:  1458495
# making new cascade
#
#
# OG Orders left:  1458495
# Cascade length:  2250
# New Orders left:  1456245
# making new cascade
#
#
# OG Orders left:  1456245
# Cascade length:  2530
# New Orders left:  1453715
# making new cascade
#
#
# OG Orders left:  1453715
# Cascade length:  1349
# New Orders left:  1452366
# making new cascade
#
#
# OG Orders left:  1452366
# Cascade length:  2209
# New Orders left:  1450157
# making new cascade
#
#
# OG Orders left:  1450157
# Cascade length:  3213
# New Orders left:  1446944
# making new cascade
#
#
# OG Orders left:  1446944
# Cascade length:  1467
# New Orders left:  1445477
# making new cascade
#
#
# OG Orders left:  1445477
# Cascade length:  1523
# New Orders left:  1443954
# making new cascade
#
#
# OG Orders left:  1443954
# Cascade length:  2425
# New Orders left:  1441529
# making new cascade
#
#
# OG Orders left:  1441529
# Cascade length:  1
# New Orders left:  1441528
# making new cascade
#
#
# OG Orders left:  1441528
# Cascade length:  2
# New Orders left:  1441526
# making new cascade
#
#
# OG Orders left:  1441526
# Cascade length:  1671
# New Orders left:  1439855
# making new cascade
#
#
# OG Orders left:  1439855
# Cascade length:  2081
# New Orders left:  1437774
# making new cascade
#
#
# OG Orders left:  1437774
# Cascade length:  2361
# New Orders left:  1435413
# making new cascade
#
#
# OG Orders left:  1435413
# Cascade length:  2366
# New Orders left:  1433047
# making new cascade
#
#
# OG Orders left:  1433047
# Cascade length:  2072
# New Orders left:  1430975
# making new cascade
#
#
# OG Orders left:  1430975
# Cascade length:  1514
# New Orders left:  1429461
# making new cascade
#
#
# OG Orders left:  1429461
# Cascade length:  1119
# New Orders left:  1428342
# making new cascade
#
#
# OG Orders left:  1428342
# Cascade length:  1841
# New Orders left:  1426501
# making new cascade
#
#
# OG Orders left:  1426501
# Cascade length:  2350
# New Orders left:  1424151
# making new cascade
#
#
# OG Orders left:  1424151
# Cascade length:  1910
# New Orders left:  1422241
# making new cascade
#
#
# OG Orders left:  1422241
# Cascade length:  1739
# New Orders left:  1420502
# making new cascade
#
#
# OG Orders left:  1420502
# Cascade length:  2142
# New Orders left:  1418360
# making new cascade
#
#
# OG Orders left:  1418360
# Cascade length:  2397
# New Orders left:  1415963
# making new cascade
#
#
# OG Orders left:  1415963
# Cascade length:  2628
# New Orders left:  1413335
# making new cascade
#
#
# OG Orders left:  1413335
# Cascade length:  1257
# New Orders left:  1412078
# making new cascade
#
#
# OG Orders left:  1412078
# Cascade length:  2634
# New Orders left:  1409444
# making new cascade
#
#
# OG Orders left:  1409444
# Cascade length:  2484
# New Orders left:  1406960
# making new cascade
#
#
# OG Orders left:  1406960
# Cascade length:  2448
# New Orders left:  1404512
# making new cascade
#
#
# OG Orders left:  1404512
# Cascade length:  2132
# New Orders left:  1402380
# making new cascade
#
#
# OG Orders left:  1402380
# Cascade length:  3375
# New Orders left:  1399005
# making new cascade
#
#
# OG Orders left:  1399005
# Cascade length:  2034
# New Orders left:  1396971
# making new cascade
#
#
# OG Orders left:  1396971
# Cascade length:  2948
# New Orders left:  1394023
# making new cascade
#
#
# OG Orders left:  1394023
# Cascade length:  2242
# New Orders left:  1391781
# making new cascade
#
#
# OG Orders left:  1391781
# Cascade length:  2164
# New Orders left:  1389617
# making new cascade
#
#
# OG Orders left:  1389617
# Cascade length:  2509
# New Orders left:  1387108
# making new cascade
#
#
# OG Orders left:  1387108
# Cascade length:  1318
# New Orders left:  1385790
# making new cascade
#
#
# OG Orders left:  1385790
# Cascade length:  1
# New Orders left:  1385789
# making new cascade
#
#
# OG Orders left:  1385789
# Cascade length:  2343
# New Orders left:  1383446
# making new cascade
#
#
# OG Orders left:  1383446
# Cascade length:  1496
# New Orders left:  1381950
# making new cascade
#
#
# OG Orders left:  1381950
# Cascade length:  2007
# New Orders left:  1379943
# making new cascade
#
#
# OG Orders left:  1379943
# Cascade length:  2009
# New Orders left:  1377934
# making new cascade
#
#
# OG Orders left:  1377934
# Cascade length:  2305
# New Orders left:  1375629
# making new cascade
#
#
# OG Orders left:  1375629
# Cascade length:  2509
# New Orders left:  1373120
# making new cascade
#
#
# OG Orders left:  1373120
# Cascade length:  1696
# New Orders left:  1371424
# making new cascade
#
#
# OG Orders left:  1371424
# Cascade length:  1771
# New Orders left:  1369653
# making new cascade
#
#
# OG Orders left:  1369653
# Cascade length:  3199
# New Orders left:  1366454
# making new cascade
#
#
# OG Orders left:  1366454
# Cascade length:  3249
# New Orders left:  1363205
# making new cascade
#
#
# OG Orders left:  1363205
# Cascade length:  3117
# New Orders left:  1360088
# making new cascade
#
#
# OG Orders left:  1360088
# Cascade length:  2
# New Orders left:  1360086
# making new cascade
#
#
# OG Orders left:  1360086
# Cascade length:  25
# New Orders left:  1360061
# making new cascade
#
#
# OG Orders left:  1360061
# Cascade length:  2459
# New Orders left:  1357602
# making new cascade
#
#
# OG Orders left:  1357602
# Cascade length:  1
# New Orders left:  1357601
# making new cascade
#
#
# OG Orders left:  1357601
# Cascade length:  2426
# New Orders left:  1355175
# making new cascade
#
#
# OG Orders left:  1355175
# Cascade length:  3066
# New Orders left:  1352109
# making new cascade
#
#
# OG Orders left:  1352109
# Cascade length:  2152
# New Orders left:  1349957
# making new cascade
#
#
# OG Orders left:  1349957
# Cascade length:  3034
# New Orders left:  1346923
# making new cascade
#
#
# OG Orders left:  1346923
# Cascade length:  1667
# New Orders left:  1345256
# making new cascade
#
#
# OG Orders left:  1345256
# Cascade length:  2526
# New Orders left:  1342730
# making new cascade
#
#
# OG Orders left:  1342730
# Cascade length:  2766
# New Orders left:  1339964
# making new cascade
#
#
# OG Orders left:  1339964
# Cascade length:  2124
# New Orders left:  1337840
# making new cascade
#
#
# OG Orders left:  1337840
# Cascade length:  2461
# New Orders left:  1335379
# making new cascade
#
#
# OG Orders left:  1335379
# Cascade length:  2663
# New Orders left:  1332716
# making new cascade
#
#
# OG Orders left:  1332716
# Cascade length:  2812
# New Orders left:  1329904
# making new cascade
#
#
# OG Orders left:  1329904
# Cascade length:  2391
# New Orders left:  1327513
# making new cascade
#
#
# OG Orders left:  1327513
# Cascade length:  2464
# New Orders left:  1325049
# making new cascade
#
#
# OG Orders left:  1325049
# Cascade length:  1934
# New Orders left:  1323115
# making new cascade
#
#
# OG Orders left:  1323115
# Cascade length:  1579
# New Orders left:  1321536
# making new cascade
#
#
# OG Orders left:  1321536
# Cascade length:  1825
# New Orders left:  1319711
# making new cascade
#
#
# OG Orders left:  1319711
# Cascade length:  2281
# New Orders left:  1317430
# making new cascade
#
#
# OG Orders left:  1317430
# Cascade length:  2506
# New Orders left:  1314924
# making new cascade
#
#
# OG Orders left:  1314924
# Cascade length:  3412
# New Orders left:  1311512
# making new cascade
#
#
# OG Orders left:  1311512
# Cascade length:  2155
# New Orders left:  1309357
# making new cascade
#
#
# OG Orders left:  1309357
# Cascade length:  2
# New Orders left:  1309355
# making new cascade
#
#
# OG Orders left:  1309355
# Cascade length:  2567
# New Orders left:  1306788
# making new cascade
#
#
# OG Orders left:  1306788
# Cascade length:  2461
# New Orders left:  1304327
# making new cascade
#
#
# OG Orders left:  1304327
# Cascade length:  1890
# New Orders left:  1302437
# making new cascade
#
#
# OG Orders left:  1302437
# Cascade length:  1703
# New Orders left:  1300734
# making new cascade
#
#
# OG Orders left:  1300734
# Cascade length:  1925
# New Orders left:  1298809
# making new cascade
#
#
# OG Orders left:  1298809
# Cascade length:  2500
# New Orders left:  1296309
# making new cascade
#
#
# OG Orders left:  1296309
# Cascade length:  1702
# New Orders left:  1294607
# making new cascade
#
#
# OG Orders left:  1294607
# Cascade length:  2399
# New Orders left:  1292208
# making new cascade
#
#
# OG Orders left:  1292208
# Cascade length:  1645
# New Orders left:  1290563
# making new cascade
#
#
# OG Orders left:  1290563
# Cascade length:  2091
# New Orders left:  1288472
# making new cascade
#
#
# OG Orders left:  1288472
# Cascade length:  6
# New Orders left:  1288466
# making new cascade
#
#
# OG Orders left:  1288466
# Cascade length:  1505
# New Orders left:  1286961
# making new cascade
#
#
# OG Orders left:  1286961
# Cascade length:  1558
# New Orders left:  1285403
# making new cascade
#
#
# OG Orders left:  1285403
# Cascade length:  1489
# New Orders left:  1283914
# making new cascade
#
#
# OG Orders left:  1283914
# Cascade length:  2479
# New Orders left:  1281435
# making new cascade
#
#
# OG Orders left:  1281435
# Cascade length:  2702
# New Orders left:  1278733
# making new cascade
#
#
# OG Orders left:  1278733
# Cascade length:  1797
# New Orders left:  1276936
# making new cascade
#
#
# OG Orders left:  1276936
# Cascade length:  2118
# New Orders left:  1274818
# making new cascade
#
#
# OG Orders left:  1274818
# Cascade length:  2557
# New Orders left:  1272261
# making new cascade
#
#
# OG Orders left:  1272261
# Cascade length:  2686
# New Orders left:  1269575
# making new cascade
#
#
# OG Orders left:  1269575
# Cascade length:  2369
# New Orders left:  1267206
# making new cascade
#
#
# OG Orders left:  1267206
# Cascade length:  2109
# New Orders left:  1265097
# making new cascade
#
#
# OG Orders left:  1265097
# Cascade length:  2184
# New Orders left:  1262913
# making new cascade
#
#
# OG Orders left:  1262913
# Cascade length:  1983
# New Orders left:  1260930
# making new cascade
#
#
# OG Orders left:  1260930
# Cascade length:  2031
# New Orders left:  1258899
# making new cascade
#
#
# OG Orders left:  1258899
# Cascade length:  1585
# New Orders left:  1257314
# making new cascade
#
#
# OG Orders left:  1257314
# Cascade length:  1559
# New Orders left:  1255755
# making new cascade
#
#
# OG Orders left:  1255755
# Cascade length:  2970
# New Orders left:  1252785
# making new cascade
#
#
# OG Orders left:  1252785
# Cascade length:  1912
# New Orders left:  1250873
# making new cascade
#
#
# OG Orders left:  1250873
# Cascade length:  1658
# New Orders left:  1249215
# making new cascade
#
#
# OG Orders left:  1249215
# Cascade length:  1374
# New Orders left:  1247841
# making new cascade
#
#
# OG Orders left:  1247841
# Cascade length:  1629
# New Orders left:  1246212
# making new cascade
#
#
# OG Orders left:  1246212
# Cascade length:  2057
# New Orders left:  1244155
# making new cascade
#
#
# OG Orders left:  1244155
# Cascade length:  2044
# New Orders left:  1242111
# making new cascade
#
#
# OG Orders left:  1242111
# Cascade length:  1913
# New Orders left:  1240198
# making new cascade
#
#
# OG Orders left:  1240198
# Cascade length:  2029
# New Orders left:  1238169
# making new cascade
#
#
# OG Orders left:  1238169
# Cascade length:  2913
# New Orders left:  1235256
# making new cascade
#
#
# OG Orders left:  1235256
# Cascade length:  1817
# New Orders left:  1233439
# making new cascade
#
#
# OG Orders left:  1233439
# Cascade length:  1902
# New Orders left:  1231537
# making new cascade
#
#
# OG Orders left:  1231537
# Cascade length:  2230
# New Orders left:  1229307
# making new cascade
#
#
# OG Orders left:  1229307
# Cascade length:  1814
# New Orders left:  1227493
# making new cascade
#
#
# OG Orders left:  1227493
# Cascade length:  1610
# New Orders left:  1225883
# making new cascade
#
#
# OG Orders left:  1225883
# Cascade length:  3342
# New Orders left:  1222541
# making new cascade
#
#
# OG Orders left:  1222541
# Cascade length:  1334
# New Orders left:  1221207
# making new cascade
#
#
# OG Orders left:  1221207
# Cascade length:  1884
# New Orders left:  1219323
# making new cascade
#
#
# OG Orders left:  1219323
# Cascade length:  1913
# New Orders left:  1217410
# making new cascade
#
#
# OG Orders left:  1217410
# Cascade length:  1986
# New Orders left:  1215424
# making new cascade
#
#
# OG Orders left:  1215424
# Cascade length:  1703
# New Orders left:  1213721
# making new cascade
#
#
# OG Orders left:  1213721
# Cascade length:  1605
# New Orders left:  1212116
# making new cascade
#
#
# OG Orders left:  1212116
# Cascade length:  2572
# New Orders left:  1209544
# making new cascade
#
#
# OG Orders left:  1209544
# Cascade length:  2220
# New Orders left:  1207324
# making new cascade
#
#
# OG Orders left:  1207324
# Cascade length:  2304
# New Orders left:  1205020
# making new cascade
#
#
# OG Orders left:  1205020
# Cascade length:  2331
# New Orders left:  1202689
# making new cascade
#
#
# OG Orders left:  1202689
# Cascade length:  519
# New Orders left:  1202170
# making new cascade
#
#
# OG Orders left:  1202170
# Cascade length:  12
# New Orders left:  1202158
# making new cascade
#
#
# OG Orders left:  1202158
# Cascade length:  1440
# New Orders left:  1200718
# making new cascade
#
#
# OG Orders left:  1200718
# Cascade length:  1814
# New Orders left:  1198904
# making new cascade
#
#
# OG Orders left:  1198904
# Cascade length:  2074
# New Orders left:  1196830
# making new cascade
#
#
# OG Orders left:  1196830
# Cascade length:  1981
# New Orders left:  1194849
# making new cascade
#
#
# OG Orders left:  1194849
# Cascade length:  1885
# New Orders left:  1192964
# making new cascade
#
#
# OG Orders left:  1192964
# Cascade length:  933
# New Orders left:  1192031
# making new cascade
#
#
# OG Orders left:  1192031
# Cascade length:  2001
# New Orders left:  1190030
# making new cascade
#
#
# OG Orders left:  1190030
# Cascade length:  97
# New Orders left:  1189933
# making new cascade
#
#
# OG Orders left:  1189933
# Cascade length:  2210
# New Orders left:  1187723
# making new cascade
#
#
# OG Orders left:  1187723
# Cascade length:  2292
# New Orders left:  1185431
# making new cascade
#
#
# OG Orders left:  1185431
# Cascade length:  3005
# New Orders left:  1182426
# making new cascade
#
#
# OG Orders left:  1182426
# Cascade length:  1156
# New Orders left:  1181270
# making new cascade
#
#
# OG Orders left:  1181270
# Cascade length:  12
# New Orders left:  1181258
# making new cascade
#
#
# OG Orders left:  1181258
# Cascade length:  2694
# New Orders left:  1178564
# making new cascade
#
#
# OG Orders left:  1178564
# Cascade length:  1623
# New Orders left:  1176941
# making new cascade
#
#
# OG Orders left:  1176941
# Cascade length:  2415
# New Orders left:  1174526
# making new cascade
#
#
# OG Orders left:  1174526
# Cascade length:  26
# New Orders left:  1174500
# making new cascade
#
#
# OG Orders left:  1174500
# Cascade length:  1869
# New Orders left:  1172631
# making new cascade
#
#
# OG Orders left:  1172631
# Cascade length:  1506
# New Orders left:  1171125
# making new cascade
#
#
# OG Orders left:  1171125
# Cascade length:  2170
# New Orders left:  1168955
# making new cascade
#
#
# OG Orders left:  1168955
# Cascade length:  1985
# New Orders left:  1166970
# making new cascade
#
#
# OG Orders left:  1166970
# Cascade length:  1589
# New Orders left:  1165381
# making new cascade
#
#
# OG Orders left:  1165381
# Cascade length:  1986
# New Orders left:  1163395
# making new cascade
#
#
# OG Orders left:  1163395
# Cascade length:  1454
# New Orders left:  1161941
# making new cascade
#
#
# OG Orders left:  1161941
# Cascade length:  2305
# New Orders left:  1159636
# making new cascade
#
#
# OG Orders left:  1159636
# Cascade length:  1
# New Orders left:  1159635
# making new cascade
#
#
# OG Orders left:  1159635
# Cascade length:  1819
# New Orders left:  1157816
# making new cascade
#
#
# OG Orders left:  1157816
# Cascade length:  1916
# New Orders left:  1155900
# making new cascade
#
#
# OG Orders left:  1155900
# Cascade length:  1308
# New Orders left:  1154592
# making new cascade
#
#
# OG Orders left:  1154592
# Cascade length:  2112
# New Orders left:  1152480
# making new cascade
#
#
# OG Orders left:  1152480
# Cascade length:  2114
# New Orders left:  1150366
# making new cascade
#
#
# OG Orders left:  1150366
# Cascade length:  2165
# New Orders left:  1148201
# making new cascade
#
#
# ...
#
#
# OG Orders left:  282576
# Cascade length:  2398
# New Orders left:  280178
# making new cascade
#
#
# OG Orders left:  280178
# Cascade length:  1721
# New Orders left:  278457
# making new cascade
#
#
# OG Orders left:  278457
# Cascade length:  2110
# New Orders left:  276347
# making new cascade
#
#
# OG Orders left:  276347
# Cascade length:  10
# New Orders left:  276337
# making new cascade
#
#
# OG Orders left:  276337
# Cascade length:  2230
# New Orders left:  274107
# making new cascade
#
#
# OG Orders left:  274107
# Cascade length:  2780
# New Orders left:  271327
# making new cascade
#
#
# OG Orders left:  271327
# Cascade length:  7
# New Orders left:  271320
# making new cascade
#
#
# OG Orders left:  271320
# Cascade length:  1826
# New Orders left:  269494
# making new cascade
#
#
# OG Orders left:  269494
# Cascade length:  1471
# New Orders left:  268023
# making new cascade
#
#
# OG Orders left:  268023
# Cascade length:  3019
# New Orders left:  265004
# making new cascade
#
#
# OG Orders left:  265004
# Cascade length:  1752
# New Orders left:  263252
# making new cascade
#
#
# OG Orders left:  263252
# Cascade length:  4
# New Orders left:  263248
# making new cascade
#
#
# OG Orders left:  263248
# Cascade length:  1576
# New Orders left:  261672
# making new cascade
#
#
# OG Orders left:  261672
# Cascade length:  234
# New Orders left:  261438
# making new cascade
#
#
# OG Orders left:  261438
# Cascade length:  1779
# New Orders left:  259659
# making new cascade
#
#
# OG Orders left:  259659
# Cascade length:  3692
# New Orders left:  255967
# making new cascade
#
#
# OG Orders left:  255967
# Cascade length:  3257
# New Orders left:  252710
# making new cascade
#
#
# OG Orders left:  252710
# Cascade length:  2236
# New Orders left:  250474
# making new cascade
#
#
# OG Orders left:  250474
# Cascade length:  1
# New Orders left:  250473
# making new cascade
#
#
# OG Orders left:  250473
# Cascade length:  1736
# New Orders left:  248737
# making new cascade
#
#
# OG Orders left:  248737
# Cascade length:  1888
# New Orders left:  246849
# making new cascade
#
#
# OG Orders left:  246849
# Cascade length:  2174
# New Orders left:  244675
# making new cascade
#
#
# OG Orders left:  244675
# Cascade length:  12
# New Orders left:  244663
# making new cascade
#
#
# OG Orders left:  244663
# Cascade length:  3222
# New Orders left:  241441
# making new cascade
#
#
# OG Orders left:  241441
# Cascade length:  2514
# New Orders left:  238927
# making new cascade
#
#
# OG Orders left:  238927
# Cascade length:  2402
# New Orders left:  236525
# making new cascade
#
#
# OG Orders left:  236525
# Cascade length:  1795
# New Orders left:  234730
# making new cascade
#
#
# OG Orders left:  234730
# Cascade length:  2329
# New Orders left:  232401
# making new cascade
#
#
# OG Orders left:  232401
# Cascade length:  2304
# New Orders left:  230097
# making new cascade
#
#
# OG Orders left:  230097
# Cascade length:  2667
# New Orders left:  227430
# making new cascade
#
#
# OG Orders left:  227430
# Cascade length:  2968
# New Orders left:  224462
# making new cascade
#
#
# OG Orders left:  224462
# Cascade length:  2090
# New Orders left:  222372
# making new cascade
#
#
# OG Orders left:  222372
# Cascade length:  2897
# New Orders left:  219475
# making new cascade
#
#
# OG Orders left:  219475
# Cascade length:  1688
# New Orders left:  217787
# making new cascade
#
#
# OG Orders left:  217787
# Cascade length:  1579
# New Orders left:  216208
# making new cascade
#
#
# OG Orders left:  216208
# Cascade length:  2551
# New Orders left:  213657
# making new cascade
#
#
# OG Orders left:  213657
# Cascade length:  2651
# New Orders left:  211006
# making new cascade
#
#
# OG Orders left:  211006
# Cascade length:  2809
# New Orders left:  208197
# making new cascade
#
#
# OG Orders left:  208197
# Cascade length:  3329
# New Orders left:  204868
# making new cascade
#
#
# OG Orders left:  204868
# Cascade length:  2082
# New Orders left:  202786
# making new cascade
#
#
# OG Orders left:  202786
# Cascade length:  2622
# New Orders left:  200164
# making new cascade
#
#
# OG Orders left:  200164
# Cascade length:  2502
# New Orders left:  197662
# making new cascade
#
#
# OG Orders left:  197662
# Cascade length:  2579
# New Orders left:  195083
# making new cascade
#
#
# OG Orders left:  195083
# Cascade length:  1888
# New Orders left:  193195
# making new cascade
#
#
# OG Orders left:  193195
# Cascade length:  2284
# New Orders left:  190911
# making new cascade
#
#
# OG Orders left:  190911
# Cascade length:  2443
# New Orders left:  188468
# making new cascade
#
#
# OG Orders left:  188468
# Cascade length:  2366
# New Orders left:  186102
# making new cascade
#
#
# OG Orders left:  186102
# Cascade length:  3157
# New Orders left:  182945
# making new cascade
#
#
# OG Orders left:  182945
# Cascade length:  3497
# New Orders left:  179448
# making new cascade
#
#
# OG Orders left:  179448
# Cascade length:  2813
# New Orders left:  176635
# making new cascade
#
#
# OG Orders left:  176635
# Cascade length:  2226
# New Orders left:  174409
# making new cascade
#
#
# OG Orders left:  174409
# Cascade length:  2050
# New Orders left:  172359
# making new cascade
#
#
# OG Orders left:  172359
# Cascade length:  1922
# New Orders left:  170437
# making new cascade
#
#
# OG Orders left:  170437
# Cascade length:  1953
# New Orders left:  168484
# making new cascade
#
#
# OG Orders left:  168484
# Cascade length:  1778
# New Orders left:  166706
# making new cascade
#
#
# OG Orders left:  166706
# Cascade length:  1512
# New Orders left:  165194
# making new cascade
#
#
# OG Orders left:  165194
# Cascade length:  1817
# New Orders left:  163377
# making new cascade
#
#
# OG Orders left:  163377
# Cascade length:  1442
# New Orders left:  161935
# making new cascade
#
#
# OG Orders left:  161935
# Cascade length:  1745
# New Orders left:  160190
# making new cascade
#
#
# OG Orders left:  160190
# Cascade length:  24
# New Orders left:  160166
# making new cascade
#
#
# OG Orders left:  160166
# Cascade length:  1863
# New Orders left:  158303
# making new cascade
#
#
# OG Orders left:  158303
# Cascade length:  1934
# New Orders left:  156369
# making new cascade
#
#
# OG Orders left:  156369
# Cascade length:  2129
# New Orders left:  154240
# making new cascade
#
#
# OG Orders left:  154240
# Cascade length:  1746
# New Orders left:  152494
# making new cascade
#
#
# OG Orders left:  152494
# Cascade length:  1474
# New Orders left:  151020
# making new cascade
#
#
# OG Orders left:  151020
# Cascade length:  1867
# New Orders left:  149153
# making new cascade
#
#
# OG Orders left:  149153
# Cascade length:  2403
# New Orders left:  146750
# making new cascade
#
#
# OG Orders left:  146750
# Cascade length:  1973
# New Orders left:  144777
# making new cascade
#
#
# OG Orders left:  144777
# Cascade length:  2776
# New Orders left:  142001
# making new cascade
#
#
# OG Orders left:  142001
# Cascade length:  2219
# New Orders left:  139782
# making new cascade
#
#
# OG Orders left:  139782
# Cascade length:  3138
# New Orders left:  136644
# making new cascade
#
#
# OG Orders left:  136644
# Cascade length:  1545
# New Orders left:  135099
# making new cascade
#
#
# OG Orders left:  135099
# Cascade length:  1777
# New Orders left:  133322
# making new cascade
#
#
# OG Orders left:  133322
# Cascade length:  1541
# New Orders left:  131781
# making new cascade
#
#
# OG Orders left:  131781
# Cascade length:  1781
# New Orders left:  130000
# making new cascade
#
#
# OG Orders left:  130000
# Cascade length:  1472
# New Orders left:  128528
# making new cascade
#
#
# OG Orders left:  128528
# Cascade length:  1915
# New Orders left:  126613
# making new cascade
#
#
# OG Orders left:  126613
# Cascade length:  1710
# New Orders left:  124903
# making new cascade
#
#
# OG Orders left:  124903
# Cascade length:  2463
# New Orders left:  122440
# making new cascade
#
#
# OG Orders left:  122440
# Cascade length:  2004
# New Orders left:  120436
# making new cascade
#
#
# OG Orders left:  120436
# Cascade length:  2329
# New Orders left:  118107
# making new cascade
#
#
# OG Orders left:  118107
# Cascade length:  1795
# New Orders left:  116312
# making new cascade
#
#
# OG Orders left:  116312
# Cascade length:  1786
# New Orders left:  114526
# making new cascade
#
#
# OG Orders left:  114526
# Cascade length:  1889
# New Orders left:  112637
# making new cascade
#
#
# OG Orders left:  112637
# Cascade length:  1798
# New Orders left:  110839
# making new cascade
#
#
# OG Orders left:  110839
# Cascade length:  2169
# New Orders left:  108670
# making new cascade
#
#
# OG Orders left:  108670
# Cascade length:  2869
# New Orders left:  105801
# making new cascade
#
#
# OG Orders left:  105801
# Cascade length:  2095
# New Orders left:  103706
# making new cascade
#
#
# OG Orders left:  103706
# Cascade length:  1931
# New Orders left:  101775
# making new cascade
#
#
# OG Orders left:  101775
# Cascade length:  1691
# New Orders left:  100084
# making new cascade
#
#
# OG Orders left:  100084
# Cascade length:  1870
# New Orders left:  98214
# making new cascade
#
#
# OG Orders left:  98214
# Cascade length:  1164
# New Orders left:  97050
# making new cascade
#
#
# OG Orders left:  97050
# Cascade length:  2309
# New Orders left:  94741
# making new cascade
#
#
# OG Orders left:  94741
# Cascade length:  1936
# New Orders left:  92805
# making new cascade
#
#
# OG Orders left:  92805
# Cascade length:  2041
# New Orders left:  90764
# making new cascade
#
#
# OG Orders left:  90764
# Cascade length:  1947
# New Orders left:  88817
# making new cascade
#
#
# OG Orders left:  88817
# Cascade length:  2276
# New Orders left:  86541
# making new cascade
#
#
# OG Orders left:  86541
# Cascade length:  2311
# New Orders left:  84230
# making new cascade
#
#
# OG Orders left:  84230
# Cascade length:  2017
# New Orders left:  82213
# making new cascade
#
#
# OG Orders left:  82213
# Cascade length:  1840
# New Orders left:  80373
# making new cascade
#
#
# OG Orders left:  80373
# Cascade length:  1750
# New Orders left:  78623
# making new cascade
#
#
# OG Orders left:  78623
# Cascade length:  1419
# New Orders left:  77204
# making new cascade
#
#
# OG Orders left:  77204
# Cascade length:  1687
# New Orders left:  75517
# making new cascade
#
#
# OG Orders left:  75517
# Cascade length:  1580
# New Orders left:  73937
# making new cascade
#
#
# OG Orders left:  73937
# Cascade length:  1821
# New Orders left:  72116
# making new cascade
#
#
# OG Orders left:  72116
# Cascade length:  2315
# New Orders left:  69801
# making new cascade
#
#
# OG Orders left:  69801
# Cascade length:  2161
# New Orders left:  67640
# making new cascade
#
#
# OG Orders left:  67640
# Cascade length:  1654
# New Orders left:  65986
# making new cascade
#
#
# OG Orders left:  65986
# Cascade length:  1888
# New Orders left:  64098
# making new cascade
#
#
# OG Orders left:  64098
# Cascade length:  1745
# New Orders left:  62353
# making new cascade
#
#
# OG Orders left:  62353
# Cascade length:  1616
# New Orders left:  60737
# making new cascade
#
#
# OG Orders left:  60737
# Cascade length:  1512
# New Orders left:  59225
# making new cascade
#
#
# OG Orders left:  59225
# Cascade length:  1373
# New Orders left:  57852
# making new cascade
#
#
# OG Orders left:  57852
# Cascade length:  1844
# New Orders left:  56008
# making new cascade
#
#
# OG Orders left:  56008
# Cascade length:  1616
# New Orders left:  54392
# making new cascade
#
#
# OG Orders left:  54392
# Cascade length:  1663
# New Orders left:  52729
# making new cascade
#
#
# OG Orders left:  52729
# Cascade length:  1726
# New Orders left:  51003
# making new cascade
#
#
# OG Orders left:  51003
# Cascade length:  1522
# New Orders left:  49481
# making new cascade
#
#
# OG Orders left:  49481
# Cascade length:  1811
# New Orders left:  47670
# making new cascade
#
#
# OG Orders left:  47670
# Cascade length:  1488
# New Orders left:  46182
# making new cascade
#
#
# OG Orders left:  46182
# Cascade length:  1390
# New Orders left:  44792
# making new cascade
#
#
# OG Orders left:  44792
# Cascade length:  1328
# New Orders left:  43464
# making new cascade
#
#
# OG Orders left:  43464
# Cascade length:  1891
# New Orders left:  41573
# making new cascade
#
#
# OG Orders left:  41573
# Cascade length:  1849
# New Orders left:  39724
# making new cascade
#
#
# OG Orders left:  39724
# Cascade length:  1427
# New Orders left:  38297
# making new cascade
#
#
# OG Orders left:  38297
# Cascade length:  1492
# New Orders left:  36805
# making new cascade
#
#
# OG Orders left:  36805
# Cascade length:  1350
# New Orders left:  35455
# making new cascade
#
#
# OG Orders left:  35455
# Cascade length:  1181
# New Orders left:  34274
# making new cascade
#
#
# OG Orders left:  34274
# Cascade length:  1372
# New Orders left:  32902
# making new cascade
#
#
# OG Orders left:  32902
# Cascade length:  1274
# New Orders left:  31628
# making new cascade
#
#
# OG Orders left:  31628
# Cascade length:  1337
# New Orders left:  30291
# making new cascade
#
#
# OG Orders left:  30291
# Cascade length:  1303
# New Orders left:  28988
# making new cascade
#
#
# OG Orders left:  28988
# Cascade length:  1375
# New Orders left:  27613
# making new cascade
#
#
# OG Orders left:  27613
# Cascade length:  1313
# New Orders left:  26300
# making new cascade
#
#
# OG Orders left:  26300
# Cascade length:  1070
# New Orders left:  25230
# making new cascade
#
#
# OG Orders left:  25230
# Cascade length:  1198
# New Orders left:  24032
# making new cascade
#
#
# OG Orders left:  24032
# Cascade length:  975
# New Orders left:  23057
# making new cascade
#
#
# OG Orders left:  23057
# Cascade length:  1278
# New Orders left:  21779
# making new cascade
#
#
# OG Orders left:  21779
# Cascade length:  1030
# New Orders left:  20749
# making new cascade
#
#
# OG Orders left:  20749
# Cascade length:  1022
# New Orders left:  19727
# making new cascade
#
#
# OG Orders left:  19727
# Cascade length:  1549
# New Orders left:  18178
# making new cascade
#
#
# OG Orders left:  18178
# Cascade length:  1116
# New Orders left:  17062
# making new cascade
#
#
# OG Orders left:  17062
# Cascade length:  925
# New Orders left:  16137
# making new cascade
#
#
# OG Orders left:  16137
# Cascade length:  1078
# New Orders left:  15059
# making new cascade
#
#
# OG Orders left:  15059
# Cascade length:  761
# New Orders left:  14298
# making new cascade
#
#
# OG Orders left:  14298
# Cascade length:  716
# New Orders left:  13582
# making new cascade
#
#
# OG Orders left:  13582
# Cascade length:  1078
# New Orders left:  12504
# making new cascade
#
#
# OG Orders left:  12504
# Cascade length:  813
# New Orders left:  11691
# making new cascade
#
#
# OG Orders left:  11691
# Cascade length:  825
# New Orders left:  10866
# making new cascade
#
#
# OG Orders left:  10866
# Cascade length:  901
# New Orders left:  9965
# making new cascade
#
#
# OG Orders left:  9965
# Cascade length:  706
# New Orders left:  9259
# making new cascade
#
#
# OG Orders left:  9259
# Cascade length:  827
# New Orders left:  8432
# making new cascade
#
#
# OG Orders left:  8432
# Cascade length:  647
# New Orders left:  7785
# making new cascade
#
#
# OG Orders left:  7785
# Cascade length:  556
# New Orders left:  7229
# making new cascade
#
#
# OG Orders left:  7229
# Cascade length:  564
# New Orders left:  6665
# making new cascade
#
#
# OG Orders left:  6665
# Cascade length:  655
# New Orders left:  6010
# making new cascade
#
#
# OG Orders left:  6010
# Cascade length:  419
# New Orders left:  5591
# making new cascade
#
#
# OG Orders left:  5591
# Cascade length:  468
# New Orders left:  5123
# making new cascade
#
#
# OG Orders left:  5123
# Cascade length:  584
# New Orders left:  4539
# making new cascade
#
#
# OG Orders left:  4539
# Cascade length:  445
# New Orders left:  4094
# making new cascade
#
#
# OG Orders left:  4094
# Cascade length:  443
# New Orders left:  3651
# making new cascade
#
#
# OG Orders left:  3651
# Cascade length:  395
# New Orders left:  3256
# making new cascade
#
#
# OG Orders left:  3256
# Cascade length:  433
# New Orders left:  2823
# making new cascade
#
#
# OG Orders left:  2823
# Cascade length:  329
# New Orders left:  2494
# making new cascade
#
#
# OG Orders left:  2494
# Cascade length:  289
# New Orders left:  2205
# making new cascade
#
#
# OG Orders left:  2205
# Cascade length:  293
# New Orders left:  1912
# making new cascade
#
#
# OG Orders left:  1912
# Cascade length:  276
# New Orders left:  1636
# making new cascade
#
#
# OG Orders left:  1636
# Cascade length:  252
# New Orders left:  1384
# making new cascade
#
#
# OG Orders left:  1384
# Cascade length:  271
# New Orders left:  1113
# making new cascade
#
#
# OG Orders left:  1113
# Cascade length:  182
# New Orders left:  931
# making new cascade
#
#
# OG Orders left:  931
# Cascade length:  151
# New Orders left:  780
# making new cascade
#
#
# OG Orders left:  780
# Cascade length:  224
# New Orders left:  556
# making new cascade
#
#
# OG Orders left:  556
# Cascade length:  187
# New Orders left:  369
# making new cascade
#
#
# OG Orders left:  369
# Cascade length:  165
# New Orders left:  204
# making new cascade
#
#
# OG Orders left:  204
# Cascade length:  93
# New Orders left:  111
# making new cascade
#
#
# OG Orders left:  111
# Cascade length:  99
# New Orders left:  12
# making new cascade
#
#
# OG Orders left:  12
# Cascade length:  12
# New Orders left:  0
# making new cascade

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades12_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades/7-9/causalCascades11_npc_200_7200_100_10_20.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_200_7200_100_10_20_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_200_7200_100_10_20_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_200_7200_100_10_20_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*5, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
