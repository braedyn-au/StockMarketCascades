# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_501_7200_100_new2threshold_fixedhurst.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_501_7200_100_new2threshold_fixedhurst.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_501_7200_100_new2threshold_fixedhurst.npy")
TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_501_7200_100_new2threshold_fixedhurst.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_501_7200_100_new2threshold_fixedhurst.csv")

# %%
stockPoolNPC
# Out:
# array([[ 72.55414369,  72.48367366,  72.47786107, ...,  66.82550373,
#          66.8285822 ,  66.8585096 ],
#        [104.33222419, 104.34219096, 104.32046457, ..., 108.87035173,
#         108.86176565, 108.87133131],
#        [116.05218282, 116.08652872, 116.08156016, ..., 116.6607796 ,
#         116.70596924, 116.7359867 ],
#        ...,
#        [143.21525733, 143.22492891, 143.23949963, ..., 136.57049724,
#         136.57849312, 136.6003628 ],
#        [158.96062396, 158.98705745, 158.96772299, ..., 155.95960512,
#         155.96488109, 155.97398614],
#        [154.83140691, 154.8555005 , 154.83411908, ..., 150.79705719,
#         150.80035857, 150.82433182]])

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 1)

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_79o501p7200s100t_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15)*8, '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_79o501p7200s100t_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*5, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_79o501p7200s100t_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC,993, 8192, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.1), '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_79o501p7200s100t_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_79o501p7200s100t_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15)*3, '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_79o501p7200s100t_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_79o501p7200s100t_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*4, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_79o501p7200s100t_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.1)*6, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_79o501p7200s100t_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC,993, 8192, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-0.9), '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_79o501p7200s100t_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-0.9), '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_79o501p7200s100t_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*1, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_79o501p7200s100t_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    TtotalOrders = TtotalOrdersNPC
    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0, tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
# causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
# npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC)
# Out:
# OG Orders left:  7088505

# %%
# causalCascades21 = cascades.findCascades(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 1)
# npcsizes21, npcnrows21, npcduration21 = cascades.cascadeAnalyzer(causalCascades21, stockPoolNPC)

# %%
# causalCascades21 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 1)
# npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades21_npc79o501p72000s100t.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades12_npc79o501p7200s100t.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  7088505
# Cascade length:  34426
# New Orders left:  7054079
# making new cascade
#
#
# OG Orders left:  7054079
# Cascade length:  25156
# New Orders left:  7028923
# making new cascade
#
#
# OG Orders left:  7028923
# Cascade length:  23658
# New Orders left:  7005265
# making new cascade
#
#
# OG Orders left:  7005265
# Cascade length:  22643
# New Orders left:  6982622
# making new cascade
#
#
# OG Orders left:  6982622
# Cascade length:  24078
# New Orders left:  6958544
# making new cascade
#
#
# OG Orders left:  6958544
# Cascade length:  20899
# New Orders left:  6937645
# making new cascade
#
#
# OG Orders left:  6937645
# Cascade length:  19359
# New Orders left:  6918286
# making new cascade
#
#
# OG Orders left:  6918286
# Cascade length:  3
# New Orders left:  6918283
# making new cascade
#
#
# OG Orders left:  6918283
# Cascade length:  2
# New Orders left:  6918281
# making new cascade
#
#
# OG Orders left:  6918281
# Cascade length:  20545
# New Orders left:  6897736
# making new cascade
#
#
# OG Orders left:  6897736
# Cascade length:  12
# New Orders left:  6897724
# making new cascade
#
#
# OG Orders left:  6897724
# Cascade length:  13783
# New Orders left:  6883941
# making new cascade
#
#
# OG Orders left:  6883941
# Cascade length:  7948
# New Orders left:  6875993
# making new cascade
#
#
# OG Orders left:  6875993
# Cascade length:  13542
# New Orders left:  6862451
# making new cascade
#
#
# OG Orders left:  6862451
# Cascade length:  10855
# New Orders left:  6851596
# making new cascade
#
#
# OG Orders left:  6851596
# Cascade length:  11500
# New Orders left:  6840096
# making new cascade
#
#
# OG Orders left:  6840096
# Cascade length:  8894
# New Orders left:  6831202
# making new cascade
#
#
# OG Orders left:  6831202
# Cascade length:  7385
# New Orders left:  6823817
# making new cascade
#
#
# OG Orders left:  6823817
# Cascade length:  9
# New Orders left:  6823808
# making new cascade
#
#
# OG Orders left:  6823808
# Cascade length:  13326
# New Orders left:  6810482
# making new cascade
#
#
# OG Orders left:  6810482
# Cascade length:  6558
# New Orders left:  6803924
# making new cascade
#
#
# OG Orders left:  6803924
# Cascade length:  6821
# New Orders left:  6797103
# making new cascade
#
#
# OG Orders left:  6797103
# Cascade length:  7470
# New Orders left:  6789633
# making new cascade
#
#
# OG Orders left:  6789633
# Cascade length:  8
# New Orders left:  6789625
# making new cascade
#
#
# OG Orders left:  6789625
# Cascade length:  10385
# New Orders left:  6779240
# making new cascade
#
#
# OG Orders left:  6779240
# Cascade length:  7551
# New Orders left:  6771689
# making new cascade
#
#
# OG Orders left:  6771689
# Cascade length:  948
# New Orders left:  6770741
# making new cascade
#
#
# OG Orders left:  6770741
# Cascade length:  8404
# New Orders left:  6762337
# making new cascade
#
#
# OG Orders left:  6762337
# Cascade length:  7200
# New Orders left:  6755137
# making new cascade
#
#
# OG Orders left:  6755137
# Cascade length:  8251
# New Orders left:  6746886
# making new cascade
#
#
# OG Orders left:  6746886
# Cascade length:  9691
# New Orders left:  6737195
# making new cascade
#
#
# OG Orders left:  6737195
# Cascade length:  22
# New Orders left:  6737173
# making new cascade
#
#
# OG Orders left:  6737173
# Cascade length:  6669
# New Orders left:  6730504
# making new cascade
#
#
# OG Orders left:  6730504
# Cascade length:  6041
# New Orders left:  6724463
# making new cascade
#
#
# OG Orders left:  6724463
# Cascade length:  34
# New Orders left:  6724429
# making new cascade
#
#
# OG Orders left:  6724429
# Cascade length:  8960
# New Orders left:  6715469
# making new cascade
#
#
# OG Orders left:  6715469
# Cascade length:  7820
# New Orders left:  6707649
# making new cascade
#
#
# OG Orders left:  6707649
# Cascade length:  3905
# New Orders left:  6703744
# making new cascade
#
#
# OG Orders left:  6703744
# Cascade length:  5923
# New Orders left:  6697821
# making new cascade
#
#
# OG Orders left:  6697821
# Cascade length:  2
# New Orders left:  6697819
# making new cascade
#
#
# OG Orders left:  6697819
# Cascade length:  10183
# New Orders left:  6687636
# making new cascade
#
#
# OG Orders left:  6687636
# Cascade length:  11
# New Orders left:  6687625
# making new cascade
#
#
# OG Orders left:  6687625
# Cascade length:  8840
# New Orders left:  6678785
# making new cascade
#
#
# OG Orders left:  6678785
# Cascade length:  8993
# New Orders left:  6669792
# making new cascade
#
#
# OG Orders left:  6669792
# Cascade length:  7736
# New Orders left:  6662056
# making new cascade
#
#
# OG Orders left:  6662056
# Cascade length:  2558
# New Orders left:  6659498
# making new cascade
#
#
# OG Orders left:  6659498
# Cascade length:  8703
# New Orders left:  6650795
# making new cascade
#
#
# OG Orders left:  6650795
# Cascade length:  8858
# New Orders left:  6641937
# making new cascade
#
#
# OG Orders left:  6641937
# Cascade length:  11375
# New Orders left:  6630562
# making new cascade
#
#
# OG Orders left:  6630562
# Cascade length:  9974
# New Orders left:  6620588
# making new cascade
#
#
# OG Orders left:  6620588
# Cascade length:  4250
# New Orders left:  6616338
# making new cascade
#
#
# OG Orders left:  6616338
# Cascade length:  7
# New Orders left:  6616331
# making new cascade
#
#
# OG Orders left:  6616331
# Cascade length:  12
# New Orders left:  6616319
# making new cascade
#
#
# OG Orders left:  6616319
# Cascade length:  5606
# New Orders left:  6610713
# making new cascade
#
#
# OG Orders left:  6610713
# Cascade length:  5538
# New Orders left:  6605175
# making new cascade
#
#
# OG Orders left:  6605175
# Cascade length:  6589
# New Orders left:  6598586
# making new cascade
#
#
# OG Orders left:  6598586
# Cascade length:  8065
# New Orders left:  6590521
# making new cascade
#
#
# OG Orders left:  6590521
# Cascade length:  6166
# New Orders left:  6584355
# making new cascade
#
#
# OG Orders left:  6584355
# Cascade length:  3
# New Orders left:  6584352
# making new cascade
#
#
# OG Orders left:  6584352
# Cascade length:  7598
# New Orders left:  6576754
# making new cascade
#
#
# OG Orders left:  6576754
# Cascade length:  6510
# New Orders left:  6570244
# making new cascade
#
#
# OG Orders left:  6570244
# Cascade length:  5251
# New Orders left:  6564993
# making new cascade
#
#
# OG Orders left:  6564993
# Cascade length:  5370
# New Orders left:  6559623
# making new cascade
#
#
# OG Orders left:  6559623
# Cascade length:  4891
# New Orders left:  6554732
# making new cascade
#
#
# OG Orders left:  6554732
# Cascade length:  6
# New Orders left:  6554726
# making new cascade
#
#
# OG Orders left:  6554726
# Cascade length:  6213
# New Orders left:  6548513
# making new cascade
#
#
# OG Orders left:  6548513
# Cascade length:  6619
# New Orders left:  6541894
# making new cascade
#
#
# OG Orders left:  6541894
# Cascade length:  15
# New Orders left:  6541879
# making new cascade
#
#
# OG Orders left:  6541879
# Cascade length:  6
# New Orders left:  6541873
# making new cascade
#
#
# OG Orders left:  6541873
# Cascade length:  7034
# New Orders left:  6534839
# making new cascade
#
#
# OG Orders left:  6534839
# Cascade length:  6323
# New Orders left:  6528516
# making new cascade
#
#
# OG Orders left:  6528516
# Cascade length:  1422
# New Orders left:  6527094
# making new cascade
#
#
# OG Orders left:  6527094
# Cascade length:  9440
# New Orders left:  6517654
# making new cascade
#
#
# OG Orders left:  6517654
# Cascade length:  6196
# New Orders left:  6511458
# making new cascade
#
#
# OG Orders left:  6511458
# Cascade length:  12
# New Orders left:  6511446
# making new cascade
#
#
# OG Orders left:  6511446
# Cascade length:  5715
# New Orders left:  6505731
# making new cascade
#
#
# OG Orders left:  6505731
# Cascade length:  5405
# New Orders left:  6500326
# making new cascade
#
#
# OG Orders left:  6500326
# Cascade length:  4762
# New Orders left:  6495564
# making new cascade
#
#
# OG Orders left:  6495564
# Cascade length:  6032
# New Orders left:  6489532
# making new cascade
#
#
# OG Orders left:  6489532
# Cascade length:  6
# New Orders left:  6489526
# making new cascade
#
#
# OG Orders left:  6489526
# Cascade length:  5809
# New Orders left:  6483717
# making new cascade
#
#
# OG Orders left:  6483717
# Cascade length:  4318
# New Orders left:  6479399
# making new cascade
#
#
# OG Orders left:  6479399
# Cascade length:  6885
# New Orders left:  6472514
# making new cascade
#
#
# OG Orders left:  6472514
# Cascade length:  6194
# New Orders left:  6466320
# making new cascade
#
#
# OG Orders left:  6466320
# Cascade length:  6290
# New Orders left:  6460030
# making new cascade
#
#
# OG Orders left:  6460030
# Cascade length:  5539
# New Orders left:  6454491
# making new cascade
#
#
# OG Orders left:  6454491
# Cascade length:  7148
# New Orders left:  6447343
# making new cascade
#
#
# OG Orders left:  6447343
# Cascade length:  4408
# New Orders left:  6442935
# making new cascade
#
#
# OG Orders left:  6442935
# Cascade length:  4522
# New Orders left:  6438413
# making new cascade
#
#
# OG Orders left:  6438413
# Cascade length:  14
# New Orders left:  6438399
# making new cascade
#
#
# OG Orders left:  6438399
# Cascade length:  6690
# New Orders left:  6431709
# making new cascade
#
#
# OG Orders left:  6431709
# Cascade length:  5829
# New Orders left:  6425880
# making new cascade
#
#
# OG Orders left:  6425880
# Cascade length:  5401
# New Orders left:  6420479
# making new cascade
#
#
# OG Orders left:  6420479
# Cascade length:  5419
# New Orders left:  6415060
# making new cascade
#
#
# OG Orders left:  6415060
# Cascade length:  2
# New Orders left:  6415058
# making new cascade
#
#
# OG Orders left:  6415058
# Cascade length:  20
# New Orders left:  6415038
# making new cascade
#
#
# OG Orders left:  6415038
# Cascade length:  6771
# New Orders left:  6408267
# making new cascade
#
#
# OG Orders left:  6408267
# Cascade length:  38
# New Orders left:  6408229
# making new cascade
#
#
# OG Orders left:  6408229
# Cascade length:  5442
# New Orders left:  6402787
# making new cascade
#
#
# OG Orders left:  6402787
# Cascade length:  9068
# New Orders left:  6393719
# making new cascade
#
#
# OG Orders left:  6393719
# Cascade length:  1341
# New Orders left:  6392378
# making new cascade
#
#
# OG Orders left:  6392378
# Cascade length:  5746
# New Orders left:  6386632
# making new cascade
#
#
# OG Orders left:  6386632
# Cascade length:  3879
# New Orders left:  6382753
# making new cascade
#
#
# OG Orders left:  6382753
# Cascade length:  31
# New Orders left:  6382722
# making new cascade
#
#
# OG Orders left:  6382722
# Cascade length:  4670
# New Orders left:  6378052
# making new cascade
#
#
# OG Orders left:  6378052
# Cascade length:  6969
# New Orders left:  6371083
# making new cascade
#
#
# OG Orders left:  6371083
# Cascade length:  4
# New Orders left:  6371079
# making new cascade
#
#
# OG Orders left:  6371079
# Cascade length:  4614
# New Orders left:  6366465
# making new cascade
#
#
# OG Orders left:  6366465
# Cascade length:  3689
# New Orders left:  6362776
# making new cascade
#
#
# OG Orders left:  6362776
# Cascade length:  6830
# New Orders left:  6355946
# making new cascade
#
#
# OG Orders left:  6355946
# Cascade length:  8
# New Orders left:  6355938
# making new cascade
#
#
# OG Orders left:  6355938
# Cascade length:  5920
# New Orders left:  6350018
# making new cascade
#
#
# OG Orders left:  6350018
# Cascade length:  7
# New Orders left:  6350011
# making new cascade
#
#
# OG Orders left:  6350011
# Cascade length:  2
# New Orders left:  6350009
# making new cascade
#
#
# OG Orders left:  6350009
# Cascade length:  2316
# New Orders left:  6347693
# making new cascade
#
#
# OG Orders left:  6347693
# Cascade length:  5
# New Orders left:  6347688
# making new cascade
#
#
# OG Orders left:  6347688
# Cascade length:  4
# New Orders left:  6347684
# making new cascade
#
#
# OG Orders left:  6347684
# Cascade length:  6088
# New Orders left:  6341596
# making new cascade
#
#
# OG Orders left:  6341596
# Cascade length:  4751
# New Orders left:  6336845
# making new cascade
#
#
# OG Orders left:  6336845
# Cascade length:  5836
# New Orders left:  6331009
# making new cascade
#
#
# OG Orders left:  6331009
# Cascade length:  2
# New Orders left:  6331007
# making new cascade
#
#
# OG Orders left:  6331007
# Cascade length:  7489
# New Orders left:  6323518
# making new cascade
#
#
# OG Orders left:  6323518
# Cascade length:  5049
# New Orders left:  6318469
# making new cascade
#
#
# OG Orders left:  6318469
# Cascade length:  5
# New Orders left:  6318464
# making new cascade
#
#
# OG Orders left:  6318464
# Cascade length:  3458
# New Orders left:  6315006
# making new cascade
#
#
# OG Orders left:  6315006
# Cascade length:  12
# New Orders left:  6314994
# making new cascade
#
#
# OG Orders left:  6314994
# Cascade length:  6303
# New Orders left:  6308691
# making new cascade
#
#
# OG Orders left:  6308691
# Cascade length:  6
# New Orders left:  6308685
# making new cascade
#
#
# OG Orders left:  6308685
# Cascade length:  3877
# New Orders left:  6304808
# making new cascade
#
#
# OG Orders left:  6304808
# Cascade length:  7813
# New Orders left:  6296995
# making new cascade
#
#
# OG Orders left:  6296995
# Cascade length:  5603
# New Orders left:  6291392
# making new cascade
#
#
# OG Orders left:  6291392
# Cascade length:  14
# New Orders left:  6291378
# making new cascade
#
#
# OG Orders left:  6291378
# Cascade length:  1
# New Orders left:  6291377
# making new cascade
#
#
# OG Orders left:  6291377
# Cascade length:  1022
# New Orders left:  6290355
# making new cascade
#
#
# OG Orders left:  6290355
# Cascade length:  3153
# New Orders left:  6287202
# making new cascade
#
#
# OG Orders left:  6287202
# Cascade length:  5126
# New Orders left:  6282076
# making new cascade
#
#
# OG Orders left:  6282076
# Cascade length:  3962
# New Orders left:  6278114
# making new cascade
#
#
# OG Orders left:  6278114
# Cascade length:  5949
# New Orders left:  6272165
# making new cascade
#
#
# OG Orders left:  6272165
# Cascade length:  4380
# New Orders left:  6267785
# making new cascade
#
#
# OG Orders left:  6267785
# Cascade length:  7
# New Orders left:  6267778
# making new cascade
#
#
# OG Orders left:  6267778
# Cascade length:  3300
# New Orders left:  6264478
# making new cascade
#
#
# OG Orders left:  6264478
# Cascade length:  7097
# New Orders left:  6257381
# making new cascade
#
#
# OG Orders left:  6257381
# Cascade length:  10
# New Orders left:  6257371
# making new cascade
#
#
# OG Orders left:  6257371
# Cascade length:  4440
# New Orders left:  6252931
# making new cascade
#
#
# OG Orders left:  6252931
# Cascade length:  4450
# New Orders left:  6248481
# making new cascade
#
#
# OG Orders left:  6248481
# Cascade length:  4898
# New Orders left:  6243583
# making new cascade
#
#
# OG Orders left:  6243583
# Cascade length:  6
# New Orders left:  6243577
# making new cascade
#
#
# OG Orders left:  6243577
# Cascade length:  11
# New Orders left:  6243566
# making new cascade
#
#
# OG Orders left:  6243566
# Cascade length:  6532
# New Orders left:  6237034
# making new cascade
#
#
# OG Orders left:  6237034
# Cascade length:  6934
# New Orders left:  6230100
# making new cascade
#
#
# OG Orders left:  6230100
# Cascade length:  4
# New Orders left:  6230096
# making new cascade
#
#
# OG Orders left:  6230096
# Cascade length:  3498
# New Orders left:  6226598
# making new cascade
#
#
# OG Orders left:  6226598
# Cascade length:  2
# New Orders left:  6226596
# making new cascade
#
#
# OG Orders left:  6226596
# Cascade length:  2
# New Orders left:  6226594
# making new cascade
#
#
# OG Orders left:  6226594
# Cascade length:  15
# New Orders left:  6226579
# making new cascade
#
#
# OG Orders left:  6226579
# Cascade length:  2833
# New Orders left:  6223746
# making new cascade
#
#
# OG Orders left:  6223746
# Cascade length:  20
# New Orders left:  6223726
# making new cascade
#
#
# OG Orders left:  6223726
# Cascade length:  7204
# New Orders left:  6216522
# making new cascade
#
#
# OG Orders left:  6216522
# Cascade length:  5657
# New Orders left:  6210865
# making new cascade
#
#
# OG Orders left:  6210865
# Cascade length:  204
# New Orders left:  6210661
# making new cascade
#
#
# OG Orders left:  6210661
# Cascade length:  6
# New Orders left:  6210655
# making new cascade
#
#
# OG Orders left:  6210655
# Cascade length:  8952
# New Orders left:  6201703
# making new cascade
#
#
# OG Orders left:  6201703
# Cascade length:  2
# New Orders left:  6201701
# making new cascade
#
#
# OG Orders left:  6201701
# Cascade length:  10
# New Orders left:  6201691
# making new cascade
#
#
# OG Orders left:  6201691
# Cascade length:  12
# New Orders left:  6201679
# making new cascade
#
#
# OG Orders left:  6201679
# Cascade length:  4601
# New Orders left:  6197078
# making new cascade
#
#
# OG Orders left:  6197078
# Cascade length:  4837
# New Orders left:  6192241
# making new cascade
#
#
# OG Orders left:  6192241
# Cascade length:  2937
# New Orders left:  6189304
# making new cascade
#
#
# OG Orders left:  6189304
# Cascade length:  4685
# New Orders left:  6184619
# making new cascade
#
#
# OG Orders left:  6184619
# Cascade length:  6
# New Orders left:  6184613
# making new cascade
#
#
# OG Orders left:  6184613
# Cascade length:  82
# New Orders left:  6184531
# making new cascade
#
#
# OG Orders left:  6184531
# Cascade length:  6075
# New Orders left:  6178456
# making new cascade
#
#
# OG Orders left:  6178456
# Cascade length:  5166
# New Orders left:  6173290
# making new cascade
#
#
# OG Orders left:  6173290
# Cascade length:  6164
# New Orders left:  6167126
# making new cascade
#
#
# OG Orders left:  6167126
# Cascade length:  7
# New Orders left:  6167119
# making new cascade
#
#
# OG Orders left:  6167119
# Cascade length:  9
# New Orders left:  6167110
# making new cascade
#
#
# OG Orders left:  6167110
# Cascade length:  9073
# New Orders left:  6158037
# making new cascade
#
#
# OG Orders left:  6158037
# Cascade length:  9352
# New Orders left:  6148685
# making new cascade
#
#
# OG Orders left:  6148685
# Cascade length:  3345
# New Orders left:  6145340
# making new cascade
#
#
# OG Orders left:  6145340
# Cascade length:  3
# New Orders left:  6145337
# making new cascade
#
#
# OG Orders left:  6145337
# Cascade length:  9
# New Orders left:  6145328
# making new cascade
#
#
# OG Orders left:  6145328
# Cascade length:  3030
# New Orders left:  6142298
# making new cascade
#
#
# OG Orders left:  6142298
# Cascade length:  17
# New Orders left:  6142281
# making new cascade
#
#
# OG Orders left:  6142281
# Cascade length:  9
# New Orders left:  6142272
# making new cascade
#
#
# OG Orders left:  6142272
# Cascade length:  5571
# New Orders left:  6136701
# making new cascade
#
#
# OG Orders left:  6136701
# Cascade length:  68
# New Orders left:  6136633
# making new cascade
#
#
# OG Orders left:  6136633
# Cascade length:  3910
# New Orders left:  6132723
# making new cascade
#
#
# OG Orders left:  6132723
# Cascade length:  3135
# New Orders left:  6129588
# making new cascade
#
#
# OG Orders left:  6129588
# Cascade length:  10195
# New Orders left:  6119393
# making new cascade
#
#
# OG Orders left:  6119393
# Cascade length:  4414
# New Orders left:  6114979
# making new cascade
#
#
# OG Orders left:  6114979
# Cascade length:  4382
# New Orders left:  6110597
# making new cascade
#
#
# OG Orders left:  6110597
# Cascade length:  7
# New Orders left:  6110590
# making new cascade
#
#
# OG Orders left:  6110590
# Cascade length:  4
# New Orders left:  6110586
# making new cascade
#
#
# OG Orders left:  6110586
# Cascade length:  8098
# New Orders left:  6102488
# making new cascade
#
#
# OG Orders left:  6102488
# Cascade length:  3572
# New Orders left:  6098916
# making new cascade
#
#
# OG Orders left:  6098916
# Cascade length:  10
# New Orders left:  6098906
# making new cascade
#
#
# OG Orders left:  6098906
# Cascade length:  12
# New Orders left:  6098894
# making new cascade
#
#
# OG Orders left:  6098894
# Cascade length:  6
# New Orders left:  6098888
# making new cascade
#
#
# OG Orders left:  6098888
# Cascade length:  3818
# New Orders left:  6095070
# making new cascade
#
#
# OG Orders left:  6095070
# Cascade length:  6078
# New Orders left:  6088992
# making new cascade
#
#
# OG Orders left:  6088992
# Cascade length:  13
# New Orders left:  6088979
# making new cascade
#
#
# OG Orders left:  6088979
# Cascade length:  4490
# New Orders left:  6084489
# making new cascade
#
#
# OG Orders left:  6084489
# Cascade length:  6025
# New Orders left:  6078464
# making new cascade
#
#
# OG Orders left:  6078464
# Cascade length:  11
# New Orders left:  6078453
# making new cascade
#
#
# OG Orders left:  6078453
# Cascade length:  3213
# New Orders left:  6075240
# making new cascade
#
#
# OG Orders left:  6075240
# Cascade length:  7698
# New Orders left:  6067542
# making new cascade
#
#
# OG Orders left:  6067542
# Cascade length:  11
# New Orders left:  6067531
# making new cascade
#
#
# OG Orders left:  6067531
# Cascade length:  23
# New Orders left:  6067508
# making new cascade
#
#
# OG Orders left:  6067508
# Cascade length:  6416
# New Orders left:  6061092
# making new cascade
#
#
# OG Orders left:  6061092
# Cascade length:  6397
# New Orders left:  6054695
# making new cascade
#
#
# OG Orders left:  6054695
# Cascade length:  5759
# New Orders left:  6048936
# making new cascade
#
#
# OG Orders left:  6048936
# Cascade length:  3498
# New Orders left:  6045438
# making new cascade
#
#
# OG Orders left:  6045438
# Cascade length:  8942
# New Orders left:  6036496
# making new cascade
#
#
# OG Orders left:  6036496
# Cascade length:  2
# New Orders left:  6036494
# making new cascade
#
#
# OG Orders left:  6036494
# Cascade length:  5767
# New Orders left:  6030727
# making new cascade
#
#
# OG Orders left:  6030727
# Cascade length:  7293
# New Orders left:  6023434
# making new cascade
#
#
# OG Orders left:  6023434
# Cascade length:  6980
# New Orders left:  6016454
# making new cascade
#
#
# OG Orders left:  6016454
# Cascade length:  5713
# New Orders left:  6010741
# making new cascade
#
#
# OG Orders left:  6010741
# Cascade length:  4446
# New Orders left:  6006295
# making new cascade
#
#
# OG Orders left:  6006295
# Cascade length:  24
# New Orders left:  6006271
# making new cascade
#
#
# OG Orders left:  6006271
# Cascade length:  190
# New Orders left:  6006081
# making new cascade
#
#
# OG Orders left:  6006081
# Cascade length:  4703
# New Orders left:  6001378
# making new cascade
#
#
# OG Orders left:  6001378
# Cascade length:  8788
# New Orders left:  5992590
# making new cascade
#
#
# OG Orders left:  5992590
# Cascade length:  7198
# New Orders left:  5985392
# making new cascade
#
#
# OG Orders left:  5985392
# Cascade length:  9783
# New Orders left:  5975609
# making new cascade
#
#
# OG Orders left:  5975609
# Cascade length:  115
# New Orders left:  5975494
# making new cascade
#
#
# OG Orders left:  5975494
# Cascade length:  4205
# New Orders left:  5971289
# making new cascade
#
#
# OG Orders left:  5971289
# Cascade length:  12102
# New Orders left:  5959187
# making new cascade
#
#
# OG Orders left:  5959187
# Cascade length:  3815
# New Orders left:  5955372
# making new cascade
#
#
# OG Orders left:  5955372
# Cascade length:  3425
# New Orders left:  5951947
# making new cascade
#
#
# OG Orders left:  5951947
# Cascade length:  8168
# New Orders left:  5943779
# making new cascade
#
#
# OG Orders left:  5943779
# Cascade length:  4941
# New Orders left:  5938838
# making new cascade
#
#
# OG Orders left:  5938838
# Cascade length:  2997
# New Orders left:  5935841
# making new cascade
#
#
# OG Orders left:  5935841
# Cascade length:  5002
# New Orders left:  5930839
# making new cascade
#
#
# OG Orders left:  5930839
# Cascade length:  4
# New Orders left:  5930835
# making new cascade
#
#
# OG Orders left:  5930835
# Cascade length:  13
# New Orders left:  5930822
# making new cascade
#
#
# OG Orders left:  5930822
# Cascade length:  92
# New Orders left:  5930730
# making new cascade
#
#
# OG Orders left:  5930730
# Cascade length:  4095
# New Orders left:  5926635
# making new cascade
#
#
# OG Orders left:  5926635
# Cascade length:  9751
# New Orders left:  5916884
# making new cascade
#
#
# OG Orders left:  5916884
# Cascade length:  6362
# New Orders left:  5910522
# making new cascade
#
#
# OG Orders left:  5910522
# Cascade length:  9178
# New Orders left:  5901344
# making new cascade
#
#
# OG Orders left:  5901344
# Cascade length:  7283
# New Orders left:  5894061
# making new cascade
#
#
# OG Orders left:  5894061
# Cascade length:  6650
# New Orders left:  5887411
# making new cascade
#
#
# OG Orders left:  5887411
# Cascade length:  2489
# New Orders left:  5884922
# making new cascade
#
#
# OG Orders left:  5884922
# Cascade length:  2783
# New Orders left:  5882139
# making new cascade
#
#
# OG Orders left:  5882139
# Cascade length:  5457
# New Orders left:  5876682
# making new cascade
#
#
# OG Orders left:  5876682
# Cascade length:  6818
# New Orders left:  5869864
# making new cascade
#
#
# OG Orders left:  5869864
# Cascade length:  7402
# New Orders left:  5862462
# making new cascade
#
#
# OG Orders left:  5862462
# Cascade length:  4
# New Orders left:  5862458
# making new cascade
#
#
# OG Orders left:  5862458
# Cascade length:  5073
# New Orders left:  5857385
# making new cascade
#
#
# OG Orders left:  5857385
# Cascade length:  2
# New Orders left:  5857383
# making new cascade
#
#
# OG Orders left:  5857383
# Cascade length:  3448
# New Orders left:  5853935
# making new cascade
#
#
# OG Orders left:  5853935
# Cascade length:  6096
# New Orders left:  5847839
# making new cascade
#
#
# OG Orders left:  5847839
# Cascade length:  4
# New Orders left:  5847835
# making new cascade
#
#
# OG Orders left:  5847835
# Cascade length:  4145
# New Orders left:  5843690
# making new cascade
#
#
# OG Orders left:  5843690
# Cascade length:  9390
# New Orders left:  5834300
# making new cascade
#
#
# OG Orders left:  5834300
# Cascade length:  6279
# New Orders left:  5828021
# making new cascade
#
#
# OG Orders left:  5828021
# Cascade length:  4193
# New Orders left:  5823828
# making new cascade
#
#
# OG Orders left:  5823828
# Cascade length:  6203
# New Orders left:  5817625
# making new cascade
#
#
# OG Orders left:  5817625
# Cascade length:  25
# New Orders left:  5817600
# making new cascade
#
#
# OG Orders left:  5817600
# Cascade length:  2836
# New Orders left:  5814764
# making new cascade
#
#
# OG Orders left:  5814764
# Cascade length:  3
# New Orders left:  5814761
# making new cascade
#
#
# OG Orders left:  5814761
# Cascade length:  2440
# New Orders left:  5812321
# making new cascade
#
#
# OG Orders left:  5812321
# Cascade length:  1
# New Orders left:  5812320
# making new cascade
#
#
# OG Orders left:  5812320
# Cascade length:  55
# New Orders left:  5812265
# making new cascade
#
#
# OG Orders left:  5812265
# Cascade length:  5794
# New Orders left:  5806471
# making new cascade
#
#
# OG Orders left:  5806471
# Cascade length:  5280
# New Orders left:  5801191
# making new cascade
#
#
# OG Orders left:  5801191
# Cascade length:  6885
# New Orders left:  5794306
# making new cascade
#
#
# OG Orders left:  5794306
# Cascade length:  3941
# New Orders left:  5790365
# making new cascade
#
#
# OG Orders left:  5790365
# Cascade length:  3
# New Orders left:  5790362
# making new cascade
#
#
# OG Orders left:  5790362
# Cascade length:  3635
# New Orders left:  5786727
# making new cascade
#
#
# OG Orders left:  5786727
# Cascade length:  3299
# New Orders left:  5783428
# making new cascade
#
#
# OG Orders left:  5783428
# Cascade length:  23
# New Orders left:  5783405
# making new cascade
#
#
# OG Orders left:  5783405
# Cascade length:  160
# New Orders left:  5783245
# making new cascade
#
#
# OG Orders left:  5783245
# Cascade length:  1
# New Orders left:  5783244
# making new cascade
#
#
# OG Orders left:  5783244
# Cascade length:  2878
# New Orders left:  5780366
# making new cascade
#
#
# OG Orders left:  5780366
# Cascade length:  4
# New Orders left:  5780362
# making new cascade
#
#
# OG Orders left:  5780362
# Cascade length:  7211
# New Orders left:  5773151
# making new cascade
#
#
# OG Orders left:  5773151
# Cascade length:  5097
# New Orders left:  5768054
# making new cascade
#
#
# OG Orders left:  5768054
# Cascade length:  15
# New Orders left:  5768039
# making new cascade
#
#
# OG Orders left:  5768039
# Cascade length:  6034
# New Orders left:  5762005
# making new cascade
#
#
# OG Orders left:  5762005
# Cascade length:  5116
# New Orders left:  5756889
# making new cascade
#
#
# OG Orders left:  5756889
# Cascade length:  6
# New Orders left:  5756883
# making new cascade
#
#
# OG Orders left:  5756883
# Cascade length:  8781
# New Orders left:  5748102
# making new cascade
#
#
# OG Orders left:  5748102
# Cascade length:  52
# New Orders left:  5748050
# making new cascade
#
#
# OG Orders left:  5748050
# Cascade length:  55
# New Orders left:  5747995
# making new cascade
#
#
# OG Orders left:  5747995
# Cascade length:  3131
# New Orders left:  5744864
# making new cascade
#
#
# OG Orders left:  5744864
# Cascade length:  9215
# New Orders left:  5735649
# making new cascade
#
#
# OG Orders left:  5735649
# Cascade length:  6890
# New Orders left:  5728759
# making new cascade
#
#
# OG Orders left:  5728759
# Cascade length:  100
# New Orders left:  5728659
# making new cascade
#
#
# OG Orders left:  5728659
# Cascade length:  8371
# New Orders left:  5720288
# making new cascade
#
#
# OG Orders left:  5720288
# Cascade length:  9
# New Orders left:  5720279
# making new cascade
#
#
# OG Orders left:  5720279
# Cascade length:  6288
# New Orders left:  5713991
# making new cascade
#
#
# OG Orders left:  5713991
# Cascade length:  6
# New Orders left:  5713985
# making new cascade
#
#
# OG Orders left:  5713985
# Cascade length:  9645
# New Orders left:  5704340
# making new cascade
#
#
# OG Orders left:  5704340
# Cascade length:  634
# New Orders left:  5703706
# making new cascade
#
#
# OG Orders left:  5703706
# Cascade length:  9
# New Orders left:  5703697
# making new cascade
#
#
# OG Orders left:  5703697
# Cascade length:  9219
# New Orders left:  5694478
# making new cascade
#
#
# OG Orders left:  5694478
# Cascade length:  3491
# New Orders left:  5690987
# making new cascade
#
#
# OG Orders left:  5690987
# Cascade length:  6
# New Orders left:  5690981
# making new cascade
#
#
# OG Orders left:  5690981
# Cascade length:  70
# New Orders left:  5690911
# making new cascade
#
#
# OG Orders left:  5690911
# Cascade length:  5041
# New Orders left:  5685870
# making new cascade
#
#
# OG Orders left:  5685870
# Cascade length:  7130
# New Orders left:  5678740
# making new cascade
#
#
# OG Orders left:  5678740
# Cascade length:  191
# New Orders left:  5678549
# making new cascade
#
#
# OG Orders left:  5678549
# Cascade length:  11323
# New Orders left:  5667226
# making new cascade
#
#
# OG Orders left:  5667226
# Cascade length:  4115
# New Orders left:  5663111
# making new cascade
#
#
# OG Orders left:  5663111
# Cascade length:  8
# New Orders left:  5663103
# making new cascade
#
#
# OG Orders left:  5663103
# Cascade length:  61
# New Orders left:  5663042
# making new cascade
#
#
# OG Orders left:  5663042
# Cascade length:  10400
# New Orders left:  5652642
# making new cascade
#
#
# OG Orders left:  5652642
# Cascade length:  4813
# New Orders left:  5647829
# making new cascade
#
#
# OG Orders left:  5647829
# Cascade length:  9
# New Orders left:  5647820
# making new cascade
#
#
# OG Orders left:  5647820
# Cascade length:  5671
# New Orders left:  5642149
# making new cascade
#
#
# OG Orders left:  5642149
# Cascade length:  19
# New Orders left:  5642130
# making new cascade
#
#
# OG Orders left:  5642130
# Cascade length:  6
# New Orders left:  5642124
# making new cascade
#
#
# OG Orders left:  5642124
# Cascade length:  3970
# New Orders left:  5638154
# making new cascade
#
#
# OG Orders left:  5638154
# Cascade length:  6331
# New Orders left:  5631823
# making new cascade
#
#
# OG Orders left:  5631823
# Cascade length:  2676
# New Orders left:  5629147
# making new cascade
#
#
# OG Orders left:  5629147
# Cascade length:  172
# New Orders left:  5628975
# making new cascade
#
#
# OG Orders left:  5628975
# Cascade length:  8170
# New Orders left:  5620805
# making new cascade
#
#
# OG Orders left:  5620805
# Cascade length:  4676
# New Orders left:  5616129
# making new cascade
#
#
# OG Orders left:  5616129
# Cascade length:  4531
# New Orders left:  5611598
# making new cascade
#
#
# OG Orders left:  5611598
# Cascade length:  4495
# New Orders left:  5607103
# making new cascade
#
#
# OG Orders left:  5607103
# Cascade length:  6959
# New Orders left:  5600144
# making new cascade
#
#
# OG Orders left:  5600144
# Cascade length:  6
# New Orders left:  5600138
# making new cascade
#
#
# OG Orders left:  5600138
# Cascade length:  69
# New Orders left:  5600069
# making new cascade
#
#
# OG Orders left:  5600069
# Cascade length:  4020
# New Orders left:  5596049
# making new cascade
#
#
# OG Orders left:  5596049
# Cascade length:  5391
# New Orders left:  5590658
# making new cascade
#
#
# OG Orders left:  5590658
# Cascade length:  3907
# New Orders left:  5586751
# making new cascade
#
#
# OG Orders left:  5586751
# Cascade length:  5851
# New Orders left:  5580900
# making new cascade
#
#
# OG Orders left:  5580900
# Cascade length:  8848
# New Orders left:  5572052
# making new cascade
#
#
# OG Orders left:  5572052
# Cascade length:  109
# New Orders left:  5571943
# making new cascade
#
#
# OG Orders left:  5571943
# Cascade length:  6115
# New Orders left:  5565828
# making new cascade
#
#
# OG Orders left:  5565828
# Cascade length:  5740
# New Orders left:  5560088
# making new cascade
#
#
# OG Orders left:  5560088
# Cascade length:  4352
# New Orders left:  5555736
# making new cascade
#
#
# OG Orders left:  5555736
# Cascade length:  10866
# New Orders left:  5544870
# making new cascade
#
#
# OG Orders left:  5544870
# Cascade length:  7068
# New Orders left:  5537802
# making new cascade
#
#
# OG Orders left:  5537802
# Cascade length:  11541
# New Orders left:  5526261
# making new cascade
#
#
# OG Orders left:  5526261
# Cascade length:  48
# New Orders left:  5526213
# making new cascade
#
#
# OG Orders left:  5526213
# Cascade length:  6281
# New Orders left:  5519932
# making new cascade
#
#
# OG Orders left:  5519932
# Cascade length:  10607
# New Orders left:  5509325
# making new cascade
#
#
# OG Orders left:  5509325
# Cascade length:  5081
# New Orders left:  5504244
# making new cascade
#
#
# OG Orders left:  5504244
# Cascade length:  6626
# New Orders left:  5497618
# making new cascade
#
#
# OG Orders left:  5497618
# Cascade length:  10082
# New Orders left:  5487536
# making new cascade
#
#
# OG Orders left:  5487536
# Cascade length:  161
# New Orders left:  5487375
# making new cascade
#
#
# OG Orders left:  5487375
# Cascade length:  8594
# New Orders left:  5478781
# making new cascade
#
#
# OG Orders left:  5478781
# Cascade length:  44
# New Orders left:  5478737
# making new cascade
#
#
# OG Orders left:  5478737
# Cascade length:  11105
# New Orders left:  5467632
# making new cascade
#
#
# OG Orders left:  5467632
# Cascade length:  11521
# New Orders left:  5456111
# making new cascade
#
#
# OG Orders left:  5456111
# Cascade length:  6495
# New Orders left:  5449616
# making new cascade
#
#
# OG Orders left:  5449616
# Cascade length:  2
# New Orders left:  5449614
# making new cascade
#
#
# OG Orders left:  5449614
# Cascade length:  5005
# New Orders left:  5444609
# making new cascade
#
#
# OG Orders left:  5444609
# Cascade length:  8
# New Orders left:  5444601
# making new cascade
#
#
# OG Orders left:  5444601
# Cascade length:  6275
# New Orders left:  5438326
# making new cascade
#
#
# OG Orders left:  5438326
# Cascade length:  3566
# New Orders left:  5434760
# making new cascade
#
#
# OG Orders left:  5434760
# Cascade length:  3430
# New Orders left:  5431330
# making new cascade
#
#
# OG Orders left:  5431330
# Cascade length:  9
# New Orders left:  5431321
# making new cascade
#
#
# OG Orders left:  5431321
# Cascade length:  5804
# New Orders left:  5425517
# making new cascade
#
#
# OG Orders left:  5425517
# Cascade length:  4395
# New Orders left:  5421122
# making new cascade
#
#
# OG Orders left:  5421122
# Cascade length:  46
# New Orders left:  5421076
# making new cascade
#
#
# OG Orders left:  5421076
# Cascade length:  18
# New Orders left:  5421058
# making new cascade
#
#
# OG Orders left:  5421058
# Cascade length:  2
# New Orders left:  5421056
# making new cascade
#
#
# OG Orders left:  5421056
# Cascade length:  14
# New Orders left:  5421042
# making new cascade
#
#
# OG Orders left:  5421042
# Cascade length:  4579
# New Orders left:  5416463
# making new cascade
#
#
# OG Orders left:  5416463
# Cascade length:  11530
# New Orders left:  5404933
# making new cascade
#
#
# OG Orders left:  5404933
# Cascade length:  5275
# New Orders left:  5399658
# making new cascade
#
#
# OG Orders left:  5399658
# Cascade length:  3
# New Orders left:  5399655
# making new cascade
#
#
# OG Orders left:  5399655
# Cascade length:  7732
# New Orders left:  5391923
# making new cascade
#
#
# OG Orders left:  5391923
# Cascade length:  2
# New Orders left:  5391921
# making new cascade
#
#
# OG Orders left:  5391921
# Cascade length:  3008
# New Orders left:  5388913
# making new cascade
#
#
# OG Orders left:  5388913
# Cascade length:  8706
# New Orders left:  5380207
# making new cascade
#
#
# OG Orders left:  5380207
# Cascade length:  1958
# New Orders left:  5378249
# making new cascade
#
#
# OG Orders left:  5378249
# Cascade length:  2767
# New Orders left:  5375482
# making new cascade
#
#
# OG Orders left:  5375482
# Cascade length:  149
# New Orders left:  5375333
# making new cascade
#
#
# OG Orders left:  5375333
# Cascade length:  7149
# New Orders left:  5368184
# making new cascade
#
#
# OG Orders left:  5368184
# Cascade length:  7596
# New Orders left:  5360588
# making new cascade
#
#
# OG Orders left:  5360588
# Cascade length:  3246
# New Orders left:  5357342
# making new cascade
#
#
# OG Orders left:  5357342
# Cascade length:  4580
# New Orders left:  5352762
# making new cascade
#
#
# OG Orders left:  5352762
# Cascade length:  2725
# New Orders left:  5350037
# making new cascade
#
#
# OG Orders left:  5350037
# Cascade length:  9655
# New Orders left:  5340382
# making new cascade
#
#
# OG Orders left:  5340382
# Cascade length:  12
# New Orders left:  5340370
# making new cascade
#
#
# OG Orders left:  5340370
# Cascade length:  294
# New Orders left:  5340076
# making new cascade
#
#
# OG Orders left:  5340076
# Cascade length:  1981
# New Orders left:  5338095
# making new cascade
#
#
# OG Orders left:  5338095
# Cascade length:  4515
# New Orders left:  5333580
# making new cascade
#
#
# OG Orders left:  5333580
# Cascade length:  4299
# New Orders left:  5329281
# making new cascade
#
#
# OG Orders left:  5329281
# Cascade length:  10
# New Orders left:  5329271
# making new cascade
#
#
# OG Orders left:  5329271
# Cascade length:  8064
# New Orders left:  5321207
# making new cascade
#
#
# OG Orders left:  5321207
# Cascade length:  2
# New Orders left:  5321205
# making new cascade
#
#
# OG Orders left:  5321205
# Cascade length:  2087
# New Orders left:  5319118
# making new cascade
#
#
# OG Orders left:  5319118
# Cascade length:  2
# New Orders left:  5319116
# making new cascade
#
#
# OG Orders left:  5319116
# Cascade length:  3736
# New Orders left:  5315380
# making new cascade
#
#
# OG Orders left:  5315380
# Cascade length:  13
# New Orders left:  5315367
# making new cascade
#
#
# OG Orders left:  5315367
# Cascade length:  2
# New Orders left:  5315365
# making new cascade
#
#
# OG Orders left:  5315365
# Cascade length:  10141
# New Orders left:  5305224
# making new cascade
#
#
# OG Orders left:  5305224
# Cascade length:  3582
# New Orders left:  5301642
# making new cascade
#
#
# OG Orders left:  5301642
# Cascade length:  10959
# New Orders left:  5290683
# making new cascade
#
#
# OG Orders left:  5290683
# Cascade length:  2
# New Orders left:  5290681
# making new cascade
#
#
# OG Orders left:  5290681
# Cascade length:  6470
# New Orders left:  5284211
# making new cascade
#
#
# OG Orders left:  5284211
# Cascade length:  8
# New Orders left:  5284203
# making new cascade
#
#
# OG Orders left:  5284203
# Cascade length:  4013
# New Orders left:  5280190
# making new cascade
#
#
# OG Orders left:  5280190
# Cascade length:  16
# New Orders left:  5280174
# making new cascade
#
#
# OG Orders left:  5280174
# Cascade length:  5486
# New Orders left:  5274688
# making new cascade
#
#
# OG Orders left:  5274688
# Cascade length:  5
# New Orders left:  5274683
# making new cascade
#
#
# OG Orders left:  5274683
# Cascade length:  7104
# New Orders left:  5267579
# making new cascade
#
#
# OG Orders left:  5267579
# Cascade length:  2
# New Orders left:  5267577
# making new cascade
#
#
# OG Orders left:  5267577
# Cascade length:  5322
# New Orders left:  5262255
# making new cascade
#
#
# OG Orders left:  5262255
# Cascade length:  116
# New Orders left:  5262139
# making new cascade
#
#
# OG Orders left:  5262139
# Cascade length:  5457
# New Orders left:  5256682
# making new cascade
#
#
# OG Orders left:  5256682
# Cascade length:  12639
# New Orders left:  5244043
# making new cascade
#
#
# OG Orders left:  5244043
# Cascade length:  3868
# New Orders left:  5240175
# making new cascade
#
#
# OG Orders left:  5240175
# Cascade length:  17
# New Orders left:  5240158
# making new cascade
#
#
# OG Orders left:  5240158
# Cascade length:  3634
# New Orders left:  5236524
# making new cascade
#
#
# OG Orders left:  5236524
# Cascade length:  2
# New Orders left:  5236522
# making new cascade
#
#
# OG Orders left:  5236522
# Cascade length:  4816
# New Orders left:  5231706
# making new cascade
#
#
# OG Orders left:  5231706
# Cascade length:  15
# New Orders left:  5231691
# making new cascade
#
#
# OG Orders left:  5231691
# Cascade length:  5813
# New Orders left:  5225878
# making new cascade
#
#
# OG Orders left:  5225878
# Cascade length:  6
# New Orders left:  5225872
# making new cascade
#
#
# OG Orders left:  5225872
# Cascade length:  10
# New Orders left:  5225862
# making new cascade
#
#
# OG Orders left:  5225862
# Cascade length:  7542
# New Orders left:  5218320
# making new cascade
#
#
# OG Orders left:  5218320
# Cascade length:  6445
# New Orders left:  5211875
# making new cascade
#
#
# OG Orders left:  5211875
# Cascade length:  68
# New Orders left:  5211807
# making new cascade
#
#
# OG Orders left:  5211807
# Cascade length:  8530
# New Orders left:  5203277
# making new cascade
#
#
# OG Orders left:  5203277
# Cascade length:  12
# New Orders left:  5203265
# making new cascade
#
#
# OG Orders left:  5203265
# Cascade length:  41
# New Orders left:  5203224
# making new cascade
#
#
# OG Orders left:  5203224
# Cascade length:  9064
# New Orders left:  5194160
# making new cascade
#
#
# OG Orders left:  5194160
# Cascade length:  74
# New Orders left:  5194086
# making new cascade
#
#
# OG Orders left:  5194086
# Cascade length:  37
# New Orders left:  5194049
# making new cascade
#
#
# OG Orders left:  5194049
# Cascade length:  4404
# New Orders left:  5189645
# making new cascade
#
#
# OG Orders left:  5189645
# Cascade length:  3341
# New Orders left:  5186304
# making new cascade
#
#
# OG Orders left:  5186304
# Cascade length:  6397
# New Orders left:  5179907
# making new cascade
#
#
# OG Orders left:  5179907
# Cascade length:  2
# New Orders left:  5179905
# making new cascade
#
#
# OG Orders left:  5179905
# Cascade length:  4393
# New Orders left:  5175512
# making new cascade
#
#
# OG Orders left:  5175512
# Cascade length:  6981
# New Orders left:  5168531
# making new cascade
#
#
# OG Orders left:  5168531
# Cascade length:  5253
# New Orders left:  5163278
# making new cascade
#
#
# OG Orders left:  5163278
# Cascade length:  2880
# New Orders left:  5160398
# making new cascade
#
#
# OG Orders left:  5160398
# Cascade length:  7344
# New Orders left:  5153054
# making new cascade
#
#
# OG Orders left:  5153054
# Cascade length:  3797
# New Orders left:  5149257
# making new cascade
#
#
# OG Orders left:  5149257
# Cascade length:  4
# New Orders left:  5149253
# making new cascade
#
#
# OG Orders left:  5149253
# Cascade length:  973
# New Orders left:  5148280
# making new cascade
#
#
# OG Orders left:  5148280
# Cascade length:  4621
# New Orders left:  5143659
# making new cascade
#
#
# OG Orders left:  5143659
# Cascade length:  3
# New Orders left:  5143656
# making new cascade
#
#
# OG Orders left:  5143656
# Cascade length:  7133
# New Orders left:  5136523
# making new cascade
#
#
# OG Orders left:  5136523
# Cascade length:  9663
# New Orders left:  5126860
# making new cascade
#
#
# OG Orders left:  5126860
# Cascade length:  59
# New Orders left:  5126801
# making new cascade
#
#
# OG Orders left:  5126801
# Cascade length:  257
# New Orders left:  5126544
# making new cascade
#
#
# OG Orders left:  5126544
# Cascade length:  4845
# New Orders left:  5121699
# making new cascade
#
#
# OG Orders left:  5121699
# Cascade length:  18
# New Orders left:  5121681
# making new cascade
#
#
# OG Orders left:  5121681
# Cascade length:  167
# New Orders left:  5121514
# making new cascade
#
#
# OG Orders left:  5121514
# Cascade length:  1600
# New Orders left:  5119914
# making new cascade
#
#
# OG Orders left:  5119914
# Cascade length:  3499
# New Orders left:  5116415
# making new cascade
#
#
# OG Orders left:  5116415
# Cascade length:  4
# New Orders left:  5116411
# making new cascade
#
#
# OG Orders left:  5116411
# Cascade length:  153
# New Orders left:  5116258
# making new cascade
#
#
# OG Orders left:  5116258
# Cascade length:  5482
# New Orders left:  5110776
# making new cascade
#
#
# OG Orders left:  5110776
# Cascade length:  25
# New Orders left:  5110751
# making new cascade
#
#
# OG Orders left:  5110751
# Cascade length:  3967
# New Orders left:  5106784
# making new cascade
#
#
# OG Orders left:  5106784
# Cascade length:  6740
# New Orders left:  5100044
# making new cascade
#
#
# OG Orders left:  5100044
# Cascade length:  21
# New Orders left:  5100023
# making new cascade
#
#
# OG Orders left:  5100023
# Cascade length:  6957
# New Orders left:  5093066
# making new cascade
#
#
# OG Orders left:  5093066
# Cascade length:  5789
# New Orders left:  5087277
# making new cascade
#
#
# OG Orders left:  5087277
# Cascade length:  5834
# New Orders left:  5081443
# making new cascade
#
#
# OG Orders left:  5081443
# Cascade length:  9
# New Orders left:  5081434
# making new cascade
#
#
# OG Orders left:  5081434
# Cascade length:  18
# New Orders left:  5081416
# making new cascade
#
#
# OG Orders left:  5081416
# Cascade length:  7419
# New Orders left:  5073997
# making new cascade
#
#
# OG Orders left:  5073997
# Cascade length:  2813
# New Orders left:  5071184
# making new cascade
#
#
# OG Orders left:  5071184
# Cascade length:  5
# New Orders left:  5071179
# making new cascade
#
#
# OG Orders left:  5071179
# Cascade length:  16
# New Orders left:  5071163
# making new cascade
#
#
# OG Orders left:  5071163
# Cascade length:  9288
# New Orders left:  5061875
# making new cascade
#
#
# OG Orders left:  5061875
# Cascade length:  1568
# New Orders left:  5060307
# making new cascade
#
#
# OG Orders left:  5060307
# Cascade length:  5685
# New Orders left:  5054622
# making new cascade
#
#
# OG Orders left:  5054622
# Cascade length:  60
# New Orders left:  5054562
# making new cascade
#
#
# OG Orders left:  5054562
# Cascade length:  33
# New Orders left:  5054529
# making new cascade
#
#
# OG Orders left:  5054529
# Cascade length:  8125
# New Orders left:  5046404
# making new cascade
#
#
# OG Orders left:  5046404
# Cascade length:  7514
# New Orders left:  5038890
# making new cascade
#
#
# OG Orders left:  5038890
# Cascade length:  10660
# New Orders left:  5028230
# making new cascade
#
#
# OG Orders left:  5028230
# Cascade length:  5084
# New Orders left:  5023146
# making new cascade
#
#
# OG Orders left:  5023146
# Cascade length:  8
# New Orders left:  5023138
# making new cascade
#
#
# OG Orders left:  5023138
# Cascade length:  2546
# New Orders left:  5020592
# making new cascade
#
#
# OG Orders left:  5020592
# Cascade length:  4382
# New Orders left:  5016210
# making new cascade
#
#
# OG Orders left:  5016210
# Cascade length:  7732
# New Orders left:  5008478
# making new cascade
#
#
# OG Orders left:  5008478
# Cascade length:  8174
# New Orders left:  5000304
# making new cascade
#
#
# OG Orders left:  5000304
# Cascade length:  6538
# New Orders left:  4993766
# making new cascade
#
#
# OG Orders left:  4993766
# Cascade length:  5327
# New Orders left:  4988439
# making new cascade
#
#
# OG Orders left:  4988439
# Cascade length:  10301
# New Orders left:  4978138
# making new cascade
#
#
# OG Orders left:  4978138
# Cascade length:  6166
# New Orders left:  4971972
# making new cascade
#
#
# OG Orders left:  4971972
# Cascade length:  8495
# New Orders left:  4963477
# making new cascade
#
#
# OG Orders left:  4963477
# Cascade length:  8923
# New Orders left:  4954554
# making new cascade
#
#
# OG Orders left:  4954554
# Cascade length:  496
# New Orders left:  4954058
# making new cascade
#
#
# OG Orders left:  4954058
# Cascade length:  3859
# New Orders left:  4950199
# making new cascade
#
#
# OG Orders left:  4950199
# Cascade length:  16
# New Orders left:  4950183
# making new cascade
#
#
# OG Orders left:  4950183
# Cascade length:  5095
# New Orders left:  4945088
# making new cascade
#
#
# OG Orders left:  4945088
# Cascade length:  46
# New Orders left:  4945042
# making new cascade
#
#
# OG Orders left:  4945042
# Cascade length:  7827
# New Orders left:  4937215
# making new cascade
#
#
# OG Orders left:  4937215
# Cascade length:  34
# New Orders left:  4937181
# making new cascade
#
#
# OG Orders left:  4937181
# Cascade length:  3766
# New Orders left:  4933415
# making new cascade
#
#
# OG Orders left:  4933415
# Cascade length:  16
# New Orders left:  4933399
# making new cascade
#
#
# OG Orders left:  4933399
# Cascade length:  2
# New Orders left:  4933397
# making new cascade
#
#
# OG Orders left:  4933397
# Cascade length:  3616
# New Orders left:  4929781
# making new cascade
#
#
# OG Orders left:  4929781
# Cascade length:  2590
# New Orders left:  4927191
# making new cascade
#
#
# OG Orders left:  4927191
# Cascade length:  3378
# New Orders left:  4923813
# making new cascade
#
#
# OG Orders left:  4923813
# Cascade length:  1579
# New Orders left:  4922234
# making new cascade
#
#
# OG Orders left:  4922234
# Cascade length:  4055
# New Orders left:  4918179
# making new cascade
#
#
# OG Orders left:  4918179
# Cascade length:  2002
# New Orders left:  4916177
# making new cascade
#
#
# OG Orders left:  4916177
# Cascade length:  3644
# New Orders left:  4912533
# making new cascade
#
#
# OG Orders left:  4912533
# Cascade length:  4875
# New Orders left:  4907658
# making new cascade
#
#
# OG Orders left:  4907658
# Cascade length:  3002
# New Orders left:  4904656
# making new cascade
#
#
# OG Orders left:  4904656
# Cascade length:  2227
# New Orders left:  4902429
# making new cascade
#
#
# OG Orders left:  4902429
# Cascade length:  2276
# New Orders left:  4900153
# making new cascade
#
#
# OG Orders left:  4900153
# Cascade length:  2472
# New Orders left:  4897681
# making new cascade
#
#
# OG Orders left:  4897681
# Cascade length:  3230
# New Orders left:  4894451
# making new cascade
#
#
# OG Orders left:  4894451
# Cascade length:  664
# New Orders left:  4893787
# making new cascade
#
#
# OG Orders left:  4893787
# Cascade length:  6674
# New Orders left:  4887113
# making new cascade
#
#
# OG Orders left:  4887113
# Cascade length:  45
# New Orders left:  4887068
# making new cascade
#
#
# OG Orders left:  4887068
# Cascade length:  584
# New Orders left:  4886484
# making new cascade
#
#
# OG Orders left:  4886484
# Cascade length:  2044
# New Orders left:  4884440
# making new cascade
#
#
# OG Orders left:  4884440
# Cascade length:  3
# New Orders left:  4884437
# making new cascade
#
#
# OG Orders left:  4884437
# Cascade length:  28
# ...
# making new cascade
#
#
# OG Orders left:  146198
# Cascade length:  2
# New Orders left:  146196
# making new cascade
#
#
# OG Orders left:  146196
# Cascade length:  1421
# New Orders left:  144775
# making new cascade
#
#
# OG Orders left:  144775
# Cascade length:  4
# New Orders left:  144771
# making new cascade
#
#
# OG Orders left:  144771
# Cascade length:  2393
# New Orders left:  142378
# making new cascade
#
#
# OG Orders left:  142378
# Cascade length:  4
# New Orders left:  142374
# making new cascade
#
#
# OG Orders left:  142374
# Cascade length:  2
# New Orders left:  142372
# making new cascade
#
#
# OG Orders left:  142372
# Cascade length:  9
# New Orders left:  142363
# making new cascade
#
#
# OG Orders left:  142363
# Cascade length:  2446
# New Orders left:  139917
# making new cascade
#
#
# OG Orders left:  139917
# Cascade length:  23
# New Orders left:  139894
# making new cascade
#
#
# OG Orders left:  139894
# Cascade length:  29
# New Orders left:  139865
# making new cascade
#
#
# OG Orders left:  139865
# Cascade length:  1328
# New Orders left:  138537
# making new cascade
#
#
# OG Orders left:  138537
# Cascade length:  7
# New Orders left:  138530
# making new cascade
#
#
# OG Orders left:  138530
# Cascade length:  33
# New Orders left:  138497
# making new cascade
#
#
# OG Orders left:  138497
# Cascade length:  222
# New Orders left:  138275
# making new cascade
#
#
# OG Orders left:  138275
# Cascade length:  1
# New Orders left:  138274
# making new cascade
#
#
# OG Orders left:  138274
# Cascade length:  3510
# New Orders left:  134764
# making new cascade
#
#
# OG Orders left:  134764
# Cascade length:  4
# New Orders left:  134760
# making new cascade
#
#
# OG Orders left:  134760
# Cascade length:  1163
# New Orders left:  133597
# making new cascade
#
#
# OG Orders left:  133597
# Cascade length:  2
# New Orders left:  133595
# making new cascade
#
#
# OG Orders left:  133595
# Cascade length:  6
# New Orders left:  133589
# making new cascade
#
#
# OG Orders left:  133589
# Cascade length:  2626
# New Orders left:  130963
# making new cascade
#
#
# OG Orders left:  130963
# Cascade length:  12
# New Orders left:  130951
# making new cascade
#
#
# OG Orders left:  130951
# Cascade length:  1606
# New Orders left:  129345
# making new cascade
#
#
# OG Orders left:  129345
# Cascade length:  360
# New Orders left:  128985
# making new cascade
#
#
# OG Orders left:  128985
# Cascade length:  9
# New Orders left:  128976
# making new cascade
#
#
# OG Orders left:  128976
# Cascade length:  3
# New Orders left:  128973
# making new cascade
#
#
# OG Orders left:  128973
# Cascade length:  4820
# New Orders left:  124153
# making new cascade
#
#
# OG Orders left:  124153
# Cascade length:  6665
# New Orders left:  117488
# making new cascade
#
#
# OG Orders left:  117488
# Cascade length:  5317
# New Orders left:  112171
# making new cascade
#
#
# OG Orders left:  112171
# Cascade length:  104
# New Orders left:  112067
# making new cascade
#
#
# OG Orders left:  112067
# Cascade length:  3
# New Orders left:  112064
# making new cascade
#
#
# OG Orders left:  112064
# Cascade length:  4
# New Orders left:  112060
# making new cascade
#
#
# OG Orders left:  112060
# Cascade length:  4378
# New Orders left:  107682
# making new cascade
#
#
# OG Orders left:  107682
# Cascade length:  2685
# New Orders left:  104997
# making new cascade
#
#
# OG Orders left:  104997
# Cascade length:  7
# New Orders left:  104990
# making new cascade
#
#
# OG Orders left:  104990
# Cascade length:  6
# New Orders left:  104984
# making new cascade
#
#
# OG Orders left:  104984
# Cascade length:  8
# New Orders left:  104976
# making new cascade
#
#
# OG Orders left:  104976
# Cascade length:  4544
# New Orders left:  100432
# making new cascade
#
#
# OG Orders left:  100432
# Cascade length:  4
# New Orders left:  100428
# making new cascade
#
#
# OG Orders left:  100428
# Cascade length:  9
# New Orders left:  100419
# making new cascade
#
#
# OG Orders left:  100419
# Cascade length:  444
# New Orders left:  99975
# making new cascade
#
#
# OG Orders left:  99975
# Cascade length:  16
# New Orders left:  99959
# making new cascade
#
#
# OG Orders left:  99959
# Cascade length:  3080
# New Orders left:  96879
# making new cascade
#
#
# OG Orders left:  96879
# Cascade length:  3
# New Orders left:  96876
# making new cascade
#
#
# OG Orders left:  96876
# Cascade length:  6
# New Orders left:  96870
# making new cascade
#
#
# OG Orders left:  96870
# Cascade length:  2
# New Orders left:  96868
# making new cascade
#
#
# OG Orders left:  96868
# Cascade length:  2791
# New Orders left:  94077
# making new cascade
#
#
# OG Orders left:  94077
# Cascade length:  7
# New Orders left:  94070
# making new cascade
#
#
# OG Orders left:  94070
# Cascade length:  351
# New Orders left:  93719
# making new cascade
#
#
# OG Orders left:  93719
# Cascade length:  631
# New Orders left:  93088
# making new cascade
#
#
# OG Orders left:  93088
# Cascade length:  3918
# New Orders left:  89170
# making new cascade
#
#
# OG Orders left:  89170
# Cascade length:  2425
# New Orders left:  86745
# making new cascade
#
#
# OG Orders left:  86745
# Cascade length:  23
# New Orders left:  86722
# making new cascade
#
#
# OG Orders left:  86722
# Cascade length:  4
# New Orders left:  86718
# making new cascade
#
#
# OG Orders left:  86718
# Cascade length:  1065
# New Orders left:  85653
# making new cascade
#
#
# OG Orders left:  85653
# Cascade length:  720
# New Orders left:  84933
# making new cascade
#
#
# OG Orders left:  84933
# Cascade length:  919
# New Orders left:  84014
# making new cascade
#
#
# OG Orders left:  84014
# Cascade length:  2811
# New Orders left:  81203
# making new cascade
#
#
# OG Orders left:  81203
# Cascade length:  3146
# New Orders left:  78057
# making new cascade
#
#
# OG Orders left:  78057
# Cascade length:  1
# New Orders left:  78056
# making new cascade
#
#
# OG Orders left:  78056
# Cascade length:  2705
# New Orders left:  75351
# making new cascade
#
#
# OG Orders left:  75351
# Cascade length:  3483
# New Orders left:  71868
# making new cascade
#
#
# OG Orders left:  71868
# Cascade length:  2
# New Orders left:  71866
# making new cascade
#
#
# OG Orders left:  71866
# Cascade length:  13
# New Orders left:  71853
# making new cascade
#
#
# OG Orders left:  71853
# Cascade length:  3
# New Orders left:  71850
# making new cascade
#
#
# OG Orders left:  71850
# Cascade length:  2151
# New Orders left:  69699
# making new cascade
#
#
# OG Orders left:  69699
# Cascade length:  104
# New Orders left:  69595
# making new cascade
#
#
# OG Orders left:  69595
# Cascade length:  3040
# New Orders left:  66555
# making new cascade
#
#
# OG Orders left:  66555
# Cascade length:  2459
# New Orders left:  64096
# making new cascade
#
#
# OG Orders left:  64096
# Cascade length:  2295
# New Orders left:  61801
# making new cascade
#
#
# OG Orders left:  61801
# Cascade length:  2859
# New Orders left:  58942
# making new cascade
#
#
# OG Orders left:  58942
# Cascade length:  2
# New Orders left:  58940
# making new cascade
#
#
# OG Orders left:  58940
# Cascade length:  6
# New Orders left:  58934
# making new cascade
#
#
# OG Orders left:  58934
# Cascade length:  4
# New Orders left:  58930
# making new cascade
#
#
# OG Orders left:  58930
# Cascade length:  1675
# New Orders left:  57255
# making new cascade
#
#
# OG Orders left:  57255
# Cascade length:  4198
# New Orders left:  53057
# making new cascade
#
#
# OG Orders left:  53057
# Cascade length:  3
# New Orders left:  53054
# making new cascade
#
#
# OG Orders left:  53054
# Cascade length:  2
# New Orders left:  53052
# making new cascade
#
#
# OG Orders left:  53052
# Cascade length:  7
# New Orders left:  53045
# making new cascade
#
#
# OG Orders left:  53045
# Cascade length:  26
# New Orders left:  53019
# making new cascade
#
#
# OG Orders left:  53019
# Cascade length:  1350
# New Orders left:  51669
# making new cascade
#
#
# OG Orders left:  51669
# Cascade length:  2733
# New Orders left:  48936
# making new cascade
#
#
# OG Orders left:  48936
# Cascade length:  21
# New Orders left:  48915
# making new cascade
#
#
# OG Orders left:  48915
# Cascade length:  802
# New Orders left:  48113
# making new cascade
#
#
# OG Orders left:  48113
# Cascade length:  13
# New Orders left:  48100
# making new cascade
#
#
# OG Orders left:  48100
# Cascade length:  18
# New Orders left:  48082
# making new cascade
#
#
# OG Orders left:  48082
# Cascade length:  46
# New Orders left:  48036
# making new cascade
#
#
# OG Orders left:  48036
# Cascade length:  2328
# New Orders left:  45708
# making new cascade
#
#
# OG Orders left:  45708
# Cascade length:  1322
# New Orders left:  44386
# making new cascade
#
#
# OG Orders left:  44386
# Cascade length:  3171
# New Orders left:  41215
# making new cascade
#
#
# OG Orders left:  41215
# Cascade length:  1930
# New Orders left:  39285
# making new cascade
#
#
# OG Orders left:  39285
# Cascade length:  2537
# New Orders left:  36748
# making new cascade
#
#
# OG Orders left:  36748
# Cascade length:  2035
# New Orders left:  34713
# making new cascade
#
#
# OG Orders left:  34713
# Cascade length:  2213
# New Orders left:  32500
# making new cascade
#
#
# OG Orders left:  32500
# Cascade length:  1773
# New Orders left:  30727
# making new cascade
#
#
# OG Orders left:  30727
# Cascade length:  277
# New Orders left:  30450
# making new cascade
#
#
# OG Orders left:  30450
# Cascade length:  10
# New Orders left:  30440
# making new cascade
#
#
# OG Orders left:  30440
# Cascade length:  1553
# New Orders left:  28887
# making new cascade
#
#
# OG Orders left:  28887
# Cascade length:  4
# New Orders left:  28883
# making new cascade
#
#
# OG Orders left:  28883
# Cascade length:  2080
# New Orders left:  26803
# making new cascade
#
#
# OG Orders left:  26803
# Cascade length:  42
# New Orders left:  26761
# making new cascade
#
#
# OG Orders left:  26761
# Cascade length:  8
# New Orders left:  26753
# making new cascade
#
#
# OG Orders left:  26753
# Cascade length:  1370
# New Orders left:  25383
# making new cascade
#
#
# OG Orders left:  25383
# Cascade length:  1441
# New Orders left:  23942
# making new cascade
#
#
# OG Orders left:  23942
# Cascade length:  2054
# New Orders left:  21888
# making new cascade
#
#
# OG Orders left:  21888
# Cascade length:  1199
# New Orders left:  20689
# making new cascade
#
#
# OG Orders left:  20689
# Cascade length:  2299
# New Orders left:  18390
# making new cascade
#
#
# OG Orders left:  18390
# Cascade length:  1023
# New Orders left:  17367
# making new cascade
#
#
# OG Orders left:  17367
# Cascade length:  11
# New Orders left:  17356
# making new cascade
#
#
# OG Orders left:  17356
# Cascade length:  57
# New Orders left:  17299
# making new cascade
#
#
# OG Orders left:  17299
# Cascade length:  368
# New Orders left:  16931
# making new cascade
#
#
# OG Orders left:  16931
# Cascade length:  827
# New Orders left:  16104
# making new cascade
#
#
# OG Orders left:  16104
# Cascade length:  841
# New Orders left:  15263
# making new cascade
#
#
# OG Orders left:  15263
# Cascade length:  4
# New Orders left:  15259
# making new cascade
#
#
# OG Orders left:  15259
# Cascade length:  743
# New Orders left:  14516
# making new cascade
#
#
# OG Orders left:  14516
# Cascade length:  6
# New Orders left:  14510
# making new cascade
#
#
# OG Orders left:  14510
# Cascade length:  20
# New Orders left:  14490
# making new cascade
#
#
# OG Orders left:  14490
# Cascade length:  583
# New Orders left:  13907
# making new cascade
#
#
# OG Orders left:  13907
# Cascade length:  505
# New Orders left:  13402
# making new cascade
#
#
# OG Orders left:  13402
# Cascade length:  98
# New Orders left:  13304
# making new cascade
#
#
# OG Orders left:  13304
# Cascade length:  602
# New Orders left:  12702
# making new cascade
#
#
# OG Orders left:  12702
# Cascade length:  5
# New Orders left:  12697
# making new cascade
#
#
# OG Orders left:  12697
# Cascade length:  1679
# New Orders left:  11018
# making new cascade
#
#
# OG Orders left:  11018
# Cascade length:  6
# New Orders left:  11012
# making new cascade
#
#
# OG Orders left:  11012
# Cascade length:  296
# New Orders left:  10716
# making new cascade
#
#
# OG Orders left:  10716
# Cascade length:  22
# New Orders left:  10694
# making new cascade
#
#
# OG Orders left:  10694
# Cascade length:  202
# New Orders left:  10492
# making new cascade
#
#
# OG Orders left:  10492
# Cascade length:  64
# New Orders left:  10428
# making new cascade
#
#
# OG Orders left:  10428
# Cascade length:  663
# New Orders left:  9765
# making new cascade
#
#
# OG Orders left:  9765
# Cascade length:  633
# New Orders left:  9132
# making new cascade
#
#
# OG Orders left:  9132
# Cascade length:  19
# New Orders left:  9113
# making new cascade
#
#
# OG Orders left:  9113
# Cascade length:  950
# New Orders left:  8163
# making new cascade
#
#
# OG Orders left:  8163
# Cascade length:  437
# New Orders left:  7726
# making new cascade
#
#
# OG Orders left:  7726
# Cascade length:  12
# New Orders left:  7714
# making new cascade
#
#
# OG Orders left:  7714
# Cascade length:  30
# New Orders left:  7684
# making new cascade
#
#
# OG Orders left:  7684
# Cascade length:  494
# New Orders left:  7190
# making new cascade
#
#
# OG Orders left:  7190
# Cascade length:  2
# New Orders left:  7188
# making new cascade
#
#
# OG Orders left:  7188
# Cascade length:  617
# New Orders left:  6571
# making new cascade
#
#
# OG Orders left:  6571
# Cascade length:  620
# New Orders left:  5951
# making new cascade
#
#
# OG Orders left:  5951
# Cascade length:  7
# New Orders left:  5944
# making new cascade
#
#
# OG Orders left:  5944
# Cascade length:  873
# New Orders left:  5071
# making new cascade
#
#
# OG Orders left:  5071
# Cascade length:  251
# New Orders left:  4820
# making new cascade
#
#
# OG Orders left:  4820
# Cascade length:  387
# New Orders left:  4433
# making new cascade
#
#
# OG Orders left:  4433
# Cascade length:  13
# New Orders left:  4420
# making new cascade
#
#
# OG Orders left:  4420
# Cascade length:  293
# New Orders left:  4127
# making new cascade
#
#
# OG Orders left:  4127
# Cascade length:  47
# New Orders left:  4080
# making new cascade
#
#
# OG Orders left:  4080
# Cascade length:  18
# New Orders left:  4062
# making new cascade
#
#
# OG Orders left:  4062
# Cascade length:  17
# New Orders left:  4045
# making new cascade
#
#
# OG Orders left:  4045
# Cascade length:  237
# New Orders left:  3808
# making new cascade
#
#
# OG Orders left:  3808
# Cascade length:  264
# New Orders left:  3544
# making new cascade
#
#
# OG Orders left:  3544
# Cascade length:  222
# New Orders left:  3322
# making new cascade
#
#
# OG Orders left:  3322
# Cascade length:  11
# New Orders left:  3311
# making new cascade
#
#
# OG Orders left:  3311
# Cascade length:  390
# New Orders left:  2921
# making new cascade
#
#
# OG Orders left:  2921
# Cascade length:  41
# New Orders left:  2880
# making new cascade
#
#
# OG Orders left:  2880
# Cascade length:  195
# New Orders left:  2685
# making new cascade
#
#
# OG Orders left:  2685
# Cascade length:  16
# New Orders left:  2669
# making new cascade
#
#
# OG Orders left:  2669
# Cascade length:  208
# New Orders left:  2461
# making new cascade
#
#
# OG Orders left:  2461
# Cascade length:  218
# New Orders left:  2243
# making new cascade
#
#
# OG Orders left:  2243
# Cascade length:  298
# New Orders left:  1945
# making new cascade
#
#
# OG Orders left:  1945
# Cascade length:  118
# New Orders left:  1827
# making new cascade
#
#
# OG Orders left:  1827
# Cascade length:  97
# New Orders left:  1730
# making new cascade
#
#
# OG Orders left:  1730
# Cascade length:  3
# New Orders left:  1727
# making new cascade
#
#
# OG Orders left:  1727
# Cascade length:  65
# New Orders left:  1662
# making new cascade
#
#
# OG Orders left:  1662
# Cascade length:  139
# New Orders left:  1523
# making new cascade
#
#
# OG Orders left:  1523
# Cascade length:  174
# New Orders left:  1349
# making new cascade
#
#
# OG Orders left:  1349
# Cascade length:  212
# New Orders left:  1137
# making new cascade
#
#
# OG Orders left:  1137
# Cascade length:  63
# New Orders left:  1074
# making new cascade
#
#
# OG Orders left:  1074
# Cascade length:  115
# New Orders left:  959
# making new cascade
#
#
# OG Orders left:  959
# Cascade length:  193
# New Orders left:  766
# making new cascade
#
#
# OG Orders left:  766
# Cascade length:  326
# New Orders left:  440
# making new cascade
#
#
# OG Orders left:  440
# Cascade length:  67
# New Orders left:  373
# making new cascade
#
#
# OG Orders left:  373
# Cascade length:  9
# New Orders left:  364
# making new cascade
#
#
# OG Orders left:  364
# Cascade length:  82
# New Orders left:  282
# making new cascade
#
#
# OG Orders left:  282
# Cascade length:  45
# New Orders left:  237
# making new cascade
#
#
# OG Orders left:  237
# Cascade length:  46
# New Orders left:  191
# making new cascade
#
#
# OG Orders left:  191
# Cascade length:  104
# New Orders left:  87
# making new cascade
#
#
# OG Orders left:  87
# Cascade length:  18
# New Orders left:  69
# making new cascade
#
#
# OG Orders left:  69
# Cascade length:  40
# New Orders left:  29
# making new cascade
#
#
# OG Orders left:  29
# Cascade length:  5
# New Orders left:  24
# making new cascade
#
#
# OG Orders left:  24
# Cascade length:  19
# New Orders left:  5
# making new cascade
#
#
# OG Orders left:  5
# Cascade length:  5
# New Orders left:  0
# making new cascade

# %%
# causalCascades11 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=8192)

# %%
with open('../causalCascades11_npc79o501p72000s100t.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),30))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc79o501p7200s100t_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),30))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*100, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc79o501p7200s100t_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc79o501p7200s100t_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc79o501p7200s100t_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc79o501p7200s100t_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35), '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc79o501p7200s100t_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc79o501p7200s100t_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc79o501p7200s100t_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35), '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc79o501p7200s100t_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc79o501p7200s100t_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc79o501p7200s100t_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35), '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc79o501p7200s100t_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
