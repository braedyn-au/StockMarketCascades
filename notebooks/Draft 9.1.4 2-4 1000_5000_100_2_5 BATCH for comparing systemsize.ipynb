# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle 
from library import utils, config, cascades

# %%
with open('./results/nopricechange/2-4/traderIDs_1000_5000_100_2_5.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/2-4/stockPool_1000_5000_100_2_5.npy")
hurstPoolNPC = np.load("./results/nopricechange/2-4/hurstPool_1000_5000_100_2_5.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/2-4/totalOrders_1000_5000_100_2_5.csv")

# %%
(TtotalOrdersNPC)
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 2   993     pcaot      6    1.0
# 1                 0   993     vpneq     10    2.0
# 2                 3   993     vpneq     13   -1.0
# 3                 2   993     jzndk     14    1.0
# 4                 1   993     jwivu     13   -2.0
# ...             ...   ...       ...    ...    ...
# 2139960           2  5992     khrsl     62    4.0
# 2139961           0  5992     sujzt     75   -6.0
# 2139962           1  5992     sujzt     62    4.0
# 2139963           0  5992     gdnqf     75  -91.0
# 2139964           1  5992     gdnqf     62   67.0
#
# [2139965 rows x 5 columns]

# %%
# def findStockOrderCascades(stockOrders, cascades, minSep = 2):
#     """
#     inpurt filtered stockOrders table
#     works on stockOrder tables from TtotalOrders, returns panda tables of each cascade
#     returns all cascades
#     FOR LOOKING AT INDIVIDUAL STOCK CASCADES NOV14
#     """
#     if len(stockOrders) > 0 :
#         #Find seperations in trading times
#         ToS = stockOrders['time'].unique()
#         sep = np.diff(ToS)
#         keySep = np.where(sep>minSep)[0]
#         i0 = 0

#         if len(cascades) > 0:
#             n = max(cascades.keys())
#         else:
#             # first cascade
#             n = 0

#         if len(keySep)>0:
#             for key in keySep:
#                 key += 1
#                 stockCascade = stockOrders[stockOrders['time']<=ToS[key]]
#                 stockCascade = stockCascade[stockCascade['time']>=ToS[i0]]
#                 cascades[n] = stockCascade
#                 i0 = key
#                 n += 1
                
#     #cascades is a dictionary
#     return cascades

# def stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep ):    
#     """
#     analysis for stock order cascades seen in draft 8.#
#     ALL IN ONE
#     """
#     cascades = {}
#     for stock in range(len(stockPool)):
#         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)

#     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)

#     return sizes, nrows, duration

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-64414ca3f7cb> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/mat36/lib/python3.6/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     732                 return NotImplemented
#     733             else:
# --> 734                 return cudf_func(*args, **kwargs)
#     735
#     736         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 5992, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
# plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/2-4/causalCascades22_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2139965

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/2-4/causalCascades21_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2139965

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/2-4/causalCascades12_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2139965

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC[TtotalOrdersNPC['time']<=5992], traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/2-4/causalCascades11_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2139965
# Cascade length:  2014
# New Orders left:  2137951
# making new cascade
#
#
# OG Orders left:  2137951
# Cascade length:  2561
# New Orders left:  2135390
# making new cascade
#
#
# OG Orders left:  2135390
# Cascade length:  2665
# New Orders left:  2132725
# making new cascade
#
#
# OG Orders left:  2132725
# Cascade length:  2582
# New Orders left:  2130143
# making new cascade
#
#
# OG Orders left:  2130143
# Cascade length:  4
# New Orders left:  2130139
# making new cascade
#
#
# OG Orders left:  2130139
# Cascade length:  2000
# New Orders left:  2128139
# making new cascade
#
#
# OG Orders left:  2128139
# Cascade length:  1
# New Orders left:  2128138
# making new cascade
#
#
# OG Orders left:  2128138
# Cascade length:  2
# New Orders left:  2128136
# making new cascade
#
#
# OG Orders left:  2128136
# Cascade length:  2646
# New Orders left:  2125490
# making new cascade
#
#
# OG Orders left:  2125490
# Cascade length:  2302
# New Orders left:  2123188
# making new cascade
#
#
# OG Orders left:  2123188
# Cascade length:  2308
# New Orders left:  2120880
# making new cascade
#
#
# OG Orders left:  2120880
# Cascade length:  1972
# New Orders left:  2118908
# making new cascade
#
#
# OG Orders left:  2118908
# Cascade length:  2
# New Orders left:  2118906
# making new cascade
#
#
# OG Orders left:  2118906
# Cascade length:  15
# New Orders left:  2118891
# making new cascade
#
#
# OG Orders left:  2118891
# Cascade length:  1698
# New Orders left:  2117193
# making new cascade
#
#
# OG Orders left:  2117193
# Cascade length:  3
# New Orders left:  2117190
# making new cascade
#
#
# OG Orders left:  2117190
# Cascade length:  2444
# New Orders left:  2114746
# making new cascade
#
#
# OG Orders left:  2114746
# Cascade length:  2326
# New Orders left:  2112420
# making new cascade
#
#
# OG Orders left:  2112420
# Cascade length:  2
# New Orders left:  2112418
# making new cascade
#
#
# OG Orders left:  2112418
# Cascade length:  2284
# New Orders left:  2110134
# making new cascade
#
#
# OG Orders left:  2110134
# Cascade length:  1651
# New Orders left:  2108483
# making new cascade
#
#
# OG Orders left:  2108483
# Cascade length:  1812
# New Orders left:  2106671
# making new cascade
#
#
# OG Orders left:  2106671
# Cascade length:  2
# New Orders left:  2106669
# making new cascade
#
#
# OG Orders left:  2106669
# Cascade length:  2026
# New Orders left:  2104643
# making new cascade
#
#
# OG Orders left:  2104643
# Cascade length:  1427
# New Orders left:  2103216
# making new cascade
#
#
# OG Orders left:  2103216
# Cascade length:  2
# New Orders left:  2103214
# making new cascade
#
#
# OG Orders left:  2103214
# Cascade length:  2106
# New Orders left:  2101108
# making new cascade
#
#
# OG Orders left:  2101108
# Cascade length:  1957
# New Orders left:  2099151
# making new cascade
#
#
# OG Orders left:  2099151
# Cascade length:  2393
# New Orders left:  2096758
# making new cascade
#
#
# OG Orders left:  2096758
# Cascade length:  3
# New Orders left:  2096755
# making new cascade
#
#
# OG Orders left:  2096755
# Cascade length:  2171
# New Orders left:  2094584
# making new cascade
#
#
# OG Orders left:  2094584
# Cascade length:  4
# New Orders left:  2094580
# making new cascade
#
#
# OG Orders left:  2094580
# Cascade length:  2
# New Orders left:  2094578
# making new cascade
#
#
# OG Orders left:  2094578
# Cascade length:  2113
# New Orders left:  2092465
# making new cascade
#
#
# OG Orders left:  2092465
# Cascade length:  2264
# New Orders left:  2090201
# making new cascade
#
#
# OG Orders left:  2090201
# Cascade length:  1
# New Orders left:  2090200
# making new cascade
#
#
# OG Orders left:  2090200
# Cascade length:  2098
# New Orders left:  2088102
# making new cascade
#
#
# OG Orders left:  2088102
# Cascade length:  4
# New Orders left:  2088098
# making new cascade
#
#
# OG Orders left:  2088098
# Cascade length:  1356
# New Orders left:  2086742
# making new cascade
#
#
# OG Orders left:  2086742
# Cascade length:  4
# New Orders left:  2086738
# making new cascade
#
#
# OG Orders left:  2086738
# Cascade length:  2
# New Orders left:  2086736
# making new cascade
#
#
# OG Orders left:  2086736
# Cascade length:  1
# New Orders left:  2086735
# making new cascade
#
#
# OG Orders left:  2086735
# Cascade length:  7
# New Orders left:  2086728
# making new cascade
#
#
# OG Orders left:  2086728
# Cascade length:  2287
# New Orders left:  2084441
# making new cascade
#
#
# OG Orders left:  2084441
# Cascade length:  2
# New Orders left:  2084439
# making new cascade
#
#
# OG Orders left:  2084439
# Cascade length:  1
# New Orders left:  2084438
# making new cascade
#
#
# OG Orders left:  2084438
# Cascade length:  1193
# New Orders left:  2083245
# making new cascade
#
#
# OG Orders left:  2083245
# Cascade length:  1928
# New Orders left:  2081317
# making new cascade
#
#
# OG Orders left:  2081317
# Cascade length:  1965
# New Orders left:  2079352
# making new cascade
#
#
# OG Orders left:  2079352
# Cascade length:  1367
# New Orders left:  2077985
# making new cascade
#
#
# OG Orders left:  2077985
# Cascade length:  4
# New Orders left:  2077981
# making new cascade
#
#
# OG Orders left:  2077981
# Cascade length:  2
# New Orders left:  2077979
# making new cascade
#
#
# OG Orders left:  2077979
# Cascade length:  5
# New Orders left:  2077974
# making new cascade
#
#
# OG Orders left:  2077974
# Cascade length:  3
# New Orders left:  2077971
# making new cascade
#
#
# OG Orders left:  2077971
# Cascade length:  1184
# New Orders left:  2076787
# making new cascade
#
#
# OG Orders left:  2076787
# Cascade length:  2
# New Orders left:  2076785
# making new cascade
#
#
# OG Orders left:  2076785
# Cascade length:  15
# New Orders left:  2076770
# making new cascade
#
#
# OG Orders left:  2076770
# Cascade length:  10
# New Orders left:  2076760
# making new cascade
#
#
# OG Orders left:  2076760
# Cascade length:  4
# New Orders left:  2076756
# making new cascade
#
#
# OG Orders left:  2076756
# Cascade length:  3
# New Orders left:  2076753
# making new cascade
#
#
# OG Orders left:  2076753
# Cascade length:  2
# New Orders left:  2076751
# making new cascade
#
#
# OG Orders left:  2076751
# Cascade length:  1480
# New Orders left:  2075271
# making new cascade
#
#
# OG Orders left:  2075271
# Cascade length:  2
# New Orders left:  2075269
# making new cascade
#
#
# OG Orders left:  2075269
# Cascade length:  2051
# New Orders left:  2073218
# making new cascade
#
#
# OG Orders left:  2073218
# Cascade length:  1321
# New Orders left:  2071897
# making new cascade
#
#
# OG Orders left:  2071897
# Cascade length:  1861
# New Orders left:  2070036
# making new cascade
#
#
# OG Orders left:  2070036
# Cascade length:  1637
# New Orders left:  2068399
# making new cascade
#
#
# OG Orders left:  2068399
# Cascade length:  8
# New Orders left:  2068391
# making new cascade
#
#
# OG Orders left:  2068391
# Cascade length:  2
# New Orders left:  2068389
# making new cascade
#
#
# OG Orders left:  2068389
# Cascade length:  1687
# New Orders left:  2066702
# making new cascade
#
#
# OG Orders left:  2066702
# Cascade length:  2
# New Orders left:  2066700
# making new cascade
#
#
# OG Orders left:  2066700
# Cascade length:  1592
# New Orders left:  2065108
# making new cascade
#
#
# OG Orders left:  2065108
# Cascade length:  4
# New Orders left:  2065104
# making new cascade
#
#
# OG Orders left:  2065104
# Cascade length:  1695
# New Orders left:  2063409
# making new cascade
#
#
# OG Orders left:  2063409
# Cascade length:  1734
# New Orders left:  2061675
# making new cascade
#
#
# OG Orders left:  2061675
# Cascade length:  1630
# New Orders left:  2060045
# making new cascade
#
#
# OG Orders left:  2060045
# Cascade length:  1
# New Orders left:  2060044
# making new cascade
#
#
# OG Orders left:  2060044
# Cascade length:  1372
# New Orders left:  2058672
# making new cascade
#
#
# OG Orders left:  2058672
# Cascade length:  8
# New Orders left:  2058664
# making new cascade
#
#
# OG Orders left:  2058664
# Cascade length:  1380
# New Orders left:  2057284
# making new cascade
#
#
# OG Orders left:  2057284
# Cascade length:  5
# New Orders left:  2057279
# making new cascade
#
#
# OG Orders left:  2057279
# Cascade length:  1417
# New Orders left:  2055862
# making new cascade
#
#
# OG Orders left:  2055862
# Cascade length:  1786
# New Orders left:  2054076
# making new cascade
#
#
# OG Orders left:  2054076
# Cascade length:  1571
# New Orders left:  2052505
# making new cascade
#
#
# OG Orders left:  2052505
# Cascade length:  2
# New Orders left:  2052503
# making new cascade
#
#
# OG Orders left:  2052503
# Cascade length:  21
# New Orders left:  2052482
# making new cascade
#
#
# OG Orders left:  2052482
# Cascade length:  1271
# New Orders left:  2051211
# making new cascade
#
#
# OG Orders left:  2051211
# Cascade length:  2
# New Orders left:  2051209
# making new cascade
#
#
# OG Orders left:  2051209
# Cascade length:  2
# New Orders left:  2051207
# making new cascade
#
#
# OG Orders left:  2051207
# Cascade length:  1431
# New Orders left:  2049776
# making new cascade
#
#
# OG Orders left:  2049776
# Cascade length:  2
# New Orders left:  2049774
# making new cascade
#
#
# OG Orders left:  2049774
# Cascade length:  1269
# New Orders left:  2048505
# making new cascade
#
#
# OG Orders left:  2048505
# Cascade length:  1155
# New Orders left:  2047350
# making new cascade
#
#
# OG Orders left:  2047350
# Cascade length:  1691
# New Orders left:  2045659
# making new cascade
#
#
# OG Orders left:  2045659
# Cascade length:  1667
# New Orders left:  2043992
# making new cascade
#
#
# OG Orders left:  2043992
# Cascade length:  7
# New Orders left:  2043985
# making new cascade
#
#
# OG Orders left:  2043985
# Cascade length:  1
# New Orders left:  2043984
# making new cascade
#
#
# OG Orders left:  2043984
# Cascade length:  932
# New Orders left:  2043052
# making new cascade
#
#
# OG Orders left:  2043052
# Cascade length:  1865
# New Orders left:  2041187
# making new cascade
#
#
# OG Orders left:  2041187
# Cascade length:  1692
# New Orders left:  2039495
# making new cascade
#
#
# OG Orders left:  2039495
# Cascade length:  1
# New Orders left:  2039494
# making new cascade
#
#
# OG Orders left:  2039494
# Cascade length:  15
# New Orders left:  2039479
# making new cascade
#
#
# OG Orders left:  2039479
# Cascade length:  1179
# New Orders left:  2038300
# making new cascade
#
#
# OG Orders left:  2038300
# Cascade length:  8
# New Orders left:  2038292
# making new cascade
#
#
# OG Orders left:  2038292
# Cascade length:  1644
# New Orders left:  2036648
# making new cascade
#
#
# OG Orders left:  2036648
# Cascade length:  1575
# New Orders left:  2035073
# making new cascade
#
#
# OG Orders left:  2035073
# Cascade length:  1
# New Orders left:  2035072
# making new cascade
#
#
# OG Orders left:  2035072
# Cascade length:  2
# New Orders left:  2035070
# making new cascade
#
#
# OG Orders left:  2035070
# Cascade length:  4
# New Orders left:  2035066
# making new cascade
#
#
# OG Orders left:  2035066
# Cascade length:  455
# New Orders left:  2034611
# making new cascade
#
#
# OG Orders left:  2034611
# Cascade length:  1696
# New Orders left:  2032915
# making new cascade
#
#
# OG Orders left:  2032915
# Cascade length:  1234
# New Orders left:  2031681
# making new cascade
#
#
# OG Orders left:  2031681
# Cascade length:  10
# New Orders left:  2031671
# making new cascade
#
#
# OG Orders left:  2031671
# Cascade length:  1178
# New Orders left:  2030493
# making new cascade
#
#
# OG Orders left:  2030493
# Cascade length:  2
# New Orders left:  2030491
# making new cascade
#
#
# OG Orders left:  2030491
# Cascade length:  1973
# New Orders left:  2028518
# making new cascade
#
#
# OG Orders left:  2028518
# Cascade length:  8
# New Orders left:  2028510
# making new cascade
#
#
# OG Orders left:  2028510
# Cascade length:  97
# New Orders left:  2028413
# making new cascade
#
#
# OG Orders left:  2028413
# Cascade length:  2
# New Orders left:  2028411
# making new cascade
#
#
# OG Orders left:  2028411
# Cascade length:  62
# New Orders left:  2028349
# making new cascade
#
#
# OG Orders left:  2028349
# Cascade length:  4
# New Orders left:  2028345
# making new cascade
#
#
# OG Orders left:  2028345
# Cascade length:  1
# New Orders left:  2028344
# making new cascade
#
#
# OG Orders left:  2028344
# Cascade length:  8
# New Orders left:  2028336
# making new cascade
#
#
# OG Orders left:  2028336
# Cascade length:  1
# New Orders left:  2028335
# making new cascade
#
#
# OG Orders left:  2028335
# Cascade length:  2
# New Orders left:  2028333
# making new cascade
#
#
# OG Orders left:  2028333
# Cascade length:  4
# New Orders left:  2028329
# making new cascade
#
#
# OG Orders left:  2028329
# Cascade length:  6
# New Orders left:  2028323
# making new cascade
#
#
# OG Orders left:  2028323
# Cascade length:  2
# New Orders left:  2028321
# making new cascade
#
#
# OG Orders left:  2028321
# Cascade length:  2
# New Orders left:  2028319
# making new cascade
#
#
# OG Orders left:  2028319
# Cascade length:  1185
# New Orders left:  2027134
# making new cascade
#
#
# OG Orders left:  2027134
# Cascade length:  1743
# New Orders left:  2025391
# making new cascade
#
#
# OG Orders left:  2025391
# Cascade length:  1078
# New Orders left:  2024313
# making new cascade
#
#
# OG Orders left:  2024313
# Cascade length:  2
# New Orders left:  2024311
# making new cascade
#
#
# OG Orders left:  2024311
# Cascade length:  1248
# New Orders left:  2023063
# making new cascade
#
#
# OG Orders left:  2023063
# Cascade length:  22
# New Orders left:  2023041
# making new cascade
#
#
# OG Orders left:  2023041
# Cascade length:  15
# New Orders left:  2023026
# making new cascade
#
#
# OG Orders left:  2023026
# Cascade length:  1175
# New Orders left:  2021851
# making new cascade
#
#
# OG Orders left:  2021851
# Cascade length:  3
# New Orders left:  2021848
# making new cascade
#
#
# OG Orders left:  2021848
# Cascade length:  7
# New Orders left:  2021841
# making new cascade
#
#
# OG Orders left:  2021841
# Cascade length:  2
# New Orders left:  2021839
# making new cascade
#
#
# OG Orders left:  2021839
# Cascade length:  1412
# New Orders left:  2020427
# making new cascade
#
#
# OG Orders left:  2020427
# Cascade length:  738
# New Orders left:  2019689
# making new cascade
#
#
# OG Orders left:  2019689
# Cascade length:  1
# New Orders left:  2019688
# making new cascade
#
#
# OG Orders left:  2019688
# Cascade length:  1185
# New Orders left:  2018503
# making new cascade
#
#
# OG Orders left:  2018503
# Cascade length:  568
# New Orders left:  2017935
# making new cascade
#
#
# OG Orders left:  2017935
# Cascade length:  373
# New Orders left:  2017562
# making new cascade
#
#
# OG Orders left:  2017562
# Cascade length:  1299
# New Orders left:  2016263
# making new cascade
#
#
# OG Orders left:  2016263
# Cascade length:  1
# New Orders left:  2016262
# making new cascade
#
#
# OG Orders left:  2016262
# Cascade length:  1218
# New Orders left:  2015044
# making new cascade
#
#
# OG Orders left:  2015044
# Cascade length:  7
# New Orders left:  2015037
# making new cascade
#
#
# OG Orders left:  2015037
# Cascade length:  1064
# New Orders left:  2013973
# making new cascade
#
#
# OG Orders left:  2013973
# Cascade length:  434
# New Orders left:  2013539
# making new cascade
#
#
# OG Orders left:  2013539
# Cascade length:  4
# New Orders left:  2013535
# making new cascade
#
#
# OG Orders left:  2013535
# Cascade length:  179
# New Orders left:  2013356
# making new cascade
#
#
# OG Orders left:  2013356
# Cascade length:  2
# New Orders left:  2013354
# making new cascade
#
#
# OG Orders left:  2013354
# Cascade length:  85
# New Orders left:  2013269
# making new cascade
#
#
# OG Orders left:  2013269
# Cascade length:  4
# New Orders left:  2013265
# making new cascade
#
#
# OG Orders left:  2013265
# Cascade length:  771
# New Orders left:  2012494
# making new cascade
#
#
# OG Orders left:  2012494
# Cascade length:  7
# New Orders left:  2012487
# making new cascade
#
#
# OG Orders left:  2012487
# Cascade length:  4
# New Orders left:  2012483
# making new cascade
#
#
# OG Orders left:  2012483
# Cascade length:  1
# New Orders left:  2012482
# making new cascade
#
#
# OG Orders left:  2012482
# Cascade length:  313
# New Orders left:  2012169
# making new cascade
#
#
# OG Orders left:  2012169
# Cascade length:  2
# New Orders left:  2012167
# making new cascade
#
#
# OG Orders left:  2012167
# Cascade length:  17
# New Orders left:  2012150
# making new cascade
#
#
# OG Orders left:  2012150
# Cascade length:  1
# New Orders left:  2012149
# making new cascade
#
#
# OG Orders left:  2012149
# Cascade length:  46
# New Orders left:  2012103
# making new cascade
#
#
# OG Orders left:  2012103
# Cascade length:  1341
# New Orders left:  2010762
# making new cascade
#
#
# OG Orders left:  2010762
# Cascade length:  5
# New Orders left:  2010757
# making new cascade
#
#
# OG Orders left:  2010757
# Cascade length:  3
# New Orders left:  2010754
# making new cascade
#
#
# OG Orders left:  2010754
# Cascade length:  4
# New Orders left:  2010750
# making new cascade
#
#
# OG Orders left:  2010750
# Cascade length:  970
# New Orders left:  2009780
# making new cascade
#
#
# OG Orders left:  2009780
# Cascade length:  1
# New Orders left:  2009779
# making new cascade
#
#
# OG Orders left:  2009779
# Cascade length:  980
# New Orders left:  2008799
# making new cascade
#
#
# OG Orders left:  2008799
# Cascade length:  9
# New Orders left:  2008790
# making new cascade
#
#
# OG Orders left:  2008790
# Cascade length:  689
# New Orders left:  2008101
# making new cascade
#
#
# OG Orders left:  2008101
# Cascade length:  711
# New Orders left:  2007390
# making new cascade
#
#
# OG Orders left:  2007390
# Cascade length:  2
# New Orders left:  2007388
# making new cascade
#
#
# OG Orders left:  2007388
# Cascade length:  3
# New Orders left:  2007385
# making new cascade
#
#
# OG Orders left:  2007385
# Cascade length:  12
# New Orders left:  2007373
# making new cascade
#
#
# OG Orders left:  2007373
# Cascade length:  5
# New Orders left:  2007368
# making new cascade
#
#
# OG Orders left:  2007368
# Cascade length:  992
# New Orders left:  2006376
# making new cascade
#
#
# OG Orders left:  2006376
# Cascade length:  746
# New Orders left:  2005630
# making new cascade
#
#
# OG Orders left:  2005630
# Cascade length:  823
# New Orders left:  2004807
# making new cascade
#
#
# OG Orders left:  2004807
# Cascade length:  406
# New Orders left:  2004401
# making new cascade
#
#
# OG Orders left:  2004401
# Cascade length:  9
# New Orders left:  2004392
# making new cascade
#
#
# OG Orders left:  2004392
# Cascade length:  794
# New Orders left:  2003598
# making new cascade
#
#
# OG Orders left:  2003598
# Cascade length:  5
# New Orders left:  2003593
# making new cascade
#
#
# OG Orders left:  2003593
# Cascade length:  6
# New Orders left:  2003587
# making new cascade
#
#
# OG Orders left:  2003587
# Cascade length:  1023
# New Orders left:  2002564
# making new cascade
#
#
# OG Orders left:  2002564
# Cascade length:  39
# New Orders left:  2002525
# making new cascade
#
#
# OG Orders left:  2002525
# Cascade length:  1644
# New Orders left:  2000881
# making new cascade
#
#
# OG Orders left:  2000881
# Cascade length:  401
# New Orders left:  2000480
# making new cascade
#
#
# OG Orders left:  2000480
# Cascade length:  13
# New Orders left:  2000467
# making new cascade
#
#
# OG Orders left:  2000467
# Cascade length:  868
# New Orders left:  1999599
# making new cascade
#
#
# OG Orders left:  1999599
# Cascade length:  624
# New Orders left:  1998975
# making new cascade
#
#
# OG Orders left:  1998975
# Cascade length:  2
# New Orders left:  1998973
# making new cascade
#
#
# OG Orders left:  1998973
# Cascade length:  6
# New Orders left:  1998967
# making new cascade
#
#
# OG Orders left:  1998967
# Cascade length:  220
# New Orders left:  1998747
# making new cascade
#
#
# OG Orders left:  1998747
# Cascade length:  17
# New Orders left:  1998730
# making new cascade
#
#
# OG Orders left:  1998730
# Cascade length:  2
# New Orders left:  1998728
# making new cascade
#
#
# OG Orders left:  1998728
# Cascade length:  319
# New Orders left:  1998409
# making new cascade
#
#
# OG Orders left:  1998409
# Cascade length:  721
# New Orders left:  1997688
# making new cascade
#
#
# OG Orders left:  1997688
# Cascade length:  3
# New Orders left:  1997685
# making new cascade
#
#
# OG Orders left:  1997685
# Cascade length:  3
# New Orders left:  1997682
# making new cascade
#
#
# OG Orders left:  1997682
# Cascade length:  268
# New Orders left:  1997414
# making new cascade
#
#
# OG Orders left:  1997414
# Cascade length:  24
# New Orders left:  1997390
# making new cascade
#
#
# OG Orders left:  1997390
# Cascade length:  12
# New Orders left:  1997378
# making new cascade
#
#
# OG Orders left:  1997378
# Cascade length:  2
# New Orders left:  1997376
# making new cascade
#
#
# OG Orders left:  1997376
# Cascade length:  1120
# New Orders left:  1996256
# making new cascade
#
#
# OG Orders left:  1996256
# Cascade length:  746
# New Orders left:  1995510
# making new cascade
#
#
# OG Orders left:  1995510
# Cascade length:  8
# New Orders left:  1995502
# making new cascade
#
#
# OG Orders left:  1995502
# Cascade length:  7
# New Orders left:  1995495
# making new cascade
#
#
# OG Orders left:  1995495
# Cascade length:  1
# New Orders left:  1995494
# making new cascade
#
#
# OG Orders left:  1995494
# Cascade length:  20
# New Orders left:  1995474
# making new cascade
#
#
# OG Orders left:  1995474
# Cascade length:  9
# New Orders left:  1995465
# making new cascade
#
#
# OG Orders left:  1995465
# Cascade length:  527
# New Orders left:  1994938
# making new cascade
#
#
# OG Orders left:  1994938
# Cascade length:  2
# New Orders left:  1994936
# making new cascade
#
#
# OG Orders left:  1994936
# Cascade length:  11
# New Orders left:  1994925
# making new cascade
#
#
# OG Orders left:  1994925
# Cascade length:  1174
# New Orders left:  1993751
# making new cascade
#
#
# OG Orders left:  1993751
# Cascade length:  1011
# New Orders left:  1992740
# making new cascade
#
#
# OG Orders left:  1992740
# Cascade length:  7
# New Orders left:  1992733
# making new cascade
#
#
# OG Orders left:  1992733
# Cascade length:  1036
# New Orders left:  1991697
# making new cascade
#
#
# OG Orders left:  1991697
# Cascade length:  2
# New Orders left:  1991695
# making new cascade
#
#
# OG Orders left:  1991695
# Cascade length:  66
# New Orders left:  1991629
# making new cascade
#
#
# OG Orders left:  1991629
# Cascade length:  9
# New Orders left:  1991620
# making new cascade
#
#
# OG Orders left:  1991620
# Cascade length:  2
# New Orders left:  1991618
# making new cascade
#
#
# OG Orders left:  1991618
# Cascade length:  11
# New Orders left:  1991607
# making new cascade
#
#
# OG Orders left:  1991607
# Cascade length:  27
# New Orders left:  1991580
# making new cascade
#
#
# OG Orders left:  1991580
# Cascade length:  1
# New Orders left:  1991579
# making new cascade
#
#
# OG Orders left:  1991579
# Cascade length:  810
# New Orders left:  1990769
# making new cascade
#
#
# OG Orders left:  1990769
# Cascade length:  1
# New Orders left:  1990768
# making new cascade
#
#
# OG Orders left:  1990768
# Cascade length:  1
# New Orders left:  1990767
# making new cascade
#
#
# OG Orders left:  1990767
# Cascade length:  20
# New Orders left:  1990747
# making new cascade
#
#
# OG Orders left:  1990747
# Cascade length:  10
# New Orders left:  1990737
# making new cascade
#
#
# OG Orders left:  1990737
# Cascade length:  450
# New Orders left:  1990287
# making new cascade
#
#
# OG Orders left:  1990287
# Cascade length:  2
# New Orders left:  1990285
# making new cascade
#
#
# OG Orders left:  1990285
# Cascade length:  5
# New Orders left:  1990280
# making new cascade
#
#
# OG Orders left:  1990280
# Cascade length:  596
# New Orders left:  1989684
# making new cascade
#
#
# OG Orders left:  1989684
# Cascade length:  1313
# New Orders left:  1988371
# making new cascade
#
#
# OG Orders left:  1988371
# Cascade length:  869
# New Orders left:  1987502
# making new cascade
#
#
# OG Orders left:  1987502
# Cascade length:  5
# New Orders left:  1987497
# making new cascade
#
#
# OG Orders left:  1987497
# Cascade length:  15
# New Orders left:  1987482
# making new cascade
#
#
# OG Orders left:  1987482
# Cascade length:  2
# New Orders left:  1987480
# making new cascade
#
#
# OG Orders left:  1987480
# Cascade length:  964
# New Orders left:  1986516
# making new cascade
#
#
# OG Orders left:  1986516
# Cascade length:  3
# New Orders left:  1986513
# making new cascade
#
#
# OG Orders left:  1986513
# Cascade length:  795
# New Orders left:  1985718
# making new cascade
#
#
# OG Orders left:  1985718
# Cascade length:  2
# New Orders left:  1985716
# making new cascade
#
#
# OG Orders left:  1985716
# Cascade length:  688
# New Orders left:  1985028
# making new cascade
#
#
# OG Orders left:  1985028
# Cascade length:  4
# New Orders left:  1985024
# making new cascade
#
#
# OG Orders left:  1985024
# Cascade length:  1012
# New Orders left:  1984012
# making new cascade
#
#
# OG Orders left:  1984012
# Cascade length:  27
# New Orders left:  1983985
# making new cascade
#
#
# OG Orders left:  1983985
# Cascade length:  1112
# New Orders left:  1982873
# making new cascade
#
#
# OG Orders left:  1982873
# Cascade length:  1409
# New Orders left:  1981464
# making new cascade
#
#
# OG Orders left:  1981464
# Cascade length:  7
# New Orders left:  1981457
# making new cascade
#
#
# OG Orders left:  1981457
# Cascade length:  2
# New Orders left:  1981455
# making new cascade
#
#
# OG Orders left:  1981455
# Cascade length:  2
# New Orders left:  1981453
# making new cascade
#
#
# OG Orders left:  1981453
# Cascade length:  1310
# New Orders left:  1980143
# making new cascade
#
#
# OG Orders left:  1980143
# Cascade length:  8
# New Orders left:  1980135
# making new cascade
#
#
# OG Orders left:  1980135
# Cascade length:  844
# New Orders left:  1979291
# making new cascade
#
#
# OG Orders left:  1979291
# Cascade length:  214
# New Orders left:  1979077
# making new cascade
#
#
# OG Orders left:  1979077
# Cascade length:  6
# New Orders left:  1979071
# making new cascade
#
#
# OG Orders left:  1979071
# Cascade length:  406
# New Orders left:  1978665
# making new cascade
#
#
# OG Orders left:  1978665
# Cascade length:  4
# New Orders left:  1978661
# making new cascade
#
#
# OG Orders left:  1978661
# Cascade length:  2
# New Orders left:  1978659
# making new cascade
#
#
# OG Orders left:  1978659
# Cascade length:  11
# New Orders left:  1978648
# making new cascade
#
#
# OG Orders left:  1978648
# Cascade length:  1769
# New Orders left:  1976879
# making new cascade
#
#
# OG Orders left:  1976879
# Cascade length:  462
# New Orders left:  1976417
# making new cascade
#
#
# OG Orders left:  1976417
# Cascade length:  2
# New Orders left:  1976415
# making new cascade
#
#
# OG Orders left:  1976415
# Cascade length:  4
# New Orders left:  1976411
# making new cascade
#
#
# OG Orders left:  1976411
# Cascade length:  145
# New Orders left:  1976266
# making new cascade
#
#
# OG Orders left:  1976266
# Cascade length:  8
# New Orders left:  1976258
# making new cascade
#
#
# OG Orders left:  1976258
# Cascade length:  837
# New Orders left:  1975421
# making new cascade
#
#
# OG Orders left:  1975421
# Cascade length:  2
# New Orders left:  1975419
# making new cascade
#
#
# OG Orders left:  1975419
# Cascade length:  4
# New Orders left:  1975415
# making new cascade
#
#
# OG Orders left:  1975415
# Cascade length:  5
# New Orders left:  1975410
# making new cascade
#
#
# OG Orders left:  1975410
# Cascade length:  268
# New Orders left:  1975142
# making new cascade
#
#
# OG Orders left:  1975142
# Cascade length:  5
# New Orders left:  1975137
# making new cascade
#
#
# OG Orders left:  1975137
# Cascade length:  610
# New Orders left:  1974527
# making new cascade
#
#
# OG Orders left:  1974527
# Cascade length:  332
# New Orders left:  1974195
# making new cascade
#
#
# OG Orders left:  1974195
# Cascade length:  552
# New Orders left:  1973643
# making new cascade
#
#
# OG Orders left:  1973643
# Cascade length:  2
# New Orders left:  1973641
# making new cascade
#
#
# OG Orders left:  1973641
# Cascade length:  1
# New Orders left:  1973640
# making new cascade
#
#
# OG Orders left:  1973640
# Cascade length:  14
# New Orders left:  1973626
# making new cascade
#
#
# OG Orders left:  1973626
# Cascade length:  1135
# New Orders left:  1972491
# making new cascade
#
#
# OG Orders left:  1972491
# Cascade length:  1
# New Orders left:  1972490
# making new cascade
#
#
# OG Orders left:  1972490
# Cascade length:  4
# New Orders left:  1972486
# making new cascade
#
#
# OG Orders left:  1972486
# Cascade length:  21
# New Orders left:  1972465
# making new cascade
#
#
# OG Orders left:  1972465
# Cascade length:  190
# New Orders left:  1972275
# making new cascade
#
#
# OG Orders left:  1972275
# Cascade length:  2
# New Orders left:  1972273
# making new cascade
#
#
# OG Orders left:  1972273
# Cascade length:  1079
# New Orders left:  1971194
# making new cascade
#
#
# OG Orders left:  1971194
# Cascade length:  2
# New Orders left:  1971192
# making new cascade
#
#
# OG Orders left:  1971192
# Cascade length:  463
# New Orders left:  1970729
# making new cascade
#
#
# OG Orders left:  1970729
# Cascade length:  771
# New Orders left:  1969958
# making new cascade
#
#
# OG Orders left:  1969958
# Cascade length:  620
# New Orders left:  1969338
# making new cascade
#
#
# OG Orders left:  1969338
# Cascade length:  968
# New Orders left:  1968370
# making new cascade
#
#
# OG Orders left:  1968370
# Cascade length:  1013
# New Orders left:  1967357
# making new cascade
#
#
# OG Orders left:  1967357
# Cascade length:  3
# New Orders left:  1967354
# making new cascade
#
#
# OG Orders left:  1967354
# Cascade length:  8
# New Orders left:  1967346
# making new cascade
#
#
# OG Orders left:  1967346
# Cascade length:  10
# New Orders left:  1967336
# making new cascade
#
#
# OG Orders left:  1967336
# Cascade length:  437
# New Orders left:  1966899
# making new cascade
#
#
# OG Orders left:  1966899
# Cascade length:  2
# New Orders left:  1966897
# making new cascade
#
#
# OG Orders left:  1966897
# Cascade length:  6
# New Orders left:  1966891
# making new cascade
#
#
# OG Orders left:  1966891
# Cascade length:  557
# New Orders left:  1966334
# making new cascade
#
#
# OG Orders left:  1966334
# Cascade length:  319
# New Orders left:  1966015
# making new cascade
#
#
# OG Orders left:  1966015
# Cascade length:  18
# New Orders left:  1965997
# making new cascade
#
#
# OG Orders left:  1965997
# Cascade length:  7
# New Orders left:  1965990
# making new cascade
#
#
# OG Orders left:  1965990
# Cascade length:  854
# New Orders left:  1965136
# making new cascade
#
#
# OG Orders left:  1965136
# Cascade length:  1133
# New Orders left:  1964003
# making new cascade
#
#
# OG Orders left:  1964003
# Cascade length:  2
# New Orders left:  1964001
# making new cascade
#
#
# OG Orders left:  1964001
# Cascade length:  3
# New Orders left:  1963998
# making new cascade
#
#
# OG Orders left:  1963998
# Cascade length:  1
# New Orders left:  1963997
# making new cascade
#
#
# OG Orders left:  1963997
# Cascade length:  4
# New Orders left:  1963993
# making new cascade
#
#
# OG Orders left:  1963993
# Cascade length:  109
# New Orders left:  1963884
# making new cascade
#
#
# OG Orders left:  1963884
# Cascade length:  2
# New Orders left:  1963882
# making new cascade
#
#
# OG Orders left:  1963882
# Cascade length:  718
# New Orders left:  1963164
# making new cascade
#
#
# OG Orders left:  1963164
# Cascade length:  6
# New Orders left:  1963158
# making new cascade
#
#
# OG Orders left:  1963158
# Cascade length:  2
# New Orders left:  1963156
# making new cascade
#
#
# OG Orders left:  1963156
# Cascade length:  759
# New Orders left:  1962397
# making new cascade
#
#
# OG Orders left:  1962397
# Cascade length:  7
# New Orders left:  1962390
# making new cascade
#
#
# OG Orders left:  1962390
# Cascade length:  728
# New Orders left:  1961662
# making new cascade
#
#
# OG Orders left:  1961662
# Cascade length:  15
# New Orders left:  1961647
# making new cascade
#
#
# OG Orders left:  1961647
# Cascade length:  556
# New Orders left:  1961091
# making new cascade
#
#
# OG Orders left:  1961091
# Cascade length:  1095
# New Orders left:  1959996
# making new cascade
#
#
# OG Orders left:  1959996
# Cascade length:  2
# New Orders left:  1959994
# making new cascade
#
#
# OG Orders left:  1959994
# Cascade length:  1
# New Orders left:  1959993
# making new cascade
#
#
# OG Orders left:  1959993
# Cascade length:  560
# New Orders left:  1959433
# making new cascade
#
#
# OG Orders left:  1959433
# Cascade length:  1
# New Orders left:  1959432
# making new cascade
#
#
# OG Orders left:  1959432
# Cascade length:  8
# New Orders left:  1959424
# making new cascade
#
#
# OG Orders left:  1959424
# Cascade length:  316
# New Orders left:  1959108
# making new cascade
#
#
# OG Orders left:  1959108
# Cascade length:  4
# New Orders left:  1959104
# making new cascade
#
#
# OG Orders left:  1959104
# Cascade length:  7
# New Orders left:  1959097
# making new cascade
#
#
# OG Orders left:  1959097
# Cascade length:  1
# New Orders left:  1959096
# making new cascade
#
#
# OG Orders left:  1959096
# Cascade length:  4
# New Orders left:  1959092
# making new cascade
#
#
# OG Orders left:  1959092
# Cascade length:  826
# New Orders left:  1958266
# making new cascade
#
#
# OG Orders left:  1958266
# Cascade length:  2
# New Orders left:  1958264
# making new cascade
#
#
# OG Orders left:  1958264
# Cascade length:  693
# New Orders left:  1957571
# making new cascade
#
#
# OG Orders left:  1957571
# Cascade length:  573
# New Orders left:  1956998
# making new cascade
#
#
# OG Orders left:  1956998
# Cascade length:  477
# New Orders left:  1956521
# making new cascade
#
#
# OG Orders left:  1956521
# Cascade length:  2
# New Orders left:  1956519
# making new cascade
#
#
# OG Orders left:  1956519
# Cascade length:  2
# New Orders left:  1956517
# making new cascade
#
#
# OG Orders left:  1956517
# Cascade length:  2
# New Orders left:  1956515
# making new cascade
#
#
# OG Orders left:  1956515
# Cascade length:  13
# New Orders left:  1956502
# making new cascade
#
#
# OG Orders left:  1956502
# Cascade length:  8
# New Orders left:  1956494
# making new cascade
#
#
# OG Orders left:  1956494
# Cascade length:  10
# New Orders left:  1956484
# making new cascade
#
#
# OG Orders left:  1956484
# Cascade length:  4
# New Orders left:  1956480
# making new cascade
#
#
# OG Orders left:  1956480
# Cascade length:  1
# New Orders left:  1956479
# making new cascade
#
#
# OG Orders left:  1956479
# Cascade length:  1
# New Orders left:  1956478
# making new cascade
#
#
# OG Orders left:  1956478
# Cascade length:  9
# New Orders left:  1956469
# making new cascade
#
#
# OG Orders left:  1956469
# Cascade length:  464
# New Orders left:  1956005
# making new cascade
#
#
# OG Orders left:  1956005
# Cascade length:  1200
# New Orders left:  1954805
# making new cascade
#
#
# OG Orders left:  1954805
# Cascade length:  679
# New Orders left:  1954126
# making new cascade
#
#
# OG Orders left:  1954126
# Cascade length:  116
# New Orders left:  1954010
# making new cascade
#
#
# OG Orders left:  1954010
# Cascade length:  112
# New Orders left:  1953898
# making new cascade
#
#
# OG Orders left:  1953898
# Cascade length:  9
# New Orders left:  1953889
# making new cascade
#
#
# OG Orders left:  1953889
# Cascade length:  1
# New Orders left:  1953888
# making new cascade
#
#
# OG Orders left:  1953888
# Cascade length:  1000
# New Orders left:  1952888
# making new cascade
#
#
# OG Orders left:  1952888
# Cascade length:  14
# New Orders left:  1952874
# making new cascade
#
#
# OG Orders left:  1952874
# Cascade length:  69
# New Orders left:  1952805
# making new cascade
#
#
# OG Orders left:  1952805
# Cascade length:  8
# New Orders left:  1952797
# making new cascade
#
#
# OG Orders left:  1952797
# Cascade length:  705
# New Orders left:  1952092
# making new cascade
#
#
# OG Orders left:  1952092
# Cascade length:  54
# New Orders left:  1952038
# making new cascade
#
#
# OG Orders left:  1952038
# Cascade length:  56
# New Orders left:  1951982
# making new cascade
#
#
# OG Orders left:  1951982
# Cascade length:  144
# New Orders left:  1951838
# making new cascade
#
#
# OG Orders left:  1951838
# Cascade length:  20
# New Orders left:  1951818
# making new cascade
#
#
# OG Orders left:  1951818
# Cascade length:  1
# New Orders left:  1951817
# making new cascade
#
#
# OG Orders left:  1951817
# Cascade length:  415
# New Orders left:  1951402
# making new cascade
#
#
# OG Orders left:  1951402
# Cascade length:  3
# New Orders left:  1951399
# making new cascade
#
#
# OG Orders left:  1951399
# Cascade length:  562
# New Orders left:  1950837
# making new cascade
#
#
# OG Orders left:  1950837
# Cascade length:  655
# New Orders left:  1950182
# making new cascade
#
#
# OG Orders left:  1950182
# Cascade length:  18
# New Orders left:  1950164
# making new cascade
#
#
# OG Orders left:  1950164
# Cascade length:  6
# New Orders left:  1950158
# making new cascade
#
#
# OG Orders left:  1950158
# Cascade length:  11
# New Orders left:  1950147
# making new cascade
#
#
# OG Orders left:  1950147
# Cascade length:  2
# New Orders left:  1950145
# making new cascade
#
#
# OG Orders left:  1950145
# Cascade length:  4
# New Orders left:  1950141
# making new cascade
#
#
# OG Orders left:  1950141
# Cascade length:  373
# New Orders left:  1949768
# making new cascade
#
#
# OG Orders left:  1949768
# Cascade length:  65
# New Orders left:  1949703
# making new cascade
#
#
# OG Orders left:  1949703
# Cascade length:  614
# New Orders left:  1949089
# making new cascade
#
#
# OG Orders left:  1949089
# Cascade length:  2
# New Orders left:  1949087
# making new cascade
#
#
# OG Orders left:  1949087
# Cascade length:  64
# New Orders left:  1949023
# making new cascade
#
#
# OG Orders left:  1949023
# Cascade length:  14
# New Orders left:  1949009
# making new cascade
#
#
# OG Orders left:  1949009
# Cascade length:  1100
# New Orders left:  1947909
# making new cascade
#
#
# OG Orders left:  1947909
# Cascade length:  453
# New Orders left:  1947456
# making new cascade
#
#
# OG Orders left:  1947456
# Cascade length:  808
# New Orders left:  1946648
# making new cascade
#
#
# OG Orders left:  1946648
# Cascade length:  10
# New Orders left:  1946638
# making new cascade
#
#
# OG Orders left:  1946638
# Cascade length:  495
# New Orders left:  1946143
# making new cascade
#
#
# OG Orders left:  1946143
# Cascade length:  17
# New Orders left:  1946126
# making new cascade
#
#
# OG Orders left:  1946126
# Cascade length:  12
# New Orders left:  1946114
# making new cascade
#
#
# OG Orders left:  1946114
# Cascade length:  320
# New Orders left:  1945794
# making new cascade
#
#
# OG Orders left:  1945794
# Cascade length:  2
# New Orders left:  1945792
# making new cascade
#
#
# OG Orders left:  1945792
# Cascade length:  2
# New Orders left:  1945790
# making new cascade
#
#
# OG Orders left:  1945790
# Cascade length:  1
# New Orders left:  1945789
# making new cascade
#
#
# OG Orders left:  1945789
# Cascade length:  432
# New Orders left:  1945357
# making new cascade
#
#
# OG Orders left:  1945357
# Cascade length:  480
# New Orders left:  1944877
# making new cascade
#
#
# OG Orders left:  1944877
# Cascade length:  4
# New Orders left:  1944873
# making new cascade
#
#
# OG Orders left:  1944873
# Cascade length:  6
# New Orders left:  1944867
# making new cascade
#
#
# OG Orders left:  1944867
# Cascade length:  938
# New Orders left:  1943929
# making new cascade
#
#
# OG Orders left:  1943929
# Cascade length:  1
# New Orders left:  1943928
# making new cascade
#
#
# OG Orders left:  1943928
# Cascade length:  9
# New Orders left:  1943919
# making new cascade
#
#
# OG Orders left:  1943919
# Cascade length:  846
# New Orders left:  1943073
# making new cascade
#
#
# OG Orders left:  1943073
# Cascade length:  4
# New Orders left:  1943069
# making new cascade
#
#
# OG Orders left:  1943069
# Cascade length:  24
# New Orders left:  1943045
# making new cascade
#
#
# OG Orders left:  1943045
# Cascade length:  2
# New Orders left:  1943043
# making new cascade
#
#
# OG Orders left:  1943043
# Cascade length:  76
# New Orders left:  1942967
# making new cascade
#
#
# OG Orders left:  1942967
# Cascade length:  51
# New Orders left:  1942916
# making new cascade
#
#
# OG Orders left:  1942916
# Cascade length:  40
# New Orders left:  1942876
# making new cascade
#
#
# OG Orders left:  1942876
# Cascade length:  1185
# New Orders left:  1941691
# making new cascade
#
#
# OG Orders left:  1941691
# Cascade length:  44
# New Orders left:  1941647
# making new cascade
#
#
# OG Orders left:  1941647
# Cascade length:  678
# New Orders left:  1940969
# making new cascade
#
#
# OG Orders left:  1940969
# Cascade length:  585
# New Orders left:  1940384
# making new cascade
#
#
# OG Orders left:  1940384
# Cascade length:  2
# New Orders left:  1940382
# making new cascade
#
#
# OG Orders left:  1940382
# Cascade length:  6
# New Orders left:  1940376
# making new cascade
#
#
# OG Orders left:  1940376
# Cascade length:  1732
# New Orders left:  1938644
# making new cascade
#
#
# OG Orders left:  1938644
# Cascade length:  13
# New Orders left:  1938631
# making new cascade
#
#
# OG Orders left:  1938631
# Cascade length:  3
# New Orders left:  1938628
# making new cascade
#
#
# OG Orders left:  1938628
# Cascade length:  56
# New Orders left:  1938572
# making new cascade
#
#
# OG Orders left:  1938572
# Cascade length:  16
# New Orders left:  1938556
# making new cascade
#
#
# OG Orders left:  1938556
# Cascade length:  398
# New Orders left:  1938158
# making new cascade
#
#
# OG Orders left:  1938158
# Cascade length:  64
# New Orders left:  1938094
# making new cascade
#
#
# OG Orders left:  1938094
# Cascade length:  668
# New Orders left:  1937426
# making new cascade
#
#
# OG Orders left:  1937426
# Cascade length:  1
# New Orders left:  1937425
# making new cascade
#
#
# OG Orders left:  1937425
# Cascade length:  55
# New Orders left:  1937370
# making new cascade
#
#
# OG Orders left:  1937370
# Cascade length:  218
# New Orders left:  1937152
# making new cascade
#
#
# OG Orders left:  1937152
# Cascade length:  1
# New Orders left:  1937151
# making new cascade
#
#
# OG Orders left:  1937151
# Cascade length:  385
# New Orders left:  1936766
# making new cascade
#
#
# OG Orders left:  1936766
# Cascade length:  2
# New Orders left:  1936764
# making new cascade
#
#
# OG Orders left:  1936764
# Cascade length:  540
# New Orders left:  1936224
# making new cascade
#
#
# OG Orders left:  1936224
# Cascade length:  132
# New Orders left:  1936092
# making new cascade
#
#
# OG Orders left:  1936092
# Cascade length:  2
# New Orders left:  1936090
# making new cascade
#
#
# OG Orders left:  1936090
# Cascade length:  12
# New Orders left:  1936078
# making new cascade
#
#
# OG Orders left:  1936078
# Cascade length:  6
# New Orders left:  1936072
# making new cascade
#
#
# OG Orders left:  1936072
# Cascade length:  1082
# New Orders left:  1934990
# making new cascade
#
#
# OG Orders left:  1934990
# Cascade length:  35
# New Orders left:  1934955
# making new cascade
#
#
# OG Orders left:  1934955
# Cascade length:  930
# New Orders left:  1934025
# making new cascade
#
#
# OG Orders left:  1934025
# Cascade length:  176
# New Orders left:  1933849
# making new cascade
#
#
# OG Orders left:  1933849
# Cascade length:  6
# New Orders left:  1933843
# making new cascade
#
#
# OG Orders left:  1933843
# Cascade length:  18
# New Orders left:  1933825
# making new cascade
#
#
# OG Orders left:  1933825
# Cascade length:  69
# New Orders left:  1933756
# making new cascade
#
#
# OG Orders left:  1933756
# Cascade length:  395
# New Orders left:  1933361
# making new cascade
#
#
# OG Orders left:  1933361
# Cascade length:  3
# New Orders left:  1933358
# making new cascade
#
#
# OG Orders left:  1933358
# Cascade length:  2
# New Orders left:  1933356
# making new cascade
#
#
# OG Orders left:  1933356
# Cascade length:  256
# New Orders left:  1933100
# making new cascade
#
#
# OG Orders left:  1933100
# Cascade length:  308
# New Orders left:  1932792
# making new cascade
#
#
# OG Orders left:  1932792
# Cascade length:  4
# New Orders left:  1932788
# making new cascade
#
#
# OG Orders left:  1932788
# Cascade length:  490
# New Orders left:  1932298
# making new cascade
#
#
# OG Orders left:  1932298
# Cascade length:  2
# New Orders left:  1932296
# making new cascade
#
#
# OG Orders left:  1932296
# Cascade length:  9
# New Orders left:  1932287
# making new cascade
#
#
# OG Orders left:  1932287
# Cascade length:  4
# New Orders left:  1932283
# making new cascade
#
#
# OG Orders left:  1932283
# Cascade length:  685
# New Orders left:  1931598
# making new cascade
#
#
# OG Orders left:  1931598
# Cascade length:  10
# New Orders left:  1931588
# making new cascade
#
#
# OG Orders left:  1931588
# Cascade length:  1
# New Orders left:  1931587
# making new cascade
#
#
# OG Orders left:  1931587
# Cascade length:  15
# New Orders left:  1931572
# making new cascade
#
#
# OG Orders left:  1931572
# Cascade length:  19
# New Orders left:  1931553
# making new cascade
#
#
# OG Orders left:  1931553
# Cascade length:  1148
# New Orders left:  1930405
# making new cascade
#
#
# OG Orders left:  1930405
# Cascade length:  1
# New Orders left:  1930404
# making new cascade
#
#
# OG Orders left:  1930404
# Cascade length:  10
# New Orders left:  1930394
# making new cascade
#
#
# OG Orders left:  1930394
# Cascade length:  3
# New Orders left:  1930391
# making new cascade
#
#
# OG Orders left:  1930391
# Cascade length:  10
# New Orders left:  1930381
# making new cascade
#
#
# OG Orders left:  1930381
# Cascade length:  80
# New Orders left:  1930301
# making new cascade
#
#
# OG Orders left:  1930301
# Cascade length:  41
# New Orders left:  1930260
# making new cascade
#
#
# OG Orders left:  1930260
# Cascade length:  2
# New Orders left:  1930258
# making new cascade
#
#
# OG Orders left:  1930258
# Cascade length:  161
# New Orders left:  1930097
# making new cascade
#
#
# OG Orders left:  1930097
# Cascade length:  1
# New Orders left:  1930096
# making new cascade
#
#
# OG Orders left:  1930096
# Cascade length:  571
# New Orders left:  1929525
# making new cascade
#
#
# OG Orders left:  1929525
# Cascade length:  479
# New Orders left:  1929046
# making new cascade
#
#
# OG Orders left:  1929046
# Cascade length:  32
# New Orders left:  1929014
# making new cascade
#
#
# OG Orders left:  1929014
# Cascade length:  2
# New Orders left:  1929012
# making new cascade
#
#
# OG Orders left:  1929012
# Cascade length:  2
# New Orders left:  1929010
# making new cascade
#
#
# OG Orders left:  1929010
# Cascade length:  2
# New Orders left:  1929008
# making new cascade
#
#
# OG Orders left:  1929008
# Cascade length:  1
# New Orders left:  1929007
# making new cascade
#
#
# OG Orders left:  1929007
# Cascade length:  4
# New Orders left:  1929003
# making new cascade
#
#
# OG Orders left:  1929003
# Cascade length:  5
# New Orders left:  1928998
# making new cascade
#
#
# OG Orders left:  1928998
# Cascade length:  7
# New Orders left:  1928991
# making new cascade
#
#
# OG Orders left:  1928991
# Cascade length:  753
# New Orders left:  1928238
# making new cascade
#
#
# OG Orders left:  1928238
# Cascade length:  31
# New Orders left:  1928207
# making new cascade
#
#
# OG Orders left:  1928207
# Cascade length:  2
# New Orders left:  1928205
# making new cascade
#
#
# OG Orders left:  1928205
# Cascade length:  591
# New Orders left:  1927614
# making new cascade
#
#
# OG Orders left:  1927614
# Cascade length:  1
# New Orders left:  1927613
# making new cascade
#
#
# OG Orders left:  1927613
# Cascade length:  302
# New Orders left:  1927311
# making new cascade
#
#
# OG Orders left:  1927311
# Cascade length:  23
# New Orders left:  1927288
# making new cascade
#
#
# OG Orders left:  1927288
# Cascade length:  193
# New Orders left:  1927095
# making new cascade
#
#
# OG Orders left:  1927095
# Cascade length:  29
# New Orders left:  1927066
# making new cascade
#
#
# OG Orders left:  1927066
# Cascade length:  8
# New Orders left:  1927058
# making new cascade
#
#
# OG Orders left:  1927058
# Cascade length:  7
# New Orders left:  1927051
# making new cascade
#
#
# OG Orders left:  1927051
# Cascade length:  916
# New Orders left:  1926135
# making new cascade
#
#
# OG Orders left:  1926135
# Cascade length:  12
# New Orders left:  1926123
# making new cascade
#
#
# OG Orders left:  1926123
# Cascade length:  1
# New Orders left:  1926122
# making new cascade
#
#
# OG Orders left:  1926122
# Cascade length:  525
# New Orders left:  1925597
# making new cascade
#
#
# OG Orders left:  1925597
# Cascade length:  72
# New Orders left:  1925525
# making new cascade
#
#
# OG Orders left:  1925525
# Cascade length:  37
# New Orders left:  1925488
# making new cascade
#
#
# OG Orders left:  1925488
# Cascade length:  38
# New Orders left:  1925450
# making new cascade
#
#
# OG Orders left:  1925450
# Cascade length:  4
# New Orders left:  1925446
# making new cascade
#
#
# OG Orders left:  1925446
# Cascade length:  410
# New Orders left:  1925036
# making new cascade
#
#
# OG Orders left:  1925036
# Cascade length:  1052
# New Orders left:  1923984
# making new cascade
#
#
# OG Orders left:  1923984
# Cascade length:  794
# New Orders left:  1923190
# making new cascade
#
#
# OG Orders left:  1923190
# Cascade length:  1
# New Orders left:  1923189
# making new cascade
#
#
# OG Orders left:  1923189
# Cascade length:  2
# New Orders left:  1923187
# making new cascade
#
#
# OG Orders left:  1923187
# Cascade length:  7
# New Orders left:  1923180
# making new cascade
#
#
# OG Orders left:  1923180
# Cascade length:  2
# New Orders left:  1923178
# making new cascade
#
#
# OG Orders left:  1923178
# Cascade length:  3
# New Orders left:  1923175
# making new cascade
#
#
# OG Orders left:  1923175
# Cascade length:  2
# New Orders left:  1923173
# making new cascade
#
#
# OG Orders left:  1923173
# Cascade length:  145
# New Orders left:  1923028
# making new cascade
#
#
# OG Orders left:  1923028
# Cascade length:  75
# New Orders left:  1922953
# making new cascade
#
#
# OG Orders left:  1922953
# Cascade length:  21
# New Orders left:  1922932
# making new cascade
#
#
# OG Orders left:  1922932
# Cascade length:  17
# New Orders left:  1922915
# making new cascade
#
#
# OG Orders left:  1922915
# Cascade length:  390
# New Orders left:  1922525
# making new cascade
#
#
# OG Orders left:  1922525
# Cascade length:  1534
# New Orders left:  1920991
# making new cascade
#
#
# OG Orders left:  1920991
# Cascade length:  9
# New Orders left:  1920982
# making new cascade
#
#
# OG Orders left:  1920982
# Cascade length:  3
# New Orders left:  1920979
# making new cascade
#
#
# OG Orders left:  1920979
# Cascade length:  27
# New Orders left:  1920952
# making new cascade
#
#
# OG Orders left:  1920952
# Cascade length:  19
# New Orders left:  1920933
# making new cascade
#
#
# OG Orders left:  1920933
# Cascade length:  381
# New Orders left:  1920552
# making new cascade
#
#
# OG Orders left:  1920552
# Cascade length:  4
# New Orders left:  1920548
# making new cascade
#
#
# OG Orders left:  1920548
# Cascade length:  314
# New Orders left:  1920234
# making new cascade
#
#
# OG Orders left:  1920234
# Cascade length:  27
# New Orders left:  1920207
# making new cascade
#
#
# OG Orders left:  1920207
# Cascade length:  12
# New Orders left:  1920195
# making new cascade
#
#
# OG Orders left:  1920195
# Cascade length:  2
# New Orders left:  1920193
# making new cascade
#
#
# OG Orders left:  1920193
# Cascade length:  12
# New Orders left:  1920181
# making new cascade
#
#
# OG Orders left:  1920181
# Cascade length:  238
# New Orders left:  1919943
# making new cascade
#
#
# OG Orders left:  1919943
# Cascade length:  5
# New Orders left:  1919938
# making new cascade
#
#
# OG Orders left:  1919938
# Cascade length:  429
# New Orders left:  1919509
# making new cascade
#
#
# OG Orders left:  1919509
# Cascade length:  410
# ...
# Cascade length:  8
# New Orders left:  5357
# making new cascade
#
#
# OG Orders left:  5357
# Cascade length:  38
# New Orders left:  5319
# making new cascade
#
#
# OG Orders left:  5319
# Cascade length:  61
# New Orders left:  5258
# making new cascade
#
#
# OG Orders left:  5258
# Cascade length:  76
# New Orders left:  5182
# making new cascade
#
#
# OG Orders left:  5182
# Cascade length:  87
# New Orders left:  5095
# making new cascade
#
#
# OG Orders left:  5095
# Cascade length:  73
# New Orders left:  5022
# making new cascade
#
#
# OG Orders left:  5022
# Cascade length:  121
# New Orders left:  4901
# making new cascade
#
#
# OG Orders left:  4901
# Cascade length:  13
# New Orders left:  4888
# making new cascade
#
#
# OG Orders left:  4888
# Cascade length:  111
# New Orders left:  4777
# making new cascade
#
#
# OG Orders left:  4777
# Cascade length:  12
# New Orders left:  4765
# making new cascade
#
#
# OG Orders left:  4765
# Cascade length:  1
# New Orders left:  4764
# making new cascade
#
#
# OG Orders left:  4764
# Cascade length:  1
# New Orders left:  4763
# making new cascade
#
#
# OG Orders left:  4763
# Cascade length:  4
# New Orders left:  4759
# making new cascade
#
#
# OG Orders left:  4759
# Cascade length:  2
# New Orders left:  4757
# making new cascade
#
#
# OG Orders left:  4757
# Cascade length:  5
# New Orders left:  4752
# making new cascade
#
#
# OG Orders left:  4752
# Cascade length:  19
# New Orders left:  4733
# making new cascade
#
#
# OG Orders left:  4733
# Cascade length:  40
# New Orders left:  4693
# making new cascade
#
#
# OG Orders left:  4693
# Cascade length:  21
# New Orders left:  4672
# making new cascade
#
#
# OG Orders left:  4672
# Cascade length:  95
# New Orders left:  4577
# making new cascade
#
#
# OG Orders left:  4577
# Cascade length:  105
# New Orders left:  4472
# making new cascade
#
#
# OG Orders left:  4472
# Cascade length:  27
# New Orders left:  4445
# making new cascade
#
#
# OG Orders left:  4445
# Cascade length:  2
# New Orders left:  4443
# making new cascade
#
#
# OG Orders left:  4443
# Cascade length:  260
# New Orders left:  4183
# making new cascade
#
#
# OG Orders left:  4183
# Cascade length:  3
# New Orders left:  4180
# making new cascade
#
#
# OG Orders left:  4180
# Cascade length:  16
# New Orders left:  4164
# making new cascade
#
#
# OG Orders left:  4164
# Cascade length:  12
# New Orders left:  4152
# making new cascade
#
#
# OG Orders left:  4152
# Cascade length:  94
# New Orders left:  4058
# making new cascade
#
#
# OG Orders left:  4058
# Cascade length:  4
# New Orders left:  4054
# making new cascade
#
#
# OG Orders left:  4054
# Cascade length:  1
# New Orders left:  4053
# making new cascade
#
#
# OG Orders left:  4053
# Cascade length:  2
# New Orders left:  4051
# making new cascade
#
#
# OG Orders left:  4051
# Cascade length:  2
# New Orders left:  4049
# making new cascade
#
#
# OG Orders left:  4049
# Cascade length:  62
# New Orders left:  3987
# making new cascade
#
#
# OG Orders left:  3987
# Cascade length:  114
# New Orders left:  3873
# making new cascade
#
#
# OG Orders left:  3873
# Cascade length:  48
# New Orders left:  3825
# making new cascade
#
#
# OG Orders left:  3825
# Cascade length:  23
# New Orders left:  3802
# making new cascade
#
#
# OG Orders left:  3802
# Cascade length:  74
# New Orders left:  3728
# making new cascade
#
#
# OG Orders left:  3728
# Cascade length:  8
# New Orders left:  3720
# making new cascade
#
#
# OG Orders left:  3720
# Cascade length:  10
# New Orders left:  3710
# making new cascade
#
#
# OG Orders left:  3710
# Cascade length:  2
# New Orders left:  3708
# making new cascade
#
#
# OG Orders left:  3708
# Cascade length:  52
# New Orders left:  3656
# making new cascade
#
#
# OG Orders left:  3656
# Cascade length:  68
# New Orders left:  3588
# making new cascade
#
#
# OG Orders left:  3588
# Cascade length:  43
# New Orders left:  3545
# making new cascade
#
#
# OG Orders left:  3545
# Cascade length:  30
# New Orders left:  3515
# making new cascade
#
#
# OG Orders left:  3515
# Cascade length:  22
# New Orders left:  3493
# making new cascade
#
#
# OG Orders left:  3493
# Cascade length:  4
# New Orders left:  3489
# making new cascade
#
#
# OG Orders left:  3489
# Cascade length:  112
# New Orders left:  3377
# making new cascade
#
#
# OG Orders left:  3377
# Cascade length:  11
# New Orders left:  3366
# making new cascade
#
#
# OG Orders left:  3366
# Cascade length:  11
# New Orders left:  3355
# making new cascade
#
#
# OG Orders left:  3355
# Cascade length:  75
# New Orders left:  3280
# making new cascade
#
#
# OG Orders left:  3280
# Cascade length:  51
# New Orders left:  3229
# making new cascade
#
#
# OG Orders left:  3229
# Cascade length:  14
# New Orders left:  3215
# making new cascade
#
#
# OG Orders left:  3215
# Cascade length:  20
# New Orders left:  3195
# making new cascade
#
#
# OG Orders left:  3195
# Cascade length:  1
# New Orders left:  3194
# making new cascade
#
#
# OG Orders left:  3194
# Cascade length:  68
# New Orders left:  3126
# making new cascade
#
#
# OG Orders left:  3126
# Cascade length:  74
# New Orders left:  3052
# making new cascade
#
#
# OG Orders left:  3052
# Cascade length:  24
# New Orders left:  3028
# making new cascade
#
#
# OG Orders left:  3028
# Cascade length:  86
# New Orders left:  2942
# making new cascade
#
#
# OG Orders left:  2942
# Cascade length:  4
# New Orders left:  2938
# making new cascade
#
#
# OG Orders left:  2938
# Cascade length:  2
# New Orders left:  2936
# making new cascade
#
#
# OG Orders left:  2936
# Cascade length:  8
# New Orders left:  2928
# making new cascade
#
#
# OG Orders left:  2928
# Cascade length:  2
# New Orders left:  2926
# making new cascade
#
#
# OG Orders left:  2926
# Cascade length:  28
# New Orders left:  2898
# making new cascade
#
#
# OG Orders left:  2898
# Cascade length:  3
# New Orders left:  2895
# making new cascade
#
#
# OG Orders left:  2895
# Cascade length:  2
# New Orders left:  2893
# making new cascade
#
#
# OG Orders left:  2893
# Cascade length:  1
# New Orders left:  2892
# making new cascade
#
#
# OG Orders left:  2892
# Cascade length:  65
# New Orders left:  2827
# making new cascade
#
#
# OG Orders left:  2827
# Cascade length:  71
# New Orders left:  2756
# making new cascade
#
#
# OG Orders left:  2756
# Cascade length:  4
# New Orders left:  2752
# making new cascade
#
#
# OG Orders left:  2752
# Cascade length:  42
# New Orders left:  2710
# making new cascade
#
#
# OG Orders left:  2710
# Cascade length:  29
# New Orders left:  2681
# making new cascade
#
#
# OG Orders left:  2681
# Cascade length:  9
# New Orders left:  2672
# making new cascade
#
#
# OG Orders left:  2672
# Cascade length:  32
# New Orders left:  2640
# making new cascade
#
#
# OG Orders left:  2640
# Cascade length:  57
# New Orders left:  2583
# making new cascade
#
#
# OG Orders left:  2583
# Cascade length:  1
# New Orders left:  2582
# making new cascade
#
#
# OG Orders left:  2582
# Cascade length:  15
# New Orders left:  2567
# making new cascade
#
#
# OG Orders left:  2567
# Cascade length:  24
# New Orders left:  2543
# making new cascade
#
#
# OG Orders left:  2543
# Cascade length:  11
# New Orders left:  2532
# making new cascade
#
#
# OG Orders left:  2532
# Cascade length:  56
# New Orders left:  2476
# making new cascade
#
#
# OG Orders left:  2476
# Cascade length:  61
# New Orders left:  2415
# making new cascade
#
#
# OG Orders left:  2415
# Cascade length:  1
# New Orders left:  2414
# making new cascade
#
#
# OG Orders left:  2414
# Cascade length:  1
# New Orders left:  2413
# making new cascade
#
#
# OG Orders left:  2413
# Cascade length:  99
# New Orders left:  2314
# making new cascade
#
#
# OG Orders left:  2314
# Cascade length:  20
# New Orders left:  2294
# making new cascade
#
#
# OG Orders left:  2294
# Cascade length:  9
# New Orders left:  2285
# making new cascade
#
#
# OG Orders left:  2285
# Cascade length:  10
# New Orders left:  2275
# making new cascade
#
#
# OG Orders left:  2275
# Cascade length:  1
# New Orders left:  2274
# making new cascade
#
#
# OG Orders left:  2274
# Cascade length:  83
# New Orders left:  2191
# making new cascade
#
#
# OG Orders left:  2191
# Cascade length:  2
# New Orders left:  2189
# making new cascade
#
#
# OG Orders left:  2189
# Cascade length:  28
# New Orders left:  2161
# making new cascade
#
#
# OG Orders left:  2161
# Cascade length:  70
# New Orders left:  2091
# making new cascade
#
#
# OG Orders left:  2091
# Cascade length:  5
# New Orders left:  2086
# making new cascade
#
#
# OG Orders left:  2086
# Cascade length:  4
# New Orders left:  2082
# making new cascade
#
#
# OG Orders left:  2082
# Cascade length:  5
# New Orders left:  2077
# making new cascade
#
#
# OG Orders left:  2077
# Cascade length:  90
# New Orders left:  1987
# making new cascade
#
#
# OG Orders left:  1987
# Cascade length:  37
# New Orders left:  1950
# making new cascade
#
#
# OG Orders left:  1950
# Cascade length:  39
# New Orders left:  1911
# making new cascade
#
#
# OG Orders left:  1911
# Cascade length:  94
# New Orders left:  1817
# making new cascade
#
#
# OG Orders left:  1817
# Cascade length:  2
# New Orders left:  1815
# making new cascade
#
#
# OG Orders left:  1815
# Cascade length:  79
# New Orders left:  1736
# making new cascade
#
#
# OG Orders left:  1736
# Cascade length:  1
# New Orders left:  1735
# making new cascade
#
#
# OG Orders left:  1735
# Cascade length:  25
# New Orders left:  1710
# making new cascade
#
#
# OG Orders left:  1710
# Cascade length:  103
# New Orders left:  1607
# making new cascade
#
#
# OG Orders left:  1607
# Cascade length:  33
# New Orders left:  1574
# making new cascade
#
#
# OG Orders left:  1574
# Cascade length:  2
# New Orders left:  1572
# making new cascade
#
#
# OG Orders left:  1572
# Cascade length:  1
# New Orders left:  1571
# making new cascade
#
#
# OG Orders left:  1571
# Cascade length:  10
# New Orders left:  1561
# making new cascade
#
#
# OG Orders left:  1561
# Cascade length:  6
# New Orders left:  1555
# making new cascade
#
#
# OG Orders left:  1555
# Cascade length:  1
# New Orders left:  1554
# making new cascade
#
#
# OG Orders left:  1554
# Cascade length:  8
# New Orders left:  1546
# making new cascade
#
#
# OG Orders left:  1546
# Cascade length:  3
# New Orders left:  1543
# making new cascade
#
#
# OG Orders left:  1543
# Cascade length:  85
# New Orders left:  1458
# making new cascade
#
#
# OG Orders left:  1458
# Cascade length:  28
# New Orders left:  1430
# making new cascade
#
#
# OG Orders left:  1430
# Cascade length:  79
# New Orders left:  1351
# making new cascade
#
#
# OG Orders left:  1351
# Cascade length:  16
# New Orders left:  1335
# making new cascade
#
#
# OG Orders left:  1335
# Cascade length:  1
# New Orders left:  1334
# making new cascade
#
#
# OG Orders left:  1334
# Cascade length:  89
# New Orders left:  1245
# making new cascade
#
#
# OG Orders left:  1245
# Cascade length:  34
# New Orders left:  1211
# making new cascade
#
#
# OG Orders left:  1211
# Cascade length:  29
# New Orders left:  1182
# making new cascade
#
#
# OG Orders left:  1182
# Cascade length:  94
# New Orders left:  1088
# making new cascade
#
#
# OG Orders left:  1088
# Cascade length:  2
# New Orders left:  1086
# making new cascade
#
#
# OG Orders left:  1086
# Cascade length:  15
# New Orders left:  1071
# making new cascade
#
#
# OG Orders left:  1071
# Cascade length:  20
# New Orders left:  1051
# making new cascade
#
#
# OG Orders left:  1051
# Cascade length:  19
# New Orders left:  1032
# making new cascade
#
#
# OG Orders left:  1032
# Cascade length:  7
# New Orders left:  1025
# making new cascade
#
#
# OG Orders left:  1025
# Cascade length:  51
# New Orders left:  974
# making new cascade
#
#
# OG Orders left:  974
# Cascade length:  18
# New Orders left:  956
# making new cascade
#
#
# OG Orders left:  956
# Cascade length:  31
# New Orders left:  925
# making new cascade
#
#
# OG Orders left:  925
# Cascade length:  1
# New Orders left:  924
# making new cascade
#
#
# OG Orders left:  924
# Cascade length:  28
# New Orders left:  896
# making new cascade
#
#
# OG Orders left:  896
# Cascade length:  49
# New Orders left:  847
# making new cascade
#
#
# OG Orders left:  847
# Cascade length:  102
# New Orders left:  745
# making new cascade
#
#
# OG Orders left:  745
# Cascade length:  46
# New Orders left:  699
# making new cascade
#
#
# OG Orders left:  699
# Cascade length:  4
# New Orders left:  695
# making new cascade
#
#
# OG Orders left:  695
# Cascade length:  1
# New Orders left:  694
# making new cascade
#
#
# OG Orders left:  694
# Cascade length:  3
# New Orders left:  691
# making new cascade
#
#
# OG Orders left:  691
# Cascade length:  24
# New Orders left:  667
# making new cascade
#
#
# OG Orders left:  667
# Cascade length:  11
# New Orders left:  656
# making new cascade
#
#
# OG Orders left:  656
# Cascade length:  49
# New Orders left:  607
# making new cascade
#
#
# OG Orders left:  607
# Cascade length:  16
# New Orders left:  591
# making new cascade
#
#
# OG Orders left:  591
# Cascade length:  8
# New Orders left:  583
# making new cascade
#
#
# OG Orders left:  583
# Cascade length:  7
# New Orders left:  576
# making new cascade
#
#
# OG Orders left:  576
# Cascade length:  6
# New Orders left:  570
# making new cascade
#
#
# OG Orders left:  570
# Cascade length:  3
# New Orders left:  567
# making new cascade
#
#
# OG Orders left:  567
# Cascade length:  14
# New Orders left:  553
# making new cascade
#
#
# OG Orders left:  553
# Cascade length:  2
# New Orders left:  551
# making new cascade
#
#
# OG Orders left:  551
# Cascade length:  29
# New Orders left:  522
# making new cascade
#
#
# OG Orders left:  522
# Cascade length:  1
# New Orders left:  521
# making new cascade
#
#
# OG Orders left:  521
# Cascade length:  24
# New Orders left:  497
# making new cascade
#
#
# OG Orders left:  497
# Cascade length:  36
# New Orders left:  461
# making new cascade
#
#
# OG Orders left:  461
# Cascade length:  5
# New Orders left:  456
# making new cascade
#
#
# OG Orders left:  456
# Cascade length:  8
# New Orders left:  448
# making new cascade
#
#
# OG Orders left:  448
# Cascade length:  14
# New Orders left:  434
# making new cascade
#
#
# OG Orders left:  434
# Cascade length:  23
# New Orders left:  411
# making new cascade
#
#
# OG Orders left:  411
# Cascade length:  11
# New Orders left:  400
# making new cascade
#
#
# OG Orders left:  400
# Cascade length:  9
# New Orders left:  391
# making new cascade
#
#
# OG Orders left:  391
# Cascade length:  54
# New Orders left:  337
# making new cascade
#
#
# OG Orders left:  337
# Cascade length:  7
# New Orders left:  330
# making new cascade
#
#
# OG Orders left:  330
# Cascade length:  9
# New Orders left:  321
# making new cascade
#
#
# OG Orders left:  321
# Cascade length:  1
# New Orders left:  320
# making new cascade
#
#
# OG Orders left:  320
# Cascade length:  4
# New Orders left:  316
# making new cascade
#
#
# OG Orders left:  316
# Cascade length:  10
# New Orders left:  306
# making new cascade
#
#
# OG Orders left:  306
# Cascade length:  31
# New Orders left:  275
# making new cascade
#
#
# OG Orders left:  275
# Cascade length:  2
# New Orders left:  273
# making new cascade
#
#
# OG Orders left:  273
# Cascade length:  21
# New Orders left:  252
# making new cascade
#
#
# OG Orders left:  252
# Cascade length:  34
# New Orders left:  218
# making new cascade
#
#
# OG Orders left:  218
# Cascade length:  13
# New Orders left:  205
# making new cascade
#
#
# OG Orders left:  205
# Cascade length:  1
# New Orders left:  204
# making new cascade
#
#
# OG Orders left:  204
# Cascade length:  7
# New Orders left:  197
# making new cascade
#
#
# OG Orders left:  197
# Cascade length:  1
# New Orders left:  196
# making new cascade
#
#
# OG Orders left:  196
# Cascade length:  33
# New Orders left:  163
# making new cascade
#
#
# OG Orders left:  163
# Cascade length:  31
# New Orders left:  132
# making new cascade
#
#
# OG Orders left:  132
# Cascade length:  2
# New Orders left:  130
# making new cascade
#
#
# OG Orders left:  130
# Cascade length:  25
# New Orders left:  105
# making new cascade
#
#
# OG Orders left:  105
# Cascade length:  13
# New Orders left:  92
# making new cascade
#
#
# OG Orders left:  92
# Cascade length:  10
# New Orders left:  82
# making new cascade
#
#
# OG Orders left:  82
# Cascade length:  9
# New Orders left:  73
# making new cascade
#
#
# OG Orders left:  73
# Cascade length:  4
# New Orders left:  69
# making new cascade
#
#
# OG Orders left:  69
# Cascade length:  13
# New Orders left:  56
# making new cascade
#
#
# OG Orders left:  56
# Cascade length:  8
# New Orders left:  48
# making new cascade
#
#
# OG Orders left:  48
# Cascade length:  11
# New Orders left:  37
# making new cascade
#
#
# OG Orders left:  37
# Cascade length:  2
# New Orders left:  35
# making new cascade
#
#
# OG Orders left:  35
# Cascade length:  6
# New Orders left:  29
# making new cascade
#
#
# OG Orders left:  29
# Cascade length:  10
# New Orders left:  19
# making new cascade
#
#
# OG Orders left:  19
# Cascade length:  6
# New Orders left:  13
# making new cascade
#
#
# OG Orders left:  13
# Cascade length:  4
# New Orders left:  9
# making new cascade
#
#
# OG Orders left:  9
# Cascade length:  5
# New Orders left:  4
# making new cascade
#
#
# OG Orders left:  4
# Cascade length:  2
# New Orders left:  2
# making new cascade
#
#
# OG Orders left:  2
# Cascade length:  1
# New Orders left:  1
# making new cascade
#
#
# OG Orders left:  1
# Cascade length:  1
# New Orders left:  0
# making new cascade

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1)*1, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.9), '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.7), '-.', label= "$x^{-0.7}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.8), '-.', label= "$x^{-0.8}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*5, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/2-4/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
