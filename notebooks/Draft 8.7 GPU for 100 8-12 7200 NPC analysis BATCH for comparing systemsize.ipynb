# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_100_7200_100_new2threshold_fixedhurst.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_100_7200_100_new2threshold_fixedhurst.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_100_7200_100_new2threshold_fixedhurst.csv")

# %%
TtotalOrdersNPC
# Out:
#         Unnamed: 0  time portfolio  stock  order
# 0                1   993     wesyg     92   -2.0
# 1                3   993     wesyg     94    1.0
# 2                1   993     vdqtz     89   -1.0
# 3                2   993     vdqtz     90    1.0
# 4                3   993     vdqtz     91   -2.0
# ...            ...   ...       ...    ...    ...
# 638535           1  8192     ypwom     86   -7.0
# 638536           2  8192     ypwom     47    2.0
# 638537           0  8192     nqtpu     43   -2.0
# 638538           1  8192     nqtpu     57    1.0
# 638539           3  8192     nqtpu     62    3.0
#
# [638540 rows x 5 columns]

# %%
type(TtotalOrdersNPC)
# Out:
# cudf.core.dataframe.DataFrame

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-8eb6452f45de> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     811                 return NotImplemented
#     812             else:
# --> 813                 return cudf_func(*args, **kwargs)
#     814
#     815         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    TtotalOrders = TtotalOrdersNPC
    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1425670
# Cascade length:  11686
# New Orders left:  1413984
# making new cascade
#
#
# OG Orders left:  1413984
# Cascade length:  5169
# New Orders left:  1408815
# making new cascade
#
#
# OG Orders left:  1408815
# Cascade length:  5692
# New Orders left:  1403123
# making new cascade
#
#
# OG Orders left:  1403123
# Cascade length:  2979
# New Orders left:  1400144
# making new cascade
#
#
# OG Orders left:  1400144
# Cascade length:  2886
# New Orders left:  1397258
# making new cascade
#
#
# OG Orders left:  1397258
# Cascade length:  6438
# New Orders left:  1390820
# making new cascade
#
#
# OG Orders left:  1390820
# Cascade length:  2045
# New Orders left:  1388775
# making new cascade
#
#
# OG Orders left:  1388775
# Cascade length:  2535
# New Orders left:  1386240
# making new cascade
#
#
# OG Orders left:  1386240
# Cascade length:  2350
# New Orders left:  1383890
# making new cascade
#
#
# OG Orders left:  1383890
# Cascade length:  3885
# New Orders left:  1380005
# making new cascade
#
#
# OG Orders left:  1380005
# Cascade length:  874
# New Orders left:  1379131
# making new cascade
#
#
# OG Orders left:  1379131
# Cascade length:  2234
# New Orders left:  1376897
# making new cascade
#
#
# OG Orders left:  1376897
# Cascade length:  1967
# New Orders left:  1374930
# making new cascade
#
#
# OG Orders left:  1374930
# Cascade length:  1410
# New Orders left:  1373520
# making new cascade
#
#
# OG Orders left:  1373520
# Cascade length:  2799
# New Orders left:  1370721
# making new cascade
#
#
# OG Orders left:  1370721
# Cascade length:  2792
# New Orders left:  1367929
# making new cascade
#
#
# OG Orders left:  1367929
# Cascade length:  2290
# New Orders left:  1365639
# making new cascade
#
#
# OG Orders left:  1365639
# Cascade length:  1952
# New Orders left:  1363687
# making new cascade
#
#
# OG Orders left:  1363687
# Cascade length:  2973
# New Orders left:  1360714
# making new cascade
#
#
# OG Orders left:  1360714
# Cascade length:  19
# New Orders left:  1360695
# making new cascade
#
#
# OG Orders left:  1360695
# Cascade length:  1377
# New Orders left:  1359318
# making new cascade
#
#
# OG Orders left:  1359318
# Cascade length:  2289
# New Orders left:  1357029
# making new cascade
#
#
# OG Orders left:  1357029
# Cascade length:  1149
# New Orders left:  1355880
# making new cascade
#
#
# OG Orders left:  1355880
# Cascade length:  548
# New Orders left:  1355332
# making new cascade
#
#
# OG Orders left:  1355332
# Cascade length:  716
# New Orders left:  1354616
# making new cascade
#
#
# OG Orders left:  1354616
# Cascade length:  2631
# New Orders left:  1351985
# making new cascade
#
#
# OG Orders left:  1351985
# Cascade length:  2427
# New Orders left:  1349558
# making new cascade
#
#
# OG Orders left:  1349558
# Cascade length:  1100
# New Orders left:  1348458
# making new cascade
#
#
# OG Orders left:  1348458
# Cascade length:  3161
# New Orders left:  1345297
# making new cascade
#
#
# OG Orders left:  1345297
# Cascade length:  887
# New Orders left:  1344410
# making new cascade
#
#
# OG Orders left:  1344410
# Cascade length:  21
# New Orders left:  1344389
# making new cascade
#
#
# OG Orders left:  1344389
# Cascade length:  658
# New Orders left:  1343731
# making new cascade
#
#
# OG Orders left:  1343731
# Cascade length:  1441
# New Orders left:  1342290
# making new cascade
#
#
# OG Orders left:  1342290
# Cascade length:  1029
# New Orders left:  1341261
# making new cascade
#
#
# OG Orders left:  1341261
# Cascade length:  504
# New Orders left:  1340757
# making new cascade
#
#
# OG Orders left:  1340757
# Cascade length:  911
# New Orders left:  1339846
# making new cascade
#
#
# OG Orders left:  1339846
# Cascade length:  1406
# New Orders left:  1338440
# making new cascade
#
#
# OG Orders left:  1338440
# Cascade length:  1878
# New Orders left:  1336562
# making new cascade
#
#
# OG Orders left:  1336562
# Cascade length:  12
# New Orders left:  1336550
# making new cascade
#
#
# OG Orders left:  1336550
# Cascade length:  776
# New Orders left:  1335774
# making new cascade
#
#
# OG Orders left:  1335774
# Cascade length:  874
# New Orders left:  1334900
# making new cascade
#
#
# OG Orders left:  1334900
# Cascade length:  1778
# New Orders left:  1333122
# making new cascade
#
#
# OG Orders left:  1333122
# Cascade length:  904
# New Orders left:  1332218
# making new cascade
#
#
# OG Orders left:  1332218
# Cascade length:  1782
# New Orders left:  1330436
# making new cascade
#
#
# OG Orders left:  1330436
# Cascade length:  27
# New Orders left:  1330409
# making new cascade
#
#
# OG Orders left:  1330409
# Cascade length:  911
# New Orders left:  1329498
# making new cascade
#
#
# OG Orders left:  1329498
# Cascade length:  661
# New Orders left:  1328837
# making new cascade
#
#
# OG Orders left:  1328837
# Cascade length:  799
# New Orders left:  1328038
# making new cascade
#
#
# OG Orders left:  1328038
# Cascade length:  886
# New Orders left:  1327152
# making new cascade
#
#
# OG Orders left:  1327152
# Cascade length:  3
# New Orders left:  1327149
# making new cascade
#
#
# OG Orders left:  1327149
# Cascade length:  1034
# New Orders left:  1326115
# making new cascade
#
#
# OG Orders left:  1326115
# Cascade length:  9
# New Orders left:  1326106
# making new cascade
#
#
# OG Orders left:  1326106
# Cascade length:  833
# New Orders left:  1325273
# making new cascade
#
#
# OG Orders left:  1325273
# Cascade length:  1333
# New Orders left:  1323940
# making new cascade
#
#
# OG Orders left:  1323940
# Cascade length:  21
# New Orders left:  1323919
# making new cascade
#
#
# OG Orders left:  1323919
# Cascade length:  1647
# New Orders left:  1322272
# making new cascade
#
#
# OG Orders left:  1322272
# Cascade length:  52
# New Orders left:  1322220
# making new cascade
#
#
# OG Orders left:  1322220
# Cascade length:  779
# New Orders left:  1321441
# making new cascade
#
#
# OG Orders left:  1321441
# Cascade length:  2278
# New Orders left:  1319163
# making new cascade
#
#
# OG Orders left:  1319163
# Cascade length:  1627
# New Orders left:  1317536
# making new cascade
#
#
# OG Orders left:  1317536
# Cascade length:  991
# New Orders left:  1316545
# making new cascade
#
#
# OG Orders left:  1316545
# Cascade length:  644
# New Orders left:  1315901
# making new cascade
#
#
# OG Orders left:  1315901
# Cascade length:  600
# New Orders left:  1315301
# making new cascade
#
#
# OG Orders left:  1315301
# Cascade length:  1634
# New Orders left:  1313667
# making new cascade
#
#
# OG Orders left:  1313667
# Cascade length:  590
# New Orders left:  1313077
# making new cascade
#
#
# OG Orders left:  1313077
# Cascade length:  1082
# New Orders left:  1311995
# making new cascade
#
#
# OG Orders left:  1311995
# Cascade length:  986
# New Orders left:  1311009
# making new cascade
#
#
# OG Orders left:  1311009
# Cascade length:  459
# New Orders left:  1310550
# making new cascade
#
#
# OG Orders left:  1310550
# Cascade length:  477
# New Orders left:  1310073
# making new cascade
#
#
# OG Orders left:  1310073
# Cascade length:  365
# New Orders left:  1309708
# making new cascade
#
#
# OG Orders left:  1309708
# Cascade length:  627
# New Orders left:  1309081
# making new cascade
#
#
# OG Orders left:  1309081
# Cascade length:  1098
# New Orders left:  1307983
# making new cascade
#
#
# OG Orders left:  1307983
# Cascade length:  31
# New Orders left:  1307952
# making new cascade
#
#
# OG Orders left:  1307952
# Cascade length:  1667
# New Orders left:  1306285
# making new cascade
#
#
# OG Orders left:  1306285
# Cascade length:  615
# New Orders left:  1305670
# making new cascade
#
#
# OG Orders left:  1305670
# Cascade length:  1164
# New Orders left:  1304506
# making new cascade
#
#
# OG Orders left:  1304506
# Cascade length:  2
# New Orders left:  1304504
# making new cascade
#
#
# OG Orders left:  1304504
# Cascade length:  8
# New Orders left:  1304496
# making new cascade
#
#
# OG Orders left:  1304496
# Cascade length:  769
# New Orders left:  1303727
# making new cascade
#
#
# OG Orders left:  1303727
# Cascade length:  2
# New Orders left:  1303725
# making new cascade
#
#
# OG Orders left:  1303725
# Cascade length:  818
# New Orders left:  1302907
# making new cascade
#
#
# OG Orders left:  1302907
# Cascade length:  15
# New Orders left:  1302892
# making new cascade
#
#
# OG Orders left:  1302892
# Cascade length:  1
# New Orders left:  1302891
# making new cascade
#
#
# OG Orders left:  1302891
# Cascade length:  904
# New Orders left:  1301987
# making new cascade
#
#
# OG Orders left:  1301987
# Cascade length:  622
# New Orders left:  1301365
# making new cascade
#
#
# OG Orders left:  1301365
# Cascade length:  2
# New Orders left:  1301363
# making new cascade
#
#
# OG Orders left:  1301363
# Cascade length:  1028
# New Orders left:  1300335
# making new cascade
#
#
# OG Orders left:  1300335
# Cascade length:  1051
# New Orders left:  1299284
# making new cascade
#
#
# OG Orders left:  1299284
# Cascade length:  18
# New Orders left:  1299266
# making new cascade
#
#
# OG Orders left:  1299266
# Cascade length:  973
# New Orders left:  1298293
# making new cascade
#
#
# OG Orders left:  1298293
# Cascade length:  1133
# New Orders left:  1297160
# making new cascade
#
#
# OG Orders left:  1297160
# Cascade length:  4
# New Orders left:  1297156
# making new cascade
#
#
# OG Orders left:  1297156
# Cascade length:  1087
# New Orders left:  1296069
# making new cascade
#
#
# OG Orders left:  1296069
# Cascade length:  62
# New Orders left:  1296007
# making new cascade
#
#
# OG Orders left:  1296007
# Cascade length:  16
# New Orders left:  1295991
# making new cascade
#
#
# OG Orders left:  1295991
# Cascade length:  865
# New Orders left:  1295126
# making new cascade
#
#
# OG Orders left:  1295126
# Cascade length:  835
# New Orders left:  1294291
# making new cascade
#
#
# OG Orders left:  1294291
# Cascade length:  560
# New Orders left:  1293731
# making new cascade
#
#
# OG Orders left:  1293731
# Cascade length:  48
# New Orders left:  1293683
# making new cascade
#
#
# OG Orders left:  1293683
# Cascade length:  1458
# New Orders left:  1292225
# making new cascade
#
#
# OG Orders left:  1292225
# Cascade length:  819
# New Orders left:  1291406
# making new cascade
#
#
# OG Orders left:  1291406
# Cascade length:  804
# New Orders left:  1290602
# making new cascade
#
#
# OG Orders left:  1290602
# Cascade length:  27
# New Orders left:  1290575
# making new cascade
#
#
# OG Orders left:  1290575
# Cascade length:  667
# New Orders left:  1289908
# making new cascade
#
#
# OG Orders left:  1289908
# Cascade length:  2
# New Orders left:  1289906
# making new cascade
#
#
# OG Orders left:  1289906
# Cascade length:  461
# New Orders left:  1289445
# making new cascade
#
#
# OG Orders left:  1289445
# Cascade length:  446
# New Orders left:  1288999
# making new cascade
#
#
# OG Orders left:  1288999
# Cascade length:  908
# New Orders left:  1288091
# making new cascade
#
#
# OG Orders left:  1288091
# Cascade length:  32
# New Orders left:  1288059
# making new cascade
#
#
# OG Orders left:  1288059
# Cascade length:  34
# New Orders left:  1288025
# making new cascade
#
#
# OG Orders left:  1288025
# Cascade length:  1309
# New Orders left:  1286716
# making new cascade
#
#
# OG Orders left:  1286716
# Cascade length:  902
# New Orders left:  1285814
# making new cascade
#
#
# OG Orders left:  1285814
# Cascade length:  918
# New Orders left:  1284896
# making new cascade
#
#
# OG Orders left:  1284896
# Cascade length:  881
# New Orders left:  1284015
# making new cascade
#
#
# OG Orders left:  1284015
# Cascade length:  809
# New Orders left:  1283206
# making new cascade
#
#
# OG Orders left:  1283206
# Cascade length:  29
# New Orders left:  1283177
# making new cascade
#
#
# OG Orders left:  1283177
# Cascade length:  4
# New Orders left:  1283173
# making new cascade
#
#
# OG Orders left:  1283173
# Cascade length:  1
# New Orders left:  1283172
# making new cascade
#
#
# OG Orders left:  1283172
# Cascade length:  905
# New Orders left:  1282267
# making new cascade
#
#
# OG Orders left:  1282267
# Cascade length:  40
# New Orders left:  1282227
# making new cascade
#
#
# OG Orders left:  1282227
# Cascade length:  1032
# New Orders left:  1281195
# making new cascade
#
#
# OG Orders left:  1281195
# Cascade length:  1140
# New Orders left:  1280055
# making new cascade
#
#
# OG Orders left:  1280055
# Cascade length:  1208
# New Orders left:  1278847
# making new cascade
#
#
# OG Orders left:  1278847
# Cascade length:  19
# New Orders left:  1278828
# making new cascade
#
#
# OG Orders left:  1278828
# Cascade length:  1439
# New Orders left:  1277389
# making new cascade
#
#
# OG Orders left:  1277389
# Cascade length:  541
# New Orders left:  1276848
# making new cascade
#
#
# OG Orders left:  1276848
# Cascade length:  15
# New Orders left:  1276833
# making new cascade
#
#
# OG Orders left:  1276833
# Cascade length:  2
# New Orders left:  1276831
# making new cascade
#
#
# OG Orders left:  1276831
# Cascade length:  536
# New Orders left:  1276295
# making new cascade
#
#
# OG Orders left:  1276295
# Cascade length:  6
# New Orders left:  1276289
# making new cascade
#
#
# OG Orders left:  1276289
# Cascade length:  685
# New Orders left:  1275604
# making new cascade
#
#
# OG Orders left:  1275604
# Cascade length:  3
# New Orders left:  1275601
# making new cascade
#
#
# OG Orders left:  1275601
# Cascade length:  400
# New Orders left:  1275201
# making new cascade
#
#
# OG Orders left:  1275201
# Cascade length:  415
# New Orders left:  1274786
# making new cascade
#
#
# OG Orders left:  1274786
# Cascade length:  4
# New Orders left:  1274782
# making new cascade
#
#
# OG Orders left:  1274782
# Cascade length:  1505
# New Orders left:  1273277
# making new cascade
#
#
# OG Orders left:  1273277
# Cascade length:  10
# New Orders left:  1273267
# making new cascade
#
#
# OG Orders left:  1273267
# Cascade length:  1061
# New Orders left:  1272206
# making new cascade
#
#
# OG Orders left:  1272206
# Cascade length:  658
# New Orders left:  1271548
# making new cascade
#
#
# OG Orders left:  1271548
# Cascade length:  1382
# New Orders left:  1270166
# making new cascade
#
#
# OG Orders left:  1270166
# Cascade length:  16
# New Orders left:  1270150
# making new cascade
#
#
# OG Orders left:  1270150
# Cascade length:  472
# New Orders left:  1269678
# making new cascade
#
#
# OG Orders left:  1269678
# Cascade length:  1468
# New Orders left:  1268210
# making new cascade
#
#
# OG Orders left:  1268210
# Cascade length:  1025
# New Orders left:  1267185
# making new cascade
#
#
# OG Orders left:  1267185
# Cascade length:  1273
# New Orders left:  1265912
# making new cascade
#
#
# OG Orders left:  1265912
# Cascade length:  531
# New Orders left:  1265381
# making new cascade
#
#
# OG Orders left:  1265381
# Cascade length:  1420
# New Orders left:  1263961
# making new cascade
#
#
# OG Orders left:  1263961
# Cascade length:  780
# New Orders left:  1263181
# making new cascade
#
#
# OG Orders left:  1263181
# Cascade length:  1842
# New Orders left:  1261339
# making new cascade
#
#
# OG Orders left:  1261339
# Cascade length:  770
# New Orders left:  1260569
# making new cascade
#
#
# OG Orders left:  1260569
# Cascade length:  2
# New Orders left:  1260567
# making new cascade
#
#
# OG Orders left:  1260567
# Cascade length:  60
# New Orders left:  1260507
# making new cascade
#
#
# OG Orders left:  1260507
# Cascade length:  60
# New Orders left:  1260447
# making new cascade
#
#
# OG Orders left:  1260447
# Cascade length:  431
# New Orders left:  1260016
# making new cascade
#
#
# OG Orders left:  1260016
# Cascade length:  809
# New Orders left:  1259207
# making new cascade
#
#
# OG Orders left:  1259207
# Cascade length:  481
# New Orders left:  1258726
# making new cascade
#
#
# OG Orders left:  1258726
# Cascade length:  14
# New Orders left:  1258712
# making new cascade
#
#
# OG Orders left:  1258712
# Cascade length:  417
# New Orders left:  1258295
# making new cascade
#
#
# OG Orders left:  1258295
# Cascade length:  570
# New Orders left:  1257725
# making new cascade
#
#
# OG Orders left:  1257725
# Cascade length:  590
# New Orders left:  1257135
# making new cascade
#
#
# OG Orders left:  1257135
# Cascade length:  632
# New Orders left:  1256503
# making new cascade
#
#
# OG Orders left:  1256503
# Cascade length:  379
# New Orders left:  1256124
# making new cascade
#
#
# OG Orders left:  1256124
# Cascade length:  12
# New Orders left:  1256112
# making new cascade
#
#
# OG Orders left:  1256112
# Cascade length:  19
# New Orders left:  1256093
# making new cascade
#
#
# OG Orders left:  1256093
# Cascade length:  5
# New Orders left:  1256088
# making new cascade
#
#
# OG Orders left:  1256088
# Cascade length:  638
# New Orders left:  1255450
# making new cascade
#
#
# OG Orders left:  1255450
# Cascade length:  18
# New Orders left:  1255432
# making new cascade
#
#
# OG Orders left:  1255432
# Cascade length:  67
# New Orders left:  1255365
# making new cascade
#
#
# OG Orders left:  1255365
# Cascade length:  1
# New Orders left:  1255364
# making new cascade
#
#
# OG Orders left:  1255364
# Cascade length:  504
# New Orders left:  1254860
# making new cascade
#
#
# OG Orders left:  1254860
# Cascade length:  2
# New Orders left:  1254858
# making new cascade
#
#
# OG Orders left:  1254858
# Cascade length:  713
# New Orders left:  1254145
# making new cascade
#
#
# OG Orders left:  1254145
# Cascade length:  59
# New Orders left:  1254086
# making new cascade
#
#
# OG Orders left:  1254086
# Cascade length:  84
# New Orders left:  1254002
# making new cascade
#
#
# OG Orders left:  1254002
# Cascade length:  14
# New Orders left:  1253988
# making new cascade
#
#
# OG Orders left:  1253988
# Cascade length:  23
# New Orders left:  1253965
# making new cascade
#
#
# OG Orders left:  1253965
# Cascade length:  24
# New Orders left:  1253941
# making new cascade
#
#
# OG Orders left:  1253941
# Cascade length:  2
# New Orders left:  1253939
# making new cascade
#
#
# OG Orders left:  1253939
# Cascade length:  494
# New Orders left:  1253445
# making new cascade
#
#
# OG Orders left:  1253445
# Cascade length:  1341
# New Orders left:  1252104
# making new cascade
#
#
# OG Orders left:  1252104
# Cascade length:  591
# New Orders left:  1251513
# making new cascade
#
#
# OG Orders left:  1251513
# Cascade length:  2
# New Orders left:  1251511
# making new cascade
#
#
# OG Orders left:  1251511
# Cascade length:  21
# New Orders left:  1251490
# making new cascade
#
#
# OG Orders left:  1251490
# Cascade length:  34
# New Orders left:  1251456
# making new cascade
#
#
# OG Orders left:  1251456
# Cascade length:  1014
# New Orders left:  1250442
# making new cascade
#
#
# OG Orders left:  1250442
# Cascade length:  3
# New Orders left:  1250439
# making new cascade
#
#
# OG Orders left:  1250439
# Cascade length:  1593
# New Orders left:  1248846
# making new cascade
#
#
# OG Orders left:  1248846
# Cascade length:  1210
# New Orders left:  1247636
# making new cascade
#
#
# OG Orders left:  1247636
# Cascade length:  930
# New Orders left:  1246706
# making new cascade
#
#
# OG Orders left:  1246706
# Cascade length:  437
# New Orders left:  1246269
# making new cascade
#
#
# OG Orders left:  1246269
# Cascade length:  1359
# New Orders left:  1244910
# making new cascade
#
#
# OG Orders left:  1244910
# Cascade length:  21
# New Orders left:  1244889
# making new cascade
#
#
# OG Orders left:  1244889
# Cascade length:  949
# New Orders left:  1243940
# making new cascade
#
#
# OG Orders left:  1243940
# Cascade length:  2
# New Orders left:  1243938
# making new cascade
#
#
# OG Orders left:  1243938
# Cascade length:  13
# New Orders left:  1243925
# making new cascade
#
#
# OG Orders left:  1243925
# Cascade length:  13
# New Orders left:  1243912
# making new cascade
#
#
# OG Orders left:  1243912
# Cascade length:  2
# New Orders left:  1243910
# making new cascade
#
#
# OG Orders left:  1243910
# Cascade length:  30
# New Orders left:  1243880
# making new cascade
#
#
# OG Orders left:  1243880
# Cascade length:  14
# New Orders left:  1243866
# making new cascade
#
#
# OG Orders left:  1243866
# Cascade length:  614
# New Orders left:  1243252
# making new cascade
#
#
# OG Orders left:  1243252
# Cascade length:  1
# New Orders left:  1243251
# making new cascade
#
#
# OG Orders left:  1243251
# Cascade length:  23
# New Orders left:  1243228
# making new cascade
#
#
# OG Orders left:  1243228
# Cascade length:  16
# New Orders left:  1243212
# making new cascade
#
#
# OG Orders left:  1243212
# Cascade length:  794
# New Orders left:  1242418
# making new cascade
#
#
# OG Orders left:  1242418
# Cascade length:  62
# New Orders left:  1242356
# making new cascade
#
#
# OG Orders left:  1242356
# Cascade length:  8
# New Orders left:  1242348
# making new cascade
#
#
# OG Orders left:  1242348
# Cascade length:  1
# New Orders left:  1242347
# making new cascade
#
#
# OG Orders left:  1242347
# Cascade length:  719
# New Orders left:  1241628
# making new cascade
#
#
# OG Orders left:  1241628
# Cascade length:  551
# New Orders left:  1241077
# making new cascade
#
#
# OG Orders left:  1241077
# Cascade length:  37
# New Orders left:  1241040
# making new cascade
#
#
# OG Orders left:  1241040
# Cascade length:  925
# New Orders left:  1240115
# making new cascade
#
#
# OG Orders left:  1240115
# Cascade length:  27
# New Orders left:  1240088
# making new cascade
#
#
# OG Orders left:  1240088
# Cascade length:  1479
# New Orders left:  1238609
# making new cascade
#
#
# OG Orders left:  1238609
# Cascade length:  953
# New Orders left:  1237656
# making new cascade
#
#
# OG Orders left:  1237656
# Cascade length:  2
# New Orders left:  1237654
# making new cascade
#
#
# OG Orders left:  1237654
# Cascade length:  10
# New Orders left:  1237644
# making new cascade
#
#
# OG Orders left:  1237644
# Cascade length:  729
# New Orders left:  1236915
# making new cascade
#
#
# OG Orders left:  1236915
# Cascade length:  873
# New Orders left:  1236042
# making new cascade
#
#
# OG Orders left:  1236042
# Cascade length:  1
# New Orders left:  1236041
# making new cascade
#
#
# OG Orders left:  1236041
# Cascade length:  2
# New Orders left:  1236039
# making new cascade
#
#
# OG Orders left:  1236039
# Cascade length:  47
# New Orders left:  1235992
# making new cascade
#
#
# OG Orders left:  1235992
# Cascade length:  1118
# New Orders left:  1234874
# making new cascade
#
#
# OG Orders left:  1234874
# Cascade length:  14
# New Orders left:  1234860
# making new cascade
#
#
# OG Orders left:  1234860
# Cascade length:  4
# New Orders left:  1234856
# making new cascade
#
#
# OG Orders left:  1234856
# Cascade length:  969
# New Orders left:  1233887
# making new cascade
#
#
# OG Orders left:  1233887
# Cascade length:  23
# New Orders left:  1233864
# making new cascade
#
#
# OG Orders left:  1233864
# Cascade length:  2182
# New Orders left:  1231682
# making new cascade
#
#
# OG Orders left:  1231682
# Cascade length:  43
# New Orders left:  1231639
# making new cascade
#
#
# OG Orders left:  1231639
# Cascade length:  1
# New Orders left:  1231638
# making new cascade
#
#
# OG Orders left:  1231638
# Cascade length:  37
# New Orders left:  1231601
# making new cascade
#
#
# OG Orders left:  1231601
# Cascade length:  3
# New Orders left:  1231598
# making new cascade
#
#
# OG Orders left:  1231598
# Cascade length:  6
# New Orders left:  1231592
# making new cascade
#
#
# OG Orders left:  1231592
# Cascade length:  988
# New Orders left:  1230604
# making new cascade
#
#
# OG Orders left:  1230604
# Cascade length:  9
# New Orders left:  1230595
# making new cascade
#
#
# OG Orders left:  1230595
# Cascade length:  2028
# New Orders left:  1228567
# making new cascade
#
#
# OG Orders left:  1228567
# Cascade length:  13
# New Orders left:  1228554
# making new cascade
#
#
# OG Orders left:  1228554
# Cascade length:  1341
# New Orders left:  1227213
# making new cascade
#
#
# OG Orders left:  1227213
# Cascade length:  2
# New Orders left:  1227211
# making new cascade
#
#
# OG Orders left:  1227211
# Cascade length:  1208
# New Orders left:  1226003
# making new cascade
#
#
# OG Orders left:  1226003
# Cascade length:  30
# New Orders left:  1225973
# making new cascade
#
#
# OG Orders left:  1225973
# Cascade length:  6
# New Orders left:  1225967
# making new cascade
#
#
# OG Orders left:  1225967
# Cascade length:  1
# New Orders left:  1225966
# making new cascade
#
#
# OG Orders left:  1225966
# Cascade length:  362
# New Orders left:  1225604
# making new cascade
#
#
# OG Orders left:  1225604
# Cascade length:  1641
# New Orders left:  1223963
# making new cascade
#
#
# OG Orders left:  1223963
# Cascade length:  699
# New Orders left:  1223264
# making new cascade
#
#
# OG Orders left:  1223264
# Cascade length:  1
# New Orders left:  1223263
# making new cascade
#
#
# OG Orders left:  1223263
# Cascade length:  1922
# New Orders left:  1221341
# making new cascade
#
#
# OG Orders left:  1221341
# Cascade length:  2
# New Orders left:  1221339
# making new cascade
#
#
# OG Orders left:  1221339
# Cascade length:  3
# New Orders left:  1221336
# making new cascade
#
#
# OG Orders left:  1221336
# Cascade length:  673
# New Orders left:  1220663
# making new cascade
#
#
# OG Orders left:  1220663
# Cascade length:  950
# New Orders left:  1219713
# making new cascade
#
#
# OG Orders left:  1219713
# Cascade length:  2
# New Orders left:  1219711
# making new cascade
#
#
# OG Orders left:  1219711
# Cascade length:  1731
# New Orders left:  1217980
# making new cascade
#
#
# OG Orders left:  1217980
# Cascade length:  1352
# New Orders left:  1216628
# making new cascade
#
#
# OG Orders left:  1216628
# Cascade length:  15
# New Orders left:  1216613
# making new cascade
#
#
# OG Orders left:  1216613
# Cascade length:  6
# New Orders left:  1216607
# making new cascade
#
#
# OG Orders left:  1216607
# Cascade length:  690
# New Orders left:  1215917
# making new cascade
#
#
# OG Orders left:  1215917
# Cascade length:  4
# New Orders left:  1215913
# making new cascade
#
#
# OG Orders left:  1215913
# Cascade length:  1068
# New Orders left:  1214845
# making new cascade
#
#
# OG Orders left:  1214845
# Cascade length:  46
# New Orders left:  1214799
# making new cascade
#
#
# OG Orders left:  1214799
# Cascade length:  1
# New Orders left:  1214798
# making new cascade
#
#
# OG Orders left:  1214798
# Cascade length:  556
# New Orders left:  1214242
# making new cascade
#
#
# OG Orders left:  1214242
# Cascade length:  1204
# New Orders left:  1213038
# making new cascade
#
#
# OG Orders left:  1213038
# Cascade length:  2
# New Orders left:  1213036
# making new cascade
#
#
# OG Orders left:  1213036
# Cascade length:  7
# New Orders left:  1213029
# making new cascade
#
#
# OG Orders left:  1213029
# Cascade length:  2
# New Orders left:  1213027
# making new cascade
#
#
# OG Orders left:  1213027
# Cascade length:  1050
# New Orders left:  1211977
# making new cascade
#
#
# OG Orders left:  1211977
# Cascade length:  4
# New Orders left:  1211973
# making new cascade
#
#
# OG Orders left:  1211973
# Cascade length:  364
# New Orders left:  1211609
# making new cascade
#
#
# OG Orders left:  1211609
# Cascade length:  634
# New Orders left:  1210975
# making new cascade
#
#
# OG Orders left:  1210975
# Cascade length:  6
# New Orders left:  1210969
# making new cascade
#
#
# OG Orders left:  1210969
# Cascade length:  1
# New Orders left:  1210968
# making new cascade
#
#
# OG Orders left:  1210968
# Cascade length:  1687
# New Orders left:  1209281
# making new cascade
#
#
# OG Orders left:  1209281
# Cascade length:  1402
# New Orders left:  1207879
# making new cascade
#
#
# OG Orders left:  1207879
# Cascade length:  13
# New Orders left:  1207866
# making new cascade
#
#
# OG Orders left:  1207866
# Cascade length:  2096
# New Orders left:  1205770
# making new cascade
#
#
# OG Orders left:  1205770
# Cascade length:  5
# New Orders left:  1205765
# making new cascade
#
#
# OG Orders left:  1205765
# Cascade length:  2
# New Orders left:  1205763
# making new cascade
#
#
# OG Orders left:  1205763
# Cascade length:  1163
# New Orders left:  1204600
# making new cascade
#
#
# OG Orders left:  1204600
# Cascade length:  4
# New Orders left:  1204596
# making new cascade
#
#
# OG Orders left:  1204596
# Cascade length:  784
# New Orders left:  1203812
# making new cascade
#
#
# OG Orders left:  1203812
# Cascade length:  374
# New Orders left:  1203438
# making new cascade
#
#
# OG Orders left:  1203438
# Cascade length:  539
# New Orders left:  1202899
# making new cascade
#
#
# OG Orders left:  1202899
# Cascade length:  5
# New Orders left:  1202894
# making new cascade
#
#
# OG Orders left:  1202894
# Cascade length:  573
# New Orders left:  1202321
# making new cascade
#
#
# OG Orders left:  1202321
# Cascade length:  1683
# New Orders left:  1200638
# making new cascade
#
#
# OG Orders left:  1200638
# Cascade length:  1710
# New Orders left:  1198928
# making new cascade
#
#
# OG Orders left:  1198928
# Cascade length:  10
# New Orders left:  1198918
# making new cascade
#
#
# OG Orders left:  1198918
# Cascade length:  355
# New Orders left:  1198563
# making new cascade
#
#
# OG Orders left:  1198563
# Cascade length:  1822
# New Orders left:  1196741
# making new cascade
#
#
# OG Orders left:  1196741
# Cascade length:  1319
# New Orders left:  1195422
# making new cascade
#
#
# OG Orders left:  1195422
# Cascade length:  3230
# New Orders left:  1192192
# making new cascade
#
#
# OG Orders left:  1192192
# Cascade length:  19
# New Orders left:  1192173
# making new cascade
#
#
# OG Orders left:  1192173
# Cascade length:  838
# New Orders left:  1191335
# making new cascade
#
#
# OG Orders left:  1191335
# Cascade length:  3
# New Orders left:  1191332
# making new cascade
#
#
# OG Orders left:  1191332
# Cascade length:  591
# New Orders left:  1190741
# making new cascade
#
#
# OG Orders left:  1190741
# Cascade length:  1709
# New Orders left:  1189032
# making new cascade
#
#
# OG Orders left:  1189032
# Cascade length:  551
# New Orders left:  1188481
# making new cascade
#
#
# OG Orders left:  1188481
# Cascade length:  72
# New Orders left:  1188409
# making new cascade
#
#
# OG Orders left:  1188409
# Cascade length:  479
# New Orders left:  1187930
# making new cascade
#
#
# OG Orders left:  1187930
# Cascade length:  18
# New Orders left:  1187912
# making new cascade
#
#
# OG Orders left:  1187912
# Cascade length:  3125
# New Orders left:  1184787
# making new cascade
#
#
# OG Orders left:  1184787
# Cascade length:  59
# New Orders left:  1184728
# making new cascade
#
#
# OG Orders left:  1184728
# Cascade length:  727
# New Orders left:  1184001
# making new cascade
#
#
# OG Orders left:  1184001
# Cascade length:  1632
# New Orders left:  1182369
# making new cascade
#
#
# OG Orders left:  1182369
# Cascade length:  59
# New Orders left:  1182310
# making new cascade
#
#
# OG Orders left:  1182310
# Cascade length:  2915
# New Orders left:  1179395
# making new cascade
#
#
# OG Orders left:  1179395
# Cascade length:  104
# New Orders left:  1179291
# making new cascade
#
#
# OG Orders left:  1179291
# Cascade length:  5175
# New Orders left:  1174116
# making new cascade
#
#
# OG Orders left:  1174116
# Cascade length:  964
# New Orders left:  1173152
# making new cascade
#
#
# OG Orders left:  1173152
# Cascade length:  19
# New Orders left:  1173133
# making new cascade
#
#
# OG Orders left:  1173133
# Cascade length:  1041
# New Orders left:  1172092
# making new cascade
#
#
# OG Orders left:  1172092
# Cascade length:  12
# New Orders left:  1172080
# making new cascade
#
#
# OG Orders left:  1172080
# Cascade length:  1538
# New Orders left:  1170542
# making new cascade
#
#
# OG Orders left:  1170542
# Cascade length:  981
# New Orders left:  1169561
# making new cascade
#
#
# OG Orders left:  1169561
# Cascade length:  17
# New Orders left:  1169544
# making new cascade
#
#
# OG Orders left:  1169544
# Cascade length:  28
# New Orders left:  1169516
# making new cascade
#
#
# OG Orders left:  1169516
# Cascade length:  31
# New Orders left:  1169485
# making new cascade
#
#
# OG Orders left:  1169485
# Cascade length:  907
# New Orders left:  1168578
# making new cascade
#
#
# OG Orders left:  1168578
# Cascade length:  360
# New Orders left:  1168218
# making new cascade
#
#
# OG Orders left:  1168218
# Cascade length:  41
# New Orders left:  1168177
# making new cascade
#
#
# OG Orders left:  1168177
# Cascade length:  4
# New Orders left:  1168173
# making new cascade
#
#
# OG Orders left:  1168173
# Cascade length:  708
# New Orders left:  1167465
# making new cascade
#
#
# OG Orders left:  1167465
# Cascade length:  843
# New Orders left:  1166622
# making new cascade
#
#
# OG Orders left:  1166622
# Cascade length:  10
# New Orders left:  1166612
# making new cascade
#
#
# OG Orders left:  1166612
# Cascade length:  24
# New Orders left:  1166588
# making new cascade
#
#
# OG Orders left:  1166588
# Cascade length:  2451
# New Orders left:  1164137
# making new cascade
#
#
# OG Orders left:  1164137
# Cascade length:  1067
# New Orders left:  1163070
# making new cascade
#
#
# OG Orders left:  1163070
# Cascade length:  52
# New Orders left:  1163018
# making new cascade
#
#
# OG Orders left:  1163018
# Cascade length:  2279
# New Orders left:  1160739
# making new cascade
#
#
# OG Orders left:  1160739
# Cascade length:  16
# New Orders left:  1160723
# making new cascade
#
#
# OG Orders left:  1160723
# Cascade length:  1068
# New Orders left:  1159655
# making new cascade
#
#
# OG Orders left:  1159655
# Cascade length:  644
# New Orders left:  1159011
# making new cascade
#
#
# OG Orders left:  1159011
# Cascade length:  13
# New Orders left:  1158998
# making new cascade
#
#
# OG Orders left:  1158998
# Cascade length:  2239
# New Orders left:  1156759
# making new cascade
#
#
# OG Orders left:  1156759
# Cascade length:  447
# New Orders left:  1156312
# making new cascade
#
#
# OG Orders left:  1156312
# Cascade length:  1300
# New Orders left:  1155012
# making new cascade
#
#
# OG Orders left:  1155012
# Cascade length:  4
# New Orders left:  1155008
# making new cascade
#
#
# OG Orders left:  1155008
# Cascade length:  5
# New Orders left:  1155003
# making new cascade
#
#
# OG Orders left:  1155003
# Cascade length:  738
# New Orders left:  1154265
# making new cascade
#
#
# OG Orders left:  1154265
# Cascade length:  331
# New Orders left:  1153934
# making new cascade
#
#
# OG Orders left:  1153934
# Cascade length:  12
# New Orders left:  1153922
# making new cascade
#
#
# OG Orders left:  1153922
# Cascade length:  823
# New Orders left:  1153099
# making new cascade
#
#
# OG Orders left:  1153099
# Cascade length:  8
# New Orders left:  1153091
# making new cascade
#
#
# OG Orders left:  1153091
# Cascade length:  1973
# New Orders left:  1151118
# making new cascade
#
#
# OG Orders left:  1151118
# Cascade length:  45
# New Orders left:  1151073
# making new cascade
#
#
# OG Orders left:  1151073
# Cascade length:  4021
# New Orders left:  1147052
# making new cascade
#
#
# OG Orders left:  1147052
# Cascade length:  19
# New Orders left:  1147033
# making new cascade
#
#
# OG Orders left:  1147033
# Cascade length:  31
# New Orders left:  1147002
# making new cascade
#
#
# OG Orders left:  1147002
# Cascade length:  512
# New Orders left:  1146490
# making new cascade
#
#
# OG Orders left:  1146490
# Cascade length:  15
# New Orders left:  1146475
# making new cascade
#
#
# OG Orders left:  1146475
# Cascade length:  74
# New Orders left:  1146401
# making new cascade
#
#
# OG Orders left:  1146401
# Cascade length:  1399
# New Orders left:  1145002
# making new cascade
#
#
# OG Orders left:  1145002
# Cascade length:  20
# New Orders left:  1144982
# making new cascade
#
#
# OG Orders left:  1144982
# Cascade length:  13
# New Orders left:  1144969
# making new cascade
#
#
# OG Orders left:  1144969
# Cascade length:  790
# New Orders left:  1144179
# making new cascade
#
#
# OG Orders left:  1144179
# Cascade length:  1395
# New Orders left:  1142784
# making new cascade
#
#
# OG Orders left:  1142784
# Cascade length:  1781
# New Orders left:  1141003
# making new cascade
#
#
# OG Orders left:  1141003
# Cascade length:  610
# New Orders left:  1140393
# making new cascade
#
#
# OG Orders left:  1140393
# Cascade length:  26
# New Orders left:  1140367
# making new cascade
#
#
# OG Orders left:  1140367
# Cascade length:  2065
# New Orders left:  1138302
# making new cascade
#
#
# OG Orders left:  1138302
# Cascade length:  17
# New Orders left:  1138285
# making new cascade
#
#
# OG Orders left:  1138285
# Cascade length:  1107
# New Orders left:  1137178
# making new cascade
#
#
# OG Orders left:  1137178
# Cascade length:  253
# New Orders left:  1136925
# making new cascade
#
#
# OG Orders left:  1136925
# Cascade length:  45
# New Orders left:  1136880
# making new cascade
#
#
# OG Orders left:  1136880
# Cascade length:  916
# New Orders left:  1135964
# making new cascade
#
#
# OG Orders left:  1135964
# Cascade length:  9
# New Orders left:  1135955
# making new cascade
#
#
# OG Orders left:  1135955
# Cascade length:  705
# New Orders left:  1135250
# making new cascade
#
#
# OG Orders left:  1135250
# Cascade length:  370
# New Orders left:  1134880
# making new cascade
#
#
# OG Orders left:  1134880
# Cascade length:  1140
# New Orders left:  1133740
# making new cascade
#
#
# OG Orders left:  1133740
# Cascade length:  2
# New Orders left:  1133738
# making new cascade
#
#
# OG Orders left:  1133738
# Cascade length:  845
# New Orders left:  1132893
# making new cascade
#
#
# OG Orders left:  1132893
# Cascade length:  6
# New Orders left:  1132887
# making new cascade
#
#
# OG Orders left:  1132887
# Cascade length:  99
# New Orders left:  1132788
# making new cascade
#
#
# OG Orders left:  1132788
# Cascade length:  1
# New Orders left:  1132787
# making new cascade
#
#
# OG Orders left:  1132787
# Cascade length:  1
# New Orders left:  1132786
# making new cascade
#
#
# OG Orders left:  1132786
# Cascade length:  656
# New Orders left:  1132130
# making new cascade
#
#
# OG Orders left:  1132130
# Cascade length:  183
# New Orders left:  1131947
# making new cascade
#
#
# OG Orders left:  1131947
# Cascade length:  52
# New Orders left:  1131895
# making new cascade
#
#
# OG Orders left:  1131895
# Cascade length:  106
# New Orders left:  1131789
# making new cascade
#
#
# OG Orders left:  1131789
# Cascade length:  499
# New Orders left:  1131290
# making new cascade
#
#
# OG Orders left:  1131290
# Cascade length:  1154
# New Orders left:  1130136
# making new cascade
#
#
# OG Orders left:  1130136
# Cascade length:  883
# New Orders left:  1129253
# making new cascade
#
#
# OG Orders left:  1129253
# Cascade length:  673
# New Orders left:  1128580
# making new cascade
#
#
# OG Orders left:  1128580
# Cascade length:  898
# New Orders left:  1127682
# making new cascade
#
#
# OG Orders left:  1127682
# Cascade length:  1376
# New Orders left:  1126306
# making new cascade
#
#
# OG Orders left:  1126306
# Cascade length:  29
# New Orders left:  1126277
# making new cascade
#
#
# OG Orders left:  1126277
# Cascade length:  704
# New Orders left:  1125573
# making new cascade
#
#
# OG Orders left:  1125573
# Cascade length:  10
# New Orders left:  1125563
# making new cascade
#
#
# OG Orders left:  1125563
# Cascade length:  410
# New Orders left:  1125153
# making new cascade
#
#
# OG Orders left:  1125153
# Cascade length:  1170
# New Orders left:  1123983
# making new cascade
#
#
# OG Orders left:  1123983
# Cascade length:  174
# New Orders left:  1123809
# making new cascade
#
#
# OG Orders left:  1123809
# Cascade length:  1019
# New Orders left:  1122790
# making new cascade
#
#
# OG Orders left:  1122790
# Cascade length:  733
# New Orders left:  1122057
# making new cascade
#
#
# OG Orders left:  1122057
# Cascade length:  24
# New Orders left:  1122033
# making new cascade
#
#
# OG Orders left:  1122033
# Cascade length:  480
# New Orders left:  1121553
# making new cascade
#
#
# OG Orders left:  1121553
# Cascade length:  25
# New Orders left:  1121528
# making new cascade
#
#
# OG Orders left:  1121528
# Cascade length:  11
# New Orders left:  1121517
# making new cascade
#
#
# OG Orders left:  1121517
# Cascade length:  21
# New Orders left:  1121496
# making new cascade
#
#
# OG Orders left:  1121496
# Cascade length:  1234
# New Orders left:  1120262
# making new cascade
#
#
# OG Orders left:  1120262
# Cascade length:  1246
# New Orders left:  1119016
# making new cascade
#
#
# OG Orders left:  1119016
# Cascade length:  19
# New Orders left:  1118997
# making new cascade
#
#
# OG Orders left:  1118997
# Cascade length:  800
# New Orders left:  1118197
# making new cascade
#
#
# OG Orders left:  1118197
# Cascade length:  923
# New Orders left:  1117274
# making new cascade
#
#
# OG Orders left:  1117274
# Cascade length:  1378
# New Orders left:  1115896
# making new cascade
#
#
# OG Orders left:  1115896
# Cascade length:  284
# New Orders left:  1115612
# making new cascade
#
#
# OG Orders left:  1115612
# Cascade length:  18
# New Orders left:  1115594
# making new cascade
#
#
# OG Orders left:  1115594
# Cascade length:  894
# New Orders left:  1114700
# making new cascade
#
#
# OG Orders left:  1114700
# Cascade length:  48
# New Orders left:  1114652
# making new cascade
#
#
# OG Orders left:  1114652
# Cascade length:  588
# New Orders left:  1114064
# making new cascade
#
#
# OG Orders left:  1114064
# Cascade length:  551
# New Orders left:  1113513
# making new cascade
#
#
# OG Orders left:  1113513
# Cascade length:  768
# New Orders left:  1112745
# making new cascade
#
#
# OG Orders left:  1112745
# Cascade length:  1643
# New Orders left:  1111102
# making new cascade
#
#
# OG Orders left:  1111102
# Cascade length:  42
# New Orders left:  1111060
# making new cascade
#
#
# OG Orders left:  1111060
# Cascade length:  1054
# New Orders left:  1110006
# making new cascade
#
#
# OG Orders left:  1110006
# Cascade length:  16
# New Orders left:  1109990
# making new cascade
#
#
# OG Orders left:  1109990
# Cascade length:  391
# New Orders left:  1109599
# making new cascade
#
#
# OG Orders left:  1109599
# Cascade length:  110
# New Orders left:  1109489
# making new cascade
#
#
# OG Orders left:  1109489
# Cascade length:  81
# New Orders left:  1109408
# making new cascade
#
#
# OG Orders left:  1109408
# Cascade length:  830
# New Orders left:  1108578
# making new cascade
#
#
# OG Orders left:  1108578
# Cascade length:  38
# New Orders left:  1108540
# making new cascade
#
#
# OG Orders left:  1108540
# Cascade length:  4294
# New Orders left:  1104246
# making new cascade
#
#
# OG Orders left:  1104246
# Cascade length:  2
# New Orders left:  1104244
# making new cascade
#
#
# OG Orders left:  1104244
# Cascade length:  23
# New Orders left:  1104221
# making new cascade
#
#
# OG Orders left:  1104221
# Cascade length:  16
# New Orders left:  1104205
# making new cascade
#
#
# OG Orders left:  1104205
# Cascade length:  749
# New Orders left:  1103456
# making new cascade
#
#
# OG Orders left:  1103456
# Cascade length:  2001
# New Orders left:  1101455
# making new cascade
#
#
# OG Orders left:  1101455
# Cascade length:  423
# New Orders left:  1101032
# making new cascade
#
#
# OG Orders left:  1101032
# Cascade length:  3
# New Orders left:  1101029
# making new cascade
#
#
# OG Orders left:  1101029
# Cascade length:  3135
# New Orders left:  1097894
# making new cascade
#
#
# OG Orders left:  1097894
# Cascade length:  33
# New Orders left:  1097861
# making new cascade
#
#
# OG Orders left:  1097861
# Cascade length:  1007
# New Orders left:  1096854
# making new cascade
#
#
# OG Orders left:  1096854
# Cascade length:  10
# New Orders left:  1096844
# making new cascade
#
#
# OG Orders left:  1096844
# Cascade length:  126
# New Orders left:  1096718
# making new cascade
#
#
# OG Orders left:  1096718
# Cascade length:  1910
# New Orders left:  1094808
# making new cascade
#
#
# OG Orders left:  1094808
# Cascade length:  3
# New Orders left:  1094805
# making new cascade
#
#
# OG Orders left:  1094805
# Cascade length:  6
# New Orders left:  1094799
# making new cascade
#
#
# OG Orders left:  1094799
# Cascade length:  1522
# New Orders left:  1093277
# making new cascade
#
#
# OG Orders left:  1093277
# Cascade length:  62
# New Orders left:  1093215
# making new cascade
#
#
# OG Orders left:  1093215
# Cascade length:  55
# New Orders left:  1093160
# making new cascade
#
#
# OG Orders left:  1093160
# Cascade length:  171
# New Orders left:  1092989
# making new cascade
#
#
# OG Orders left:  1092989
# Cascade length:  1097
# New Orders left:  1091892
# making new cascade
#
#
# OG Orders left:  1091892
# Cascade length:  60
# New Orders left:  1091832
# making new cascade
#
#
# OG Orders left:  1091832
# Cascade length:  3627
# New Orders left:  1088205
# making new cascade
#
#
# OG Orders left:  1088205
# Cascade length:  813
# New Orders left:  1087392
# making new cascade
#
#
# OG Orders left:  1087392
# Cascade length:  2
# New Orders left:  1087390
# making new cascade
#
#
# OG Orders left:  1087390
# Cascade length:  2
# New Orders left:  1087388
# making new cascade
#
#
# OG Orders left:  1087388
# Cascade length:  611
# New Orders left:  1086777
# making new cascade
#
#
# OG Orders left:  1086777
# Cascade length:  1301
# New Orders left:  1085476
# making new cascade
#
#
# OG Orders left:  1085476
# Cascade length:  982
# New Orders left:  1084494
# making new cascade
#
#
# OG Orders left:  1084494
# Cascade length:  160
# New Orders left:  1084334
# making new cascade
#
#
# OG Orders left:  1084334
# Cascade length:  2
# New Orders left:  1084332
# making new cascade
#
#
# OG Orders left:  1084332
# Cascade length:  4
# New Orders left:  1084328
# making new cascade
#
#
# OG Orders left:  1084328
# Cascade length:  35
# New Orders left:  1084293
# making new cascade
#
#
# OG Orders left:  1084293
# Cascade length:  23
# New Orders left:  1084270
# making new cascade
#
#
# OG Orders left:  1084270
# Cascade length:  4
# New Orders left:  1084266
# making new cascade
#
#
# OG Orders left:  1084266
# Cascade length:  615
# New Orders left:  1083651
# making new cascade
#
#
# OG Orders left:  1083651
# Cascade length:  250
# New Orders left:  1083401
# making new cascade
#
#
# OG Orders left:  1083401
# Cascade length:  640
# New Orders left:  1082761
# making new cascade
#
#
# OG Orders left:  1082761
# Cascade length:  314
# New Orders left:  1082447
# making new cascade
#
#
# OG Orders left:  1082447
# Cascade length:  3
# New Orders left:  1082444
# making new cascade
#
#
# OG Orders left:  1082444
# Cascade length:  668
# New Orders left:  1081776
# making new cascade
#
#
# OG Orders left:  1081776
# Cascade length:  1173
# New Orders left:  1080603
# making new cascade
#
#
# OG Orders left:  1080603
# Cascade length:  901
# New Orders left:  1079702
# making new cascade
#
#
# OG Orders left:  1079702
# Cascade length:  38
# New Orders left:  1079664
# making new cascade
#
#
# OG Orders left:  1079664
# Cascade length:  48
# New Orders left:  1079616
# making new cascade
#
#
# OG Orders left:  1079616
# Cascade length:  735
# New Orders left:  1078881
# making new cascade
#
#
# OG Orders left:  1078881
# Cascade length:  341
# New Orders left:  1078540
# making new cascade
#
#
# OG Orders left:  1078540
# Cascade length:  607
# New Orders left:  1077933
# making new cascade
#
#
# OG Orders left:  1077933
# Cascade length:  778
# New Orders left:  1077155
# making new cascade
#
#
# OG Orders left:  1077155
# Cascade length:  1874
# New Orders left:  1075281
# making new cascade
#
#
# OG Orders left:  1075281
# Cascade length:  2504
# New Orders left:  1072777
# making new cascade
#
#
# OG Orders left:  1072777
# Cascade length:  9
# New Orders left:  1072768
# making new cascade
#
#
# OG Orders left:  1072768
# Cascade length:  1049
# New Orders left:  1071719
# making new cascade
#
#
# OG Orders left:  1071719
# Cascade length:  459
# New Orders left:  1071260
# making new cascade
#
#
# OG Orders left:  1071260
# Cascade length:  351
# New Orders left:  1070909
# making new cascade
#
#
# OG Orders left:  1070909
# Cascade length:  2
# New Orders left:  1070907
# making new cascade
#
#
# OG Orders left:  1070907
# Cascade length:  16
# New Orders left:  1070891
# making new cascade
#
#
# OG Orders left:  1070891
# Cascade length:  21
# New Orders left:  1070870
# making new cascade
#
#
# OG Orders left:  1070870
# Cascade length:  524
# New Orders left:  1070346
# making new cascade
#
#
# OG Orders left:  1070346
# Cascade length:  453
# New Orders left:  1069893
# making new cascade
#
#
# OG Orders left:  1069893
# Cascade length:  755
# New Orders left:  1069138
# making new cascade
#
#
# OG Orders left:  1069138
# Cascade length:  18
# New Orders left:  1069120
# making new cascade
#
#
# OG Orders left:  1069120
# Cascade length:  21
# New Orders left:  1069099
# making new cascade
#
#
# OG Orders left:  1069099
# Cascade length:  265
# New Orders left:  1068834
# making new cascade
#
#
# OG Orders left:  1068834
# Cascade length:  72
# New Orders left:  1068762
# making new cascade
#
#
# OG Orders left:  1068762
# Cascade length:  314
# New Orders left:  1068448
# making new cascade
#
#
# OG Orders left:  1068448
# Cascade length:  350
# New Orders left:  1068098
# making new cascade
#
#
# OG Orders left:  1068098
# Cascade length:  559
# New Orders left:  1067539
# making new cascade
#
#
# OG Orders left:  1067539
# Cascade length:  116
# New Orders left:  1067423
# making new cascade
#
#
# OG Orders left:  1067423
# Cascade length:  1440
# New Orders left:  1065983
# making new cascade
#
#
# OG Orders left:  1065983
# Cascade length:  79
# New Orders left:  1065904
# making new cascade
#
#
# OG Orders left:  1065904
# Cascade length:  2487
# New Orders left:  1063417
# making new cascade
#
#
# OG Orders left:  1063417
# Cascade length:  476
# New Orders left:  1062941
# making new cascade
#
#
# OG Orders left:  1062941
# Cascade length:  905
# New Orders left:  1062036
# making new cascade
#
#
# OG Orders left:  1062036
# Cascade length:  1412
# New Orders left:  1060624
# making new cascade
#
#
# OG Orders left:  1060624
# Cascade length:  487
# New Orders left:  1060137
# making new cascade
#
#
# OG Orders left:  1060137
# Cascade length:  571
# New Orders left:  1059566
# making new cascade
#
#
# OG Orders left:  1059566
# Cascade length:  2145
# New Orders left:  1057421
# making new cascade
#
#
# OG Orders left:  1057421
# Cascade length:  427
# New Orders left:  1056994
# making new cascade
#
#
# OG Orders left:  1056994
# Cascade length:  50
# New Orders left:  1056944
# making new cascade
#
#
# OG Orders left:  1056944
# Cascade length:  70
# New Orders left:  1056874
# making new cascade
#
#
# OG Orders left:  1056874
# Cascade length:  97
# New Orders left:  1056777
# making new cascade
#
#
# OG Orders left:  1056777
# Cascade length:  492
# New Orders left:  1056285
# making new cascade
#
#
# OG Orders left:  1056285
# Cascade length:  1
# New Orders left:  1056284
# making new cascade
#
#
# OG Orders left:  1056284
# Cascade length:  551
# New Orders left:  1055733
# making new cascade
#
#
# OG Orders left:  1055733
# Cascade length:  5
# New Orders left:  1055728
# making new cascade
#
#
# OG Orders left:  1055728
# Cascade length:  68
# New Orders left:  1055660
# making new cascade
#
#
# OG Orders left:  1055660
# Cascade length:  1112
# New Orders left:  1054548
# making new cascade
#
#
# OG Orders left:  1054548
# Cascade length:  1
# New Orders left:  1054547
# making new cascade
#
#
# OG Orders left:  1054547
# Cascade length:  1030
# New Orders left:  1053517
# making new cascade
#
#
# OG Orders left:  1053517
# Cascade length:  1
# New Orders left:  1053516
# making new cascade
#
#
# OG Orders left:  1053516
# Cascade length:  39
# New Orders left:  1053477
# making new cascade
#
#
# OG Orders left:  1053477
# Cascade length:  4
# New Orders left:  1053473
# making new cascade
#
#
# OG Orders left:  1053473
# Cascade length:  21
# New Orders left:  1053452
# making new cascade
#
#
# OG Orders left:  1053452
# Cascade length:  3335
# New Orders left:  1050117
# making new cascade
#
#
# OG Orders left:  1050117
# Cascade length:  763
# New Orders left:  1049354
# making new cascade
#
#
# OG Orders left:  1049354
# Cascade length:  306
# ...
# Cascade length:  578
# New Orders left:  118945
# making new cascade
#
#
# OG Orders left:  118945
# Cascade length:  2155
# New Orders left:  116790
# making new cascade
#
#
# OG Orders left:  116790
# Cascade length:  15
# New Orders left:  116775
# making new cascade
#
#
# OG Orders left:  116775
# Cascade length:  25
# New Orders left:  116750
# making new cascade
#
#
# OG Orders left:  116750
# Cascade length:  2681
# New Orders left:  114069
# making new cascade
#
#
# OG Orders left:  114069
# Cascade length:  1248
# New Orders left:  112821
# making new cascade
#
#
# OG Orders left:  112821
# Cascade length:  773
# New Orders left:  112048
# making new cascade
#
#
# OG Orders left:  112048
# Cascade length:  997
# New Orders left:  111051
# making new cascade
#
#
# OG Orders left:  111051
# Cascade length:  1624
# New Orders left:  109427
# making new cascade
#
#
# OG Orders left:  109427
# Cascade length:  1557
# New Orders left:  107870
# making new cascade
#
#
# OG Orders left:  107870
# Cascade length:  682
# New Orders left:  107188
# making new cascade
#
#
# OG Orders left:  107188
# Cascade length:  792
# New Orders left:  106396
# making new cascade
#
#
# OG Orders left:  106396
# Cascade length:  975
# New Orders left:  105421
# making new cascade
#
#
# OG Orders left:  105421
# Cascade length:  987
# New Orders left:  104434
# making new cascade
#
#
# OG Orders left:  104434
# Cascade length:  514
# New Orders left:  103920
# making new cascade
#
#
# OG Orders left:  103920
# Cascade length:  1
# New Orders left:  103919
# making new cascade
#
#
# OG Orders left:  103919
# Cascade length:  840
# New Orders left:  103079
# making new cascade
#
#
# OG Orders left:  103079
# Cascade length:  621
# New Orders left:  102458
# making new cascade
#
#
# OG Orders left:  102458
# Cascade length:  668
# New Orders left:  101790
# making new cascade
#
#
# OG Orders left:  101790
# Cascade length:  1183
# New Orders left:  100607
# making new cascade
#
#
# OG Orders left:  100607
# Cascade length:  632
# New Orders left:  99975
# making new cascade
#
#
# OG Orders left:  99975
# Cascade length:  2444
# New Orders left:  97531
# making new cascade
#
#
# OG Orders left:  97531
# Cascade length:  726
# New Orders left:  96805
# making new cascade
#
#
# OG Orders left:  96805
# Cascade length:  102
# New Orders left:  96703
# making new cascade
#
#
# OG Orders left:  96703
# Cascade length:  386
# New Orders left:  96317
# making new cascade
#
#
# OG Orders left:  96317
# Cascade length:  972
# New Orders left:  95345
# making new cascade
#
#
# OG Orders left:  95345
# Cascade length:  5275
# New Orders left:  90070
# making new cascade
#
#
# OG Orders left:  90070
# Cascade length:  759
# New Orders left:  89311
# making new cascade
#
#
# OG Orders left:  89311
# Cascade length:  1003
# New Orders left:  88308
# making new cascade
#
#
# OG Orders left:  88308
# Cascade length:  1223
# New Orders left:  87085
# making new cascade
#
#
# OG Orders left:  87085
# Cascade length:  510
# New Orders left:  86575
# making new cascade
#
#
# OG Orders left:  86575
# Cascade length:  1957
# New Orders left:  84618
# making new cascade
#
#
# OG Orders left:  84618
# Cascade length:  721
# New Orders left:  83897
# making new cascade
#
#
# OG Orders left:  83897
# Cascade length:  1199
# New Orders left:  82698
# making new cascade
#
#
# OG Orders left:  82698
# Cascade length:  3
# New Orders left:  82695
# making new cascade
#
#
# OG Orders left:  82695
# Cascade length:  1031
# New Orders left:  81664
# making new cascade
#
#
# OG Orders left:  81664
# Cascade length:  511
# New Orders left:  81153
# making new cascade
#
#
# OG Orders left:  81153
# Cascade length:  2884
# New Orders left:  78269
# making new cascade
#
#
# OG Orders left:  78269
# Cascade length:  8
# New Orders left:  78261
# making new cascade
#
#
# OG Orders left:  78261
# Cascade length:  755
# New Orders left:  77506
# making new cascade
#
#
# OG Orders left:  77506
# Cascade length:  1090
# New Orders left:  76416
# making new cascade
#
#
# OG Orders left:  76416
# Cascade length:  1421
# New Orders left:  74995
# making new cascade
#
#
# OG Orders left:  74995
# Cascade length:  12
# New Orders left:  74983
# making new cascade
#
#
# OG Orders left:  74983
# Cascade length:  2771
# New Orders left:  72212
# making new cascade
#
#
# OG Orders left:  72212
# Cascade length:  593
# New Orders left:  71619
# making new cascade
#
#
# OG Orders left:  71619
# Cascade length:  620
# New Orders left:  70999
# making new cascade
#
#
# OG Orders left:  70999
# Cascade length:  929
# New Orders left:  70070
# making new cascade
#
#
# OG Orders left:  70070
# Cascade length:  1057
# New Orders left:  69013
# making new cascade
#
#
# OG Orders left:  69013
# Cascade length:  3
# New Orders left:  69010
# making new cascade
#
#
# OG Orders left:  69010
# Cascade length:  1030
# New Orders left:  67980
# making new cascade
#
#
# OG Orders left:  67980
# Cascade length:  469
# New Orders left:  67511
# making new cascade
#
#
# OG Orders left:  67511
# Cascade length:  293
# New Orders left:  67218
# making new cascade
#
#
# OG Orders left:  67218
# Cascade length:  1107
# New Orders left:  66111
# making new cascade
#
#
# OG Orders left:  66111
# Cascade length:  767
# New Orders left:  65344
# making new cascade
#
#
# OG Orders left:  65344
# Cascade length:  2419
# New Orders left:  62925
# making new cascade
#
#
# OG Orders left:  62925
# Cascade length:  540
# New Orders left:  62385
# making new cascade
#
#
# OG Orders left:  62385
# Cascade length:  883
# New Orders left:  61502
# making new cascade
#
#
# OG Orders left:  61502
# Cascade length:  846
# New Orders left:  60656
# making new cascade
#
#
# OG Orders left:  60656
# Cascade length:  863
# New Orders left:  59793
# making new cascade
#
#
# OG Orders left:  59793
# Cascade length:  517
# New Orders left:  59276
# making new cascade
#
#
# OG Orders left:  59276
# Cascade length:  805
# New Orders left:  58471
# making new cascade
#
#
# OG Orders left:  58471
# Cascade length:  1453
# New Orders left:  57018
# making new cascade
#
#
# OG Orders left:  57018
# Cascade length:  56
# New Orders left:  56962
# making new cascade
#
#
# OG Orders left:  56962
# Cascade length:  481
# New Orders left:  56481
# making new cascade
#
#
# OG Orders left:  56481
# Cascade length:  879
# New Orders left:  55602
# making new cascade
#
#
# OG Orders left:  55602
# Cascade length:  1672
# New Orders left:  53930
# making new cascade
#
#
# OG Orders left:  53930
# Cascade length:  761
# New Orders left:  53169
# making new cascade
#
#
# OG Orders left:  53169
# Cascade length:  955
# New Orders left:  52214
# making new cascade
#
#
# OG Orders left:  52214
# Cascade length:  754
# New Orders left:  51460
# making new cascade
#
#
# OG Orders left:  51460
# Cascade length:  513
# New Orders left:  50947
# making new cascade
#
#
# OG Orders left:  50947
# Cascade length:  336
# New Orders left:  50611
# making new cascade
#
#
# OG Orders left:  50611
# Cascade length:  1267
# New Orders left:  49344
# making new cascade
#
#
# OG Orders left:  49344
# Cascade length:  383
# New Orders left:  48961
# making new cascade
#
#
# OG Orders left:  48961
# Cascade length:  19
# New Orders left:  48942
# making new cascade
#
#
# OG Orders left:  48942
# Cascade length:  1254
# New Orders left:  47688
# making new cascade
#
#
# OG Orders left:  47688
# Cascade length:  56
# New Orders left:  47632
# making new cascade
#
#
# OG Orders left:  47632
# Cascade length:  579
# New Orders left:  47053
# making new cascade
#
#
# OG Orders left:  47053
# Cascade length:  1610
# New Orders left:  45443
# making new cascade
#
#
# OG Orders left:  45443
# Cascade length:  369
# New Orders left:  45074
# making new cascade
#
#
# OG Orders left:  45074
# Cascade length:  16
# New Orders left:  45058
# making new cascade
#
#
# OG Orders left:  45058
# Cascade length:  746
# New Orders left:  44312
# making new cascade
#
#
# OG Orders left:  44312
# Cascade length:  388
# New Orders left:  43924
# making new cascade
#
#
# OG Orders left:  43924
# Cascade length:  27
# New Orders left:  43897
# making new cascade
#
#
# OG Orders left:  43897
# Cascade length:  23
# New Orders left:  43874
# making new cascade
#
#
# OG Orders left:  43874
# Cascade length:  995
# New Orders left:  42879
# making new cascade
#
#
# OG Orders left:  42879
# Cascade length:  861
# New Orders left:  42018
# making new cascade
#
#
# OG Orders left:  42018
# Cascade length:  1634
# New Orders left:  40384
# making new cascade
#
#
# OG Orders left:  40384
# Cascade length:  1261
# New Orders left:  39123
# making new cascade
#
#
# OG Orders left:  39123
# Cascade length:  1782
# New Orders left:  37341
# making new cascade
#
#
# OG Orders left:  37341
# Cascade length:  570
# New Orders left:  36771
# making new cascade
#
#
# OG Orders left:  36771
# Cascade length:  55
# New Orders left:  36716
# making new cascade
#
#
# OG Orders left:  36716
# Cascade length:  231
# New Orders left:  36485
# making new cascade
#
#
# OG Orders left:  36485
# Cascade length:  1188
# New Orders left:  35297
# making new cascade
#
#
# OG Orders left:  35297
# Cascade length:  860
# New Orders left:  34437
# making new cascade
#
#
# OG Orders left:  34437
# Cascade length:  974
# New Orders left:  33463
# making new cascade
#
#
# OG Orders left:  33463
# Cascade length:  540
# New Orders left:  32923
# making new cascade
#
#
# OG Orders left:  32923
# Cascade length:  738
# New Orders left:  32185
# making new cascade
#
#
# OG Orders left:  32185
# Cascade length:  948
# New Orders left:  31237
# making new cascade
#
#
# OG Orders left:  31237
# Cascade length:  765
# New Orders left:  30472
# making new cascade
#
#
# OG Orders left:  30472
# Cascade length:  855
# New Orders left:  29617
# making new cascade
#
#
# OG Orders left:  29617
# Cascade length:  807
# New Orders left:  28810
# making new cascade
#
#
# OG Orders left:  28810
# Cascade length:  2
# New Orders left:  28808
# making new cascade
#
#
# OG Orders left:  28808
# Cascade length:  28
# New Orders left:  28780
# making new cascade
#
#
# OG Orders left:  28780
# Cascade length:  14
# New Orders left:  28766
# making new cascade
#
#
# OG Orders left:  28766
# Cascade length:  326
# New Orders left:  28440
# making new cascade
#
#
# OG Orders left:  28440
# Cascade length:  691
# New Orders left:  27749
# making new cascade
#
#
# OG Orders left:  27749
# Cascade length:  562
# New Orders left:  27187
# making new cascade
#
#
# OG Orders left:  27187
# Cascade length:  774
# New Orders left:  26413
# making new cascade
#
#
# OG Orders left:  26413
# Cascade length:  840
# New Orders left:  25573
# making new cascade
#
#
# OG Orders left:  25573
# Cascade length:  908
# New Orders left:  24665
# making new cascade
#
#
# OG Orders left:  24665
# Cascade length:  14
# New Orders left:  24651
# making new cascade
#
#
# OG Orders left:  24651
# Cascade length:  727
# New Orders left:  23924
# making new cascade
#
#
# OG Orders left:  23924
# Cascade length:  605
# New Orders left:  23319
# making new cascade
#
#
# OG Orders left:  23319
# Cascade length:  4
# New Orders left:  23315
# making new cascade
#
#
# OG Orders left:  23315
# Cascade length:  1192
# New Orders left:  22123
# making new cascade
#
#
# OG Orders left:  22123
# Cascade length:  28
# New Orders left:  22095
# making new cascade
#
#
# OG Orders left:  22095
# Cascade length:  258
# New Orders left:  21837
# making new cascade
#
#
# OG Orders left:  21837
# Cascade length:  668
# New Orders left:  21169
# making new cascade
#
#
# OG Orders left:  21169
# Cascade length:  560
# New Orders left:  20609
# making new cascade
#
#
# OG Orders left:  20609
# Cascade length:  564
# New Orders left:  20045
# making new cascade
#
#
# OG Orders left:  20045
# Cascade length:  937
# New Orders left:  19108
# making new cascade
#
#
# OG Orders left:  19108
# Cascade length:  36
# New Orders left:  19072
# making new cascade
#
#
# OG Orders left:  19072
# Cascade length:  997
# New Orders left:  18075
# making new cascade
#
#
# OG Orders left:  18075
# Cascade length:  470
# New Orders left:  17605
# making new cascade
#
#
# OG Orders left:  17605
# Cascade length:  10
# New Orders left:  17595
# making new cascade
#
#
# OG Orders left:  17595
# Cascade length:  960
# New Orders left:  16635
# making new cascade
#
#
# OG Orders left:  16635
# Cascade length:  461
# New Orders left:  16174
# making new cascade
#
#
# OG Orders left:  16174
# Cascade length:  517
# New Orders left:  15657
# making new cascade
#
#
# OG Orders left:  15657
# Cascade length:  400
# New Orders left:  15257
# making new cascade
#
#
# OG Orders left:  15257
# Cascade length:  43
# New Orders left:  15214
# making new cascade
#
#
# OG Orders left:  15214
# Cascade length:  1208
# New Orders left:  14006
# making new cascade
#
#
# OG Orders left:  14006
# Cascade length:  12
# New Orders left:  13994
# making new cascade
#
#
# OG Orders left:  13994
# Cascade length:  662
# New Orders left:  13332
# making new cascade
#
#
# OG Orders left:  13332
# Cascade length:  239
# New Orders left:  13093
# making new cascade
#
#
# OG Orders left:  13093
# Cascade length:  45
# New Orders left:  13048
# making new cascade
#
#
# OG Orders left:  13048
# Cascade length:  521
# New Orders left:  12527
# making new cascade
#
#
# OG Orders left:  12527
# Cascade length:  517
# New Orders left:  12010
# making new cascade
#
#
# OG Orders left:  12010
# Cascade length:  478
# New Orders left:  11532
# making new cascade
#
#
# OG Orders left:  11532
# Cascade length:  608
# New Orders left:  10924
# making new cascade
#
#
# OG Orders left:  10924
# Cascade length:  1
# New Orders left:  10923
# making new cascade
#
#
# OG Orders left:  10923
# Cascade length:  368
# New Orders left:  10555
# making new cascade
#
#
# OG Orders left:  10555
# Cascade length:  941
# New Orders left:  9614
# making new cascade
#
#
# OG Orders left:  9614
# Cascade length:  1126
# New Orders left:  8488
# making new cascade
#
#
# OG Orders left:  8488
# Cascade length:  1
# New Orders left:  8487
# making new cascade
#
#
# OG Orders left:  8487
# Cascade length:  7
# New Orders left:  8480
# making new cascade
#
#
# OG Orders left:  8480
# Cascade length:  125
# New Orders left:  8355
# making new cascade
#
#
# OG Orders left:  8355
# Cascade length:  276
# New Orders left:  8079
# making new cascade
#
#
# OG Orders left:  8079
# Cascade length:  365
# New Orders left:  7714
# making new cascade
#
#
# OG Orders left:  7714
# Cascade length:  359
# New Orders left:  7355
# making new cascade
#
#
# OG Orders left:  7355
# Cascade length:  332
# New Orders left:  7023
# making new cascade
#
#
# OG Orders left:  7023
# Cascade length:  396
# New Orders left:  6627
# making new cascade
#
#
# OG Orders left:  6627
# Cascade length:  323
# New Orders left:  6304
# making new cascade
#
#
# OG Orders left:  6304
# Cascade length:  677
# New Orders left:  5627
# making new cascade
#
#
# OG Orders left:  5627
# Cascade length:  398
# New Orders left:  5229
# making new cascade
#
#
# OG Orders left:  5229
# Cascade length:  779
# New Orders left:  4450
# making new cascade
#
#
# OG Orders left:  4450
# Cascade length:  104
# New Orders left:  4346
# making new cascade
#
#
# OG Orders left:  4346
# Cascade length:  455
# New Orders left:  3891
# making new cascade
#
#
# OG Orders left:  3891
# Cascade length:  517
# New Orders left:  3374
# making new cascade
#
#
# OG Orders left:  3374
# Cascade length:  358
# New Orders left:  3016
# making new cascade
#
#
# OG Orders left:  3016
# Cascade length:  182
# New Orders left:  2834
# making new cascade
#
#
# OG Orders left:  2834
# Cascade length:  382
# New Orders left:  2452
# making new cascade
#
#
# OG Orders left:  2452
# Cascade length:  158
# New Orders left:  2294
# making new cascade
#
#
# OG Orders left:  2294
# Cascade length:  284
# New Orders left:  2010
# making new cascade
#
#
# OG Orders left:  2010
# Cascade length:  364
# New Orders left:  1646
# making new cascade
#
#
# OG Orders left:  1646
# Cascade length:  135
# New Orders left:  1511
# making new cascade
#
#
# OG Orders left:  1511
# Cascade length:  326
# New Orders left:  1185
# making new cascade
#
#
# OG Orders left:  1185
# Cascade length:  223
# New Orders left:  962
# making new cascade
#
#
# OG Orders left:  962
# Cascade length:  82
# New Orders left:  880
# making new cascade
#
#
# OG Orders left:  880
# Cascade length:  270
# New Orders left:  610
# making new cascade
#
#
# OG Orders left:  610
# Cascade length:  157
# New Orders left:  453
# making new cascade
#
#
# OG Orders left:  453
# Cascade length:  10
# New Orders left:  443
# making new cascade
#
#
# OG Orders left:  443
# Cascade length:  12
# New Orders left:  431
# making new cascade
#
#
# OG Orders left:  431
# Cascade length:  118
# New Orders left:  313
# making new cascade
#
#
# OG Orders left:  313
# Cascade length:  24
# New Orders left:  289
# making new cascade
#
#
# OG Orders left:  289
# Cascade length:  94
# New Orders left:  195
# making new cascade
#
#
# OG Orders left:  195
# Cascade length:  124
# New Orders left:  71
# making new cascade
#
#
# OG Orders left:  71
# Cascade length:  30
# New Orders left:  41
# making new cascade
#
#
# OG Orders left:  41
# Cascade length:  6
# New Orders left:  35
# making new cascade
#
#
# OG Orders left:  35
# Cascade length:  18
# New Orders left:  17
# making new cascade
#
#
# OG Orders left:  17
# Cascade length:  14
# New Orders left:  3
# making new cascade
#
#
# OG Orders left:  3
# Cascade length:  3
# New Orders left:  0
# making new cascade

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades21_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1425670
# Cascade length:  1644
# New Orders left:  1424026
# making new cascade
#
#
# OG Orders left:  1424026
# Cascade length:  1224
# New Orders left:  1422802
# making new cascade
#
#
# OG Orders left:  1422802
# Cascade length:  1310
# New Orders left:  1421492
# making new cascade
#
#
# OG Orders left:  1421492
# Cascade length:  1390
# New Orders left:  1420102
# making new cascade
#
#
# OG Orders left:  1420102
# Cascade length:  1680
# New Orders left:  1418422
# making new cascade
#
#
# OG Orders left:  1418422
# Cascade length:  1540
# New Orders left:  1416882
# making new cascade
#
#
# OG Orders left:  1416882
# Cascade length:  1278
# New Orders left:  1415604
# making new cascade
#
#
# OG Orders left:  1415604
# Cascade length:  1703
# New Orders left:  1413901
# making new cascade
#
#
# OG Orders left:  1413901
# Cascade length:  1384
# New Orders left:  1412517
# making new cascade
#
#
# OG Orders left:  1412517
# Cascade length:  1444
# New Orders left:  1411073
# making new cascade
#
#
# OG Orders left:  1411073
# Cascade length:  940
# New Orders left:  1410133
# making new cascade
#
#
# OG Orders left:  1410133
# Cascade length:  1578
# New Orders left:  1408555
# making new cascade
#
#
# OG Orders left:  1408555
# Cascade length:  1452
# New Orders left:  1407103
# making new cascade
#
#
# OG Orders left:  1407103
# Cascade length:  1819
# New Orders left:  1405284
# making new cascade
#
#
# OG Orders left:  1405284
# Cascade length:  1593
# New Orders left:  1403691
# making new cascade
#
#
# OG Orders left:  1403691
# Cascade length:  944
# New Orders left:  1402747
# making new cascade
#
#
# OG Orders left:  1402747
# Cascade length:  822
# New Orders left:  1401925
# making new cascade
#
#
# OG Orders left:  1401925
# Cascade length:  1235
# New Orders left:  1400690
# making new cascade
#
#
# OG Orders left:  1400690
# Cascade length:  1200
# New Orders left:  1399490
# making new cascade
#
#
# OG Orders left:  1399490
# Cascade length:  1522
# New Orders left:  1397968
# making new cascade
#
#
# OG Orders left:  1397968
# Cascade length:  15
# New Orders left:  1397953
# making new cascade
#
#
# OG Orders left:  1397953
# Cascade length:  5
# New Orders left:  1397948
# making new cascade
#
#
# OG Orders left:  1397948
# Cascade length:  744
# New Orders left:  1397204
# making new cascade
#
#
# OG Orders left:  1397204
# Cascade length:  913
# New Orders left:  1396291
# making new cascade
#
#
# OG Orders left:  1396291
# Cascade length:  3
# New Orders left:  1396288
# making new cascade
#
#
# OG Orders left:  1396288
# Cascade length:  1204
# New Orders left:  1395084
# making new cascade
#
#
# OG Orders left:  1395084
# Cascade length:  1053
# New Orders left:  1394031
# making new cascade
#
#
# OG Orders left:  1394031
# Cascade length:  3
# New Orders left:  1394028
# making new cascade
#
#
# OG Orders left:  1394028
# Cascade length:  795
# New Orders left:  1393233
# making new cascade
#
#
# OG Orders left:  1393233
# Cascade length:  1479
# New Orders left:  1391754
# making new cascade
#
#
# OG Orders left:  1391754
# Cascade length:  22
# New Orders left:  1391732
# making new cascade
#
#
# OG Orders left:  1391732
# Cascade length:  1056
# New Orders left:  1390676
# making new cascade
#
#
# OG Orders left:  1390676
# Cascade length:  800
# New Orders left:  1389876
# making new cascade
#
#
# OG Orders left:  1389876
# Cascade length:  1429
# New Orders left:  1388447
# making new cascade
#
#
# OG Orders left:  1388447
# Cascade length:  635
# New Orders left:  1387812
# making new cascade
#
#
# OG Orders left:  1387812
# Cascade length:  921
# New Orders left:  1386891
# making new cascade
#
#
# OG Orders left:  1386891
# Cascade length:  13
# New Orders left:  1386878
# making new cascade
#
#
# OG Orders left:  1386878
# Cascade length:  1493
# New Orders left:  1385385
# making new cascade
#
#
# OG Orders left:  1385385
# Cascade length:  6
# New Orders left:  1385379
# making new cascade
#
#
# OG Orders left:  1385379
# Cascade length:  800
# New Orders left:  1384579
# making new cascade
#
#
# OG Orders left:  1384579
# Cascade length:  1147
# New Orders left:  1383432
# making new cascade
#
#
# OG Orders left:  1383432
# Cascade length:  1184
# New Orders left:  1382248
# making new cascade
#
#
# OG Orders left:  1382248
# Cascade length:  21
# New Orders left:  1382227
# making new cascade
#
#
# OG Orders left:  1382227
# Cascade length:  794
# New Orders left:  1381433
# making new cascade
#
#
# OG Orders left:  1381433
# Cascade length:  944
# New Orders left:  1380489
# making new cascade
#
#
# OG Orders left:  1380489
# Cascade length:  3
# New Orders left:  1380486
# making new cascade
#
#
# OG Orders left:  1380486
# Cascade length:  889
# New Orders left:  1379597
# making new cascade
#
#
# OG Orders left:  1379597
# Cascade length:  5
# New Orders left:  1379592
# making new cascade
#
#
# OG Orders left:  1379592
# Cascade length:  884
# New Orders left:  1378708
# making new cascade
#
#
# OG Orders left:  1378708
# Cascade length:  976
# New Orders left:  1377732
# making new cascade
#
#
# OG Orders left:  1377732
# Cascade length:  12
# New Orders left:  1377720
# making new cascade
#
#
# OG Orders left:  1377720
# Cascade length:  794
# New Orders left:  1376926
# making new cascade
#
#
# OG Orders left:  1376926
# Cascade length:  1068
# New Orders left:  1375858
# making new cascade
#
#
# OG Orders left:  1375858
# Cascade length:  1
# New Orders left:  1375857
# making new cascade
#
#
# OG Orders left:  1375857
# Cascade length:  8
# New Orders left:  1375849
# making new cascade
#
#
# OG Orders left:  1375849
# Cascade length:  1004
# New Orders left:  1374845
# making new cascade
#
#
# OG Orders left:  1374845
# Cascade length:  7
# New Orders left:  1374838
# making new cascade
#
#
# OG Orders left:  1374838
# Cascade length:  905
# New Orders left:  1373933
# making new cascade
#
#
# OG Orders left:  1373933
# Cascade length:  31
# New Orders left:  1373902
# making new cascade
#
#
# OG Orders left:  1373902
# Cascade length:  9
# New Orders left:  1373893
# making new cascade
#
#
# OG Orders left:  1373893
# Cascade length:  1074
# New Orders left:  1372819
# making new cascade
#
#
# OG Orders left:  1372819
# Cascade length:  11
# New Orders left:  1372808
# making new cascade
#
#
# OG Orders left:  1372808
# Cascade length:  1465
# New Orders left:  1371343
# making new cascade
#
#
# OG Orders left:  1371343
# Cascade length:  953
# New Orders left:  1370390
# making new cascade
#
#
# OG Orders left:  1370390
# Cascade length:  17
# New Orders left:  1370373
# making new cascade
#
#
# OG Orders left:  1370373
# Cascade length:  650
# New Orders left:  1369723
# making new cascade
#
#
# OG Orders left:  1369723
# Cascade length:  2
# New Orders left:  1369721
# making new cascade
#
#
# OG Orders left:  1369721
# Cascade length:  1024
# New Orders left:  1368697
# making new cascade
#
#
# OG Orders left:  1368697
# Cascade length:  822
# New Orders left:  1367875
# making new cascade
#
#
# OG Orders left:  1367875
# Cascade length:  36
# New Orders left:  1367839
# making new cascade
#
#
# OG Orders left:  1367839
# Cascade length:  1020
# New Orders left:  1366819
# making new cascade
#
#
# OG Orders left:  1366819
# Cascade length:  797
# New Orders left:  1366022
# making new cascade
#
#
# OG Orders left:  1366022
# Cascade length:  47
# New Orders left:  1365975
# making new cascade
#
#
# OG Orders left:  1365975
# Cascade length:  452
# New Orders left:  1365523
# making new cascade
#
#
# OG Orders left:  1365523
# Cascade length:  415
# New Orders left:  1365108
# making new cascade
#
#
# OG Orders left:  1365108
# Cascade length:  693
# New Orders left:  1364415
# making new cascade
#
#
# OG Orders left:  1364415
# Cascade length:  344
# New Orders left:  1364071
# making new cascade
#
#
# OG Orders left:  1364071
# Cascade length:  9
# New Orders left:  1364062
# making new cascade
#
#
# OG Orders left:  1364062
# Cascade length:  20
# New Orders left:  1364042
# making new cascade
#
#
# OG Orders left:  1364042
# Cascade length:  23
# New Orders left:  1364019
# making new cascade
#
#
# OG Orders left:  1364019
# Cascade length:  794
# New Orders left:  1363225
# making new cascade
#
#
# OG Orders left:  1363225
# Cascade length:  903
# New Orders left:  1362322
# making new cascade
#
#
# OG Orders left:  1362322
# Cascade length:  583
# New Orders left:  1361739
# making new cascade
#
#
# OG Orders left:  1361739
# Cascade length:  17
# New Orders left:  1361722
# making new cascade
#
#
# OG Orders left:  1361722
# Cascade length:  519
# New Orders left:  1361203
# making new cascade
#
#
# OG Orders left:  1361203
# Cascade length:  31
# New Orders left:  1361172
# making new cascade
#
#
# OG Orders left:  1361172
# Cascade length:  704
# New Orders left:  1360468
# making new cascade
#
#
# OG Orders left:  1360468
# Cascade length:  945
# New Orders left:  1359523
# making new cascade
#
#
# OG Orders left:  1359523
# Cascade length:  13
# New Orders left:  1359510
# making new cascade
#
#
# OG Orders left:  1359510
# Cascade length:  770
# New Orders left:  1358740
# making new cascade
#
#
# OG Orders left:  1358740
# Cascade length:  590
# New Orders left:  1358150
# making new cascade
#
#
# OG Orders left:  1358150
# Cascade length:  25
# New Orders left:  1358125
# making new cascade
#
#
# OG Orders left:  1358125
# Cascade length:  653
# New Orders left:  1357472
# making new cascade
#
#
# OG Orders left:  1357472
# Cascade length:  690
# New Orders left:  1356782
# making new cascade
#
#
# OG Orders left:  1356782
# Cascade length:  579
# New Orders left:  1356203
# making new cascade
#
#
# OG Orders left:  1356203
# Cascade length:  495
# New Orders left:  1355708
# making new cascade
#
#
# OG Orders left:  1355708
# Cascade length:  1068
# New Orders left:  1354640
# making new cascade
#
#
# OG Orders left:  1354640
# Cascade length:  457
# New Orders left:  1354183
# making new cascade
#
#
# OG Orders left:  1354183
# Cascade length:  45
# New Orders left:  1354138
# making new cascade
#
#
# OG Orders left:  1354138
# Cascade length:  402
# New Orders left:  1353736
# making new cascade
#
#
# OG Orders left:  1353736
# Cascade length:  673
# New Orders left:  1353063
# making new cascade
#
#
# OG Orders left:  1353063
# Cascade length:  544
# New Orders left:  1352519
# making new cascade
#
#
# OG Orders left:  1352519
# Cascade length:  965
# New Orders left:  1351554
# making new cascade
#
#
# OG Orders left:  1351554
# Cascade length:  660
# New Orders left:  1350894
# making new cascade
#
#
# OG Orders left:  1350894
# Cascade length:  2
# New Orders left:  1350892
# making new cascade
#
#
# OG Orders left:  1350892
# Cascade length:  3
# New Orders left:  1350889
# making new cascade
#
#
# OG Orders left:  1350889
# Cascade length:  41
# New Orders left:  1350848
# making new cascade
#
#
# OG Orders left:  1350848
# Cascade length:  32
# New Orders left:  1350816
# making new cascade
#
#
# OG Orders left:  1350816
# Cascade length:  9
# New Orders left:  1350807
# making new cascade
#
#
# OG Orders left:  1350807
# Cascade length:  1002
# New Orders left:  1349805
# making new cascade
#
#
# OG Orders left:  1349805
# Cascade length:  556
# New Orders left:  1349249
# making new cascade
#
#
# OG Orders left:  1349249
# Cascade length:  1042
# New Orders left:  1348207
# making new cascade
#
#
# OG Orders left:  1348207
# Cascade length:  793
# New Orders left:  1347414
# making new cascade
#
#
# OG Orders left:  1347414
# Cascade length:  25
# New Orders left:  1347389
# making new cascade
#
#
# OG Orders left:  1347389
# Cascade length:  6
# New Orders left:  1347383
# making new cascade
#
#
# OG Orders left:  1347383
# Cascade length:  4
# New Orders left:  1347379
# making new cascade
#
#
# OG Orders left:  1347379
# Cascade length:  800
# New Orders left:  1346579
# making new cascade
#
#
# OG Orders left:  1346579
# Cascade length:  1
# New Orders left:  1346578
# making new cascade
#
#
# OG Orders left:  1346578
# Cascade length:  1
# New Orders left:  1346577
# making new cascade
#
#
# OG Orders left:  1346577
# Cascade length:  40
# New Orders left:  1346537
# making new cascade
#
#
# OG Orders left:  1346537
# Cascade length:  429
# New Orders left:  1346108
# making new cascade
#
#
# OG Orders left:  1346108
# Cascade length:  31
# New Orders left:  1346077
# making new cascade
#
#
# OG Orders left:  1346077
# Cascade length:  762
# New Orders left:  1345315
# making new cascade
#
#
# OG Orders left:  1345315
# Cascade length:  584
# New Orders left:  1344731
# making new cascade
#
#
# OG Orders left:  1344731
# Cascade length:  567
# New Orders left:  1344164
# making new cascade
#
#
# OG Orders left:  1344164
# Cascade length:  29
# New Orders left:  1344135
# making new cascade
#
#
# OG Orders left:  1344135
# Cascade length:  1070
# New Orders left:  1343065
# making new cascade
#
#
# OG Orders left:  1343065
# Cascade length:  8
# New Orders left:  1343057
# making new cascade
#
#
# OG Orders left:  1343057
# Cascade length:  572
# New Orders left:  1342485
# making new cascade
#
#
# OG Orders left:  1342485
# Cascade length:  477
# New Orders left:  1342008
# making new cascade
#
#
# OG Orders left:  1342008
# Cascade length:  1128
# New Orders left:  1340880
# making new cascade
#
#
# OG Orders left:  1340880
# Cascade length:  5
# New Orders left:  1340875
# making new cascade
#
#
# OG Orders left:  1340875
# Cascade length:  11
# New Orders left:  1340864
# making new cascade
#
#
# OG Orders left:  1340864
# Cascade length:  1227
# New Orders left:  1339637
# making new cascade
#
#
# OG Orders left:  1339637
# Cascade length:  432
# New Orders left:  1339205
# making new cascade
#
#
# OG Orders left:  1339205
# Cascade length:  19
# New Orders left:  1339186
# making new cascade
#
#
# OG Orders left:  1339186
# Cascade length:  647
# New Orders left:  1338539
# making new cascade
#
#
# OG Orders left:  1338539
# Cascade length:  823
# New Orders left:  1337716
# making new cascade
#
#
# OG Orders left:  1337716
# Cascade length:  302
# New Orders left:  1337414
# making new cascade
#
#
# OG Orders left:  1337414
# Cascade length:  13
# New Orders left:  1337401
# making new cascade
#
#
# OG Orders left:  1337401
# Cascade length:  6
# New Orders left:  1337395
# making new cascade
#
#
# OG Orders left:  1337395
# Cascade length:  498
# New Orders left:  1336897
# making new cascade
#
#
# OG Orders left:  1336897
# Cascade length:  1
# New Orders left:  1336896
# making new cascade
#
#
# OG Orders left:  1336896
# Cascade length:  706
# New Orders left:  1336190
# making new cascade
#
#
# OG Orders left:  1336190
# Cascade length:  48
# New Orders left:  1336142
# making new cascade
#
#
# OG Orders left:  1336142
# Cascade length:  558
# New Orders left:  1335584
# making new cascade
#
#
# OG Orders left:  1335584
# Cascade length:  579
# New Orders left:  1335005
# making new cascade
#
#
# OG Orders left:  1335005
# Cascade length:  600
# New Orders left:  1334405
# making new cascade
#
#
# OG Orders left:  1334405
# Cascade length:  41
# New Orders left:  1334364
# making new cascade
#
#
# OG Orders left:  1334364
# Cascade length:  8
# New Orders left:  1334356
# making new cascade
#
#
# OG Orders left:  1334356
# Cascade length:  55
# New Orders left:  1334301
# making new cascade
#
#
# OG Orders left:  1334301
# Cascade length:  679
# New Orders left:  1333622
# making new cascade
#
#
# OG Orders left:  1333622
# Cascade length:  408
# New Orders left:  1333214
# making new cascade
#
#
# OG Orders left:  1333214
# Cascade length:  180
# New Orders left:  1333034
# making new cascade
#
#
# OG Orders left:  1333034
# Cascade length:  34
# New Orders left:  1333000
# making new cascade
#
#
# OG Orders left:  1333000
# Cascade length:  503
# New Orders left:  1332497
# making new cascade
#
#
# OG Orders left:  1332497
# Cascade length:  216
# New Orders left:  1332281
# making new cascade
#
#
# OG Orders left:  1332281
# Cascade length:  3
# New Orders left:  1332278
# making new cascade
#
#
# OG Orders left:  1332278
# Cascade length:  562
# New Orders left:  1331716
# making new cascade
#
#
# OG Orders left:  1331716
# Cascade length:  11
# New Orders left:  1331705
# making new cascade
#
#
# OG Orders left:  1331705
# Cascade length:  358
# New Orders left:  1331347
# making new cascade
#
#
# OG Orders left:  1331347
# Cascade length:  614
# New Orders left:  1330733
# making new cascade
#
#
# OG Orders left:  1330733
# Cascade length:  11
# New Orders left:  1330722
# making new cascade
#
#
# OG Orders left:  1330722
# Cascade length:  733
# New Orders left:  1329989
# making new cascade
#
#
# OG Orders left:  1329989
# Cascade length:  819
# New Orders left:  1329170
# making new cascade
#
#
# OG Orders left:  1329170
# Cascade length:  869
# New Orders left:  1328301
# making new cascade
#
#
# OG Orders left:  1328301
# Cascade length:  1
# New Orders left:  1328300
# making new cascade
#
#
# OG Orders left:  1328300
# Cascade length:  54
# New Orders left:  1328246
# making new cascade
#
#
# OG Orders left:  1328246
# Cascade length:  818
# New Orders left:  1327428
# making new cascade
#
#
# OG Orders left:  1327428
# Cascade length:  1032
# New Orders left:  1326396
# making new cascade
#
#
# OG Orders left:  1326396
# Cascade length:  9
# New Orders left:  1326387
# making new cascade
#
#
# OG Orders left:  1326387
# Cascade length:  1072
# New Orders left:  1325315
# making new cascade
#
#
# OG Orders left:  1325315
# Cascade length:  2
# New Orders left:  1325313
# making new cascade
#
#
# OG Orders left:  1325313
# Cascade length:  7
# New Orders left:  1325306
# making new cascade
#
#
# OG Orders left:  1325306
# Cascade length:  501
# New Orders left:  1324805
# making new cascade
#
#
# OG Orders left:  1324805
# Cascade length:  589
# New Orders left:  1324216
# making new cascade
#
#
# OG Orders left:  1324216
# Cascade length:  8
# New Orders left:  1324208
# making new cascade
#
#
# OG Orders left:  1324208
# Cascade length:  21
# New Orders left:  1324187
# making new cascade
#
#
# OG Orders left:  1324187
# Cascade length:  420
# New Orders left:  1323767
# making new cascade
#
#
# OG Orders left:  1323767
# Cascade length:  767
# New Orders left:  1323000
# making new cascade
#
#
# OG Orders left:  1323000
# Cascade length:  242
# New Orders left:  1322758
# making new cascade
#
#
# OG Orders left:  1322758
# Cascade length:  524
# New Orders left:  1322234
# making new cascade
#
#
# OG Orders left:  1322234
# Cascade length:  2
# New Orders left:  1322232
# making new cascade
#
#
# OG Orders left:  1322232
# Cascade length:  375
# New Orders left:  1321857
# making new cascade
#
#
# OG Orders left:  1321857
# Cascade length:  892
# New Orders left:  1320965
# making new cascade
#
#
# OG Orders left:  1320965
# Cascade length:  9
# New Orders left:  1320956
# making new cascade
#
#
# OG Orders left:  1320956
# Cascade length:  1
# New Orders left:  1320955
# making new cascade
#
#
# OG Orders left:  1320955
# Cascade length:  19
# New Orders left:  1320936
# making new cascade
#
#
# OG Orders left:  1320936
# Cascade length:  52
# New Orders left:  1320884
# making new cascade
#
#
# OG Orders left:  1320884
# Cascade length:  496
# New Orders left:  1320388
# making new cascade
#
#
# OG Orders left:  1320388
# Cascade length:  632
# New Orders left:  1319756
# making new cascade
#
#
# OG Orders left:  1319756
# Cascade length:  791
# New Orders left:  1318965
# making new cascade
#
#
# OG Orders left:  1318965
# Cascade length:  8
# New Orders left:  1318957
# making new cascade
#
#
# OG Orders left:  1318957
# Cascade length:  2
# New Orders left:  1318955
# making new cascade
#
#
# OG Orders left:  1318955
# Cascade length:  1095
# New Orders left:  1317860
# making new cascade
#
#
# OG Orders left:  1317860
# Cascade length:  32
# New Orders left:  1317828
# making new cascade
#
#
# OG Orders left:  1317828
# Cascade length:  1
# New Orders left:  1317827
# making new cascade
#
#
# OG Orders left:  1317827
# Cascade length:  5
# New Orders left:  1317822
# making new cascade
#
#
# OG Orders left:  1317822
# Cascade length:  590
# New Orders left:  1317232
# making new cascade
#
#
# OG Orders left:  1317232
# Cascade length:  636
# New Orders left:  1316596
# making new cascade
#
#
# OG Orders left:  1316596
# Cascade length:  635
# New Orders left:  1315961
# making new cascade
#
#
# OG Orders left:  1315961
# Cascade length:  10
# New Orders left:  1315951
# making new cascade
#
#
# OG Orders left:  1315951
# Cascade length:  37
# New Orders left:  1315914
# making new cascade
#
#
# OG Orders left:  1315914
# Cascade length:  351
# New Orders left:  1315563
# making new cascade
#
#
# OG Orders left:  1315563
# Cascade length:  537
# New Orders left:  1315026
# making new cascade
#
#
# OG Orders left:  1315026
# Cascade length:  21
# New Orders left:  1315005
# making new cascade
#
#
# OG Orders left:  1315005
# Cascade length:  4
# New Orders left:  1315001
# making new cascade
#
#
# OG Orders left:  1315001
# Cascade length:  743
# New Orders left:  1314258
# making new cascade
#
#
# OG Orders left:  1314258
# Cascade length:  13
# New Orders left:  1314245
# making new cascade
#
#
# OG Orders left:  1314245
# Cascade length:  1
# New Orders left:  1314244
# making new cascade
#
#
# OG Orders left:  1314244
# Cascade length:  550
# New Orders left:  1313694
# making new cascade
#
#
# OG Orders left:  1313694
# Cascade length:  286
# New Orders left:  1313408
# making new cascade
#
#
# OG Orders left:  1313408
# Cascade length:  672
# New Orders left:  1312736
# making new cascade
#
#
# OG Orders left:  1312736
# Cascade length:  583
# New Orders left:  1312153
# making new cascade
#
#
# OG Orders left:  1312153
# Cascade length:  517
# New Orders left:  1311636
# making new cascade
#
#
# OG Orders left:  1311636
# Cascade length:  3
# New Orders left:  1311633
# making new cascade
#
#
# OG Orders left:  1311633
# Cascade length:  628
# New Orders left:  1311005
# making new cascade
#
#
# OG Orders left:  1311005
# Cascade length:  9
# New Orders left:  1310996
# making new cascade
#
#
# OG Orders left:  1310996
# Cascade length:  15
# New Orders left:  1310981
# making new cascade
#
#
# OG Orders left:  1310981
# Cascade length:  34
# New Orders left:  1310947
# making new cascade
#
#
# OG Orders left:  1310947
# Cascade length:  336
# New Orders left:  1310611
# making new cascade
#
#
# OG Orders left:  1310611
# Cascade length:  4
# New Orders left:  1310607
# making new cascade
#
#
# OG Orders left:  1310607
# Cascade length:  669
# New Orders left:  1309938
# making new cascade
#
#
# OG Orders left:  1309938
# Cascade length:  18
# New Orders left:  1309920
# making new cascade
#
#
# OG Orders left:  1309920
# Cascade length:  15
# New Orders left:  1309905
# making new cascade
#
#
# OG Orders left:  1309905
# Cascade length:  5
# New Orders left:  1309900
# making new cascade
#
#
# OG Orders left:  1309900
# Cascade length:  686
# New Orders left:  1309214
# making new cascade
#
#
# OG Orders left:  1309214
# Cascade length:  17
# New Orders left:  1309197
# making new cascade
#
#
# OG Orders left:  1309197
# Cascade length:  3
# New Orders left:  1309194
# making new cascade
#
#
# OG Orders left:  1309194
# Cascade length:  1
# New Orders left:  1309193
# making new cascade
#
#
# OG Orders left:  1309193
# Cascade length:  398
# New Orders left:  1308795
# making new cascade
#
#
# OG Orders left:  1308795
# Cascade length:  437
# New Orders left:  1308358
# making new cascade
#
#
# OG Orders left:  1308358
# Cascade length:  10
# New Orders left:  1308348
# making new cascade
#
#
# OG Orders left:  1308348
# Cascade length:  1
# New Orders left:  1308347
# making new cascade
#
#
# OG Orders left:  1308347
# Cascade length:  14
# New Orders left:  1308333
# making new cascade
#
#
# OG Orders left:  1308333
# Cascade length:  20
# New Orders left:  1308313
# making new cascade
#
#
# OG Orders left:  1308313
# Cascade length:  19
# New Orders left:  1308294
# making new cascade
#
#
# OG Orders left:  1308294
# Cascade length:  7
# New Orders left:  1308287
# making new cascade
#
#
# OG Orders left:  1308287
# Cascade length:  617
# New Orders left:  1307670
# making new cascade
#
#
# OG Orders left:  1307670
# Cascade length:  13
# New Orders left:  1307657
# making new cascade
#
#
# OG Orders left:  1307657
# Cascade length:  498
# New Orders left:  1307159
# making new cascade
#
#
# OG Orders left:  1307159
# Cascade length:  20
# New Orders left:  1307139
# making new cascade
#
#
# OG Orders left:  1307139
# Cascade length:  395
# New Orders left:  1306744
# making new cascade
#
#
# OG Orders left:  1306744
# Cascade length:  524
# New Orders left:  1306220
# making new cascade
#
#
# OG Orders left:  1306220
# Cascade length:  13
# New Orders left:  1306207
# making new cascade
#
#
# OG Orders left:  1306207
# Cascade length:  10
# New Orders left:  1306197
# making new cascade
#
#
# OG Orders left:  1306197
# Cascade length:  550
# New Orders left:  1305647
# making new cascade
#
#
# OG Orders left:  1305647
# Cascade length:  474
# New Orders left:  1305173
# making new cascade
#
#
# OG Orders left:  1305173
# Cascade length:  7
# New Orders left:  1305166
# making new cascade
#
#
# OG Orders left:  1305166
# Cascade length:  19
# New Orders left:  1305147
# making new cascade
#
#
# OG Orders left:  1305147
# Cascade length:  505
# New Orders left:  1304642
# making new cascade
#
#
# OG Orders left:  1304642
# Cascade length:  260
# New Orders left:  1304382
# making new cascade
#
#
# OG Orders left:  1304382
# Cascade length:  9
# New Orders left:  1304373
# making new cascade
#
#
# OG Orders left:  1304373
# Cascade length:  258
# New Orders left:  1304115
# making new cascade
#
#
# OG Orders left:  1304115
# Cascade length:  525
# New Orders left:  1303590
# making new cascade
#
#
# OG Orders left:  1303590
# Cascade length:  476
# New Orders left:  1303114
# making new cascade
#
#
# OG Orders left:  1303114
# Cascade length:  1
# New Orders left:  1303113
# making new cascade
#
#
# OG Orders left:  1303113
# Cascade length:  7
# New Orders left:  1303106
# making new cascade
#
#
# OG Orders left:  1303106
# Cascade length:  27
# New Orders left:  1303079
# making new cascade
#
#
# OG Orders left:  1303079
# Cascade length:  773
# New Orders left:  1302306
# making new cascade
#
#
# OG Orders left:  1302306
# Cascade length:  489
# New Orders left:  1301817
# making new cascade
#
#
# OG Orders left:  1301817
# Cascade length:  251
# New Orders left:  1301566
# making new cascade
#
#
# OG Orders left:  1301566
# Cascade length:  6
# New Orders left:  1301560
# making new cascade
#
#
# OG Orders left:  1301560
# Cascade length:  1
# New Orders left:  1301559
# making new cascade
#
#
# OG Orders left:  1301559
# Cascade length:  7
# New Orders left:  1301552
# making new cascade
#
#
# OG Orders left:  1301552
# Cascade length:  22
# New Orders left:  1301530
# making new cascade
#
#
# OG Orders left:  1301530
# Cascade length:  686
# New Orders left:  1300844
# making new cascade
#
#
# OG Orders left:  1300844
# Cascade length:  9
# New Orders left:  1300835
# making new cascade
#
#
# OG Orders left:  1300835
# Cascade length:  540
# New Orders left:  1300295
# making new cascade
#
#
# OG Orders left:  1300295
# Cascade length:  394
# New Orders left:  1299901
# making new cascade
#
#
# OG Orders left:  1299901
# Cascade length:  550
# New Orders left:  1299351
# making new cascade
#
#
# OG Orders left:  1299351
# Cascade length:  4
# New Orders left:  1299347
# making new cascade
#
#
# OG Orders left:  1299347
# Cascade length:  1037
# New Orders left:  1298310
# making new cascade
#
#
# OG Orders left:  1298310
# Cascade length:  6
# New Orders left:  1298304
# making new cascade
#
#
# OG Orders left:  1298304
# Cascade length:  454
# New Orders left:  1297850
# making new cascade
#
#
# OG Orders left:  1297850
# Cascade length:  472
# New Orders left:  1297378
# making new cascade
#
#
# OG Orders left:  1297378
# Cascade length:  422
# New Orders left:  1296956
# making new cascade
#
#
# OG Orders left:  1296956
# Cascade length:  5
# New Orders left:  1296951
# making new cascade
#
#
# OG Orders left:  1296951
# Cascade length:  5
# New Orders left:  1296946
# making new cascade
#
#
# OG Orders left:  1296946
# Cascade length:  1
# New Orders left:  1296945
# making new cascade
#
#
# OG Orders left:  1296945
# Cascade length:  26
# New Orders left:  1296919
# making new cascade
#
#
# OG Orders left:  1296919
# Cascade length:  547
# New Orders left:  1296372
# making new cascade
#
#
# OG Orders left:  1296372
# Cascade length:  56
# New Orders left:  1296316
# making new cascade
#
#
# OG Orders left:  1296316
# Cascade length:  767
# New Orders left:  1295549
# making new cascade
#
#
# OG Orders left:  1295549
# Cascade length:  2
# New Orders left:  1295547
# making new cascade
#
#
# OG Orders left:  1295547
# Cascade length:  596
# New Orders left:  1294951
# making new cascade
#
#
# OG Orders left:  1294951
# Cascade length:  209
# New Orders left:  1294742
# making new cascade
#
#
# OG Orders left:  1294742
# Cascade length:  5
# New Orders left:  1294737
# making new cascade
#
#
# OG Orders left:  1294737
# Cascade length:  509
# New Orders left:  1294228
# making new cascade
#
#
# OG Orders left:  1294228
# Cascade length:  13
# New Orders left:  1294215
# making new cascade
#
#
# OG Orders left:  1294215
# Cascade length:  366
# New Orders left:  1293849
# making new cascade
#
#
# OG Orders left:  1293849
# Cascade length:  406
# New Orders left:  1293443
# making new cascade
#
#
# OG Orders left:  1293443
# Cascade length:  2
# New Orders left:  1293441
# making new cascade
#
#
# OG Orders left:  1293441
# Cascade length:  34
# New Orders left:  1293407
# making new cascade
#
#
# OG Orders left:  1293407
# Cascade length:  15
# New Orders left:  1293392
# making new cascade
#
#
# OG Orders left:  1293392
# Cascade length:  2
# New Orders left:  1293390
# making new cascade
#
#
# OG Orders left:  1293390
# Cascade length:  434
# New Orders left:  1292956
# making new cascade
#
#
# OG Orders left:  1292956
# Cascade length:  36
# New Orders left:  1292920
# making new cascade
#
#
# OG Orders left:  1292920
# Cascade length:  4
# New Orders left:  1292916
# making new cascade
#
#
# OG Orders left:  1292916
# Cascade length:  1
# New Orders left:  1292915
# making new cascade
#
#
# OG Orders left:  1292915
# Cascade length:  1
# New Orders left:  1292914
# making new cascade
#
#
# OG Orders left:  1292914
# Cascade length:  148
# New Orders left:  1292766
# making new cascade
#
#
# OG Orders left:  1292766
# Cascade length:  1
# New Orders left:  1292765
# making new cascade
#
#
# OG Orders left:  1292765
# Cascade length:  2
# New Orders left:  1292763
# making new cascade
#
#
# OG Orders left:  1292763
# Cascade length:  5
# New Orders left:  1292758
# making new cascade
#
#
# OG Orders left:  1292758
# Cascade length:  460
# New Orders left:  1292298
# making new cascade
#
#
# OG Orders left:  1292298
# Cascade length:  21
# New Orders left:  1292277
# making new cascade
#
#
# OG Orders left:  1292277
# Cascade length:  6
# New Orders left:  1292271
# making new cascade
#
#
# OG Orders left:  1292271
# Cascade length:  93
# New Orders left:  1292178
# making new cascade
#
#
# OG Orders left:  1292178
# Cascade length:  20
# New Orders left:  1292158
# making new cascade
#
#
# OG Orders left:  1292158
# Cascade length:  4
# New Orders left:  1292154
# making new cascade
#
#
# OG Orders left:  1292154
# Cascade length:  457
# New Orders left:  1291697
# making new cascade
#
#
# OG Orders left:  1291697
# Cascade length:  433
# New Orders left:  1291264
# making new cascade
#
#
# OG Orders left:  1291264
# Cascade length:  428
# New Orders left:  1290836
# making new cascade
#
#
# OG Orders left:  1290836
# Cascade length:  373
# New Orders left:  1290463
# making new cascade
#
#
# OG Orders left:  1290463
# Cascade length:  421
# New Orders left:  1290042
# making new cascade
#
#
# OG Orders left:  1290042
# Cascade length:  3
# New Orders left:  1290039
# making new cascade
#
#
# OG Orders left:  1290039
# Cascade length:  4
# New Orders left:  1290035
# making new cascade
#
#
# OG Orders left:  1290035
# Cascade length:  21
# New Orders left:  1290014
# making new cascade
#
#
# OG Orders left:  1290014
# Cascade length:  456
# New Orders left:  1289558
# making new cascade
#
#
# OG Orders left:  1289558
# Cascade length:  33
# New Orders left:  1289525
# making new cascade
#
#
# OG Orders left:  1289525
# Cascade length:  3
# New Orders left:  1289522
# making new cascade
#
#
# OG Orders left:  1289522
# Cascade length:  473
# New Orders left:  1289049
# making new cascade
#
#
# OG Orders left:  1289049
# Cascade length:  10
# New Orders left:  1289039
# making new cascade
#
#
# OG Orders left:  1289039
# Cascade length:  545
# New Orders left:  1288494
# making new cascade
#
#
# OG Orders left:  1288494
# Cascade length:  37
# New Orders left:  1288457
# making new cascade
#
#
# OG Orders left:  1288457
# Cascade length:  395
# New Orders left:  1288062
# making new cascade
#
#
# OG Orders left:  1288062
# Cascade length:  525
# New Orders left:  1287537
# making new cascade
#
#
# OG Orders left:  1287537
# Cascade length:  301
# New Orders left:  1287236
# making new cascade
#
#
# OG Orders left:  1287236
# Cascade length:  5
# New Orders left:  1287231
# making new cascade
#
#
# OG Orders left:  1287231
# Cascade length:  19
# New Orders left:  1287212
# making new cascade
#
#
# OG Orders left:  1287212
# Cascade length:  10
# New Orders left:  1287202
# making new cascade
#
#
# OG Orders left:  1287202
# Cascade length:  509
# New Orders left:  1286693
# making new cascade
#
#
# OG Orders left:  1286693
# Cascade length:  347
# New Orders left:  1286346
# making new cascade
#
#
# OG Orders left:  1286346
# Cascade length:  4
# New Orders left:  1286342
# making new cascade
#
#
# OG Orders left:  1286342
# Cascade length:  19
# New Orders left:  1286323
# making new cascade
#
#
# OG Orders left:  1286323
# Cascade length:  16
# New Orders left:  1286307
# making new cascade
#
#
# OG Orders left:  1286307
# Cascade length:  24
# New Orders left:  1286283
# making new cascade
#
#
# OG Orders left:  1286283
# Cascade length:  7
# New Orders left:  1286276
# making new cascade
#
#
# OG Orders left:  1286276
# Cascade length:  575
# New Orders left:  1285701
# making new cascade
#
#
# OG Orders left:  1285701
# Cascade length:  41
# New Orders left:  1285660
# making new cascade
#
#
# OG Orders left:  1285660
# Cascade length:  575
# New Orders left:  1285085
# making new cascade
#
#
# OG Orders left:  1285085
# Cascade length:  2
# New Orders left:  1285083
# making new cascade
#
#
# OG Orders left:  1285083
# Cascade length:  8
# New Orders left:  1285075
# making new cascade
#
#
# OG Orders left:  1285075
# Cascade length:  2
# New Orders left:  1285073
# making new cascade
#
#
# OG Orders left:  1285073
# Cascade length:  10
# New Orders left:  1285063
# making new cascade
#
#
# OG Orders left:  1285063
# Cascade length:  612
# New Orders left:  1284451
# making new cascade
#
#
# OG Orders left:  1284451
# Cascade length:  60
# New Orders left:  1284391
# making new cascade
#
#
# OG Orders left:  1284391
# Cascade length:  547
# New Orders left:  1283844
# making new cascade
#
#
# OG Orders left:  1283844
# Cascade length:  11
# New Orders left:  1283833
# making new cascade
#
#
# OG Orders left:  1283833
# Cascade length:  283
# New Orders left:  1283550
# making new cascade
#
#
# OG Orders left:  1283550
# Cascade length:  7
# New Orders left:  1283543
# making new cascade
#
#
# OG Orders left:  1283543
# Cascade length:  622
# New Orders left:  1282921
# making new cascade
#
#
# OG Orders left:  1282921
# Cascade length:  139
# New Orders left:  1282782
# making new cascade
#
#
# OG Orders left:  1282782
# Cascade length:  46
# New Orders left:  1282736
# making new cascade
#
#
# OG Orders left:  1282736
# Cascade length:  735
# New Orders left:  1282001
# making new cascade
#
#
# OG Orders left:  1282001
# Cascade length:  8
# New Orders left:  1281993
# making new cascade
#
#
# OG Orders left:  1281993
# Cascade length:  590
# New Orders left:  1281403
# making new cascade
#
#
# OG Orders left:  1281403
# Cascade length:  6
# New Orders left:  1281397
# making new cascade
#
#
# OG Orders left:  1281397
# Cascade length:  509
# New Orders left:  1280888
# making new cascade
#
#
# OG Orders left:  1280888
# Cascade length:  26
# New Orders left:  1280862
# making new cascade
#
#
# OG Orders left:  1280862
# Cascade length:  2
# New Orders left:  1280860
# making new cascade
#
#
# OG Orders left:  1280860
# Cascade length:  6
# New Orders left:  1280854
# making new cascade
#
#
# OG Orders left:  1280854
# Cascade length:  32
# New Orders left:  1280822
# making new cascade
#
#
# OG Orders left:  1280822
# Cascade length:  1
# New Orders left:  1280821
# making new cascade
#
#
# OG Orders left:  1280821
# Cascade length:  1
# New Orders left:  1280820
# making new cascade
#
#
# OG Orders left:  1280820
# Cascade length:  7
# New Orders left:  1280813
# making new cascade
#
#
# OG Orders left:  1280813
# Cascade length:  493
# New Orders left:  1280320
# making new cascade
#
#
# OG Orders left:  1280320
# Cascade length:  20
# New Orders left:  1280300
# making new cascade
#
#
# OG Orders left:  1280300
# Cascade length:  5
# New Orders left:  1280295
# making new cascade
#
#
# OG Orders left:  1280295
# Cascade length:  6
# New Orders left:  1280289
# making new cascade
#
#
# OG Orders left:  1280289
# Cascade length:  4
# New Orders left:  1280285
# making new cascade
#
#
# OG Orders left:  1280285
# Cascade length:  11
# New Orders left:  1280274
# making new cascade
#
#
# OG Orders left:  1280274
# Cascade length:  551
# New Orders left:  1279723
# making new cascade
#
#
# OG Orders left:  1279723
# Cascade length:  8
# New Orders left:  1279715
# making new cascade
#
#
# OG Orders left:  1279715
# Cascade length:  562
# New Orders left:  1279153
# making new cascade
#
#
# OG Orders left:  1279153
# Cascade length:  16
# New Orders left:  1279137
# making new cascade
#
#
# OG Orders left:  1279137
# Cascade length:  6
# New Orders left:  1279131
# making new cascade
#
#
# OG Orders left:  1279131
# Cascade length:  5
# New Orders left:  1279126
# making new cascade
#
#
# OG Orders left:  1279126
# Cascade length:  2
# New Orders left:  1279124
# making new cascade
#
#
# OG Orders left:  1279124
# Cascade length:  616
# New Orders left:  1278508
# making new cascade
#
#
# OG Orders left:  1278508
# Cascade length:  386
# New Orders left:  1278122
# making new cascade
#
#
# OG Orders left:  1278122
# Cascade length:  19
# New Orders left:  1278103
# making new cascade
#
#
# OG Orders left:  1278103
# Cascade length:  10
# New Orders left:  1278093
# making new cascade
#
#
# OG Orders left:  1278093
# Cascade length:  490
# New Orders left:  1277603
# making new cascade
#
#
# OG Orders left:  1277603
# Cascade length:  1
# New Orders left:  1277602
# making new cascade
#
#
# OG Orders left:  1277602
# Cascade length:  714
# New Orders left:  1276888
# making new cascade
#
#
# OG Orders left:  1276888
# Cascade length:  13
# New Orders left:  1276875
# making new cascade
#
#
# OG Orders left:  1276875
# Cascade length:  8
# New Orders left:  1276867
# making new cascade
#
#
# OG Orders left:  1276867
# Cascade length:  513
# New Orders left:  1276354
# making new cascade
#
#
# OG Orders left:  1276354
# Cascade length:  330
# New Orders left:  1276024
# making new cascade
#
#
# OG Orders left:  1276024
# Cascade length:  2
# New Orders left:  1276022
# making new cascade
#
#
# OG Orders left:  1276022
# Cascade length:  349
# New Orders left:  1275673
# making new cascade
#
#
# OG Orders left:  1275673
# Cascade length:  9
# New Orders left:  1275664
# making new cascade
#
#
# OG Orders left:  1275664
# Cascade length:  14
# New Orders left:  1275650
# making new cascade
#
#
# OG Orders left:  1275650
# Cascade length:  460
# New Orders left:  1275190
# making new cascade
#
#
# OG Orders left:  1275190
# Cascade length:  392
# New Orders left:  1274798
# making new cascade
#
#
# OG Orders left:  1274798
# Cascade length:  10
# New Orders left:  1274788
# making new cascade
#
#
# OG Orders left:  1274788
# Cascade length:  25
# New Orders left:  1274763
# making new cascade
#
#
# OG Orders left:  1274763
# Cascade length:  22
# New Orders left:  1274741
# making new cascade
#
#
# OG Orders left:  1274741
# Cascade length:  437
# New Orders left:  1274304
# making new cascade
#
#
# OG Orders left:  1274304
# Cascade length:  7
# New Orders left:  1274297
# making new cascade
#
#
# OG Orders left:  1274297
# Cascade length:  2
# New Orders left:  1274295
# making new cascade
#
#
# OG Orders left:  1274295
# Cascade length:  2
# New Orders left:  1274293
# making new cascade
#
#
# OG Orders left:  1274293
# Cascade length:  327
# New Orders left:  1273966
# making new cascade
#
#
# OG Orders left:  1273966
# Cascade length:  438
# New Orders left:  1273528
# making new cascade
#
#
# OG Orders left:  1273528
# Cascade length:  24
# New Orders left:  1273504
# making new cascade
#
#
# OG Orders left:  1273504
# Cascade length:  13
# New Orders left:  1273491
# making new cascade
#
#
# OG Orders left:  1273491
# Cascade length:  403
# New Orders left:  1273088
# making new cascade
#
#
# OG Orders left:  1273088
# Cascade length:  10
# New Orders left:  1273078
# making new cascade
#
#
# OG Orders left:  1273078
# Cascade length:  532
# New Orders left:  1272546
# making new cascade
#
#
# OG Orders left:  1272546
# Cascade length:  2
# New Orders left:  1272544
# making new cascade
#
#
# OG Orders left:  1272544
# Cascade length:  7
# New Orders left:  1272537
# making new cascade
#
#
# OG Orders left:  1272537
# Cascade length:  2
# New Orders left:  1272535
# making new cascade
#
#
# OG Orders left:  1272535
# Cascade length:  465
# New Orders left:  1272070
# making new cascade
#
#
# OG Orders left:  1272070
# Cascade length:  1
# New Orders left:  1272069
# making new cascade
#
#
# OG Orders left:  1272069
# Cascade length:  21
# New Orders left:  1272048
# making new cascade
#
#
# OG Orders left:  1272048
# Cascade length:  11
# New Orders left:  1272037
# making new cascade
#
#
# OG Orders left:  1272037
# Cascade length:  485
# New Orders left:  1271552
# making new cascade
#
#
# OG Orders left:  1271552
# Cascade length:  406
# New Orders left:  1271146
# making new cascade
#
#
# OG Orders left:  1271146
# Cascade length:  39
# New Orders left:  1271107
# making new cascade
#
#
# OG Orders left:  1271107
# Cascade length:  143
# New Orders left:  1270964
# making new cascade
#
#
# OG Orders left:  1270964
# Cascade length:  334
# New Orders left:  1270630
# making new cascade
#
#
# OG Orders left:  1270630
# Cascade length:  17
# New Orders left:  1270613
# making new cascade
#
#
# OG Orders left:  1270613
# Cascade length:  608
# New Orders left:  1270005
# making new cascade
#
#
# OG Orders left:  1270005
# Cascade length:  285
# New Orders left:  1269720
# making new cascade
#
#
# OG Orders left:  1269720
# Cascade length:  20
# New Orders left:  1269700
# making new cascade
#
#
# OG Orders left:  1269700
# Cascade length:  10
# New Orders left:  1269690
# making new cascade
#
#
# OG Orders left:  1269690
# Cascade length:  15
# New Orders left:  1269675
# making new cascade
#
#
# OG Orders left:  1269675
# Cascade length:  506
# New Orders left:  1269169
# making new cascade
#
#
# OG Orders left:  1269169
# Cascade length:  518
# New Orders left:  1268651
# making new cascade
#
#
# OG Orders left:  1268651
# Cascade length:  4
# New Orders left:  1268647
# making new cascade
#
#
# OG Orders left:  1268647
# Cascade length:  8
# New Orders left:  1268639
# making new cascade
#
#
# OG Orders left:  1268639
# Cascade length:  1
# New Orders left:  1268638
# making new cascade
#
#
# OG Orders left:  1268638
# Cascade length:  7
# New Orders left:  1268631
# making new cascade
#
#
# OG Orders left:  1268631
# Cascade length:  479
# New Orders left:  1268152
# making new cascade
#
#
# OG Orders left:  1268152
# Cascade length:  1
# New Orders left:  1268151
# making new cascade
#
#
# OG Orders left:  1268151
# Cascade length:  10
# New Orders left:  1268141
# making new cascade
#
#
# OG Orders left:  1268141
# Cascade length:  5
# New Orders left:  1268136
# making new cascade
#
#
# OG Orders left:  1268136
# Cascade length:  519
# New Orders left:  1267617
# making new cascade
#
#
# OG Orders left:  1267617
# Cascade length:  2
# New Orders left:  1267615
# making new cascade
#
#
# OG Orders left:  1267615
# Cascade length:  37
# New Orders left:  1267578
# making new cascade
#
#
# OG Orders left:  1267578
# Cascade length:  12
# New Orders left:  1267566
# making new cascade
#
#
# OG Orders left:  1267566
# Cascade length:  1
# New Orders left:  1267565
# making new cascade
#
#
# OG Orders left:  1267565
# Cascade length:  4
# New Orders left:  1267561
# making new cascade
#
#
# OG Orders left:  1267561
# Cascade length:  624
# New Orders left:  1266937
# making new cascade
#
#
# OG Orders left:  1266937
# Cascade length:  1
# New Orders left:  1266936
# making new cascade
#
#
# OG Orders left:  1266936
# Cascade length:  549
# New Orders left:  1266387
# making new cascade
#
#
# OG Orders left:  1266387
# Cascade length:  1
# New Orders left:  1266386
# making new cascade
#
#
# OG Orders left:  1266386
# Cascade length:  547
# New Orders left:  1265839
# making new cascade
#
#
# OG Orders left:  1265839
# Cascade length:  25
# New Orders left:  1265814
# making new cascade
#
#
# OG Orders left:  1265814
# Cascade length:  10
# New Orders left:  1265804
# making new cascade
#
#
# OG Orders left:  1265804
# Cascade length:  5
# New Orders left:  1265799
# making new cascade
#
#
# OG Orders left:  1265799
# Cascade length:  12
# New Orders left:  1265787
# making new cascade
#
#
# OG Orders left:  1265787
# Cascade length:  10
# New Orders left:  1265777
# making new cascade
#
#
# OG Orders left:  1265777
# Cascade length:  739
# New Orders left:  1265038
# making new cascade
#
#
# OG Orders left:  1265038
# Cascade length:  497
# New Orders left:  1264541
# making new cascade
#
#
# OG Orders left:  1264541
# Cascade length:  8
# New Orders left:  1264533
# making new cascade
#
#
# OG Orders left:  1264533
# Cascade length:  17
# New Orders left:  1264516
# making new cascade
#
#
# OG Orders left:  1264516
# Cascade length:  457
# New Orders left:  1264059
# making new cascade
#
#
# OG Orders left:  1264059
# Cascade length:  524
# New Orders left:  1263535
# making new cascade
#
#
# OG Orders left:  1263535
# Cascade length:  2
# New Orders left:  1263533
# making new cascade
#
#
# OG Orders left:  1263533
# Cascade length:  4
# New Orders left:  1263529
# making new cascade
#
#
# OG Orders left:  1263529
# Cascade length:  5
# New Orders left:  1263524
# making new cascade
#
#
# OG Orders left:  1263524
# Cascade length:  530
# New Orders left:  1262994
# making new cascade
#
#
# OG Orders left:  1262994
# Cascade length:  23
# New Orders left:  1262971
# making new cascade
#
#
# OG Orders left:  1262971
# Cascade length:  4
# New Orders left:  1262967
# making new cascade
#
#
# OG Orders left:  1262967
# Cascade length:  13
# New Orders left:  1262954
# making new cascade
#
#
# OG Orders left:  1262954
# Cascade length:  683
# New Orders left:  1262271
# making new cascade
#
#
# OG Orders left:  1262271
# Cascade length:  451
# New Orders left:  1261820
# making new cascade
#
#
# OG Orders left:  1261820
# Cascade length:  2
# New Orders left:  1261818
# making new cascade
#
#
# OG Orders left:  1261818
# Cascade length:  3
# New Orders left:  1261815
# making new cascade
#
#
# OG Orders left:  1261815
# Cascade length:  19
# New Orders left:  1261796
# making new cascade
#
#
# OG Orders left:  1261796
# Cascade length:  466
# New Orders left:  1261330
# making new cascade
#
#
# OG Orders left:  1261330
# Cascade length:  297
# New Orders left:  1261033
# making new cascade
#
#
# OG Orders left:  1261033
# Cascade length:  8
# New Orders left:  1261025
# making new cascade
#
#
# OG Orders left:  1261025
# Cascade length:  1
# New Orders left:  1261024
# making new cascade
#
#
# OG Orders left:  1261024
# Cascade length:  1
# New Orders left:  1261023
# making new cascade
#
#
# OG Orders left:  1261023
# Cascade length:  2
# New Orders left:  1261021
# making new cascade
#
#
# OG Orders left:  1261021
# Cascade length:  14
# New Orders left:  1261007
# making new cascade
#
#
# OG Orders left:  1261007
# Cascade length:  39
# New Orders left:  1260968
# making new cascade
#
#
# OG Orders left:  1260968
# Cascade length:  3
# New Orders left:  1260965
# making new cascade
#
#
# OG Orders left:  1260965
# Cascade length:  487
# New Orders left:  1260478
# making new cascade
#
#
# OG Orders left:  1260478
# Cascade length:  2
# New Orders left:  1260476
# making new cascade
#
#
# OG Orders left:  1260476
# Cascade length:  926
# New Orders left:  1259550
# making new cascade
#
#
# OG Orders left:  1259550
# Cascade length:  311
# New Orders left:  1259239
# making new cascade
#
#
# OG Orders left:  1259239
# Cascade length:  19
# New Orders left:  1259220
# making new cascade
#
#
# OG Orders left:  1259220
# Cascade length:  680
# New Orders left:  1258540
# making new cascade
#
#
# OG Orders left:  1258540
# Cascade length:  604
# New Orders left:  1257936
# making new cascade
#
#
# OG Orders left:  1257936
# Cascade length:  692
# New Orders left:  1257244
# making new cascade
#
#
# OG Orders left:  1257244
# Cascade length:  8
# New Orders left:  1257236
# making new cascade
#
#
# OG Orders left:  1257236
# Cascade length:  4
# New Orders left:  1257232
# making new cascade
#
#
# OG Orders left:  1257232
# Cascade length:  10
# New Orders left:  1257222
# making new cascade
#
#
# OG Orders left:  1257222
# Cascade length:  521
# New Orders left:  1256701
# making new cascade
#
#
# OG Orders left:  1256701
# Cascade length:  653
# New Orders left:  1256048
# making new cascade
#
#
# OG Orders left:  1256048
# Cascade length:  28
# New Orders left:  1256020
# making new cascade
#
#
# OG Orders left:  1256020
# Cascade length:  950
# New Orders left:  1255070
# making new cascade
#
#
# OG Orders left:  1255070
# Cascade length:  659
# New Orders left:  1254411
# making new cascade
#
#
# OG Orders left:  1254411
# Cascade length:  8
# New Orders left:  1254403
# making new cascade
#
#
# OG Orders left:  1254403
# Cascade length:  1
# New Orders left:  1254402
# making new cascade
#
#
# OG Orders left:  1254402
# Cascade length:  711
# New Orders left:  1253691
# making new cascade
#
#
# OG Orders left:  1253691
# Cascade length:  1093
# New Orders left:  1252598
# making new cascade
#
#
# OG Orders left:  1252598
# Cascade length:  4
# New Orders left:  1252594
# making new cascade
#
#
# OG Orders left:  1252594
# Cascade length:  8
# New Orders left:  1252586
# making new cascade
#
#
# OG Orders left:  1252586
# Cascade length:  704
# New Orders left:  1251882
# making new cascade
#
#
# OG Orders left:  1251882
# Cascade length:  2
# New Orders left:  1251880
# making new cascade
#
#
# OG Orders left:  1251880
# Cascade length:  885
# New Orders left:  1250995
# making new cascade
#
#
# OG Orders left:  1250995
# Cascade length:  2
# New Orders left:  1250993
# making new cascade
#
#
# OG Orders left:  1250993
# Cascade length:  9
# New Orders left:  1250984
# making new cascade
#
#
# OG Orders left:  1250984
# Cascade length:  372
# New Orders left:  1250612
# making new cascade
#
#
# OG Orders left:  1250612
# Cascade length:  4
# New Orders left:  1250608
# making new cascade
#
#
# OG Orders left:  1250608
# Cascade length:  825
# New Orders left:  1249783
# making new cascade
#
#
# OG Orders left:  1249783
# Cascade length:  380
# New Orders left:  1249403
# making new cascade
#
#
# OG Orders left:  1249403
# Cascade length:  297
# New Orders left:  1249106
# making new cascade
#
#
# OG Orders left:  1249106
# Cascade length:  153
# New Orders left:  1248953
# making new cascade
#
#
# OG Orders left:  1248953
# Cascade length:  1
# New Orders left:  1248952
# making new cascade
#
#
# OG Orders left:  1248952
# Cascade length:  34
# New Orders left:  1248918
# making new cascade
#
#
# OG Orders left:  1248918
# Cascade length:  305
# New Orders left:  1248613
# making new cascade
#
#
# OG Orders left:  1248613
# Cascade length:  2
# New Orders left:  1248611
# making new cascade
#
#
# OG Orders left:  1248611
# Cascade length:  9
# New Orders left:  1248602
# making new cascade
#
#
# ...
#
#
# OG Orders left:  46446
# Cascade length:  361
# New Orders left:  46085
# making new cascade
#
#
# OG Orders left:  46085
# Cascade length:  1
# New Orders left:  46084
# making new cascade
#
#
# OG Orders left:  46084
# Cascade length:  665
# New Orders left:  45419
# making new cascade
#
#
# OG Orders left:  45419
# Cascade length:  59
# New Orders left:  45360
# making new cascade
#
#
# OG Orders left:  45360
# Cascade length:  473
# New Orders left:  44887
# making new cascade
#
#
# OG Orders left:  44887
# Cascade length:  28
# New Orders left:  44859
# making new cascade
#
#
# OG Orders left:  44859
# Cascade length:  321
# New Orders left:  44538
# making new cascade
#
#
# OG Orders left:  44538
# Cascade length:  653
# New Orders left:  43885
# making new cascade
#
#
# OG Orders left:  43885
# Cascade length:  18
# New Orders left:  43867
# making new cascade
#
#
# OG Orders left:  43867
# Cascade length:  515
# New Orders left:  43352
# making new cascade
#
#
# OG Orders left:  43352
# Cascade length:  938
# New Orders left:  42414
# making new cascade
#
#
# OG Orders left:  42414
# Cascade length:  3
# New Orders left:  42411
# making new cascade
#
#
# OG Orders left:  42411
# Cascade length:  19
# New Orders left:  42392
# making new cascade
#
#
# OG Orders left:  42392
# Cascade length:  4
# New Orders left:  42388
# making new cascade
#
#
# OG Orders left:  42388
# Cascade length:  36
# New Orders left:  42352
# making new cascade
#
#
# OG Orders left:  42352
# Cascade length:  13
# New Orders left:  42339
# making new cascade
#
#
# OG Orders left:  42339
# Cascade length:  599
# New Orders left:  41740
# making new cascade
#
#
# OG Orders left:  41740
# Cascade length:  712
# New Orders left:  41028
# making new cascade
#
#
# OG Orders left:  41028
# Cascade length:  14
# New Orders left:  41014
# making new cascade
#
#
# OG Orders left:  41014
# Cascade length:  448
# New Orders left:  40566
# making new cascade
#
#
# OG Orders left:  40566
# Cascade length:  38
# New Orders left:  40528
# making new cascade
#
#
# OG Orders left:  40528
# Cascade length:  10
# New Orders left:  40518
# making new cascade
#
#
# OG Orders left:  40518
# Cascade length:  522
# New Orders left:  39996
# making new cascade
#
#
# OG Orders left:  39996
# Cascade length:  18
# New Orders left:  39978
# making new cascade
#
#
# OG Orders left:  39978
# Cascade length:  592
# New Orders left:  39386
# making new cascade
#
#
# OG Orders left:  39386
# Cascade length:  1
# New Orders left:  39385
# making new cascade
#
#
# OG Orders left:  39385
# Cascade length:  443
# New Orders left:  38942
# making new cascade
#
#
# OG Orders left:  38942
# Cascade length:  5
# New Orders left:  38937
# making new cascade
#
#
# OG Orders left:  38937
# Cascade length:  404
# New Orders left:  38533
# making new cascade
#
#
# OG Orders left:  38533
# Cascade length:  3
# New Orders left:  38530
# making new cascade
#
#
# OG Orders left:  38530
# Cascade length:  62
# New Orders left:  38468
# making new cascade
#
#
# OG Orders left:  38468
# Cascade length:  531
# New Orders left:  37937
# making new cascade
#
#
# OG Orders left:  37937
# Cascade length:  17
# New Orders left:  37920
# making new cascade
#
#
# OG Orders left:  37920
# Cascade length:  779
# New Orders left:  37141
# making new cascade
#
#
# OG Orders left:  37141
# Cascade length:  86
# New Orders left:  37055
# making new cascade
#
#
# OG Orders left:  37055
# Cascade length:  21
# New Orders left:  37034
# making new cascade
#
#
# OG Orders left:  37034
# Cascade length:  38
# New Orders left:  36996
# making new cascade
#
#
# OG Orders left:  36996
# Cascade length:  933
# New Orders left:  36063
# making new cascade
#
#
# OG Orders left:  36063
# Cascade length:  11
# New Orders left:  36052
# making new cascade
#
#
# OG Orders left:  36052
# Cascade length:  6
# New Orders left:  36046
# making new cascade
#
#
# OG Orders left:  36046
# Cascade length:  763
# New Orders left:  35283
# making new cascade
#
#
# OG Orders left:  35283
# Cascade length:  4
# New Orders left:  35279
# making new cascade
#
#
# OG Orders left:  35279
# Cascade length:  636
# New Orders left:  34643
# making new cascade
#
#
# OG Orders left:  34643
# Cascade length:  5
# New Orders left:  34638
# making new cascade
#
#
# OG Orders left:  34638
# Cascade length:  749
# New Orders left:  33889
# making new cascade
#
#
# OG Orders left:  33889
# Cascade length:  1
# New Orders left:  33888
# making new cascade
#
#
# OG Orders left:  33888
# Cascade length:  8
# New Orders left:  33880
# making new cascade
#
#
# OG Orders left:  33880
# Cascade length:  815
# New Orders left:  33065
# making new cascade
#
#
# OG Orders left:  33065
# Cascade length:  172
# New Orders left:  32893
# making new cascade
#
#
# OG Orders left:  32893
# Cascade length:  105
# New Orders left:  32788
# making new cascade
#
#
# OG Orders left:  32788
# Cascade length:  665
# New Orders left:  32123
# making new cascade
#
#
# OG Orders left:  32123
# Cascade length:  340
# New Orders left:  31783
# making new cascade
#
#
# OG Orders left:  31783
# Cascade length:  500
# New Orders left:  31283
# making new cascade
#
#
# OG Orders left:  31283
# Cascade length:  12
# New Orders left:  31271
# making new cascade
#
#
# OG Orders left:  31271
# Cascade length:  840
# New Orders left:  30431
# making new cascade
#
#
# OG Orders left:  30431
# Cascade length:  389
# New Orders left:  30042
# making new cascade
#
#
# OG Orders left:  30042
# Cascade length:  55
# New Orders left:  29987
# making new cascade
#
#
# OG Orders left:  29987
# Cascade length:  8
# New Orders left:  29979
# making new cascade
#
#
# OG Orders left:  29979
# Cascade length:  30
# New Orders left:  29949
# making new cascade
#
#
# OG Orders left:  29949
# Cascade length:  799
# New Orders left:  29150
# making new cascade
#
#
# OG Orders left:  29150
# Cascade length:  483
# New Orders left:  28667
# making new cascade
#
#
# OG Orders left:  28667
# Cascade length:  16
# New Orders left:  28651
# making new cascade
#
#
# OG Orders left:  28651
# Cascade length:  1
# New Orders left:  28650
# making new cascade
#
#
# OG Orders left:  28650
# Cascade length:  621
# New Orders left:  28029
# making new cascade
#
#
# OG Orders left:  28029
# Cascade length:  551
# New Orders left:  27478
# making new cascade
#
#
# OG Orders left:  27478
# Cascade length:  704
# New Orders left:  26774
# making new cascade
#
#
# OG Orders left:  26774
# Cascade length:  8
# New Orders left:  26766
# making new cascade
#
#
# OG Orders left:  26766
# Cascade length:  8
# New Orders left:  26758
# making new cascade
#
#
# OG Orders left:  26758
# Cascade length:  32
# New Orders left:  26726
# making new cascade
#
#
# OG Orders left:  26726
# Cascade length:  11
# New Orders left:  26715
# making new cascade
#
#
# OG Orders left:  26715
# Cascade length:  1017
# New Orders left:  25698
# making new cascade
#
#
# OG Orders left:  25698
# Cascade length:  6
# New Orders left:  25692
# making new cascade
#
#
# OG Orders left:  25692
# Cascade length:  990
# New Orders left:  24702
# making new cascade
#
#
# OG Orders left:  24702
# Cascade length:  4
# New Orders left:  24698
# making new cascade
#
#
# OG Orders left:  24698
# Cascade length:  604
# New Orders left:  24094
# making new cascade
#
#
# OG Orders left:  24094
# Cascade length:  286
# New Orders left:  23808
# making new cascade
#
#
# OG Orders left:  23808
# Cascade length:  50
# New Orders left:  23758
# making new cascade
#
#
# OG Orders left:  23758
# Cascade length:  724
# New Orders left:  23034
# making new cascade
#
#
# OG Orders left:  23034
# Cascade length:  1
# New Orders left:  23033
# making new cascade
#
#
# OG Orders left:  23033
# Cascade length:  499
# New Orders left:  22534
# making new cascade
#
#
# OG Orders left:  22534
# Cascade length:  1
# New Orders left:  22533
# making new cascade
#
#
# OG Orders left:  22533
# Cascade length:  748
# New Orders left:  21785
# making new cascade
#
#
# OG Orders left:  21785
# Cascade length:  8
# New Orders left:  21777
# making new cascade
#
#
# OG Orders left:  21777
# Cascade length:  726
# New Orders left:  21051
# making new cascade
#
#
# OG Orders left:  21051
# Cascade length:  97
# New Orders left:  20954
# making new cascade
#
#
# OG Orders left:  20954
# Cascade length:  930
# New Orders left:  20024
# making new cascade
#
#
# OG Orders left:  20024
# Cascade length:  1
# New Orders left:  20023
# making new cascade
#
#
# OG Orders left:  20023
# Cascade length:  476
# New Orders left:  19547
# making new cascade
#
#
# OG Orders left:  19547
# Cascade length:  533
# New Orders left:  19014
# making new cascade
#
#
# OG Orders left:  19014
# Cascade length:  436
# New Orders left:  18578
# making new cascade
#
#
# OG Orders left:  18578
# Cascade length:  624
# New Orders left:  17954
# making new cascade
#
#
# OG Orders left:  17954
# Cascade length:  452
# New Orders left:  17502
# making new cascade
#
#
# OG Orders left:  17502
# Cascade length:  1
# New Orders left:  17501
# making new cascade
#
#
# OG Orders left:  17501
# Cascade length:  679
# New Orders left:  16822
# making new cascade
#
#
# OG Orders left:  16822
# Cascade length:  597
# New Orders left:  16225
# making new cascade
#
#
# OG Orders left:  16225
# Cascade length:  430
# New Orders left:  15795
# making new cascade
#
#
# OG Orders left:  15795
# Cascade length:  17
# New Orders left:  15778
# making new cascade
#
#
# OG Orders left:  15778
# Cascade length:  811
# New Orders left:  14967
# making new cascade
#
#
# OG Orders left:  14967
# Cascade length:  16
# New Orders left:  14951
# making new cascade
#
#
# OG Orders left:  14951
# Cascade length:  641
# New Orders left:  14310
# making new cascade
#
#
# OG Orders left:  14310
# Cascade length:  539
# New Orders left:  13771
# making new cascade
#
#
# OG Orders left:  13771
# Cascade length:  39
# New Orders left:  13732
# making new cascade
#
#
# OG Orders left:  13732
# Cascade length:  2
# New Orders left:  13730
# making new cascade
#
#
# OG Orders left:  13730
# Cascade length:  579
# New Orders left:  13151
# making new cascade
#
#
# OG Orders left:  13151
# Cascade length:  523
# New Orders left:  12628
# making new cascade
#
#
# OG Orders left:  12628
# Cascade length:  4
# New Orders left:  12624
# making new cascade
#
#
# OG Orders left:  12624
# Cascade length:  25
# New Orders left:  12599
# making new cascade
#
#
# OG Orders left:  12599
# Cascade length:  63
# New Orders left:  12536
# making new cascade
#
#
# OG Orders left:  12536
# Cascade length:  408
# New Orders left:  12128
# making new cascade
#
#
# OG Orders left:  12128
# Cascade length:  41
# New Orders left:  12087
# making new cascade
#
#
# OG Orders left:  12087
# Cascade length:  447
# New Orders left:  11640
# making new cascade
#
#
# OG Orders left:  11640
# Cascade length:  2
# New Orders left:  11638
# making new cascade
#
#
# OG Orders left:  11638
# Cascade length:  322
# New Orders left:  11316
# making new cascade
#
#
# OG Orders left:  11316
# Cascade length:  88
# New Orders left:  11228
# making new cascade
#
#
# OG Orders left:  11228
# Cascade length:  370
# New Orders left:  10858
# making new cascade
#
#
# OG Orders left:  10858
# Cascade length:  391
# New Orders left:  10467
# making new cascade
#
#
# OG Orders left:  10467
# Cascade length:  512
# New Orders left:  9955
# making new cascade
#
#
# OG Orders left:  9955
# Cascade length:  6
# New Orders left:  9949
# making new cascade
#
#
# OG Orders left:  9949
# Cascade length:  326
# New Orders left:  9623
# making new cascade
#
#
# OG Orders left:  9623
# Cascade length:  187
# New Orders left:  9436
# making new cascade
#
#
# OG Orders left:  9436
# Cascade length:  460
# New Orders left:  8976
# making new cascade
#
#
# OG Orders left:  8976
# Cascade length:  483
# New Orders left:  8493
# making new cascade
#
#
# OG Orders left:  8493
# Cascade length:  1
# New Orders left:  8492
# making new cascade
#
#
# OG Orders left:  8492
# Cascade length:  345
# New Orders left:  8147
# making new cascade
#
#
# OG Orders left:  8147
# Cascade length:  13
# New Orders left:  8134
# making new cascade
#
#
# OG Orders left:  8134
# Cascade length:  369
# New Orders left:  7765
# making new cascade
#
#
# OG Orders left:  7765
# Cascade length:  5
# New Orders left:  7760
# making new cascade
#
#
# OG Orders left:  7760
# Cascade length:  241
# New Orders left:  7519
# making new cascade
#
#
# OG Orders left:  7519
# Cascade length:  13
# New Orders left:  7506
# making new cascade
#
#
# OG Orders left:  7506
# Cascade length:  303
# New Orders left:  7203
# making new cascade
#
#
# OG Orders left:  7203
# Cascade length:  345
# New Orders left:  6858
# making new cascade
#
#
# OG Orders left:  6858
# Cascade length:  544
# New Orders left:  6314
# making new cascade
#
#
# OG Orders left:  6314
# Cascade length:  80
# New Orders left:  6234
# making new cascade
#
#
# OG Orders left:  6234
# Cascade length:  1
# New Orders left:  6233
# making new cascade
#
#
# OG Orders left:  6233
# Cascade length:  298
# New Orders left:  5935
# making new cascade
#
#
# OG Orders left:  5935
# Cascade length:  178
# New Orders left:  5757
# making new cascade
#
#
# OG Orders left:  5757
# Cascade length:  408
# New Orders left:  5349
# making new cascade
#
#
# OG Orders left:  5349
# Cascade length:  397
# New Orders left:  4952
# making new cascade
#
#
# OG Orders left:  4952
# Cascade length:  6
# New Orders left:  4946
# making new cascade
#
#
# OG Orders left:  4946
# Cascade length:  16
# New Orders left:  4930
# making new cascade
#
#
# OG Orders left:  4930
# Cascade length:  252
# New Orders left:  4678
# making new cascade
#
#
# OG Orders left:  4678
# Cascade length:  279
# New Orders left:  4399
# making new cascade
#
#
# OG Orders left:  4399
# Cascade length:  92
# New Orders left:  4307
# making new cascade
#
#
# OG Orders left:  4307
# Cascade length:  277
# New Orders left:  4030
# making new cascade
#
#
# OG Orders left:  4030
# Cascade length:  12
# New Orders left:  4018
# making new cascade
#
#
# OG Orders left:  4018
# Cascade length:  159
# New Orders left:  3859
# making new cascade
#
#
# OG Orders left:  3859
# Cascade length:  166
# New Orders left:  3693
# making new cascade
#
#
# OG Orders left:  3693
# Cascade length:  217
# New Orders left:  3476
# making new cascade
#
#
# OG Orders left:  3476
# Cascade length:  140
# New Orders left:  3336
# making new cascade
#
#
# OG Orders left:  3336
# Cascade length:  24
# New Orders left:  3312
# making new cascade
#
#
# OG Orders left:  3312
# Cascade length:  275
# New Orders left:  3037
# making new cascade
#
#
# OG Orders left:  3037
# Cascade length:  72
# New Orders left:  2965
# making new cascade
#
#
# OG Orders left:  2965
# Cascade length:  298
# New Orders left:  2667
# making new cascade
#
#
# OG Orders left:  2667
# Cascade length:  7
# New Orders left:  2660
# making new cascade
#
#
# OG Orders left:  2660
# Cascade length:  156
# New Orders left:  2504
# making new cascade
#
#
# OG Orders left:  2504
# Cascade length:  21
# New Orders left:  2483
# making new cascade
#
#
# OG Orders left:  2483
# Cascade length:  68
# New Orders left:  2415
# making new cascade
#
#
# OG Orders left:  2415
# Cascade length:  225
# New Orders left:  2190
# making new cascade
#
#
# OG Orders left:  2190
# Cascade length:  19
# New Orders left:  2171
# making new cascade
#
#
# OG Orders left:  2171
# Cascade length:  368
# New Orders left:  1803
# making new cascade
#
#
# OG Orders left:  1803
# Cascade length:  1
# New Orders left:  1802
# making new cascade
#
#
# OG Orders left:  1802
# Cascade length:  4
# New Orders left:  1798
# making new cascade
#
#
# OG Orders left:  1798
# Cascade length:  17
# New Orders left:  1781
# making new cascade
#
#
# OG Orders left:  1781
# Cascade length:  117
# New Orders left:  1664
# making new cascade
#
#
# OG Orders left:  1664
# Cascade length:  83
# New Orders left:  1581
# making new cascade
#
#
# OG Orders left:  1581
# Cascade length:  20
# New Orders left:  1561
# making new cascade
#
#
# OG Orders left:  1561
# Cascade length:  255
# New Orders left:  1306
# making new cascade
#
#
# OG Orders left:  1306
# Cascade length:  208
# New Orders left:  1098
# making new cascade
#
#
# OG Orders left:  1098
# Cascade length:  252
# New Orders left:  846
# making new cascade
#
#
# OG Orders left:  846
# Cascade length:  234
# New Orders left:  612
# making new cascade
#
#
# OG Orders left:  612
# Cascade length:  8
# New Orders left:  604
# making new cascade
#
#
# OG Orders left:  604
# Cascade length:  87
# New Orders left:  517
# making new cascade
#
#
# OG Orders left:  517
# Cascade length:  79
# New Orders left:  438
# making new cascade
#
#
# OG Orders left:  438
# Cascade length:  166
# New Orders left:  272
# making new cascade
#
#
# OG Orders left:  272
# Cascade length:  85
# New Orders left:  187
# making new cascade
#
#
# OG Orders left:  187
# Cascade length:  13
# New Orders left:  174
# making new cascade
#
#
# OG Orders left:  174
# Cascade length:  101
# New Orders left:  73
# making new cascade
#
#
# OG Orders left:  73
# Cascade length:  40
# New Orders left:  33
# making new cascade
#
#
# OG Orders left:  33
# Cascade length:  1
# New Orders left:  32
# making new cascade
#
#
# OG Orders left:  32
# Cascade length:  1
# New Orders left:  31
# making new cascade
#
#
# OG Orders left:  31
# Cascade length:  14
# New Orders left:  17
# making new cascade
#
#
# OG Orders left:  17
# Cascade length:  12
# New Orders left:  5
# making new cascade
#
#
# OG Orders left:  5
# Cascade length:  5
# New Orders left:  0
# making new cascade

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades12_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1425670
# Cascade length:  11686
# New Orders left:  1413984
# making new cascade
#
#
# OG Orders left:  1413984
# Cascade length:  4367
# New Orders left:  1409617
# making new cascade
#
#
# OG Orders left:  1409617
# Cascade length:  5109
# New Orders left:  1404508
# making new cascade
#
#
# OG Orders left:  1404508
# Cascade length:  2670
# New Orders left:  1401838
# making new cascade
#
#
# OG Orders left:  1401838
# Cascade length:  2678
# New Orders left:  1399160
# making new cascade
#
#
# OG Orders left:  1399160
# Cascade length:  3584
# New Orders left:  1395576
# making new cascade
#
#
# OG Orders left:  1395576
# Cascade length:  1472
# New Orders left:  1394104
# making new cascade
#
#
# OG Orders left:  1394104
# Cascade length:  1267
# New Orders left:  1392837
# making new cascade
#
#
# OG Orders left:  1392837
# Cascade length:  1401
# New Orders left:  1391436
# making new cascade
#
#
# OG Orders left:  1391436
# Cascade length:  2453
# New Orders left:  1388983
# making new cascade
#
#
# OG Orders left:  1388983
# Cascade length:  2311
# New Orders left:  1386672
# making new cascade
#
#
# OG Orders left:  1386672
# Cascade length:  1377
# New Orders left:  1385295
# making new cascade
#
#
# OG Orders left:  1385295
# Cascade length:  2679
# New Orders left:  1382616
# making new cascade
#
#
# OG Orders left:  1382616
# Cascade length:  1872
# New Orders left:  1380744
# making new cascade
#
#
# OG Orders left:  1380744
# Cascade length:  43
# New Orders left:  1380701
# making new cascade
#
#
# OG Orders left:  1380701
# Cascade length:  592
# New Orders left:  1380109
# making new cascade
#
#
# OG Orders left:  1380109
# Cascade length:  142
# New Orders left:  1379967
# making new cascade
#
#
# OG Orders left:  1379967
# Cascade length:  2562
# New Orders left:  1377405
# making new cascade
#
#
# OG Orders left:  1377405
# Cascade length:  1563
# New Orders left:  1375842
# making new cascade
#
#
# OG Orders left:  1375842
# Cascade length:  975
# New Orders left:  1374867
# making new cascade
#
#
# OG Orders left:  1374867
# Cascade length:  19
# New Orders left:  1374848
# making new cascade
#
#
# OG Orders left:  1374848
# Cascade length:  1194
# New Orders left:  1373654
# making new cascade
#
#
# OG Orders left:  1373654
# Cascade length:  1210
# New Orders left:  1372444
# making new cascade
#
#
# OG Orders left:  1372444
# Cascade length:  2885
# New Orders left:  1369559
# making new cascade
#
#
# OG Orders left:  1369559
# Cascade length:  25
# New Orders left:  1369534
# making new cascade
#
#
# OG Orders left:  1369534
# Cascade length:  2030
# New Orders left:  1367504
# making new cascade
#
#
# OG Orders left:  1367504
# Cascade length:  38
# New Orders left:  1367466
# making new cascade
#
#
# OG Orders left:  1367466
# Cascade length:  1063
# New Orders left:  1366403
# making new cascade
#
#
# OG Orders left:  1366403
# Cascade length:  1013
# New Orders left:  1365390
# making new cascade
#
#
# OG Orders left:  1365390
# Cascade length:  4003
# New Orders left:  1361387
# making new cascade
#
#
# OG Orders left:  1361387
# Cascade length:  741
# New Orders left:  1360646
# making new cascade
#
#
# OG Orders left:  1360646
# Cascade length:  1387
# New Orders left:  1359259
# making new cascade
#
#
# OG Orders left:  1359259
# Cascade length:  1993
# New Orders left:  1357266
# making new cascade
#
#
# OG Orders left:  1357266
# Cascade length:  21
# New Orders left:  1357245
# making new cascade
#
#
# OG Orders left:  1357245
# Cascade length:  2301
# New Orders left:  1354944
# making new cascade
#
#
# OG Orders left:  1354944
# Cascade length:  710
# New Orders left:  1354234
# making new cascade
#
#
# OG Orders left:  1354234
# Cascade length:  18
# New Orders left:  1354216
# making new cascade
#
#
# OG Orders left:  1354216
# Cascade length:  1457
# New Orders left:  1352759
# making new cascade
#
#
# OG Orders left:  1352759
# Cascade length:  449
# New Orders left:  1352310
# making new cascade
#
#
# OG Orders left:  1352310
# Cascade length:  1145
# New Orders left:  1351165
# making new cascade
#
#
# OG Orders left:  1351165
# Cascade length:  2055
# New Orders left:  1349110
# making new cascade
#
#
# OG Orders left:  1349110
# Cascade length:  5
# New Orders left:  1349105
# making new cascade
#
#
# OG Orders left:  1349105
# Cascade length:  1230
# New Orders left:  1347875
# making new cascade
#
#
# OG Orders left:  1347875
# Cascade length:  661
# New Orders left:  1347214
# making new cascade
#
#
# OG Orders left:  1347214
# Cascade length:  7
# New Orders left:  1347207
# making new cascade
#
#
# OG Orders left:  1347207
# Cascade length:  33
# New Orders left:  1347174
# making new cascade
#
#
# OG Orders left:  1347174
# Cascade length:  846
# New Orders left:  1346328
# making new cascade
#
#
# OG Orders left:  1346328
# Cascade length:  704
# New Orders left:  1345624
# making new cascade
#
#
# OG Orders left:  1345624
# Cascade length:  1091
# New Orders left:  1344533
# making new cascade
#
#
# OG Orders left:  1344533
# Cascade length:  642
# New Orders left:  1343891
# making new cascade
#
#
# OG Orders left:  1343891
# Cascade length:  158
# New Orders left:  1343733
# making new cascade
#
#
# OG Orders left:  1343733
# Cascade length:  523
# New Orders left:  1343210
# making new cascade
#
#
# OG Orders left:  1343210
# Cascade length:  1059
# New Orders left:  1342151
# making new cascade
#
#
# OG Orders left:  1342151
# Cascade length:  3
# New Orders left:  1342148
# making new cascade
#
#
# OG Orders left:  1342148
# Cascade length:  692
# New Orders left:  1341456
# making new cascade
#
#
# OG Orders left:  1341456
# Cascade length:  5
# New Orders left:  1341451
# making new cascade
#
#
# OG Orders left:  1341451
# Cascade length:  9
# New Orders left:  1341442
# making new cascade
#
#
# OG Orders left:  1341442
# Cascade length:  577
# New Orders left:  1340865
# making new cascade
#
#
# OG Orders left:  1340865
# Cascade length:  1200
# New Orders left:  1339665
# making new cascade
#
#
# OG Orders left:  1339665
# Cascade length:  1383
# New Orders left:  1338282
# making new cascade
#
#
# OG Orders left:  1338282
# Cascade length:  23
# New Orders left:  1338259
# making new cascade
#
#
# OG Orders left:  1338259
# Cascade length:  929
# New Orders left:  1337330
# making new cascade
#
#
# OG Orders left:  1337330
# Cascade length:  2
# New Orders left:  1337328
# making new cascade
#
#
# OG Orders left:  1337328
# Cascade length:  52
# New Orders left:  1337276
# making new cascade
#
#
# OG Orders left:  1337276
# Cascade length:  727
# New Orders left:  1336549
# making new cascade
#
#
# OG Orders left:  1336549
# Cascade length:  1570
# New Orders left:  1334979
# making new cascade
#
#
# OG Orders left:  1334979
# Cascade length:  705
# New Orders left:  1334274
# making new cascade
#
#
# OG Orders left:  1334274
# Cascade length:  1279
# New Orders left:  1332995
# making new cascade
#
#
# OG Orders left:  1332995
# Cascade length:  84
# New Orders left:  1332911
# making new cascade
#
#
# OG Orders left:  1332911
# Cascade length:  2725
# New Orders left:  1330186
# making new cascade
#
#
# OG Orders left:  1330186
# Cascade length:  1704
# New Orders left:  1328482
# making new cascade
#
#
# OG Orders left:  1328482
# Cascade length:  982
# New Orders left:  1327500
# making new cascade
#
#
# OG Orders left:  1327500
# Cascade length:  604
# New Orders left:  1326896
# making new cascade
#
#
# OG Orders left:  1326896
# Cascade length:  713
# New Orders left:  1326183
# making new cascade
#
#
# OG Orders left:  1326183
# Cascade length:  301
# New Orders left:  1325882
# making new cascade
#
#
# OG Orders left:  1325882
# Cascade length:  950
# New Orders left:  1324932
# making new cascade
#
#
# OG Orders left:  1324932
# Cascade length:  716
# New Orders left:  1324216
# making new cascade
#
#
# OG Orders left:  1324216
# Cascade length:  12
# New Orders left:  1324204
# making new cascade
#
#
# OG Orders left:  1324204
# Cascade length:  652
# New Orders left:  1323552
# making new cascade
#
#
# OG Orders left:  1323552
# Cascade length:  54
# New Orders left:  1323498
# making new cascade
#
#
# OG Orders left:  1323498
# Cascade length:  1767
# New Orders left:  1321731
# making new cascade
#
#
# OG Orders left:  1321731
# Cascade length:  2536
# New Orders left:  1319195
# making new cascade
#
#
# OG Orders left:  1319195
# Cascade length:  1439
# New Orders left:  1317756
# making new cascade
#
#
# OG Orders left:  1317756
# Cascade length:  1048
# New Orders left:  1316708
# making new cascade
#
#
# OG Orders left:  1316708
# Cascade length:  2
# New Orders left:  1316706
# making new cascade
#
#
# OG Orders left:  1316706
# Cascade length:  319
# New Orders left:  1316387
# making new cascade
#
#
# OG Orders left:  1316387
# Cascade length:  2
# New Orders left:  1316385
# making new cascade
#
#
# OG Orders left:  1316385
# Cascade length:  8
# New Orders left:  1316377
# making new cascade
#
#
# OG Orders left:  1316377
# Cascade length:  778
# New Orders left:  1315599
# making new cascade
#
#
# OG Orders left:  1315599
# Cascade length:  2
# New Orders left:  1315597
# making new cascade
#
#
# OG Orders left:  1315597
# Cascade length:  3
# New Orders left:  1315594
# making new cascade
#
#
# OG Orders left:  1315594
# Cascade length:  7
# New Orders left:  1315587
# making new cascade
#
#
# OG Orders left:  1315587
# Cascade length:  1223
# New Orders left:  1314364
# making new cascade
#
#
# OG Orders left:  1314364
# Cascade length:  430
# New Orders left:  1313934
# making new cascade
#
#
# OG Orders left:  1313934
# Cascade length:  8
# New Orders left:  1313926
# making new cascade
#
#
# OG Orders left:  1313926
# Cascade length:  4
# New Orders left:  1313922
# making new cascade
#
#
# OG Orders left:  1313922
# Cascade length:  911
# New Orders left:  1313011
# making new cascade
#
#
# OG Orders left:  1313011
# Cascade length:  2
# New Orders left:  1313009
# making new cascade
#
#
# OG Orders left:  1313009
# Cascade length:  1786
# New Orders left:  1311223
# making new cascade
#
#
# OG Orders left:  1311223
# Cascade length:  18
# New Orders left:  1311205
# making new cascade
#
#
# OG Orders left:  1311205
# Cascade length:  1147
# New Orders left:  1310058
# making new cascade
#
#
# OG Orders left:  1310058
# Cascade length:  2
# New Orders left:  1310056
# making new cascade
#
#
# OG Orders left:  1310056
# Cascade length:  1555
# New Orders left:  1308501
# making new cascade
#
#
# OG Orders left:  1308501
# Cascade length:  4
# New Orders left:  1308497
# making new cascade
#
#
# OG Orders left:  1308497
# Cascade length:  11
# New Orders left:  1308486
# making new cascade
#
#
# OG Orders left:  1308486
# Cascade length:  62
# New Orders left:  1308424
# making new cascade
#
#
# OG Orders left:  1308424
# Cascade length:  13
# New Orders left:  1308411
# making new cascade
#
#
# OG Orders left:  1308411
# Cascade length:  950
# New Orders left:  1307461
# making new cascade
#
#
# OG Orders left:  1307461
# Cascade length:  996
# New Orders left:  1306465
# making new cascade
#
#
# OG Orders left:  1306465
# Cascade length:  431
# New Orders left:  1306034
# making new cascade
#
#
# OG Orders left:  1306034
# Cascade length:  3
# New Orders left:  1306031
# making new cascade
#
#
# OG Orders left:  1306031
# Cascade length:  13
# New Orders left:  1306018
# making new cascade
#
#
# OG Orders left:  1306018
# Cascade length:  4
# New Orders left:  1306014
# making new cascade
#
#
# OG Orders left:  1306014
# Cascade length:  173
# New Orders left:  1305841
# making new cascade
#
#
# OG Orders left:  1305841
# Cascade length:  743
# New Orders left:  1305098
# making new cascade
#
#
# OG Orders left:  1305098
# Cascade length:  35
# New Orders left:  1305063
# making new cascade
#
#
# OG Orders left:  1305063
# Cascade length:  617
# New Orders left:  1304446
# making new cascade
#
#
# OG Orders left:  1304446
# Cascade length:  719
# New Orders left:  1303727
# making new cascade
#
#
# OG Orders left:  1303727
# Cascade length:  27
# New Orders left:  1303700
# making new cascade
#
#
# OG Orders left:  1303700
# Cascade length:  2
# New Orders left:  1303698
# making new cascade
#
#
# OG Orders left:  1303698
# Cascade length:  15
# New Orders left:  1303683
# making new cascade
#
#
# OG Orders left:  1303683
# Cascade length:  968
# New Orders left:  1302715
# making new cascade
#
#
# OG Orders left:  1302715
# Cascade length:  1439
# New Orders left:  1301276
# making new cascade
#
#
# OG Orders left:  1301276
# Cascade length:  5
# New Orders left:  1301271
# making new cascade
#
#
# OG Orders left:  1301271
# Cascade length:  5
# New Orders left:  1301266
# making new cascade
#
#
# OG Orders left:  1301266
# Cascade length:  4
# New Orders left:  1301262
# making new cascade
#
#
# OG Orders left:  1301262
# Cascade length:  500
# New Orders left:  1300762
# making new cascade
#
#
# OG Orders left:  1300762
# Cascade length:  16
# New Orders left:  1300746
# making new cascade
#
#
# OG Orders left:  1300746
# Cascade length:  820
# New Orders left:  1299926
# making new cascade
#
#
# OG Orders left:  1299926
# Cascade length:  27
# New Orders left:  1299899
# making new cascade
#
#
# OG Orders left:  1299899
# Cascade length:  1365
# New Orders left:  1298534
# making new cascade
#
#
# OG Orders left:  1298534
# Cascade length:  624
# New Orders left:  1297910
# making new cascade
#
#
# OG Orders left:  1297910
# Cascade length:  922
# New Orders left:  1296988
# making new cascade
#
#
# OG Orders left:  1296988
# Cascade length:  6
# New Orders left:  1296982
# making new cascade
#
#
# OG Orders left:  1296982
# Cascade length:  29
# New Orders left:  1296953
# making new cascade
#
#
# OG Orders left:  1296953
# Cascade length:  4
# New Orders left:  1296949
# making new cascade
#
#
# OG Orders left:  1296949
# Cascade length:  1
# New Orders left:  1296948
# making new cascade
#
#
# OG Orders left:  1296948
# Cascade length:  729
# New Orders left:  1296219
# making new cascade
#
#
# OG Orders left:  1296219
# Cascade length:  1202
# New Orders left:  1295017
# making new cascade
#
#
# OG Orders left:  1295017
# Cascade length:  15
# New Orders left:  1295002
# making new cascade
#
#
# OG Orders left:  1295002
# Cascade length:  714
# New Orders left:  1294288
# making new cascade
#
#
# OG Orders left:  1294288
# Cascade length:  1168
# New Orders left:  1293120
# making new cascade
#
#
# OG Orders left:  1293120
# Cascade length:  707
# New Orders left:  1292413
# making new cascade
#
#
# OG Orders left:  1292413
# Cascade length:  1254
# New Orders left:  1291159
# making new cascade
#
#
# OG Orders left:  1291159
# Cascade length:  8
# New Orders left:  1291151
# making new cascade
#
#
# OG Orders left:  1291151
# Cascade length:  14
# New Orders left:  1291137
# making new cascade
#
#
# OG Orders left:  1291137
# Cascade length:  989
# New Orders left:  1290148
# making new cascade
#
#
# OG Orders left:  1290148
# Cascade length:  3
# New Orders left:  1290145
# making new cascade
#
#
# OG Orders left:  1290145
# Cascade length:  2
# New Orders left:  1290143
# making new cascade
#
#
# OG Orders left:  1290143
# Cascade length:  920
# New Orders left:  1289223
# making new cascade
#
#
# OG Orders left:  1289223
# Cascade length:  6
# New Orders left:  1289217
# making new cascade
#
#
# OG Orders left:  1289217
# Cascade length:  12
# New Orders left:  1289205
# making new cascade
#
#
# OG Orders left:  1289205
# Cascade length:  381
# New Orders left:  1288824
# making new cascade
#
#
# OG Orders left:  1288824
# Cascade length:  43
# New Orders left:  1288781
# making new cascade
#
#
# OG Orders left:  1288781
# Cascade length:  3
# New Orders left:  1288778
# making new cascade
#
#
# OG Orders left:  1288778
# Cascade length:  13
# New Orders left:  1288765
# making new cascade
#
#
# OG Orders left:  1288765
# Cascade length:  651
# New Orders left:  1288114
# making new cascade
#
#
# OG Orders left:  1288114
# Cascade length:  4
# New Orders left:  1288110
# making new cascade
#
#
# OG Orders left:  1288110
# Cascade length:  7
# New Orders left:  1288103
# making new cascade
#
#
# OG Orders left:  1288103
# Cascade length:  40
# New Orders left:  1288063
# making new cascade
#
#
# OG Orders left:  1288063
# Cascade length:  724
# New Orders left:  1287339
# making new cascade
#
#
# OG Orders left:  1287339
# Cascade length:  736
# New Orders left:  1286603
# making new cascade
#
#
# OG Orders left:  1286603
# Cascade length:  413
# New Orders left:  1286190
# making new cascade
#
#
# OG Orders left:  1286190
# Cascade length:  3
# New Orders left:  1286187
# making new cascade
#
#
# OG Orders left:  1286187
# Cascade length:  303
# New Orders left:  1285884
# making new cascade
#
#
# OG Orders left:  1285884
# Cascade length:  6
# New Orders left:  1285878
# making new cascade
#
#
# OG Orders left:  1285878
# Cascade length:  306
# New Orders left:  1285572
# making new cascade
#
#
# OG Orders left:  1285572
# Cascade length:  1088
# New Orders left:  1284484
# making new cascade
#
#
# OG Orders left:  1284484
# Cascade length:  962
# New Orders left:  1283522
# making new cascade
#
#
# OG Orders left:  1283522
# Cascade length:  14
# New Orders left:  1283508
# making new cascade
#
#
# OG Orders left:  1283508
# Cascade length:  917
# New Orders left:  1282591
# making new cascade
#
#
# OG Orders left:  1282591
# Cascade length:  16
# New Orders left:  1282575
# making new cascade
#
#
# OG Orders left:  1282575
# Cascade length:  1633
# New Orders left:  1280942
# making new cascade
#
#
# OG Orders left:  1280942
# Cascade length:  1108
# New Orders left:  1279834
# making new cascade
#
#
# OG Orders left:  1279834
# Cascade length:  2
# New Orders left:  1279832
# making new cascade
#
#
# OG Orders left:  1279832
# Cascade length:  1066
# New Orders left:  1278766
# making new cascade
#
#
# OG Orders left:  1278766
# Cascade length:  100
# New Orders left:  1278666
# making new cascade
#
#
# OG Orders left:  1278666
# Cascade length:  661
# New Orders left:  1278005
# making new cascade
#
#
# OG Orders left:  1278005
# Cascade length:  774
# New Orders left:  1277231
# making new cascade
#
#
# OG Orders left:  1277231
# Cascade length:  10
# New Orders left:  1277221
# making new cascade
#
#
# OG Orders left:  1277221
# Cascade length:  653
# New Orders left:  1276568
# making new cascade
#
#
# OG Orders left:  1276568
# Cascade length:  132
# New Orders left:  1276436
# making new cascade
#
#
# OG Orders left:  1276436
# Cascade length:  866
# New Orders left:  1275570
# making new cascade
#
#
# OG Orders left:  1275570
# Cascade length:  13
# New Orders left:  1275557
# making new cascade
#
#
# OG Orders left:  1275557
# Cascade length:  17
# New Orders left:  1275540
# making new cascade
#
#
# OG Orders left:  1275540
# Cascade length:  423
# New Orders left:  1275117
# making new cascade
#
#
# OG Orders left:  1275117
# Cascade length:  11
# New Orders left:  1275106
# making new cascade
#
#
# OG Orders left:  1275106
# Cascade length:  12
# New Orders left:  1275094
# making new cascade
#
#
# OG Orders left:  1275094
# Cascade length:  754
# New Orders left:  1274340
# making new cascade
#
#
# OG Orders left:  1274340
# Cascade length:  284
# New Orders left:  1274056
# making new cascade
#
#
# OG Orders left:  1274056
# Cascade length:  3
# New Orders left:  1274053
# making new cascade
#
#
# OG Orders left:  1274053
# Cascade length:  1053
# New Orders left:  1273000
# making new cascade
#
#
# OG Orders left:  1273000
# Cascade length:  21
# New Orders left:  1272979
# making new cascade
#
#
# OG Orders left:  1272979
# Cascade length:  457
# New Orders left:  1272522
# making new cascade
#
#
# OG Orders left:  1272522
# Cascade length:  67
# New Orders left:  1272455
# making new cascade
#
#
# OG Orders left:  1272455
# Cascade length:  1
# New Orders left:  1272454
# making new cascade
#
#
# OG Orders left:  1272454
# Cascade length:  48
# New Orders left:  1272406
# making new cascade
#
#
# OG Orders left:  1272406
# Cascade length:  1357
# New Orders left:  1271049
# making new cascade
#
#
# OG Orders left:  1271049
# Cascade length:  2
# New Orders left:  1271047
# making new cascade
#
#
# OG Orders left:  1271047
# Cascade length:  145
# New Orders left:  1270902
# making new cascade
#
#
# OG Orders left:  1270902
# Cascade length:  41
# New Orders left:  1270861
# making new cascade
#
#
# OG Orders left:  1270861
# Cascade length:  14
# New Orders left:  1270847
# making new cascade
#
#
# OG Orders left:  1270847
# Cascade length:  13
# New Orders left:  1270834
# making new cascade
#
#
# OG Orders left:  1270834
# Cascade length:  487
# New Orders left:  1270347
# making new cascade
#
#
# OG Orders left:  1270347
# Cascade length:  17
# New Orders left:  1270330
# making new cascade
#
#
# OG Orders left:  1270330
# Cascade length:  11
# New Orders left:  1270319
# making new cascade
#
#
# OG Orders left:  1270319
# Cascade length:  1836
# New Orders left:  1268483
# making new cascade
#
#
# OG Orders left:  1268483
# Cascade length:  30
# New Orders left:  1268453
# making new cascade
#
#
# OG Orders left:  1268453
# Cascade length:  996
# New Orders left:  1267457
# making new cascade
#
#
# OG Orders left:  1267457
# Cascade length:  7
# New Orders left:  1267450
# making new cascade
#
#
# OG Orders left:  1267450
# Cascade length:  490
# New Orders left:  1266960
# making new cascade
#
#
# OG Orders left:  1266960
# Cascade length:  3
# New Orders left:  1266957
# making new cascade
#
#
# OG Orders left:  1266957
# Cascade length:  2
# New Orders left:  1266955
# making new cascade
#
#
# OG Orders left:  1266955
# Cascade length:  924
# New Orders left:  1266031
# making new cascade
#
#
# OG Orders left:  1266031
# Cascade length:  3
# New Orders left:  1266028
# making new cascade
#
#
# OG Orders left:  1266028
# Cascade length:  930
# New Orders left:  1265098
# making new cascade
#
#
# OG Orders left:  1265098
# Cascade length:  18
# New Orders left:  1265080
# making new cascade
#
#
# OG Orders left:  1265080
# Cascade length:  1294
# New Orders left:  1263786
# making new cascade
#
#
# OG Orders left:  1263786
# Cascade length:  1136
# New Orders left:  1262650
# making new cascade
#
#
# OG Orders left:  1262650
# Cascade length:  826
# New Orders left:  1261824
# making new cascade
#
#
# OG Orders left:  1261824
# Cascade length:  34
# New Orders left:  1261790
# making new cascade
#
#
# OG Orders left:  1261790
# Cascade length:  810
# New Orders left:  1260980
# making new cascade
#
#
# OG Orders left:  1260980
# Cascade length:  523
# New Orders left:  1260457
# making new cascade
#
#
# OG Orders left:  1260457
# Cascade length:  27
# New Orders left:  1260430
# making new cascade
#
#
# OG Orders left:  1260430
# Cascade length:  2
# New Orders left:  1260428
# making new cascade
#
#
# OG Orders left:  1260428
# Cascade length:  1630
# New Orders left:  1258798
# making new cascade
#
#
# OG Orders left:  1258798
# Cascade length:  2
# New Orders left:  1258796
# making new cascade
#
#
# OG Orders left:  1258796
# Cascade length:  1
# New Orders left:  1258795
# making new cascade
#
#
# OG Orders left:  1258795
# Cascade length:  13
# New Orders left:  1258782
# making new cascade
#
#
# OG Orders left:  1258782
# Cascade length:  34
# New Orders left:  1258748
# making new cascade
#
#
# OG Orders left:  1258748
# Cascade length:  2
# New Orders left:  1258746
# making new cascade
#
#
# OG Orders left:  1258746
# Cascade length:  16
# New Orders left:  1258730
# making new cascade
#
#
# OG Orders left:  1258730
# Cascade length:  14
# New Orders left:  1258716
# making new cascade
#
#
# OG Orders left:  1258716
# Cascade length:  1
# New Orders left:  1258715
# making new cascade
#
#
# OG Orders left:  1258715
# Cascade length:  50
# New Orders left:  1258665
# making new cascade
#
#
# OG Orders left:  1258665
# Cascade length:  761
# New Orders left:  1257904
# making new cascade
#
#
# OG Orders left:  1257904
# Cascade length:  14
# New Orders left:  1257890
# making new cascade
#
#
# OG Orders left:  1257890
# Cascade length:  1
# New Orders left:  1257889
# making new cascade
#
#
# OG Orders left:  1257889
# Cascade length:  923
# New Orders left:  1256966
# making new cascade
#
#
# OG Orders left:  1256966
# Cascade length:  3
# New Orders left:  1256963
# making new cascade
#
#
# OG Orders left:  1256963
# Cascade length:  2
# New Orders left:  1256961
# making new cascade
#
#
# OG Orders left:  1256961
# Cascade length:  35
# New Orders left:  1256926
# making new cascade
#
#
# OG Orders left:  1256926
# Cascade length:  2
# New Orders left:  1256924
# making new cascade
#
#
# OG Orders left:  1256924
# Cascade length:  49
# New Orders left:  1256875
# making new cascade
#
#
# OG Orders left:  1256875
# Cascade length:  676
# New Orders left:  1256199
# making new cascade
#
#
# OG Orders left:  1256199
# Cascade length:  18
# New Orders left:  1256181
# making new cascade
#
#
# OG Orders left:  1256181
# Cascade length:  5
# New Orders left:  1256176
# making new cascade
#
#
# OG Orders left:  1256176
# Cascade length:  1998
# New Orders left:  1254178
# making new cascade
#
#
# OG Orders left:  1254178
# Cascade length:  939
# New Orders left:  1253239
# making new cascade
#
#
# OG Orders left:  1253239
# Cascade length:  8
# New Orders left:  1253231
# making new cascade
#
#
# OG Orders left:  1253231
# Cascade length:  8
# New Orders left:  1253223
# making new cascade
#
#
# OG Orders left:  1253223
# Cascade length:  1053
# New Orders left:  1252170
# making new cascade
#
#
# OG Orders left:  1252170
# Cascade length:  1
# New Orders left:  1252169
# making new cascade
#
#
# OG Orders left:  1252169
# Cascade length:  2
# New Orders left:  1252167
# making new cascade
#
#
# OG Orders left:  1252167
# Cascade length:  35
# New Orders left:  1252132
# making new cascade
#
#
# OG Orders left:  1252132
# Cascade length:  912
# New Orders left:  1251220
# making new cascade
#
#
# OG Orders left:  1251220
# Cascade length:  10
# New Orders left:  1251210
# making new cascade
#
#
# OG Orders left:  1251210
# Cascade length:  9
# New Orders left:  1251201
# making new cascade
#
#
# OG Orders left:  1251201
# Cascade length:  1278
# New Orders left:  1249923
# making new cascade
#
#
# OG Orders left:  1249923
# Cascade length:  10
# New Orders left:  1249913
# making new cascade
#
#
# OG Orders left:  1249913
# Cascade length:  1676
# New Orders left:  1248237
# making new cascade
#
#
# OG Orders left:  1248237
# Cascade length:  24
# New Orders left:  1248213
# making new cascade
#
#
# OG Orders left:  1248213
# Cascade length:  1225
# New Orders left:  1246988
# making new cascade
#
#
# OG Orders left:  1246988
# Cascade length:  1
# New Orders left:  1246987
# making new cascade
#
#
# OG Orders left:  1246987
# Cascade length:  7
# New Orders left:  1246980
# making new cascade
#
#
# OG Orders left:  1246980
# Cascade length:  3
# New Orders left:  1246977
# making new cascade
#
#
# OG Orders left:  1246977
# Cascade length:  34
# New Orders left:  1246943
# making new cascade
#
#
# OG Orders left:  1246943
# Cascade length:  1014
# New Orders left:  1245929
# making new cascade
#
#
# OG Orders left:  1245929
# Cascade length:  6
# New Orders left:  1245923
# making new cascade
#
#
# OG Orders left:  1245923
# Cascade length:  754
# New Orders left:  1245169
# making new cascade
#
#
# OG Orders left:  1245169
# Cascade length:  13
# New Orders left:  1245156
# making new cascade
#
#
# OG Orders left:  1245156
# Cascade length:  1292
# New Orders left:  1243864
# making new cascade
#
#
# OG Orders left:  1243864
# Cascade length:  2
# New Orders left:  1243862
# making new cascade
#
#
# OG Orders left:  1243862
# Cascade length:  24
# New Orders left:  1243838
# making new cascade
#
#
# OG Orders left:  1243838
# Cascade length:  1063
# New Orders left:  1242775
# making new cascade
#
#
# OG Orders left:  1242775
# Cascade length:  77
# New Orders left:  1242698
# making new cascade
#
#
# OG Orders left:  1242698
# Cascade length:  2
# New Orders left:  1242696
# making new cascade
#
#
# OG Orders left:  1242696
# Cascade length:  462
# New Orders left:  1242234
# making new cascade
#
#
# OG Orders left:  1242234
# Cascade length:  1
# New Orders left:  1242233
# making new cascade
#
#
# OG Orders left:  1242233
# Cascade length:  444
# New Orders left:  1241789
# making new cascade
#
#
# OG Orders left:  1241789
# Cascade length:  34
# New Orders left:  1241755
# making new cascade
#
#
# OG Orders left:  1241755
# Cascade length:  1
# New Orders left:  1241754
# making new cascade
#
#
# OG Orders left:  1241754
# Cascade length:  2
# New Orders left:  1241752
# making new cascade
#
#
# OG Orders left:  1241752
# Cascade length:  3
# New Orders left:  1241749
# making new cascade
#
#
# OG Orders left:  1241749
# Cascade length:  778
# New Orders left:  1240971
# making new cascade
#
#
# OG Orders left:  1240971
# Cascade length:  2
# New Orders left:  1240969
# making new cascade
#
#
# OG Orders left:  1240969
# Cascade length:  844
# New Orders left:  1240125
# making new cascade
#
#
# OG Orders left:  1240125
# Cascade length:  14
# New Orders left:  1240111
# making new cascade
#
#
# OG Orders left:  1240111
# Cascade length:  54
# New Orders left:  1240057
# making new cascade
#
#
# OG Orders left:  1240057
# Cascade length:  1758
# New Orders left:  1238299
# making new cascade
#
#
# OG Orders left:  1238299
# Cascade length:  1735
# New Orders left:  1236564
# making new cascade
#
#
# OG Orders left:  1236564
# Cascade length:  1076
# New Orders left:  1235488
# making new cascade
#
#
# OG Orders left:  1235488
# Cascade length:  21
# New Orders left:  1235467
# making new cascade
#
#
# OG Orders left:  1235467
# Cascade length:  4
# New Orders left:  1235463
# making new cascade
#
#
# OG Orders left:  1235463
# Cascade length:  496
# New Orders left:  1234967
# making new cascade
#
#
# OG Orders left:  1234967
# Cascade length:  954
# New Orders left:  1234013
# making new cascade
#
#
# OG Orders left:  1234013
# Cascade length:  692
# New Orders left:  1233321
# making new cascade
#
#
# OG Orders left:  1233321
# Cascade length:  1
# New Orders left:  1233320
# making new cascade
#
#
# OG Orders left:  1233320
# Cascade length:  19
# New Orders left:  1233301
# making new cascade
#
#
# OG Orders left:  1233301
# Cascade length:  2
# New Orders left:  1233299
# making new cascade
#
#
# OG Orders left:  1233299
# Cascade length:  2436
# New Orders left:  1230863
# making new cascade
#
#
# OG Orders left:  1230863
# Cascade length:  778
# New Orders left:  1230085
# making new cascade
#
#
# OG Orders left:  1230085
# Cascade length:  2
# New Orders left:  1230083
# making new cascade
#
#
# OG Orders left:  1230083
# Cascade length:  1125
# New Orders left:  1228958
# making new cascade
#
#
# OG Orders left:  1228958
# Cascade length:  5
# New Orders left:  1228953
# making new cascade
#
#
# OG Orders left:  1228953
# Cascade length:  4
# New Orders left:  1228949
# making new cascade
#
#
# OG Orders left:  1228949
# Cascade length:  2
# New Orders left:  1228947
# making new cascade
#
#
# OG Orders left:  1228947
# Cascade length:  771
# New Orders left:  1228176
# making new cascade
#
#
# OG Orders left:  1228176
# Cascade length:  6
# New Orders left:  1228170
# making new cascade
#
#
# OG Orders left:  1228170
# Cascade length:  9
# New Orders left:  1228161
# making new cascade
#
#
# OG Orders left:  1228161
# Cascade length:  1
# New Orders left:  1228160
# making new cascade
#
#
# OG Orders left:  1228160
# Cascade length:  1177
# New Orders left:  1226983
# making new cascade
#
#
# OG Orders left:  1226983
# Cascade length:  688
# New Orders left:  1226295
# making new cascade
#
#
# OG Orders left:  1226295
# Cascade length:  10
# New Orders left:  1226285
# making new cascade
#
#
# OG Orders left:  1226285
# Cascade length:  2192
# New Orders left:  1224093
# making new cascade
#
#
# OG Orders left:  1224093
# Cascade length:  7
# New Orders left:  1224086
# making new cascade
#
#
# OG Orders left:  1224086
# Cascade length:  184
# New Orders left:  1223902
# making new cascade
#
#
# OG Orders left:  1223902
# Cascade length:  2
# New Orders left:  1223900
# making new cascade
#
#
# OG Orders left:  1223900
# Cascade length:  8
# New Orders left:  1223892
# making new cascade
#
#
# OG Orders left:  1223892
# Cascade length:  848
# New Orders left:  1223044
# making new cascade
#
#
# OG Orders left:  1223044
# Cascade length:  2
# New Orders left:  1223042
# making new cascade
#
#
# OG Orders left:  1223042
# Cascade length:  982
# New Orders left:  1222060
# making new cascade
#
#
# OG Orders left:  1222060
# Cascade length:  1429
# New Orders left:  1220631
# making new cascade
#
#
# OG Orders left:  1220631
# Cascade length:  3
# New Orders left:  1220628
# making new cascade
#
#
# OG Orders left:  1220628
# Cascade length:  67
# New Orders left:  1220561
# making new cascade
#
#
# OG Orders left:  1220561
# Cascade length:  2
# New Orders left:  1220559
# making new cascade
#
#
# OG Orders left:  1220559
# Cascade length:  574
# New Orders left:  1219985
# making new cascade
#
#
# OG Orders left:  1219985
# Cascade length:  1044
# New Orders left:  1218941
# making new cascade
#
#
# OG Orders left:  1218941
# Cascade length:  876
# New Orders left:  1218065
# making new cascade
#
#
# OG Orders left:  1218065
# Cascade length:  23
# New Orders left:  1218042
# making new cascade
#
#
# OG Orders left:  1218042
# Cascade length:  657
# New Orders left:  1217385
# making new cascade
#
#
# OG Orders left:  1217385
# Cascade length:  9
# New Orders left:  1217376
# making new cascade
#
#
# OG Orders left:  1217376
# Cascade length:  4
# New Orders left:  1217372
# making new cascade
#
#
# OG Orders left:  1217372
# Cascade length:  384
# New Orders left:  1216988
# making new cascade
#
#
# OG Orders left:  1216988
# Cascade length:  1150
# New Orders left:  1215838
# making new cascade
#
#
# OG Orders left:  1215838
# Cascade length:  3
# New Orders left:  1215835
# making new cascade
#
#
# OG Orders left:  1215835
# Cascade length:  520
# New Orders left:  1215315
# making new cascade
#
#
# OG Orders left:  1215315
# Cascade length:  1854
# New Orders left:  1213461
# making new cascade
#
#
# OG Orders left:  1213461
# Cascade length:  3
# New Orders left:  1213458
# making new cascade
#
#
# OG Orders left:  1213458
# Cascade length:  8
# New Orders left:  1213450
# making new cascade
#
#
# OG Orders left:  1213450
# Cascade length:  404
# New Orders left:  1213046
# making new cascade
#
#
# OG Orders left:  1213046
# Cascade length:  2526
# New Orders left:  1210520
# making new cascade
#
#
# OG Orders left:  1210520
# Cascade length:  3
# New Orders left:  1210517
# making new cascade
#
#
# OG Orders left:  1210517
# Cascade length:  3
# New Orders left:  1210514
# making new cascade
#
#
# OG Orders left:  1210514
# Cascade length:  47
# New Orders left:  1210467
# making new cascade
#
#
# OG Orders left:  1210467
# Cascade length:  789
# New Orders left:  1209678
# making new cascade
#
#
# OG Orders left:  1209678
# Cascade length:  75
# New Orders left:  1209603
# making new cascade
#
#
# OG Orders left:  1209603
# Cascade length:  643
# New Orders left:  1208960
# making new cascade
#
#
# OG Orders left:  1208960
# Cascade length:  69
# New Orders left:  1208891
# making new cascade
#
#
# OG Orders left:  1208891
# Cascade length:  894
# New Orders left:  1207997
# making new cascade
#
#
# OG Orders left:  1207997
# Cascade length:  1494
# New Orders left:  1206503
# making new cascade
#
#
# OG Orders left:  1206503
# Cascade length:  649
# New Orders left:  1205854
# making new cascade
#
#
# OG Orders left:  1205854
# Cascade length:  506
# New Orders left:  1205348
# making new cascade
#
#
# OG Orders left:  1205348
# Cascade length:  534
# New Orders left:  1204814
# making new cascade
#
#
# OG Orders left:  1204814
# Cascade length:  475
# New Orders left:  1204339
# making new cascade
#
#
# OG Orders left:  1204339
# Cascade length:  40
# New Orders left:  1204299
# making new cascade
#
#
# OG Orders left:  1204299
# Cascade length:  1377
# New Orders left:  1202922
# making new cascade
#
#
# OG Orders left:  1202922
# Cascade length:  22
# New Orders left:  1202900
# making new cascade
#
#
# OG Orders left:  1202900
# Cascade length:  19
# New Orders left:  1202881
# making new cascade
#
#
# OG Orders left:  1202881
# Cascade length:  12
# New Orders left:  1202869
# making new cascade
#
#
# OG Orders left:  1202869
# Cascade length:  564
# New Orders left:  1202305
# making new cascade
#
#
# OG Orders left:  1202305
# Cascade length:  65
# New Orders left:  1202240
# making new cascade
#
#
# OG Orders left:  1202240
# Cascade length:  2253
# New Orders left:  1199987
# making new cascade
#
#
# OG Orders left:  1199987
# Cascade length:  17
# New Orders left:  1199970
# making new cascade
#
#
# OG Orders left:  1199970
# Cascade length:  28
# New Orders left:  1199942
# making new cascade
#
#
# OG Orders left:  1199942
# Cascade length:  1367
# New Orders left:  1198575
# making new cascade
#
#
# OG Orders left:  1198575
# Cascade length:  2425
# New Orders left:  1196150
# making new cascade
#
#
# OG Orders left:  1196150
# Cascade length:  355
# New Orders left:  1195795
# making new cascade
#
#
# OG Orders left:  1195795
# Cascade length:  124
# New Orders left:  1195671
# making new cascade
#
#
# OG Orders left:  1195671
# Cascade length:  2
# New Orders left:  1195669
# making new cascade
#
#
# OG Orders left:  1195669
# Cascade length:  1347
# New Orders left:  1194322
# making new cascade
#
#
# OG Orders left:  1194322
# Cascade length:  2
# New Orders left:  1194320
# making new cascade
#
#
# OG Orders left:  1194320
# Cascade length:  44
# New Orders left:  1194276
# making new cascade
#
#
# OG Orders left:  1194276
# Cascade length:  10
# New Orders left:  1194266
# making new cascade
#
#
# OG Orders left:  1194266
# Cascade length:  24
# New Orders left:  1194242
# making new cascade
#
#
# OG Orders left:  1194242
# Cascade length:  1755
# New Orders left:  1192487
# making new cascade
#
#
# OG Orders left:  1192487
# Cascade length:  1306
# New Orders left:  1191181
# making new cascade
#
#
# OG Orders left:  1191181
# Cascade length:  392
# New Orders left:  1190789
# making new cascade
#
#
# OG Orders left:  1190789
# Cascade length:  17
# New Orders left:  1190772
# making new cascade
#
#
# OG Orders left:  1190772
# Cascade length:  447
# New Orders left:  1190325
# making new cascade
#
#
# OG Orders left:  1190325
# Cascade length:  46
# New Orders left:  1190279
# making new cascade
#
#
# OG Orders left:  1190279
# Cascade length:  688
# New Orders left:  1189591
# making new cascade
#
#
# OG Orders left:  1189591
# Cascade length:  2925
# New Orders left:  1186666
# making new cascade
#
#
# OG Orders left:  1186666
# Cascade length:  13
# New Orders left:  1186653
# making new cascade
#
#
# OG Orders left:  1186653
# Cascade length:  906
# New Orders left:  1185747
# making new cascade
#
#
# OG Orders left:  1185747
# Cascade length:  665
# New Orders left:  1185082
# making new cascade
#
#
# OG Orders left:  1185082
# Cascade length:  23
# New Orders left:  1185059
# making new cascade
#
#
# OG Orders left:  1185059
# Cascade length:  2
# New Orders left:  1185057
# making new cascade
#
#
# OG Orders left:  1185057
# Cascade length:  5
# New Orders left:  1185052
# making new cascade
#
#
# OG Orders left:  1185052
# Cascade length:  2
# New Orders left:  1185050
# making new cascade
#
#
# OG Orders left:  1185050
# Cascade length:  2370
# New Orders left:  1182680
# making new cascade
#
#
# OG Orders left:  1182680
# Cascade length:  41
# New Orders left:  1182639
# making new cascade
#
#
# OG Orders left:  1182639
# Cascade length:  33
# New Orders left:  1182606
# making new cascade
#
#
# OG Orders left:  1182606
# Cascade length:  973
# New Orders left:  1181633
# making new cascade
#
#
# OG Orders left:  1181633
# Cascade length:  8
# New Orders left:  1181625
# making new cascade
#
#
# OG Orders left:  1181625
# Cascade length:  15
# New Orders left:  1181610
# making new cascade
#
#
# OG Orders left:  1181610
# Cascade length:  1991
# New Orders left:  1179619
# making new cascade
#
#
# OG Orders left:  1179619
# Cascade length:  1687
# New Orders left:  1177932
# making new cascade
#
#
# OG Orders left:  1177932
# Cascade length:  112
# New Orders left:  1177820
# making new cascade
#
#
# OG Orders left:  1177820
# Cascade length:  31
# New Orders left:  1177789
# making new cascade
#
#
# OG Orders left:  1177789
# Cascade length:  504
# New Orders left:  1177285
# making new cascade
#
#
# OG Orders left:  1177285
# Cascade length:  556
# New Orders left:  1176729
# making new cascade
#
#
# OG Orders left:  1176729
# Cascade length:  3
# New Orders left:  1176726
# making new cascade
#
#
# OG Orders left:  1176726
# Cascade length:  291
# New Orders left:  1176435
# making new cascade
#
#
# OG Orders left:  1176435
# Cascade length:  393
# New Orders left:  1176042
# making new cascade
#
#
# OG Orders left:  1176042
# Cascade length:  977
# New Orders left:  1175065
# making new cascade
#
#
# OG Orders left:  1175065
# Cascade length:  20
# New Orders left:  1175045
# making new cascade
#
#
# OG Orders left:  1175045
# Cascade length:  13
# New Orders left:  1175032
# making new cascade
#
#
# OG Orders left:  1175032
# Cascade length:  4591
# New Orders left:  1170441
# making new cascade
#
#
# OG Orders left:  1170441
# Cascade length:  545
# New Orders left:  1169896
# making new cascade
#
#
# OG Orders left:  1169896
# Cascade length:  19
# New Orders left:  1169877
# making new cascade
#
#
# OG Orders left:  1169877
# Cascade length:  1071
# New Orders left:  1168806
# making new cascade
#
#
# OG Orders left:  1168806
# Cascade length:  26
# New Orders left:  1168780
# making new cascade
#
#
# OG Orders left:  1168780
# Cascade length:  1054
# New Orders left:  1167726
# making new cascade
#
#
# OG Orders left:  1167726
# Cascade length:  17
# New Orders left:  1167709
# making new cascade
#
#
# OG Orders left:  1167709
# Cascade length:  817
# New Orders left:  1166892
# making new cascade
#
#
# OG Orders left:  1166892
# Cascade length:  32
# New Orders left:  1166860
# making new cascade
#
#
# OG Orders left:  1166860
# Cascade length:  9
# New Orders left:  1166851
# making new cascade
#
#
# OG Orders left:  1166851
# Cascade length:  560
# New Orders left:  1166291
# making new cascade
#
#
# OG Orders left:  1166291
# Cascade length:  134
# New Orders left:  1166157
# making new cascade
#
#
# OG Orders left:  1166157
# Cascade length:  7
# New Orders left:  1166150
# making new cascade
#
#
# OG Orders left:  1166150
# Cascade length:  1972
# New Orders left:  1164178
# making new cascade
#
#
# OG Orders left:  1164178
# Cascade length:  537
# New Orders left:  1163641
# making new cascade
#
#
# OG Orders left:  1163641
# Cascade length:  2268
# New Orders left:  1161373
# making new cascade
#
#
# OG Orders left:  1161373
# Cascade length:  2
# New Orders left:  1161371
# making new cascade
#
#
# OG Orders left:  1161371
# Cascade length:  2
# New Orders left:  1161369
# making new cascade
#
#
# OG Orders left:  1161369
# Cascade length:  852
# New Orders left:  1160517
# making new cascade
#
#
# OG Orders left:  1160517
# Cascade length:  6
# New Orders left:  1160511
# making new cascade
#
#
# OG Orders left:  1160511
# Cascade length:  6
# New Orders left:  1160505
# making new cascade
#
#
# OG Orders left:  1160505
# Cascade length:  109
# New Orders left:  1160396
# making new cascade
#
#
# OG Orders left:  1160396
# Cascade length:  27
# New Orders left:  1160369
# making new cascade
#
#
# OG Orders left:  1160369
# Cascade length:  1
# New Orders left:  1160368
# making new cascade
#
#
# OG Orders left:  1160368
# Cascade length:  403
# New Orders left:  1159965
# making new cascade
#
#
# OG Orders left:  1159965
# Cascade length:  1347
# New Orders left:  1158618
# making new cascade
#
#
# OG Orders left:  1158618
# Cascade length:  64
# New Orders left:  1158554
# making new cascade
#
#
# OG Orders left:  1158554
# Cascade length:  826
# New Orders left:  1157728
# making new cascade
#
#
# OG Orders left:  1157728
# Cascade length:  1108
# New Orders left:  1156620
# making new cascade
#
#
# OG Orders left:  1156620
# Cascade length:  542
# New Orders left:  1156078
# making new cascade
#
#
# OG Orders left:  1156078
# Cascade length:  2
# New Orders left:  1156076
# making new cascade
#
#
# OG Orders left:  1156076
# Cascade length:  1870
# New Orders left:  1154206
# making new cascade
#
#
# OG Orders left:  1154206
# Cascade length:  2
# New Orders left:  1154204
# making new cascade
#
#
# OG Orders left:  1154204
# Cascade length:  204
# New Orders left:  1154000
# making new cascade
#
#
# OG Orders left:  1154000
# Cascade length:  1165
# New Orders left:  1152835
# making new cascade
#
#
# OG Orders left:  1152835
# Cascade length:  1157
# New Orders left:  1151678
# making new cascade
#
#
# OG Orders left:  1151678
# Cascade length:  467
# New Orders left:  1151211
# making new cascade
#
#
# OG Orders left:  1151211
# Cascade length:  10
# New Orders left:  1151201
# making new cascade
#
#
# OG Orders left:  1151201
# Cascade length:  227
# New Orders left:  1150974
# making new cascade
#
#
# OG Orders left:  1150974
# Cascade length:  1
# New Orders left:  1150973
# making new cascade
#
#
# OG Orders left:  1150973
# Cascade length:  1558
# New Orders left:  1149415
# making new cascade
#
#
# OG Orders left:  1149415
# Cascade length:  2416
# New Orders left:  1146999
# making new cascade
#
#
# OG Orders left:  1146999
# Cascade length:  10
# New Orders left:  1146989
# making new cascade
#
#
# OG Orders left:  1146989
# Cascade length:  123
# New Orders left:  1146866
# making new cascade
#
#
# OG Orders left:  1146866
# Cascade length:  275
# New Orders left:  1146591
# making new cascade
#
#
# OG Orders left:  1146591
# Cascade length:  66
# New Orders left:  1146525
# making new cascade
#
#
# OG Orders left:  1146525
# Cascade length:  29
# New Orders left:  1146496
# making new cascade
#
#
# OG Orders left:  1146496
# Cascade length:  16
# New Orders left:  1146480
# making new cascade
#
#
# OG Orders left:  1146480
# Cascade length:  642
# New Orders left:  1145838
# making new cascade
#
#
# OG Orders left:  1145838
# Cascade length:  25
# New Orders left:  1145813
# making new cascade
#
#
# OG Orders left:  1145813
# Cascade length:  1030
# New Orders left:  1144783
# making new cascade
#
#
# OG Orders left:  1144783
# Cascade length:  11
# New Orders left:  1144772
# making new cascade
#
#
# OG Orders left:  1144772
# Cascade length:  457
# New Orders left:  1144315
# making new cascade
#
#
# OG Orders left:  1144315
# Cascade length:  204
# New Orders left:  1144111
# making new cascade
#
#
# OG Orders left:  1144111
# Cascade length:  102
# New Orders left:  1144009
# making new cascade
#
#
# OG Orders left:  1144009
# Cascade length:  10
# New Orders left:  1143999
# making new cascade
#
#
# OG Orders left:  1143999
# Cascade length:  419
# New Orders left:  1143580
# making new cascade
#
#
# OG Orders left:  1143580
# Cascade length:  1364
# New Orders left:  1142216
# making new cascade
#
#
# OG Orders left:  1142216
# Cascade length:  429
# New Orders left:  1141787
# making new cascade
#
#
# OG Orders left:  1141787
# Cascade length:  593
# New Orders left:  1141194
# making new cascade
#
#
# OG Orders left:  1141194
# Cascade length:  728
# New Orders left:  1140466
# making new cascade
#
#
# OG Orders left:  1140466
# Cascade length:  21
# New Orders left:  1140445
# making new cascade
#
#
# OG Orders left:  1140445
# Cascade length:  27
# New Orders left:  1140418
# making new cascade
#
#
# OG Orders left:  1140418
# Cascade length:  1366
# New Orders left:  1139052
# making new cascade
#
#
# OG Orders left:  1139052
# Cascade length:  1792
# New Orders left:  1137260
# making new cascade
#
#
# OG Orders left:  1137260
# Cascade length:  1300
# New Orders left:  1135960
# making new cascade
#
#
# OG Orders left:  1135960
# Cascade length:  856
# New Orders left:  1135104
# making new cascade
#
#
# OG Orders left:  1135104
# Cascade length:  42
# New Orders left:  1135062
# making new cascade
#
#
# OG Orders left:  1135062
# Cascade length:  1514
# New Orders left:  1133548
# making new cascade
#
#
# OG Orders left:  1133548
# Cascade length:  785
# New Orders left:  1132763
# making new cascade
#
#
# OG Orders left:  1132763
# Cascade length:  742
# New Orders left:  1132021
# making new cascade
#
#
# OG Orders left:  1132021
# Cascade length:  16
# New Orders left:  1132005
# making new cascade
#
#
# OG Orders left:  1132005
# Cascade length:  427
# New Orders left:  1131578
# making new cascade
#
#
# OG Orders left:  1131578
# Cascade length:  659
# New Orders left:  1130919
# making new cascade
#
#
# OG Orders left:  1130919
# Cascade length:  23
# New Orders left:  1130896
# making new cascade
#
#
# OG Orders left:  1130896
# Cascade length:  2
# New Orders left:  1130894
# making new cascade
#
#
# OG Orders left:  1130894
# Cascade length:  599
# New Orders left:  1130295
# making new cascade
#
#
# OG Orders left:  1130295
# Cascade length:  23
# New Orders left:  1130272
# making new cascade
#
#
# OG Orders left:  1130272
# Cascade length:  16
# New Orders left:  1130256
# making new cascade
#
#
# OG Orders left:  1130256
# Cascade length:  1309
# New Orders left:  1128947
# making new cascade
#
#
# OG Orders left:  1128947
# Cascade length:  48
# New Orders left:  1128899
# making new cascade
#
#
# OG Orders left:  1128899
# Cascade length:  1942
# New Orders left:  1126957
# making new cascade
#
#
# OG Orders left:  1126957
# Cascade length:  3
# New Orders left:  1126954
# making new cascade
#
#
# OG Orders left:  1126954
# Cascade length:  105
# New Orders left:  1126849
# making new cascade
#
#
# OG Orders left:  1126849
# Cascade length:  6
# New Orders left:  1126843
# making new cascade
#
#
# OG Orders left:  1126843
# Cascade length:  398
# New Orders left:  1126445
# making new cascade
#
#
# OG Orders left:  1126445
# Cascade length:  10
# New Orders left:  1126435
# making new cascade
#
#
# OG Orders left:  1126435
# Cascade length:  1330
# New Orders left:  1125105
# making new cascade
#
#
# OG Orders left:  1125105
# Cascade length:  13
# New Orders left:  1125092
# making new cascade
#
#
# OG Orders left:  1125092
# Cascade length:  1085
# New Orders left:  1124007
# making new cascade
#
#
# OG Orders left:  1124007
# Cascade length:  5
# New Orders left:  1124002
# making new cascade
#
#
# OG Orders left:  1124002
# Cascade length:  3
# New Orders left:  1123999
# making new cascade
#
#
# OG Orders left:  1123999
# Cascade length:  2
# New Orders left:  1123997
# making new cascade
#
#
# OG Orders left:  1123997
# Cascade length:  94
# New Orders left:  1123903
# making new cascade
#
#
# OG Orders left:  1123903
# Cascade length:  50
# New Orders left:  1123853
# making new cascade
#
#
# OG Orders left:  1123853
# Cascade length:  47
# New Orders left:  1123806
# making new cascade
#
#
# OG Orders left:  1123806
# Cascade length:  808
# New Orders left:  1122998
# making new cascade
#
#
# OG Orders left:  1122998
# Cascade length:  43
# New Orders left:  1122955
# making new cascade
#
#
# OG Orders left:  1122955
# Cascade length:  519
# New Orders left:  1122436
# making new cascade
#
#
# OG Orders left:  1122436
# Cascade length:  78
# New Orders left:  1122358
# making new cascade
#
#
# OG Orders left:  1122358
# Cascade length:  103
# New Orders left:  1122255
# making new cascade
#
#
# OG Orders left:  1122255
# Cascade length:  2008
# New Orders left:  1120247
# making new cascade
#
#
# OG Orders left:  1120247
# Cascade length:  2
# New Orders left:  1120245
# making new cascade
#
#
# OG Orders left:  1120245
# Cascade length:  2
# New Orders left:  1120243
# making new cascade
#
#
# OG Orders left:  1120243
# Cascade length:  954
# New Orders left:  1119289
# making new cascade
#
#
# OG Orders left:  1119289
# Cascade length:  2302
# New Orders left:  1116987
# making new cascade
#
#
# OG Orders left:  1116987
# Cascade length:  511
# New Orders left:  1116476
# making new cascade
#
#
# OG Orders left:  1116476
# Cascade length:  30
# New Orders left:  1116446
# making new cascade
#
#
# OG Orders left:  1116446
# Cascade length:  2
# New Orders left:  1116444
# making new cascade
#
#
# OG Orders left:  1116444
# Cascade length:  4
# New Orders left:  1116440
# making new cascade
#
#
# OG Orders left:  1116440
# Cascade length:  5460
# ...
# making new cascade
#
#
# OG Orders left:  110737
# Cascade length:  1400
# New Orders left:  109337
# making new cascade
#
#
# OG Orders left:  109337
# Cascade length:  1695
# New Orders left:  107642
# making new cascade
#
#
# OG Orders left:  107642
# Cascade length:  555
# New Orders left:  107087
# making new cascade
#
#
# OG Orders left:  107087
# Cascade length:  177
# New Orders left:  106910
# making new cascade
#
#
# OG Orders left:  106910
# Cascade length:  3372
# New Orders left:  103538
# making new cascade
#
#
# OG Orders left:  103538
# Cascade length:  2659
# New Orders left:  100879
# making new cascade
#
#
# OG Orders left:  100879
# Cascade length:  3
# New Orders left:  100876
# making new cascade
#
#
# OG Orders left:  100876
# Cascade length:  1253
# New Orders left:  99623
# making new cascade
#
#
# OG Orders left:  99623
# Cascade length:  75
# New Orders left:  99548
# making new cascade
#
#
# OG Orders left:  99548
# Cascade length:  537
# New Orders left:  99011
# making new cascade
#
#
# OG Orders left:  99011
# Cascade length:  734
# New Orders left:  98277
# making new cascade
#
#
# OG Orders left:  98277
# Cascade length:  404
# New Orders left:  97873
# making new cascade
#
#
# OG Orders left:  97873
# Cascade length:  8
# New Orders left:  97865
# making new cascade
#
#
# OG Orders left:  97865
# Cascade length:  1760
# New Orders left:  96105
# making new cascade
#
#
# OG Orders left:  96105
# Cascade length:  374
# New Orders left:  95731
# making new cascade
#
#
# OG Orders left:  95731
# Cascade length:  1133
# New Orders left:  94598
# making new cascade
#
#
# OG Orders left:  94598
# Cascade length:  471
# New Orders left:  94127
# making new cascade
#
#
# OG Orders left:  94127
# Cascade length:  12
# New Orders left:  94115
# making new cascade
#
#
# OG Orders left:  94115
# Cascade length:  1418
# New Orders left:  92697
# making new cascade
#
#
# OG Orders left:  92697
# Cascade length:  296
# New Orders left:  92401
# making new cascade
#
#
# OG Orders left:  92401
# Cascade length:  629
# New Orders left:  91772
# making new cascade
#
#
# OG Orders left:  91772
# Cascade length:  18
# New Orders left:  91754
# making new cascade
#
#
# OG Orders left:  91754
# Cascade length:  1955
# New Orders left:  89799
# making new cascade
#
#
# OG Orders left:  89799
# Cascade length:  6
# New Orders left:  89793
# making new cascade
#
#
# OG Orders left:  89793
# Cascade length:  723
# New Orders left:  89070
# making new cascade
#
#
# OG Orders left:  89070
# Cascade length:  1791
# New Orders left:  87279
# making new cascade
#
#
# OG Orders left:  87279
# Cascade length:  617
# New Orders left:  86662
# making new cascade
#
#
# OG Orders left:  86662
# Cascade length:  3
# New Orders left:  86659
# making new cascade
#
#
# OG Orders left:  86659
# Cascade length:  1137
# New Orders left:  85522
# making new cascade
#
#
# OG Orders left:  85522
# Cascade length:  23
# New Orders left:  85499
# making new cascade
#
#
# OG Orders left:  85499
# Cascade length:  885
# New Orders left:  84614
# making new cascade
#
#
# OG Orders left:  84614
# Cascade length:  3616
# New Orders left:  80998
# making new cascade
#
#
# OG Orders left:  80998
# Cascade length:  910
# New Orders left:  80088
# making new cascade
#
#
# OG Orders left:  80088
# Cascade length:  1407
# New Orders left:  78681
# making new cascade
#
#
# OG Orders left:  78681
# Cascade length:  49
# New Orders left:  78632
# making new cascade
#
#
# OG Orders left:  78632
# Cascade length:  3148
# New Orders left:  75484
# making new cascade
#
#
# OG Orders left:  75484
# Cascade length:  803
# New Orders left:  74681
# making new cascade
#
#
# OG Orders left:  74681
# Cascade length:  676
# New Orders left:  74005
# making new cascade
#
#
# OG Orders left:  74005
# Cascade length:  40
# New Orders left:  73965
# making new cascade
#
#
# OG Orders left:  73965
# Cascade length:  472
# New Orders left:  73493
# making new cascade
#
#
# OG Orders left:  73493
# Cascade length:  654
# New Orders left:  72839
# making new cascade
#
#
# OG Orders left:  72839
# Cascade length:  2227
# New Orders left:  70612
# making new cascade
#
#
# OG Orders left:  70612
# Cascade length:  561
# New Orders left:  70051
# making new cascade
#
#
# OG Orders left:  70051
# Cascade length:  839
# New Orders left:  69212
# making new cascade
#
#
# OG Orders left:  69212
# Cascade length:  186
# New Orders left:  69026
# making new cascade
#
#
# OG Orders left:  69026
# Cascade length:  960
# New Orders left:  68066
# making new cascade
#
#
# OG Orders left:  68066
# Cascade length:  1051
# New Orders left:  67015
# making new cascade
#
#
# OG Orders left:  67015
# Cascade length:  446
# New Orders left:  66569
# making new cascade
#
#
# OG Orders left:  66569
# Cascade length:  1030
# New Orders left:  65539
# making new cascade
#
#
# OG Orders left:  65539
# Cascade length:  28
# New Orders left:  65511
# making new cascade
#
#
# OG Orders left:  65511
# Cascade length:  8
# New Orders left:  65503
# making new cascade
#
#
# OG Orders left:  65503
# Cascade length:  884
# New Orders left:  64619
# making new cascade
#
#
# OG Orders left:  64619
# Cascade length:  788
# New Orders left:  63831
# making new cascade
#
#
# OG Orders left:  63831
# Cascade length:  58
# New Orders left:  63773
# making new cascade
#
#
# OG Orders left:  63773
# Cascade length:  971
# New Orders left:  62802
# making new cascade
#
#
# OG Orders left:  62802
# Cascade length:  838
# New Orders left:  61964
# making new cascade
#
#
# OG Orders left:  61964
# Cascade length:  31
# New Orders left:  61933
# making new cascade
#
#
# OG Orders left:  61933
# Cascade length:  906
# New Orders left:  61027
# making new cascade
#
#
# OG Orders left:  61027
# Cascade length:  1181
# New Orders left:  59846
# making new cascade
#
#
# OG Orders left:  59846
# Cascade length:  16
# New Orders left:  59830
# making new cascade
#
#
# OG Orders left:  59830
# Cascade length:  203
# New Orders left:  59627
# making new cascade
#
#
# OG Orders left:  59627
# Cascade length:  702
# New Orders left:  58925
# making new cascade
#
#
# OG Orders left:  58925
# Cascade length:  969
# New Orders left:  57956
# making new cascade
#
#
# OG Orders left:  57956
# Cascade length:  3
# New Orders left:  57953
# making new cascade
#
#
# OG Orders left:  57953
# Cascade length:  166
# New Orders left:  57787
# making new cascade
#
#
# OG Orders left:  57787
# Cascade length:  16
# New Orders left:  57771
# making new cascade
#
#
# OG Orders left:  57771
# Cascade length:  534
# New Orders left:  57237
# making new cascade
#
#
# OG Orders left:  57237
# Cascade length:  828
# New Orders left:  56409
# making new cascade
#
#
# OG Orders left:  56409
# Cascade length:  15
# New Orders left:  56394
# making new cascade
#
#
# OG Orders left:  56394
# Cascade length:  63
# New Orders left:  56331
# making new cascade
#
#
# OG Orders left:  56331
# Cascade length:  720
# New Orders left:  55611
# making new cascade
#
#
# OG Orders left:  55611
# Cascade length:  1065
# New Orders left:  54546
# making new cascade
#
#
# OG Orders left:  54546
# Cascade length:  2
# New Orders left:  54544
# making new cascade
#
#
# OG Orders left:  54544
# Cascade length:  674
# New Orders left:  53870
# making new cascade
#
#
# OG Orders left:  53870
# Cascade length:  1226
# New Orders left:  52644
# making new cascade
#
#
# OG Orders left:  52644
# Cascade length:  85
# New Orders left:  52559
# making new cascade
#
#
# OG Orders left:  52559
# Cascade length:  40
# New Orders left:  52519
# making new cascade
#
#
# OG Orders left:  52519
# Cascade length:  860
# New Orders left:  51659
# making new cascade
#
#
# OG Orders left:  51659
# Cascade length:  794
# New Orders left:  50865
# making new cascade
#
#
# OG Orders left:  50865
# Cascade length:  871
# New Orders left:  49994
# making new cascade
#
#
# OG Orders left:  49994
# Cascade length:  355
# New Orders left:  49639
# making new cascade
#
#
# OG Orders left:  49639
# Cascade length:  890
# New Orders left:  48749
# making new cascade
#
#
# OG Orders left:  48749
# Cascade length:  1098
# New Orders left:  47651
# making new cascade
#
#
# OG Orders left:  47651
# Cascade length:  878
# New Orders left:  46773
# making new cascade
#
#
# OG Orders left:  46773
# Cascade length:  7
# New Orders left:  46766
# making new cascade
#
#
# OG Orders left:  46766
# Cascade length:  40
# New Orders left:  46726
# making new cascade
#
#
# OG Orders left:  46726
# Cascade length:  14
# New Orders left:  46712
# making new cascade
#
#
# OG Orders left:  46712
# Cascade length:  440
# New Orders left:  46272
# making new cascade
#
#
# OG Orders left:  46272
# Cascade length:  278
# New Orders left:  45994
# making new cascade
#
#
# OG Orders left:  45994
# Cascade length:  12
# New Orders left:  45982
# making new cascade
#
#
# OG Orders left:  45982
# Cascade length:  3349
# New Orders left:  42633
# making new cascade
#
#
# OG Orders left:  42633
# Cascade length:  955
# New Orders left:  41678
# making new cascade
#
#
# OG Orders left:  41678
# Cascade length:  990
# New Orders left:  40688
# making new cascade
#
#
# OG Orders left:  40688
# Cascade length:  2
# New Orders left:  40686
# making new cascade
#
#
# OG Orders left:  40686
# Cascade length:  41
# New Orders left:  40645
# making new cascade
#
#
# OG Orders left:  40645
# Cascade length:  52
# New Orders left:  40593
# making new cascade
#
#
# OG Orders left:  40593
# Cascade length:  596
# New Orders left:  39997
# making new cascade
#
#
# OG Orders left:  39997
# Cascade length:  2656
# New Orders left:  37341
# making new cascade
#
#
# OG Orders left:  37341
# Cascade length:  1499
# New Orders left:  35842
# making new cascade
#
#
# OG Orders left:  35842
# Cascade length:  2
# New Orders left:  35840
# making new cascade
#
#
# OG Orders left:  35840
# Cascade length:  901
# New Orders left:  34939
# making new cascade
#
#
# OG Orders left:  34939
# Cascade length:  614
# New Orders left:  34325
# making new cascade
#
#
# OG Orders left:  34325
# Cascade length:  190
# New Orders left:  34135
# making new cascade
#
#
# OG Orders left:  34135
# Cascade length:  857
# New Orders left:  33278
# making new cascade
#
#
# OG Orders left:  33278
# Cascade length:  65
# New Orders left:  33213
# making new cascade
#
#
# OG Orders left:  33213
# Cascade length:  305
# New Orders left:  32908
# making new cascade
#
#
# OG Orders left:  32908
# Cascade length:  1031
# New Orders left:  31877
# making new cascade
#
#
# OG Orders left:  31877
# Cascade length:  97
# New Orders left:  31780
# making new cascade
#
#
# OG Orders left:  31780
# Cascade length:  20
# New Orders left:  31760
# making new cascade
#
#
# OG Orders left:  31760
# Cascade length:  311
# New Orders left:  31449
# making new cascade
#
#
# OG Orders left:  31449
# Cascade length:  694
# New Orders left:  30755
# making new cascade
#
#
# OG Orders left:  30755
# Cascade length:  1863
# New Orders left:  28892
# making new cascade
#
#
# OG Orders left:  28892
# Cascade length:  10
# New Orders left:  28882
# making new cascade
#
#
# OG Orders left:  28882
# Cascade length:  516
# New Orders left:  28366
# making new cascade
#
#
# OG Orders left:  28366
# Cascade length:  438
# New Orders left:  27928
# making new cascade
#
#
# OG Orders left:  27928
# Cascade length:  11
# New Orders left:  27917
# making new cascade
#
#
# OG Orders left:  27917
# Cascade length:  871
# New Orders left:  27046
# making new cascade
#
#
# OG Orders left:  27046
# Cascade length:  7
# New Orders left:  27039
# making new cascade
#
#
# OG Orders left:  27039
# Cascade length:  1255
# New Orders left:  25784
# making new cascade
#
#
# OG Orders left:  25784
# Cascade length:  24
# New Orders left:  25760
# making new cascade
#
#
# OG Orders left:  25760
# Cascade length:  31
# New Orders left:  25729
# making new cascade
#
#
# OG Orders left:  25729
# Cascade length:  854
# New Orders left:  24875
# making new cascade
#
#
# OG Orders left:  24875
# Cascade length:  811
# New Orders left:  24064
# making new cascade
#
#
# OG Orders left:  24064
# Cascade length:  75
# New Orders left:  23989
# making new cascade
#
#
# OG Orders left:  23989
# Cascade length:  840
# New Orders left:  23149
# making new cascade
#
#
# OG Orders left:  23149
# Cascade length:  20
# New Orders left:  23129
# making new cascade
#
#
# OG Orders left:  23129
# Cascade length:  1121
# New Orders left:  22008
# making new cascade
#
#
# OG Orders left:  22008
# Cascade length:  691
# New Orders left:  21317
# making new cascade
#
#
# OG Orders left:  21317
# Cascade length:  6
# New Orders left:  21311
# making new cascade
#
#
# OG Orders left:  21311
# Cascade length:  1
# New Orders left:  21310
# making new cascade
#
#
# OG Orders left:  21310
# Cascade length:  1497
# New Orders left:  19813
# making new cascade
#
#
# OG Orders left:  19813
# Cascade length:  1075
# New Orders left:  18738
# making new cascade
#
#
# OG Orders left:  18738
# Cascade length:  83
# New Orders left:  18655
# making new cascade
#
#
# OG Orders left:  18655
# Cascade length:  1
# New Orders left:  18654
# making new cascade
#
#
# OG Orders left:  18654
# Cascade length:  7
# New Orders left:  18647
# making new cascade
#
#
# OG Orders left:  18647
# Cascade length:  772
# New Orders left:  17875
# making new cascade
#
#
# OG Orders left:  17875
# Cascade length:  36
# New Orders left:  17839
# making new cascade
#
#
# OG Orders left:  17839
# Cascade length:  684
# New Orders left:  17155
# making new cascade
#
#
# OG Orders left:  17155
# Cascade length:  1327
# New Orders left:  15828
# making new cascade
#
#
# OG Orders left:  15828
# Cascade length:  684
# New Orders left:  15144
# making new cascade
#
#
# OG Orders left:  15144
# Cascade length:  4
# New Orders left:  15140
# making new cascade
#
#
# OG Orders left:  15140
# Cascade length:  1598
# New Orders left:  13542
# making new cascade
#
#
# OG Orders left:  13542
# Cascade length:  884
# New Orders left:  12658
# making new cascade
#
#
# OG Orders left:  12658
# Cascade length:  620
# New Orders left:  12038
# making new cascade
#
#
# OG Orders left:  12038
# Cascade length:  397
# New Orders left:  11641
# making new cascade
#
#
# OG Orders left:  11641
# Cascade length:  962
# New Orders left:  10679
# making new cascade
#
#
# OG Orders left:  10679
# Cascade length:  32
# New Orders left:  10647
# making new cascade
#
#
# OG Orders left:  10647
# Cascade length:  1442
# New Orders left:  9205
# making new cascade
#
#
# OG Orders left:  9205
# Cascade length:  444
# New Orders left:  8761
# making new cascade
#
#
# OG Orders left:  8761
# Cascade length:  1048
# New Orders left:  7713
# making new cascade
#
#
# OG Orders left:  7713
# Cascade length:  574
# New Orders left:  7139
# making new cascade
#
#
# OG Orders left:  7139
# Cascade length:  27
# New Orders left:  7112
# making new cascade
#
#
# OG Orders left:  7112
# Cascade length:  513
# New Orders left:  6599
# making new cascade
#
#
# OG Orders left:  6599
# Cascade length:  4
# New Orders left:  6595
# making new cascade
#
#
# OG Orders left:  6595
# Cascade length:  557
# New Orders left:  6038
# making new cascade
#
#
# OG Orders left:  6038
# Cascade length:  1060
# New Orders left:  4978
# making new cascade
#
#
# OG Orders left:  4978
# Cascade length:  706
# New Orders left:  4272
# making new cascade
#
#
# OG Orders left:  4272
# Cascade length:  29
# New Orders left:  4243
# making new cascade
#
#
# OG Orders left:  4243
# Cascade length:  584
# New Orders left:  3659
# making new cascade
#
#
# OG Orders left:  3659
# Cascade length:  6
# New Orders left:  3653
# making new cascade
#
#
# OG Orders left:  3653
# Cascade length:  528
# New Orders left:  3125
# making new cascade
#
#
# OG Orders left:  3125
# Cascade length:  432
# New Orders left:  2693
# making new cascade
#
#
# OG Orders left:  2693
# Cascade length:  46
# New Orders left:  2647
# making new cascade
#
#
# OG Orders left:  2647
# Cascade length:  388
# New Orders left:  2259
# making new cascade
#
#
# OG Orders left:  2259
# Cascade length:  12
# New Orders left:  2247
# making new cascade
#
#
# OG Orders left:  2247
# Cascade length:  261
# New Orders left:  1986
# making new cascade
#
#
# OG Orders left:  1986
# Cascade length:  291
# New Orders left:  1695
# making new cascade
#
#
# OG Orders left:  1695
# Cascade length:  519
# New Orders left:  1176
# making new cascade
#
#
# OG Orders left:  1176
# Cascade length:  165
# New Orders left:  1011
# making new cascade
#
#
# OG Orders left:  1011
# Cascade length:  147
# New Orders left:  864
# making new cascade
#
#
# OG Orders left:  864
# Cascade length:  240
# New Orders left:  624
# making new cascade
#
#
# OG Orders left:  624
# Cascade length:  88
# New Orders left:  536
# making new cascade
#
#
# OG Orders left:  536
# Cascade length:  24
# New Orders left:  512
# making new cascade
#
#
# OG Orders left:  512
# Cascade length:  75
# New Orders left:  437
# making new cascade
#
#
# OG Orders left:  437
# Cascade length:  112
# New Orders left:  325
# making new cascade
#
#
# OG Orders left:  325
# Cascade length:  195
# New Orders left:  130
# making new cascade
#
#
# OG Orders left:  130
# Cascade length:  40
# New Orders left:  90
# making new cascade
#
#
# OG Orders left:  90
# Cascade length:  18
# New Orders left:  72
# making new cascade
#
#
# OG Orders left:  72
# Cascade length:  56
# New Orders left:  16
# making new cascade
#
#
# OG Orders left:  16
# Cascade length:  12
# New Orders left:  4
# making new cascade
#
#
# OG Orders left:  4
# Cascade length:  4
# New Orders left:  0
# making new cascade

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=8192)
with open('../causalCascades11_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  1425670
# Cascade length:  1644
# New Orders left:  1424026
# making new cascade
#
#
# OG Orders left:  1424026
# Cascade length:  1224
# New Orders left:  1422802
# making new cascade
#
#
# OG Orders left:  1422802
# Cascade length:  1308
# New Orders left:  1421494
# making new cascade
#
#
# OG Orders left:  1421494
# Cascade length:  1305
# New Orders left:  1420189
# making new cascade
#
#
# OG Orders left:  1420189
# Cascade length:  2
# New Orders left:  1420187
# making new cascade
#
#
# OG Orders left:  1420187
# Cascade length:  1379
# New Orders left:  1418808
# making new cascade
#
#
# OG Orders left:  1418808
# Cascade length:  1538
# New Orders left:  1417270
# making new cascade
#
#
# OG Orders left:  1417270
# Cascade length:  1401
# New Orders left:  1415869
# making new cascade
#
#
# OG Orders left:  1415869
# Cascade length:  2
# New Orders left:  1415867
# making new cascade
#
#
# OG Orders left:  1415867
# Cascade length:  40
# New Orders left:  1415827
# making new cascade
#
#
# OG Orders left:  1415827
# Cascade length:  1301
# New Orders left:  1414526
# making new cascade
#
#
# OG Orders left:  1414526
# Cascade length:  926
# New Orders left:  1413600
# making new cascade
#
#
# OG Orders left:  1413600
# Cascade length:  25
# New Orders left:  1413575
# making new cascade
#
#
# OG Orders left:  1413575
# Cascade length:  578
# New Orders left:  1412997
# making new cascade
#
#
# OG Orders left:  1412997
# Cascade length:  12
# New Orders left:  1412985
# making new cascade
#
#
# OG Orders left:  1412985
# Cascade length:  1619
# New Orders left:  1411366
# making new cascade
#
#
# OG Orders left:  1411366
# Cascade length:  1209
# New Orders left:  1410157
# making new cascade
#
#
# OG Orders left:  1410157
# Cascade length:  1073
# New Orders left:  1409084
# making new cascade
#
#
# OG Orders left:  1409084
# Cascade length:  287
# New Orders left:  1408797
# making new cascade
#
#
# OG Orders left:  1408797
# Cascade length:  1174
# New Orders left:  1407623
# making new cascade
#
#
# OG Orders left:  1407623
# Cascade length:  891
# New Orders left:  1406732
# making new cascade
#
#
# OG Orders left:  1406732
# Cascade length:  2
# New Orders left:  1406730
# making new cascade
#
#
# OG Orders left:  1406730
# Cascade length:  909
# New Orders left:  1405821
# making new cascade
#
#
# OG Orders left:  1405821
# Cascade length:  1342
# New Orders left:  1404479
# making new cascade
#
#
# OG Orders left:  1404479
# Cascade length:  847
# New Orders left:  1403632
# making new cascade
#
#
# OG Orders left:  1403632
# Cascade length:  1294
# New Orders left:  1402338
# making new cascade
#
#
# OG Orders left:  1402338
# Cascade length:  1063
# New Orders left:  1401275
# making new cascade
#
#
# OG Orders left:  1401275
# Cascade length:  11
# New Orders left:  1401264
# making new cascade
#
#
# OG Orders left:  1401264
# Cascade length:  3
# New Orders left:  1401261
# making new cascade
#
#
# OG Orders left:  1401261
# Cascade length:  477
# New Orders left:  1400784
# making new cascade
#
#
# OG Orders left:  1400784
# Cascade length:  2
# New Orders left:  1400782
# making new cascade
#
#
# OG Orders left:  1400782
# Cascade length:  643
# New Orders left:  1400139
# making new cascade
#
#
# OG Orders left:  1400139
# Cascade length:  4
# New Orders left:  1400135
# making new cascade
#
#
# OG Orders left:  1400135
# Cascade length:  389
# New Orders left:  1399746
# making new cascade
#
#
# OG Orders left:  1399746
# Cascade length:  3
# New Orders left:  1399743
# making new cascade
#
#
# OG Orders left:  1399743
# Cascade length:  991
# New Orders left:  1398752
# making new cascade
#
#
# OG Orders left:  1398752
# Cascade length:  959
# New Orders left:  1397793
# making new cascade
#
#
# OG Orders left:  1397793
# Cascade length:  3
# New Orders left:  1397790
# making new cascade
#
#
# OG Orders left:  1397790
# Cascade length:  599
# New Orders left:  1397191
# making new cascade
#
#
# OG Orders left:  1397191
# Cascade length:  953
# New Orders left:  1396238
# making new cascade
#
#
# OG Orders left:  1396238
# Cascade length:  2
# New Orders left:  1396236
# making new cascade
#
#
# OG Orders left:  1396236
# Cascade length:  485
# New Orders left:  1395751
# making new cascade
#
#
# OG Orders left:  1395751
# Cascade length:  942
# New Orders left:  1394809
# making new cascade
#
#
# OG Orders left:  1394809
# Cascade length:  350
# New Orders left:  1394459
# making new cascade
#
#
# OG Orders left:  1394459
# Cascade length:  952
# New Orders left:  1393507
# making new cascade
#
#
# OG Orders left:  1393507
# Cascade length:  602
# New Orders left:  1392905
# making new cascade
#
#
# OG Orders left:  1392905
# Cascade length:  822
# New Orders left:  1392083
# making new cascade
#
#
# OG Orders left:  1392083
# Cascade length:  6
# New Orders left:  1392077
# making new cascade
#
#
# OG Orders left:  1392077
# Cascade length:  682
# New Orders left:  1391395
# making new cascade
#
#
# OG Orders left:  1391395
# Cascade length:  21
# New Orders left:  1391374
# making new cascade
#
#
# OG Orders left:  1391374
# Cascade length:  1102
# New Orders left:  1390272
# making new cascade
#
#
# OG Orders left:  1390272
# Cascade length:  36
# New Orders left:  1390236
# making new cascade
#
#
# OG Orders left:  1390236
# Cascade length:  5
# New Orders left:  1390231
# making new cascade
#
#
# OG Orders left:  1390231
# Cascade length:  967
# New Orders left:  1389264
# making new cascade
#
#
# OG Orders left:  1389264
# Cascade length:  668
# New Orders left:  1388596
# making new cascade
#
#
# OG Orders left:  1388596
# Cascade length:  1
# New Orders left:  1388595
# making new cascade
#
#
# OG Orders left:  1388595
# Cascade length:  597
# New Orders left:  1387998
# making new cascade
#
#
# OG Orders left:  1387998
# Cascade length:  6
# New Orders left:  1387992
# making new cascade
#
#
# OG Orders left:  1387992
# Cascade length:  39
# New Orders left:  1387953
# making new cascade
#
#
# OG Orders left:  1387953
# Cascade length:  1094
# New Orders left:  1386859
# making new cascade
#
#
# OG Orders left:  1386859
# Cascade length:  3
# New Orders left:  1386856
# making new cascade
#
#
# OG Orders left:  1386856
# Cascade length:  25
# New Orders left:  1386831
# making new cascade
#
#
# OG Orders left:  1386831
# Cascade length:  1207
# New Orders left:  1385624
# making new cascade
#
#
# OG Orders left:  1385624
# Cascade length:  7
# New Orders left:  1385617
# making new cascade
#
#
# OG Orders left:  1385617
# Cascade length:  4
# New Orders left:  1385613
# making new cascade
#
#
# OG Orders left:  1385613
# Cascade length:  11
# New Orders left:  1385602
# making new cascade
#
#
# OG Orders left:  1385602
# Cascade length:  11
# New Orders left:  1385591
# making new cascade
#
#
# OG Orders left:  1385591
# Cascade length:  539
# New Orders left:  1385052
# making new cascade
#
#
# OG Orders left:  1385052
# Cascade length:  759
# New Orders left:  1384293
# making new cascade
#
#
# OG Orders left:  1384293
# Cascade length:  1055
# New Orders left:  1383238
# making new cascade
#
#
# OG Orders left:  1383238
# Cascade length:  2
# New Orders left:  1383236
# making new cascade
#
#
# OG Orders left:  1383236
# Cascade length:  704
# New Orders left:  1382532
# making new cascade
#
#
# OG Orders left:  1382532
# Cascade length:  1
# New Orders left:  1382531
# making new cascade
#
#
# OG Orders left:  1382531
# Cascade length:  828
# New Orders left:  1381703
# making new cascade
#
#
# OG Orders left:  1381703
# Cascade length:  7
# New Orders left:  1381696
# making new cascade
#
#
# OG Orders left:  1381696
# Cascade length:  2
# New Orders left:  1381694
# making new cascade
#
#
# OG Orders left:  1381694
# Cascade length:  907
# New Orders left:  1380787
# making new cascade
#
#
# OG Orders left:  1380787
# Cascade length:  3
# New Orders left:  1380784
# making new cascade
#
#
# OG Orders left:  1380784
# Cascade length:  739
# New Orders left:  1380045
# making new cascade
#
#
# OG Orders left:  1380045
# Cascade length:  978
# New Orders left:  1379067
# making new cascade
#
#
# OG Orders left:  1379067
# Cascade length:  8
# New Orders left:  1379059
# making new cascade
#
#
# OG Orders left:  1379059
# Cascade length:  21
# New Orders left:  1379038
# making new cascade
#
#
# OG Orders left:  1379038
# Cascade length:  1
# New Orders left:  1379037
# making new cascade
#
#
# OG Orders left:  1379037
# Cascade length:  1163
# New Orders left:  1377874
# making new cascade
#
#
# OG Orders left:  1377874
# Cascade length:  1
# New Orders left:  1377873
# making new cascade
#
#
# OG Orders left:  1377873
# Cascade length:  1
# New Orders left:  1377872
# making new cascade
#
#
# OG Orders left:  1377872
# Cascade length:  917
# New Orders left:  1376955
# making new cascade
#
#
# OG Orders left:  1376955
# Cascade length:  17
# New Orders left:  1376938
# making new cascade
#
#
# OG Orders left:  1376938
# Cascade length:  2
# New Orders left:  1376936
# making new cascade
#
#
# OG Orders left:  1376936
# Cascade length:  909
# New Orders left:  1376027
# making new cascade
#
#
# OG Orders left:  1376027
# Cascade length:  9
# New Orders left:  1376018
# making new cascade
#
#
# OG Orders left:  1376018
# Cascade length:  1
# New Orders left:  1376017
# making new cascade
#
#
# OG Orders left:  1376017
# Cascade length:  22
# New Orders left:  1375995
# making new cascade
#
#
# OG Orders left:  1375995
# Cascade length:  33
# New Orders left:  1375962
# making new cascade
#
#
# OG Orders left:  1375962
# Cascade length:  584
# New Orders left:  1375378
# making new cascade
#
#
# OG Orders left:  1375378
# Cascade length:  29
# New Orders left:  1375349
# making new cascade
#
#
# OG Orders left:  1375349
# Cascade length:  715
# New Orders left:  1374634
# making new cascade
#
#
# OG Orders left:  1374634
# Cascade length:  556
# New Orders left:  1374078
# making new cascade
#
#
# OG Orders left:  1374078
# Cascade length:  21
# New Orders left:  1374057
# making new cascade
#
#
# OG Orders left:  1374057
# Cascade length:  6
# New Orders left:  1374051
# making new cascade
#
#
# OG Orders left:  1374051
# Cascade length:  496
# New Orders left:  1373555
# making new cascade
#
#
# OG Orders left:  1373555
# Cascade length:  9
# New Orders left:  1373546
# making new cascade
#
#
# OG Orders left:  1373546
# Cascade length:  981
# New Orders left:  1372565
# making new cascade
#
#
# OG Orders left:  1372565
# Cascade length:  14
# New Orders left:  1372551
# making new cascade
#
#
# OG Orders left:  1372551
# Cascade length:  17
# New Orders left:  1372534
# making new cascade
#
#
# OG Orders left:  1372534
# Cascade length:  399
# New Orders left:  1372135
# making new cascade
#
#
# OG Orders left:  1372135
# Cascade length:  6
# New Orders left:  1372129
# making new cascade
#
#
# OG Orders left:  1372129
# Cascade length:  5
# New Orders left:  1372124
# making new cascade
#
#
# OG Orders left:  1372124
# Cascade length:  722
# New Orders left:  1371402
# making new cascade
#
#
# OG Orders left:  1371402
# Cascade length:  1111
# New Orders left:  1370291
# making new cascade
#
#
# OG Orders left:  1370291
# Cascade length:  4
# New Orders left:  1370287
# making new cascade
#
#
# OG Orders left:  1370287
# Cascade length:  45
# New Orders left:  1370242
# making new cascade
#
#
# OG Orders left:  1370242
# Cascade length:  8
# New Orders left:  1370234
# making new cascade
#
#
# OG Orders left:  1370234
# Cascade length:  13
# New Orders left:  1370221
# making new cascade
#
#
# OG Orders left:  1370221
# Cascade length:  724
# New Orders left:  1369497
# making new cascade
#
#
# OG Orders left:  1369497
# Cascade length:  15
# New Orders left:  1369482
# making new cascade
#
#
# OG Orders left:  1369482
# Cascade length:  771
# New Orders left:  1368711
# making new cascade
#
#
# OG Orders left:  1368711
# Cascade length:  1416
# New Orders left:  1367295
# making new cascade
#
#
# OG Orders left:  1367295
# Cascade length:  13
# New Orders left:  1367282
# making new cascade
#
#
# OG Orders left:  1367282
# Cascade length:  55
# New Orders left:  1367227
# making new cascade
#
#
# OG Orders left:  1367227
# Cascade length:  1116
# New Orders left:  1366111
# making new cascade
#
#
# OG Orders left:  1366111
# Cascade length:  77
# New Orders left:  1366034
# making new cascade
#
#
# OG Orders left:  1366034
# Cascade length:  575
# New Orders left:  1365459
# making new cascade
#
#
# OG Orders left:  1365459
# Cascade length:  770
# New Orders left:  1364689
# making new cascade
#
#
# OG Orders left:  1364689
# Cascade length:  13
# New Orders left:  1364676
# making new cascade
#
#
# OG Orders left:  1364676
# Cascade length:  603
# New Orders left:  1364073
# making new cascade
#
#
# OG Orders left:  1364073
# Cascade length:  1100
# New Orders left:  1362973
# making new cascade
#
#
# OG Orders left:  1362973
# Cascade length:  1174
# New Orders left:  1361799
# making new cascade
#
#
# OG Orders left:  1361799
# Cascade length:  445
# New Orders left:  1361354
# making new cascade
#
#
# OG Orders left:  1361354
# Cascade length:  9
# New Orders left:  1361345
# making new cascade
#
#
# OG Orders left:  1361345
# Cascade length:  742
# New Orders left:  1360603
# making new cascade
#
#
# OG Orders left:  1360603
# Cascade length:  18
# New Orders left:  1360585
# making new cascade
#
#
# OG Orders left:  1360585
# Cascade length:  623
# New Orders left:  1359962
# making new cascade
#
#
# OG Orders left:  1359962
# Cascade length:  769
# New Orders left:  1359193
# making new cascade
#
#
# OG Orders left:  1359193
# Cascade length:  5
# New Orders left:  1359188
# making new cascade
#
#
# OG Orders left:  1359188
# Cascade length:  13
# New Orders left:  1359175
# making new cascade
#
#
# OG Orders left:  1359175
# Cascade length:  122
# New Orders left:  1359053
# making new cascade
#
#
# OG Orders left:  1359053
# Cascade length:  410
# New Orders left:  1358643
# making new cascade
#
#
# OG Orders left:  1358643
# Cascade length:  2
# New Orders left:  1358641
# making new cascade
#
#
# OG Orders left:  1358641
# Cascade length:  21
# New Orders left:  1358620
# making new cascade
#
#
# OG Orders left:  1358620
# Cascade length:  4
# New Orders left:  1358616
# making new cascade
#
#
# OG Orders left:  1358616
# Cascade length:  54
# New Orders left:  1358562
# making new cascade
#
#
# OG Orders left:  1358562
# Cascade length:  523
# New Orders left:  1358039
# making new cascade
#
#
# OG Orders left:  1358039
# Cascade length:  3
# New Orders left:  1358036
# making new cascade
#
#
# OG Orders left:  1358036
# Cascade length:  846
# New Orders left:  1357190
# making new cascade
#
#
# OG Orders left:  1357190
# Cascade length:  5
# New Orders left:  1357185
# making new cascade
#
#
# OG Orders left:  1357185
# Cascade length:  509
# New Orders left:  1356676
# making new cascade
#
#
# OG Orders left:  1356676
# Cascade length:  942
# New Orders left:  1355734
# making new cascade
#
#
# OG Orders left:  1355734
# Cascade length:  417
# New Orders left:  1355317
# making new cascade
#
#
# OG Orders left:  1355317
# Cascade length:  25
# New Orders left:  1355292
# making new cascade
#
#
# OG Orders left:  1355292
# Cascade length:  6
# New Orders left:  1355286
# making new cascade
#
#
# OG Orders left:  1355286
# Cascade length:  508
# New Orders left:  1354778
# making new cascade
#
#
# OG Orders left:  1354778
# Cascade length:  599
# New Orders left:  1354179
# making new cascade
#
#
# OG Orders left:  1354179
# Cascade length:  1
# New Orders left:  1354178
# making new cascade
#
#
# OG Orders left:  1354178
# Cascade length:  1
# New Orders left:  1354177
# making new cascade
#
#
# OG Orders left:  1354177
# Cascade length:  2
# New Orders left:  1354175
# making new cascade
#
#
# OG Orders left:  1354175
# Cascade length:  6
# New Orders left:  1354169
# making new cascade
#
#
# OG Orders left:  1354169
# Cascade length:  31
# New Orders left:  1354138
# making new cascade
#
#
# OG Orders left:  1354138
# Cascade length:  782
# New Orders left:  1353356
# making new cascade
#
#
# OG Orders left:  1353356
# Cascade length:  682
# New Orders left:  1352674
# making new cascade
#
#
# OG Orders left:  1352674
# Cascade length:  633
# New Orders left:  1352041
# making new cascade
#
#
# OG Orders left:  1352041
# Cascade length:  1
# New Orders left:  1352040
# making new cascade
#
#
# OG Orders left:  1352040
# Cascade length:  19
# New Orders left:  1352021
# making new cascade
#
#
# OG Orders left:  1352021
# Cascade length:  14
# New Orders left:  1352007
# making new cascade
#
#
# OG Orders left:  1352007
# Cascade length:  815
# New Orders left:  1351192
# making new cascade
#
#
# OG Orders left:  1351192
# Cascade length:  3
# New Orders left:  1351189
# making new cascade
#
#
# OG Orders left:  1351189
# Cascade length:  676
# New Orders left:  1350513
# making new cascade
#
#
# OG Orders left:  1350513
# Cascade length:  5
# New Orders left:  1350508
# making new cascade
#
#
# OG Orders left:  1350508
# Cascade length:  889
# New Orders left:  1349619
# making new cascade
#
#
# OG Orders left:  1349619
# Cascade length:  5
# New Orders left:  1349614
# making new cascade
#
#
# OG Orders left:  1349614
# Cascade length:  114
# New Orders left:  1349500
# making new cascade
#
#
# OG Orders left:  1349500
# Cascade length:  6
# New Orders left:  1349494
# making new cascade
#
#
# OG Orders left:  1349494
# Cascade length:  23
# New Orders left:  1349471
# making new cascade
#
#
# OG Orders left:  1349471
# Cascade length:  575
# New Orders left:  1348896
# making new cascade
#
#
# OG Orders left:  1348896
# Cascade length:  4
# New Orders left:  1348892
# making new cascade
#
#
# OG Orders left:  1348892
# Cascade length:  1068
# New Orders left:  1347824
# making new cascade
#
#
# OG Orders left:  1347824
# Cascade length:  552
# New Orders left:  1347272
# making new cascade
#
#
# OG Orders left:  1347272
# Cascade length:  44
# New Orders left:  1347228
# making new cascade
#
#
# OG Orders left:  1347228
# Cascade length:  914
# New Orders left:  1346314
# making new cascade
#
#
# OG Orders left:  1346314
# Cascade length:  1
# New Orders left:  1346313
# making new cascade
#
#
# OG Orders left:  1346313
# Cascade length:  18
# New Orders left:  1346295
# making new cascade
#
#
# OG Orders left:  1346295
# Cascade length:  906
# New Orders left:  1345389
# making new cascade
#
#
# OG Orders left:  1345389
# Cascade length:  983
# New Orders left:  1344406
# making new cascade
#
#
# OG Orders left:  1344406
# Cascade length:  1
# New Orders left:  1344405
# making new cascade
#
#
# OG Orders left:  1344405
# Cascade length:  30
# New Orders left:  1344375
# making new cascade
#
#
# OG Orders left:  1344375
# Cascade length:  329
# New Orders left:  1344046
# making new cascade
#
#
# OG Orders left:  1344046
# Cascade length:  671
# New Orders left:  1343375
# making new cascade
#
#
# OG Orders left:  1343375
# Cascade length:  441
# New Orders left:  1342934
# making new cascade
#
#
# OG Orders left:  1342934
# Cascade length:  31
# New Orders left:  1342903
# making new cascade
#
#
# OG Orders left:  1342903
# Cascade length:  6
# New Orders left:  1342897
# making new cascade
#
#
# OG Orders left:  1342897
# Cascade length:  459
# New Orders left:  1342438
# making new cascade
#
#
# OG Orders left:  1342438
# Cascade length:  182
# New Orders left:  1342256
# making new cascade
#
#
# OG Orders left:  1342256
# Cascade length:  8
# New Orders left:  1342248
# making new cascade
#
#
# OG Orders left:  1342248
# Cascade length:  8
# New Orders left:  1342240
# making new cascade
#
#
# OG Orders left:  1342240
# Cascade length:  405
# New Orders left:  1341835
# making new cascade
#
#
# OG Orders left:  1341835
# Cascade length:  506
# New Orders left:  1341329
# making new cascade
#
#
# OG Orders left:  1341329
# Cascade length:  2
# New Orders left:  1341327
# making new cascade
#
#
# OG Orders left:  1341327
# Cascade length:  19
# New Orders left:  1341308
# making new cascade
#
#
# OG Orders left:  1341308
# Cascade length:  405
# New Orders left:  1340903
# making new cascade
#
#
# OG Orders left:  1340903
# Cascade length:  2
# New Orders left:  1340901
# making new cascade
#
#
# OG Orders left:  1340901
# Cascade length:  814
# New Orders left:  1340087
# making new cascade
#
#
# OG Orders left:  1340087
# Cascade length:  3
# New Orders left:  1340084
# making new cascade
#
#
# OG Orders left:  1340084
# Cascade length:  640
# New Orders left:  1339444
# making new cascade
#
#
# OG Orders left:  1339444
# Cascade length:  11
# New Orders left:  1339433
# making new cascade
#
#
# OG Orders left:  1339433
# Cascade length:  6
# New Orders left:  1339427
# making new cascade
#
#
# OG Orders left:  1339427
# Cascade length:  408
# New Orders left:  1339019
# making new cascade
#
#
# OG Orders left:  1339019
# Cascade length:  4
# New Orders left:  1339015
# making new cascade
#
#
# OG Orders left:  1339015
# Cascade length:  83
# New Orders left:  1338932
# making new cascade
#
#
# OG Orders left:  1338932
# Cascade length:  4
# New Orders left:  1338928
# making new cascade
#
#
# OG Orders left:  1338928
# Cascade length:  62
# New Orders left:  1338866
# making new cascade
#
#
# OG Orders left:  1338866
# Cascade length:  461
# New Orders left:  1338405
# making new cascade
#
#
# OG Orders left:  1338405
# Cascade length:  328
# New Orders left:  1338077
# making new cascade
#
#
# OG Orders left:  1338077
# Cascade length:  490
# New Orders left:  1337587
# making new cascade
#
#
# OG Orders left:  1337587
# Cascade length:  1
# New Orders left:  1337586
# making new cascade
#
#
# OG Orders left:  1337586
# Cascade length:  184
# New Orders left:  1337402
# making new cascade
#
#
# OG Orders left:  1337402
# Cascade length:  5
# New Orders left:  1337397
# making new cascade
#
#
# OG Orders left:  1337397
# Cascade length:  1140
# New Orders left:  1336257
# making new cascade
#
#
# OG Orders left:  1336257
# Cascade length:  10
# New Orders left:  1336247
# making new cascade
#
#
# OG Orders left:  1336247
# Cascade length:  699
# New Orders left:  1335548
# making new cascade
#
#
# OG Orders left:  1335548
# Cascade length:  608
# New Orders left:  1334940
# making new cascade
#
#
# OG Orders left:  1334940
# Cascade length:  7
# New Orders left:  1334933
# making new cascade
#
#
# OG Orders left:  1334933
# Cascade length:  2
# New Orders left:  1334931
# making new cascade
#
#
# OG Orders left:  1334931
# Cascade length:  682
# New Orders left:  1334249
# making new cascade
#
#
# OG Orders left:  1334249
# Cascade length:  2
# New Orders left:  1334247
# making new cascade
#
#
# OG Orders left:  1334247
# Cascade length:  448
# New Orders left:  1333799
# making new cascade
#
#
# OG Orders left:  1333799
# Cascade length:  7
# New Orders left:  1333792
# making new cascade
#
#
# OG Orders left:  1333792
# Cascade length:  7
# New Orders left:  1333785
# making new cascade
#
#
# OG Orders left:  1333785
# Cascade length:  663
# New Orders left:  1333122
# making new cascade
#
#
# OG Orders left:  1333122
# Cascade length:  64
# New Orders left:  1333058
# making new cascade
#
#
# OG Orders left:  1333058
# Cascade length:  602
# New Orders left:  1332456
# making new cascade
#
#
# OG Orders left:  1332456
# Cascade length:  1
# New Orders left:  1332455
# making new cascade
#
#
# OG Orders left:  1332455
# Cascade length:  1
# New Orders left:  1332454
# making new cascade
#
#
# OG Orders left:  1332454
# Cascade length:  228
# New Orders left:  1332226
# making new cascade
#
#
# OG Orders left:  1332226
# Cascade length:  712
# New Orders left:  1331514
# making new cascade
#
#
# OG Orders left:  1331514
# Cascade length:  785
# New Orders left:  1330729
# making new cascade
#
#
# OG Orders left:  1330729
# Cascade length:  2
# New Orders left:  1330727
# making new cascade
#
#
# OG Orders left:  1330727
# Cascade length:  26
# New Orders left:  1330701
# making new cascade
#
#
# OG Orders left:  1330701
# Cascade length:  1
# New Orders left:  1330700
# making new cascade
#
#
# OG Orders left:  1330700
# Cascade length:  7
# New Orders left:  1330693
# making new cascade
#
#
# OG Orders left:  1330693
# Cascade length:  1
# New Orders left:  1330692
# making new cascade
#
#
# OG Orders left:  1330692
# Cascade length:  798
# New Orders left:  1329894
# making new cascade
#
#
# OG Orders left:  1329894
# Cascade length:  14
# New Orders left:  1329880
# making new cascade
#
#
# OG Orders left:  1329880
# Cascade length:  457
# New Orders left:  1329423
# making new cascade
#
#
# OG Orders left:  1329423
# Cascade length:  2
# New Orders left:  1329421
# making new cascade
#
#
# OG Orders left:  1329421
# Cascade length:  1
# New Orders left:  1329420
# making new cascade
#
#
# OG Orders left:  1329420
# Cascade length:  198
# New Orders left:  1329222
# making new cascade
#
#
# OG Orders left:  1329222
# Cascade length:  6
# New Orders left:  1329216
# making new cascade
#
#
# OG Orders left:  1329216
# Cascade length:  696
# New Orders left:  1328520
# making new cascade
#
#
# OG Orders left:  1328520
# Cascade length:  178
# New Orders left:  1328342
# making new cascade
#
#
# OG Orders left:  1328342
# Cascade length:  958
# New Orders left:  1327384
# making new cascade
#
#
# OG Orders left:  1327384
# Cascade length:  2
# New Orders left:  1327382
# making new cascade
#
#
# OG Orders left:  1327382
# Cascade length:  47
# New Orders left:  1327335
# making new cascade
#
#
# OG Orders left:  1327335
# Cascade length:  1
# New Orders left:  1327334
# making new cascade
#
#
# OG Orders left:  1327334
# Cascade length:  3
# New Orders left:  1327331
# making new cascade
#
#
# OG Orders left:  1327331
# Cascade length:  566
# New Orders left:  1326765
# making new cascade
#
#
# OG Orders left:  1326765
# Cascade length:  2
# New Orders left:  1326763
# making new cascade
#
#
# OG Orders left:  1326763
# Cascade length:  2
# New Orders left:  1326761
# making new cascade
#
#
# OG Orders left:  1326761
# Cascade length:  669
# New Orders left:  1326092
# making new cascade
#
#
# OG Orders left:  1326092
# Cascade length:  5
# New Orders left:  1326087
# making new cascade
#
#
# OG Orders left:  1326087
# Cascade length:  5
# New Orders left:  1326082
# making new cascade
#
#
# OG Orders left:  1326082
# Cascade length:  390
# New Orders left:  1325692
# making new cascade
#
#
# OG Orders left:  1325692
# Cascade length:  4
# New Orders left:  1325688
# making new cascade
#
#
# OG Orders left:  1325688
# Cascade length:  6
# New Orders left:  1325682
# making new cascade
#
#
# OG Orders left:  1325682
# Cascade length:  278
# New Orders left:  1325404
# making new cascade
#
#
# OG Orders left:  1325404
# Cascade length:  4
# New Orders left:  1325400
# making new cascade
#
#
# OG Orders left:  1325400
# Cascade length:  22
# New Orders left:  1325378
# making new cascade
#
#
# OG Orders left:  1325378
# Cascade length:  30
# New Orders left:  1325348
# making new cascade
#
#
# OG Orders left:  1325348
# Cascade length:  505
# New Orders left:  1324843
# making new cascade
#
#
# OG Orders left:  1324843
# Cascade length:  13
# New Orders left:  1324830
# making new cascade
#
#
# OG Orders left:  1324830
# Cascade length:  6
# New Orders left:  1324824
# making new cascade
#
#
# OG Orders left:  1324824
# Cascade length:  414
# New Orders left:  1324410
# making new cascade
#
#
# OG Orders left:  1324410
# Cascade length:  208
# New Orders left:  1324202
# making new cascade
#
#
# OG Orders left:  1324202
# Cascade length:  7
# New Orders left:  1324195
# making new cascade
#
#
# OG Orders left:  1324195
# Cascade length:  568
# New Orders left:  1323627
# making new cascade
#
#
# OG Orders left:  1323627
# Cascade length:  276
# New Orders left:  1323351
# making new cascade
#
#
# OG Orders left:  1323351
# Cascade length:  403
# New Orders left:  1322948
# making new cascade
#
#
# OG Orders left:  1322948
# Cascade length:  3
# New Orders left:  1322945
# making new cascade
#
#
# OG Orders left:  1322945
# Cascade length:  696
# New Orders left:  1322249
# making new cascade
#
#
# OG Orders left:  1322249
# Cascade length:  9
# New Orders left:  1322240
# making new cascade
#
#
# OG Orders left:  1322240
# Cascade length:  715
# New Orders left:  1321525
# making new cascade
#
#
# OG Orders left:  1321525
# Cascade length:  4
# New Orders left:  1321521
# making new cascade
#
#
# OG Orders left:  1321521
# Cascade length:  13
# New Orders left:  1321508
# making new cascade
#
#
# OG Orders left:  1321508
# Cascade length:  18
# New Orders left:  1321490
# making new cascade
#
#
# OG Orders left:  1321490
# Cascade length:  1
# New Orders left:  1321489
# making new cascade
#
#
# OG Orders left:  1321489
# Cascade length:  2
# New Orders left:  1321487
# making new cascade
#
#
# OG Orders left:  1321487
# Cascade length:  3
# New Orders left:  1321484
# making new cascade
#
#
# OG Orders left:  1321484
# Cascade length:  712
# New Orders left:  1320772
# making new cascade
#
#
# OG Orders left:  1320772
# Cascade length:  14
# New Orders left:  1320758
# making new cascade
#
#
# OG Orders left:  1320758
# Cascade length:  918
# New Orders left:  1319840
# making new cascade
#
#
# OG Orders left:  1319840
# Cascade length:  6
# New Orders left:  1319834
# making new cascade
#
#
# OG Orders left:  1319834
# Cascade length:  3
# New Orders left:  1319831
# making new cascade
#
#
# OG Orders left:  1319831
# Cascade length:  2
# New Orders left:  1319829
# making new cascade
#
#
# OG Orders left:  1319829
# Cascade length:  8
# New Orders left:  1319821
# making new cascade
#
#
# OG Orders left:  1319821
# Cascade length:  3
# New Orders left:  1319818
# making new cascade
#
#
# OG Orders left:  1319818
# Cascade length:  15
# New Orders left:  1319803
# making new cascade
#
#
# OG Orders left:  1319803
# Cascade length:  1
# New Orders left:  1319802
# making new cascade
#
#
# OG Orders left:  1319802
# Cascade length:  782
# New Orders left:  1319020
# making new cascade
#
#
# OG Orders left:  1319020
# Cascade length:  579
# New Orders left:  1318441
# making new cascade
#
#
# OG Orders left:  1318441
# Cascade length:  6
# New Orders left:  1318435
# making new cascade
#
#
# OG Orders left:  1318435
# Cascade length:  1
# New Orders left:  1318434
# making new cascade
#
#
# OG Orders left:  1318434
# Cascade length:  14
# New Orders left:  1318420
# making new cascade
#
#
# OG Orders left:  1318420
# Cascade length:  12
# New Orders left:  1318408
# making new cascade
#
#
# OG Orders left:  1318408
# Cascade length:  4
# New Orders left:  1318404
# making new cascade
#
#
# OG Orders left:  1318404
# Cascade length:  494
# New Orders left:  1317910
# making new cascade
#
#
# OG Orders left:  1317910
# Cascade length:  4
# New Orders left:  1317906
# making new cascade
#
#
# OG Orders left:  1317906
# Cascade length:  2
# New Orders left:  1317904
# making new cascade
#
#
# OG Orders left:  1317904
# Cascade length:  15
# New Orders left:  1317889
# making new cascade
#
#
# OG Orders left:  1317889
# Cascade length:  721
# New Orders left:  1317168
# making new cascade
#
#
# OG Orders left:  1317168
# Cascade length:  886
# New Orders left:  1316282
# making new cascade
#
#
# OG Orders left:  1316282
# Cascade length:  13
# New Orders left:  1316269
# making new cascade
#
#
# OG Orders left:  1316269
# Cascade length:  591
# New Orders left:  1315678
# making new cascade
#
#
# OG Orders left:  1315678
# Cascade length:  683
# New Orders left:  1314995
# making new cascade
#
#
# OG Orders left:  1314995
# Cascade length:  7
# New Orders left:  1314988
# making new cascade
#
#
# OG Orders left:  1314988
# Cascade length:  2
# New Orders left:  1314986
# making new cascade
#
#
# OG Orders left:  1314986
# Cascade length:  987
# New Orders left:  1313999
# making new cascade
#
#
# OG Orders left:  1313999
# Cascade length:  5
# New Orders left:  1313994
# making new cascade
#
#
# OG Orders left:  1313994
# Cascade length:  16
# New Orders left:  1313978
# making new cascade
#
#
# OG Orders left:  1313978
# Cascade length:  571
# New Orders left:  1313407
# making new cascade
#
#
# OG Orders left:  1313407
# Cascade length:  38
# New Orders left:  1313369
# making new cascade
#
#
# OG Orders left:  1313369
# Cascade length:  6
# New Orders left:  1313363
# making new cascade
#
#
# OG Orders left:  1313363
# Cascade length:  61
# New Orders left:  1313302
# making new cascade
#
#
# OG Orders left:  1313302
# Cascade length:  713
# New Orders left:  1312589
# making new cascade
#
#
# OG Orders left:  1312589
# Cascade length:  25
# New Orders left:  1312564
# making new cascade
#
#
# OG Orders left:  1312564
# Cascade length:  3
# New Orders left:  1312561
# making new cascade
#
#
# OG Orders left:  1312561
# Cascade length:  1
# New Orders left:  1312560
# making new cascade
#
#
# OG Orders left:  1312560
# Cascade length:  6
# New Orders left:  1312554
# making new cascade
#
#
# OG Orders left:  1312554
# Cascade length:  496
# New Orders left:  1312058
# making new cascade
#
#
# OG Orders left:  1312058
# Cascade length:  483
# New Orders left:  1311575
# making new cascade
#
#
# OG Orders left:  1311575
# Cascade length:  5
# New Orders left:  1311570
# making new cascade
#
#
# OG Orders left:  1311570
# Cascade length:  637
# New Orders left:  1310933
# making new cascade
#
#
# OG Orders left:  1310933
# Cascade length:  1
# New Orders left:  1310932
# making new cascade
#
#
# OG Orders left:  1310932
# Cascade length:  5
# New Orders left:  1310927
# making new cascade
#
#
# OG Orders left:  1310927
# Cascade length:  977
# New Orders left:  1309950
# making new cascade
#
#
# OG Orders left:  1309950
# Cascade length:  17
# New Orders left:  1309933
# making new cascade
#
#
# OG Orders left:  1309933
# Cascade length:  664
# New Orders left:  1309269
# making new cascade
#
#
# OG Orders left:  1309269
# Cascade length:  2
# New Orders left:  1309267
# making new cascade
#
#
# OG Orders left:  1309267
# Cascade length:  10
# New Orders left:  1309257
# making new cascade
#
#
# OG Orders left:  1309257
# Cascade length:  83
# New Orders left:  1309174
# making new cascade
#
#
# OG Orders left:  1309174
# Cascade length:  4
# New Orders left:  1309170
# making new cascade
#
#
# OG Orders left:  1309170
# Cascade length:  3
# New Orders left:  1309167
# making new cascade
#
#
# OG Orders left:  1309167
# Cascade length:  1
# New Orders left:  1309166
# making new cascade
#
#
# OG Orders left:  1309166
# Cascade length:  614
# New Orders left:  1308552
# making new cascade
#
#
# OG Orders left:  1308552
# Cascade length:  22
# New Orders left:  1308530
# making new cascade
#
#
# OG Orders left:  1308530
# Cascade length:  9
# New Orders left:  1308521
# making new cascade
#
#
# OG Orders left:  1308521
# Cascade length:  1007
# New Orders left:  1307514
# making new cascade
#
#
# OG Orders left:  1307514
# Cascade length:  4
# New Orders left:  1307510
# making new cascade
#
#
# OG Orders left:  1307510
# Cascade length:  384
# New Orders left:  1307126
# making new cascade
#
#
# OG Orders left:  1307126
# Cascade length:  268
# New Orders left:  1306858
# making new cascade
#
#
# OG Orders left:  1306858
# Cascade length:  2
# New Orders left:  1306856
# making new cascade
#
#
# OG Orders left:  1306856
# Cascade length:  2
# New Orders left:  1306854
# making new cascade
#
#
# OG Orders left:  1306854
# Cascade length:  698
# New Orders left:  1306156
# making new cascade
#
#
# OG Orders left:  1306156
# Cascade length:  12
# New Orders left:  1306144
# making new cascade
#
#
# OG Orders left:  1306144
# Cascade length:  202
# New Orders left:  1305942
# making new cascade
#
#
# OG Orders left:  1305942
# Cascade length:  523
# New Orders left:  1305419
# making new cascade
#
#
# OG Orders left:  1305419
# Cascade length:  1
# New Orders left:  1305418
# making new cascade
#
#
# OG Orders left:  1305418
# Cascade length:  2
# New Orders left:  1305416
# making new cascade
#
#
# OG Orders left:  1305416
# Cascade length:  2
# New Orders left:  1305414
# making new cascade
#
#
# OG Orders left:  1305414
# Cascade length:  499
# New Orders left:  1304915
# making new cascade
#
#
# OG Orders left:  1304915
# Cascade length:  522
# New Orders left:  1304393
# making new cascade
#
#
# OG Orders left:  1304393
# Cascade length:  1
# New Orders left:  1304392
# making new cascade
#
#
# OG Orders left:  1304392
# Cascade length:  15
# New Orders left:  1304377
# making new cascade
#
#
# OG Orders left:  1304377
# Cascade length:  14
# New Orders left:  1304363
# making new cascade
#
#
# OG Orders left:  1304363
# Cascade length:  1
# New Orders left:  1304362
# making new cascade
#
#
# OG Orders left:  1304362
# Cascade length:  1
# New Orders left:  1304361
# making new cascade
#
#
# OG Orders left:  1304361
# Cascade length:  7
# New Orders left:  1304354
# making new cascade
#
#
# OG Orders left:  1304354
# Cascade length:  48
# New Orders left:  1304306
# making new cascade
#
#
# OG Orders left:  1304306
# Cascade length:  404
# New Orders left:  1303902
# making new cascade
#
#
# OG Orders left:  1303902
# Cascade length:  2
# New Orders left:  1303900
# making new cascade
#
#
# OG Orders left:  1303900
# Cascade length:  23
# New Orders left:  1303877
# making new cascade
#
#
# OG Orders left:  1303877
# Cascade length:  21
# New Orders left:  1303856
# making new cascade
#
#
# OG Orders left:  1303856
# Cascade length:  12
# New Orders left:  1303844
# making new cascade
#
#
# OG Orders left:  1303844
# Cascade length:  569
# New Orders left:  1303275
# making new cascade
#
#
# OG Orders left:  1303275
# Cascade length:  471
# New Orders left:  1302804
# making new cascade
#
#
# OG Orders left:  1302804
# Cascade length:  431
# New Orders left:  1302373
# making new cascade
#
#
# OG Orders left:  1302373
# Cascade length:  7
# New Orders left:  1302366
# making new cascade
#
#
# OG Orders left:  1302366
# Cascade length:  20
# New Orders left:  1302346
# making new cascade
#
#
# OG Orders left:  1302346
# Cascade length:  537
# New Orders left:  1301809
# making new cascade
#
#
# OG Orders left:  1301809
# Cascade length:  2
# New Orders left:  1301807
# making new cascade
#
#
# OG Orders left:  1301807
# Cascade length:  462
# New Orders left:  1301345
# making new cascade
#
#
# OG Orders left:  1301345
# Cascade length:  3
# New Orders left:  1301342
# making new cascade
#
#
# OG Orders left:  1301342
# Cascade length:  6
# New Orders left:  1301336
# making new cascade
#
#
# OG Orders left:  1301336
# Cascade length:  309
# New Orders left:  1301027
# making new cascade
#
#
# OG Orders left:  1301027
# Cascade length:  404
# New Orders left:  1300623
# making new cascade
#
#
# OG Orders left:  1300623
# Cascade length:  31
# New Orders left:  1300592
# making new cascade
#
#
# OG Orders left:  1300592
# Cascade length:  3
# New Orders left:  1300589
# making new cascade
#
#
# OG Orders left:  1300589
# Cascade length:  14
# New Orders left:  1300575
# making new cascade
#
#
# OG Orders left:  1300575
# Cascade length:  1
# New Orders left:  1300574
# making new cascade
#
#
# OG Orders left:  1300574
# Cascade length:  2
# New Orders left:  1300572
# making new cascade
#
#
# OG Orders left:  1300572
# Cascade length:  1
# New Orders left:  1300571
# making new cascade
#
#
# OG Orders left:  1300571
# Cascade length:  444
# New Orders left:  1300127
# making new cascade
#
#
# OG Orders left:  1300127
# Cascade length:  1
# New Orders left:  1300126
# making new cascade
#
#
# OG Orders left:  1300126
# Cascade length:  2
# New Orders left:  1300124
# making new cascade
#
#
# OG Orders left:  1300124
# Cascade length:  1
# New Orders left:  1300123
# making new cascade
#
#
# OG Orders left:  1300123
# Cascade length:  407
# New Orders left:  1299716
# making new cascade
#
#
# OG Orders left:  1299716
# Cascade length:  14
# New Orders left:  1299702
# making new cascade
#
#
# OG Orders left:  1299702
# Cascade length:  4
# New Orders left:  1299698
# making new cascade
#
#
# OG Orders left:  1299698
# Cascade length:  408
# New Orders left:  1299290
# making new cascade
#
#
# OG Orders left:  1299290
# Cascade length:  16
# New Orders left:  1299274
# making new cascade
#
#
# OG Orders left:  1299274
# Cascade length:  4
# New Orders left:  1299270
# making new cascade
#
#
# OG Orders left:  1299270
# Cascade length:  320
# New Orders left:  1298950
# making new cascade
#
#
# OG Orders left:  1298950
# Cascade length:  89
# New Orders left:  1298861
# making new cascade
#
#
# OG Orders left:  1298861
# Cascade length:  386
# New Orders left:  1298475
# making new cascade
#
#
# OG Orders left:  1298475
# Cascade length:  22
# New Orders left:  1298453
# making new cascade
#
#
# OG Orders left:  1298453
# Cascade length:  2
# New Orders left:  1298451
# making new cascade
#
#
# OG Orders left:  1298451
# Cascade length:  2
# New Orders left:  1298449
# making new cascade
#
#
# OG Orders left:  1298449
# Cascade length:  493
# New Orders left:  1297956
# making new cascade
#
#
# OG Orders left:  1297956
# Cascade length:  388
# New Orders left:  1297568
# making new cascade
#
#
# OG Orders left:  1297568
# Cascade length:  1
# New Orders left:  1297567
# making new cascade
#
#
# OG Orders left:  1297567
# Cascade length:  2
# New Orders left:  1297565
# making new cascade
#
#
# OG Orders left:  1297565
# Cascade length:  620
# New Orders left:  1296945
# making new cascade
#
#
# OG Orders left:  1296945
# Cascade length:  14
# New Orders left:  1296931
# making new cascade
#
#
# OG Orders left:  1296931
# Cascade length:  3
# New Orders left:  1296928
# making new cascade
#
#
# OG Orders left:  1296928
# Cascade length:  230
# New Orders left:  1296698
# making new cascade
#
#
# OG Orders left:  1296698
# Cascade length:  354
# New Orders left:  1296344
# making new cascade
#
#
# OG Orders left:  1296344
# Cascade length:  402
# New Orders left:  1295942
# making new cascade
#
#
# OG Orders left:  1295942
# Cascade length:  15
# New Orders left:  1295927
# making new cascade
#
#
# OG Orders left:  1295927
# Cascade length:  5
# New Orders left:  1295922
# making new cascade
#
#
# OG Orders left:  1295922
# Cascade length:  545
# New Orders left:  1295377
# making new cascade
#
#
# OG Orders left:  1295377
# Cascade length:  1
# New Orders left:  1295376
# making new cascade
#
#
# OG Orders left:  1295376
# Cascade length:  6
# New Orders left:  1295370
# making new cascade
#
#
# OG Orders left:  1295370
# Cascade length:  231
# New Orders left:  1295139
# making new cascade
#
#
# OG Orders left:  1295139
# Cascade length:  3
# New Orders left:  1295136
# making new cascade
#
#
# OG Orders left:  1295136
# Cascade length:  11
# New Orders left:  1295125
# making new cascade
#
#
# OG Orders left:  1295125
# Cascade length:  12
# New Orders left:  1295113
# making new cascade
#
#
# OG Orders left:  1295113
# Cascade length:  579
# New Orders left:  1294534
# making new cascade
#
#
# OG Orders left:  1294534
# Cascade length:  2
# New Orders left:  1294532
# making new cascade
#
#
# OG Orders left:  1294532
# Cascade length:  491
# New Orders left:  1294041
# making new cascade
#
#
# OG Orders left:  1294041
# Cascade length:  3
# New Orders left:  1294038
# making new cascade
#
#
# OG Orders left:  1294038
# Cascade length:  2
# New Orders left:  1294036
# making new cascade
#
#
# OG Orders left:  1294036
# Cascade length:  11
# New Orders left:  1294025
# making new cascade
#
#
# OG Orders left:  1294025
# Cascade length:  8
# New Orders left:  1294017
# making new cascade
#
#
# OG Orders left:  1294017
# Cascade length:  2
# New Orders left:  1294015
# making new cascade
#
#
# OG Orders left:  1294015
# Cascade length:  1
# New Orders left:  1294014
# making new cascade
#
#
# OG Orders left:  1294014
# Cascade length:  434
# New Orders left:  1293580
# making new cascade
#
#
# OG Orders left:  1293580
# Cascade length:  7
# New Orders left:  1293573
# making new cascade
#
#
# OG Orders left:  1293573
# Cascade length:  10
# New Orders left:  1293563
# making new cascade
#
#
# OG Orders left:  1293563
# Cascade length:  488
# New Orders left:  1293075
# making new cascade
#
#
# OG Orders left:  1293075
# Cascade length:  2
# New Orders left:  1293073
# making new cascade
#
#
# OG Orders left:  1293073
# Cascade length:  10
# New Orders left:  1293063
# making new cascade
#
#
# OG Orders left:  1293063
# Cascade length:  1228
# New Orders left:  1291835
# making new cascade
#
#
# OG Orders left:  1291835
# Cascade length:  36
# New Orders left:  1291799
# making new cascade
#
#
# OG Orders left:  1291799
# Cascade length:  8
# New Orders left:  1291791
# making new cascade
#
#
# OG Orders left:  1291791
# Cascade length:  2
# New Orders left:  1291789
# making new cascade
#
#
# OG Orders left:  1291789
# Cascade length:  32
# New Orders left:  1291757
# making new cascade
#
#
# OG Orders left:  1291757
# Cascade length:  478
# New Orders left:  1291279
# making new cascade
#
#
# OG Orders left:  1291279
# Cascade length:  22
# New Orders left:  1291257
# making new cascade
#
#
# OG Orders left:  1291257
# Cascade length:  453
# New Orders left:  1290804
# making new cascade
#
#
# OG Orders left:  1290804
# Cascade length:  1
# New Orders left:  1290803
# making new cascade
#
#
# OG Orders left:  1290803
# Cascade length:  387
# New Orders left:  1290416
# making new cascade
#
#
# OG Orders left:  1290416
# Cascade length:  4
# New Orders left:  1290412
# making new cascade
#
#
# OG Orders left:  1290412
# Cascade length:  4
# New Orders left:  1290408
# making new cascade
#
#
# OG Orders left:  1290408
# Cascade length:  3
# New Orders left:  1290405
# making new cascade
#
#
# OG Orders left:  1290405
# Cascade length:  433
# New Orders left:  1289972
# making new cascade
#
#
# OG Orders left:  1289972
# Cascade length:  3
# New Orders left:  1289969
# making new cascade
#
#
# OG Orders left:  1289969
# Cascade length:  31
# New Orders left:  1289938
# making new cascade
#
#
# OG Orders left:  1289938
# Cascade length:  507
# New Orders left:  1289431
# making new cascade
#
#
# OG Orders left:  1289431
# Cascade length:  6
# New Orders left:  1289425
# making new cascade
#
#
# OG Orders left:  1289425
# Cascade length:  2
# New Orders left:  1289423
# making new cascade
#
#
# OG Orders left:  1289423
# Cascade length:  435
# New Orders left:  1288988
# making new cascade
#
#
# OG Orders left:  1288988
# Cascade length:  7
# New Orders left:  1288981
# making new cascade
#
#
# OG Orders left:  1288981
# Cascade length:  9
# New Orders left:  1288972
# making new cascade
#
#
# OG Orders left:  1288972
# Cascade length:  2
# New Orders left:  1288970
# making new cascade
#
#
# OG Orders left:  1288970
# Cascade length:  508
# New Orders left:  1288462
# making new cascade
#
#
# OG Orders left:  1288462
# Cascade length:  351
# New Orders left:  1288111
# making new cascade
#
#
# OG Orders left:  1288111
# Cascade length:  2
# New Orders left:  1288109
# making new cascade
#
#
# OG Orders left:  1288109
# Cascade length:  1
# New Orders left:  1288108
# making new cascade
#
#
# OG Orders left:  1288108
# Cascade length:  10
# New Orders left:  1288098
# making new cascade
#
#
# OG Orders left:  1288098
# Cascade length:  1
# New Orders left:  1288097
# making new cascade
#
#
# OG Orders left:  1288097
# Cascade length:  1
# New Orders left:  1288096
# making new cascade
#
#
# OG Orders left:  1288096
# Cascade length:  209
# New Orders left:  1287887
# making new cascade
#
#
# OG Orders left:  1287887
# Cascade length:  41
# New Orders left:  1287846
# making new cascade
#
#
# OG Orders left:  1287846
# Cascade length:  1
# New Orders left:  1287845
# making new cascade
#
#
# OG Orders left:  1287845
# Cascade length:  1
# New Orders left:  1287844
# making new cascade
#
#
# OG Orders left:  1287844
# Cascade length:  37
# New Orders left:  1287807
# making new cascade
#
#
# OG Orders left:  1287807
# Cascade length:  566
# New Orders left:  1287241
# making new cascade
#
#
# OG Orders left:  1287241
# Cascade length:  6
# New Orders left:  1287235
# making new cascade
#
#
# OG Orders left:  1287235
# Cascade length:  13
# New Orders left:  1287222
# making new cascade
#
#
# OG Orders left:  1287222
# Cascade length:  9
# New Orders left:  1287213
# making new cascade
#
#
# OG Orders left:  1287213
# Cascade length:  6
# New Orders left:  1287207
# making new cascade
#
#
# OG Orders left:  1287207
# Cascade length:  6
# New Orders left:  1287201
# making new cascade
#
#
# OG Orders left:  1287201
# Cascade length:  4
# New Orders left:  1287197
# making new cascade
#
#
# OG Orders left:  1287197
# Cascade length:  55
# New Orders left:  1287142
# making new cascade
#
#
# OG Orders left:  1287142
# Cascade length:  583
# New Orders left:  1286559
# making new cascade
#
#
# OG Orders left:  1286559
# Cascade length:  4
# New Orders left:  1286555
# making new cascade
#
#
# OG Orders left:  1286555
# Cascade length:  485
# New Orders left:  1286070
# making new cascade
#
#
# OG Orders left:  1286070
# Cascade length:  433
# New Orders left:  1285637
# making new cascade
#
#
# OG Orders left:  1285637
# Cascade length:  4
# New Orders left:  1285633
# making new cascade
#
#
# OG Orders left:  1285633
# Cascade length:  547
# New Orders left:  1285086
# making new cascade
#
#
# OG Orders left:  1285086
# Cascade length:  3
# New Orders left:  1285083
# making new cascade
#
#
# OG Orders left:  1285083
# Cascade length:  8
# New Orders left:  1285075
# making new cascade
#
#
# OG Orders left:  1285075
# Cascade length:  2
# New Orders left:  1285073
# making new cascade
#
#
# OG Orders left:  1285073
# Cascade length:  448
# New Orders left:  1284625
# making new cascade
#
#
# OG Orders left:  1284625
# Cascade length:  509
# New Orders left:  1284116
# making new cascade
#
#
# OG Orders left:  1284116
# Cascade length:  19
# New Orders left:  1284097
# making new cascade
#
#
# OG Orders left:  1284097
# Cascade length:  10
# New Orders left:  1284087
# making new cascade
#
#
# OG Orders left:  1284087
# Cascade length:  443
# New Orders left:  1283644
# making new cascade
#
#
# OG Orders left:  1283644
# Cascade length:  1
# New Orders left:  1283643
# making new cascade
#
#
# OG Orders left:  1283643
# Cascade length:  3
# New Orders left:  1283640
# making new cascade
#
#
# OG Orders left:  1283640
# Cascade length:  573
# New Orders left:  1283067
# making new cascade
#
#
# OG Orders left:  1283067
# Cascade length:  7
# New Orders left:  1283060
# making new cascade
#
#
# OG Orders left:  1283060
# Cascade length:  8
# New Orders left:  1283052
# making new cascade
#
#
# OG Orders left:  1283052
# Cascade length:  392
# New Orders left:  1282660
# making new cascade
#
#
# OG Orders left:  1282660
# Cascade length:  4
# New Orders left:  1282656
# making new cascade
#
#
# OG Orders left:  1282656
# Cascade length:  336
# New Orders left:  1282320
# making new cascade
#
#
# OG Orders left:  1282320
# Cascade length:  2
# New Orders left:  1282318
# making new cascade
#
#
# OG Orders left:  1282318
# Cascade length:  359
# New Orders left:  1281959
# making new cascade
#
#
# OG Orders left:  1281959
# Cascade length:  10
# New Orders left:  1281949
# making new cascade
#
#
# OG Orders left:  1281949
# Cascade length:  14
# New Orders left:  1281935
# making new cascade
#
#
# OG Orders left:  1281935
# Cascade length:  614
# New Orders left:  1281321
# making new cascade
#
#
# OG Orders left:  1281321
# Cascade length:  338
# New Orders left:  1280983
# making new cascade
#
#
# OG Orders left:  1280983
# Cascade length:  8
# New Orders left:  1280975
# making new cascade
#
#
# OG Orders left:  1280975
# Cascade length:  31
# New Orders left:  1280944
# making new cascade
#
#
# OG Orders left:  1280944
# Cascade length:  1
# New Orders left:  1280943
# making new cascade
#
#
# OG Orders left:  1280943
# Cascade length:  1
# New Orders left:  1280942
# making new cascade
#
#
# OG Orders left:  1280942
# Cascade length:  4
# New Orders left:  1280938
# making new cascade
#
#
# OG Orders left:  1280938
# Cascade length:  15
# New Orders left:  1280923
# making new cascade
#
#
# OG Orders left:  1280923
# Cascade length:  2
# New Orders left:  1280921
# making new cascade
#
#
# OG Orders left:  1280921
# Cascade length:  7
# New Orders left:  1280914
# making new cascade
#
#
# OG Orders left:  1280914
# Cascade length:  2
# New Orders left:  1280912
# making new cascade
#
#
# OG Orders left:  1280912
# Cascade length:  2
# New Orders left:  1280910
# making new cascade
#
#
# OG Orders left:  1280910
# Cascade length:  387
# New Orders left:  1280523
# making new cascade
#
#
# OG Orders left:  1280523
# ...
# making new cascade
#
#
# OG Orders left:  47077
# Cascade length:  19
# New Orders left:  47058
# making new cascade
#
#
# OG Orders left:  47058
# Cascade length:  668
# New Orders left:  46390
# making new cascade
#
#
# OG Orders left:  46390
# Cascade length:  5
# New Orders left:  46385
# making new cascade
#
#
# OG Orders left:  46385
# Cascade length:  876
# New Orders left:  45509
# making new cascade
#
#
# OG Orders left:  45509
# Cascade length:  5
# New Orders left:  45504
# making new cascade
#
#
# OG Orders left:  45504
# Cascade length:  23
# New Orders left:  45481
# making new cascade
#
#
# OG Orders left:  45481
# Cascade length:  2
# New Orders left:  45479
# making new cascade
#
#
# OG Orders left:  45479
# Cascade length:  9
# New Orders left:  45470
# making new cascade
#
#
# OG Orders left:  45470
# Cascade length:  2
# New Orders left:  45468
# making new cascade
#
#
# OG Orders left:  45468
# Cascade length:  682
# New Orders left:  44786
# making new cascade
#
#
# OG Orders left:  44786
# Cascade length:  1
# New Orders left:  44785
# making new cascade
#
#
# OG Orders left:  44785
# Cascade length:  6
# New Orders left:  44779
# making new cascade
#
#
# OG Orders left:  44779
# Cascade length:  484
# New Orders left:  44295
# making new cascade
#
#
# OG Orders left:  44295
# Cascade length:  2
# New Orders left:  44293
# making new cascade
#
#
# OG Orders left:  44293
# Cascade length:  4
# New Orders left:  44289
# making new cascade
#
#
# OG Orders left:  44289
# Cascade length:  554
# New Orders left:  43735
# making new cascade
#
#
# OG Orders left:  43735
# Cascade length:  8
# New Orders left:  43727
# making new cascade
#
#
# OG Orders left:  43727
# Cascade length:  966
# New Orders left:  42761
# making new cascade
#
#
# OG Orders left:  42761
# Cascade length:  18
# New Orders left:  42743
# making new cascade
#
#
# OG Orders left:  42743
# Cascade length:  23
# New Orders left:  42720
# making new cascade
#
#
# OG Orders left:  42720
# Cascade length:  366
# New Orders left:  42354
# making new cascade
#
#
# OG Orders left:  42354
# Cascade length:  57
# New Orders left:  42297
# making new cascade
#
#
# OG Orders left:  42297
# Cascade length:  4
# New Orders left:  42293
# making new cascade
#
#
# OG Orders left:  42293
# Cascade length:  490
# New Orders left:  41803
# making new cascade
#
#
# OG Orders left:  41803
# Cascade length:  7
# New Orders left:  41796
# making new cascade
#
#
# OG Orders left:  41796
# Cascade length:  478
# New Orders left:  41318
# making new cascade
#
#
# OG Orders left:  41318
# Cascade length:  445
# New Orders left:  40873
# making new cascade
#
#
# OG Orders left:  40873
# Cascade length:  7
# New Orders left:  40866
# making new cascade
#
#
# OG Orders left:  40866
# Cascade length:  3
# New Orders left:  40863
# making new cascade
#
#
# OG Orders left:  40863
# Cascade length:  450
# New Orders left:  40413
# making new cascade
#
#
# OG Orders left:  40413
# Cascade length:  820
# New Orders left:  39593
# making new cascade
#
#
# OG Orders left:  39593
# Cascade length:  14
# New Orders left:  39579
# making new cascade
#
#
# OG Orders left:  39579
# Cascade length:  1
# New Orders left:  39578
# making new cascade
#
#
# OG Orders left:  39578
# Cascade length:  5
# New Orders left:  39573
# making new cascade
#
#
# OG Orders left:  39573
# Cascade length:  679
# New Orders left:  38894
# making new cascade
#
#
# OG Orders left:  38894
# Cascade length:  21
# New Orders left:  38873
# making new cascade
#
#
# OG Orders left:  38873
# Cascade length:  1
# New Orders left:  38872
# making new cascade
#
#
# OG Orders left:  38872
# Cascade length:  1
# New Orders left:  38871
# making new cascade
#
#
# OG Orders left:  38871
# Cascade length:  563
# New Orders left:  38308
# making new cascade
#
#
# OG Orders left:  38308
# Cascade length:  2
# New Orders left:  38306
# making new cascade
#
#
# OG Orders left:  38306
# Cascade length:  586
# New Orders left:  37720
# making new cascade
#
#
# OG Orders left:  37720
# Cascade length:  4
# New Orders left:  37716
# making new cascade
#
#
# OG Orders left:  37716
# Cascade length:  3
# New Orders left:  37713
# making new cascade
#
#
# OG Orders left:  37713
# Cascade length:  776
# New Orders left:  36937
# making new cascade
#
#
# OG Orders left:  36937
# Cascade length:  4
# New Orders left:  36933
# making new cascade
#
#
# OG Orders left:  36933
# Cascade length:  29
# New Orders left:  36904
# making new cascade
#
#
# OG Orders left:  36904
# Cascade length:  655
# New Orders left:  36249
# making new cascade
#
#
# OG Orders left:  36249
# Cascade length:  3
# New Orders left:  36246
# making new cascade
#
#
# OG Orders left:  36246
# Cascade length:  10
# New Orders left:  36236
# making new cascade
#
#
# OG Orders left:  36236
# Cascade length:  3
# New Orders left:  36233
# making new cascade
#
#
# OG Orders left:  36233
# Cascade length:  817
# New Orders left:  35416
# making new cascade
#
#
# OG Orders left:  35416
# Cascade length:  573
# New Orders left:  34843
# making new cascade
#
#
# OG Orders left:  34843
# Cascade length:  470
# New Orders left:  34373
# making new cascade
#
#
# OG Orders left:  34373
# Cascade length:  8
# New Orders left:  34365
# making new cascade
#
#
# OG Orders left:  34365
# Cascade length:  8
# New Orders left:  34357
# making new cascade
#
#
# OG Orders left:  34357
# Cascade length:  1024
# New Orders left:  33333
# making new cascade
#
#
# OG Orders left:  33333
# Cascade length:  1
# New Orders left:  33332
# making new cascade
#
#
# OG Orders left:  33332
# Cascade length:  10
# New Orders left:  33322
# making new cascade
#
#
# OG Orders left:  33322
# Cascade length:  1031
# New Orders left:  32291
# making new cascade
#
#
# OG Orders left:  32291
# Cascade length:  647
# New Orders left:  31644
# making new cascade
#
#
# OG Orders left:  31644
# Cascade length:  1
# New Orders left:  31643
# making new cascade
#
#
# OG Orders left:  31643
# Cascade length:  16
# New Orders left:  31627
# making new cascade
#
#
# OG Orders left:  31627
# Cascade length:  4
# New Orders left:  31623
# making new cascade
#
#
# OG Orders left:  31623
# Cascade length:  323
# New Orders left:  31300
# making new cascade
#
#
# OG Orders left:  31300
# Cascade length:  493
# New Orders left:  30807
# making new cascade
#
#
# OG Orders left:  30807
# Cascade length:  699
# New Orders left:  30108
# making new cascade
#
#
# OG Orders left:  30108
# Cascade length:  33
# New Orders left:  30075
# making new cascade
#
#
# OG Orders left:  30075
# Cascade length:  3
# New Orders left:  30072
# making new cascade
#
#
# OG Orders left:  30072
# Cascade length:  444
# New Orders left:  29628
# making new cascade
#
#
# OG Orders left:  29628
# Cascade length:  2
# New Orders left:  29626
# making new cascade
#
#
# OG Orders left:  29626
# Cascade length:  535
# New Orders left:  29091
# making new cascade
#
#
# OG Orders left:  29091
# Cascade length:  575
# New Orders left:  28516
# making new cascade
#
#
# OG Orders left:  28516
# Cascade length:  2
# New Orders left:  28514
# making new cascade
#
#
# OG Orders left:  28514
# Cascade length:  620
# New Orders left:  27894
# making new cascade
#
#
# OG Orders left:  27894
# Cascade length:  2
# New Orders left:  27892
# making new cascade
#
#
# OG Orders left:  27892
# Cascade length:  569
# New Orders left:  27323
# making new cascade
#
#
# OG Orders left:  27323
# Cascade length:  1
# New Orders left:  27322
# making new cascade
#
#
# OG Orders left:  27322
# Cascade length:  696
# New Orders left:  26626
# making new cascade
#
#
# OG Orders left:  26626
# Cascade length:  1330
# New Orders left:  25296
# making new cascade
#
#
# OG Orders left:  25296
# Cascade length:  1
# New Orders left:  25295
# making new cascade
#
#
# OG Orders left:  25295
# Cascade length:  658
# New Orders left:  24637
# making new cascade
#
#
# OG Orders left:  24637
# Cascade length:  284
# New Orders left:  24353
# making new cascade
#
#
# OG Orders left:  24353
# Cascade length:  7
# New Orders left:  24346
# making new cascade
#
#
# OG Orders left:  24346
# Cascade length:  27
# New Orders left:  24319
# making new cascade
#
#
# OG Orders left:  24319
# Cascade length:  502
# New Orders left:  23817
# making new cascade
#
#
# OG Orders left:  23817
# Cascade length:  634
# New Orders left:  23183
# making new cascade
#
#
# OG Orders left:  23183
# Cascade length:  574
# New Orders left:  22609
# making new cascade
#
#
# OG Orders left:  22609
# Cascade length:  2
# New Orders left:  22607
# making new cascade
#
#
# OG Orders left:  22607
# Cascade length:  1066
# New Orders left:  21541
# making new cascade
#
#
# OG Orders left:  21541
# Cascade length:  1169
# New Orders left:  20372
# making new cascade
#
#
# OG Orders left:  20372
# Cascade length:  109
# New Orders left:  20263
# making new cascade
#
#
# OG Orders left:  20263
# Cascade length:  4
# New Orders left:  20259
# making new cascade
#
#
# OG Orders left:  20259
# Cascade length:  1
# New Orders left:  20258
# making new cascade
#
#
# OG Orders left:  20258
# Cascade length:  467
# New Orders left:  19791
# making new cascade
#
#
# OG Orders left:  19791
# Cascade length:  596
# New Orders left:  19195
# making new cascade
#
#
# OG Orders left:  19195
# Cascade length:  2
# New Orders left:  19193
# making new cascade
#
#
# OG Orders left:  19193
# Cascade length:  459
# New Orders left:  18734
# making new cascade
#
#
# OG Orders left:  18734
# Cascade length:  34
# New Orders left:  18700
# making new cascade
#
#
# OG Orders left:  18700
# Cascade length:  431
# New Orders left:  18269
# making new cascade
#
#
# OG Orders left:  18269
# Cascade length:  2
# New Orders left:  18267
# making new cascade
#
#
# OG Orders left:  18267
# Cascade length:  946
# New Orders left:  17321
# making new cascade
#
#
# OG Orders left:  17321
# Cascade length:  15
# New Orders left:  17306
# making new cascade
#
#
# OG Orders left:  17306
# Cascade length:  512
# New Orders left:  16794
# making new cascade
#
#
# OG Orders left:  16794
# Cascade length:  3
# New Orders left:  16791
# making new cascade
#
#
# OG Orders left:  16791
# Cascade length:  1
# New Orders left:  16790
# making new cascade
#
#
# OG Orders left:  16790
# Cascade length:  110
# New Orders left:  16680
# making new cascade
#
#
# OG Orders left:  16680
# Cascade length:  909
# New Orders left:  15771
# making new cascade
#
#
# OG Orders left:  15771
# Cascade length:  590
# New Orders left:  15181
# making new cascade
#
#
# OG Orders left:  15181
# Cascade length:  6
# New Orders left:  15175
# making new cascade
#
#
# OG Orders left:  15175
# Cascade length:  18
# New Orders left:  15157
# making new cascade
#
#
# OG Orders left:  15157
# Cascade length:  599
# New Orders left:  14558
# making new cascade
#
#
# OG Orders left:  14558
# Cascade length:  1
# New Orders left:  14557
# making new cascade
#
#
# OG Orders left:  14557
# Cascade length:  5
# New Orders left:  14552
# making new cascade
#
#
# OG Orders left:  14552
# Cascade length:  679
# New Orders left:  13873
# making new cascade
#
#
# OG Orders left:  13873
# Cascade length:  4
# New Orders left:  13869
# making new cascade
#
#
# OG Orders left:  13869
# Cascade length:  1
# New Orders left:  13868
# making new cascade
#
#
# OG Orders left:  13868
# Cascade length:  934
# New Orders left:  12934
# making new cascade
#
#
# OG Orders left:  12934
# Cascade length:  665
# New Orders left:  12269
# making new cascade
#
#
# OG Orders left:  12269
# Cascade length:  8
# New Orders left:  12261
# making new cascade
#
#
# OG Orders left:  12261
# Cascade length:  937
# New Orders left:  11324
# making new cascade
#
#
# OG Orders left:  11324
# Cascade length:  5
# New Orders left:  11319
# making new cascade
#
#
# OG Orders left:  11319
# Cascade length:  16
# New Orders left:  11303
# making new cascade
#
#
# OG Orders left:  11303
# Cascade length:  78
# New Orders left:  11225
# making new cascade
#
#
# OG Orders left:  11225
# Cascade length:  1
# New Orders left:  11224
# making new cascade
#
#
# OG Orders left:  11224
# Cascade length:  435
# New Orders left:  10789
# making new cascade
#
#
# OG Orders left:  10789
# Cascade length:  4
# New Orders left:  10785
# making new cascade
#
#
# OG Orders left:  10785
# Cascade length:  299
# New Orders left:  10486
# making new cascade
#
#
# OG Orders left:  10486
# Cascade length:  704
# New Orders left:  9782
# making new cascade
#
#
# OG Orders left:  9782
# Cascade length:  455
# New Orders left:  9327
# making new cascade
#
#
# OG Orders left:  9327
# Cascade length:  69
# New Orders left:  9258
# making new cascade
#
#
# OG Orders left:  9258
# Cascade length:  36
# New Orders left:  9222
# making new cascade
#
#
# OG Orders left:  9222
# Cascade length:  1
# New Orders left:  9221
# making new cascade
#
#
# OG Orders left:  9221
# Cascade length:  454
# New Orders left:  8767
# making new cascade
#
#
# OG Orders left:  8767
# Cascade length:  12
# New Orders left:  8755
# making new cascade
#
#
# OG Orders left:  8755
# Cascade length:  603
# New Orders left:  8152
# making new cascade
#
#
# OG Orders left:  8152
# Cascade length:  447
# New Orders left:  7705
# making new cascade
#
#
# OG Orders left:  7705
# Cascade length:  55
# New Orders left:  7650
# making new cascade
#
#
# OG Orders left:  7650
# Cascade length:  660
# New Orders left:  6990
# making new cascade
#
#
# OG Orders left:  6990
# Cascade length:  9
# New Orders left:  6981
# making new cascade
#
#
# OG Orders left:  6981
# Cascade length:  29
# New Orders left:  6952
# making new cascade
#
#
# OG Orders left:  6952
# Cascade length:  716
# New Orders left:  6236
# making new cascade
#
#
# OG Orders left:  6236
# Cascade length:  3
# New Orders left:  6233
# making new cascade
#
#
# OG Orders left:  6233
# Cascade length:  12
# New Orders left:  6221
# making new cascade
#
#
# OG Orders left:  6221
# Cascade length:  463
# New Orders left:  5758
# making new cascade
#
#
# OG Orders left:  5758
# Cascade length:  10
# New Orders left:  5748
# making new cascade
#
#
# OG Orders left:  5748
# Cascade length:  98
# New Orders left:  5650
# making new cascade
#
#
# OG Orders left:  5650
# Cascade length:  19
# New Orders left:  5631
# making new cascade
#
#
# OG Orders left:  5631
# Cascade length:  42
# New Orders left:  5589
# making new cascade
#
#
# OG Orders left:  5589
# Cascade length:  2
# New Orders left:  5587
# making new cascade
#
#
# OG Orders left:  5587
# Cascade length:  431
# New Orders left:  5156
# making new cascade
#
#
# OG Orders left:  5156
# Cascade length:  526
# New Orders left:  4630
# making new cascade
#
#
# OG Orders left:  4630
# Cascade length:  5
# New Orders left:  4625
# making new cascade
#
#
# OG Orders left:  4625
# Cascade length:  1
# New Orders left:  4624
# making new cascade
#
#
# OG Orders left:  4624
# Cascade length:  381
# New Orders left:  4243
# making new cascade
#
#
# OG Orders left:  4243
# Cascade length:  18
# New Orders left:  4225
# making new cascade
#
#
# OG Orders left:  4225
# Cascade length:  607
# New Orders left:  3618
# making new cascade
#
#
# OG Orders left:  3618
# Cascade length:  219
# New Orders left:  3399
# making new cascade
#
#
# OG Orders left:  3399
# Cascade length:  188
# New Orders left:  3211
# making new cascade
#
#
# OG Orders left:  3211
# Cascade length:  94
# New Orders left:  3117
# making new cascade
#
#
# OG Orders left:  3117
# Cascade length:  162
# New Orders left:  2955
# making new cascade
#
#
# OG Orders left:  2955
# Cascade length:  242
# New Orders left:  2713
# making new cascade
#
#
# OG Orders left:  2713
# Cascade length:  37
# New Orders left:  2676
# making new cascade
#
#
# OG Orders left:  2676
# Cascade length:  20
# New Orders left:  2656
# making new cascade
#
#
# OG Orders left:  2656
# Cascade length:  3
# New Orders left:  2653
# making new cascade
#
#
# OG Orders left:  2653
# Cascade length:  446
# New Orders left:  2207
# making new cascade
#
#
# OG Orders left:  2207
# Cascade length:  275
# New Orders left:  1932
# making new cascade
#
#
# OG Orders left:  1932
# Cascade length:  201
# New Orders left:  1731
# making new cascade
#
#
# OG Orders left:  1731
# Cascade length:  251
# New Orders left:  1480
# making new cascade
#
#
# OG Orders left:  1480
# Cascade length:  39
# New Orders left:  1441
# making new cascade
#
#
# OG Orders left:  1441
# Cascade length:  319
# New Orders left:  1122
# making new cascade
#
#
# OG Orders left:  1122
# Cascade length:  233
# New Orders left:  889
# making new cascade
#
#
# OG Orders left:  889
# Cascade length:  232
# New Orders left:  657
# making new cascade
#
#
# OG Orders left:  657
# Cascade length:  189
# New Orders left:  468
# making new cascade
#
#
# OG Orders left:  468
# Cascade length:  21
# New Orders left:  447
# making new cascade
#
#
# OG Orders left:  447
# Cascade length:  177
# New Orders left:  270
# making new cascade
#
#
# OG Orders left:  270
# Cascade length:  132
# New Orders left:  138
# making new cascade
#
#
# OG Orders left:  138
# Cascade length:  18
# New Orders left:  120
# making new cascade
#
#
# OG Orders left:  120
# Cascade length:  34
# New Orders left:  86
# making new cascade
#
#
# OG Orders left:  86
# Cascade length:  42
# New Orders left:  44
# making new cascade
#
#
# OG Orders left:  44
# Cascade length:  9
# New Orders left:  35
# making new cascade
#
#
# OG Orders left:  35
# Cascade length:  13
# New Orders left:  22
# making new cascade
#
#
# OG Orders left:  22
# Cascade length:  16
# New Orders left:  6
# making new cascade
#
#
# OG Orders left:  6
# Cascade length:  6
# New Orders left:  0
# making new cascade

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*3, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)/10, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*3, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35), '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2), '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*6, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.3)*5, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.3)*2, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*5, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.4), '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
