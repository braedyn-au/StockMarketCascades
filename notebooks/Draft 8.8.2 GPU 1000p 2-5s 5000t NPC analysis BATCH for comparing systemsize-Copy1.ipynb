# %%
import cupy as np
import cudf as pd
import matplotlib.pyplot as plt
import pickle
from library import utils, config, cascades

# %%
with open('./results/nopricechange/7-9/traderIDs_1000_5000_100_2_5.pkl', 'rb') as f:
    traderIDsNPC = pickle.load(f)
# Out:
# Importing MATLAB

# %%
stockPoolNPC = np.load("./results/nopricechange/7-9/stockPool_1000_5000_100_2_5.npy")
hurstPoolNPC = np.load("./results/nopricechange/7-9/hurstPool_1000_5000_100_2_5.npy")
# TtransactionsNPC = pd.read_csv("./results/nopricechange/7-9/transactions_200_7200_100_2_5.csv")
TtotalOrdersNPC = pd.read_csv("./results/nopricechange/7-9/totalOrders_1000_5000_100_2_5.csv")

# %%
TtotalOrdersNPC
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 0                 0   993     sniel     86    1.0
# 1                 0   993     yeqal     83   -1.0
# 2                 2   993     yeqal     85    2.0
# 3                 0   993     tcnoe     73    3.0
# 4                 1   993     tcnoe     74   -3.0
# ...             ...   ...       ...    ...    ...
# 2136648           2  5992     lekvh     62   16.0
# 2136649           0  5992     uesjc     42    5.0
# 2136650           3  5992     uesjc     50   -7.0
# 2136651           1  5992     vuemj     58    7.0
# 2136652           2  5992     vuemj     89   -3.0
#
# [2136653 rows x 5 columns]

# %%
type(TtotalOrdersNPC)
# Out:
# cudf.core.dataframe.DataFrame

# %% [markdown]
# # minSep = 1

# %%
sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-8eb6452f45de> in <module>
# ----> 1 sizes1, nrows1, duration1 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192,1)
#
# ~/Documents/singapore/library/cascades.py in stockOrderCascadeAnalyzer(Ttotalorders, stockPool, t0, tf, minSep)
#     225     cascades = {}
#     226     for stock in range(len(stockPool)):
# --> 227         cascades = findStockOrderCascades(Ttotalorders[Ttotalorders['stock']==stock], cascades = cascades, minSep = minSep)
#     228
#     229     sizes, nrows, duration = cascadeAnalyzer(cascades, stockPool, t0=t0, tf=tf)
#
# ~/Documents/singapore/library/cascades.py in findStockOrderCascades(stockOrders, cascades, minSep)
#     143         ToS = stockOrders['time'].unique()
#     144         sep = np.diff(ToS)
# --> 145         keySep = np.where(sep>minSep)[0]
#     146         i0 = 0
#     147
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/series.py in __array_function__(self, func, types, args, kwargs)
#     811                 return NotImplemented
#     812             else:
# --> 813                 return cudf_func(*args, **kwargs)
#     814
#     815         else:
#
# TypeError: where() missing 1 required positional argument: 'cond'

# %%
hist, bins = np.histogram(nrows1, bins=np.logspace(np.log10(min(nrows1)),np.log10(max(nrows1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2), '-.', label= "$x^{-1..2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes1, bins=np.logspace(np.log10(min(sizes1)),np.log10(max(sizes1)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*8, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration1, bins=np.logspace(np.log10(min(duration1)),np.log10(max(duration1)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration1),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.4)*5, '-.', label= "$x^{-1.4}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep1_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 2

# %%
sizes2, nrows2, duration2 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 2)

# %%
hist, bins = np.histogram(nrows2, bins=np.logspace(np.log10(min(nrows2)),np.log10(max(nrows2)),18))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.15), '-.', label= "$x^{-1.15}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes2, bins=np.logspace(np.log10(min(sizes2)),np.log10(max(sizes2)),17))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration2, bins=np.logspace(np.log10(min(duration2)),np.log10(max(duration2)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration2),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*8, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep2_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 5

# %%
sizes5, nrows5, duration5 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 5)

# %%
hist, bins = np.histogram(nrows5, bins=np.logspace(np.log10(min(nrows5)),np.log10(max(nrows5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.0)*5, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes5, bins=np.logspace(np.log10(min(sizes5)),np.log10(max(sizes5)),14))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.2)*4, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 5")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_vol_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration5, bins=np.logspace(np.log10(min(duration5)),np.log10(max(duration5)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration5),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.55)*6, '-.', label= "$x^{-1.55}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 5")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep5_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # minSep = 10

# %%
sizes10, nrows10, duration10 = cascades.stockOrderCascadeAnalyzer(TtotalOrdersNPC, stockPoolNPC, 993, 8192, 10)

# %%
hist, bins = np.histogram(nrows10, bins=np.logspace(np.log10(min(nrows10)),np.log10(max(nrows10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(nrows10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (ntrans) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_ntrans_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(sizes10, bins=np.logspace(np.log10(min(sizes10)),np.log10(max(sizes10)),20))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(sizes10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (volume) | Min Down Time: 10")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_volume_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %%
hist, bins = np.histogram(duration10, bins=np.logspace(np.log10(min(duration10)),np.log10(max(duration10)),15))
binsize = np.diff(bins)

mid = np.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = np.append(mid,avg)

plt.plot(mid,np.divide(hist,binsize)/len(duration10),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,np.power(mid,-1.3)*7, '-.', label= "$x^{-1.3}$")
plt.loglog()
plt.legend()
plt.title("NPC Individual Stock Cascade (duration) | Min Down Time: 10")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/stockcascadesize_duration_npc100_7200_100_new2threshold_fixedhurst_minSep10_.png", dpi=250)
plt.show()
plt.close()

# %% [markdown]
# # Causal Cascades

# %%
def findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep):
    """
    find causal cascades USING GPU
    conda activate rapids-0.16
    """

    TtotalOrders = TtotalOrdersNPC
    cascades = {}
    numCascade = 0
    while len(TtotalOrders) > 0:
        print("OG Orders left: ", len(TtotalOrders))
        
        # Seed portfolio to begin the cascade
        seed = TtotalOrders['portfolio'].loc[0]
        t0 = TtotalOrders['time'].loc[0]
        seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
        cascades[numCascade] = seedCascade

        # Dictionary keeping track of how long a stock is still "affected" from previous trade
        stockTimes = {}

        for row in np.asarray(seedCascade.index):
            row = row.item()
            stock = seedCascade['stock'].loc[row]
            time = seedCascade['time'].loc[row]
            order = seedCascade['order'].loc[row]
            if stock in stockTimes:
                stockTimes[stock] += abs(order)*maxtimeeff
            else:
                stockTimes[stock] = time + abs(order)*maxtimeeff

        # check first cascade is greater than 0
        assert len(seedCascade) > 0

        # remove rows included in first cascade from the order list
        TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)

        #PT2 Portfolio perspective
        for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
            match = False
             # see if the current portfolio has overlapping stocks with the ongoing cascade 
            if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
                 # check if overlapping portfolio is already included in the ongoing cascade
                if childPortf not in cascades[numCascade]['portfolio']:
                     # include new portfolio into the cascade along with all of its cascading trading activity
                    childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
                     # check if trading activity falls into the time affect window of ongoing cascade
                    for row in np.asarray(childPortfCascade.index):
                        row = row.item()
                        stock = childPortfCascade['stock'].loc[row]
                        time = childPortfCascade['time'].loc[row]
                        order = childPortfCascade['order'].loc[row]
                        if stock in stockTimes:
                            if time <= stockTimes[stock]:
                                match = True
                                break 
                                
                    if match == True:        
                         # add new cascade to the ongoing cascade and remove rows from the orderList
                        cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
                        TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
                        
                         # add new stocks and their time affects, or extend time affects of previous stocks
                        for row in np.asarray(childPortfCascade.index):
                            row = row.item()
                            stock = childPortfCascade['stock'].loc[row]
                            time = childPortfCascade['time'].loc[row]
                            order = childPortfCascade['order'].loc[row]
                            if stock in stockTimes:
                                stockTimes[stock] += abs(order)*maxtimeeff
                            else:
                                stockTimes[stock] = time + abs(order)*maxtimeeff

        print("Cascade length: ",len(cascades[numCascade]))
        print("New Orders left: ", len(TtotalOrders))
        print("making new cascade")
        print("\n")
        numCascade += 1
        TtotalOrders.reset_index(drop = True, inplace=True)
        
    return cascades

def cascadeAnalyzerGPU(cascades, stockPool, t0 , tf):
    """
    returns arrays of general cascade sizes (value), nrows, and duration for histogramming
    CALL FINDCASCADES FIRST FOR CAUSAL CASCADES
    """
    sizes = np.array([])
    nrows = np.array([])
    duration = np.array([])
    numCascade = len(cascades)
    for i in range(numCascade):
        casc = cascades[i]
        if casc['time'].min() > t0 and casc['time'].max() < tf:
            size = 0
            for row in range(len(casc)):
                time = (casc['time'].iloc[row])
                stock = (casc['stock'].iloc[row])
                volume = (casc['order'].iloc[row])
                size += stockPool[stock][time]*abs(volume)
            dur = casc['time'].max()-casc['time'].min()
            if dur == 0:
                dur = 1
            duration = np.concatenate((duration, np.array([int(dur)])))
            sizes = np.concatenate((sizes, np.array([int(size)])))
            nrows = np.concatenate((nrows, np.array([int(len(casc))])))
        # else:
            # print('passed cascade '+ str(i) + ' of size ' + str(len(cascades[i])))
            
    return sizes, nrows, duration

def findPortfOrderCascadeGPU(TtotalOrders, portf, t0, maxSep = 1):
    """
    finds all subsequent activity traded by a portfolio (time threshold) (1 cascade only)
    input TtotalOrders, the portfolio, and minimum time
    Using Portf cascade is more logical than stock cascade
    FOR REAL CASCADES Aug18
    """

    portfOrders = TtotalOrders[TtotalOrders['portfolio']==portf]
    portfOrders = portfOrders[portfOrders['time']>=t0]

    if len(portfOrders)>0:
        ToS = portfOrders['time'].unique()
        sep = np.diff(ToS)
        keySep = np.where(sep>maxSep)[0]
        if len(keySep)>0:
            endtime = int(ToS.take(int(keySep[0]))) #end of this cascade

        else:
            endtime = int(ToS.take(-1))

        portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
        return portfCascade
    
    else:
        return pd.DataFrame()

#Potential faster code?
# stockTimes = Dict.empty(key_type=types.uint64, value_type=types.uint64)
# # global stockTimes
# def stockTimer(stock,time, order, out1, maxtimeeff):
#     for i, (s,t,o) in enumerate(zip(stock,time,order)):
#         out1[i] = t + abs(o*maxtimeeff)
#         if s not in stockTimes:
#             stockTimes[int(s)] = int(t + abs(o)*maxtimeeff)
#         else:
#             stockTimes[int(s)] += int(abs(o)*maxtimeeff)
# seedCascade = seedCascade.apply_rows(stockTimer, 
#                        incols=['stock', 'time', 'order'],
#                        outcols=dict(out1=np.int64),
#                        kwargs=dict(maxtimeeff=2))

# %%
causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades22_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2136653
# Cascade length:  5629
# New Orders left:  2131024
# making new cascade
#
#
# OG Orders left:  2131024
# Cascade length:  5282
# New Orders left:  2125742
# making new cascade
#
#
# OG Orders left:  2125742
# Cascade length:  4954
# New Orders left:  2120788
# making new cascade
#
#
# OG Orders left:  2120788
# Cascade length:  3791
# New Orders left:  2116997
# making new cascade
#
#
# OG Orders left:  2116997
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e9bfa8d439f1> in <module>
# ----> 1 causalCascades22 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 2)
#       2 npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=5992)
#       3 with open('../causalCascades/7-9/causalCascades22_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
#       4     pickle.dump(causalCascades22, handle, protocol=pickle.HIGHEST_PROTOCOL)
#
# <ipython-input-6-2da9571d3e2e> in findCascadesGPU(TtotalOrders, traderIDs, maxtimeeff, maxSep)
#      64                         for row in np.asarray(childPortfCascade.index):
#      65                             row = row.item()
# ---> 66                             stock = childPortfCascade['stock'].loc[row]
#      67                             time = childPortfCascade['time'].loc[row]
#      68                             order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     414         replaced = self.copy()
#     415         to_replace_col, replacement_col, replaced = numeric_normalize_types(
# --> 416             to_replace_col, replacement_col, replaced
#     417         )
#     418         return libcudf.replace.replace(
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in numeric_normalize_types(*args)
#     104     """
#     105     dtype = np.result_type(*[a.dtype for a in args])
# --> 106     return [a.astype(dtype) for a in args]
#     107
#     108
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in <listcomp>(.0)
#     104     """
#     105     dtype = np.result_type(*[a.dtype for a in args])
# --> 106     return [a.astype(dtype) for a in args]
#     107
#     108
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in astype(self, dtype, **kwargs)
#     979         }:
#     980             return self.as_string_column(dtype, **kwargs)
# --> 981         elif is_list_dtype(dtype):
#     982             if not self.dtype == dtype:
#     983                 raise NotImplementedError(
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_list_dtype(obj)
#     187         or type(obj) is cudf.core.column.ListColumn
#     188         or obj is cudf.core.column.ListColumn
# --> 189         or (isinstance(obj, str) and obj == cudf.core.dtypes.ListDtype.name)
#     190         or (hasattr(obj, "dtype") and is_list_dtype(obj.dtype))
#     191     )
#
# KeyboardInterrupt:

# %%
causalCascades21 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 2, maxSep = 1)
npcsizes21, npcnrows21, npcduration21 = cascadeAnalyzerGPU(causalCascades21, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades21_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades21, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# OG Orders left:  2136653
# Cascade length:  2798
# New Orders left:  2133855
# making new cascade
#
#
# OG Orders left:  2133855
# Cascade length:  2795
# New Orders left:  2131060
# making new cascade
#
#
# OG Orders left:  2131060
# Cascade length:  2588
# New Orders left:  2128472
# making new cascade
#
#
# OG Orders left:  2128472
# Cascade length:  2489
# New Orders left:  2125983
# making new cascade
#
#
# OG Orders left:  2125983
# Cascade length:  2456
# New Orders left:  2123527
# making new cascade
#
#
# OG Orders left:  2123527
# Cascade length:  1
# New Orders left:  2123526
# making new cascade
#
#
# OG Orders left:  2123526
# Cascade length:  2643
# New Orders left:  2120883
# making new cascade
#
#
# OG Orders left:  2120883
# Cascade length:  2123
# New Orders left:  2118760
# making new cascade
#
#
# OG Orders left:  2118760
# Cascade length:  2056
# New Orders left:  2116704
# making new cascade
#
#
# OG Orders left:  2116704
# Cascade length:  4
# New Orders left:  2116700
# making new cascade
#
#
# OG Orders left:  2116700
# Cascade length:  2213
# New Orders left:  2114487
# making new cascade
#
#
# OG Orders left:  2114487
# Cascade length:  2460
# New Orders left:  2112027
# making new cascade
#
#
# OG Orders left:  2112027
# Cascade length:  2674
# New Orders left:  2109353
# making new cascade
#
#
# OG Orders left:  2109353
# Cascade length:  2477
# New Orders left:  2106876
# making new cascade
#
#
# OG Orders left:  2106876
# Cascade length:  2488
# New Orders left:  2104388
# making new cascade
#
#
# OG Orders left:  2104388
# Cascade length:  2544
# New Orders left:  2101844
# making new cascade
#
#
# OG Orders left:  2101844
# Cascade length:  14
# New Orders left:  2101830
# making new cascade
#
#
# OG Orders left:  2101830
# Cascade length:  2146
# New Orders left:  2099684
# making new cascade
#
#
# OG Orders left:  2099684
# Cascade length:  2760
# New Orders left:  2096924
# making new cascade
#
#
# OG Orders left:  2096924
# Cascade length:  2506
# New Orders left:  2094418
# making new cascade
#
#
# OG Orders left:  2094418
# Cascade length:  1
# New Orders left:  2094417
# making new cascade
#
#
# OG Orders left:  2094417
# Cascade length:  2
# New Orders left:  2094415
# making new cascade
#
#
# OG Orders left:  2094415
# Cascade length:  1
# New Orders left:  2094414
# making new cascade
#
#
# OG Orders left:  2094414
# Cascade length:  2222
# New Orders left:  2092192
# making new cascade
#
#
# OG Orders left:  2092192
# Cascade length:  1
# New Orders left:  2092191
# making new cascade
#
#
# OG Orders left:  2092191
# Cascade length:  2485
# New Orders left:  2089706
# making new cascade
#
#
# OG Orders left:  2089706
# Cascade length:  2196
# New Orders left:  2087510
# making new cascade
#
#
# OG Orders left:  2087510
# Cascade length:  4
# New Orders left:  2087506
# making new cascade
#
#
# OG Orders left:  2087506
# Cascade length:  2475
# New Orders left:  2085031
# making new cascade
#
#
# OG Orders left:  2085031
# Cascade length:  2359
# New Orders left:  2082672
# making new cascade
#
#
# OG Orders left:  2082672
# Cascade length:  2169
# New Orders left:  2080503
# making new cascade
#
#
# OG Orders left:  2080503
# Cascade length:  2563
# New Orders left:  2077940
# making new cascade
#
#
# OG Orders left:  2077940
# Cascade length:  2428
# New Orders left:  2075512
# making new cascade
#
#
# OG Orders left:  2075512
# Cascade length:  1992
# New Orders left:  2073520
# making new cascade
#
#
# OG Orders left:  2073520
# Cascade length:  2
# New Orders left:  2073518
# making new cascade
#
#
# OG Orders left:  2073518
# Cascade length:  2257
# New Orders left:  2071261
# making new cascade
#
#
# OG Orders left:  2071261
# Cascade length:  2327
# New Orders left:  2068934
# making new cascade
#
#
# OG Orders left:  2068934
# Cascade length:  1
# New Orders left:  2068933
# making new cascade
#
#
# OG Orders left:  2068933
# Cascade length:  2158
# New Orders left:  2066775
# making new cascade
#
#
# OG Orders left:  2066775
# Cascade length:  2156
# New Orders left:  2064619
# making new cascade
#
#
# OG Orders left:  2064619
# Cascade length:  2306
# New Orders left:  2062313
# making new cascade
#
#
# OG Orders left:  2062313
# Cascade length:  2157
# New Orders left:  2060156
# making new cascade
#
#
# OG Orders left:  2060156
# Cascade length:  33
# New Orders left:  2060123
# making new cascade
#
#
# OG Orders left:  2060123
# Cascade length:  8
# New Orders left:  2060115
# making new cascade
#
#
# OG Orders left:  2060115
# Cascade length:  14
# New Orders left:  2060101
# making new cascade
#
#
# OG Orders left:  2060101
# Cascade length:  15
# New Orders left:  2060086
# making new cascade
#
#
# OG Orders left:  2060086
# Cascade length:  5
# New Orders left:  2060081
# making new cascade
#
#
# OG Orders left:  2060081
# Cascade length:  1797
# New Orders left:  2058284
# making new cascade
#
#
# OG Orders left:  2058284
# Cascade length:  2155
# New Orders left:  2056129
# making new cascade
#
#
# OG Orders left:  2056129
# Cascade length:  2689
# New Orders left:  2053440
# making new cascade
#
#
# OG Orders left:  2053440
# Cascade length:  2
# New Orders left:  2053438
# making new cascade
#
#
# OG Orders left:  2053438
# Cascade length:  2260
# New Orders left:  2051178
# making new cascade
#
#
# OG Orders left:  2051178
# Cascade length:  2235
# New Orders left:  2048943
# making new cascade
#
#
# OG Orders left:  2048943
# Cascade length:  9
# New Orders left:  2048934
# making new cascade
#
#
# OG Orders left:  2048934
# Cascade length:  2181
# New Orders left:  2046753
# making new cascade
#
#
# OG Orders left:  2046753
# Cascade length:  1
# New Orders left:  2046752
# making new cascade
#
#
# OG Orders left:  2046752
# Cascade length:  2244
# New Orders left:  2044508
# making new cascade
#
#
# OG Orders left:  2044508
# Cascade length:  1876
# New Orders left:  2042632
# making new cascade
#
#
# OG Orders left:  2042632
# Cascade length:  2021
# New Orders left:  2040611
# making new cascade
#
#
# OG Orders left:  2040611
# Cascade length:  2088
# New Orders left:  2038523
# making new cascade
#
#
# OG Orders left:  2038523
# Cascade length:  4
# New Orders left:  2038519
# making new cascade
#
#
# OG Orders left:  2038519
# Cascade length:  12
# New Orders left:  2038507
# making new cascade
#
#
# OG Orders left:  2038507
# Cascade length:  2005
# New Orders left:  2036502
# making new cascade
#
#
# OG Orders left:  2036502
# Cascade length:  1845
# New Orders left:  2034657
# making new cascade
#
#
# OG Orders left:  2034657
# Cascade length:  8
# New Orders left:  2034649
# making new cascade
#
#
# OG Orders left:  2034649
# Cascade length:  2421
# New Orders left:  2032228
# making new cascade
#
#
# OG Orders left:  2032228
# Cascade length:  1964
# New Orders left:  2030264
# making new cascade
#
#
# OG Orders left:  2030264
# Cascade length:  2307
# New Orders left:  2027957
# making new cascade
#
#
# OG Orders left:  2027957
# Cascade length:  1519
# New Orders left:  2026438
# making new cascade
#
#
# OG Orders left:  2026438
# Cascade length:  2010
# New Orders left:  2024428
# making new cascade
#
#
# OG Orders left:  2024428
# Cascade length:  2150
# New Orders left:  2022278
# making new cascade
#
#
# OG Orders left:  2022278
# Cascade length:  5
# New Orders left:  2022273
# making new cascade
#
#
# OG Orders left:  2022273
# Cascade length:  1502
# New Orders left:  2020771
# making new cascade
#
#
# OG Orders left:  2020771
# Cascade length:  1633
# New Orders left:  2019138
# making new cascade
#
#
# OG Orders left:  2019138
# Cascade length:  26
# New Orders left:  2019112
# making new cascade
#
#
# OG Orders left:  2019112
# Cascade length:  2183
# New Orders left:  2016929
# making new cascade
#
#
# OG Orders left:  2016929
# Cascade length:  1948
# New Orders left:  2014981
# making new cascade
#
#
# OG Orders left:  2014981
# Cascade length:  22
# New Orders left:  2014959
# making new cascade
#
#
# OG Orders left:  2014959
# Cascade length:  2018
# New Orders left:  2012941
# making new cascade
#
#
# OG Orders left:  2012941
# Cascade length:  1903
# New Orders left:  2011038
# making new cascade
#
#
# OG Orders left:  2011038
# Cascade length:  1
# New Orders left:  2011037
# making new cascade
#
#
# OG Orders left:  2011037
# Cascade length:  1
# New Orders left:  2011036
# making new cascade
#
#
# OG Orders left:  2011036
# Cascade length:  1711
# New Orders left:  2009325
# making new cascade
#
#
# OG Orders left:  2009325
# Cascade length:  1
# New Orders left:  2009324
# making new cascade
#
#
# OG Orders left:  2009324
# Cascade length:  1
# New Orders left:  2009323
# making new cascade
#
#
# OG Orders left:  2009323
# Cascade length:  9
# New Orders left:  2009314
# making new cascade
#
#
# OG Orders left:  2009314
# Cascade length:  1969
# New Orders left:  2007345
# making new cascade
#
#
# OG Orders left:  2007345
# Cascade length:  2043
# New Orders left:  2005302
# making new cascade
#
#
# OG Orders left:  2005302
# Cascade length:  2030
# New Orders left:  2003272
# making new cascade
#
#
# OG Orders left:  2003272
# Cascade length:  2315
# New Orders left:  2000957
# making new cascade
#
#
# OG Orders left:  2000957
# Cascade length:  13
# New Orders left:  2000944
# making new cascade
#
#
# OG Orders left:  2000944
# Cascade length:  29
# New Orders left:  2000915
# making new cascade
#
#
# OG Orders left:  2000915
# Cascade length:  2181
# New Orders left:  1998734
# making new cascade
#
#
# OG Orders left:  1998734
# Cascade length:  3
# New Orders left:  1998731
# making new cascade
#
#
# OG Orders left:  1998731
# Cascade length:  1759
# New Orders left:  1996972
# making new cascade
#
#
# OG Orders left:  1996972
# Cascade length:  14
# New Orders left:  1996958
# making new cascade
#
#
# OG Orders left:  1996958
# Cascade length:  1637
# New Orders left:  1995321
# making new cascade
#
#
# OG Orders left:  1995321
# Cascade length:  4
# New Orders left:  1995317
# making new cascade
#
#
# OG Orders left:  1995317
# Cascade length:  1
# New Orders left:  1995316
# making new cascade
#
#
# OG Orders left:  1995316
# Cascade length:  7
# New Orders left:  1995309
# making new cascade
#
#
# OG Orders left:  1995309
# Cascade length:  2171
# New Orders left:  1993138
# making new cascade
#
#
# OG Orders left:  1993138
# Cascade length:  1214
# New Orders left:  1991924
# making new cascade
#
#
# OG Orders left:  1991924
# Cascade length:  43
# New Orders left:  1991881
# making new cascade
#
#
# OG Orders left:  1991881
# Cascade length:  2
# New Orders left:  1991879
# making new cascade
#
#
# OG Orders left:  1991879
# Cascade length:  1597
# New Orders left:  1990282
# making new cascade
#
#
# OG Orders left:  1990282
# Cascade length:  7
# New Orders left:  1990275
# making new cascade
#
#
# OG Orders left:  1990275
# Cascade length:  1826
# New Orders left:  1988449
# making new cascade
#
#
# OG Orders left:  1988449
# Cascade length:  20
# New Orders left:  1988429
# making new cascade
#
#
# OG Orders left:  1988429
# Cascade length:  1866
# New Orders left:  1986563
# making new cascade
#
#
# OG Orders left:  1986563
# Cascade length:  1025
# New Orders left:  1985538
# making new cascade
#
#
# OG Orders left:  1985538
# Cascade length:  22
# New Orders left:  1985516
# making new cascade
#
#
# OG Orders left:  1985516
# Cascade length:  1
# New Orders left:  1985515
# making new cascade
#
#
# OG Orders left:  1985515
# Cascade length:  1686
# New Orders left:  1983829
# making new cascade
#
#
# OG Orders left:  1983829
# Cascade length:  2
# New Orders left:  1983827
# making new cascade
#
#
# OG Orders left:  1983827
# Cascade length:  23
# New Orders left:  1983804
# making new cascade
#
#
# OG Orders left:  1983804
# Cascade length:  1913
# New Orders left:  1981891
# making new cascade
#
#
# OG Orders left:  1981891
# Cascade length:  1707
# New Orders left:  1980184
# making new cascade
#
#
# OG Orders left:  1980184
# Cascade length:  13
# New Orders left:  1980171
# making new cascade
#
#
# OG Orders left:  1980171
# Cascade length:  2
# New Orders left:  1980169
# making new cascade
#
#
# OG Orders left:  1980169
# Cascade length:  1
# New Orders left:  1980168
# making new cascade
#
#
# OG Orders left:  1980168
# Cascade length:  37
# New Orders left:  1980131
# making new cascade
#
#
# OG Orders left:  1980131
# Cascade length:  7
# New Orders left:  1980124
# making new cascade
#
#
# OG Orders left:  1980124
# Cascade length:  1495
# New Orders left:  1978629
# making new cascade
#
#
# OG Orders left:  1978629
# Cascade length:  5
# New Orders left:  1978624
# making new cascade
#
#
# OG Orders left:  1978624
# Cascade length:  1800
# New Orders left:  1976824
# making new cascade
#
#
# OG Orders left:  1976824
# Cascade length:  1550
# New Orders left:  1975274
# making new cascade
#
#
# OG Orders left:  1975274
# Cascade length:  1919
# New Orders left:  1973355
# making new cascade
#
#
# OG Orders left:  1973355
# Cascade length:  1051
# New Orders left:  1972304
# making new cascade
#
#
# OG Orders left:  1972304
# Cascade length:  1434
# New Orders left:  1970870
# making new cascade
#
#
# OG Orders left:  1970870
# Cascade length:  5
# New Orders left:  1970865
# making new cascade
#
#
# OG Orders left:  1970865
# Cascade length:  1549
# New Orders left:  1969316
# making new cascade
#
#
# OG Orders left:  1969316
# Cascade length:  1545
# New Orders left:  1967771
# making new cascade
#
#
# OG Orders left:  1967771
# Cascade length:  1826
# New Orders left:  1965945
# making new cascade
#
#
# OG Orders left:  1965945
# Cascade length:  4
# New Orders left:  1965941
# making new cascade
#
#
# OG Orders left:  1965941
# Cascade length:  2
# New Orders left:  1965939
# making new cascade
#
#
# OG Orders left:  1965939
# Cascade length:  22
# New Orders left:  1965917
# making new cascade
#
#
# OG Orders left:  1965917
# Cascade length:  3
# New Orders left:  1965914
# making new cascade
#
#
# OG Orders left:  1965914
# Cascade length:  1962
# New Orders left:  1963952
# making new cascade
#
#
# OG Orders left:  1963952
# Cascade length:  1270
# New Orders left:  1962682
# making new cascade
#
#
# OG Orders left:  1962682
# Cascade length:  1
# New Orders left:  1962681
# making new cascade
#
#
# OG Orders left:  1962681
# Cascade length:  1575
# New Orders left:  1961106
# making new cascade
#
#
# OG Orders left:  1961106
# Cascade length:  1197
# New Orders left:  1959909
# making new cascade
#
#
# OG Orders left:  1959909
# Cascade length:  1
# New Orders left:  1959908
# making new cascade
#
#
# OG Orders left:  1959908
# Cascade length:  7
# New Orders left:  1959901
# making new cascade
#
#
# OG Orders left:  1959901
# Cascade length:  1580
# New Orders left:  1958321
# making new cascade
#
#
# OG Orders left:  1958321
# Cascade length:  5
# New Orders left:  1958316
# making new cascade
#
#
# OG Orders left:  1958316
# Cascade length:  2
# New Orders left:  1958314
# making new cascade
#
#
# OG Orders left:  1958314
# Cascade length:  1103
# New Orders left:  1957211
# making new cascade
#
#
# OG Orders left:  1957211
# Cascade length:  1093
# New Orders left:  1956118
# making new cascade
#
#
# OG Orders left:  1956118
# Cascade length:  1714
# New Orders left:  1954404
# making new cascade
#
#
# OG Orders left:  1954404
# Cascade length:  1558
# New Orders left:  1952846
# making new cascade
#
#
# OG Orders left:  1952846
# Cascade length:  736
# New Orders left:  1952110
# making new cascade
#
#
# OG Orders left:  1952110
# Cascade length:  39
# New Orders left:  1952071
# making new cascade
#
#
# OG Orders left:  1952071
# Cascade length:  1426
# New Orders left:  1950645
# making new cascade
#
#
# OG Orders left:  1950645
# Cascade length:  2
# New Orders left:  1950643
# making new cascade
#
#
# OG Orders left:  1950643
# Cascade length:  1013
# New Orders left:  1949630
# making new cascade
#
#
# OG Orders left:  1949630
# Cascade length:  1950
# New Orders left:  1947680
# making new cascade
#
#
# OG Orders left:  1947680
# Cascade length:  1339
# New Orders left:  1946341
# making new cascade
#
#
# OG Orders left:  1946341
# Cascade length:  15
# New Orders left:  1946326
# making new cascade
#
#
# OG Orders left:  1946326
# Cascade length:  2
# New Orders left:  1946324
# making new cascade
#
#
# OG Orders left:  1946324
# Cascade length:  1378
# New Orders left:  1944946
# making new cascade
#
#
# OG Orders left:  1944946
# Cascade length:  627
# New Orders left:  1944319
# making new cascade
#
#
# OG Orders left:  1944319
# Cascade length:  1950
# New Orders left:  1942369
# making new cascade
#
#
# OG Orders left:  1942369
# Cascade length:  700
# New Orders left:  1941669
# making new cascade
#
#
# OG Orders left:  1941669
# Cascade length:  8
# New Orders left:  1941661
# making new cascade
#
#
# OG Orders left:  1941661
# Cascade length:  5
# New Orders left:  1941656
# making new cascade
#
#
# OG Orders left:  1941656
# Cascade length:  1
# New Orders left:  1941655
# making new cascade
#
#
# OG Orders left:  1941655
# Cascade length:  70
# New Orders left:  1941585
# making new cascade
#
#
# OG Orders left:  1941585
# Cascade length:  1703
# New Orders left:  1939882
# making new cascade
#
#
# OG Orders left:  1939882
# Cascade length:  9
# New Orders left:  1939873
# making new cascade
#
#
# OG Orders left:  1939873
# Cascade length:  1861
# New Orders left:  1938012
# making new cascade
#
#
# OG Orders left:  1938012
# Cascade length:  9
# New Orders left:  1938003
# making new cascade
#
#
# OG Orders left:  1938003
# Cascade length:  1484
# New Orders left:  1936519
# making new cascade
#
#
# OG Orders left:  1936519
# Cascade length:  1269
# New Orders left:  1935250
# making new cascade
#
#
# OG Orders left:  1935250
# Cascade length:  1500
# New Orders left:  1933750
# making new cascade
#
#
# OG Orders left:  1933750
# Cascade length:  1359
# New Orders left:  1932391
# making new cascade
#
#
# OG Orders left:  1932391
# Cascade length:  1044
# New Orders left:  1931347
# making new cascade
#
#
# OG Orders left:  1931347
# Cascade length:  1504
# New Orders left:  1929843
# making new cascade
#
#
# OG Orders left:  1929843
# Cascade length:  19
# New Orders left:  1929824
# making new cascade
#
#
# OG Orders left:  1929824
# Cascade length:  1303
# New Orders left:  1928521
# making new cascade
#
#
# OG Orders left:  1928521
# Cascade length:  1703
# New Orders left:  1926818
# making new cascade
#
#
# OG Orders left:  1926818
# Cascade length:  1492
# New Orders left:  1925326
# making new cascade
#
#
# OG Orders left:  1925326
# Cascade length:  1089
# New Orders left:  1924237
# making new cascade
#
#
# OG Orders left:  1924237
# Cascade length:  1397
# New Orders left:  1922840
# making new cascade
#
#
# OG Orders left:  1922840
# Cascade length:  999
# New Orders left:  1921841
# making new cascade
#
#
# OG Orders left:  1921841
# Cascade length:  1040
# New Orders left:  1920801
# making new cascade
#
#
# OG Orders left:  1920801
# Cascade length:  7
# New Orders left:  1920794
# making new cascade
#
#
# OG Orders left:  1920794
# Cascade length:  9
# New Orders left:  1920785
# making new cascade
#
#
# OG Orders left:  1920785
# Cascade length:  1
# New Orders left:  1920784
# making new cascade
#
#
# OG Orders left:  1920784
# Cascade length:  10
# New Orders left:  1920774
# making new cascade
#
#
# OG Orders left:  1920774
# Cascade length:  1291
# New Orders left:  1919483
# making new cascade
#
#
# OG Orders left:  1919483
# Cascade length:  1807
# New Orders left:  1917676
# making new cascade
#
#
# OG Orders left:  1917676
# Cascade length:  969
# New Orders left:  1916707
# making new cascade
#
#
# OG Orders left:  1916707
# Cascade length:  3
# New Orders left:  1916704
# making new cascade
#
#
# OG Orders left:  1916704
# Cascade length:  17
# New Orders left:  1916687
# making new cascade
#
#
# OG Orders left:  1916687
# Cascade length:  2
# New Orders left:  1916685
# making new cascade
#
#
# OG Orders left:  1916685
# Cascade length:  1
# New Orders left:  1916684
# making new cascade
#
#
# OG Orders left:  1916684
# Cascade length:  936
# New Orders left:  1915748
# making new cascade
#
#
# OG Orders left:  1915748
# Cascade length:  14
# New Orders left:  1915734
# making new cascade
#
#
# OG Orders left:  1915734
# Cascade length:  4
# New Orders left:  1915730
# making new cascade
#
#
# OG Orders left:  1915730
# Cascade length:  1204
# New Orders left:  1914526
# making new cascade
#
#
# OG Orders left:  1914526
# Cascade length:  1140
# New Orders left:  1913386
# making new cascade
#
#
# OG Orders left:  1913386
# Cascade length:  22
# New Orders left:  1913364
# making new cascade
#
#
# OG Orders left:  1913364
# Cascade length:  1226
# New Orders left:  1912138
# making new cascade
#
#
# OG Orders left:  1912138
# Cascade length:  1286
# New Orders left:  1910852
# making new cascade
#
#
# OG Orders left:  1910852
# Cascade length:  1
# New Orders left:  1910851
# making new cascade
#
#
# OG Orders left:  1910851
# Cascade length:  652
# New Orders left:  1910199
# making new cascade
#
#
# OG Orders left:  1910199
# Cascade length:  5
# New Orders left:  1910194
# making new cascade
#
#
# OG Orders left:  1910194
# Cascade length:  77
# New Orders left:  1910117
# making new cascade
#
#
# OG Orders left:  1910117
# Cascade length:  860
# New Orders left:  1909257
# making new cascade
#
#
# OG Orders left:  1909257
# Cascade length:  4
# New Orders left:  1909253
# making new cascade
#
#
# OG Orders left:  1909253
# Cascade length:  47
# New Orders left:  1909206
# making new cascade
#
#
# OG Orders left:  1909206
# Cascade length:  1229
# New Orders left:  1907977
# making new cascade
#
#
# OG Orders left:  1907977
# Cascade length:  3
# New Orders left:  1907974
# making new cascade
#
#
# OG Orders left:  1907974
# Cascade length:  793
# New Orders left:  1907181
# making new cascade
#
#
# OG Orders left:  1907181
# Cascade length:  5
# New Orders left:  1907176
# making new cascade
#
#
# OG Orders left:  1907176
# Cascade length:  1112
# New Orders left:  1906064
# making new cascade
#
#
# OG Orders left:  1906064
# Cascade length:  9
# New Orders left:  1906055
# making new cascade
#
#
# OG Orders left:  1906055
# Cascade length:  1
# New Orders left:  1906054
# making new cascade
#
#
# OG Orders left:  1906054
# Cascade length:  1181
# New Orders left:  1904873
# making new cascade
#
#
# OG Orders left:  1904873
# Cascade length:  722
# New Orders left:  1904151
# making new cascade
#
#
# OG Orders left:  1904151
# Cascade length:  744
# New Orders left:  1903407
# making new cascade
#
#
# OG Orders left:  1903407
# Cascade length:  1482
# New Orders left:  1901925
# making new cascade
#
#
# OG Orders left:  1901925
# Cascade length:  8
# New Orders left:  1901917
# making new cascade
#
#
# OG Orders left:  1901917
# Cascade length:  1036
# New Orders left:  1900881
# making new cascade
#
#
# OG Orders left:  1900881
# Cascade length:  2
# New Orders left:  1900879
# making new cascade
#
#
# OG Orders left:  1900879
# Cascade length:  1394
# New Orders left:  1899485
# making new cascade
#
#
# OG Orders left:  1899485
# Cascade length:  1546
# New Orders left:  1897939
# making new cascade
#
#
# OG Orders left:  1897939
# Cascade length:  15
# New Orders left:  1897924
# making new cascade
#
#
# OG Orders left:  1897924
# Cascade length:  15
# New Orders left:  1897909
# making new cascade
#
#
# OG Orders left:  1897909
# Cascade length:  1095
# New Orders left:  1896814
# making new cascade
#
#
# OG Orders left:  1896814
# Cascade length:  1332
# New Orders left:  1895482
# making new cascade
#
#
# OG Orders left:  1895482
# Cascade length:  9
# New Orders left:  1895473
# making new cascade
#
#
# OG Orders left:  1895473
# Cascade length:  17
# New Orders left:  1895456
# making new cascade
#
#
# OG Orders left:  1895456
# Cascade length:  591
# New Orders left:  1894865
# making new cascade
#
#
# OG Orders left:  1894865
# Cascade length:  710
# New Orders left:  1894155
# making new cascade
#
#
# OG Orders left:  1894155
# Cascade length:  1102
# New Orders left:  1893053
# making new cascade
#
#
# OG Orders left:  1893053
# Cascade length:  882
# New Orders left:  1892171
# making new cascade
#
#
# OG Orders left:  1892171
# Cascade length:  21
# New Orders left:  1892150
# making new cascade
#
#
# OG Orders left:  1892150
# Cascade length:  680
# New Orders left:  1891470
# making new cascade
#
#
# OG Orders left:  1891470
# Cascade length:  6
# New Orders left:  1891464
# making new cascade
#
#
# OG Orders left:  1891464
# Cascade length:  603
# New Orders left:  1890861
# making new cascade
#
#
# OG Orders left:  1890861
# Cascade length:  6
# New Orders left:  1890855
# making new cascade
#
#
# OG Orders left:  1890855
# Cascade length:  950
# New Orders left:  1889905
# making new cascade
#
#
# OG Orders left:  1889905
# Cascade length:  865
# New Orders left:  1889040
# making new cascade
#
#
# OG Orders left:  1889040
# Cascade length:  1
# New Orders left:  1889039
# making new cascade
#
#
# OG Orders left:  1889039
# Cascade length:  1237
# New Orders left:  1887802
# making new cascade
#
#
# OG Orders left:  1887802
# Cascade length:  1551
# New Orders left:  1886251
# making new cascade
#
#
# OG Orders left:  1886251
# Cascade length:  557
# New Orders left:  1885694
# making new cascade
#
#
# OG Orders left:  1885694
# Cascade length:  4
# New Orders left:  1885690
# making new cascade
#
#
# OG Orders left:  1885690
# Cascade length:  217
# New Orders left:  1885473
# making new cascade
#
#
# OG Orders left:  1885473
# Cascade length:  1608
# New Orders left:  1883865
# making new cascade
#
#
# OG Orders left:  1883865
# Cascade length:  837
# New Orders left:  1883028
# making new cascade
#
#
# OG Orders left:  1883028
# Cascade length:  13
# New Orders left:  1883015
# making new cascade
#
#
# OG Orders left:  1883015
# Cascade length:  26
# New Orders left:  1882989
# making new cascade
#
#
# OG Orders left:  1882989
# Cascade length:  75
# New Orders left:  1882914
# making new cascade
#
#
# OG Orders left:  1882914
# Cascade length:  2
# New Orders left:  1882912
# making new cascade
#
#
# OG Orders left:  1882912
# Cascade length:  11
# New Orders left:  1882901
# making new cascade
#
#
# OG Orders left:  1882901
# Cascade length:  14
# New Orders left:  1882887
# making new cascade
#
#
# OG Orders left:  1882887
# Cascade length:  1128
# New Orders left:  1881759
# making new cascade
#
#
# OG Orders left:  1881759
# Cascade length:  17
# New Orders left:  1881742
# making new cascade
#
#
# OG Orders left:  1881742
# Cascade length:  20
# New Orders left:  1881722
# making new cascade
#
#
# OG Orders left:  1881722
# Cascade length:  11
# New Orders left:  1881711
# making new cascade
#
#
# OG Orders left:  1881711
# Cascade length:  1190
# New Orders left:  1880521
# making new cascade
#
#
# OG Orders left:  1880521
# Cascade length:  503
# New Orders left:  1880018
# making new cascade
#
#
# OG Orders left:  1880018
# Cascade length:  13
# New Orders left:  1880005
# making new cascade
#
#
# OG Orders left:  1880005
# Cascade length:  1020
# New Orders left:  1878985
# making new cascade
#
#
# OG Orders left:  1878985
# Cascade length:  304
# New Orders left:  1878681
# making new cascade
#
#
# OG Orders left:  1878681
# Cascade length:  876
# New Orders left:  1877805
# making new cascade
#
#
# OG Orders left:  1877805
# Cascade length:  24
# New Orders left:  1877781
# making new cascade
#
#
# OG Orders left:  1877781
# Cascade length:  754
# New Orders left:  1877027
# making new cascade
#
#
# OG Orders left:  1877027
# Cascade length:  3
# New Orders left:  1877024
# making new cascade
#
#
# OG Orders left:  1877024
# Cascade length:  3
# New Orders left:  1877021
# making new cascade
#
#
# OG Orders left:  1877021
# Cascade length:  1091
# New Orders left:  1875930
# making new cascade
#
#
# OG Orders left:  1875930
# Cascade length:  88
# New Orders left:  1875842
# making new cascade
#
#
# OG Orders left:  1875842
# Cascade length:  1274
# New Orders left:  1874568
# making new cascade
#
#
# OG Orders left:  1874568
# Cascade length:  13
# New Orders left:  1874555
# making new cascade
#
#
# OG Orders left:  1874555
# Cascade length:  675
# New Orders left:  1873880
# making new cascade
#
#
# OG Orders left:  1873880
# Cascade length:  8
# New Orders left:  1873872
# making new cascade
#
#
# OG Orders left:  1873872
# Cascade length:  854
# New Orders left:  1873018
# making new cascade
#
#
# OG Orders left:  1873018
# Cascade length:  77
# New Orders left:  1872941
# making new cascade
#
#
# OG Orders left:  1872941
# Cascade length:  7
# New Orders left:  1872934
# making new cascade
#
#
# OG Orders left:  1872934
# Cascade length:  972
# New Orders left:  1871962
# making new cascade
#
#
# OG Orders left:  1871962
# Cascade length:  272
# New Orders left:  1871690
# making new cascade
#
#
# OG Orders left:  1871690
# Cascade length:  27
# New Orders left:  1871663
# making new cascade
#
#
# OG Orders left:  1871663
# Cascade length:  402
# New Orders left:  1871261
# making new cascade
#
#
# OG Orders left:  1871261
# Cascade length:  4
# New Orders left:  1871257
# making new cascade
#
#
# OG Orders left:  1871257
# Cascade length:  568
# New Orders left:  1870689
# making new cascade
#
#
# OG Orders left:  1870689
# Cascade length:  80
# New Orders left:  1870609
# making new cascade
#
#
# OG Orders left:  1870609
# Cascade length:  618
# New Orders left:  1869991
# making new cascade
#
#
# OG Orders left:  1869991
# Cascade length:  1366
# New Orders left:  1868625
# making new cascade
#
#
# OG Orders left:  1868625
# Cascade length:  465
# New Orders left:  1868160
# making new cascade
#
#
# OG Orders left:  1868160
# Cascade length:  15
# New Orders left:  1868145
# making new cascade
#
#
# OG Orders left:  1868145
# Cascade length:  1074
# New Orders left:  1867071
# making new cascade
#
#
# OG Orders left:  1867071
# Cascade length:  3
# New Orders left:  1867068
# making new cascade
#
#
# OG Orders left:  1867068
# Cascade length:  4
# New Orders left:  1867064
# making new cascade
#
#
# OG Orders left:  1867064
# Cascade length:  927
# New Orders left:  1866137
# making new cascade
#
#
# OG Orders left:  1866137
# Cascade length:  195
# New Orders left:  1865942
# making new cascade
#
#
# OG Orders left:  1865942
# Cascade length:  1332
# New Orders left:  1864610
# making new cascade
#
#
# OG Orders left:  1864610
# Cascade length:  876
# New Orders left:  1863734
# making new cascade
#
#
# OG Orders left:  1863734
# Cascade length:  4
# New Orders left:  1863730
# making new cascade
#
#
# OG Orders left:  1863730
# Cascade length:  9
# New Orders left:  1863721
# making new cascade
#
#
# OG Orders left:  1863721
# Cascade length:  7
# New Orders left:  1863714
# making new cascade
#
#
# OG Orders left:  1863714
# Cascade length:  9
# New Orders left:  1863705
# making new cascade
#
#
# OG Orders left:  1863705
# Cascade length:  24
# New Orders left:  1863681
# making new cascade
#
#
# OG Orders left:  1863681
# Cascade length:  681
# New Orders left:  1863000
# making new cascade
#
#
# OG Orders left:  1863000
# Cascade length:  20
# New Orders left:  1862980
# making new cascade
#
#
# OG Orders left:  1862980
# Cascade length:  713
# New Orders left:  1862267
# making new cascade
#
#
# OG Orders left:  1862267
# Cascade length:  580
# New Orders left:  1861687
# making new cascade
#
#
# OG Orders left:  1861687
# Cascade length:  87
# New Orders left:  1861600
# making new cascade
#
#
# OG Orders left:  1861600
# Cascade length:  85
# New Orders left:  1861515
# making new cascade
#
#
# OG Orders left:  1861515
# Cascade length:  639
# New Orders left:  1860876
# making new cascade
#
#
# OG Orders left:  1860876
# Cascade length:  436
# New Orders left:  1860440
# making new cascade
#
#
# OG Orders left:  1860440
# Cascade length:  857
# New Orders left:  1859583
# making new cascade
#
#
# OG Orders left:  1859583
# Cascade length:  6
# New Orders left:  1859577
# making new cascade
#
#
# OG Orders left:  1859577
# Cascade length:  644
# New Orders left:  1858933
# making new cascade
#
#
# OG Orders left:  1858933
# Cascade length:  36
# New Orders left:  1858897
# making new cascade
#
#
# OG Orders left:  1858897
# Cascade length:  7
# New Orders left:  1858890
# making new cascade
#
#
# OG Orders left:  1858890
# Cascade length:  205
# New Orders left:  1858685
# making new cascade
#
#
# OG Orders left:  1858685
# Cascade length:  1407
# New Orders left:  1857278
# making new cascade
#
#
# OG Orders left:  1857278
# Cascade length:  8
# New Orders left:  1857270
# making new cascade
#
#
# OG Orders left:  1857270
# Cascade length:  1328
# New Orders left:  1855942
# making new cascade
#
#
# OG Orders left:  1855942
# Cascade length:  39
# New Orders left:  1855903
# making new cascade
#
#
# OG Orders left:  1855903
# Cascade length:  503
# New Orders left:  1855400
# making new cascade
#
#
# OG Orders left:  1855400
# Cascade length:  888
# New Orders left:  1854512
# making new cascade
#
#
# OG Orders left:  1854512
# Cascade length:  435
# New Orders left:  1854077
# making new cascade
#
#
# OG Orders left:  1854077
# Cascade length:  797
# New Orders left:  1853280
# making new cascade
#
#
# OG Orders left:  1853280
# Cascade length:  2
# New Orders left:  1853278
# making new cascade
#
#
# OG Orders left:  1853278
# Cascade length:  961
# New Orders left:  1852317
# making new cascade
#
#
# OG Orders left:  1852317
# Cascade length:  5
# New Orders left:  1852312
# making new cascade
#
#
# OG Orders left:  1852312
# Cascade length:  151
# New Orders left:  1852161
# making new cascade
#
#
# OG Orders left:  1852161
# Cascade length:  871
# New Orders left:  1851290
# making new cascade
#
#
# OG Orders left:  1851290
# Cascade length:  1
# New Orders left:  1851289
# making new cascade
#
#
# OG Orders left:  1851289
# Cascade length:  1
# New Orders left:  1851288
# making new cascade
#
#
# OG Orders left:  1851288
# Cascade length:  22
# New Orders left:  1851266
# making new cascade
#
#
# OG Orders left:  1851266
# Cascade length:  1034
# New Orders left:  1850232
# making new cascade
#
#
# OG Orders left:  1850232
# Cascade length:  107
# New Orders left:  1850125
# making new cascade
#
#
# OG Orders left:  1850125
# Cascade length:  48
# New Orders left:  1850077
# making new cascade
#
#
# OG Orders left:  1850077
# Cascade length:  1
# New Orders left:  1850076
# making new cascade
#
#
# OG Orders left:  1850076
# Cascade length:  69
# New Orders left:  1850007
# making new cascade
#
#
# OG Orders left:  1850007
# Cascade length:  1
# New Orders left:  1850006
# making new cascade
#
#
# OG Orders left:  1850006
# Cascade length:  719
# New Orders left:  1849287
# making new cascade
#
#
# OG Orders left:  1849287
# Cascade length:  1
# New Orders left:  1849286
# making new cascade
#
#
# OG Orders left:  1849286
# Cascade length:  31
# New Orders left:  1849255
# making new cascade
#
#
# OG Orders left:  1849255
# Cascade length:  18
# New Orders left:  1849237
# making new cascade
#
#
# OG Orders left:  1849237
# Cascade length:  354
# New Orders left:  1848883
# making new cascade
#
#
# OG Orders left:  1848883
# Cascade length:  1
# New Orders left:  1848882
# making new cascade
#
#
# OG Orders left:  1848882
# Cascade length:  544
# New Orders left:  1848338
# making new cascade
#
#
# OG Orders left:  1848338
# Cascade length:  140
# New Orders left:  1848198
# making new cascade
#
#
# OG Orders left:  1848198
# Cascade length:  16
# New Orders left:  1848182
# making new cascade
#
#
# OG Orders left:  1848182
# Cascade length:  1
# New Orders left:  1848181
# making new cascade
#
#
# OG Orders left:  1848181
# Cascade length:  44
# New Orders left:  1848137
# making new cascade
#
#
# OG Orders left:  1848137
# Cascade length:  49
# New Orders left:  1848088
# making new cascade
#
#
# OG Orders left:  1848088
# Cascade length:  478
# New Orders left:  1847610
# making new cascade
#
#
# OG Orders left:  1847610
# Cascade length:  574
# New Orders left:  1847036
# making new cascade
#
#
# OG Orders left:  1847036
# Cascade length:  6
# New Orders left:  1847030
# making new cascade
#
#
# OG Orders left:  1847030
# Cascade length:  982
# New Orders left:  1846048
# making new cascade
#
#
# OG Orders left:  1846048
# Cascade length:  53
# New Orders left:  1845995
# making new cascade
#
#
# OG Orders left:  1845995
# Cascade length:  1119
# New Orders left:  1844876
# making new cascade
#
#
# OG Orders left:  1844876
# Cascade length:  19
# New Orders left:  1844857
# making new cascade
#
#
# OG Orders left:  1844857
# Cascade length:  1
# New Orders left:  1844856
# making new cascade
#
#
# OG Orders left:  1844856
# Cascade length:  767
# New Orders left:  1844089
# making new cascade
#
#
# OG Orders left:  1844089
# Cascade length:  542
# New Orders left:  1843547
# making new cascade
#
#
# OG Orders left:  1843547
# Cascade length:  414
# New Orders left:  1843133
# making new cascade
#
#
# OG Orders left:  1843133
# Cascade length:  2
# New Orders left:  1843131
# making new cascade
#
#
# OG Orders left:  1843131
# Cascade length:  1
# New Orders left:  1843130
# making new cascade
#
#
# OG Orders left:  1843130
# Cascade length:  1
# New Orders left:  1843129
# making new cascade
#
#
# OG Orders left:  1843129
# Cascade length:  597
# New Orders left:  1842532
# making new cascade
#
#
# OG Orders left:  1842532
# Cascade length:  23
# New Orders left:  1842509
# making new cascade
#
#
# OG Orders left:  1842509
# Cascade length:  11
# New Orders left:  1842498
# making new cascade
#
#
# OG Orders left:  1842498
# Cascade length:  5
# New Orders left:  1842493
# making new cascade
#
#
# OG Orders left:  1842493
# Cascade length:  2
# New Orders left:  1842491
# making new cascade
#
#
# OG Orders left:  1842491
# Cascade length:  48
# New Orders left:  1842443
# making new cascade
#
#
# OG Orders left:  1842443
# Cascade length:  20
# New Orders left:  1842423
# making new cascade
#
#
# OG Orders left:  1842423
# Cascade length:  21
# New Orders left:  1842402
# making new cascade
#
#
# OG Orders left:  1842402
# Cascade length:  145
# New Orders left:  1842257
# making new cascade
#
#
# OG Orders left:  1842257
# Cascade length:  847
# New Orders left:  1841410
# making new cascade
#
#
# OG Orders left:  1841410
# Cascade length:  1052
# New Orders left:  1840358
# making new cascade
#
#
# OG Orders left:  1840358
# Cascade length:  1
# New Orders left:  1840357
# making new cascade
#
#
# OG Orders left:  1840357
# Cascade length:  32
# New Orders left:  1840325
# making new cascade
#
#
# OG Orders left:  1840325
# Cascade length:  1
# New Orders left:  1840324
# making new cascade
#
#
# OG Orders left:  1840324
# Cascade length:  269
# New Orders left:  1840055
# making new cascade
#
#
# OG Orders left:  1840055
# Cascade length:  154
# New Orders left:  1839901
# making new cascade
#
#
# OG Orders left:  1839901
# Cascade length:  295
# New Orders left:  1839606
# making new cascade
#
#
# OG Orders left:  1839606
# Cascade length:  182
# New Orders left:  1839424
# making new cascade
#
#
# OG Orders left:  1839424
# Cascade length:  857
# New Orders left:  1838567
# making new cascade
#
#
# OG Orders left:  1838567
# Cascade length:  1539
# New Orders left:  1837028
# making new cascade
#
#
# OG Orders left:  1837028
# Cascade length:  824
# New Orders left:  1836204
# making new cascade
#
#
# OG Orders left:  1836204
# Cascade length:  36
# New Orders left:  1836168
# making new cascade
#
#
# OG Orders left:  1836168
# Cascade length:  765
# New Orders left:  1835403
# making new cascade
#
#
# OG Orders left:  1835403
# Cascade length:  1121
# New Orders left:  1834282
# making new cascade
#
#
# OG Orders left:  1834282
# Cascade length:  40
# New Orders left:  1834242
# making new cascade
#
#
# OG Orders left:  1834242
# Cascade length:  35
# New Orders left:  1834207
# making new cascade
#
#
# OG Orders left:  1834207
# Cascade length:  1
# New Orders left:  1834206
# making new cascade
#
#
# OG Orders left:  1834206
# Cascade length:  128
# New Orders left:  1834078
# making new cascade
#
#
# OG Orders left:  1834078
# Cascade length:  782
# New Orders left:  1833296
# making new cascade
#
#
# OG Orders left:  1833296
# Cascade length:  558
# New Orders left:  1832738
# making new cascade
#
#
# OG Orders left:  1832738
# Cascade length:  11
# New Orders left:  1832727
# making new cascade
#
#
# OG Orders left:  1832727
# Cascade length:  4
# New Orders left:  1832723
# making new cascade
#
#
# OG Orders left:  1832723
# Cascade length:  754
# New Orders left:  1831969
# making new cascade
#
#
# OG Orders left:  1831969
# Cascade length:  1156
# New Orders left:  1830813
# making new cascade
#
#
# OG Orders left:  1830813
# Cascade length:  3
# New Orders left:  1830810
# making new cascade
#
#
# OG Orders left:  1830810
# Cascade length:  1
# New Orders left:  1830809
# making new cascade
#
#
# OG Orders left:  1830809
# Cascade length:  192
# New Orders left:  1830617
# making new cascade
#
#
# OG Orders left:  1830617
# Cascade length:  10
# New Orders left:  1830607
# making new cascade
#
#
# OG Orders left:  1830607
# Cascade length:  334
# New Orders left:  1830273
# making new cascade
#
#
# OG Orders left:  1830273
# Cascade length:  74
# New Orders left:  1830199
# making new cascade
#
#
# OG Orders left:  1830199
# Cascade length:  66
# New Orders left:  1830133
# making new cascade
#
#
# OG Orders left:  1830133
# Cascade length:  1
# New Orders left:  1830132
# making new cascade
#
#
# OG Orders left:  1830132
# Cascade length:  9
# New Orders left:  1830123
# making new cascade
#
#
# OG Orders left:  1830123
# Cascade length:  28
# New Orders left:  1830095
# making new cascade
#
#
# OG Orders left:  1830095
# Cascade length:  8
# New Orders left:  1830087
# making new cascade
#
#
# OG Orders left:  1830087
# Cascade length:  2
# New Orders left:  1830085
# making new cascade
#
#
# OG Orders left:  1830085
# Cascade length:  1205
# New Orders left:  1828880
# making new cascade
#
#
# OG Orders left:  1828880
# Cascade length:  16
# New Orders left:  1828864
# making new cascade
#
#
# OG Orders left:  1828864
# Cascade length:  45
# New Orders left:  1828819
# making new cascade
#
#
# OG Orders left:  1828819
# Cascade length:  852
# New Orders left:  1827967
# making new cascade
#
#
# OG Orders left:  1827967
# Cascade length:  430
# New Orders left:  1827537
# making new cascade
#
#
# OG Orders left:  1827537
# Cascade length:  369
# New Orders left:  1827168
# making new cascade
#
#
# OG Orders left:  1827168
# Cascade length:  516
# New Orders left:  1826652
# making new cascade
#
#
# OG Orders left:  1826652
# Cascade length:  4
# New Orders left:  1826648
# making new cascade
#
#
# OG Orders left:  1826648
# Cascade length:  483
# New Orders left:  1826165
# making new cascade
#
#
# OG Orders left:  1826165
# Cascade length:  19
# New Orders left:  1826146
# making new cascade
#
#
# OG Orders left:  1826146
# Cascade length:  2
# New Orders left:  1826144
# making new cascade
#
#
# OG Orders left:  1826144
# Cascade length:  283
# New Orders left:  1825861
# making new cascade
#
#
# OG Orders left:  1825861
# Cascade length:  10
# New Orders left:  1825851
# making new cascade
#
#
# OG Orders left:  1825851
# Cascade length:  33
# New Orders left:  1825818
# making new cascade
#
#
# OG Orders left:  1825818
# Cascade length:  18
# New Orders left:  1825800
# making new cascade
#
#
# OG Orders left:  1825800
# Cascade length:  1
# New Orders left:  1825799
# making new cascade
#
#
# OG Orders left:  1825799
# Cascade length:  45
# New Orders left:  1825754
# making new cascade
#
#
# OG Orders left:  1825754
# Cascade length:  8
# New Orders left:  1825746
# making new cascade
#
#
# OG Orders left:  1825746
# Cascade length:  1068
# New Orders left:  1824678
# making new cascade
#
#
# OG Orders left:  1824678
# Cascade length:  21
# New Orders left:  1824657
# making new cascade
#
#
# OG Orders left:  1824657
# Cascade length:  40
# New Orders left:  1824617
# making new cascade
#
#
# OG Orders left:  1824617
# Cascade length:  10
# New Orders left:  1824607
# making new cascade
#
#
# OG Orders left:  1824607
# Cascade length:  10
# New Orders left:  1824597
# making new cascade
#
#
# OG Orders left:  1824597
# Cascade length:  73
# New Orders left:  1824524
# making new cascade
#
#
# OG Orders left:  1824524
# Cascade length:  29
# New Orders left:  1824495
# making new cascade
#
#
# OG Orders left:  1824495
# Cascade length:  517
# New Orders left:  1823978
# making new cascade
#
#
# OG Orders left:  1823978
# Cascade length:  158
# New Orders left:  1823820
# making new cascade
#
#
# OG Orders left:  1823820
# Cascade length:  241
# New Orders left:  1823579
# making new cascade
#
#
# OG Orders left:  1823579
# Cascade length:  8
# New Orders left:  1823571
# making new cascade
#
#
# OG Orders left:  1823571
# Cascade length:  16
# New Orders left:  1823555
# making new cascade
#
#
# OG Orders left:  1823555
# Cascade length:  7
# New Orders left:  1823548
# making new cascade
#
#
# OG Orders left:  1823548
# Cascade length:  223
# New Orders left:  1823325
# making new cascade
#
#
# OG Orders left:  1823325
# Cascade length:  415
# New Orders left:  1822910
# making new cascade
#
#
# OG Orders left:  1822910
# Cascade length:  301
# New Orders left:  1822609
# making new cascade
#
#
# OG Orders left:  1822609
# Cascade length:  198
# New Orders left:  1822411
# making new cascade
#
#
# OG Orders left:  1822411
# Cascade length:  149
# New Orders left:  1822262
# making new cascade
#
#
# OG Orders left:  1822262
# Cascade length:  311
# New Orders left:  1821951
# making new cascade
#
#
# OG Orders left:  1821951
# Cascade length:  31
# New Orders left:  1821920
# making new cascade
#
#
# OG Orders left:  1821920
# Cascade length:  382
# New Orders left:  1821538
# making new cascade
#
#
# OG Orders left:  1821538
# Cascade length:  20
# New Orders left:  1821518
# making new cascade
#
#
# OG Orders left:  1821518
# Cascade length:  228
# New Orders left:  1821290
# making new cascade
#
#
# OG Orders left:  1821290
# Cascade length:  120
# New Orders left:  1821170
# making new cascade
#
#
# OG Orders left:  1821170
# Cascade length:  147
# New Orders left:  1821023
# making new cascade
#
#
# OG Orders left:  1821023
# Cascade length:  99
# New Orders left:  1820924
# making new cascade
#
#
# OG Orders left:  1820924
# Cascade length:  301
# New Orders left:  1820623
# making new cascade
#
#
# OG Orders left:  1820623
# Cascade length:  618
# New Orders left:  1820005
# making new cascade
#
#
# OG Orders left:  1820005
# Cascade length:  30
# New Orders left:  1819975
# making new cascade
#
#
# OG Orders left:  1819975
# Cascade length:  436
# New Orders left:  1819539
# making new cascade
#
#
# OG Orders left:  1819539
# Cascade length:  458
# New Orders left:  1819081
# making new cascade
#
#
# OG Orders left:  1819081
# Cascade length:  263
# New Orders left:  1818818
# making new cascade
#
#
# OG Orders left:  1818818
# Cascade length:  1
# New Orders left:  1818817
# making new cascade
#
#
# OG Orders left:  1818817
# Cascade length:  4
# New Orders left:  1818813
# making new cascade
#
#
# OG Orders left:  1818813
# Cascade length:  1294
# New Orders left:  1817519
# making new cascade
#
#
# OG Orders left:  1817519
# Cascade length:  2
# New Orders left:  1817517
# making new cascade
#
#
# OG Orders left:  1817517
# Cascade length:  40
# New Orders left:  1817477
# making new cascade
#
#
# OG Orders left:  1817477
# Cascade length:  451
# New Orders left:  1817026
# making new cascade
#
#
# OG Orders left:  1817026
# Cascade length:  685
# New Orders left:  1816341
# making new cascade
#
#
# OG Orders left:  1816341
# Cascade length:  4
# New Orders left:  1816337
# making new cascade
#
#
# OG Orders left:  1816337
# Cascade length:  141
# New Orders left:  1816196
# making new cascade
#
#
# OG Orders left:  1816196
# Cascade length:  290
# New Orders left:  1815906
# making new cascade
#
#
# OG Orders left:  1815906
# Cascade length:  107
# New Orders left:  1815799
# making new cascade
#
#
# OG Orders left:  1815799
# Cascade length:  3
# New Orders left:  1815796
# making new cascade
#
#
# OG Orders left:  1815796
# Cascade length:  10
# New Orders left:  1815786
# making new cascade
#
#
# OG Orders left:  1815786
# Cascade length:  5
# New Orders left:  1815781
# making new cascade
#
#
# OG Orders left:  1815781
# Cascade length:  3
# New Orders left:  1815778
# making new cascade
#
#
# OG Orders left:  1815778
# Cascade length:  721
# New Orders left:  1815057
# making new cascade
#
#
# OG Orders left:  1815057
# Cascade length:  735
# New Orders left:  1814322
# making new cascade
#
#
# OG Orders left:  1814322
# Cascade length:  228
# New Orders left:  1814094
# making new cascade
#
#
# OG Orders left:  1814094
# Cascade length:  9
# New Orders left:  1814085
# making new cascade
#
#
# OG Orders left:  1814085
# Cascade length:  751
# New Orders left:  1813334
# making new cascade
#
#
# OG Orders left:  1813334
# Cascade length:  139
# New Orders left:  1813195
# making new cascade
#
#
# OG Orders left:  1813195
# Cascade length:  3
# New Orders left:  1813192
# making new cascade
#
#
# OG Orders left:  1813192
# Cascade length:  2
# New Orders left:  1813190
# making new cascade
#
#
# OG Orders left:  1813190
# Cascade length:  544
# New Orders left:  1812646
# making new cascade
#
#
# OG Orders left:  1812646
# Cascade length:  48
# New Orders left:  1812598
# making new cascade
#
#
# OG Orders left:  1812598
# Cascade length:  4
# New Orders left:  1812594
# making new cascade
#
#
# OG Orders left:  1812594
# Cascade length:  44
# New Orders left:  1812550
# making new cascade
#
#
# OG Orders left:  1812550
# Cascade length:  3
# New Orders left:  1812547
# making new cascade
#
#
# OG Orders left:  1812547
# Cascade length:  10
# New Orders left:  1812537
# making new cascade
#
#
# OG Orders left:  1812537
# Cascade length:  619
# New Orders left:  1811918
# making new cascade
#
#
# OG Orders left:  1811918
# Cascade length:  3
# New Orders left:  1811915
# making new cascade
#
#
# OG Orders left:  1811915
# Cascade length:  10
# New Orders left:  1811905
# making new cascade
#
#
# OG Orders left:  1811905
# Cascade length:  71
# New Orders left:  1811834
# making new cascade
#
#
# OG Orders left:  1811834
# Cascade length:  724
# New Orders left:  1811110
# making new cascade
#
#
# OG Orders left:  1811110
# Cascade length:  3
# New Orders left:  1811107
# making new cascade
#
#
# OG Orders left:  1811107
# Cascade length:  2
# New Orders left:  1811105
# making new cascade
#
#
# OG Orders left:  1811105
# Cascade length:  231
# New Orders left:  1810874
# making new cascade
#
#
# OG Orders left:  1810874
# Cascade length:  5
# New Orders left:  1810869
# making new cascade
#
#
# OG Orders left:  1810869
# Cascade length:  18
# New Orders left:  1810851
# making new cascade
#
#
# OG Orders left:  1810851
# Cascade length:  710
# New Orders left:  1810141
# making new cascade
#
#
# OG Orders left:  1810141
# Cascade length:  462
# New Orders left:  1809679
# making new cascade
#
#
# OG Orders left:  1809679
# Cascade length:  7
# New Orders left:  1809672
# making new cascade
#
#
# OG Orders left:  1809672
# Cascade length:  329
# New Orders left:  1809343
# making new cascade
#
#
# OG Orders left:  1809343
# Cascade length:  425
# New Orders left:  1808918
# making new cascade
#
#
# OG Orders left:  1808918
# Cascade length:  903
# New Orders left:  1808015
# making new cascade
#
#
# OG Orders left:  1808015
# Cascade length:  962
# New Orders left:  1807053
# making new cascade
#
#
# OG Orders left:  1807053
# Cascade length:  91
# New Orders left:  1806962
# making new cascade
#
#
# OG Orders left:  1806962
# Cascade length:  25
# New Orders left:  1806937
# making new cascade
#
#
# OG Orders left:  1806937
# Cascade length:  643
# New Orders left:  1806294
# making new cascade
#
#
# OG Orders left:  1806294
# Cascade length:  452
# New Orders left:  1805842
# making new cascade
#
#
# OG Orders left:  1805842
# Cascade length:  22
# New Orders left:  1805820
# making new cascade
#
#
# OG Orders left:  1805820
# Cascade length:  93
# New Orders left:  1805727
# making new cascade
#
#
# OG Orders left:  1805727
# Cascade length:  525
# New Orders left:  1805202
# making new cascade
#
#
# OG Orders left:  1805202
# Cascade length:  16
# New Orders left:  1805186
# making new cascade
#
#
# OG Orders left:  1805186
# Cascade length:  60
# New Orders left:  1805126
# making new cascade
#
#
# OG Orders left:  1805126
# Cascade length:  506
# ...
# Cascade length:  18
# New Orders left:  4778
# making new cascade
#
#
# OG Orders left:  4778
# Cascade length:  43
# New Orders left:  4735
# making new cascade
#
#
# OG Orders left:  4735
# Cascade length:  45
# New Orders left:  4690
# making new cascade
#
#
# OG Orders left:  4690
# Cascade length:  61
# New Orders left:  4629
# making new cascade
#
#
# OG Orders left:  4629
# Cascade length:  17
# New Orders left:  4612
# making new cascade
#
#
# OG Orders left:  4612
# Cascade length:  64
# New Orders left:  4548
# making new cascade
#
#
# OG Orders left:  4548
# Cascade length:  5
# New Orders left:  4543
# making new cascade
#
#
# OG Orders left:  4543
# Cascade length:  26
# New Orders left:  4517
# making new cascade
#
#
# OG Orders left:  4517
# Cascade length:  51
# New Orders left:  4466
# making new cascade
#
#
# OG Orders left:  4466
# Cascade length:  35
# New Orders left:  4431
# making new cascade
#
#
# OG Orders left:  4431
# Cascade length:  16
# New Orders left:  4415
# making new cascade
#
#
# OG Orders left:  4415
# Cascade length:  102
# New Orders left:  4313
# making new cascade
#
#
# OG Orders left:  4313
# Cascade length:  9
# New Orders left:  4304
# making new cascade
#
#
# OG Orders left:  4304
# Cascade length:  1
# New Orders left:  4303
# making new cascade
#
#
# OG Orders left:  4303
# Cascade length:  8
# New Orders left:  4295
# making new cascade
#
#
# OG Orders left:  4295
# Cascade length:  46
# New Orders left:  4249
# making new cascade
#
#
# OG Orders left:  4249
# Cascade length:  30
# New Orders left:  4219
# making new cascade
#
#
# OG Orders left:  4219
# Cascade length:  36
# New Orders left:  4183
# making new cascade
#
#
# OG Orders left:  4183
# Cascade length:  39
# New Orders left:  4144
# making new cascade
#
#
# OG Orders left:  4144
# Cascade length:  1
# New Orders left:  4143
# making new cascade
#
#
# OG Orders left:  4143
# Cascade length:  1
# New Orders left:  4142
# making new cascade
#
#
# OG Orders left:  4142
# Cascade length:  96
# New Orders left:  4046
# making new cascade
#
#
# OG Orders left:  4046
# Cascade length:  1
# New Orders left:  4045
# making new cascade
#
#
# OG Orders left:  4045
# Cascade length:  33
# New Orders left:  4012
# making new cascade
#
#
# OG Orders left:  4012
# Cascade length:  11
# New Orders left:  4001
# making new cascade
#
#
# OG Orders left:  4001
# Cascade length:  2
# New Orders left:  3999
# making new cascade
#
#
# OG Orders left:  3999
# Cascade length:  171
# New Orders left:  3828
# making new cascade
#
#
# OG Orders left:  3828
# Cascade length:  73
# New Orders left:  3755
# making new cascade
#
#
# OG Orders left:  3755
# Cascade length:  8
# New Orders left:  3747
# making new cascade
#
#
# OG Orders left:  3747
# Cascade length:  17
# New Orders left:  3730
# making new cascade
#
#
# OG Orders left:  3730
# Cascade length:  42
# New Orders left:  3688
# making new cascade
#
#
# OG Orders left:  3688
# Cascade length:  36
# New Orders left:  3652
# making new cascade
#
#
# OG Orders left:  3652
# Cascade length:  9
# New Orders left:  3643
# making new cascade
#
#
# OG Orders left:  3643
# Cascade length:  45
# New Orders left:  3598
# making new cascade
#
#
# OG Orders left:  3598
# Cascade length:  62
# New Orders left:  3536
# making new cascade
#
#
# OG Orders left:  3536
# Cascade length:  23
# New Orders left:  3513
# making new cascade
#
#
# OG Orders left:  3513
# Cascade length:  88
# New Orders left:  3425
# making new cascade
#
#
# OG Orders left:  3425
# Cascade length:  34
# New Orders left:  3391
# making new cascade
#
#
# OG Orders left:  3391
# Cascade length:  2
# New Orders left:  3389
# making new cascade
#
#
# OG Orders left:  3389
# Cascade length:  64
# New Orders left:  3325
# making new cascade
#
#
# OG Orders left:  3325
# Cascade length:  7
# New Orders left:  3318
# making new cascade
#
#
# OG Orders left:  3318
# Cascade length:  115
# New Orders left:  3203
# making new cascade
#
#
# OG Orders left:  3203
# Cascade length:  67
# New Orders left:  3136
# making new cascade
#
#
# OG Orders left:  3136
# Cascade length:  50
# New Orders left:  3086
# making new cascade
#
#
# OG Orders left:  3086
# Cascade length:  76
# New Orders left:  3010
# making new cascade
#
#
# OG Orders left:  3010
# Cascade length:  32
# New Orders left:  2978
# making new cascade
#
#
# OG Orders left:  2978
# Cascade length:  35
# New Orders left:  2943
# making new cascade
#
#
# OG Orders left:  2943
# Cascade length:  8
# New Orders left:  2935
# making new cascade
#
#
# OG Orders left:  2935
# Cascade length:  44
# New Orders left:  2891
# making new cascade
#
#
# OG Orders left:  2891
# Cascade length:  39
# New Orders left:  2852
# making new cascade
#
#
# OG Orders left:  2852
# Cascade length:  23
# New Orders left:  2829
# making new cascade
#
#
# OG Orders left:  2829
# Cascade length:  8
# New Orders left:  2821
# making new cascade
#
#
# OG Orders left:  2821
# Cascade length:  1
# New Orders left:  2820
# making new cascade
#
#
# OG Orders left:  2820
# Cascade length:  32
# New Orders left:  2788
# making new cascade
#
#
# OG Orders left:  2788
# Cascade length:  28
# New Orders left:  2760
# making new cascade
#
#
# OG Orders left:  2760
# Cascade length:  2
# New Orders left:  2758
# making new cascade
#
#
# OG Orders left:  2758
# Cascade length:  8
# New Orders left:  2750
# making new cascade
#
#
# OG Orders left:  2750
# Cascade length:  11
# New Orders left:  2739
# making new cascade
#
#
# OG Orders left:  2739
# Cascade length:  44
# New Orders left:  2695
# making new cascade
#
#
# OG Orders left:  2695
# Cascade length:  37
# New Orders left:  2658
# making new cascade
#
#
# OG Orders left:  2658
# Cascade length:  7
# New Orders left:  2651
# making new cascade
#
#
# OG Orders left:  2651
# Cascade length:  3
# New Orders left:  2648
# making new cascade
#
#
# OG Orders left:  2648
# Cascade length:  2
# New Orders left:  2646
# making new cascade
#
#
# OG Orders left:  2646
# Cascade length:  65
# New Orders left:  2581
# making new cascade
#
#
# OG Orders left:  2581
# Cascade length:  3
# New Orders left:  2578
# making new cascade
#
#
# OG Orders left:  2578
# Cascade length:  3
# New Orders left:  2575
# making new cascade
#
#
# OG Orders left:  2575
# Cascade length:  18
# New Orders left:  2557
# making new cascade
#
#
# OG Orders left:  2557
# Cascade length:  4
# New Orders left:  2553
# making new cascade
#
#
# OG Orders left:  2553
# Cascade length:  20
# New Orders left:  2533
# making new cascade
#
#
# OG Orders left:  2533
# Cascade length:  15
# New Orders left:  2518
# making new cascade
#
#
# OG Orders left:  2518
# Cascade length:  37
# New Orders left:  2481
# making new cascade
#
#
# OG Orders left:  2481
# Cascade length:  37
# New Orders left:  2444
# making new cascade
#
#
# OG Orders left:  2444
# Cascade length:  89
# New Orders left:  2355
# making new cascade
#
#
# OG Orders left:  2355
# Cascade length:  11
# New Orders left:  2344
# making new cascade
#
#
# OG Orders left:  2344
# Cascade length:  33
# New Orders left:  2311
# making new cascade
#
#
# OG Orders left:  2311
# Cascade length:  2
# New Orders left:  2309
# making new cascade
#
#
# OG Orders left:  2309
# Cascade length:  75
# New Orders left:  2234
# making new cascade
#
#
# OG Orders left:  2234
# Cascade length:  8
# New Orders left:  2226
# making new cascade
#
#
# OG Orders left:  2226
# Cascade length:  74
# New Orders left:  2152
# making new cascade
#
#
# OG Orders left:  2152
# Cascade length:  43
# New Orders left:  2109
# making new cascade
#
#
# OG Orders left:  2109
# Cascade length:  21
# New Orders left:  2088
# making new cascade
#
#
# OG Orders left:  2088
# Cascade length:  27
# New Orders left:  2061
# making new cascade
#
#
# OG Orders left:  2061
# Cascade length:  1
# New Orders left:  2060
# making new cascade
#
#
# OG Orders left:  2060
# Cascade length:  69
# New Orders left:  1991
# making new cascade
#
#
# OG Orders left:  1991
# Cascade length:  66
# New Orders left:  1925
# making new cascade
#
#
# OG Orders left:  1925
# Cascade length:  37
# New Orders left:  1888
# making new cascade
#
#
# OG Orders left:  1888
# Cascade length:  20
# New Orders left:  1868
# making new cascade
#
#
# OG Orders left:  1868
# Cascade length:  4
# New Orders left:  1864
# making new cascade
#
#
# OG Orders left:  1864
# Cascade length:  4
# New Orders left:  1860
# making new cascade
#
#
# OG Orders left:  1860
# Cascade length:  24
# New Orders left:  1836
# making new cascade
#
#
# OG Orders left:  1836
# Cascade length:  29
# New Orders left:  1807
# making new cascade
#
#
# OG Orders left:  1807
# Cascade length:  49
# New Orders left:  1758
# making new cascade
#
#
# OG Orders left:  1758
# Cascade length:  21
# New Orders left:  1737
# making new cascade
#
#
# OG Orders left:  1737
# Cascade length:  16
# New Orders left:  1721
# making new cascade
#
#
# OG Orders left:  1721
# Cascade length:  22
# New Orders left:  1699
# making new cascade
#
#
# OG Orders left:  1699
# Cascade length:  65
# New Orders left:  1634
# making new cascade
#
#
# OG Orders left:  1634
# Cascade length:  1
# New Orders left:  1633
# making new cascade
#
#
# OG Orders left:  1633
# Cascade length:  15
# New Orders left:  1618
# making new cascade
#
#
# OG Orders left:  1618
# Cascade length:  16
# New Orders left:  1602
# making new cascade
#
#
# OG Orders left:  1602
# Cascade length:  3
# New Orders left:  1599
# making new cascade
#
#
# OG Orders left:  1599
# Cascade length:  22
# New Orders left:  1577
# making new cascade
#
#
# OG Orders left:  1577
# Cascade length:  61
# New Orders left:  1516
# making new cascade
#
#
# OG Orders left:  1516
# Cascade length:  2
# New Orders left:  1514
# making new cascade
#
#
# OG Orders left:  1514
# Cascade length:  34
# New Orders left:  1480
# making new cascade
#
#
# OG Orders left:  1480
# Cascade length:  14
# New Orders left:  1466
# making new cascade
#
#
# OG Orders left:  1466
# Cascade length:  40
# New Orders left:  1426
# making new cascade
#
#
# OG Orders left:  1426
# Cascade length:  12
# New Orders left:  1414
# making new cascade
#
#
# OG Orders left:  1414
# Cascade length:  6
# New Orders left:  1408
# making new cascade
#
#
# OG Orders left:  1408
# Cascade length:  43
# New Orders left:  1365
# making new cascade
#
#
# OG Orders left:  1365
# Cascade length:  3
# New Orders left:  1362
# making new cascade
#
#
# OG Orders left:  1362
# Cascade length:  12
# New Orders left:  1350
# making new cascade
#
#
# OG Orders left:  1350
# Cascade length:  53
# New Orders left:  1297
# making new cascade
#
#
# OG Orders left:  1297
# Cascade length:  4
# New Orders left:  1293
# making new cascade
#
#
# OG Orders left:  1293
# Cascade length:  1
# New Orders left:  1292
# making new cascade
#
#
# OG Orders left:  1292
# Cascade length:  23
# New Orders left:  1269
# making new cascade
#
#
# OG Orders left:  1269
# Cascade length:  11
# New Orders left:  1258
# making new cascade
#
#
# OG Orders left:  1258
# Cascade length:  26
# New Orders left:  1232
# making new cascade
#
#
# OG Orders left:  1232
# Cascade length:  86
# New Orders left:  1146
# making new cascade
#
#
# OG Orders left:  1146
# Cascade length:  23
# New Orders left:  1123
# making new cascade
#
#
# OG Orders left:  1123
# Cascade length:  4
# New Orders left:  1119
# making new cascade
#
#
# OG Orders left:  1119
# Cascade length:  2
# New Orders left:  1117
# making new cascade
#
#
# OG Orders left:  1117
# Cascade length:  6
# New Orders left:  1111
# making new cascade
#
#
# OG Orders left:  1111
# Cascade length:  30
# New Orders left:  1081
# making new cascade
#
#
# OG Orders left:  1081
# Cascade length:  20
# New Orders left:  1061
# making new cascade
#
#
# OG Orders left:  1061
# Cascade length:  68
# New Orders left:  993
# making new cascade
#
#
# OG Orders left:  993
# Cascade length:  68
# New Orders left:  925
# making new cascade
#
#
# OG Orders left:  925
# Cascade length:  1
# New Orders left:  924
# making new cascade
#
#
# OG Orders left:  924
# Cascade length:  22
# New Orders left:  902
# making new cascade
#
#
# OG Orders left:  902
# Cascade length:  41
# New Orders left:  861
# making new cascade
#
#
# OG Orders left:  861
# Cascade length:  4
# New Orders left:  857
# making new cascade
#
#
# OG Orders left:  857
# Cascade length:  33
# New Orders left:  824
# making new cascade
#
#
# OG Orders left:  824
# Cascade length:  5
# New Orders left:  819
# making new cascade
#
#
# OG Orders left:  819
# Cascade length:  2
# New Orders left:  817
# making new cascade
#
#
# OG Orders left:  817
# Cascade length:  41
# New Orders left:  776
# making new cascade
#
#
# OG Orders left:  776
# Cascade length:  12
# New Orders left:  764
# making new cascade
#
#
# OG Orders left:  764
# Cascade length:  12
# New Orders left:  752
# making new cascade
#
#
# OG Orders left:  752
# Cascade length:  9
# New Orders left:  743
# making new cascade
#
#
# OG Orders left:  743
# Cascade length:  15
# New Orders left:  728
# making new cascade
#
#
# OG Orders left:  728
# Cascade length:  32
# New Orders left:  696
# making new cascade
#
#
# OG Orders left:  696
# Cascade length:  6
# New Orders left:  690
# making new cascade
#
#
# OG Orders left:  690
# Cascade length:  30
# New Orders left:  660
# making new cascade
#
#
# OG Orders left:  660
# Cascade length:  19
# New Orders left:  641
# making new cascade
#
#
# OG Orders left:  641
# Cascade length:  8
# New Orders left:  633
# making new cascade
#
#
# OG Orders left:  633
# Cascade length:  8
# New Orders left:  625
# making new cascade
#
#
# OG Orders left:  625
# Cascade length:  12
# New Orders left:  613
# making new cascade
#
#
# OG Orders left:  613
# Cascade length:  38
# New Orders left:  575
# making new cascade
#
#
# OG Orders left:  575
# Cascade length:  15
# New Orders left:  560
# making new cascade
#
#
# OG Orders left:  560
# Cascade length:  10
# New Orders left:  550
# making new cascade
#
#
# OG Orders left:  550
# Cascade length:  46
# New Orders left:  504
# making new cascade
#
#
# OG Orders left:  504
# Cascade length:  16
# New Orders left:  488
# making new cascade
#
#
# OG Orders left:  488
# Cascade length:  1
# New Orders left:  487
# making new cascade
#
#
# OG Orders left:  487
# Cascade length:  7
# New Orders left:  480
# making new cascade
#
#
# OG Orders left:  480
# Cascade length:  5
# New Orders left:  475
# making new cascade
#
#
# OG Orders left:  475
# Cascade length:  17
# New Orders left:  458
# making new cascade
#
#
# OG Orders left:  458
# Cascade length:  8
# New Orders left:  450
# making new cascade
#
#
# OG Orders left:  450
# Cascade length:  22
# New Orders left:  428
# making new cascade
#
#
# OG Orders left:  428
# Cascade length:  11
# New Orders left:  417
# making new cascade
#
#
# OG Orders left:  417
# Cascade length:  47
# New Orders left:  370
# making new cascade
#
#
# OG Orders left:  370
# Cascade length:  45
# New Orders left:  325
# making new cascade
#
#
# OG Orders left:  325
# Cascade length:  6
# New Orders left:  319
# making new cascade
#
#
# OG Orders left:  319
# Cascade length:  32
# New Orders left:  287
# making new cascade
#
#
# OG Orders left:  287
# Cascade length:  14
# New Orders left:  273
# making new cascade
#
#
# OG Orders left:  273
# Cascade length:  8
# New Orders left:  265
# making new cascade
#
#
# OG Orders left:  265
# Cascade length:  29
# New Orders left:  236
# making new cascade
#
#
# OG Orders left:  236
# Cascade length:  18
# New Orders left:  218
# making new cascade
#
#
# OG Orders left:  218
# Cascade length:  2
# New Orders left:  216
# making new cascade
#
#
# OG Orders left:  216
# Cascade length:  16
# New Orders left:  200
# making new cascade
#
#
# OG Orders left:  200
# Cascade length:  26
# New Orders left:  174
# making new cascade
#
#
# OG Orders left:  174
# Cascade length:  11
# New Orders left:  163
# making new cascade
#
#
# OG Orders left:  163
# Cascade length:  2
# New Orders left:  161
# making new cascade
#
#
# OG Orders left:  161
# Cascade length:  27
# New Orders left:  134
# making new cascade
#
#
# OG Orders left:  134
# Cascade length:  33
# New Orders left:  101
# making new cascade
#
#
# OG Orders left:  101
# Cascade length:  3
# New Orders left:  98
# making new cascade
#
#
# OG Orders left:  98
# Cascade length:  2
# New Orders left:  96
# making new cascade
#
#
# OG Orders left:  96
# Cascade length:  6
# New Orders left:  90
# making new cascade
#
#
# OG Orders left:  90
# Cascade length:  15
# New Orders left:  75
# making new cascade
#
#
# OG Orders left:  75
# Cascade length:  1
# New Orders left:  74
# making new cascade
#
#
# OG Orders left:  74
# Cascade length:  2
# New Orders left:  72
# making new cascade
#
#
# OG Orders left:  72
# Cascade length:  7
# New Orders left:  65
# making new cascade
#
#
# OG Orders left:  65
# Cascade length:  6
# New Orders left:  59
# making new cascade
#
#
# OG Orders left:  59
# Cascade length:  21
# New Orders left:  38
# making new cascade
#
#
# OG Orders left:  38
# Cascade length:  5
# New Orders left:  33
# making new cascade
#
#
# OG Orders left:  33
# Cascade length:  7
# New Orders left:  26
# making new cascade
#
#
# OG Orders left:  26
# Cascade length:  7
# New Orders left:  19
# making new cascade
#
#
# OG Orders left:  19
# Cascade length:  2
# New Orders left:  17
# making new cascade
#
#
# OG Orders left:  17
# Cascade length:  7
# New Orders left:  10
# making new cascade
#
#
# OG Orders left:  10
# Cascade length:  7
# New Orders left:  3
# making new cascade
#
#
# OG Orders left:  3
# Cascade length:  2
# New Orders left:  1
# making new cascade
#
#
# OG Orders left:  1
# Cascade length:  1
# New Orders left:  0
# making new cascade

# %%
causalCascades12 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 2)
npcsizes12, npcnrows12, npcduration12 = cascadeAnalyzerGPU(causalCascades12, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades12_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades12, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
causalCascades11 = findCascadesGPU(TtotalOrdersNPC, traderIDsNPC, maxtimeeff = 1, maxSep = 1)
npcsizes11, npcnrows11, npcduration11 = cascadeAnalyzerGPU(causalCascades11, stockPoolNPC, t0=993, tf=5992)
with open('../causalCascades/7-9/causalCascades11_npc_1000_5000_100_2_5.pkl', 'wb') as handle:
    pickle.dump(causalCascades11, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('../causalCascades22_npc_100_7200_100_new2threshold_fixedhurst.pkl', 'rb') as handle:
#     causalCascades22 = pickle.load(handle)

# %%
npcsizes22, npcnrows22, npcduration22 = cascadeAnalyzerGPU(causalCascades22, stockPoolNPC, t0=993, tf=8192)

# %%
import numpy

# %%
#npcsizes22, npcnrows22, npcduration22
hist, bins = np.histogram(npcnrows22, bins=np.logspace(np.log10(min(npcnrows22)),np.log10(max(npcnrows22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.9)*3, '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes22, bins=np.logspace(np.log10(min(npcsizes22)),np.log10(max(npcsizes22)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration22, bins=np.logspace(np.log10(min(npcduration22)),np.log10(max(npcduration22)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration22),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*3, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff2_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes21, npcnrows21, npcduration21
hist, bins = np.histogram(npcnrows21, bins=np.logspace(np.log10(min(npcnrows21)),np.log10(max(npcnrows21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1), '-.', label= "$x^{-1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes21, bins=np.logspace(np.log10(min(npcsizes21)),np.log10(max(npcsizes21)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-0.9), '-.', label= "$x^{-0.9}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration21, bins=np.logspace(np.log10(min(npcduration21)),np.log10(max(npcduration21)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration21),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1), '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 2 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_1000_5000_100_2_5_maxeff2_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes12, npcnrows12, npcduration12
hist, bins = np.histogram(npcnrows12, bins=np.logspace(np.log10(min(npcnrows12)),np.log10(max(npcnrows12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.0)*2, '-.', label= "$x^{-1.0}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes12, bins=np.logspace(np.log10(min(npcsizes12)),np.log10(max(npcsizes12)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration12, bins=np.logspace(np.log10(min(npcduration12)),np.log10(max(npcduration12)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration12),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*5, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 2")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep2.png", dpi=250)
plt.show()
plt.close()

# %%
#npcsizes11, npcnrows11, npcduration11
hist, bins = np.histogram(npcnrows11, bins=np.logspace(np.log10(min(npcnrows11)),np.log10(max(npcnrows11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
#     print(np.array([((bins[i]+bins[i+1])/2)]))
#     avg = np.array([(bins[i]+bins[i+1])/2])
    avg = (bins[i]+bins[i+1])/2
#     print((avg.shape))
#     print((mid.shape))
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcnrows11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.2)*7, '-.', label= "$x^{-1.2}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (ntrans) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Number of transactions)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_ntrans_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcsizes11, bins=np.logspace(np.log10(min(npcsizes11)),np.log10(max(npcsizes11)),20))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)

plt.plot(mid,numpy.divide(hist,binsize)/len(npcsizes11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.1)*5, '-.', label= "$x^{-1.1}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (volume) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(S)')
plt.xlabel('Size (Volume)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_volume_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

hist, bins = np.histogram(npcduration11, bins=np.logspace(np.log10(min(npcduration11)),np.log10(max(npcduration11)),15))
binsize = np.diff(bins)

hist = np.asnumpy(hist)
bins = np.asnumpy(bins)
binsize = np.asnumpy(binsize)

mid = numpy.array([])
for i in range(len(binsize)):
    avg = (bins[i]+bins[i+1])/2
    mid = numpy.append(mid,avg)
    
plt.plot(mid,numpy.divide(hist,binsize)/len(npcduration11),'o-', linewidth = 1, markersize = 3)
plt.plot(mid,numpy.power(mid,-1.35)*3, '-.', label= "$x^{-1.35}$")
plt.loglog()
plt.legend()
plt.title("NPC Causal Cascades (duration) | Max Eff: 1 | Min Down Time: 1")
plt.ylabel('P(T)')
plt.xlabel('Duration (T)')
plt.grid(True)
plt.savefig("./results/nopricechange/7-9/npcplots/causalcascade_duration_npc_100_7200_100_new2threshold_fixedhurst_maxeff1_maxsep1.png", dpi=250)
plt.show()
plt.close()

# %%
import numpy

# %% [markdown]
# # Troubleshooting

# %%
maxSep , maxtimeeff = 2,2
TtotalOrders = TtotalOrdersNPC
cascades = {}
numCascade = 0
# while len(TtotalOrders) > 0:
#     totalTimeOrders = TtotalOrders[TtotalOrders['time']==t]
    # seed with first portfolio
print("OG Orders left: ", len(TtotalOrders))
seed = TtotalOrders['portfolio'].loc[0]
t0 = TtotalOrders['time'].loc[0]

seedCascade = findPortfOrderCascadeGPU(TtotalOrders, seed, t0, maxSep = maxSep)
cascades[numCascade] = seedCascade

# Dictionary keeping track of how long a stock is still "affected" from previous trade
stockTimes = {}

for row in np.asarray(seedCascade.index):
    row = row.item()
    stock = seedCascade['stock'].loc[row]
    time = seedCascade['time'].loc[row]
    order = seedCascade['order'].loc[row]
    if stock in stockTimes:
        stockTimes[stock] += abs(order)*maxtimeeff
    else:
        stockTimes[stock] = time + abs(order)*maxtimeeff

# check first cascade is greater than 0
assert len(seedCascade) > 0

# remove rows included in first cascade from the order list
TtotalOrders=TtotalOrders.drop(labels = seedCascade.index, axis=0)
# print(TtotalOrders)
print(seedCascade)
#PT2
#     # NEW VERSION (PORTFOLIO PERSPECTIVE)
for childPortf in (TtotalOrders['portfolio'].unique()).values_host:
    match = False

#     # see if the current portfolio has overlapping stocks with the ongoing cascade 
    if any(np.isin(cascades[numCascade]['stock'].values,np.asarray(traderIDsNPC[childPortf].stocks))):
#         # check if overlapping portfolio is already included in the ongoing cascade
        if childPortf not in cascades[numCascade]['portfolio']:
#             # include new portfolio into the cascade along with all of its cascading trading activity
            childPortfCascade = findPortfOrderCascadeGPU(TtotalOrders,childPortf,t0, maxSep = maxSep)
#             # check if trading activity falls into the time affect window of ongoing cascade
            print(childPortfCascade)
            for row in np.asarray(childPortfCascade.index):
                row = row.item()
                stock = childPortfCascade['stock'].loc[row]
                time = childPortfCascade['time'].loc[row]
                order = childPortfCascade['order'].loc[row]
                if stock in stockTimes:
                    if time <= stockTimes[stock]:
                        match = True
                        print(stock)
                        break 
            if match == True:        
#                 # add new cascade to the ongoing cascade and remove rows from the orderList
                cascades[numCascade] = pd.concat([cascades[numCascade],childPortfCascade])
#                 TtotalOrders = TtotalOrders[~TtotalOrders.isin(childPortfCascade)].dropna()
                TtotalOrders=TtotalOrders.drop(labels = childPortfCascade.index, axis=0)
#                 # add new stocks and their time affects, or extend time affects of previous stocks
                for row in np.asarray(childPortfCascade.index):
                    row = row.item()
                    stock = childPortfCascade['stock'].loc[row]
                    time = childPortfCascade['time'].loc[row]
                    order = childPortfCascade['order'].loc[row]
                    if stock in stockTimes:
                        stockTimes[stock] += abs(order)*maxtimeeff
                    else:
                        stockTimes[stock] = time + abs(order)*maxtimeeff

print("Cascade length: ",len(cascades[numCascade]))
print("New Orders left: ", len(TtotalOrders))
print("making new cascade")
print("\n")
numCascade += 1

# print(cascadeStocks)
# print(cascadePortfs)
# print(cascadeTime)
# print(cascades)
# Out:
# OG Orders left:  7088505
#       Unnamed: 0  time portfolio  stock  order
# 0              2   993     cwodj      2   -1.0
# 1              6   993     cwodj      6    1.0
# 2113           1   995     cwodj      1   -1.0
# 2114           2   995     cwodj      2   -1.0
# 2115           3   995     cwodj      3    4.0
# 2116           4   995     cwodj      4   -1.0
# 3146           1   996     cwodj      1   -1.0
#       Unnamed: 0  time portfolio  stock  order
# 1499           3   994     agibt      3    1.0
# 1500           4   994     agibt     83   -1.0
# 1501           6   994     agibt     31    1.0
# 2529           3   995     agibt      3    3.0
# 2530           6   995     agibt     31   -2.0
# 4522           3   997     agibt      3    2.0
# 6536           3   999     agibt      3   -4.0
# 6537           6   999     agibt     31    1.0
# 7576           3  1000     agibt      3   -1.0
# 7577           4  1000     agibt     83    1.0
# 3
#        Unnamed: 0  time portfolio  stock  order
# 478             2   993     ahikz     19   -1.0
# 1544            2   994     ahikz     19    1.0
# 1545            8   994     ahikz     77   -1.0
# 3562            2   996     ahikz     19   -1.0
# 4568            0   997     ahikz      1    1.0
# 4569            2   997     ahikz     19    1.0
# 4570            6   997     ahikz     51   -1.0
# 5617            4   998     ahikz     78   -1.0
# 5618            8   998     ahikz     77   -1.0
# 6588            3   999     ahikz     91    1.0
# 6589            5   999     ahikz     59    1.0
# 7637            1  1000     ahikz     66   -1.0
# 7638            8  1000     ahikz     77    1.0
# 8693            3  1001     ahikz     91   -1.0
# 9709            3  1002     ahikz     91    1.0
# 10686           0  1003     ahikz      1    1.0
# 10687           7  1003     ahikz     28    1.0
# 11690           7  1004     ahikz     28   -1.0
# 11691           8  1004     ahikz     77   -1.0
# 12791           5  1005     ahikz     59   -1.0
# 13912           1  1006     ahikz     66   -1.0
# 13913           3  1006     ahikz     91    1.0
# 13914           6  1006     ahikz     51   -1.0
# 13915           8  1006     ahikz     77    1.0
# 14962           0  1007     ahikz      1    1.0
# 14963           1  1007     ahikz     66    1.0
# 14964           2  1007     ahikz     19    1.0
# 14965           3  1007     ahikz     91   -1.0
# 14966           8  1007     ahikz     77   -1.0
# 16010           0  1008     ahikz      1    1.0
# 16011           1  1008     ahikz     66   -1.0
# 16012           2  1008     ahikz     19   -1.0
# 16013           4  1008     ahikz     78    1.0
# 16961           0  1009     ahikz      1    1.0
# 16962           7  1009     ahikz     28    1.0
# 17957           7  1010     ahikz     28   -1.0
# 18978           3  1011     ahikz     91    1.0
# 18979           5  1011     ahikz     59   -1.0
# 18980           7  1011     ahikz     28    1.0
# 21125           2  1013     ahikz     19   -1.0
# 22213           3  1014     ahikz     91   -1.0
# 22214           4  1014     ahikz     78    1.0
# 23281           3  1015     ahikz     91    1.0
# 23282           6  1015     ahikz     51    1.0
# 23283           7  1015     ahikz     28   -1.0
# 1
#       Unnamed: 0  time portfolio  stock  order
# 2081           0   994     ahxwz     88    8.0
# 2082           2   994     ahxwz     99  -22.0
# 2083           3   994     ahxwz     75  -17.0
# 2084           4   994     ahxwz     20    6.0
# 2085           7   994     ahxwz     57  -19.0
# 2086           8   994     ahxwz     28    9.0
# 2087           9   994     ahxwz     15   16.0
# 28
#         Unnamed: 0  time portfolio  stock  order
# 1241             2   994     aildg     14   -1.0
# 1242             3   994     aildg     99   -2.0
# 1243             4   994     aildg     20    1.0
# 1244             8   994     aildg     24    2.0
# 1245             9   994     aildg     86   -1.0
# ...            ...   ...       ...    ...    ...
# 110637           4  1097     aildg     20    1.0
# 110638           8  1097     aildg     24   -1.0
# 110639           9  1097     aildg     86   -1.0
# 111663           7  1098     aildg      3   -1.0
# 111664           8  1098     aildg     24    1.0
#
# [358 rows x 5 columns]
# 99
#       Unnamed: 0  time portfolio  stock  order
# 629            2   993     aiosw     60   -9.0
# 630            4   993     aiosw     11   12.0
# 631            6   993     aiosw     90    5.0
# 1703           2   994     aiosw     60    2.0
# 1704           5   994     aiosw     88    5.0
# 1705           6   994     aiosw     90   -3.0
# 3714           2   996     aiosw     60    5.0
# 3715           4   996     aiosw     11    7.0
# 3716           5   996     aiosw     88    9.0
# 3717           6   996     aiosw     90  -12.0
# 4711           2   997     aiosw     60    1.0
# 4712           4   997     aiosw     11    2.0
# 4713           5   997     aiosw     88    4.0
# 4714           6   997     aiosw     90   -3.0
# 5773           4   998     aiosw     11   -4.0
# 5774           5   998     aiosw     88    9.0
# 5775           6   998     aiosw     90   -1.0
# 88
#       Unnamed: 0  time portfolio  stock  order
# 1015           2   993     aivyz     83   -9.0
# 1016           3   993     aivyz     86    1.0
# 1017           6   993     aivyz     95   -4.0
# 1018           7   993     aivyz     24   11.0
# 1019           8   993     aivyz     45    3.0
# 1020           9   993     aivyz     33    3.0
# 2010           0   994     aivyz      1   -5.0
# 2011           2   994     aivyz     83    1.0
# 2012           3   994     aivyz     86   -4.0
# 2013           6   994     aivyz     95   -1.0
# 2014           7   994     aivyz     24    6.0
# 2015           8   994     aivyz     45    8.0
# 2016           9   994     aivyz     33   -5.0
# 3072           0   995     aivyz      1    1.0
# 3073           2   995     aivyz     83    1.0
# 3074           3   995     aivyz     86    6.0
# 3075           6   995     aivyz     95   -2.0
# 3076           7   995     aivyz     24    4.0
# 3077           8   995     aivyz     45   -4.0
# 3078           9   995     aivyz     33   -2.0
# 3996           0   996     aivyz      1   -1.0
# 3997           2   996     aivyz     83    5.0
# 3998           3   996     aivyz     86   -5.0
# 3999           6   996     aivyz     95   -5.0
# 4000           7   996     aivyz     24    7.0
# 4001           8   996     aivyz     45   -1.0
# 4002           9   996     aivyz     33   -2.0
# 5069           0   997     aivyz      1   11.0
# 5070           2   997     aivyz     83   -8.0
# 5071           3   997     aivyz     86    3.0
# 5072           6   997     aivyz     95    1.0
# 5073           8   997     aivyz     45   -4.0
# 5074           9   997     aivyz     33    4.0
# 6071           0   998     aivyz      1   -1.0
# 6072           2   998     aivyz     83    1.0
# 6073           3   998     aivyz     86    9.0
# 6074           6   998     aivyz     95    1.0
# 6075           7   998     aivyz     24   -5.0
# 6076           8   998     aivyz     45    1.0
# 6077           9   998     aivyz     33   -6.0
# 8156           0  1000     aivyz      1   -2.0
# 8157           2  1000     aivyz     83   -4.0
# 8158           3  1000     aivyz     86    9.0
# 8159           8  1000     aivyz     45    2.0
# 9204           0  1001     aivyz      1    7.0
# 9205           2  1001     aivyz     83   -2.0
# 9206           3  1001     aivyz     86    1.0
# 9207           6  1001     aivyz     95    2.0
# 9208           7  1001     aivyz     24    6.0
# 9209           8  1001     aivyz     45   -5.0
# 9210           9  1001     aivyz     33   -3.0
# 83
#        Unnamed: 0  time portfolio  stock  order
# 1037            8   993     aiytj     40    3.0
# 2041            0   994     aiytj     98    1.0
# 2042            1   994     aiytj     53    1.0
# 2043            2   994     aiytj     19    1.0
# 2044            5   994     aiytj     13   -2.0
# 2045            8   994     aiytj     40   -1.0
# 3091            0   995     aiytj     98    1.0
# 3092            2   995     aiytj     19   -1.0
# 3093            5   995     aiytj     13   -1.0
# 3094            8   995     aiytj     40    1.0
# 5098            1   997     aiytj     53   -1.0
# 5099            2   997     aiytj     19    1.0
# 5100            5   997     aiytj     13    1.0
# 5101            8   997     aiytj     40   -1.0
# 6097            0   998     aiytj     98   -2.0
# 6098            1   998     aiytj     53   -2.0
# 6099            2   998     aiytj     19    1.0
# 6100            5   998     aiytj     13    1.0
# 6101            8   998     aiytj     40   -1.0
# 7074            5   999     aiytj     13    1.0
# 8170            1  1000     aiytj     53   -2.0
# 8171            2  1000     aiytj     19   -1.0
# 8172            5  1000     aiytj     13    2.0
# 9225            5  1001     aiytj     13    1.0
# 9226            8  1001     aiytj     40   -1.0
# 11155           1  1003     aiytj     53   -1.0
# 11156           8  1003     aiytj     40   -1.0
# 12229           8  1004     aiytj     40    1.0
# 13363           1  1005     aiytj     53   -1.0
# 13364           2  1005     aiytj     19   -1.0
# 13365           5  1005     aiytj     13    1.0
# 13366           8  1005     aiytj     40   -1.0
# 14442           1  1006     aiytj     53   -2.0
# 14443           5  1006     aiytj     13    2.0
# 14444           8  1006     aiytj     40   -1.0
# 15482           2  1007     aiytj     19    1.0
# 15483           5  1007     aiytj     13   -1.0
# 15484           8  1007     aiytj     40    1.0
# 16541           1  1008     aiytj     53    1.0
# 16542           2  1008     aiytj     19   -1.0
# 16543           5  1008     aiytj     13    1.0
# 16544           8  1008     aiytj     40   -1.0
# 17465           8  1009     aiytj     40   -1.0
# 18443           5  1010     aiytj     13    1.0
# 19482           1  1011     aiytj     53    1.0
# 19483           2  1011     aiytj     19   -1.0
# 19484           8  1011     aiytj     40    1.0
# 21678           1  1013     aiytj     53   -2.0
# 21679           2  1013     aiytj     19   -1.0
# 21680           5  1013     aiytj     13    2.0
# 21681           8  1013     aiytj     40   -1.0
# 22777           1  1014     aiytj     53   -1.0
# 22778           2  1014     aiytj     19   -1.0
# 22779           5  1014     aiytj     13    2.0
# 19
#        Unnamed: 0  time portfolio  stock  order
# 330             0   993     ajpet     51  -10.0
# 331             3   993     ajpet     24   10.0
# 332             4   993     ajpet     18    8.0
# 333             6   993     ajpet     54   -1.0
# 334             7   993     ajpet     91   -1.0
# 335             8   993     ajpet     43    1.0
# 1446            0   994     ajpet     51    2.0
# 1447            2   994     ajpet     88    5.0
# 1448            3   994     ajpet     24    7.0
# 1449            6   994     ajpet     54   -9.0
# 1450            7   994     ajpet     91   -4.0
# 1451            8   994     ajpet     43    3.0
# 3422            0   996     ajpet     51   -6.0
# 3423            2   996     ajpet     88    7.0
# 3424            3   996     ajpet     24   10.0
# 3425            4   996     ajpet     18   -6.0
# 3426            6   996     ajpet     54   -7.0
# 3427            7   996     ajpet     91    1.0
# 3428            8   996     ajpet     43    5.0
# 5491            0   998     ajpet     51   -5.0
# 5492            2   998     ajpet     88   13.0
# 5493            3   998     ajpet     24   -5.0
# 5494            4   998     ajpet     18   -3.0
# 5495            6   998     ajpet     54  -14.0
# 5496            7   998     ajpet     91   12.0
# 5497            8   998     ajpet     43    5.0
# 6466            0   999     ajpet     51    3.0
# 6467            2   999     ajpet     88   -6.0
# 6468            3   999     ajpet     24   -1.0
# 6469            7   999     ajpet     91    4.0
# 6470            8   999     ajpet     43   -2.0
# 7469            0  1000     ajpet     51    6.0
# 7470            3  1000     ajpet     24    1.0
# 7471            4  1000     ajpet     18   -2.0
# 7472            6  1000     ajpet     54   -1.0
# 7473            7  1000     ajpet     91    3.0
# 7474            8  1000     ajpet     43   -4.0
# 8560            0  1001     ajpet     51   -6.0
# 8561            3  1001     ajpet     24    6.0
# 8562            4  1001     ajpet     18   -7.0
# 8563            6  1001     ajpet     54    7.0
# 8564            8  1001     ajpet     43    2.0
# 10579           0  1003     ajpet     51  -16.0
# 10580           2  1003     ajpet     88    2.0
# 10581           3  1003     ajpet     24   14.0
# 10582           4  1003     ajpet     18   -1.0
# 10583           6  1003     ajpet     54   -5.0
# 10584           7  1003     ajpet     91    1.0
# 10585           8  1003     ajpet     43    9.0
# 51
#       Unnamed: 0  time portfolio  stock  order
# 943            1   993     ajzws      6    2.0
# 944            3   993     ajzws     36   -4.0
# 945            5   993     ajzws     13   -1.0
# 946            6   993     ajzws     50    2.0
# 947            8   993     ajzws     59    5.0
# 948            9   993     ajzws     54   -2.0
# 1957           0   994     ajzws      4    3.0
# 1958           1   994     ajzws      6    2.0
# 1959           3   994     ajzws     36    1.0
# 1960           5   994     ajzws     13   -7.0
# 1961           6   994     ajzws     50    6.0
# 1962           8   994     ajzws     59   -1.0
# 1963           9   994     ajzws     54   -5.0
# 2997           0   995     ajzws      4   -4.0
# 2998           1   995     ajzws      6    1.0
# 2999           3   995     ajzws     36    1.0
# 3000           5   995     ajzws     13   -3.0
# 3001           6   995     ajzws     50    4.0
# 3002           8   995     ajzws     59    2.0
# 3003           9   995     ajzws     54    1.0
# 3938           1   996     ajzws      6    1.0
# 3939           3   996     ajzws     36    2.0
# 3940           5   996     ajzws     13   -3.0
# 3941           6   996     ajzws     50    2.0
# 3942           8   996     ajzws     59    1.0
# 3943           9   996     ajzws     54   -4.0
# 5010           0   997     ajzws      4    2.0
# 5011           1   997     ajzws      6    1.0
# 5012           3   997     ajzws     36   -4.0
# 5013           5   997     ajzws     13    5.0
# 5014           6   997     ajzws     50    3.0
# 5015           8   997     ajzws     59    2.0
# 5016           9   997     ajzws     54  -11.0
# 6991           1   999     ajzws      6   -4.0
# 6992           5   999     ajzws     13    9.0
# 6993           6   999     ajzws     50   -8.0
# 6994           8   999     ajzws     59    4.0
# 6995           9   999     ajzws     54   -6.0
# 9136           1  1001     ajzws      6   -4.0
# 9137           3  1001     ajzws     36   -9.0
# 9138           5  1001     ajzws     13   11.0
# 9139           8  1001     ajzws     59    4.0
# 9140           9  1001     ajzws     54   -3.0
# 6
#      Unnamed: 0  time portfolio  stock  order
# 579           0   993     akbpz     24   36.0
# 580           1   993     akbpz     72   16.0
# 581           4   993     akbpz     35   -6.0
# 582           6   993     akbpz     95  -18.0
# 583           7   993     akbpz     14  -25.0
# 24
#       Unnamed: 0  time portfolio  stock  order
# 34             0   993     akupo     35   -2.0
# 35             1   993     akupo     36   -8.0
# 36             5   993     akupo     40    7.0
# 37             6   993     akupo     41    3.0
# 38             8   993     akupo     43    1.0
# 39            10   993     akupo     45    3.0
# 2154           0   995     akupo     35   12.0
# 2155           1   995     akupo     36  -12.0
# 2156           6   995     akupo     41    3.0
# 2157           8   995     akupo     43    2.0
# 2158          10   995     akupo     45    4.0
# 3187           0   996     akupo     35   -1.0
# 3188           5   996     akupo     40   -6.0
# 3189           6   996     akupo     41    1.0
# 3190           8   996     akupo     43    4.0
# 3191          10   996     akupo     45   -2.0
# 35
#       Unnamed: 0  time portfolio  stock  order
# 1290           1   994     alhow     86    4.0
# 1291           2   994     alhow      2    3.0
# 1292           6   994     alhow     60   -4.0
# 86
#       Unnamed: 0  time portfolio  stock  order
# 2964           0   995     amwnt     32  -17.0
# 2965           1   995     amwnt     78   -2.0
# 2966           4   995     amwnt     72   10.0
# 2967           8   995     amwnt     74   -9.0
# 2968           9   995     amwnt      3   16.0
# 3912           0   996     amwnt     32   -7.0
# 3913           4   996     amwnt     72   -2.0
# 3914           5   996     amwnt     66    2.0
# 3915           8   996     amwnt     74    6.0
# 3916           9   996     amwnt      3    2.0
# 5993           0   998     amwnt     32   13.0
# 5994           1   998     amwnt     78   -8.0
# 5995           4   998     amwnt     72    4.0
# 5996           5   998     amwnt     66    1.0
# 5997           9   998     amwnt      3   -8.0
# 6956           0   999     amwnt     32   -3.0
# 6957           1   999     amwnt     78    1.0
# 9090           0  1001     amwnt     32    4.0
# 9091           1  1001     amwnt     78   -5.0
# 9092           4  1001     amwnt     72    8.0
# 9093           5  1001     amwnt     66   -9.0
# 9094           8  1001     amwnt     74    8.0
# 9095           9  1001     amwnt      3   -6.0
# 78
#       Unnamed: 0  time portfolio  stock  order
# 2765           1   995     aocgl     53  -12.0
# 2766           2   995     aocgl     10   20.0
# 2767           3   995     aocgl     68   -6.0
# 2768           7   995     aocgl     33  -12.0
# 3767           1   996     aocgl     53   -6.0
# 3768           2   996     aocgl     10   12.0
# 3769           3   996     aocgl     68   -8.0
# 3770           7   996     aocgl     33   -3.0
# 53
#       Unnamed: 0  time portfolio  stock  order
# 1409           1   994     aocir     54   -6.0
# 1410           2   994     aocir     55  -14.0
# 1411           3   994     aocir     25   -5.0
# 1412           4   994     aocir     24   42.0
# 1413           7   994     aocir      2   13.0
# 54
#       Unnamed: 0  time portfolio  stock  order
# 140            0   993     aomzg     57   -1.0
# 141            3   993     aomzg     59    1.0
# 1256           2   994     aomzg     77   -1.0
# 2259           0   995     aomzg     57    1.0
# 2260           1   995     aomzg     53    1.0
# 2261           6   995     aomzg     88    1.0
# 2262           7   995     aomzg     73   -1.0
# 3290           1   996     aomzg     53   -1.0
# 3291           2   996     aomzg     77   -1.0
# 3292           6   996     aomzg     88    1.0
# 4241           0   997     aomzg     57   -1.0
# 4242           3   997     aomzg     59    1.0
# 4243           7   997     aomzg     73    1.0
# 57
#       Unnamed: 0  time portfolio  stock  order
# 716            2   993     aovfh     15    1.0
# 717            6   993     aovfh     20    1.0
# 718            7   993     aovfh     66   -2.0
# 1767           2   994     aovfh     15    1.0
# 1768           7   994     aovfh     66   -2.0
# 2771           2   995     aovfh     15   -1.0
# 2772           3   995     aovfh     35    2.0
# 3774           2   996     aovfh     15   -1.0
# 3775           6   996     aovfh     20   -1.0
# 3776           7   996     aovfh     66    2.0
# 4775           6   997     aovfh     20    1.0
# 15
#        Unnamed: 0  time portfolio  stock  order
# 76              0   993     apxte     15    1.0
# 77              1   993     apxte     30    1.0
# 78              3   993     apxte     43    1.0
# 79              7   993     apxte     32   -3.0
# 80              8   993     apxte     56   -1.0
# ...           ...   ...       ...    ...    ...
# 86483           0  1075     apxte     15   -1.0
# 86484           1  1075     apxte     30   -1.0
# 86485           3  1075     apxte     43    1.0
# 87632           3  1076     apxte     43    1.0
# 87633           7  1076     apxte     32    1.0
#
# [241 rows x 5 columns]
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-caca55f2abb3> in <module>
#      64                 for row in np.asarray(childPortfCascade.index):
#      65                     row = row.item()
# ---> 66                     stock = childPortfCascade['stock'].loc[row]
#      67                     time = childPortfCascade['time'].loc[row]
#      68                     order = childPortfCascade['order'].loc[row]
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in __getitem__(self, arg)
#     114     def __getitem__(self, arg):
#     115         try:
# --> 116             arg = self._loc_to_iloc(arg)
#     117         except (TypeError, KeyError, IndexError, ValueError):
#     118             raise IndexError("Failed to convert index to appropirate row")
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/indexing.py in _loc_to_iloc(self, arg)
#     134             try:
#     135                 found_index = self._sr.index._values.find_first_value(
# --> 136                     arg, closest=False
#     137                 )
#     138                 return found_index
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_first_value(self, value, closest)
#     454         if len(self):
#     455             found = cudautils.find_first(
# --> 456                 self.data_array_view, value, mask=self.mask
#     457             )
#     458         if found == -1 and self.is_monotonic and closest:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/cudautils.py in find_first(arr, val, mask, compare)
#     184
#     185     found_col = find_index_of_val(arr, val, mask=mask, compare=compare)
# --> 186     found_col = found_col.find_and_replace([arr.size], [None], True)
#     187
#     188     min_index = found_col.min()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in find_and_replace(self, to_replace, replacement, all_nan)
#     398         """
#     399         to_replace_col = _normalize_find_and_replace_input(
# --> 400             self.dtype, to_replace
#     401         )
#     402         if all_nan:
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/numerical.py in _normalize_find_and_replace_input(input_column_dtype, col_to_normalize)
#     607     if isinstance(col_to_normalize, list):
#     608         col_to_normalize_dtype = min_column_type(
# --> 609             normalized_column, input_column_dtype
#     610         )
#     611         # Scalar case
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in min_column_type(x, expected_type)
#     432
#     433     if np.issubdtype(expected_type, np.integer):
# --> 434         max_bound_dtype = np.min_scalar_type(x.max())
#     435         min_bound_dtype = np.min_scalar_type(x.min())
#     436         return np.promote_types(max_bound_dtype, min_bound_dtype)
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/core/column/column.py in max(self, skipna, dtype)
#    1143         result_col = self._process_for_reduction(skipna=skipna)
#    1144         if isinstance(result_col, ColumnBase):
# -> 1145             return libcudf.reduce.reduce("max", result_col, dtype=dtype)
#    1146         else:
#    1147             return result_col
#
# cudf/_lib/reduce.pyx in cudf._lib.reduce.reduce()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column.view()
#
# cudf/_lib/column.pyx in cudf._lib.column.Column._view()
#
# ~/anaconda3/envs/rapids-0.16/lib/python3.7/site-packages/cudf/utils/dtypes.py in is_struct_dtype(obj)
#     198         # or type(obj) is cudf.core.column.StructColumn
#     199         # or obj is cudf.core.column.StructColumn
# --> 200         or (isinstance(obj, str) and obj == cudf.core.dtypes.StructDtype.name)
#     201         or (hasattr(obj, "dtype") and is_struct_dtype(obj.dtype))
#     202     )
#
# KeyboardInterrupt:

# %%
seed = TtotalOrders['portfolio'].iloc[0]
t0 = TtotalOrders['time'].iloc[0]

# %%
TtotalOrders
# Out:
#          Unnamed: 0  time portfolio  stock  order
# 41                9   993     zjwdk     51   -2.0
# 69                2   993     ztnkc     15    1.0
# 70                4   993     ztnkc     60   -1.0
# 71                7   993     ztnkc     95   -1.0
# 262               3   993     zdmkf     98    9.0
# ...             ...   ...       ...    ...    ...
# 7088500           2  8192     gnqpm     56  -25.0
# 7088501           3  8192     gnqpm     55   10.0
# 7088502           5  8192     gnqpm     79    2.0
# 7088503           6  8192     gnqpm     85   19.0
# 7088504           7  8192     gnqpm     76   21.0
#
# [7056036 rows x 5 columns]

# %%
portfOrders = TtotalOrdersNPC[TtotalOrdersNPC['portfolio']=='cwodj']
portfOrders = portfOrders[portfOrders['time']>=993]
if len(portfOrders)>0:
    ToS = portfOrders['time'].unique()
#     print(ToS)
    sep = np.diff(ToS)
#     print(sep[:13])
#     print(max(sep))
    keySep = np.where(sep>2)[0]
#     print(keySep[:10])
    if len(keySep)>0:
        endtime = int(ToS.take(int(keySep[0]))) #end of this cascade
#         print(endtime)
#         print(ToS)
    else:
        endtime = int(ToS.take(-1))
    
    print("\n ENDTIME: ",(endtime))
    print(type(ToS))
    print(endtime, type(endtime))
#     print(type((endtime[int(keySep[0])])))
portfCascade = portfOrders.loc[portfOrders['time']<=(endtime)]
# Out:
#  ENDTIME:  996
# <class 'cudf.core.series.Series'>
# 996 <class 'int'>

# %%
portfs = (TtotalOrders['portfolio'].unique()).values_host
# portfs.values_host

# %%
(seedCascade['stock'].loc[0]).item()
# Out:
# 2

# %%
if childPortf in cascades[numCascade]['portfolio']
# Out:
# False

# %%
traderIDsNPC['gnqpm'].stocks
# Out:
# array([43, 26, 56, 55,  0, 79, 85, 76, 74])

# %%
type(np.asarray(seedCascade.index))
# Out:
# cupy.core.core.ndarray

# %%
a = pd.concat([seedCascade, seedCascade])

# %%
TtotalOrders.loc[TtotalOrders['time']<=993]
# Out:
#       Unnamed: 0  time portfolio  stock  order
# 2              2   993     gozxi      6   -1.0
# 3              6   993     gozxi     10    2.0
# 4              7   993     gozxi     11    1.0
# 5              9   993     gozxi     13   -1.0
# 6             10   993     gozxi     14   -2.0
# ...          ...   ...       ...    ...    ...
# 1081           7   993     zwjtq     55   -2.0
# 1082           0   993     myduz     56   14.0
# 1083           1   993     myduz     55  -18.0
# 1084           4   993     myduz     85   38.0
# 1085           6   993     myduz     74  -14.0
#
# [1040 rows x 5 columns]
